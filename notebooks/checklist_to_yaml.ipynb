# %% [markdown]
# Goal: Write a YAML file birding checklist for a particular region using the eBird API.

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from birding.ebird_api import get_ebird_api_key

ebird_api_key = get_ebird_api_key()

# %%
regions = ["Minneapolis, Minnesota, United States", "Minnesota, US"]

# %%
from birding.geocoding import find_coordinate
from birding.sqlite_cache import init_db

init_db()
region_coords = [find_coordinate(region) for region in regions]
region_coords
# Out:
# Geocode for query 'Minneapolis, Minnesota, United States' was already cached.
# Geocode for query 'Minnesota, US' was already cached.
# [Coordinate(latitude=44.9772995, longitude=-93.2654692),
#  Coordinate(latitude=45.9896587, longitude=-94.6113288)]

# %%
from birding.ebird_api import find_nearest_hotspot

region_coords = [c for c in region_coords if c is not None]

nearest_hotspots = [find_nearest_hotspot(coord) for coord in region_coords]
nearest_hotspots
# Out:
# Nearby hotspots for (44.9773, -93.2655) were already cached.
# Nearby hotspots for (44.9773, -93.2655) were already cached.
# Nearby hotspots for (45.9897, -94.6113) were already cached.
# Nearby hotspots for (45.9897, -94.6113) were already cached.
# [EBirdHotspot(location=EBirdLocation(id='L19287778', name='Government Center Park', coord=Coordinate(latitude=44.9751968, longitude=-93.2672095), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=60),
#  EBirdHotspot(location=EBirdLocation(id='L470477', name='Irish Creek — MN 27, 0.2 mi E of Todd Co. line', coord=Coordinate(latitude=45.9767038, longitude=-94.6418183), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-097', subnat2_name=None), all_time_species=34)]

# %%
from birding.ebird_api import find_ebird_region_code

init_db()
region_codes = [find_ebird_region_code(r, c) for r, c in zip(regions, region_coords, strict=True)]
region_codes
# Out:
# Nearby hotspots for (44.9773, -93.2655) were already cached.
# Nearby hotspots for (44.9773, -93.2655) were already cached.
# Region information for code 'US' was already cached.
# Region information for code 'US-MN' was already cached.
# Region information for code 'US-MN-053' was already cached.
# Nearby hotspots for (45.9897, -94.6113) were already cached.
# Nearby hotspots for (45.9897, -94.6113) were already cached.
# Region information for code 'US' was already cached.
# Region information for code 'US-MN' was already cached.
# Region information for code 'US-MN-097' was already cached.
# ['US-MN-053', 'US-MN']

# %%
from birding.ebird_api import retrieve_hotspots_in_region

recent_hotspots = [retrieve_hotspots_in_region(code) for code in region_codes]
for region, hotspot_list in zip(regions, recent_hotspots, strict=True):
    print(f"Found {len(hotspot_list)} active hotspots in the region '{region}'.")

recent_hotspots
# Out:
# eBird hotspots in region 'US-MN-053' were already cached.
# eBird hotspots in region 'US-MN' were already cached.
# Found 330 active hotspots in the region 'Minneapolis, Minnesota, United States'.
# Found 4653 active hotspots in the region 'Minnesota, US'.
# [[EBirdHotspot(location=EBirdLocation(id='L29366351', name='Adeline Nature Area/Schaper Park', coord=Coordinate(latitude=44.988003, longitude=-93.343572), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=131),
#   EBirdHotspot(location=EBirdLocation(id='L3916966', name='Anderson Lakes Park Reserve', coord=Coordinate(latitude=44.8376362, longitude=-93.4020925), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=165),
#   EBirdHotspot(location=EBirdLocation(id='L26443662', name='Arbor Lake', coord=Coordinate(latitude=45.0969682, longitude=-93.4387228), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=62),
#   EBirdHotspot(location=EBirdLocation(id='L7156530', name='Arden Park', coord=Coordinate(latitude=44.9073426, longitude=-93.3345544), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=153),
#   EBirdHotspot(location=EBirdLocation(id='L26789547', name='Audubon Park', coord=Coordinate(latitude=45.0199958, longitude=-93.239859), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=35),
#   EBirdHotspot(location=EBirdLocation(id='L632581', name='Auto Club Park (Formerly Isaak Walton Club Park)', coord=Coordinate(latitude=44.7924041, longitude=-93.3689833), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=138),
#   EBirdHotspot(location=EBirdLocation(id='L256147', name='Baker Park Reserve', coord=Coordinate(latitude=45.007191, longitude=-93.6157503), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=211),
#   EBirdHotspot(location=EBirdLocation(id='L28094377', name='Bass Creek Park', coord=Coordinate(latitude=45.0756269, longitude=-93.3928227), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=15),
#   EBirdHotspot(location=EBirdLocation(id='L4377497', name='Bass Lake Preserve', coord=Coordinate(latitude=44.9401216, longitude=-93.3361638), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=180),
#   EBirdHotspot(location=EBirdLocation(id='L1252506', name='Bassett Creek Park', coord=Coordinate(latitude=45.0120254, longitude=-93.35392), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=146),
#   EBirdHotspot(location=EBirdLocation(id='L1430669', name='Bassett Creek--Mallard Creek Apartments', coord=Coordinate(latitude=44.987672, longitude=-93.3874592), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=61),
#   EBirdHotspot(location=EBirdLocation(id='L6961177', name="Bassett's Creek Park", coord=Coordinate(latitude=44.979371, longitude=-93.3111763), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=121),
#   EBirdHotspot(location=EBirdLocation(id='L7185545', name="Bassett's Creek Playground", coord=Coordinate(latitude=44.9784829, longitude=-93.313058), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=121),
#   EBirdHotspot(location=EBirdLocation(id='L28031212', name='Basswood Park', coord=Coordinate(latitude=45.0735886, longitude=-93.4754035), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=1),
#   EBirdHotspot(location=EBirdLocation(id='L358400', name='Bde Maka Ska', coord=Coordinate(latitude=44.9411696, longitude=-93.3118629), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=191),
#   EBirdHotspot(location=EBirdLocation(id='L2026894', name='Beards Plaisance', coord=Coordinate(latitude=44.92072, longitude=-93.31354), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=99),
#   EBirdHotspot(location=EBirdLocation(id='L17972514', name='Bechtold Road', coord=Coordinate(latitude=45.1284523, longitude=-93.6051838), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=94),
#   EBirdHotspot(location=EBirdLocation(id='L1334722', name='Berry Park', coord=Coordinate(latitude=44.9323666, longitude=-93.3102936), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=101),
#   EBirdHotspot(location=EBirdLocation(id='L652066', name='Big Willow Park', coord=Coordinate(latitude=44.9447691, longitude=-93.434397), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=148),
#   EBirdHotspot(location=EBirdLocation(id='L4678233', name='Birch Island Woods', coord=Coordinate(latitude=44.8861095, longitude=-93.4631975), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=138),
#   EBirdHotspot(location=EBirdLocation(id='L9541439', name='Bloomington Off-leash Dog Park', coord=Coordinate(latitude=44.8092782, longitude=-93.3728359), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=105),
#   EBirdHotspot(location=EBirdLocation(id='L9894450', name='Bohemian Flats Park', coord=Coordinate(latitude=44.97523, longitude=-93.240831), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=72),
#   EBirdHotspot(location=EBirdLocation(id='L1497885', name='Boom Island Park', coord=Coordinate(latitude=44.9912583, longitude=-93.2670888), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=150),
#   EBirdHotspot(location=EBirdLocation(id='L11344241', name='Boundary Creek Park', coord=Coordinate(latitude=45.1465556, longitude=-93.4098243), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=90),
#   EBirdHotspot(location=EBirdLocation(id='L5898544', name='Braemar Golf Course', coord=Coordinate(latitude=44.868252, longitude=-93.386768), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=81),
#   EBirdHotspot(location=EBirdLocation(id='L653355', name='Bredesen Park', coord=Coordinate(latitude=44.8953734, longitude=-93.3806562), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=167),
#   EBirdHotspot(location=EBirdLocation(id='L24479870', name='Briarwood Nature Area', coord=Coordinate(latitude=45.0066726, longitude=-93.3474094), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=78),
#   EBirdHotspot(location=EBirdLocation(id='L16420448', name='Brookdale Park', coord=Coordinate(latitude=45.0928228, longitude=-93.3338785), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=129),
#   EBirdHotspot(location=EBirdLocation(id='L12887575', name='Brooklyn Park Environmental Nature Area', coord=Coordinate(latitude=45.1390063, longitude=-93.3162403), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=140),
#   EBirdHotspot(location=EBirdLocation(id='L15827649', name='Brookview Park', coord=Coordinate(latitude=44.9798228, longitude=-93.3814963), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=113),
#   EBirdHotspot(location=EBirdLocation(id='L2952748', name='Brownie Lake', coord=Coordinate(latitude=44.9668, longitude=-93.32446), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=79),
#   EBirdHotspot(location=EBirdLocation(id='L5629679', name='Bryant Lake Regional Park', coord=Coordinate(latitude=44.8814608, longitude=-93.4280078), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=157),
#   EBirdHotspot(location=EBirdLocation(id='L12287906', name='Burwell Park', coord=Coordinate(latitude=44.9415841, longitude=-93.4502526), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=51),
#   EBirdHotspot(location=EBirdLocation(id='L1170565', name='Bush Lake--East Bush Lake Rd', coord=Coordinate(latitude=44.8307023, longitude=-93.3776039), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=159),
#   EBirdHotspot(location=EBirdLocation(id='L6516372', name='Cancer Survivors Park', coord=Coordinate(latitude=44.9810861, longitude=-93.2682502), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=45),
#   EBirdHotspot(location=EBirdLocation(id='L6068057', name='Cardinal Creek Nature Trail', coord=Coordinate(latitude=44.8794714, longitude=-93.4423363), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=81),
#   EBirdHotspot(location=EBirdLocation(id='L9174481', name='Carmel Park', coord=Coordinate(latitude=44.8894867, longitude=-93.4249556), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=119),
#   EBirdHotspot(location=EBirdLocation(id='L24722324', name='Cedar Hills Park', coord=Coordinate(latitude=44.830225, longitude=-93.4865606), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=129),
#   EBirdHotspot(location=EBirdLocation(id='L361513', name='Cedar Lake', coord=Coordinate(latitude=44.9603646, longitude=-93.3207035), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=176),
#   EBirdHotspot(location=EBirdLocation(id='L4379668', name='Cedar Manor Lake Park', coord=Coordinate(latitude=44.9564471, longitude=-93.3983052), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=51),
#   EBirdHotspot(location=EBirdLocation(id='L6438733', name='Cedar Meadows Wetland', coord=Coordinate(latitude=44.9553311, longitude=-93.3285141), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=120),
#   EBirdHotspot(location=EBirdLocation(id='L1910131', name='Centennial Lakes Park', coord=Coordinate(latitude=44.8671492, longitude=-93.3259606), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=73),
#   EBirdHotspot(location=EBirdLocation(id='L13136475', name='Centennial Park', coord=Coordinate(latitude=45.0698837, longitude=-93.3114767), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=63),
#   EBirdHotspot(location=EBirdLocation(id='L1046071', name='Central Park (Bloomington)', coord=Coordinate(latitude=44.8127407, longitude=-93.3023229), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=142),
#   EBirdHotspot(location=EBirdLocation(id='L6824673', name='Central Park of Maple Grove', coord=Coordinate(latitude=45.1030045, longitude=-93.4318392), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=145),
#   EBirdHotspot(location=EBirdLocation(id='L356343', name='Clifton French Regional Park', coord=Coordinate(latitude=45.02076, longitude=-93.43516), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=223),
#   EBirdHotspot(location=EBirdLocation(id='L18894981', name='Cloquet Overlook Park', coord=Coordinate(latitude=45.219648, longitude=-93.459233), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=127),
#   EBirdHotspot(location=EBirdLocation(id='L2232032', name='Coldwater Spring', coord=Coordinate(latitude=44.9000274, longitude=-93.1963938), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=170),
#   EBirdHotspot(location=EBirdLocation(id='L3579152', name='Colman Lake Trail', coord=Coordinate(latitude=44.7919402, longitude=-93.3369899), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=194),
#   EBirdHotspot(location=EBirdLocation(id='L2299177', name='Como Student Cooperative', coord=Coordinate(latitude=44.9894864, longitude=-93.2140535), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=89),
#   EBirdHotspot(location=EBirdLocation(id='L9258133', name='Cortlawn Pond', coord=Coordinate(latitude=44.975537, longitude=-93.364801), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=107),
#   EBirdHotspot(location=EBirdLocation(id='L5720614', name='Countryside Park', coord=Coordinate(latitude=44.89033, longitude=-93.3711382), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=75),
#   EBirdHotspot(location=EBirdLocation(id='L810306', name='Crane Lake', coord=Coordinate(latitude=44.9681986, longitude=-93.4287643), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=82),
#   EBirdHotspot(location=EBirdLocation(id='L368230', name='Crow-Hassan Park Reserve', coord=Coordinate(latitude=45.1886913, longitude=-93.6407661), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=230),
#   EBirdHotspot(location=EBirdLocation(id='L22905809', name='Crystal Lake, Robbinsdale', coord=Coordinate(latitude=45.025735, longitude=-93.328572), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=67),
#   EBirdHotspot(location=EBirdLocation(id='L17411423', name="Curt Rawn's Grave", coord=Coordinate(latitude=45.0145981, longitude=-93.2173449), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=51),
#   EBirdHotspot(location=EBirdLocation(id='L5658893', name='Dakota Rail Trail--Crystal Bay', coord=Coordinate(latitude=44.9387505, longitude=-93.6070991), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=55),
#   EBirdHotspot(location=EBirdLocation(id='L26787995', name='Deming Heights Park', coord=Coordinate(latitude=45.0247751, longitude=-93.2434609), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=21),
#   EBirdHotspot(location=EBirdLocation(id='L355540', name='Diamond Lake (Dayton)', coord=Coordinate(latitude=45.19837, longitude=-93.50344), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=169),
#   EBirdHotspot(location=EBirdLocation(id='L682863', name='Diamond Lake (Minneapolis)', coord=Coordinate(latitude=44.9014837, longitude=-93.2690334), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=163),
#   EBirdHotspot(location=EBirdLocation(id='L24091493', name='Donie Galloway Riverside Park', coord=Coordinate(latitude=45.2006408, longitude=-93.42112), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=79),
#   EBirdHotspot(location=EBirdLocation(id='L3679745', name='Dowling Community Garden', coord=Coordinate(latitude=44.9328609, longitude=-93.2072031), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=87),
#   EBirdHotspot(location=EBirdLocation(id='L3538386', name='Eagle Lake Regional Park', coord=Coordinate(latitude=45.0693987, longitude=-93.4166622), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=164),
#   EBirdHotspot(location=EBirdLocation(id='L31179168', name='East Bush Lake Park', coord=Coordinate(latitude=44.8373755, longitude=-93.3789065), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=123),
#   EBirdHotspot(location=EBirdLocation(id='L5737345', name='East Medicine Lake Park', coord=Coordinate(latitude=44.9984506, longitude=-93.4032383), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=142),
#   EBirdHotspot(location=EBirdLocation(id='L3662869', name='East Mississippi River Flats, Minneapolis', coord=Coordinate(latitude=44.9606986, longitude=-93.2167196), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=176),
#   EBirdHotspot(location=EBirdLocation(id='L2910026', name='East River Flats Park', coord=Coordinate(latitude=44.9702025, longitude=-93.2343042), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=155),
#   EBirdHotspot(location=EBirdLocation(id='L9487412', name='Eden Prairie Art Center', coord=Coordinate(latitude=44.8651049, longitude=-93.4548515), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=64),
#   EBirdHotspot(location=EBirdLocation(id='L2169056', name='Edenbrook Conservation Area', coord=Coordinate(latitude=44.883607, longitude=-93.5098743), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=136),
#   EBirdHotspot(location=EBirdLocation(id='L4993460', name='Edenvale Park', coord=Coordinate(latitude=44.8714732, longitude=-93.4698343), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=80),
#   EBirdHotspot(location=EBirdLocation(id='L8089371', name='Edina High School', coord=Coordinate(latitude=44.8825617, longitude=-93.3768046), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=74),
#   EBirdHotspot(location=EBirdLocation(id='L13550118', name='Elm Creek Park', coord=Coordinate(latitude=45.0520851, longitude=-93.5020654), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=98),
#   EBirdHotspot(location=EBirdLocation(id='L1038660', name='Elm Creek Park Reserve', coord=Coordinate(latitude=45.1622504, longitude=-93.4383774), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=208),
#   EBirdHotspot(location=EBirdLocation(id='L374247', name='Elm Creek Park Reserve--Eastman Nature Center', coord=Coordinate(latitude=45.1545, longitude=-93.4497), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=198),
#   EBirdHotspot(location=EBirdLocation(id='L1009187', name='Eloise Butler Wildflower Garden and Bird Sanctuary', coord=Coordinate(latitude=44.9749397, longitude=-93.3206783), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=186),
#   EBirdHotspot(location=EBirdLocation(id='L29576353', name='Elsie Stephens Park', coord=Coordinate(latitude=45.2235009, longitude=-93.466031), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=37),
#   EBirdHotspot(location=EBirdLocation(id='L14114534', name='Eugene H. Hagel Arboretum', coord=Coordinate(latitude=45.0672165, longitude=-93.3381701), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=59),
#   EBirdHotspot(location=EBirdLocation(id='L10081672', name='Excelsior bay dock', coord=Coordinate(latitude=44.9046909, longitude=-93.5647206), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=45),
#   EBirdHotspot(location=EBirdLocation(id='L11013830', name='Farview Park', coord=Coordinate(latitude=45.0073274, longitude=-93.2865265), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=19),
#   EBirdHotspot(location=EBirdLocation(id='L3549071', name='Father Hennepin Bluffs', coord=Coordinate(latitude=44.9821334, longitude=-93.2515132), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=148),
#   EBirdHotspot(location=EBirdLocation(id='L3936874', name='Ferndale Marsh', coord=Coordinate(latitude=44.96885, longitude=-93.54996), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=67),
#   EBirdHotspot(location=EBirdLocation(id='L5749601', name='Fish Lake Regional Park', coord=Coordinate(latitude=45.085945, longitude=-93.4641373), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=129),
#   EBirdHotspot(location=EBirdLocation(id='L9134092', name='Florida Pond Nature Area', coord=Coordinate(latitude=45.024988, longitude=-93.362615), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=102),
#   EBirdHotspot(location=EBirdLocation(id='L7792050', name='Flying Cloud Drive Overlook', coord=Coordinate(latitude=44.8199669, longitude=-93.4546181), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=123),
#   EBirdHotspot(location=EBirdLocation(id='L6041728', name='Flying Cloud Fields', coord=Coordinate(latitude=44.8327739, longitude=-93.4720552), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=167),
#   EBirdHotspot(location=EBirdLocation(id='L7006558', name='Fort Snelling National Cemetery', coord=Coordinate(latitude=44.8684013, longitude=-93.2157326), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=100),
#   EBirdHotspot(location=EBirdLocation(id='L151759', name='Fort Snelling SP', coord=Coordinate(latitude=44.874446, longitude=-93.1911072), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=212),
#   EBirdHotspot(location=EBirdLocation(id='L2137159', name='Fort Snelling SP--Snelling Lake', coord=Coordinate(latitude=44.8805053, longitude=-93.1835461), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=194),
#   EBirdHotspot(location=EBirdLocation(id='L6592140', name='Fort Snelling SP--Visitor Center', coord=Coordinate(latitude=44.8904804, longitude=-93.1821084), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=146),
#   EBirdHotspot(location=EBirdLocation(id='L20452439', name='Fred Richards Park', coord=Coordinate(latitude=44.865735, longitude=-93.340989), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=89),
#   EBirdHotspot(location=EBirdLocation(id='L9269039', name='Frederick-Miller Spring Trails -Prairie Bluff Conservation Area', coord=Coordinate(latitude=44.8213602, longitude=-93.4790077), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=63),
#   EBirdHotspot(location=EBirdLocation(id='L3987194', name='French Creek Preserve', coord=Coordinate(latitude=44.961705, longitude=-93.589348), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=166),
#   EBirdHotspot(location=EBirdLocation(id='L355432', name='French Lake', coord=Coordinate(latitude=45.1778, longitude=-93.5016), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=213),
#   EBirdHotspot(location=EBirdLocation(id='L9912095', name='Gale Woods Farm', coord=Coordinate(latitude=44.9281533, longitude=-93.7048373), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=121),
#   EBirdHotspot(location=EBirdLocation(id='L3850993', name='Garden Park', coord=Coordinate(latitude=44.901911, longitude=-93.362388), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=110),
#   EBirdHotspot(location=EBirdLocation(id='L1452112', name='General Mills Nature Preserve', coord=Coordinate(latitude=44.9808149, longitude=-93.3970322), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=150),
#   EBirdHotspot(location=EBirdLocation(id='L2193021', name='General Mills Research Nature Area', coord=Coordinate(latitude=45.0000629, longitude=-93.392356), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=161),
#   EBirdHotspot(location=EBirdLocation(id='L11810960', name='George Floyd Square', coord=Coordinate(latitude=44.9353005, longitude=-93.2644572), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=27),
#   EBirdHotspot(location=EBirdLocation(id='L229889', name='Gethsemane Cemetery', coord=Coordinate(latitude=45.0292218, longitude=-93.3878878), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=42),
#   EBirdHotspot(location=EBirdLocation(id='L4592621', name='Gold Medal Park', coord=Coordinate(latitude=44.978096, longitude=-93.2532728), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=79),
#   EBirdHotspot(location=EBirdLocation(id='L23615525', name='Goldenrod Marsh Park', coord=Coordinate(latitude=45.0953828, longitude=-93.4700489), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=52),
#   EBirdHotspot(location=EBirdLocation(id='L29173439', name='Goodin Park', coord=Coordinate(latitude=45.2330745, longitude=-93.5000467), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=54),
#   EBirdHotspot(location=EBirdLocation(id='L19287778', name='Government Center Park', coord=Coordinate(latitude=44.9751968, longitude=-93.2672095), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=60),
#   EBirdHotspot(location=EBirdLocation(id='L2135666', name='Grass Lake', coord=Coordinate(latitude=44.8937621, longitude=-93.2971966), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=176),
#   EBirdHotspot(location=EBirdLocation(id='L12624835', name='Grays Bay Dam Park', coord=Coordinate(latitude=44.9524585, longitude=-93.487413), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=154),
#   EBirdHotspot(location=EBirdLocation(id='L21433386', name='Green Circle Park', coord=Coordinate(latitude=44.9004885, longitude=-93.4084736), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=53),
#   EBirdHotspot(location=EBirdLocation(id='L984254', name='Haeg Park', coord=Coordinate(latitude=44.850992, longitude=-93.3067818), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=42),
#   EBirdHotspot(location=EBirdLocation(id='L1777508', name='Hagemeister Pond Preserve Park', coord=Coordinate(latitude=45.030273, longitude=-93.3621724), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=160),
#   EBirdHotspot(location=EBirdLocation(id='L4379662', name='Hannan Lake', coord=Coordinate(latitude=44.9530609, longitude=-93.3955157), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=29),
#   EBirdHotspot(location=EBirdLocation(id='L12735545', name='Hanover Bridge', coord=Coordinate(latitude=45.1532849, longitude=-93.6619423), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=26),
#   EBirdHotspot(location=EBirdLocation(id='L3936880', name='Hardscrabble Woods/MG Tusler Sanctuary', coord=Coordinate(latitude=44.91448, longitude=-93.67977), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=55),
#   EBirdHotspot(location=EBirdLocation(id='L1045929', name='Harrison Picnic Ground', coord=Coordinate(latitude=44.8216821, longitude=-93.3021823), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=86),
#   EBirdHotspot(location=EBirdLocation(id='L31601160', name="Henry's Woods Park", coord=Coordinate(latitude=45.1860296, longitude=-93.5254955), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=59),
#   EBirdHotspot(location=EBirdLocation(id='L950136', name='Heritage Hills Park', coord=Coordinate(latitude=44.8177831, longitude=-93.3408308), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=107),
#   EBirdHotspot(location=EBirdLocation(id='L23412917', name='Heritage Park', coord=Coordinate(latitude=45.0151579, longitude=-93.4459734), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=73),
#   EBirdHotspot(location=EBirdLocation(id='L248179', name='Heron Island, Minneapolis', coord=Coordinate(latitude=45.0369815, longitude=-93.2845983), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=88),
#   EBirdHotspot(location=EBirdLocation(id='L13010718', name='Hidden Ponds Park', coord=Coordinate(latitude=44.8704088, longitude=-93.5111113), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=62),
#   EBirdHotspot(location=EBirdLocation(id='L14563575', name='Hidden Valley Park', coord=Coordinate(latitude=45.016142, longitude=-93.392407), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=66),
#   EBirdHotspot(location=EBirdLocation(id='L4724713', name='Highlands Park', coord=Coordinate(latitude=44.908678, longitude=-93.367735), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=45),
#   EBirdHotspot(location=EBirdLocation(id='L25260848', name='Hilloway Park', coord=Coordinate(latitude=44.9580713, longitude=-93.4372464), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=107),
#   EBirdHotspot(location=EBirdLocation(id='L3784809', name='Hillside Cemetery', coord=Coordinate(latitude=45.007353, longitude=-93.2212257), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=96),
#   EBirdHotspot(location=EBirdLocation(id='L5818330', name='Historic Fort Snelling', coord=Coordinate(latitude=44.8927674, longitude=-93.1806627), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=122),
#   EBirdHotspot(location=EBirdLocation(id='L23940492', name='Holmes Park', coord=Coordinate(latitude=44.9874284, longitude=-93.2515172), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=19),
#   EBirdHotspot(location=EBirdLocation(id='L356720', name='Hyland Lake Park Reserve', coord=Coordinate(latitude=44.83615, longitude=-93.37491), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=222),
#   EBirdHotspot(location=EBirdLocation(id='L1170570', name='Hyland Lake Park Reserve--Hyland Lake picnic area', coord=Coordinate(latitude=44.8225276, longitude=-93.3721898), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=158),
#   EBirdHotspot(location=EBirdLocation(id='L2376897', name='Hyland Lake Park Reserve-Hyland Lake', coord=Coordinate(latitude=44.8215264, longitude=-93.3659363), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=168),
#   EBirdHotspot(location=EBirdLocation(id='L726783', name='Hyland-Bush Lakes Park--Visitor Center', coord=Coordinate(latitude=44.8258954, longitude=-93.3714294), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=154),
#   EBirdHotspot(location=EBirdLocation(id='L3085901', name='Jackson Middle School/Oxbow Creek Park', coord=Coordinate(latitude=45.1525181, longitude=-93.3495426), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=99),
#   EBirdHotspot(location=EBirdLocation(id='L7153912', name='James A. Brown Conservation Area', coord=Coordinate(latitude=44.8073862, longitude=-93.4191084), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=77),
#   EBirdHotspot(location=EBirdLocation(id='L11289915', name='Jidana Park', coord=Coordinate(latitude=44.9432384, longitude=-93.4762301), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=95),
#   EBirdHotspot(location=EBirdLocation(id='L4444586', name='Kimberly Lane Elementary Nature Trail', coord=Coordinate(latitude=45.0311199, longitude=-93.5016889), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=130),
#   EBirdHotspot(location=EBirdLocation(id='L13947838', name='Kingswood Park', coord=Coordinate(latitude=44.9568756, longitude=-93.7092404), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=90),
#   EBirdHotspot(location=EBirdLocation(id='L17476269', name='Kylawn Park', coord=Coordinate(latitude=45.0647689, longitude=-93.3376765), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=45),
#   EBirdHotspot(location=EBirdLocation(id='L4461675', name='Lake Camelot', coord=Coordinate(latitude=45.0582894, longitude=-93.4571099), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=175),
#   EBirdHotspot(location=EBirdLocation(id='L3963472', name='Lake Cornelia', coord=Coordinate(latitude=44.8842455, longitude=-93.3390284), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=111),
#   EBirdHotspot(location=EBirdLocation(id='L1186214', name='Lake Girard Park', coord=Coordinate(latitude=44.8488105, longitude=-93.3267117), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=140),
#   EBirdHotspot(location=EBirdLocation(id='L356105', name='Lake Harriet', coord=Coordinate(latitude=44.92142, longitude=-93.30414), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=216),
#   EBirdHotspot(location=EBirdLocation(id='L1131548', name='Lake Harriet--Bandshell area', coord=Coordinate(latitude=44.9280605, longitude=-93.3076143), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=148),
#   EBirdHotspot(location=EBirdLocation(id='L1455050', name='Lake Hiawatha Park', coord=Coordinate(latitude=44.920967, longitude=-93.2347699), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=210),
#   EBirdHotspot(location=EBirdLocation(id='L22788865', name='Lake Idlewild', coord=Coordinate(latitude=44.8609278, longitude=-93.4295097), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=52),
#   EBirdHotspot(location=EBirdLocation(id='L15626615', name='Lake Independence', coord=Coordinate(latitude=45.0282009, longitude=-93.6479418), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=132),
#   EBirdHotspot(location=EBirdLocation(id='L379153', name='Lake Minnetonka', coord=Coordinate(latitude=44.9172884, longitude=-93.6045456), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=130),
#   EBirdHotspot(location=EBirdLocation(id='L12114756', name='Lake Minnetonka LRT regional trail', coord=Coordinate(latitude=44.904685, longitude=-93.5863174), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=59),
#   EBirdHotspot(location=EBirdLocation(id='L12088128', name='Lake Minnetonka Regional Park', coord=Coordinate(latitude=44.8946191, longitude=-93.6731683), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=73),
#   EBirdHotspot(location=EBirdLocation(id='L474726', name='Lake Nokomis', coord=Coordinate(latitude=44.9082924, longitude=-93.2437134), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=194),
#   EBirdHotspot(location=EBirdLocation(id='L3558142', name='Lake Nokomis--Amelia Pond', coord=Coordinate(latitude=44.9034139, longitude=-93.2503223), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=114),
#   EBirdHotspot(location=EBirdLocation(id='L3545875', name='Lake Nokomis--Gateway Pond', coord=Coordinate(latitude=44.902046, longitude=-93.2465243), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=75),
#   EBirdHotspot(location=EBirdLocation(id='L652085', name='Lake Rebecca Park Reserve', coord=Coordinate(latitude=45.0645794, longitude=-93.7510908), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=213),
#   EBirdHotspot(location=EBirdLocation(id='L26288291', name='Lake Sarah', coord=Coordinate(latitude=45.068316, longitude=-93.6899904), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=23),
#   EBirdHotspot(location=EBirdLocation(id='L42965106', name='Lake Sarah Regional Park', coord=Coordinate(latitude=45.072692, longitude=-93.711312), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=29),
#   EBirdHotspot(location=EBirdLocation(id='L1136286', name='Lake Smetana Park', coord=Coordinate(latitude=44.8633978, longitude=-93.4092593), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=163),
#   EBirdHotspot(location=EBirdLocation(id='L367854', name='Lake of the Isles', coord=Coordinate(latitude=44.9545035, longitude=-93.3065414), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=180),
#   EBirdHotspot(location=EBirdLocation(id='L364565', name='Lakewood Cemetery', coord=Coordinate(latitude=44.9335749, longitude=-93.3025074), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=157),
#   EBirdHotspot(location=EBirdLocation(id='L4325394', name='Lamplighter Pond', coord=Coordinate(latitude=44.9663, longitude=-93.377648), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=118),
#   EBirdHotspot(location=EBirdLocation(id='L31365750', name='Lennar Park Trails', coord=Coordinate(latitude=45.1606731, longitude=-93.5283762), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=49),
#   EBirdHotspot(location=EBirdLocation(id='L7369827', name='Lewis Park', coord=Coordinate(latitude=44.8703174, longitude=-93.3656573), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=62),
#   EBirdHotspot(location=EBirdLocation(id='L9912113', name='Little Long Lake', coord=Coordinate(latitude=44.9530089, longitude=-93.7070464), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=76),
#   EBirdHotspot(location=EBirdLocation(id='L18033589', name='Logan Park', coord=Coordinate(latitude=44.9998581, longitude=-93.2537985), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=56),
#   EBirdHotspot(location=EBirdLocation(id='L3692146', name='Lone Lake Park', coord=Coordinate(latitude=44.9001158, longitude=-93.431704), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=111),
#   EBirdHotspot(location=EBirdLocation(id='L348457', name='Longfellow Gardens', coord=Coordinate(latitude=44.9158525, longitude=-93.2147402), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=137),
#   EBirdHotspot(location=EBirdLocation(id='L2161102', name='Loring Park', coord=Coordinate(latitude=44.9694131, longitude=-93.2855129), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=153),
#   EBirdHotspot(location=EBirdLocation(id='L4499175', name='Lower Riverside Park', coord=Coordinate(latitude=44.966536, longitude=-93.230377), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=132),
#   EBirdHotspot(location=EBirdLocation(id='L2393305', name='Luce Line State Trail Plymouth', coord=Coordinate(latitude=44.9892048, longitude=-93.4829879), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=104),
#   EBirdHotspot(location=EBirdLocation(id='L13467188', name='Luce Line Trail--Between Stubbs Bay and Cty Rd 110', coord=Coordinate(latitude=44.9822783, longitude=-93.6397509), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=89),
#   EBirdHotspot(location=EBirdLocation(id='L2192774', name='MAC Park/Wildlife Area', coord=Coordinate(latitude=45.063958, longitude=-93.3414209), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=146),
#   EBirdHotspot(location=EBirdLocation(id='L6861720', name='MSP Aircraft Viewing Area, Cargo Rd', coord=Coordinate(latitude=44.8819954, longitude=-93.2287359), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=45),
#   EBirdHotspot(location=EBirdLocation(id='L386276', name='MSP International Airport', coord=Coordinate(latitude=44.885369, longitude=-93.2217797), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=95),
#   EBirdHotspot(location=EBirdLocation(id='L489665', name='MSP International Airport--Cargo Rd.', coord=Coordinate(latitude=44.8778597, longitude=-93.2354307), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=66),
#   EBirdHotspot(location=EBirdLocation(id='L21212078', name='Maple Grove Arboretum', coord=Coordinate(latitude=45.1251097, longitude=-93.4615195), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=73),
#   EBirdHotspot(location=EBirdLocation(id='L10765087', name='Maple Grove Forest Preservation Area B', coord=Coordinate(latitude=45.0756723, longitude=-93.482666), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=105),
#   EBirdHotspot(location=EBirdLocation(id='L12698898', name='Maple Lakes Park', coord=Coordinate(latitude=45.1087262, longitude=-93.4359312), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=110),
#   EBirdHotspot(location=EBirdLocation(id='L1563814', name='Marsh Lake Park', coord=Coordinate(latitude=44.8311908, longitude=-93.3235116), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=165),
#   EBirdHotspot(location=EBirdLocation(id='L9494115', name='Marsh Run Lake', coord=Coordinate(latitude=44.9721697, longitude=-93.4293761), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=63),
#   EBirdHotspot(location=EBirdLocation(id='L7321458', name='Marshall Terrace Park', coord=Coordinate(latitude=45.0190261, longitude=-93.2747519), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=126),
# ...
#   EBirdHotspot(location=EBirdLocation(id='L15518153', name='Darwin City Park', coord=Coordinate(latitude=45.096245, longitude=-94.4108609), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-093', subnat2_name=None), all_time_species=28),
#   EBirdHotspot(location=EBirdLocation(id='L16444291', name='Darwin Myers WMA', coord=Coordinate(latitude=47.6356193, longitude=-92.2233289), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-137', subnat2_name=None), all_time_species=143),
#   EBirdHotspot(location=EBirdLocation(id='L9799809', name='Darwin-Dassel Park', coord=Coordinate(latitude=45.092356, longitude=-94.375995), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-093', subnat2_name=None), all_time_species=103),
#   EBirdHotspot(location=EBirdLocation(id='L6258355', name='Darwin-Dassel Park--South Unit', coord=Coordinate(latitude=45.0885356, longitude=-94.3805194), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-093', subnat2_name=None), all_time_species=116),
#   EBirdHotspot(location=EBirdLocation(id='L5607463', name='Dassel WTP', coord=Coordinate(latitude=45.0848163, longitude=-94.3203735), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-093', subnat2_name=None), all_time_species=113),
#   EBirdHotspot(location=EBirdLocation(id='L35360797', name='Daub’s Lake WMA--NW Units', coord=Coordinate(latitude=44.4565825, longitude=-95.2936641), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-127', subnat2_name=None), all_time_species=12),
#   EBirdHotspot(location=EBirdLocation(id='L35383500', name='Daub’s Lake WMA--South Unit', coord=Coordinate(latitude=44.4385408, longitude=-95.2702149), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-127', subnat2_name=None), all_time_species=None),
#   EBirdHotspot(location=EBirdLocation(id='L1255698', name='David H. Steen WMA', coord=Coordinate(latitude=45.4180035, longitude=-96.4766121), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-011', subnat2_name=None), all_time_species=84),
#   EBirdHotspot(location=EBirdLocation(id='L53295017', name='Davis Farm Park', coord=Coordinate(latitude=45.2926807, longitude=-93.6317183), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-171', subnat2_name=None), all_time_species=21),
#   EBirdHotspot(location=EBirdLocation(id='L4471163', name='Dawson WTP', coord=Coordinate(latitude=44.9221945, longitude=-96.0135108), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-073', subnat2_name=None), all_time_species=59),
#   EBirdHotspot(location=EBirdLocation(id='L11106100', name='Dead Coon & Slough Lakes', coord=Coordinate(latitude=44.3660152, longitude=-96.104751), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-081', subnat2_name=None), all_time_species=110),
#   EBirdHotspot(location=EBirdLocation(id='L3008388', name='Dead Lake (Otter Tail Co.)', coord=Coordinate(latitude=46.473335, longitude=-95.7544327), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-111', subnat2_name=None), all_time_species=72),
#   EBirdHotspot(location=EBirdLocation(id='L2900277', name='Dead River (St. Louis Co.)', coord=Coordinate(latitude=47.9595828, longitude=-91.9453955), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-137', subnat2_name=None), all_time_species=41),
#   EBirdHotspot(location=EBirdLocation(id='L12721008', name='Deadshot Lake', coord=Coordinate(latitude=46.7802432, longitude=-95.8496196), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-005', subnat2_name=None), all_time_species=24),
#   EBirdHotspot(location=EBirdLocation(id='L7536362', name="Dean's Lake and Nature Trails", coord=Coordinate(latitude=44.775134, longitude=-93.447804), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-139', subnat2_name=None), all_time_species=103),
#   EBirdHotspot(location=EBirdLocation(id='L2890345', name='Deane Park', coord=Coordinate(latitude=46.9436118, longitude=-95.0675511), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-057', subnat2_name=None), all_time_species=133),
#   EBirdHotspot(location=EBirdLocation(id='L823643', name='Deep Portage Learning Center', coord=Coordinate(latitude=46.8999457, longitude=-94.3884909), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-021', subnat2_name=None), all_time_species=205),
#   EBirdHotspot(location=EBirdLocation(id='L13331359', name='Deer Lake', coord=Coordinate(latitude=45.1439662, longitude=-93.9130272), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-171', subnat2_name=None), all_time_species=25),
#   EBirdHotspot(location=EBirdLocation(id='L32369471', name='Deer Lake Boat Launch', coord=Coordinate(latitude=46.3543331, longitude=-95.7600117), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-111', subnat2_name=None), all_time_species=16),
#   EBirdHotspot(location=EBirdLocation(id='L18980364', name='Dehning WPA', coord=Coordinate(latitude=44.6093356, longitude=-93.9885494), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-143', subnat2_name=None), all_time_species=34),
#   EBirdHotspot(location=EBirdLocation(id='L9498769', name='Delaney Park', coord=Coordinate(latitude=44.7378053, longitude=-93.1658371), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-037', subnat2_name=None), all_time_species=70),
#   EBirdHotspot(location=EBirdLocation(id='L46616159', name='Delano Central Park', coord=Coordinate(latitude=45.0481143, longitude=-93.7867856), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-171', subnat2_name=None), all_time_species=38),
#   EBirdHotspot(location=EBirdLocation(id='L30271851', name='Delavan WTP', coord=Coordinate(latitude=43.767563, longitude=-94.0359115), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-043', subnat2_name=None), all_time_species=8),
#   EBirdHotspot(location=EBirdLocation(id='L27178991', name='Delmar Wetland', coord=Coordinate(latitude=44.5455275, longitude=-93.6281382), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-139', subnat2_name=None), all_time_species=75),
#   EBirdHotspot(location=EBirdLocation(id='L34154699', name='Demaree WPA', coord=Coordinate(latitude=46.0654042, longitude=-96.0391032), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-051', subnat2_name=None), all_time_species=22),
#   EBirdHotspot(location=EBirdLocation(id='L26787995', name='Deming Heights Park', coord=Coordinate(latitude=45.0247751, longitude=-93.2434609), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=21),
#   EBirdHotspot(location=EBirdLocation(id='L4874977', name='Demontreville Boat Launch and Park area', coord=Coordinate(latitude=45.0257849, longitude=-92.9490808), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-163', subnat2_name=None), all_time_species=73),
#   EBirdHotspot(location=EBirdLocation(id='L635393', name='Dennis Frandsen Regional Park', coord=Coordinate(latitude=45.7134839, longitude=-93.0796963), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-025', subnat2_name=None), all_time_species=133),
#   EBirdHotspot(location=EBirdLocation(id='L8346549', name='Dennison (town)', coord=Coordinate(latitude=44.4071206, longitude=-93.0392114), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-049', subnat2_name=None), all_time_species=47),
#   EBirdHotspot(location=EBirdLocation(id='L4822362', name='Dennison Sod Field', coord=Coordinate(latitude=44.4042928, longitude=-93.0421937), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-131', subnat2_name=None), all_time_species=86),
#   EBirdHotspot(location=EBirdLocation(id='L1294484', name='Dennison WTP', coord=Coordinate(latitude=44.4032925, longitude=-93.0503047), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-131', subnat2_name=None), all_time_species=159),
#   EBirdHotspot(location=EBirdLocation(id='L10177203', name='Dentaybow Forest Road', coord=Coordinate(latitude=48.1861202, longitude=-93.6590497), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-071', subnat2_name=None), all_time_species=93),
#   EBirdHotspot(location=EBirdLocation(id='L660271', name='Des Moines River Prairie SNA', coord=Coordinate(latitude=43.7975531, longitude=-95.0870776), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-063', subnat2_name=None), all_time_species=62),
#   EBirdHotspot(location=EBirdLocation(id='L19884237', name='Des Moines River Rest Stop', coord=Coordinate(latitude=43.640521, longitude=-95.0207505), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-063', subnat2_name=None), all_time_species=55),
#   EBirdHotspot(location=EBirdLocation(id='L13975820', name='Des Moines River WPA', coord=Coordinate(latitude=43.930091, longitude=-95.244361), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-033', subnat2_name=None), all_time_species=65),
#   EBirdHotspot(location=EBirdLocation(id='L38205715', name='Des Moines River--Petersburg Access', coord=Coordinate(latitude=43.5259057, longitude=-94.9185769), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-063', subnat2_name=None), all_time_species=6),
#   EBirdHotspot(location=EBirdLocation(id='L12604730', name='Detroit Lake', coord=Coordinate(latitude=46.7979344, longitude=-95.8512705), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-005', subnat2_name=None), all_time_species=109),
#   EBirdHotspot(location=EBirdLocation(id='L9319108', name='Detroit Lakes City Park', coord=Coordinate(latitude=46.8079117, longitude=-95.84401), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-005', subnat2_name=None), all_time_species=73),
#   EBirdHotspot(location=EBirdLocation(id='L15481581', name='Detroit Lakes Pavilion (stakeout LAGU 2021)', coord=Coordinate(latitude=46.806038, longitude=-95.845701), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-005', subnat2_name=None), all_time_species=56),
#   EBirdHotspot(location=EBirdLocation(id='L18575413', name='Detroit Lakes Wetland Management District--Headquarters WPA', coord=Coordinate(latitude=46.8475557, longitude=-95.8459104), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-005', subnat2_name=None), all_time_species=93),
#   EBirdHotspot(location=EBirdLocation(id='L17214855', name='Detroit Mountain Rec. Area', coord=Coordinate(latitude=46.8130942, longitude=-95.7832879), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-005', subnat2_name=None), all_time_species=64),
#   EBirdHotspot(location=EBirdLocation(id='L7704566', name='Devil Track Canyon trail', coord=Coordinate(latitude=47.7759204, longitude=-90.2651954), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-031', subnat2_name=None), all_time_species=60),
#   EBirdHotspot(location=EBirdLocation(id='L637308', name='Devil Track Lake', coord=Coordinate(latitude=47.821915, longitude=-90.4238319), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-031', subnat2_name=None), all_time_species=74),
#   EBirdHotspot(location=EBirdLocation(id='L374937', name='Devil Track River Mouth', coord=Coordinate(latitude=47.7700005, longitude=-90.2611506), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-031', subnat2_name=None), all_time_species=65),
#   EBirdHotspot(location=EBirdLocation(id='L9922440', name='Devilfish Lake Campground', coord=Coordinate(latitude=47.9909556, longitude=-90.0961733), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-031', subnat2_name=None), all_time_species=46),
#   EBirdHotspot(location=EBirdLocation(id='L14908158', name='Devils Run WPA', coord=Coordinate(latitude=44.01969, longitude=-95.567113), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-101', subnat2_name=None), all_time_species=22),
#   EBirdHotspot(location=EBirdLocation(id='L1668914', name='Dexter WTP', coord=Coordinate(latitude=43.7343751, longitude=-92.7103693), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-099', subnat2_name=None), all_time_species=131),
#   EBirdHotspot(location=EBirdLocation(id='L355540', name='Diamond Lake (Dayton)', coord=Coordinate(latitude=45.19837, longitude=-93.50344), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=169),
#   EBirdHotspot(location=EBirdLocation(id='L377045', name='Diamond Lake (Kandiyohi Co.)', coord=Coordinate(latitude=45.1792, longitude=-94.8417), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-067', subnat2_name=None), all_time_species=108),
#   EBirdHotspot(location=EBirdLocation(id='L682863', name='Diamond Lake (Minneapolis)', coord=Coordinate(latitude=44.9014837, longitude=-93.2690334), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-053', subnat2_name=None), all_time_species=163),
#   EBirdHotspot(location=EBirdLocation(id='L34079654', name='Diamond Lake WMA', coord=Coordinate(latitude=44.3194003, longitude=-93.5770936), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-079', subnat2_name=None), all_time_species=70),
#   EBirdHotspot(location=EBirdLocation(id='L8091491', name='Diamond Path Park', coord=Coordinate(latitude=44.7331694, longitude=-93.1597743), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-037', subnat2_name=None), all_time_species=63),
#   EBirdHotspot(location=EBirdLocation(id='L3986913', name='Diamond Point Park', coord=Coordinate(latitude=47.4841513, longitude=-94.8687565), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-007', subnat2_name=None), all_time_species=161),
#   EBirdHotspot(location=EBirdLocation(id='L29460120', name='Diekmann WPA', coord=Coordinate(latitude=45.5880671, longitude=-96.6586349), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-155', subnat2_name=None), all_time_species=19),
#   EBirdHotspot(location=EBirdLocation(id='L29501024', name='Dietrich Lange WMA', coord=Coordinate(latitude=45.2659818, longitude=-94.8523759), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-067', subnat2_name=None), all_time_species=42),
#   EBirdHotspot(location=EBirdLocation(id='L20273272', name='Dike Rd', coord=Coordinate(latitude=44.818118, longitude=-95.554079), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-173', subnat2_name=None), all_time_species=66),
#   EBirdHotspot(location=EBirdLocation(id='L21368077', name='Dinner Creek SNA', coord=Coordinate(latitude=47.0756792, longitude=-95.2140903), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-005', subnat2_name=None), all_time_species=1),
#   EBirdHotspot(location=EBirdLocation(id='L654605', name='Dishpan WMA', coord=Coordinate(latitude=47.770426, longitude=-94.0973639), country_code='US', subnat1_code='US-MN', subnat1_name=None, subnat2_code='US-MN-061', subnat2_name=None), all_time_species=49),
#   ...]]

# %%
from birding.ebird_api import find_species_in_region

species_per_region = [find_species_in_region(rc) for rc in region_codes]
species_per_region
# Out:
# Bird species list for 'US-MN-053' was already cached.
# Calling eBird API for the taxonomy entry of 15 species...
# Unable to retrieve eBird taxonomy entry for species: sxrgoo1
# Unable to retrieve eBird taxonomy entry for species: x00759
# Unable to retrieve eBird taxonomy entry for species: bwxtea1
# Unable to retrieve eBird taxonomy entry for species: x00421
# Unable to retrieve eBird taxonomy entry for species: x00420
# Unable to retrieve eBird taxonomy entry for species: x00004
# Unable to retrieve eBird taxonomy entry for species: x00679
# Unable to retrieve eBird taxonomy entry for species: x00682
# Unable to retrieve eBird taxonomy entry for species: x00655
# Unable to retrieve eBird taxonomy entry for species: x00425
# Unable to retrieve eBird taxonomy entry for species: x00039
# Unable to retrieve eBird taxonomy entry for species: x00446
# Unable to retrieve eBird taxonomy entry for species: x00669
# Unable to retrieve eBird taxonomy entry for species: brewar
# Unable to retrieve eBird taxonomy entry for species: lawwar
# Bird species list for 'US-MN' was already cached.
# Calling eBird API for the taxonomy entry of 52 species...
# Unable to retrieve eBird taxonomy entry for species: sxrgoo1
# Unable to retrieve eBird taxonomy entry for species: x00776
# Unable to retrieve eBird taxonomy entry for species: x00627
# Unable to retrieve eBird taxonomy entry for species: x00692
# Unable to retrieve eBird taxonomy entry for species: x00694
# Unable to retrieve eBird taxonomy entry for species: x00414
# Unable to retrieve eBird taxonomy entry for species: x00415
# Unable to retrieve eBird taxonomy entry for species: x00758
# Unable to retrieve eBird taxonomy entry for species: x00759
# Unable to retrieve eBird taxonomy entry for species: y00765
# Unable to retrieve eBird taxonomy entry for species: bwxtea1
# Unable to retrieve eBird taxonomy entry for species: x00629
# Unable to retrieve eBird taxonomy entry for species: x00457
# Unable to retrieve eBird taxonomy entry for species: x00724
# Unable to retrieve eBird taxonomy entry for species: x00421
# Unable to retrieve eBird taxonomy entry for species: mdxmal1
# Unable to retrieve eBird taxonomy entry for species: x00612
# Unable to retrieve eBird taxonomy entry for species: x00420
# Unable to retrieve eBird taxonomy entry for species: x00611
# Unable to retrieve eBird taxonomy entry for species: x00004
# Unable to retrieve eBird taxonomy entry for species: x00610
# Unable to retrieve eBird taxonomy entry for species: x00628
# Unable to retrieve eBird taxonomy entry for species: x00763
# Unable to retrieve eBird taxonomy entry for species: x00684
# Unable to retrieve eBird taxonomy entry for species: x00679
# Unable to retrieve eBird taxonomy entry for species: x00682
# Unable to retrieve eBird taxonomy entry for species: tdxsca1
# Unable to retrieve eBird taxonomy entry for species: x00655
# Unable to retrieve eBird taxonomy entry for species: x00909
# Unable to retrieve eBird taxonomy entry for species: cxbgol1
# Unable to retrieve eBird taxonomy entry for species: x00202
# Unable to retrieve eBird taxonomy entry for species: x00425
# Unable to retrieve eBird taxonomy entry for species: x00631
# Unable to retrieve eBird taxonomy entry for species: x00728
# Unable to retrieve eBird taxonomy entry for species: x01131
# Unable to retrieve eBird taxonomy entry for species: x01134
# Unable to retrieve eBird taxonomy entry for species: x00427
# Unable to retrieve eBird taxonomy entry for species: gxwibi1
# Unable to retrieve eBird taxonomy entry for species: x00718
# Unable to retrieve eBird taxonomy entry for species: x00754
# Unable to retrieve eBird taxonomy entry for species: x00900
# Unable to retrieve eBird taxonomy entry for species: x00039
# Unable to retrieve eBird taxonomy entry for species: x00446
# Unable to retrieve eBird taxonomy entry for species: x00669
# Unable to retrieve eBird taxonomy entry for species: brewar
# Unable to retrieve eBird taxonomy entry for species: lawwar
# Unable to retrieve eBird taxonomy entry for species: x00746
# Unable to retrieve eBird taxonomy entry for species: x00750
# Unable to retrieve eBird taxonomy entry for species: x00711
# Unable to retrieve eBird taxonomy entry for species: x00979
# Unable to retrieve eBird taxonomy entry for species: x00448
# Unable to retrieve eBird taxonomy entry for species: ixlbun
# [[EBirdSpecies(common_name='Black-bellied Whistling-Duck', specific_name='autumnalis', generic_name='Dendrocygna', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='bbwduc'),
#   EBirdSpecies(common_name='Snow Goose', specific_name='caerulescens', generic_name='Anser', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='snogoo'),
#   EBirdSpecies(common_name="Ross's Goose", specific_name='rossii', generic_name='Anser', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='rosgoo'),
#   EBirdSpecies(common_name='Greater White-fronted Goose', specific_name='albifrons', generic_name='Anser', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='gwfgoo'),
#   EBirdSpecies(common_name='Cackling Goose', specific_name='hutchinsii', generic_name='Branta', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='cacgoo1'),
#   EBirdSpecies(common_name='Canada Goose', specific_name='canadensis', generic_name='Branta', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='cangoo'),
#   EBirdSpecies(common_name='Mute Swan', specific_name='olor', generic_name='Cygnus', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='mutswa'),
#   EBirdSpecies(common_name='Black Swan', specific_name='atratus', generic_name='Cygnus', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='blkswa'),
#   EBirdSpecies(common_name='Trumpeter Swan', specific_name='buccinator', generic_name='Cygnus', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='truswa'),
#   EBirdSpecies(common_name='Tundra Swan', specific_name='columbianus', generic_name='Cygnus', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='tunswa'),
#   EBirdSpecies(common_name='Whooper Swan', specific_name='cygnus', generic_name='Cygnus', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='whoswa'),
#   EBirdSpecies(common_name='Muscovy Duck', specific_name='moschata', generic_name='Cairina', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='musduc'),
#   EBirdSpecies(common_name='Wood Duck', specific_name='sponsa', generic_name='Aix', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='wooduc'),
#   EBirdSpecies(common_name='Blue-winged Teal', specific_name='discors', generic_name='Spatula', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='buwtea'),
#   EBirdSpecies(common_name='Cinnamon Teal', specific_name='cyanoptera', generic_name='Spatula', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='cintea'),
#   EBirdSpecies(common_name='Northern Shoveler', specific_name='clypeata', generic_name='Spatula', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='norsho'),
#   EBirdSpecies(common_name='Gadwall', specific_name='strepera', generic_name='Mareca', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='gadwal'),
#   EBirdSpecies(common_name='Eurasian Wigeon', specific_name='penelope', generic_name='Mareca', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='eurwig'),
#   EBirdSpecies(common_name='American Wigeon', specific_name='americana', generic_name='Mareca', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='amewig'),
#   EBirdSpecies(common_name='Mallard', specific_name='platyrhynchos', generic_name='Anas', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='mallar3'),
#   EBirdSpecies(common_name='American Black Duck', specific_name='rubripes', generic_name='Anas', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='ambduc'),
#   EBirdSpecies(common_name='Mottled Duck', specific_name='fulvigula', generic_name='Anas', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='motduc'),
#   EBirdSpecies(common_name='Northern Pintail', specific_name='acuta', generic_name='Anas', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='norpin'),
#   EBirdSpecies(common_name='Green-winged Teal', specific_name='crecca', generic_name='Anas', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='gnwtea'),
#   EBirdSpecies(common_name='Canvasback', specific_name='valisineria', generic_name='Aythya', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='canvas'),
#   EBirdSpecies(common_name='Redhead', specific_name='americana', generic_name='Aythya', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='redhea'),
#   EBirdSpecies(common_name='Ring-necked Duck', specific_name='collaris', generic_name='Aythya', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='rinduc'),
#   EBirdSpecies(common_name='Greater Scaup', specific_name='marila', generic_name='Aythya', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='gresca'),
#   EBirdSpecies(common_name='Lesser Scaup', specific_name='affinis', generic_name='Aythya', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='lessca'),
#   EBirdSpecies(common_name='Harlequin Duck', specific_name='histrionicus', generic_name='Histrionicus', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='harduc'),
#   EBirdSpecies(common_name='Surf Scoter', specific_name='perspicillata', generic_name='Melanitta', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='sursco'),
#   EBirdSpecies(common_name='White-winged Scoter', specific_name='deglandi', generic_name='Melanitta', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='whwsco2'),
#   EBirdSpecies(common_name='Black Scoter', specific_name='americana', generic_name='Melanitta', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='blksco2'),
#   EBirdSpecies(common_name='Long-tailed Duck', specific_name='hyemalis', generic_name='Clangula', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='lotduc'),
#   EBirdSpecies(common_name='Bufflehead', specific_name='albeola', generic_name='Bucephala', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='buffle'),
#   EBirdSpecies(common_name='Common Goldeneye', specific_name='clangula', generic_name='Bucephala', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='comgol'),
#   EBirdSpecies(common_name="Barrow's Goldeneye", specific_name='islandica', generic_name='Bucephala', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='bargol'),
#   EBirdSpecies(common_name='Hooded Merganser', specific_name='cucullatus', generic_name='Lophodytes', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='hoomer'),
#   EBirdSpecies(common_name='Common Merganser', specific_name='merganser', generic_name='Mergus', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='commer'),
#   EBirdSpecies(common_name='Red-breasted Merganser', specific_name='serrator', generic_name='Mergus', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='rebmer'),
#   EBirdSpecies(common_name='Ruddy Duck', specific_name='jamaicensis', generic_name='Oxyura', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='rudduc'),
#   EBirdSpecies(common_name='Northern Bobwhite', specific_name='virginianus', generic_name='Colinus', family_common_name='New World Quail', family='Odontophoridae', order='Galliformes', ebird_species_code='norbob'),
#   EBirdSpecies(common_name='Wild Turkey', specific_name='gallopavo', generic_name='Meleagris', family_common_name='Pheasants, Grouse, and Allies', family='Phasianidae', order='Galliformes', ebird_species_code='wiltur'),
#   EBirdSpecies(common_name='Ring-necked Pheasant', specific_name='colchicus', generic_name='Phasianus', family_common_name='Pheasants, Grouse, and Allies', family='Phasianidae', order='Galliformes', ebird_species_code='rinphe1'),
#   EBirdSpecies(common_name='Green Pheasant', specific_name='versicolor', generic_name='Phasianus', family_common_name='Pheasants, Grouse, and Allies', family='Phasianidae', order='Galliformes', ebird_species_code='rinphe2'),
#   EBirdSpecies(common_name='Silver Pheasant', specific_name='nycthemera', generic_name='Lophura', family_common_name='Pheasants, Grouse, and Allies', family='Phasianidae', order='Galliformes', ebird_species_code='silphe'),
#   EBirdSpecies(common_name='Indian Peafowl', specific_name='cristatus', generic_name='Pavo', family_common_name='Pheasants, Grouse, and Allies', family='Phasianidae', order='Galliformes', ebird_species_code='compea'),
#   EBirdSpecies(common_name='Chukar', specific_name='chukar', generic_name='Alectoris', family_common_name='Pheasants, Grouse, and Allies', family='Phasianidae', order='Galliformes', ebird_species_code='chukar'),
#   EBirdSpecies(common_name='Rock Pigeon', specific_name='livia', generic_name='Columba', family_common_name='Pigeons and Doves', family='Columbidae', order='Columbiformes', ebird_species_code='rocpig'),
#   EBirdSpecies(common_name='Band-tailed Pigeon', specific_name='fasciata', generic_name='Patagioenas', family_common_name='Pigeons and Doves', family='Columbidae', order='Columbiformes', ebird_species_code='batpig1'),
#   EBirdSpecies(common_name='Passenger Pigeon', specific_name='migratorius', generic_name='Ectopistes', family_common_name='Pigeons and Doves', family='Columbidae', order='Columbiformes', ebird_species_code='paspig'),
#   EBirdSpecies(common_name='Eurasian Collared-Dove', specific_name='decaocto', generic_name='Streptopelia', family_common_name='Pigeons and Doves', family='Columbidae', order='Columbiformes', ebird_species_code='eucdov'),
#   EBirdSpecies(common_name='Spotted Dove', specific_name='chinensis', generic_name='Spilopelia', family_common_name='Pigeons and Doves', family='Columbidae', order='Columbiformes', ebird_species_code='spodov'),
#   EBirdSpecies(common_name='Common Ground Dove', specific_name='passerina', generic_name='Columbina', family_common_name='Pigeons and Doves', family='Columbidae', order='Columbiformes', ebird_species_code='cogdov'),
#   EBirdSpecies(common_name='White-winged Dove', specific_name='asiatica', generic_name='Zenaida', family_common_name='Pigeons and Doves', family='Columbidae', order='Columbiformes', ebird_species_code='whwdov'),
#   EBirdSpecies(common_name='Mourning Dove', specific_name='macroura', generic_name='Zenaida', family_common_name='Pigeons and Doves', family='Columbidae', order='Columbiformes', ebird_species_code='moudov'),
#   EBirdSpecies(common_name='Yellow-billed Cuckoo', specific_name='americanus', generic_name='Coccyzus', family_common_name='Cuckoos', family='Cuculidae', order='Cuculiformes', ebird_species_code='yebcuc'),
#   EBirdSpecies(common_name='Black-billed Cuckoo', specific_name='erythropthalmus', generic_name='Coccyzus', family_common_name='Cuckoos', family='Cuculidae', order='Cuculiformes', ebird_species_code='bkbcuc'),
#   EBirdSpecies(common_name='Common Nighthawk', specific_name='minor', generic_name='Chordeiles', family_common_name='Nightjars and Allies', family='Caprimulgidae', order='Caprimulgiformes', ebird_species_code='comnig'),
#   EBirdSpecies(common_name='Eastern Whip-poor-will', specific_name='vociferus', generic_name='Antrostomus', family_common_name='Nightjars and Allies', family='Caprimulgidae', order='Caprimulgiformes', ebird_species_code='easwpw1'),
#   EBirdSpecies(common_name='Chimney Swift', specific_name='pelagica', generic_name='Chaetura', family_common_name='Swifts', family='Apodidae', order='Apodiformes', ebird_species_code='chiswi'),
#   EBirdSpecies(common_name='Ruby-throated Hummingbird', specific_name='colubris', generic_name='Archilochus', family_common_name='Hummingbirds', family='Trochilidae', order='Apodiformes', ebird_species_code='rthhum'),
#   EBirdSpecies(common_name="Anna's Hummingbird", specific_name='anna', generic_name='Calypte', family_common_name='Hummingbirds', family='Trochilidae', order='Apodiformes', ebird_species_code='annhum'),
#   EBirdSpecies(common_name='Calliope Hummingbird', specific_name='calliope', generic_name='Selasphorus', family_common_name='Hummingbirds', family='Trochilidae', order='Apodiformes', ebird_species_code='calhum'),
#   EBirdSpecies(common_name='Rufous Hummingbird', specific_name='rufus', generic_name='Selasphorus', family_common_name='Hummingbirds', family='Trochilidae', order='Apodiformes', ebird_species_code='rufhum'),
#   EBirdSpecies(common_name='King Rail', specific_name='elegans', generic_name='Rallus', family_common_name='Rails, Gallinules, and Coots', family='Rallidae', order='Gruiformes', ebird_species_code='kinrai4'),
#   EBirdSpecies(common_name='Virginia Rail', specific_name='limicola', generic_name='Rallus', family_common_name='Rails, Gallinules, and Coots', family='Rallidae', order='Gruiformes', ebird_species_code='virrai'),
#   EBirdSpecies(common_name='Sora', specific_name='carolina', generic_name='Porzana', family_common_name='Rails, Gallinules, and Coots', family='Rallidae', order='Gruiformes', ebird_species_code='sora'),
#   EBirdSpecies(common_name='Common Gallinule', specific_name='galeata', generic_name='Gallinula', family_common_name='Rails, Gallinules, and Coots', family='Rallidae', order='Gruiformes', ebird_species_code='comgal1'),
#   EBirdSpecies(common_name='American Coot', specific_name='americana', generic_name='Fulica', family_common_name='Rails, Gallinules, and Coots', family='Rallidae', order='Gruiformes', ebird_species_code='y00475'),
#   EBirdSpecies(common_name='Yellow Rail', specific_name='noveboracensis', generic_name='Coturnicops', family_common_name='Rails, Gallinules, and Coots', family='Rallidae', order='Gruiformes', ebird_species_code='yelrai'),
#   EBirdSpecies(common_name='Sandhill Crane', specific_name='canadensis', generic_name='Antigone', family_common_name='Cranes', family='Gruidae', order='Gruiformes', ebird_species_code='sancra'),
#   EBirdSpecies(common_name='Whooping Crane', specific_name='americana', generic_name='Grus', family_common_name='Cranes', family='Gruidae', order='Gruiformes', ebird_species_code='whocra'),
#   EBirdSpecies(common_name='Black-necked Stilt', specific_name='mexicanus', generic_name='Himantopus', family_common_name='Stilts and Avocets', family='Recurvirostridae', order='Charadriiformes', ebird_species_code='bknsti'),
#   EBirdSpecies(common_name='American Avocet', specific_name='americana', generic_name='Recurvirostra', family_common_name='Stilts and Avocets', family='Recurvirostridae', order='Charadriiformes', ebird_species_code='ameavo'),
#   EBirdSpecies(common_name='Black-bellied Plover', specific_name='squatarola', generic_name='Pluvialis', family_common_name='Plovers and Lapwings', family='Charadriidae', order='Charadriiformes', ebird_species_code='bkbplo'),
#   EBirdSpecies(common_name='American Golden-Plover', specific_name='dominica', generic_name='Pluvialis', family_common_name='Plovers and Lapwings', family='Charadriidae', order='Charadriiformes', ebird_species_code='amgplo'),
#   EBirdSpecies(common_name='Killdeer', specific_name='vociferus', generic_name='Charadrius', family_common_name='Plovers and Lapwings', family='Charadriidae', order='Charadriiformes', ebird_species_code='killde'),
#   EBirdSpecies(common_name='Semipalmated Plover', specific_name='semipalmatus', generic_name='Charadrius', family_common_name='Plovers and Lapwings', family='Charadriidae', order='Charadriiformes', ebird_species_code='semplo'),
#   EBirdSpecies(common_name='Piping Plover', specific_name='melodus', generic_name='Charadrius', family_common_name='Plovers and Lapwings', family='Charadriidae', order='Charadriiformes', ebird_species_code='pipplo'),
#   EBirdSpecies(common_name='Upland Sandpiper', specific_name='longicauda', generic_name='Bartramia', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='uplsan'),
#   EBirdSpecies(common_name='Hudsonian Whimbrel', specific_name='hudsonicus', generic_name='Numenius', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='whimbr3'),
#   EBirdSpecies(common_name='Hudsonian Godwit', specific_name='haemastica', generic_name='Limosa', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='hudgod'),
#   EBirdSpecies(common_name='Marbled Godwit', specific_name='fedoa', generic_name='Limosa', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='margod'),
#   EBirdSpecies(common_name='Short-billed Dowitcher', specific_name='griseus', generic_name='Limnodromus', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='shbdow'),
#   EBirdSpecies(common_name='Long-billed Dowitcher', specific_name='scolopaceus', generic_name='Limnodromus', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='lobdow'),
#   EBirdSpecies(common_name='American Woodcock', specific_name='minor', generic_name='Scolopax', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='amewoo'),
#   EBirdSpecies(common_name="Wilson's Snipe", specific_name='delicata', generic_name='Gallinago', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='wilsni1'),
#   EBirdSpecies(common_name="Wilson's Phalarope", specific_name='tricolor', generic_name='Phalaropus', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='wilpha'),
#   EBirdSpecies(common_name='Red Phalarope', specific_name='fulicarius', generic_name='Phalaropus', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='redpha1'),
#   EBirdSpecies(common_name='Red-necked Phalarope', specific_name='lobatus', generic_name='Phalaropus', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='renpha'),
#   EBirdSpecies(common_name='Spotted Sandpiper', specific_name='macularius', generic_name='Actitis', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='sposan'),
#   EBirdSpecies(common_name='Solitary Sandpiper', specific_name='solitaria', generic_name='Tringa', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='solsan'),
#   EBirdSpecies(common_name='Lesser Yellowlegs', specific_name='flavipes', generic_name='Tringa', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='lesyel'),
#   EBirdSpecies(common_name='Willet', specific_name='semipalmata', generic_name='Tringa', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='willet1'),
#   EBirdSpecies(common_name='Greater Yellowlegs', specific_name='melanoleuca', generic_name='Tringa', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='greyel'),
#   EBirdSpecies(common_name='Ruddy Turnstone', specific_name='interpres', generic_name='Arenaria', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='rudtur'),
#   EBirdSpecies(common_name='Ruff', specific_name='pugnax', generic_name='Calidris', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='ruff'),
#   EBirdSpecies(common_name='Stilt Sandpiper', specific_name='himantopus', generic_name='Calidris', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='stisan'),
#   EBirdSpecies(common_name='Buff-breasted Sandpiper', specific_name='subruficollis', generic_name='Calidris', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='bubsan'),
#   EBirdSpecies(common_name='Sanderling', specific_name='alba', generic_name='Calidris', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='sander'),
#   EBirdSpecies(common_name='Dunlin', specific_name='alpina', generic_name='Calidris', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='dunlin'),
#   EBirdSpecies(common_name="Baird's Sandpiper", specific_name='bairdii', generic_name='Calidris', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='baisan'),
#   EBirdSpecies(common_name='White-rumped Sandpiper', specific_name='fuscicollis', generic_name='Calidris', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='whrsan'),
#   EBirdSpecies(common_name='Least Sandpiper', specific_name='minutilla', generic_name='Calidris', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='leasan'),
#   EBirdSpecies(common_name='Pectoral Sandpiper', specific_name='melanotos', generic_name='Calidris', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='pecsan'),
#   EBirdSpecies(common_name='Western Sandpiper', specific_name='mauri', generic_name='Calidris', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='wessan'),
#   EBirdSpecies(common_name='Semipalmated Sandpiper', specific_name='pusilla', generic_name='Calidris', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='semsan'),
#   EBirdSpecies(common_name='Little Gull', specific_name='minutus', generic_name='Hydrocoloeus', family_common_name='Gulls, Terns, and Skimmers', family='Laridae', order='Charadriiformes', ebird_species_code='litgul'),
#   EBirdSpecies(common_name='Black-legged Kittiwake', specific_name='tridactyla', generic_name='Rissa', family_common_name='Gulls, Terns, and Skimmers', family='Laridae', order='Charadriiformes', ebird_species_code='bklkit'),
#   EBirdSpecies(common_name="Sabine's Gull", specific_name='sabini', generic_name='Xema', family_common_name='Gulls, Terns, and Skimmers', family='Laridae', order='Charadriiformes', ebird_species_code='sabgul'),
#   EBirdSpecies(common_name="Bonaparte's Gull", specific_name='philadelphia', generic_name='Chroicocephalus', family_common_name='Gulls, Terns, and Skimmers', family='Laridae', order='Charadriiformes', ebird_species_code='bongul'),
#   EBirdSpecies(common_name="Franklin's Gull", specific_name='pipixcan', generic_name='Leucophaeus', family_common_name='Gulls, Terns, and Skimmers', family='Laridae', order='Charadriiformes', ebird_species_code='fragul'),
#   EBirdSpecies(common_name='Short-billed Gull', specific_name='brachyrhynchus', generic_name='Larus', family_common_name='Gulls, Terns, and Skimmers', family='Laridae', order='Charadriiformes', ebird_species_code='mewgul2'),
#   EBirdSpecies(common_name='Ring-billed Gull', specific_name='delawarensis', generic_name='Larus', family_common_name='Gulls, Terns, and Skimmers', family='Laridae', order='Charadriiformes', ebird_species_code='ribgul'),
#   EBirdSpecies(common_name='American Herring Gull', specific_name='smithsonianus', generic_name='Larus', family_common_name='Gulls, Terns, and Skimmers', family='Laridae', order='Charadriiformes', ebird_species_code='amhgul1'),
#   EBirdSpecies(common_name='Great Black-backed Gull', specific_name='marinus', generic_name='Larus', family_common_name='Gulls, Terns, and Skimmers', family='Laridae', order='Charadriiformes', ebird_species_code='gbbgul'),
#   EBirdSpecies(common_name='Glaucous Gull', specific_name='hyperboreus', generic_name='Larus', family_common_name='Gulls, Terns, and Skimmers', family='Laridae', order='Charadriiformes', ebird_species_code='glagul'),
#   EBirdSpecies(common_name='Lesser Black-backed Gull', specific_name='fuscus', generic_name='Larus', family_common_name='Gulls, Terns, and Skimmers', family='Laridae', order='Charadriiformes', ebird_species_code='lbbgul'),
#   EBirdSpecies(common_name='California Gull', specific_name='californicus', generic_name='Larus', family_common_name='Gulls, Terns, and Skimmers', family='Laridae', order='Charadriiformes', ebird_species_code='calgul'),
#   EBirdSpecies(common_name='Glaucous-winged Gull', specific_name='glaucescens', generic_name='Larus', family_common_name='Gulls, Terns, and Skimmers', family='Laridae', order='Charadriiformes', ebird_species_code='glwgul'),
#   EBirdSpecies(common_name='Iceland Gull', specific_name='glaucoides', generic_name='Larus', family_common_name='Gulls, Terns, and Skimmers', family='Laridae', order='Charadriiformes', ebird_species_code='y00478'),
#   EBirdSpecies(common_name='Least Tern', specific_name='antillarum', generic_name='Sternula', family_common_name='Gulls, Terns, and Skimmers', family='Laridae', order='Charadriiformes', ebird_species_code='leater1'),
#   EBirdSpecies(common_name='Caspian Tern', specific_name='caspia', generic_name='Hydroprogne', family_common_name='Gulls, Terns, and Skimmers', family='Laridae', order='Charadriiformes', ebird_species_code='caster1'),
#   EBirdSpecies(common_name='Black Tern', specific_name='niger', generic_name='Chlidonias', family_common_name='Gulls, Terns, and Skimmers', family='Laridae', order='Charadriiformes', ebird_species_code='blkter'),
#   EBirdSpecies(common_name="Forster's Tern", specific_name='forsteri', generic_name='Sterna', family_common_name='Gulls, Terns, and Skimmers', family='Laridae', order='Charadriiformes', ebird_species_code='forter'),
#   EBirdSpecies(common_name='Common Tern', specific_name='hirundo', generic_name='Sterna', family_common_name='Gulls, Terns, and Skimmers', family='Laridae', order='Charadriiformes', ebird_species_code='comter'),
#   EBirdSpecies(common_name='Pied-billed Grebe', specific_name='podiceps', generic_name='Podilymbus', family_common_name='Grebes', family='Podicipedidae', order='Podicipediformes', ebird_species_code='pibgre'),
#   EBirdSpecies(common_name='Horned Grebe', specific_name='auritus', generic_name='Podiceps', family_common_name='Grebes', family='Podicipedidae', order='Podicipediformes', ebird_species_code='horgre'),
#   EBirdSpecies(common_name='Red-necked Grebe', specific_name='grisegena', generic_name='Podiceps', family_common_name='Grebes', family='Podicipedidae', order='Podicipediformes', ebird_species_code='rengre'),
#   EBirdSpecies(common_name='Eared Grebe', specific_name='nigricollis', generic_name='Podiceps', family_common_name='Grebes', family='Podicipedidae', order='Podicipediformes', ebird_species_code='eargre'),
#   EBirdSpecies(common_name='Western Grebe', specific_name='occidentalis', generic_name='Aechmophorus', family_common_name='Grebes', family='Podicipedidae', order='Podicipediformes', ebird_species_code='wesgre'),
#   EBirdSpecies(common_name="Clark's Grebe", specific_name='clarkii', generic_name='Aechmophorus', family_common_name='Grebes', family='Podicipedidae', order='Podicipediformes', ebird_species_code='clagre'),
#   EBirdSpecies(common_name='Red-throated Loon', specific_name='stellata', generic_name='Gavia', family_common_name='Loons', family='Gaviidae', order='Gaviiformes', ebird_species_code='retloo'),
#   EBirdSpecies(common_name='Pacific Loon', specific_name='pacifica', generic_name='Gavia', family_common_name='Loons', family='Gaviidae', order='Gaviiformes', ebird_species_code='pacloo'),
#   EBirdSpecies(common_name='Common Loon', specific_name='immer', generic_name='Gavia', family_common_name='Loons', family='Gaviidae', order='Gaviiformes', ebird_species_code='comloo'),
#   EBirdSpecies(common_name='Yellow-billed Loon', specific_name='adamsii', generic_name='Gavia', family_common_name='Loons', family='Gaviidae', order='Gaviiformes', ebird_species_code='yebloo'),
#   EBirdSpecies(common_name='Double-crested Cormorant', specific_name='auritum', generic_name='Nannopterum', family_common_name='Cormorants and Shags', family='Phalacrocoracidae', order='Suliformes', ebird_species_code='doccor'),
#   EBirdSpecies(common_name='Neotropic Cormorant', specific_name='brasilianum', generic_name='Nannopterum', family_common_name='Cormorants and Shags', family='Phalacrocoracidae', order='Suliformes', ebird_species_code='neocor'),
#   EBirdSpecies(common_name='Glossy Ibis', specific_name='falcinellus', generic_name='Plegadis', family_common_name='Ibises and Spoonbills', family='Threskiornithidae', order='Pelecaniformes', ebird_species_code='gloibi'),
#   EBirdSpecies(common_name='White-faced Ibis', specific_name='chihi', generic_name='Plegadis', family_common_name='Ibises and Spoonbills', family='Threskiornithidae', order='Pelecaniformes', ebird_species_code='whfibi'),
#   EBirdSpecies(common_name='Roseate Spoonbill', specific_name='ajaja', generic_name='Platalea', family_common_name='Ibises and Spoonbills', family='Threskiornithidae', order='Pelecaniformes', ebird_species_code='rosspo1'),
#   EBirdSpecies(common_name='American Bittern', specific_name='lentiginosus', generic_name='Botaurus', family_common_name='Herons, Egrets, and Bitterns', family='Ardeidae', order='Pelecaniformes', ebird_species_code='amebit'),
#   EBirdSpecies(common_name='Least Bittern', specific_name='exilis', generic_name='Botaurus', family_common_name='Herons, Egrets, and Bitterns', family='Ardeidae', order='Pelecaniformes', ebird_species_code='leabit'),
#   EBirdSpecies(common_name='Yellow-crowned Night Heron', specific_name='violacea', generic_name='Nyctanassa', family_common_name='Herons, Egrets, and Bitterns', family='Ardeidae', order='Pelecaniformes', ebird_species_code='ycnher'),
#   EBirdSpecies(common_name='Black-crowned Night Heron', specific_name='nycticorax', generic_name='Nycticorax', family_common_name='Herons, Egrets, and Bitterns', family='Ardeidae', order='Pelecaniformes', ebird_species_code='bcnher'),
#   EBirdSpecies(common_name='Little Blue Heron', specific_name='caerulea', generic_name='Egretta', family_common_name='Herons, Egrets, and Bitterns', family='Ardeidae', order='Pelecaniformes', ebird_species_code='libher'),
#   EBirdSpecies(common_name='Tricolored Heron', specific_name='tricolor', generic_name='Egretta', family_common_name='Herons, Egrets, and Bitterns', family='Ardeidae', order='Pelecaniformes', ebird_species_code='triher'),
#   EBirdSpecies(common_name='Snowy Egret', specific_name='thula', generic_name='Egretta', family_common_name='Herons, Egrets, and Bitterns', family='Ardeidae', order='Pelecaniformes', ebird_species_code='snoegr'),
#   EBirdSpecies(common_name='Green Heron', specific_name='virescens', generic_name='Butorides', family_common_name='Herons, Egrets, and Bitterns', family='Ardeidae', order='Pelecaniformes', ebird_species_code='grnher'),
#   EBirdSpecies(common_name='Western Cattle-Egret', specific_name='ibis', generic_name='Ardea', family_common_name='Herons, Egrets, and Bitterns', family='Ardeidae', order='Pelecaniformes', ebird_species_code='categr1'),
#   EBirdSpecies(common_name='Great Egret', specific_name='alba', generic_name='Ardea', family_common_name='Herons, Egrets, and Bitterns', family='Ardeidae', order='Pelecaniformes', ebird_species_code='greegr'),
#   EBirdSpecies(common_name='Great Blue Heron', specific_name='herodias', generic_name='Ardea', family_common_name='Herons, Egrets, and Bitterns', family='Ardeidae', order='Pelecaniformes', ebird_species_code='grbher3'),
#   EBirdSpecies(common_name='American White Pelican', specific_name='erythrorhynchos', generic_name='Pelecanus', family_common_name='Pelicans', family='Pelecanidae', order='Pelecaniformes', ebird_species_code='amwpel'),
#   EBirdSpecies(common_name='Turkey Vulture', specific_name='aura', generic_name='Cathartes', family_common_name='New World Vultures', family='Cathartidae', order='Cathartiformes', ebird_species_code='turvul'),
#   EBirdSpecies(common_name='Osprey', specific_name='haliaetus', generic_name='Pandion', family_common_name='Osprey', family='Pandionidae', order='Accipitriformes', ebird_species_code='osprey'),
#   EBirdSpecies(common_name='Golden Eagle', specific_name='chrysaetos', generic_name='Aquila', family_common_name='Hawks, Eagles, and Kites', family='Accipitridae', order='Accipitriformes', ebird_species_code='goleag'),
#   EBirdSpecies(common_name='Sharp-shinned Hawk', specific_name='striatus', generic_name='Accipiter', family_common_name='Hawks, Eagles, and Kites', family='Accipitridae', order='Accipitriformes', ebird_species_code='shshaw'),
#   EBirdSpecies(common_name="Cooper's Hawk", specific_name='cooperii', generic_name='Astur', family_common_name='Hawks, Eagles, and Kites', family='Accipitridae', order='Accipitriformes', ebird_species_code='coohaw'),
#   EBirdSpecies(common_name='American Goshawk', specific_name='atricapillus', generic_name='Astur', family_common_name='Hawks, Eagles, and Kites', family='Accipitridae', order='Accipitriformes', ebird_species_code='norgos'),
#   EBirdSpecies(common_name='Northern Harrier', specific_name='hudsonius', generic_name='Circus', family_common_name='Hawks, Eagles, and Kites', family='Accipitridae', order='Accipitriformes', ebird_species_code='norhar2'),
#   EBirdSpecies(common_name='Bald Eagle', specific_name='leucocephalus', generic_name='Haliaeetus', family_common_name='Hawks, Eagles, and Kites', family='Accipitridae', order='Accipitriformes', ebird_species_code='baleag'),
#   EBirdSpecies(common_name='Mississippi Kite', specific_name='mississippiensis', generic_name='Ictinia', family_common_name='Hawks, Eagles, and Kites', family='Accipitridae', order='Accipitriformes', ebird_species_code='miskit'),
#   EBirdSpecies(common_name='Broad-winged Hawk', specific_name='platypterus', generic_name='Buteo', family_common_name='Hawks, Eagles, and Kites', family='Accipitridae', order='Accipitriformes', ebird_species_code='brwhaw'),
#   EBirdSpecies(common_name='Red-shouldered Hawk', specific_name='lineatus', generic_name='Buteo', family_common_name='Hawks, Eagles, and Kites', family='Accipitridae', order='Accipitriformes', ebird_species_code='reshaw'),
#   EBirdSpecies(common_name="Swainson's Hawk", specific_name='swainsoni', generic_name='Buteo', family_common_name='Hawks, Eagles, and Kites', family='Accipitridae', order='Accipitriformes', ebird_species_code='swahaw'),
#   EBirdSpecies(common_name='Red-tailed Hawk', specific_name='jamaicensis', generic_name='Buteo', family_common_name='Hawks, Eagles, and Kites', family='Accipitridae', order='Accipitriformes', ebird_species_code='rethaw'),
#   EBirdSpecies(common_name='Rough-legged Hawk', specific_name='lagopus', generic_name='Buteo', family_common_name='Hawks, Eagles, and Kites', family='Accipitridae', order='Accipitriformes', ebird_species_code='rolhaw'),
#   EBirdSpecies(common_name='American Barn Owl', specific_name='furcata', generic_name='Tyto', family_common_name='Barn-Owls', family='Tytonidae', order='Strigiformes', ebird_species_code='brnowl'),
#   EBirdSpecies(common_name='Eastern Screech-Owl', specific_name='asio', generic_name='Megascops', family_common_name='Owls', family='Strigidae', order='Strigiformes', ebird_species_code='easowl1'),
#   EBirdSpecies(common_name='Snowy Owl', specific_name='scandiacus', generic_name='Bubo', family_common_name='Owls', family='Strigidae', order='Strigiformes', ebird_species_code='snoowl1'),
#   EBirdSpecies(common_name='Great Horned Owl', specific_name='virginianus', generic_name='Bubo', family_common_name='Owls', family='Strigidae', order='Strigiformes', ebird_species_code='grhowl'),
#   EBirdSpecies(common_name='Barred Owl', specific_name='varia', generic_name='Strix', family_common_name='Owls', family='Strigidae', order='Strigiformes', ebird_species_code='brdowl'),
#   EBirdSpecies(common_name='Great Gray Owl', specific_name='nebulosa', generic_name='Strix', family_common_name='Owls', family='Strigidae', order='Strigiformes', ebird_species_code='grgowl'),
#   EBirdSpecies(common_name='Long-eared Owl', specific_name='otus', generic_name='Asio', family_common_name='Owls', family='Strigidae', order='Strigiformes', ebird_species_code='loeowl'),
#   EBirdSpecies(common_name='Short-eared Owl', specific_name='flammeus', generic_name='Asio', family_common_name='Owls', family='Strigidae', order='Strigiformes', ebird_species_code='sheowl'),
#   EBirdSpecies(common_name='Northern Saw-whet Owl', specific_name='acadicus', generic_name='Aegolius', family_common_name='Owls', family='Strigidae', order='Strigiformes', ebird_species_code='nswowl'),
#   EBirdSpecies(common_name='Belted Kingfisher', specific_name='alcyon', generic_name='Megaceryle', family_common_name='Kingfishers', family='Alcedinidae', order='Coraciiformes', ebird_species_code='belkin1'),
#   EBirdSpecies(common_name='Yellow-bellied Sapsucker', specific_name='varius', generic_name='Sphyrapicus', family_common_name='Woodpeckers', family='Picidae', order='Piciformes', ebird_species_code='yebsap'),
#   EBirdSpecies(common_name='Red-headed Woodpecker', specific_name='erythrocephalus', generic_name='Melanerpes', family_common_name='Woodpeckers', family='Picidae', order='Piciformes', ebird_species_code='rehwoo'),
#   EBirdSpecies(common_name='Red-bellied Woodpecker', specific_name='carolinus', generic_name='Melanerpes', family_common_name='Woodpeckers', family='Picidae', order='Piciformes', ebird_species_code='rebwoo'),
#   EBirdSpecies(common_name='American Three-toed Woodpecker', specific_name='dorsalis', generic_name='Picoides', family_common_name='Woodpeckers', family='Picidae', order='Piciformes', ebird_species_code='attwoo1'),
#   EBirdSpecies(common_name='Downy Woodpecker', specific_name='pubescens', generic_name='Dryobates', family_common_name='Woodpeckers', family='Picidae', order='Piciformes', ebird_species_code='dowwoo'),
#   EBirdSpecies(common_name='Hairy Woodpecker', specific_name='villosus', generic_name='Leuconotopicus', family_common_name='Woodpeckers', family='Picidae', order='Piciformes', ebird_species_code='haiwoo'),
#   EBirdSpecies(common_name='Pileated Woodpecker', specific_name='pileatus', generic_name='Dryocopus', family_common_name='Woodpeckers', family='Picidae', order='Piciformes', ebird_species_code='pilwoo'),
#   EBirdSpecies(common_name='Northern Flicker', specific_name='auratus', generic_name='Colaptes', family_common_name='Woodpeckers', family='Picidae', order='Piciformes', ebird_species_code='norfli'),
#   EBirdSpecies(common_name='American Kestrel', specific_name='sparverius', generic_name='Falco', family_common_name='Falcons and Caracaras', family='Falconidae', order='Falconiformes', ebird_species_code='amekes'),
#   EBirdSpecies(common_name='Merlin', specific_name='columbarius', generic_name='Falco', family_common_name='Falcons and Caracaras', family='Falconidae', order='Falconiformes', ebird_species_code='merlin'),
#   EBirdSpecies(common_name='Peregrine Falcon', specific_name='peregrinus', generic_name='Falco', family_common_name='Falcons and Caracaras', family='Falconidae', order='Falconiformes', ebird_species_code='perfal'),
#   EBirdSpecies(common_name='Prairie Falcon', specific_name='mexicanus', generic_name='Falco', family_common_name='Falcons and Caracaras', family='Falconidae', order='Falconiformes', ebird_species_code='prafal'),
#   EBirdSpecies(common_name='Budgerigar', specific_name='undulatus', generic_name='Melopsittacus', family_common_name='Old World Parrots', family='Psittaculidae', order='Psittaciformes', ebird_species_code='budger'),
#   EBirdSpecies(common_name='Monk Parakeet', specific_name='monachus', generic_name='Myiopsitta', family_common_name='New World and African Parrots', family='Psittacidae', order='Psittaciformes', ebird_species_code='monpar'),
#   EBirdSpecies(common_name='Olive-sided Flycatcher', specific_name='cooperi', generic_name='Contopus', family_common_name='Tyrant Flycatchers', family='Tyrannidae', order='Passeriformes', ebird_species_code='olsfly'),
#   EBirdSpecies(common_name='Eastern Wood-Pewee', specific_name='virens', generic_name='Contopus', family_common_name='Tyrant Flycatchers', family='Tyrannidae', order='Passeriformes', ebird_species_code='eawpew'),
#   EBirdSpecies(common_name='Yellow-bellied Flycatcher', specific_name='flaviventris', generic_name='Empidonax', family_common_name='Tyrant Flycatchers', family='Tyrannidae', order='Passeriformes', ebird_species_code='yebfly'),
#   EBirdSpecies(common_name='Acadian Flycatcher', specific_name='virescens', generic_name='Empidonax', family_common_name='Tyrant Flycatchers', family='Tyrannidae', order='Passeriformes', ebird_species_code='acafly'),
#   EBirdSpecies(common_name='Alder Flycatcher', specific_name='alnorum', generic_name='Empidonax', family_common_name='Tyrant Flycatchers', family='Tyrannidae', order='Passeriformes', ebird_species_code='aldfly'),
#   EBirdSpecies(common_name='Willow Flycatcher', specific_name='traillii', generic_name='Empidonax', family_common_name='Tyrant Flycatchers', family='Tyrannidae', order='Passeriformes', ebird_species_code='wilfly'),
#   EBirdSpecies(common_name='Least Flycatcher', specific_name='minimus', generic_name='Empidonax', family_common_name='Tyrant Flycatchers', family='Tyrannidae', order='Passeriformes', ebird_species_code='leafly'),
#   EBirdSpecies(common_name='Eastern Phoebe', specific_name='phoebe', generic_name='Sayornis', family_common_name='Tyrant Flycatchers', family='Tyrannidae', order='Passeriformes', ebird_species_code='easpho'),
#   EBirdSpecies(common_name="Say's Phoebe", specific_name='saya', generic_name='Sayornis', family_common_name='Tyrant Flycatchers', family='Tyrannidae', order='Passeriformes', ebird_species_code='saypho'),
#   EBirdSpecies(common_name='Ash-throated Flycatcher', specific_name='cinerascens', generic_name='Myiarchus', family_common_name='Tyrant Flycatchers', family='Tyrannidae', order='Passeriformes', ebird_species_code='astfly'),
#   EBirdSpecies(common_name='Great Crested Flycatcher', specific_name='crinitus', generic_name='Myiarchus', family_common_name='Tyrant Flycatchers', family='Tyrannidae', order='Passeriformes', ebird_species_code='grcfly'),
# ...
#   EBirdSpecies(common_name="Lincoln's Sparrow", specific_name='lincolnii', generic_name='Melospiza', family_common_name='New World Sparrows', family='Passerellidae', order='Passeriformes', ebird_species_code='linspa'),
#   EBirdSpecies(common_name='Swamp Sparrow', specific_name='georgiana', generic_name='Melospiza', family_common_name='New World Sparrows', family='Passerellidae', order='Passeriformes', ebird_species_code='swaspa'),
#   EBirdSpecies(common_name="Abert's Towhee", specific_name='aberti', generic_name='Melozone', family_common_name='New World Sparrows', family='Passerellidae', order='Passeriformes', ebird_species_code='abetow'),
#   EBirdSpecies(common_name='Green-tailed Towhee', specific_name='chlorurus', generic_name='Pipilo', family_common_name='New World Sparrows', family='Passerellidae', order='Passeriformes', ebird_species_code='gnttow'),
#   EBirdSpecies(common_name='Spotted Towhee', specific_name='maculatus', generic_name='Pipilo', family_common_name='New World Sparrows', family='Passerellidae', order='Passeriformes', ebird_species_code='spotow'),
#   EBirdSpecies(common_name='Eastern Towhee', specific_name='erythrophthalmus', generic_name='Pipilo', family_common_name='New World Sparrows', family='Passerellidae', order='Passeriformes', ebird_species_code='eastow'),
#   EBirdSpecies(common_name='Yellow-breasted Chat', specific_name='virens', generic_name='Icteria', family_common_name='Yellow-breasted Chat', family='Icteriidae', order='Passeriformes', ebird_species_code='yebcha'),
#   EBirdSpecies(common_name='Yellow-headed Blackbird', specific_name='xanthocephalus', generic_name='Xanthocephalus', family_common_name='Troupials and Allies', family='Icteridae', order='Passeriformes', ebird_species_code='yehbla'),
#   EBirdSpecies(common_name='Bobolink', specific_name='oryzivorus', generic_name='Dolichonyx', family_common_name='Troupials and Allies', family='Icteridae', order='Passeriformes', ebird_species_code='boboli'),
#   EBirdSpecies(common_name='Western Meadowlark', specific_name='neglecta', generic_name='Sturnella', family_common_name='Troupials and Allies', family='Icteridae', order='Passeriformes', ebird_species_code='wesmea'),
#   EBirdSpecies(common_name='Eastern Meadowlark', specific_name='magna', generic_name='Sturnella', family_common_name='Troupials and Allies', family='Icteridae', order='Passeriformes', ebird_species_code='easmea'),
#   EBirdSpecies(common_name='Orchard Oriole', specific_name='spurius', generic_name='Icterus', family_common_name='Troupials and Allies', family='Icteridae', order='Passeriformes', ebird_species_code='orcori'),
#   EBirdSpecies(common_name="Bullock's Oriole", specific_name='bullockii', generic_name='Icterus', family_common_name='Troupials and Allies', family='Icteridae', order='Passeriformes', ebird_species_code='bulori'),
#   EBirdSpecies(common_name='Baltimore Oriole', specific_name='galbula', generic_name='Icterus', family_common_name='Troupials and Allies', family='Icteridae', order='Passeriformes', ebird_species_code='balori'),
#   EBirdSpecies(common_name="Scott's Oriole", specific_name='parisorum', generic_name='Icterus', family_common_name='Troupials and Allies', family='Icteridae', order='Passeriformes', ebird_species_code='scoori'),
#   EBirdSpecies(common_name='Red-winged Blackbird', specific_name='phoeniceus', generic_name='Agelaius', family_common_name='Troupials and Allies', family='Icteridae', order='Passeriformes', ebird_species_code='rewbla'),
#   EBirdSpecies(common_name='Brown-headed Cowbird', specific_name='ater', generic_name='Molothrus', family_common_name='Troupials and Allies', family='Icteridae', order='Passeriformes', ebird_species_code='bnhcow'),
#   EBirdSpecies(common_name='Rusty Blackbird', specific_name='carolinus', generic_name='Euphagus', family_common_name='Troupials and Allies', family='Icteridae', order='Passeriformes', ebird_species_code='rusbla'),
#   EBirdSpecies(common_name="Brewer's Blackbird", specific_name='cyanocephalus', generic_name='Euphagus', family_common_name='Troupials and Allies', family='Icteridae', order='Passeriformes', ebird_species_code='brebla'),
#   EBirdSpecies(common_name='Common Grackle', specific_name='quiscula', generic_name='Quiscalus', family_common_name='Troupials and Allies', family='Icteridae', order='Passeriformes', ebird_species_code='comgra'),
#   EBirdSpecies(common_name='Great-tailed Grackle', specific_name='mexicanus', generic_name='Quiscalus', family_common_name='Troupials and Allies', family='Icteridae', order='Passeriformes', ebird_species_code='grtgra'),
#   EBirdSpecies(common_name='Ovenbird', specific_name='aurocapilla', generic_name='Seiurus', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='ovenbi1'),
#   EBirdSpecies(common_name='Worm-eating Warbler', specific_name='vermivorum', generic_name='Helmitheros', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='woewar1'),
#   EBirdSpecies(common_name='Louisiana Waterthrush', specific_name='motacilla', generic_name='Parkesia', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='louwat'),
#   EBirdSpecies(common_name='Northern Waterthrush', specific_name='noveboracensis', generic_name='Parkesia', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='norwat'),
#   EBirdSpecies(common_name='Golden-winged Warbler', specific_name='chrysoptera', generic_name='Vermivora', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='gowwar'),
#   EBirdSpecies(common_name='Blue-winged Warbler', specific_name='cyanoptera', generic_name='Vermivora', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='buwwar'),
#   EBirdSpecies(common_name='Black-and-white Warbler', specific_name='varia', generic_name='Mniotilta', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='bawwar'),
#   EBirdSpecies(common_name='Prothonotary Warbler', specific_name='citrea', generic_name='Protonotaria', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='prowar'),
#   EBirdSpecies(common_name="Swainson's Warbler", specific_name='swainsonii', generic_name='Limnothlypis', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='swawar'),
#   EBirdSpecies(common_name='Tennessee Warbler', specific_name='peregrina', generic_name='Leiothlypis', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='tenwar'),
#   EBirdSpecies(common_name='Orange-crowned Warbler', specific_name='celata', generic_name='Leiothlypis', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='orcwar'),
#   EBirdSpecies(common_name='Nashville Warbler', specific_name='ruficapilla', generic_name='Leiothlypis', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='naswar'),
#   EBirdSpecies(common_name='Connecticut Warbler', specific_name='agilis', generic_name='Oporornis', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='conwar'),
#   EBirdSpecies(common_name='Mourning Warbler', specific_name='philadelphia', generic_name='Geothlypis', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='mouwar'),
#   EBirdSpecies(common_name='Kentucky Warbler', specific_name='formosa', generic_name='Geothlypis', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='kenwar'),
#   EBirdSpecies(common_name='Common Yellowthroat', specific_name='trichas', generic_name='Geothlypis', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='comyel'),
#   EBirdSpecies(common_name='Hooded Warbler', specific_name='citrina', generic_name='Setophaga', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='hoowar'),
#   EBirdSpecies(common_name='American Redstart', specific_name='ruticilla', generic_name='Setophaga', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='amered'),
#   EBirdSpecies(common_name="Kirtland's Warbler", specific_name='kirtlandii', generic_name='Setophaga', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='kirwar'),
#   EBirdSpecies(common_name='Cape May Warbler', specific_name='tigrina', generic_name='Setophaga', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='camwar'),
#   EBirdSpecies(common_name='Cerulean Warbler', specific_name='cerulea', generic_name='Setophaga', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='cerwar'),
#   EBirdSpecies(common_name='Northern Parula', specific_name='americana', generic_name='Setophaga', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='norpar'),
#   EBirdSpecies(common_name='Magnolia Warbler', specific_name='magnolia', generic_name='Setophaga', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='magwar'),
#   EBirdSpecies(common_name='Bay-breasted Warbler', specific_name='castanea', generic_name='Setophaga', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='babwar'),
#   EBirdSpecies(common_name='Blackburnian Warbler', specific_name='fusca', generic_name='Setophaga', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='bkbwar'),
#   EBirdSpecies(common_name='Northern Yellow Warbler', specific_name='aestiva', generic_name='Setophaga', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='yelwar1'),
#   EBirdSpecies(common_name='Chestnut-sided Warbler', specific_name='pensylvanica', generic_name='Setophaga', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='chswar'),
#   EBirdSpecies(common_name='Blackpoll Warbler', specific_name='striata', generic_name='Setophaga', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='bkpwar'),
#   EBirdSpecies(common_name='Black-throated Blue Warbler', specific_name='caerulescens', generic_name='Setophaga', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='btbwar'),
#   EBirdSpecies(common_name='Palm Warbler', specific_name='palmarum', generic_name='Setophaga', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='palwar'),
#   EBirdSpecies(common_name='Pine Warbler', specific_name='pinus', generic_name='Setophaga', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='pinwar'),
#   EBirdSpecies(common_name='Yellow-rumped Warbler', specific_name='coronata', generic_name='Setophaga', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='yerwar'),
#   EBirdSpecies(common_name='Yellow-throated Warbler', specific_name='dominica', generic_name='Setophaga', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='yetwar'),
#   EBirdSpecies(common_name='Prairie Warbler', specific_name='discolor', generic_name='Setophaga', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='prawar'),
#   EBirdSpecies(common_name='Black-throated Gray Warbler', specific_name='nigrescens', generic_name='Setophaga', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='btywar'),
#   EBirdSpecies(common_name="Townsend's Warbler", specific_name='townsendi', generic_name='Setophaga', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='towwar'),
#   EBirdSpecies(common_name='Hermit Warbler', specific_name='occidentalis', generic_name='Setophaga', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='herwar'),
#   EBirdSpecies(common_name='Black-throated Green Warbler', specific_name='virens', generic_name='Setophaga', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='btnwar'),
#   EBirdSpecies(common_name='Canada Warbler', specific_name='canadensis', generic_name='Cardellina', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='canwar'),
#   EBirdSpecies(common_name="Wilson's Warbler", specific_name='pusilla', generic_name='Cardellina', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='wlswar'),
#   EBirdSpecies(common_name='Painted Redstart', specific_name='pictus', generic_name='Myioborus', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='paired'),
#   EBirdSpecies(common_name='Summer Tanager', specific_name='rubra', generic_name='Piranga', family_common_name='Cardinals and Allies', family='Cardinalidae', order='Passeriformes', ebird_species_code='sumtan'),
#   EBirdSpecies(common_name='Scarlet Tanager', specific_name='olivacea', generic_name='Piranga', family_common_name='Cardinals and Allies', family='Cardinalidae', order='Passeriformes', ebird_species_code='scatan'),
#   EBirdSpecies(common_name='Western Tanager', specific_name='ludoviciana', generic_name='Piranga', family_common_name='Cardinals and Allies', family='Cardinalidae', order='Passeriformes', ebird_species_code='westan'),
#   EBirdSpecies(common_name='Northern Cardinal', specific_name='cardinalis', generic_name='Cardinalis', family_common_name='Cardinals and Allies', family='Cardinalidae', order='Passeriformes', ebird_species_code='norcar'),
#   EBirdSpecies(common_name='Rose-breasted Grosbeak', specific_name='ludovicianus', generic_name='Pheucticus', family_common_name='Cardinals and Allies', family='Cardinalidae', order='Passeriformes', ebird_species_code='robgro'),
#   EBirdSpecies(common_name='Black-headed Grosbeak', specific_name='melanocephalus', generic_name='Pheucticus', family_common_name='Cardinals and Allies', family='Cardinalidae', order='Passeriformes', ebird_species_code='bkhgro'),
#   EBirdSpecies(common_name='Blue Grosbeak', specific_name='caerulea', generic_name='Passerina', family_common_name='Cardinals and Allies', family='Cardinalidae', order='Passeriformes', ebird_species_code='blugrb1'),
#   EBirdSpecies(common_name='Lazuli Bunting', specific_name='amoena', generic_name='Passerina', family_common_name='Cardinals and Allies', family='Cardinalidae', order='Passeriformes', ebird_species_code='lazbun'),
#   EBirdSpecies(common_name='Indigo Bunting', specific_name='cyanea', generic_name='Passerina', family_common_name='Cardinals and Allies', family='Cardinalidae', order='Passeriformes', ebird_species_code='indbun'),
#   EBirdSpecies(common_name='Painted Bunting', specific_name='ciris', generic_name='Passerina', family_common_name='Cardinals and Allies', family='Cardinalidae', order='Passeriformes', ebird_species_code='paibun'),
#   EBirdSpecies(common_name='Dickcissel', specific_name='americana', generic_name='Spiza', family_common_name='Cardinals and Allies', family='Cardinalidae', order='Passeriformes', ebird_species_code='dickci')]]

# %%
region_to_species = dict(zip(regions, species_per_region, strict=True))
region_to_species_yaml = {
    r: [s.to_yaml() for s in species_list] for r, species_list in region_to_species.items()
}
region_to_species_yaml
# Out:
# {'Minneapolis, Minnesota, United States': [{'common_name': 'Black-bellied Whistling-Duck',
#    'scientific_name': 'Dendrocygna autumnalis',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'bbwduc'},
#   {'common_name': 'Snow Goose',
#    'scientific_name': 'Anser caerulescens',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'snogoo'},
#   {'common_name': "Ross's Goose",
#    'scientific_name': 'Anser rossii',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'rosgoo'},
#   {'common_name': 'Greater White-fronted Goose',
#    'scientific_name': 'Anser albifrons',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'gwfgoo'},
#   {'common_name': 'Cackling Goose',
#    'scientific_name': 'Branta hutchinsii',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'cacgoo1'},
#   {'common_name': 'Canada Goose',
#    'scientific_name': 'Branta canadensis',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'cangoo'},
#   {'common_name': 'Mute Swan',
#    'scientific_name': 'Cygnus olor',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'mutswa'},
#   {'common_name': 'Black Swan',
#    'scientific_name': 'Cygnus atratus',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'blkswa'},
#   {'common_name': 'Trumpeter Swan',
#    'scientific_name': 'Cygnus buccinator',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'truswa'},
#   {'common_name': 'Tundra Swan',
#    'scientific_name': 'Cygnus columbianus',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'tunswa'},
#   {'common_name': 'Whooper Swan',
#    'scientific_name': 'Cygnus cygnus',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'whoswa'},
#   {'common_name': 'Muscovy Duck',
#    'scientific_name': 'Cairina moschata',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'musduc'},
#   {'common_name': 'Wood Duck',
#    'scientific_name': 'Aix sponsa',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'wooduc'},
#   {'common_name': 'Blue-winged Teal',
#    'scientific_name': 'Spatula discors',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'buwtea'},
#   {'common_name': 'Cinnamon Teal',
#    'scientific_name': 'Spatula cyanoptera',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'cintea'},
#   {'common_name': 'Northern Shoveler',
#    'scientific_name': 'Spatula clypeata',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'norsho'},
#   {'common_name': 'Gadwall',
#    'scientific_name': 'Mareca strepera',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'gadwal'},
#   {'common_name': 'Eurasian Wigeon',
#    'scientific_name': 'Mareca penelope',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'eurwig'},
#   {'common_name': 'American Wigeon',
#    'scientific_name': 'Mareca americana',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'amewig'},
#   {'common_name': 'Mallard',
#    'scientific_name': 'Anas platyrhynchos',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'mallar3'},
#   {'common_name': 'American Black Duck',
#    'scientific_name': 'Anas rubripes',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'ambduc'},
#   {'common_name': 'Mottled Duck',
#    'scientific_name': 'Anas fulvigula',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'motduc'},
#   {'common_name': 'Northern Pintail',
#    'scientific_name': 'Anas acuta',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'norpin'},
#   {'common_name': 'Green-winged Teal',
#    'scientific_name': 'Anas crecca',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'gnwtea'},
#   {'common_name': 'Canvasback',
#    'scientific_name': 'Aythya valisineria',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'canvas'},
#   {'common_name': 'Redhead',
#    'scientific_name': 'Aythya americana',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'redhea'},
#   {'common_name': 'Ring-necked Duck',
#    'scientific_name': 'Aythya collaris',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'rinduc'},
#   {'common_name': 'Greater Scaup',
#    'scientific_name': 'Aythya marila',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'gresca'},
#   {'common_name': 'Lesser Scaup',
#    'scientific_name': 'Aythya affinis',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'lessca'},
#   {'common_name': 'Harlequin Duck',
#    'scientific_name': 'Histrionicus histrionicus',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'harduc'},
#   {'common_name': 'Surf Scoter',
#    'scientific_name': 'Melanitta perspicillata',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'sursco'},
#   {'common_name': 'White-winged Scoter',
#    'scientific_name': 'Melanitta deglandi',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'whwsco2'},
#   {'common_name': 'Black Scoter',
#    'scientific_name': 'Melanitta americana',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'blksco2'},
#   {'common_name': 'Long-tailed Duck',
#    'scientific_name': 'Clangula hyemalis',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'lotduc'},
#   {'common_name': 'Bufflehead',
#    'scientific_name': 'Bucephala albeola',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'buffle'},
#   {'common_name': 'Common Goldeneye',
#    'scientific_name': 'Bucephala clangula',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'comgol'},
#   {'common_name': "Barrow's Goldeneye",
#    'scientific_name': 'Bucephala islandica',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'bargol'},
#   {'common_name': 'Hooded Merganser',
#    'scientific_name': 'Lophodytes cucullatus',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'hoomer'},
#   {'common_name': 'Common Merganser',
#    'scientific_name': 'Mergus merganser',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'commer'},
#   {'common_name': 'Red-breasted Merganser',
#    'scientific_name': 'Mergus serrator',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'rebmer'},
#   {'common_name': 'Ruddy Duck',
#    'scientific_name': 'Oxyura jamaicensis',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'rudduc'},
#   {'common_name': 'Northern Bobwhite',
#    'scientific_name': 'Colinus virginianus',
#    'family_common_name': 'New World Quail',
#    'family': 'Odontophoridae',
#    'order': 'Galliformes',
#    'ebird_species_code': 'norbob'},
#   {'common_name': 'Wild Turkey',
#    'scientific_name': 'Meleagris gallopavo',
#    'family_common_name': 'Pheasants, Grouse, and Allies',
#    'family': 'Phasianidae',
#    'order': 'Galliformes',
#    'ebird_species_code': 'wiltur'},
#   {'common_name': 'Ring-necked Pheasant',
#    'scientific_name': 'Phasianus colchicus',
#    'family_common_name': 'Pheasants, Grouse, and Allies',
#    'family': 'Phasianidae',
#    'order': 'Galliformes',
#    'ebird_species_code': 'rinphe1'},
#   {'common_name': 'Green Pheasant',
#    'scientific_name': 'Phasianus versicolor',
#    'family_common_name': 'Pheasants, Grouse, and Allies',
#    'family': 'Phasianidae',
#    'order': 'Galliformes',
#    'ebird_species_code': 'rinphe2'},
#   {'common_name': 'Silver Pheasant',
#    'scientific_name': 'Lophura nycthemera',
#    'family_common_name': 'Pheasants, Grouse, and Allies',
#    'family': 'Phasianidae',
#    'order': 'Galliformes',
#    'ebird_species_code': 'silphe'},
#   {'common_name': 'Indian Peafowl',
#    'scientific_name': 'Pavo cristatus',
#    'family_common_name': 'Pheasants, Grouse, and Allies',
#    'family': 'Phasianidae',
#    'order': 'Galliformes',
#    'ebird_species_code': 'compea'},
#   {'common_name': 'Chukar',
#    'scientific_name': 'Alectoris chukar',
#    'family_common_name': 'Pheasants, Grouse, and Allies',
#    'family': 'Phasianidae',
#    'order': 'Galliformes',
#    'ebird_species_code': 'chukar'},
#   {'common_name': 'Rock Pigeon',
#    'scientific_name': 'Columba livia',
#    'family_common_name': 'Pigeons and Doves',
#    'family': 'Columbidae',
#    'order': 'Columbiformes',
#    'ebird_species_code': 'rocpig'},
#   {'common_name': 'Band-tailed Pigeon',
#    'scientific_name': 'Patagioenas fasciata',
#    'family_common_name': 'Pigeons and Doves',
#    'family': 'Columbidae',
#    'order': 'Columbiformes',
#    'ebird_species_code': 'batpig1'},
#   {'common_name': 'Passenger Pigeon',
#    'scientific_name': 'Ectopistes migratorius',
#    'family_common_name': 'Pigeons and Doves',
#    'family': 'Columbidae',
#    'order': 'Columbiformes',
#    'ebird_species_code': 'paspig'},
#   {'common_name': 'Eurasian Collared-Dove',
#    'scientific_name': 'Streptopelia decaocto',
#    'family_common_name': 'Pigeons and Doves',
#    'family': 'Columbidae',
#    'order': 'Columbiformes',
#    'ebird_species_code': 'eucdov'},
#   {'common_name': 'Spotted Dove',
#    'scientific_name': 'Spilopelia chinensis',
#    'family_common_name': 'Pigeons and Doves',
#    'family': 'Columbidae',
#    'order': 'Columbiformes',
#    'ebird_species_code': 'spodov'},
#   {'common_name': 'Common Ground Dove',
#    'scientific_name': 'Columbina passerina',
#    'family_common_name': 'Pigeons and Doves',
#    'family': 'Columbidae',
#    'order': 'Columbiformes',
#    'ebird_species_code': 'cogdov'},
#   {'common_name': 'White-winged Dove',
#    'scientific_name': 'Zenaida asiatica',
#    'family_common_name': 'Pigeons and Doves',
#    'family': 'Columbidae',
#    'order': 'Columbiformes',
#    'ebird_species_code': 'whwdov'},
#   {'common_name': 'Mourning Dove',
#    'scientific_name': 'Zenaida macroura',
#    'family_common_name': 'Pigeons and Doves',
#    'family': 'Columbidae',
#    'order': 'Columbiformes',
#    'ebird_species_code': 'moudov'},
#   {'common_name': 'Yellow-billed Cuckoo',
#    'scientific_name': 'Coccyzus americanus',
#    'family_common_name': 'Cuckoos',
#    'family': 'Cuculidae',
#    'order': 'Cuculiformes',
#    'ebird_species_code': 'yebcuc'},
#   {'common_name': 'Black-billed Cuckoo',
#    'scientific_name': 'Coccyzus erythropthalmus',
#    'family_common_name': 'Cuckoos',
#    'family': 'Cuculidae',
#    'order': 'Cuculiformes',
#    'ebird_species_code': 'bkbcuc'},
#   {'common_name': 'Common Nighthawk',
#    'scientific_name': 'Chordeiles minor',
#    'family_common_name': 'Nightjars and Allies',
#    'family': 'Caprimulgidae',
#    'order': 'Caprimulgiformes',
#    'ebird_species_code': 'comnig'},
#   {'common_name': 'Eastern Whip-poor-will',
#    'scientific_name': 'Antrostomus vociferus',
#    'family_common_name': 'Nightjars and Allies',
#    'family': 'Caprimulgidae',
#    'order': 'Caprimulgiformes',
#    'ebird_species_code': 'easwpw1'},
#   {'common_name': 'Chimney Swift',
#    'scientific_name': 'Chaetura pelagica',
#    'family_common_name': 'Swifts',
#    'family': 'Apodidae',
#    'order': 'Apodiformes',
#    'ebird_species_code': 'chiswi'},
#   {'common_name': 'Ruby-throated Hummingbird',
#    'scientific_name': 'Archilochus colubris',
#    'family_common_name': 'Hummingbirds',
#    'family': 'Trochilidae',
#    'order': 'Apodiformes',
#    'ebird_species_code': 'rthhum'},
#   {'common_name': "Anna's Hummingbird",
#    'scientific_name': 'Calypte anna',
#    'family_common_name': 'Hummingbirds',
#    'family': 'Trochilidae',
#    'order': 'Apodiformes',
#    'ebird_species_code': 'annhum'},
#   {'common_name': 'Calliope Hummingbird',
#    'scientific_name': 'Selasphorus calliope',
#    'family_common_name': 'Hummingbirds',
#    'family': 'Trochilidae',
#    'order': 'Apodiformes',
#    'ebird_species_code': 'calhum'},
#   {'common_name': 'Rufous Hummingbird',
#    'scientific_name': 'Selasphorus rufus',
#    'family_common_name': 'Hummingbirds',
#    'family': 'Trochilidae',
#    'order': 'Apodiformes',
#    'ebird_species_code': 'rufhum'},
#   {'common_name': 'King Rail',
#    'scientific_name': 'Rallus elegans',
#    'family_common_name': 'Rails, Gallinules, and Coots',
#    'family': 'Rallidae',
#    'order': 'Gruiformes',
#    'ebird_species_code': 'kinrai4'},
#   {'common_name': 'Virginia Rail',
#    'scientific_name': 'Rallus limicola',
#    'family_common_name': 'Rails, Gallinules, and Coots',
#    'family': 'Rallidae',
#    'order': 'Gruiformes',
#    'ebird_species_code': 'virrai'},
#   {'common_name': 'Sora',
#    'scientific_name': 'Porzana carolina',
#    'family_common_name': 'Rails, Gallinules, and Coots',
#    'family': 'Rallidae',
#    'order': 'Gruiformes',
#    'ebird_species_code': 'sora'},
#   {'common_name': 'Common Gallinule',
#    'scientific_name': 'Gallinula galeata',
#    'family_common_name': 'Rails, Gallinules, and Coots',
#    'family': 'Rallidae',
#    'order': 'Gruiformes',
#    'ebird_species_code': 'comgal1'},
#   {'common_name': 'American Coot',
#    'scientific_name': 'Fulica americana',
#    'family_common_name': 'Rails, Gallinules, and Coots',
#    'family': 'Rallidae',
#    'order': 'Gruiformes',
#    'ebird_species_code': 'y00475'},
#   {'common_name': 'Yellow Rail',
#    'scientific_name': 'Coturnicops noveboracensis',
#    'family_common_name': 'Rails, Gallinules, and Coots',
#    'family': 'Rallidae',
#    'order': 'Gruiformes',
#    'ebird_species_code': 'yelrai'},
#   {'common_name': 'Sandhill Crane',
#    'scientific_name': 'Antigone canadensis',
#    'family_common_name': 'Cranes',
#    'family': 'Gruidae',
#    'order': 'Gruiformes',
#    'ebird_species_code': 'sancra'},
#   {'common_name': 'Whooping Crane',
#    'scientific_name': 'Grus americana',
#    'family_common_name': 'Cranes',
#    'family': 'Gruidae',
#    'order': 'Gruiformes',
#    'ebird_species_code': 'whocra'},
#   {'common_name': 'Black-necked Stilt',
#    'scientific_name': 'Himantopus mexicanus',
#    'family_common_name': 'Stilts and Avocets',
#    'family': 'Recurvirostridae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'bknsti'},
#   {'common_name': 'American Avocet',
#    'scientific_name': 'Recurvirostra americana',
#    'family_common_name': 'Stilts and Avocets',
#    'family': 'Recurvirostridae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'ameavo'},
#   {'common_name': 'Black-bellied Plover',
#    'scientific_name': 'Pluvialis squatarola',
#    'family_common_name': 'Plovers and Lapwings',
#    'family': 'Charadriidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'bkbplo'},
#   {'common_name': 'American Golden-Plover',
#    'scientific_name': 'Pluvialis dominica',
#    'family_common_name': 'Plovers and Lapwings',
#    'family': 'Charadriidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'amgplo'},
#   {'common_name': 'Killdeer',
#    'scientific_name': 'Charadrius vociferus',
#    'family_common_name': 'Plovers and Lapwings',
#    'family': 'Charadriidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'killde'},
#   {'common_name': 'Semipalmated Plover',
#    'scientific_name': 'Charadrius semipalmatus',
#    'family_common_name': 'Plovers and Lapwings',
#    'family': 'Charadriidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'semplo'},
#   {'common_name': 'Piping Plover',
#    'scientific_name': 'Charadrius melodus',
#    'family_common_name': 'Plovers and Lapwings',
#    'family': 'Charadriidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'pipplo'},
#   {'common_name': 'Upland Sandpiper',
#    'scientific_name': 'Bartramia longicauda',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'uplsan'},
#   {'common_name': 'Hudsonian Whimbrel',
#    'scientific_name': 'Numenius hudsonicus',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'whimbr3'},
#   {'common_name': 'Hudsonian Godwit',
#    'scientific_name': 'Limosa haemastica',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'hudgod'},
#   {'common_name': 'Marbled Godwit',
#    'scientific_name': 'Limosa fedoa',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'margod'},
#   {'common_name': 'Short-billed Dowitcher',
#    'scientific_name': 'Limnodromus griseus',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'shbdow'},
#   {'common_name': 'Long-billed Dowitcher',
#    'scientific_name': 'Limnodromus scolopaceus',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'lobdow'},
#   {'common_name': 'American Woodcock',
#    'scientific_name': 'Scolopax minor',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'amewoo'},
#   {'common_name': "Wilson's Snipe",
#    'scientific_name': 'Gallinago delicata',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'wilsni1'},
#   {'common_name': "Wilson's Phalarope",
#    'scientific_name': 'Phalaropus tricolor',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'wilpha'},
#   {'common_name': 'Red Phalarope',
#    'scientific_name': 'Phalaropus fulicarius',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'redpha1'},
#   {'common_name': 'Red-necked Phalarope',
#    'scientific_name': 'Phalaropus lobatus',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'renpha'},
#   {'common_name': 'Spotted Sandpiper',
#    'scientific_name': 'Actitis macularius',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'sposan'},
#   {'common_name': 'Solitary Sandpiper',
#    'scientific_name': 'Tringa solitaria',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'solsan'},
#   {'common_name': 'Lesser Yellowlegs',
#    'scientific_name': 'Tringa flavipes',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'lesyel'},
#   {'common_name': 'Willet',
#    'scientific_name': 'Tringa semipalmata',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'willet1'},
#   {'common_name': 'Greater Yellowlegs',
#    'scientific_name': 'Tringa melanoleuca',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'greyel'},
#   {'common_name': 'Ruddy Turnstone',
#    'scientific_name': 'Arenaria interpres',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'rudtur'},
#   {'common_name': 'Ruff',
#    'scientific_name': 'Calidris pugnax',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'ruff'},
#   {'common_name': 'Stilt Sandpiper',
#    'scientific_name': 'Calidris himantopus',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'stisan'},
#   {'common_name': 'Buff-breasted Sandpiper',
#    'scientific_name': 'Calidris subruficollis',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'bubsan'},
#   {'common_name': 'Sanderling',
#    'scientific_name': 'Calidris alba',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'sander'},
#   {'common_name': 'Dunlin',
#    'scientific_name': 'Calidris alpina',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'dunlin'},
#   {'common_name': "Baird's Sandpiper",
#    'scientific_name': 'Calidris bairdii',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'baisan'},
#   {'common_name': 'White-rumped Sandpiper',
#    'scientific_name': 'Calidris fuscicollis',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'whrsan'},
#   {'common_name': 'Least Sandpiper',
#    'scientific_name': 'Calidris minutilla',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'leasan'},
#   {'common_name': 'Pectoral Sandpiper',
#    'scientific_name': 'Calidris melanotos',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'pecsan'},
#   {'common_name': 'Western Sandpiper',
#    'scientific_name': 'Calidris mauri',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'wessan'},
#   {'common_name': 'Semipalmated Sandpiper',
#    'scientific_name': 'Calidris pusilla',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'semsan'},
#   {'common_name': 'Little Gull',
#    'scientific_name': 'Hydrocoloeus minutus',
#    'family_common_name': 'Gulls, Terns, and Skimmers',
#    'family': 'Laridae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'litgul'},
#   {'common_name': 'Black-legged Kittiwake',
#    'scientific_name': 'Rissa tridactyla',
#    'family_common_name': 'Gulls, Terns, and Skimmers',
#    'family': 'Laridae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'bklkit'},
#   {'common_name': "Sabine's Gull",
#    'scientific_name': 'Xema sabini',
#    'family_common_name': 'Gulls, Terns, and Skimmers',
#    'family': 'Laridae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'sabgul'},
#   {'common_name': "Bonaparte's Gull",
#    'scientific_name': 'Chroicocephalus philadelphia',
#    'family_common_name': 'Gulls, Terns, and Skimmers',
#    'family': 'Laridae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'bongul'},
#   {'common_name': "Franklin's Gull",
#    'scientific_name': 'Leucophaeus pipixcan',
#    'family_common_name': 'Gulls, Terns, and Skimmers',
#    'family': 'Laridae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'fragul'},
#   {'common_name': 'Short-billed Gull',
#    'scientific_name': 'Larus brachyrhynchus',
#    'family_common_name': 'Gulls, Terns, and Skimmers',
#    'family': 'Laridae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'mewgul2'},
#   {'common_name': 'Ring-billed Gull',
#    'scientific_name': 'Larus delawarensis',
#    'family_common_name': 'Gulls, Terns, and Skimmers',
#    'family': 'Laridae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'ribgul'},
#   {'common_name': 'American Herring Gull',
#    'scientific_name': 'Larus smithsonianus',
#    'family_common_name': 'Gulls, Terns, and Skimmers',
#    'family': 'Laridae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'amhgul1'},
#   {'common_name': 'Great Black-backed Gull',
#    'scientific_name': 'Larus marinus',
#    'family_common_name': 'Gulls, Terns, and Skimmers',
#    'family': 'Laridae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'gbbgul'},
#   {'common_name': 'Glaucous Gull',
#    'scientific_name': 'Larus hyperboreus',
#    'family_common_name': 'Gulls, Terns, and Skimmers',
#    'family': 'Laridae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'glagul'},
#   {'common_name': 'Lesser Black-backed Gull',
#    'scientific_name': 'Larus fuscus',
#    'family_common_name': 'Gulls, Terns, and Skimmers',
#    'family': 'Laridae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'lbbgul'},
#   {'common_name': 'California Gull',
#    'scientific_name': 'Larus californicus',
#    'family_common_name': 'Gulls, Terns, and Skimmers',
#    'family': 'Laridae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'calgul'},
#   {'common_name': 'Glaucous-winged Gull',
#    'scientific_name': 'Larus glaucescens',
#    'family_common_name': 'Gulls, Terns, and Skimmers',
#    'family': 'Laridae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'glwgul'},
#   {'common_name': 'Iceland Gull',
#    'scientific_name': 'Larus glaucoides',
#    'family_common_name': 'Gulls, Terns, and Skimmers',
#    'family': 'Laridae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'y00478'},
#   {'common_name': 'Least Tern',
#    'scientific_name': 'Sternula antillarum',
#    'family_common_name': 'Gulls, Terns, and Skimmers',
#    'family': 'Laridae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'leater1'},
#   {'common_name': 'Caspian Tern',
#    'scientific_name': 'Hydroprogne caspia',
#    'family_common_name': 'Gulls, Terns, and Skimmers',
#    'family': 'Laridae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'caster1'},
#   {'common_name': 'Black Tern',
#    'scientific_name': 'Chlidonias niger',
#    'family_common_name': 'Gulls, Terns, and Skimmers',
#    'family': 'Laridae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'blkter'},
#   {'common_name': "Forster's Tern",
#    'scientific_name': 'Sterna forsteri',
#    'family_common_name': 'Gulls, Terns, and Skimmers',
#    'family': 'Laridae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'forter'},
#   {'common_name': 'Common Tern',
#    'scientific_name': 'Sterna hirundo',
#    'family_common_name': 'Gulls, Terns, and Skimmers',
#    'family': 'Laridae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'comter'},
#   {'common_name': 'Pied-billed Grebe',
#    'scientific_name': 'Podilymbus podiceps',
#    'family_common_name': 'Grebes',
#    'family': 'Podicipedidae',
#    'order': 'Podicipediformes',
#    'ebird_species_code': 'pibgre'},
#   {'common_name': 'Horned Grebe',
#    'scientific_name': 'Podiceps auritus',
#    'family_common_name': 'Grebes',
#    'family': 'Podicipedidae',
#    'order': 'Podicipediformes',
#    'ebird_species_code': 'horgre'},
#   {'common_name': 'Red-necked Grebe',
#    'scientific_name': 'Podiceps grisegena',
#    'family_common_name': 'Grebes',
#    'family': 'Podicipedidae',
#    'order': 'Podicipediformes',
#    'ebird_species_code': 'rengre'},
#   {'common_name': 'Eared Grebe',
#    'scientific_name': 'Podiceps nigricollis',
#    'family_common_name': 'Grebes',
#    'family': 'Podicipedidae',
#    'order': 'Podicipediformes',
#    'ebird_species_code': 'eargre'},
#   {'common_name': 'Western Grebe',
#    'scientific_name': 'Aechmophorus occidentalis',
#    'family_common_name': 'Grebes',
#    'family': 'Podicipedidae',
#    'order': 'Podicipediformes',
#    'ebird_species_code': 'wesgre'},
#   {'common_name': "Clark's Grebe",
#    'scientific_name': 'Aechmophorus clarkii',
#    'family_common_name': 'Grebes',
#    'family': 'Podicipedidae',
#    'order': 'Podicipediformes',
#    'ebird_species_code': 'clagre'},
#   {'common_name': 'Red-throated Loon',
#    'scientific_name': 'Gavia stellata',
#    'family_common_name': 'Loons',
#    'family': 'Gaviidae',
#    'order': 'Gaviiformes',
#    'ebird_species_code': 'retloo'},
#   {'common_name': 'Pacific Loon',
#    'scientific_name': 'Gavia pacifica',
#    'family_common_name': 'Loons',
#    'family': 'Gaviidae',
#    'order': 'Gaviiformes',
#    'ebird_species_code': 'pacloo'},
#   {'common_name': 'Common Loon',
#    'scientific_name': 'Gavia immer',
#    'family_common_name': 'Loons',
#    'family': 'Gaviidae',
#    'order': 'Gaviiformes',
#    'ebird_species_code': 'comloo'},
#   {'common_name': 'Yellow-billed Loon',
#    'scientific_name': 'Gavia adamsii',
#    'family_common_name': 'Loons',
#    'family': 'Gaviidae',
#    'order': 'Gaviiformes',
#    'ebird_species_code': 'yebloo'},
#   {'common_name': 'Double-crested Cormorant',
#    'scientific_name': 'Nannopterum auritum',
#    'family_common_name': 'Cormorants and Shags',
#    'family': 'Phalacrocoracidae',
#    'order': 'Suliformes',
#    'ebird_species_code': 'doccor'},
#   {'common_name': 'Neotropic Cormorant',
#    'scientific_name': 'Nannopterum brasilianum',
#    'family_common_name': 'Cormorants and Shags',
#    'family': 'Phalacrocoracidae',
#    'order': 'Suliformes',
#    'ebird_species_code': 'neocor'},
#   {'common_name': 'Glossy Ibis',
#    'scientific_name': 'Plegadis falcinellus',
#    'family_common_name': 'Ibises and Spoonbills',
#    'family': 'Threskiornithidae',
#    'order': 'Pelecaniformes',
#    'ebird_species_code': 'gloibi'},
#   {'common_name': 'White-faced Ibis',
#    'scientific_name': 'Plegadis chihi',
#    'family_common_name': 'Ibises and Spoonbills',
#    'family': 'Threskiornithidae',
#    'order': 'Pelecaniformes',
#    'ebird_species_code': 'whfibi'},
#   {'common_name': 'Roseate Spoonbill',
#    'scientific_name': 'Platalea ajaja',
#    'family_common_name': 'Ibises and Spoonbills',
#    'family': 'Threskiornithidae',
#    'order': 'Pelecaniformes',
#    'ebird_species_code': 'rosspo1'},
#   {'common_name': 'American Bittern',
#    'scientific_name': 'Botaurus lentiginosus',
#    'family_common_name': 'Herons, Egrets, and Bitterns',
#    'family': 'Ardeidae',
#    'order': 'Pelecaniformes',
#    'ebird_species_code': 'amebit'},
#   {'common_name': 'Least Bittern',
#    'scientific_name': 'Botaurus exilis',
#    'family_common_name': 'Herons, Egrets, and Bitterns',
#    'family': 'Ardeidae',
#    'order': 'Pelecaniformes',
#    'ebird_species_code': 'leabit'},
#   {'common_name': 'Yellow-crowned Night Heron',
#    'scientific_name': 'Nyctanassa violacea',
#    'family_common_name': 'Herons, Egrets, and Bitterns',
#    'family': 'Ardeidae',
#    'order': 'Pelecaniformes',
#    'ebird_species_code': 'ycnher'},
#   {'common_name': 'Black-crowned Night Heron',
#    'scientific_name': 'Nycticorax nycticorax',
#    'family_common_name': 'Herons, Egrets, and Bitterns',
#    'family': 'Ardeidae',
#    'order': 'Pelecaniformes',
#    'ebird_species_code': 'bcnher'},
#   {'common_name': 'Little Blue Heron',
#    'scientific_name': 'Egretta caerulea',
#    'family_common_name': 'Herons, Egrets, and Bitterns',
#    'family': 'Ardeidae',
#    'order': 'Pelecaniformes',
#    'ebird_species_code': 'libher'},
#   {'common_name': 'Tricolored Heron',
#    'scientific_name': 'Egretta tricolor',
#    'family_common_name': 'Herons, Egrets, and Bitterns',
#    'family': 'Ardeidae',
#    'order': 'Pelecaniformes',
#    'ebird_species_code': 'triher'},
#   {'common_name': 'Snowy Egret',
#    'scientific_name': 'Egretta thula',
#    'family_common_name': 'Herons, Egrets, and Bitterns',
#    'family': 'Ardeidae',
#    'order': 'Pelecaniformes',
#    'ebird_species_code': 'snoegr'},
#   {'common_name': 'Green Heron',
#    'scientific_name': 'Butorides virescens',
#    'family_common_name': 'Herons, Egrets, and Bitterns',
#    'family': 'Ardeidae',
#    'order': 'Pelecaniformes',
#    'ebird_species_code': 'grnher'},
#   {'common_name': 'Western Cattle-Egret',
#    'scientific_name': 'Ardea ibis',
#    'family_common_name': 'Herons, Egrets, and Bitterns',
#    'family': 'Ardeidae',
#    'order': 'Pelecaniformes',
#    'ebird_species_code': 'categr1'},
#   {'common_name': 'Great Egret',
#    'scientific_name': 'Ardea alba',
#    'family_common_name': 'Herons, Egrets, and Bitterns',
#    'family': 'Ardeidae',
#    'order': 'Pelecaniformes',
#    'ebird_species_code': 'greegr'},
#   {'common_name': 'Great Blue Heron',
#    'scientific_name': 'Ardea herodias',
#    'family_common_name': 'Herons, Egrets, and Bitterns',
#    'family': 'Ardeidae',
#    'order': 'Pelecaniformes',
#    'ebird_species_code': 'grbher3'},
#   {'common_name': 'American White Pelican',
#    'scientific_name': 'Pelecanus erythrorhynchos',
#    'family_common_name': 'Pelicans',
#    'family': 'Pelecanidae',
#    'order': 'Pelecaniformes',
#    'ebird_species_code': 'amwpel'},
#   {'common_name': 'Turkey Vulture',
#    'scientific_name': 'Cathartes aura',
#    'family_common_name': 'New World Vultures',
#    'family': 'Cathartidae',
#    'order': 'Cathartiformes',
#    'ebird_species_code': 'turvul'},
#   {'common_name': 'Osprey',
#    'scientific_name': 'Pandion haliaetus',
#    'family_common_name': 'Osprey',
#    'family': 'Pandionidae',
#    'order': 'Accipitriformes',
#    'ebird_species_code': 'osprey'},
#   {'common_name': 'Golden Eagle',
#    'scientific_name': 'Aquila chrysaetos',
#    'family_common_name': 'Hawks, Eagles, and Kites',
#    'family': 'Accipitridae',
#    'order': 'Accipitriformes',
#    'ebird_species_code': 'goleag'},
#   {'common_name': 'Sharp-shinned Hawk',
#    'scientific_name': 'Accipiter striatus',
#    'family_common_name': 'Hawks, Eagles, and Kites',
#    'family': 'Accipitridae',
#    'order': 'Accipitriformes',
#    'ebird_species_code': 'shshaw'},
#   {'common_name': "Cooper's Hawk",
#    'scientific_name': 'Astur cooperii',
#    'family_common_name': 'Hawks, Eagles, and Kites',
#    'family': 'Accipitridae',
#    'order': 'Accipitriformes',
#    'ebird_species_code': 'coohaw'},
#   {'common_name': 'American Goshawk',
#    'scientific_name': 'Astur atricapillus',
#    'family_common_name': 'Hawks, Eagles, and Kites',
#    'family': 'Accipitridae',
#    'order': 'Accipitriformes',
#    'ebird_species_code': 'norgos'},
#   {'common_name': 'Northern Harrier',
#    'scientific_name': 'Circus hudsonius',
#    'family_common_name': 'Hawks, Eagles, and Kites',
#    'family': 'Accipitridae',
#    'order': 'Accipitriformes',
#    'ebird_species_code': 'norhar2'},
#   {'common_name': 'Bald Eagle',
#    'scientific_name': 'Haliaeetus leucocephalus',
#    'family_common_name': 'Hawks, Eagles, and Kites',
#    'family': 'Accipitridae',
#    'order': 'Accipitriformes',
#    'ebird_species_code': 'baleag'},
#   {'common_name': 'Mississippi Kite',
#    'scientific_name': 'Ictinia mississippiensis',
#    'family_common_name': 'Hawks, Eagles, and Kites',
#    'family': 'Accipitridae',
#    'order': 'Accipitriformes',
#    'ebird_species_code': 'miskit'},
#   {'common_name': 'Broad-winged Hawk',
#    'scientific_name': 'Buteo platypterus',
#    'family_common_name': 'Hawks, Eagles, and Kites',
#    'family': 'Accipitridae',
#    'order': 'Accipitriformes',
#    'ebird_species_code': 'brwhaw'},
#   {'common_name': 'Red-shouldered Hawk',
#    'scientific_name': 'Buteo lineatus',
#    'family_common_name': 'Hawks, Eagles, and Kites',
#    'family': 'Accipitridae',
#    'order': 'Accipitriformes',
#    'ebird_species_code': 'reshaw'},
#   {'common_name': "Swainson's Hawk",
#    'scientific_name': 'Buteo swainsoni',
#    'family_common_name': 'Hawks, Eagles, and Kites',
#    'family': 'Accipitridae',
#    'order': 'Accipitriformes',
#    'ebird_species_code': 'swahaw'},
#   {'common_name': 'Red-tailed Hawk',
#    'scientific_name': 'Buteo jamaicensis',
#    'family_common_name': 'Hawks, Eagles, and Kites',
#    'family': 'Accipitridae',
#    'order': 'Accipitriformes',
#    'ebird_species_code': 'rethaw'},
#   {'common_name': 'Rough-legged Hawk',
#    'scientific_name': 'Buteo lagopus',
#    'family_common_name': 'Hawks, Eagles, and Kites',
#    'family': 'Accipitridae',
#    'order': 'Accipitriformes',
#    'ebird_species_code': 'rolhaw'},
#   {'common_name': 'American Barn Owl',
#    'scientific_name': 'Tyto furcata',
#    'family_common_name': 'Barn-Owls',
#    'family': 'Tytonidae',
#    'order': 'Strigiformes',
#    'ebird_species_code': 'brnowl'},
#   {'common_name': 'Eastern Screech-Owl',
#    'scientific_name': 'Megascops asio',
#    'family_common_name': 'Owls',
#    'family': 'Strigidae',
#    'order': 'Strigiformes',
#    'ebird_species_code': 'easowl1'},
#   {'common_name': 'Snowy Owl',
#    'scientific_name': 'Bubo scandiacus',
#    'family_common_name': 'Owls',
#    'family': 'Strigidae',
#    'order': 'Strigiformes',
#    'ebird_species_code': 'snoowl1'},
#   {'common_name': 'Great Horned Owl',
#    'scientific_name': 'Bubo virginianus',
#    'family_common_name': 'Owls',
#    'family': 'Strigidae',
#    'order': 'Strigiformes',
#    'ebird_species_code': 'grhowl'},
#   {'common_name': 'Barred Owl',
#    'scientific_name': 'Strix varia',
#    'family_common_name': 'Owls',
#    'family': 'Strigidae',
#    'order': 'Strigiformes',
#    'ebird_species_code': 'brdowl'},
#   {'common_name': 'Great Gray Owl',
#    'scientific_name': 'Strix nebulosa',
#    'family_common_name': 'Owls',
#    'family': 'Strigidae',
#    'order': 'Strigiformes',
#    'ebird_species_code': 'grgowl'},
#   {'common_name': 'Long-eared Owl',
#    'scientific_name': 'Asio otus',
#    'family_common_name': 'Owls',
#    'family': 'Strigidae',
#    'order': 'Strigiformes',
#    'ebird_species_code': 'loeowl'},
#   {'common_name': 'Short-eared Owl',
#    'scientific_name': 'Asio flammeus',
#    'family_common_name': 'Owls',
#    'family': 'Strigidae',
#    'order': 'Strigiformes',
#    'ebird_species_code': 'sheowl'},
#   {'common_name': 'Northern Saw-whet Owl',
#    'scientific_name': 'Aegolius acadicus',
#    'family_common_name': 'Owls',
#    'family': 'Strigidae',
#    'order': 'Strigiformes',
#    'ebird_species_code': 'nswowl'},
#   {'common_name': 'Belted Kingfisher',
#    'scientific_name': 'Megaceryle alcyon',
#    'family_common_name': 'Kingfishers',
#    'family': 'Alcedinidae',
#    'order': 'Coraciiformes',
#    'ebird_species_code': 'belkin1'},
#   {'common_name': 'Yellow-bellied Sapsucker',
#    'scientific_name': 'Sphyrapicus varius',
#    'family_common_name': 'Woodpeckers',
#    'family': 'Picidae',
#    'order': 'Piciformes',
#    'ebird_species_code': 'yebsap'},
#   {'common_name': 'Red-headed Woodpecker',
#    'scientific_name': 'Melanerpes erythrocephalus',
#    'family_common_name': 'Woodpeckers',
#    'family': 'Picidae',
#    'order': 'Piciformes',
#    'ebird_species_code': 'rehwoo'},
#   {'common_name': 'Red-bellied Woodpecker',
#    'scientific_name': 'Melanerpes carolinus',
#    'family_common_name': 'Woodpeckers',
#    'family': 'Picidae',
#    'order': 'Piciformes',
#    'ebird_species_code': 'rebwoo'},
#   {'common_name': 'American Three-toed Woodpecker',
#    'scientific_name': 'Picoides dorsalis',
#    'family_common_name': 'Woodpeckers',
#    'family': 'Picidae',
#    'order': 'Piciformes',
#    'ebird_species_code': 'attwoo1'},
#   {'common_name': 'Downy Woodpecker',
#    'scientific_name': 'Dryobates pubescens',
#    'family_common_name': 'Woodpeckers',
#    'family': 'Picidae',
#    'order': 'Piciformes',
#    'ebird_species_code': 'dowwoo'},
#   {'common_name': 'Hairy Woodpecker',
#    'scientific_name': 'Leuconotopicus villosus',
#    'family_common_name': 'Woodpeckers',
#    'family': 'Picidae',
#    'order': 'Piciformes',
#    'ebird_species_code': 'haiwoo'},
#   {'common_name': 'Pileated Woodpecker',
#    'scientific_name': 'Dryocopus pileatus',
#    'family_common_name': 'Woodpeckers',
#    'family': 'Picidae',
#    'order': 'Piciformes',
#    'ebird_species_code': 'pilwoo'},
#   {'common_name': 'Northern Flicker',
#    'scientific_name': 'Colaptes auratus',
#    'family_common_name': 'Woodpeckers',
#    'family': 'Picidae',
#    'order': 'Piciformes',
#    'ebird_species_code': 'norfli'},
#   {'common_name': 'American Kestrel',
#    'scientific_name': 'Falco sparverius',
#    'family_common_name': 'Falcons and Caracaras',
#    'family': 'Falconidae',
#    'order': 'Falconiformes',
#    'ebird_species_code': 'amekes'},
#   {'common_name': 'Merlin',
#    'scientific_name': 'Falco columbarius',
#    'family_common_name': 'Falcons and Caracaras',
#    'family': 'Falconidae',
#    'order': 'Falconiformes',
#    'ebird_species_code': 'merlin'},
#   {'common_name': 'Peregrine Falcon',
#    'scientific_name': 'Falco peregrinus',
#    'family_common_name': 'Falcons and Caracaras',
#    'family': 'Falconidae',
#    'order': 'Falconiformes',
#    'ebird_species_code': 'perfal'},
#   {'common_name': 'Prairie Falcon',
#    'scientific_name': 'Falco mexicanus',
#    'family_common_name': 'Falcons and Caracaras',
#    'family': 'Falconidae',
#    'order': 'Falconiformes',
#    'ebird_species_code': 'prafal'},
#   {'common_name': 'Budgerigar',
#    'scientific_name': 'Melopsittacus undulatus',
#    'family_common_name': 'Old World Parrots',
#    'family': 'Psittaculidae',
#    'order': 'Psittaciformes',
#    'ebird_species_code': 'budger'},
#   {'common_name': 'Monk Parakeet',
#    'scientific_name': 'Myiopsitta monachus',
#    'family_common_name': 'New World and African Parrots',
#    'family': 'Psittacidae',
#    'order': 'Psittaciformes',
#    'ebird_species_code': 'monpar'},
#   {'common_name': 'Olive-sided Flycatcher',
#    'scientific_name': 'Contopus cooperi',
#    'family_common_name': 'Tyrant Flycatchers',
#    'family': 'Tyrannidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'olsfly'},
#   {'common_name': 'Eastern Wood-Pewee',
#    'scientific_name': 'Contopus virens',
#    'family_common_name': 'Tyrant Flycatchers',
#    'family': 'Tyrannidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'eawpew'},
#   {'common_name': 'Yellow-bellied Flycatcher',
#    'scientific_name': 'Empidonax flaviventris',
#    'family_common_name': 'Tyrant Flycatchers',
#    'family': 'Tyrannidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'yebfly'},
#   {'common_name': 'Acadian Flycatcher',
#    'scientific_name': 'Empidonax virescens',
#    'family_common_name': 'Tyrant Flycatchers',
#    'family': 'Tyrannidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'acafly'},
#   {'common_name': 'Alder Flycatcher',
#    'scientific_name': 'Empidonax alnorum',
#    'family_common_name': 'Tyrant Flycatchers',
#    'family': 'Tyrannidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'aldfly'},
#   {'common_name': 'Willow Flycatcher',
#    'scientific_name': 'Empidonax traillii',
#    'family_common_name': 'Tyrant Flycatchers',
#    'family': 'Tyrannidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'wilfly'},
#   {'common_name': 'Least Flycatcher',
#    'scientific_name': 'Empidonax minimus',
#    'family_common_name': 'Tyrant Flycatchers',
#    'family': 'Tyrannidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'leafly'},
#   {'common_name': 'Eastern Phoebe',
#    'scientific_name': 'Sayornis phoebe',
#    'family_common_name': 'Tyrant Flycatchers',
#    'family': 'Tyrannidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'easpho'},
#   {'common_name': "Say's Phoebe",
#    'scientific_name': 'Sayornis saya',
#    'family_common_name': 'Tyrant Flycatchers',
#    'family': 'Tyrannidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'saypho'},
#   {'common_name': 'Ash-throated Flycatcher',
#    'scientific_name': 'Myiarchus cinerascens',
#    'family_common_name': 'Tyrant Flycatchers',
#    'family': 'Tyrannidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'astfly'},
#   {'common_name': 'Great Crested Flycatcher',
#    'scientific_name': 'Myiarchus crinitus',
#    'family_common_name': 'Tyrant Flycatchers',
#    'family': 'Tyrannidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'grcfly'},
#   {'common_name': 'Western Kingbird',
#    'scientific_name': 'Tyrannus verticalis',
#    'family_common_name': 'Tyrant Flycatchers',
#    'family': 'Tyrannidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'weskin'},
#   {'common_name': 'Eastern Kingbird',
#    'scientific_name': 'Tyrannus tyrannus',
#    'family_common_name': 'Tyrant Flycatchers',
#    'family': 'Tyrannidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'easkin'},
#   {'common_name': 'White-eyed Vireo',
#    'scientific_name': 'Vireo griseus',
#    'family_common_name': 'Vireos, Shrike-Babblers, and Erpornis',
#    'family': 'Vireonidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'whevir'},
#   {'common_name': "Bell's Vireo",
#    'scientific_name': 'Vireo bellii',
#    'family_common_name': 'Vireos, Shrike-Babblers, and Erpornis',
#    'family': 'Vireonidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'belvir'},
#   {'common_name': 'Yellow-throated Vireo',
#    'scientific_name': 'Vireo flavifrons',
#    'family_common_name': 'Vireos, Shrike-Babblers, and Erpornis',
#    'family': 'Vireonidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'yetvir'},
#   {'common_name': 'Blue-headed Vireo',
#    'scientific_name': 'Vireo solitarius',
#    'family_common_name': 'Vireos, Shrike-Babblers, and Erpornis',
#    'family': 'Vireonidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'buhvir'},
#   {'common_name': 'Philadelphia Vireo',
#    'scientific_name': 'Vireo philadelphicus',
#    'family_common_name': 'Vireos, Shrike-Babblers, and Erpornis',
#    'family': 'Vireonidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'phivir'},
#   {'common_name': 'Eastern Warbling Vireo',
#    'scientific_name': 'Vireo gilvus',
#    'family_common_name': 'Vireos, Shrike-Babblers, and Erpornis',
#    'family': 'Vireonidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'eawvir1'},
#   {'common_name': 'Red-eyed Vireo',
#    'scientific_name': 'Vireo olivaceus',
#    'family_common_name': 'Vireos, Shrike-Babblers, and Erpornis',
#    'family': 'Vireonidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'reevir1'},
#   {'common_name': 'Magpie Shrike',
#    'scientific_name': 'Urolestes melanoleucus',
#    'family_common_name': 'Shrikes',
#    'family': 'Laniidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'magshr1'},
#   {'common_name': 'Loggerhead Shrike',
#    'scientific_name': 'Lanius ludovicianus',
#    'family_common_name': 'Shrikes',
#    'family': 'Laniidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'logshr'},
#   {'common_name': 'Northern Shrike',
#    'scientific_name': 'Lanius borealis',
#    'family_common_name': 'Shrikes',
#    'family': 'Laniidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'norshr4'},
#   {'common_name': 'Canada Jay',
# ...
#    'family': 'Passerellidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'swaspa'},
#   {'common_name': "Abert's Towhee",
#    'scientific_name': 'Melozone aberti',
#    'family_common_name': 'New World Sparrows',
#    'family': 'Passerellidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'abetow'},
#   {'common_name': 'Green-tailed Towhee',
#    'scientific_name': 'Pipilo chlorurus',
#    'family_common_name': 'New World Sparrows',
#    'family': 'Passerellidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'gnttow'},
#   {'common_name': 'Spotted Towhee',
#    'scientific_name': 'Pipilo maculatus',
#    'family_common_name': 'New World Sparrows',
#    'family': 'Passerellidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'spotow'},
#   {'common_name': 'Eastern Towhee',
#    'scientific_name': 'Pipilo erythrophthalmus',
#    'family_common_name': 'New World Sparrows',
#    'family': 'Passerellidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'eastow'},
#   {'common_name': 'Yellow-breasted Chat',
#    'scientific_name': 'Icteria virens',
#    'family_common_name': 'Yellow-breasted Chat',
#    'family': 'Icteriidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'yebcha'},
#   {'common_name': 'Yellow-headed Blackbird',
#    'scientific_name': 'Xanthocephalus xanthocephalus',
#    'family_common_name': 'Troupials and Allies',
#    'family': 'Icteridae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'yehbla'},
#   {'common_name': 'Bobolink',
#    'scientific_name': 'Dolichonyx oryzivorus',
#    'family_common_name': 'Troupials and Allies',
#    'family': 'Icteridae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'boboli'},
#   {'common_name': 'Western Meadowlark',
#    'scientific_name': 'Sturnella neglecta',
#    'family_common_name': 'Troupials and Allies',
#    'family': 'Icteridae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'wesmea'},
#   {'common_name': 'Eastern Meadowlark',
#    'scientific_name': 'Sturnella magna',
#    'family_common_name': 'Troupials and Allies',
#    'family': 'Icteridae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'easmea'},
#   {'common_name': 'Orchard Oriole',
#    'scientific_name': 'Icterus spurius',
#    'family_common_name': 'Troupials and Allies',
#    'family': 'Icteridae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'orcori'},
#   {'common_name': "Bullock's Oriole",
#    'scientific_name': 'Icterus bullockii',
#    'family_common_name': 'Troupials and Allies',
#    'family': 'Icteridae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'bulori'},
#   {'common_name': 'Baltimore Oriole',
#    'scientific_name': 'Icterus galbula',
#    'family_common_name': 'Troupials and Allies',
#    'family': 'Icteridae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'balori'},
#   {'common_name': "Scott's Oriole",
#    'scientific_name': 'Icterus parisorum',
#    'family_common_name': 'Troupials and Allies',
#    'family': 'Icteridae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'scoori'},
#   {'common_name': 'Red-winged Blackbird',
#    'scientific_name': 'Agelaius phoeniceus',
#    'family_common_name': 'Troupials and Allies',
#    'family': 'Icteridae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'rewbla'},
#   {'common_name': 'Brown-headed Cowbird',
#    'scientific_name': 'Molothrus ater',
#    'family_common_name': 'Troupials and Allies',
#    'family': 'Icteridae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'bnhcow'},
#   {'common_name': 'Rusty Blackbird',
#    'scientific_name': 'Euphagus carolinus',
#    'family_common_name': 'Troupials and Allies',
#    'family': 'Icteridae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'rusbla'},
#   {'common_name': "Brewer's Blackbird",
#    'scientific_name': 'Euphagus cyanocephalus',
#    'family_common_name': 'Troupials and Allies',
#    'family': 'Icteridae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'brebla'},
#   {'common_name': 'Common Grackle',
#    'scientific_name': 'Quiscalus quiscula',
#    'family_common_name': 'Troupials and Allies',
#    'family': 'Icteridae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'comgra'},
#   {'common_name': 'Great-tailed Grackle',
#    'scientific_name': 'Quiscalus mexicanus',
#    'family_common_name': 'Troupials and Allies',
#    'family': 'Icteridae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'grtgra'},
#   {'common_name': 'Ovenbird',
#    'scientific_name': 'Seiurus aurocapilla',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'ovenbi1'},
#   {'common_name': 'Worm-eating Warbler',
#    'scientific_name': 'Helmitheros vermivorum',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'woewar1'},
#   {'common_name': 'Louisiana Waterthrush',
#    'scientific_name': 'Parkesia motacilla',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'louwat'},
#   {'common_name': 'Northern Waterthrush',
#    'scientific_name': 'Parkesia noveboracensis',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'norwat'},
#   {'common_name': 'Golden-winged Warbler',
#    'scientific_name': 'Vermivora chrysoptera',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'gowwar'},
#   {'common_name': 'Blue-winged Warbler',
#    'scientific_name': 'Vermivora cyanoptera',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'buwwar'},
#   {'common_name': 'Black-and-white Warbler',
#    'scientific_name': 'Mniotilta varia',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'bawwar'},
#   {'common_name': 'Prothonotary Warbler',
#    'scientific_name': 'Protonotaria citrea',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'prowar'},
#   {'common_name': "Swainson's Warbler",
#    'scientific_name': 'Limnothlypis swainsonii',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'swawar'},
#   {'common_name': 'Tennessee Warbler',
#    'scientific_name': 'Leiothlypis peregrina',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'tenwar'},
#   {'common_name': 'Orange-crowned Warbler',
#    'scientific_name': 'Leiothlypis celata',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'orcwar'},
#   {'common_name': 'Nashville Warbler',
#    'scientific_name': 'Leiothlypis ruficapilla',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'naswar'},
#   {'common_name': 'Connecticut Warbler',
#    'scientific_name': 'Oporornis agilis',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'conwar'},
#   {'common_name': 'Mourning Warbler',
#    'scientific_name': 'Geothlypis philadelphia',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'mouwar'},
#   {'common_name': 'Kentucky Warbler',
#    'scientific_name': 'Geothlypis formosa',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'kenwar'},
#   {'common_name': 'Common Yellowthroat',
#    'scientific_name': 'Geothlypis trichas',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'comyel'},
#   {'common_name': 'Hooded Warbler',
#    'scientific_name': 'Setophaga citrina',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'hoowar'},
#   {'common_name': 'American Redstart',
#    'scientific_name': 'Setophaga ruticilla',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'amered'},
#   {'common_name': "Kirtland's Warbler",
#    'scientific_name': 'Setophaga kirtlandii',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'kirwar'},
#   {'common_name': 'Cape May Warbler',
#    'scientific_name': 'Setophaga tigrina',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'camwar'},
#   {'common_name': 'Cerulean Warbler',
#    'scientific_name': 'Setophaga cerulea',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'cerwar'},
#   {'common_name': 'Northern Parula',
#    'scientific_name': 'Setophaga americana',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'norpar'},
#   {'common_name': 'Magnolia Warbler',
#    'scientific_name': 'Setophaga magnolia',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'magwar'},
#   {'common_name': 'Bay-breasted Warbler',
#    'scientific_name': 'Setophaga castanea',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'babwar'},
#   {'common_name': 'Blackburnian Warbler',
#    'scientific_name': 'Setophaga fusca',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'bkbwar'},
#   {'common_name': 'Northern Yellow Warbler',
#    'scientific_name': 'Setophaga aestiva',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'yelwar1'},
#   {'common_name': 'Chestnut-sided Warbler',
#    'scientific_name': 'Setophaga pensylvanica',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'chswar'},
#   {'common_name': 'Blackpoll Warbler',
#    'scientific_name': 'Setophaga striata',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'bkpwar'},
#   {'common_name': 'Black-throated Blue Warbler',
#    'scientific_name': 'Setophaga caerulescens',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'btbwar'},
#   {'common_name': 'Palm Warbler',
#    'scientific_name': 'Setophaga palmarum',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'palwar'},
#   {'common_name': 'Pine Warbler',
#    'scientific_name': 'Setophaga pinus',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'pinwar'},
#   {'common_name': 'Yellow-rumped Warbler',
#    'scientific_name': 'Setophaga coronata',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'yerwar'},
#   {'common_name': 'Yellow-throated Warbler',
#    'scientific_name': 'Setophaga dominica',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'yetwar'},
#   {'common_name': 'Prairie Warbler',
#    'scientific_name': 'Setophaga discolor',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'prawar'},
#   {'common_name': 'Black-throated Gray Warbler',
#    'scientific_name': 'Setophaga nigrescens',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'btywar'},
#   {'common_name': "Townsend's Warbler",
#    'scientific_name': 'Setophaga townsendi',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'towwar'},
#   {'common_name': 'Hermit Warbler',
#    'scientific_name': 'Setophaga occidentalis',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'herwar'},
#   {'common_name': 'Black-throated Green Warbler',
#    'scientific_name': 'Setophaga virens',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'btnwar'},
#   {'common_name': 'Canada Warbler',
#    'scientific_name': 'Cardellina canadensis',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'canwar'},
#   {'common_name': "Wilson's Warbler",
#    'scientific_name': 'Cardellina pusilla',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'wlswar'},
#   {'common_name': 'Painted Redstart',
#    'scientific_name': 'Myioborus pictus',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'paired'},
#   {'common_name': 'Summer Tanager',
#    'scientific_name': 'Piranga rubra',
#    'family_common_name': 'Cardinals and Allies',
#    'family': 'Cardinalidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'sumtan'},
#   {'common_name': 'Scarlet Tanager',
#    'scientific_name': 'Piranga olivacea',
#    'family_common_name': 'Cardinals and Allies',
#    'family': 'Cardinalidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'scatan'},
#   {'common_name': 'Western Tanager',
#    'scientific_name': 'Piranga ludoviciana',
#    'family_common_name': 'Cardinals and Allies',
#    'family': 'Cardinalidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'westan'},
#   {'common_name': 'Northern Cardinal',
#    'scientific_name': 'Cardinalis cardinalis',
#    'family_common_name': 'Cardinals and Allies',
#    'family': 'Cardinalidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'norcar'},
#   {'common_name': 'Rose-breasted Grosbeak',
#    'scientific_name': 'Pheucticus ludovicianus',
#    'family_common_name': 'Cardinals and Allies',
#    'family': 'Cardinalidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'robgro'},
#   {'common_name': 'Black-headed Grosbeak',
#    'scientific_name': 'Pheucticus melanocephalus',
#    'family_common_name': 'Cardinals and Allies',
#    'family': 'Cardinalidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'bkhgro'},
#   {'common_name': 'Blue Grosbeak',
#    'scientific_name': 'Passerina caerulea',
#    'family_common_name': 'Cardinals and Allies',
#    'family': 'Cardinalidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'blugrb1'},
#   {'common_name': 'Lazuli Bunting',
#    'scientific_name': 'Passerina amoena',
#    'family_common_name': 'Cardinals and Allies',
#    'family': 'Cardinalidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'lazbun'},
#   {'common_name': 'Indigo Bunting',
#    'scientific_name': 'Passerina cyanea',
#    'family_common_name': 'Cardinals and Allies',
#    'family': 'Cardinalidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'indbun'},
#   {'common_name': 'Painted Bunting',
#    'scientific_name': 'Passerina ciris',
#    'family_common_name': 'Cardinals and Allies',
#    'family': 'Cardinalidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'paibun'},
#   {'common_name': 'Dickcissel',
#    'scientific_name': 'Spiza americana',
#    'family_common_name': 'Cardinals and Allies',
#    'family': 'Cardinalidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'dickci'}]}
