# %% [markdown]
# Goal: Retrieve the species checklist for a region using the eBird API.

# %%
from __future__ import annotations

# %%
from birding.ebird_api import get_ebird_api_key

ebird_api_key = get_ebird_api_key()

# %%
locations_of_interest = [
    "Punta Quepos, Puntarenas Province, Costa Rica",
    "Estero Damas, Puntarenas Province, Costa Rica",
    "Parque Nacional Manuel Antonio, Costa Rica",
    "Parque Nacional Carara, Costa Rica",
    "Tarcoles River, Puntarenas Province, Costa Rica",
    "Monteverde, Puntarenas Province, Costa Rica",
    "Reserva Bosque Nuboso Santa Elena, Tronadora, Guanacaste, Costa Rica",
    "Monteverde Cloud Forest Reserve, Monteverde, Puntarenas Province, Costa Rica",
    "Reserva Curi Cancha, Monteverde, Costa Rica",
    "La Fortuna, Alajuela Province, Costa Rica",
    "Parque Nacional Volcán Arenal, Costa Rica",
    "Arenal Volcano, Alajuela Province, San Carlos, Costa Rica",
    "Bogarin Trail, Alajuela Province, La Fortuna, Costa Rica",
    "Mistico Park Hanging Bridges, La Fortuna, Alajuela Province, Costa Rica",
    "Parque Nacional Volcán Poás, Costa Rica",
]

# %%
from birding.geocoding import retrieve_geocode
from birding.sqlite_cache import init_db

init_db()
for location in locations_of_interest:
    print(f"\n\nRetrieving geocode for location '{location}'...")
    data = retrieve_geocode(query=location)
    if data is None:
        print(f"Could not find geocode for location '{location}'.")
    else:
        print(data)
# Out:
# Retrieving geocode for location 'Punta Quepos, Puntarenas Province, Costa Rica'...
# Geocode for query 'Punta Quepos, Puntarenas Province, Costa Rica' was already cached.
# {'place_id': 287637760, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 5207350899, 'lat': '9.3988718', 'lon': '-84.1719522', 'class': 'natural', 'type': 'peak', 'place_rank': 18, 'importance': 0.16004359731441214, 'addresstype': 'peak', 'name': 'Punta Quepos', 'display_name': 'Punta Quepos, Quepos, Puntarenas, 60601, Costa Rica', 'boundingbox': ['9.3988218', '9.3989218', '-84.1720022', '-84.1719022']}
#
#
# Retrieving geocode for location 'Estero Damas, Puntarenas Province, Costa Rica'...
# Geocode for query 'Estero Damas, Puntarenas Province, Costa Rica' was already cached.
# {'place_id': 286614497, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 410673410, 'lat': '9.4616350', 'lon': '-84.2172554', 'class': 'waterway', 'type': 'river', 'place_rank': 19, 'importance': 0.14671026398107878, 'addresstype': 'river', 'name': 'Estero Damas', 'display_name': 'Estero Damas, Quepos, Puntarenas, 60601, Costa Rica', 'boundingbox': ['9.4610823', '9.4651871', '-84.2257529', '-84.2080974']}
#
#
# Retrieving geocode for location 'Parque Nacional Manuel Antonio, Costa Rica'...
# Geocode for query 'Parque Nacional Manuel Antonio, Costa Rica' was already cached.
# {'place_id': 285746814, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 2175048, 'lat': '9.0605046', 'lon': '-84.2449917', 'class': 'boundary', 'type': 'national_park', 'place_rank': 25, 'importance': 0.3572718937775532, 'addresstype': 'national_park', 'name': 'Parque Nacional Manuel Antonio', 'display_name': 'Parque Nacional Manuel Antonio, Quepos, Puntarenas, Costa Rica', 'boundingbox': ['8.7657404', '9.4042359', '-84.3592841', '-83.9951781']}
#
#
# Retrieving geocode for location 'Parque Nacional Carara, Costa Rica'...
# Geocode for query 'Parque Nacional Carara, Costa Rica' was already cached.
# {'place_id': 286836957, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 10326161, 'lat': '9.7900999', 'lon': '-84.5709133', 'class': 'boundary', 'type': 'national_park', 'place_rank': 25, 'importance': 0.3177684562015995, 'addresstype': 'national_park', 'name': 'Parque nacional Carara', 'display_name': 'Parque nacional Carara, Tárcoles, Garabito, Puntarenas, 61102, Costa Rica', 'boundingbox': ['9.7418376', '9.8385871', '-84.6137484', '-84.5227086']}
#
#
# Retrieving geocode for location 'Tarcoles River, Puntarenas Province, Costa Rica'...
# Geocode for query 'Tarcoles River, Puntarenas Province, Costa Rica' was already cached.
# {'place_id': 285578391, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 384272260, 'lat': '9.8096317', 'lon': '-84.5909112', 'class': 'waterway', 'type': 'river', 'place_rank': 19, 'importance': 0.14671166781109327, 'addresstype': 'river', 'name': 'Río Grande de Tárcoles', 'display_name': 'Río Grande de Tárcoles, Tárcoles, Garabito, Puntarenas, 61103, Costa Rica', 'boundingbox': ['9.7998079', '9.8124688', '-84.6072122', '-84.5799095']}
#
#
# Retrieving geocode for location 'Monteverde, Puntarenas Province, Costa Rica'...
# Geocode for query 'Monteverde, Puntarenas Province, Costa Rica' was already cached.
# {'place_id': 288032259, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 6150825, 'lat': '10.2911515', 'lon': '-84.8136439', 'class': 'boundary', 'type': 'administrative', 'place_rank': 16, 'importance': 0.3629003094109262, 'addresstype': 'city', 'name': 'Monteverde', 'display_name': 'Monteverde, Puntarenas, 61201, Costa Rica', 'boundingbox': ['10.2449287', '10.3374422', '-84.8726678', '-84.7707422']}
#
#
# Retrieving geocode for location 'Reserva Bosque Nuboso Santa Elena, Tronadora, Guanacaste, Costa Rica'...
# Geocode for query 'Reserva Bosque Nuboso Santa Elena, Tronadora, Guanacaste, Costa Rica' was already cached.
# {'place_id': 286037253, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 310530200, 'lat': '10.3433135', 'lon': '-84.7911521', 'class': 'natural', 'type': 'wood', 'place_rank': 22, 'importance': 0.10670666742961774, 'addresstype': 'wood', 'name': 'Reserva Bosque Nuboso Santa Elena', 'display_name': 'Reserva Bosque Nuboso Santa Elena, Tronadora, Tilarán, Guanacaste, 50803, Costa Rica', 'boundingbox': ['10.3346797', '10.3510160', '-84.8025239', '-84.7835768']}
#
#
# Retrieving geocode for location 'Monteverde Cloud Forest Reserve, Monteverde, Puntarenas Province, Costa Rica'...
# Geocode for query 'Monteverde Cloud Forest Reserve, Monteverde, Puntarenas Province, Costa Rica' was already cached.
# {'place_id': 291972084, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 310449313, 'lat': '10.3036512', 'lon': '-84.7877117', 'class': 'boundary', 'type': 'national_park', 'place_rank': 25, 'importance': 0.3196112102041735, 'addresstype': 'national_park', 'name': 'Reserva Biológica Bosque Nuboso Monteverde', 'display_name': 'Reserva Biológica Bosque Nuboso Monteverde, Monteverde, Puntarenas, 61201, Costa Rica', 'boundingbox': ['10.2958353', '10.3110589', '-84.7973945', '-84.7780183']}
#
#
# Retrieving geocode for location 'Reserva Curi Cancha, Monteverde, Costa Rica'...
# Geocode for query 'Reserva Curi Cancha, Monteverde, Costa Rica' was already cached.
# {'place_id': 285838011, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 6124472660, 'lat': '10.3064418', 'lon': '-84.8076789', 'class': 'tourism', 'type': 'attraction', 'place_rank': 30, 'importance': 4.5001144426596745e-05, 'addresstype': 'tourism', 'name': 'Reserva Curi Cancha', 'display_name': 'Reserva Curi Cancha, Calle Curi Cancha, Monteverde, Santa Elena, Monteverde, Puntarenas, 61201, Costa Rica', 'boundingbox': ['10.3063918', '10.3064918', '-84.8077289', '-84.8076289']}
#
#
# Retrieving geocode for location 'La Fortuna, Alajuela Province, Costa Rica'...
# Geocode for query 'La Fortuna, Alajuela Province, Costa Rica' was already cached.
# {'place_id': 286940207, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 6362231, 'lat': '10.4716839', 'lon': '-84.6444360', 'class': 'boundary', 'type': 'administrative', 'place_rank': 16, 'importance': 0.3774202560300637, 'addresstype': 'village', 'name': 'La Fortuna', 'display_name': 'La Fortuna, San Carlos, Alajuela, 21007, Costa Rica', 'boundingbox': ['10.3764847', '10.5224525', '-84.7734649', '-84.5104754']}
#
#
# Retrieving geocode for location 'Parque Nacional Volcán Arenal, Costa Rica'...
# Geocode for query 'Parque Nacional Volcán Arenal, Costa Rica' was already cached.
# {'place_id': 286028928, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 10312542, 'lat': '10.4287963', 'lon': '-84.7031956', 'class': 'boundary', 'type': 'national_park', 'place_rank': 25, 'importance': 0.3186964146910553, 'addresstype': 'national_park', 'name': 'Parque Nacional Volcán Arenal', 'display_name': 'Parque Nacional Volcán Arenal, La Fortuna, San Carlos, Alajuela, 21007, Costa Rica', 'boundingbox': ['10.3612586', '10.4969090', '-84.8359731', '-84.6672817']}
#
#
# Retrieving geocode for location 'Arenal Volcano, Alajuela Province, San Carlos, Costa Rica'...
# Geocode for query 'Arenal Volcano, Alajuela Province, San Carlos, Costa Rica' was already cached.
# {'place_id': 285840699, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 276216895, 'lat': '10.4620845', 'lon': '-84.7034096', 'class': 'natural', 'type': 'volcano', 'place_rank': 18, 'importance': 0.425021710633198, 'addresstype': 'volcano', 'name': 'Volcán Arenal', 'display_name': 'Volcán Arenal, La Fortuna, San Carlos, Alajuela, 21007, Costa Rica', 'boundingbox': ['10.4620345', '10.4621345', '-84.7034596', '-84.7033596']}
#
#
# Retrieving geocode for location 'Bogarin Trail, Alajuela Province, La Fortuna, Costa Rica'...
# Geocode for query 'Bogarin Trail, Alajuela Province, La Fortuna, Costa Rica' was already cached.
# {'place_id': 286040407, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 6097119085, 'lat': '10.4703312', 'lon': '-84.6507782', 'class': 'tourism', 'type': 'attraction', 'place_rank': 30, 'importance': 4.286793316543858e-05, 'addresstype': 'tourism', 'name': 'Bogarin Trail', 'display_name': 'Bogarin Trail, Vía 142, Los Olivos, Manolo, La Fortuna, San Carlos, Alajuela, 21007, Costa Rica', 'boundingbox': ['10.4702812', '10.4703812', '-84.6508282', '-84.6507282']}
#
#
# Retrieving geocode for location 'Mistico Park Hanging Bridges, La Fortuna, Alajuela Province, Costa Rica'...
# Geocode for query 'Mistico Park Hanging Bridges, La Fortuna, Alajuela Province, Costa Rica' was already cached.
# {'place_id': 286635844, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 772642152, 'lat': '10.4880492', 'lon': '-84.7537775', 'class': 'tourism', 'type': 'attraction', 'place_rank': 30, 'importance': 4.286793316543858e-05, 'addresstype': 'tourism', 'name': 'Mistico Arenal Hanging Bridges Park', 'display_name': 'Mistico Arenal Hanging Bridges Park, Calle Sangregado, La Fortuna, San Carlos, Alajuela, 21007, Costa Rica', 'boundingbox': ['10.4879992', '10.4880992', '-84.7538275', '-84.7537275']}
#
#
# Retrieving geocode for location 'Parque Nacional Volcán Poás, Costa Rica'...
# Geocode for query 'Parque Nacional Volcán Poás, Costa Rica' was already cached.
# {'place_id': 288776646, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 10322859, 'lat': '10.2174997', 'lon': '-84.2292426', 'class': 'boundary', 'type': 'national_park', 'place_rank': 25, 'importance': 0.32314590312055647, 'addresstype': 'national_park', 'name': 'Parque Nacional Volcán Poás', 'display_name': 'Parque Nacional Volcán Poás, Sarapiquí, Alajuela, 20114, Costa Rica', 'boundingbox': ['10.1583612', '10.2765707', '-84.2675046', '-84.1944757']}

# %%
from birding.primitives import Coordinate

raw_location_data = {loc: retrieve_geocode(query=loc) for loc in locations_of_interest}
location_data = {loc: data for loc, data in raw_location_data.items() if data is not None}
assert len(raw_location_data) == len(location_data), "A location's geocode data was None!"

location_coords = {loc: Coordinate.from_geocode_data(data) for loc, data in location_data.items()}
location_coords
# Out:
# Geocode for query 'Punta Quepos, Puntarenas Province, Costa Rica' was already cached.
# Geocode for query 'Estero Damas, Puntarenas Province, Costa Rica' was already cached.
# Geocode for query 'Parque Nacional Manuel Antonio, Costa Rica' was already cached.
# Geocode for query 'Parque Nacional Carara, Costa Rica' was already cached.
# Geocode for query 'Tarcoles River, Puntarenas Province, Costa Rica' was already cached.
# Geocode for query 'Monteverde, Puntarenas Province, Costa Rica' was already cached.
# Geocode for query 'Reserva Bosque Nuboso Santa Elena, Tronadora, Guanacaste, Costa Rica' was already cached.
# Geocode for query 'Monteverde Cloud Forest Reserve, Monteverde, Puntarenas Province, Costa Rica' was already cached.
# Geocode for query 'Reserva Curi Cancha, Monteverde, Costa Rica' was already cached.
# Geocode for query 'La Fortuna, Alajuela Province, Costa Rica' was already cached.
# Geocode for query 'Parque Nacional Volcán Arenal, Costa Rica' was already cached.
# Geocode for query 'Arenal Volcano, Alajuela Province, San Carlos, Costa Rica' was already cached.
# Geocode for query 'Bogarin Trail, Alajuela Province, La Fortuna, Costa Rica' was already cached.
# Geocode for query 'Mistico Park Hanging Bridges, La Fortuna, Alajuela Province, Costa Rica' was already cached.
# Geocode for query 'Parque Nacional Volcán Poás, Costa Rica' was already cached.
# {'Punta Quepos, Puntarenas Province, Costa Rica': Coordinate(latitude=9.3988718, longitude=-84.1719522),
#  'Estero Damas, Puntarenas Province, Costa Rica': Coordinate(latitude=9.461635, longitude=-84.2172554),
#  'Parque Nacional Manuel Antonio, Costa Rica': Coordinate(latitude=9.0605046, longitude=-84.2449917),
#  'Parque Nacional Carara, Costa Rica': Coordinate(latitude=9.7900999, longitude=-84.5709133),
#  'Tarcoles River, Puntarenas Province, Costa Rica': Coordinate(latitude=9.8096317, longitude=-84.5909112),
#  'Monteverde, Puntarenas Province, Costa Rica': Coordinate(latitude=10.2911515, longitude=-84.8136439),
#  'Reserva Bosque Nuboso Santa Elena, Tronadora, Guanacaste, Costa Rica': Coordinate(latitude=10.3433135, longitude=-84.7911521),
#  'Monteverde Cloud Forest Reserve, Monteverde, Puntarenas Province, Costa Rica': Coordinate(latitude=10.3036512, longitude=-84.7877117),
#  'Reserva Curi Cancha, Monteverde, Costa Rica': Coordinate(latitude=10.3064418, longitude=-84.8076789),
#  'La Fortuna, Alajuela Province, Costa Rica': Coordinate(latitude=10.4716839, longitude=-84.644436),
#  'Parque Nacional Volcán Arenal, Costa Rica': Coordinate(latitude=10.4287963, longitude=-84.7031956),
#  'Arenal Volcano, Alajuela Province, San Carlos, Costa Rica': Coordinate(latitude=10.4620845, longitude=-84.7034096),
#  'Bogarin Trail, Alajuela Province, La Fortuna, Costa Rica': Coordinate(latitude=10.4703312, longitude=-84.6507782),
#  'Mistico Park Hanging Bridges, La Fortuna, Alajuela Province, Costa Rica': Coordinate(latitude=10.4880492, longitude=-84.7537775),
#  'Parque Nacional Volcán Poás, Costa Rica': Coordinate(latitude=10.2174997, longitude=-84.2292426)}

# %%
from birding.ebird_api import retrieve_nearby_hotspots

for loc, coord in location_coords.items():
    print(f"\n\nRetrieving nearby hotspots for location '{loc}'...")
    hotspots = retrieve_nearby_hotspots(ebird_api_key, coord=coord)
    print(f"Found {len(hotspots)} nearby hotspots.")

    if len(hotspots) < 5:
        print("Location had less than 5 nearby hotspots!")
        more_hotspots = retrieve_nearby_hotspots(ebird_api_key, coord=coord, distance_km=50)
        print(f"Found {len(more_hotspots)} hotspots within 50 km.")
# Out:
# Retrieving nearby hotspots for location 'Punta Quepos, Puntarenas Province, Costa Rica'...
# Nearby hotspots for (9.3989, -84.1720) were already cached.
# Found 51 nearby hotspots.
#
#
# Retrieving nearby hotspots for location 'Estero Damas, Puntarenas Province, Costa Rica'...
# Nearby hotspots for (9.4616, -84.2173) were already cached.
# Found 52 nearby hotspots.
#
#
# Retrieving nearby hotspots for location 'Parque Nacional Manuel Antonio, Costa Rica'...
# Nearby hotspots for (9.0605, -84.2450) were already cached.
# Found 2 nearby hotspots.
# Location had less than 5 nearby hotspots!
# Nearby hotspots for (9.0605, -84.2450) were already cached.
# Found 52 hotspots within 50 km.
#
#
# Retrieving nearby hotspots for location 'Parque Nacional Carara, Costa Rica'...
# Nearby hotspots for (9.7901, -84.5709) were already cached.
# Found 76 nearby hotspots.
#
#
# Retrieving nearby hotspots for location 'Tarcoles River, Puntarenas Province, Costa Rica'...
# Nearby hotspots for (9.8096, -84.5909) were already cached.
# Found 68 nearby hotspots.
#
#
# Retrieving nearby hotspots for location 'Monteverde, Puntarenas Province, Costa Rica'...
# Nearby hotspots for (10.2912, -84.8136) were already cached.
# Found 124 nearby hotspots.
#
#
# Retrieving nearby hotspots for location 'Reserva Bosque Nuboso Santa Elena, Tronadora, Guanacaste, Costa Rica'...
# Nearby hotspots for (10.3433, -84.7912) were already cached.
# Found 155 nearby hotspots.
#
#
# Retrieving nearby hotspots for location 'Monteverde Cloud Forest Reserve, Monteverde, Puntarenas Province, Costa Rica'...
# Nearby hotspots for (10.3037, -84.7877) were already cached.
# Found 144 nearby hotspots.
#
#
# Retrieving nearby hotspots for location 'Reserva Curi Cancha, Monteverde, Costa Rica'...
# Nearby hotspots for (10.3064, -84.8077) were already cached.
# Found 142 nearby hotspots.
#
#
# Retrieving nearby hotspots for location 'La Fortuna, Alajuela Province, Costa Rica'...
# Nearby hotspots for (10.4717, -84.6444) were already cached.
# Found 104 nearby hotspots.
#
#
# Retrieving nearby hotspots for location 'Parque Nacional Volcán Arenal, Costa Rica'...
# Nearby hotspots for (10.4288, -84.7032) were already cached.
# Found 154 nearby hotspots.
#
#
# Retrieving nearby hotspots for location 'Arenal Volcano, Alajuela Province, San Carlos, Costa Rica'...
# Nearby hotspots for (10.4621, -84.7034) were already cached.
# Found 152 nearby hotspots.
#
#
# Retrieving nearby hotspots for location 'Bogarin Trail, Alajuela Province, La Fortuna, Costa Rica'...
# Nearby hotspots for (10.4703, -84.6508) were already cached.
# Found 112 nearby hotspots.
#
#
# Retrieving nearby hotspots for location 'Mistico Park Hanging Bridges, La Fortuna, Alajuela Province, Costa Rica'...
# Nearby hotspots for (10.4880, -84.7538) were already cached.
# Found 154 nearby hotspots.
#
#
# Retrieving nearby hotspots for location 'Parque Nacional Volcán Poás, Costa Rica'...
# Nearby hotspots for (10.2175, -84.2292) were already cached.
# Found 89 nearby hotspots.

# %%
spots_per_loc = {
    loc: retrieve_nearby_hotspots(ebird_api_key, coord) for loc, coord in location_coords.items()
}

use_50_km = ["Parque Nacional Manuel Antonio, Costa Rica"]
for loc in use_50_km:
    spots_per_loc[loc] = retrieve_nearby_hotspots(ebird_api_key, location_coords[loc], 50)

spots_per_loc
# Out:
# Nearby hotspots for (9.3989, -84.1720) were already cached.
# Nearby hotspots for (9.4616, -84.2173) were already cached.
# Nearby hotspots for (9.0605, -84.2450) were already cached.
# Nearby hotspots for (9.7901, -84.5709) were already cached.
# Nearby hotspots for (9.8096, -84.5909) were already cached.
# Nearby hotspots for (10.2912, -84.8136) were already cached.
# Nearby hotspots for (10.3433, -84.7912) were already cached.
# Nearby hotspots for (10.3037, -84.7877) were already cached.
# Nearby hotspots for (10.3064, -84.8077) were already cached.
# Nearby hotspots for (10.4717, -84.6444) were already cached.
# Nearby hotspots for (10.4288, -84.7032) were already cached.
# Nearby hotspots for (10.4621, -84.7034) were already cached.
# Nearby hotspots for (10.4703, -84.6508) were already cached.
# Nearby hotspots for (10.4880, -84.7538) were already cached.
# Nearby hotspots for (10.2175, -84.2292) were already cached.
# Nearby hotspots for (9.0605, -84.2450) were already cached.
# {'Punta Quepos, Puntarenas Province, Costa Rica': [{'locId': 'L2102226',
#    'locName': 'Arenas del Mar Resort (reserve, hotel grounds and drive way)',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.3983113,
#    'lng': -84.1629338,
#    'latestObsDt': '2025-10-12 15:09',
#    'numSpeciesAllTime': 191},
#   {'locId': 'L3300769',
#    'locName': 'Barrio Lourdes (town)',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.4505872,
#    'lng': -84.1271296,
#    'latestObsDt': '2025-12-15 06:10',
#    'numSpeciesAllTime': 101},
#   {'locId': 'L2873762',
#    'locName': 'Biesanz beach',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.401709,
#    'lng': -84.1675043,
#    'latestObsDt': '2025-12-09 15:40',
#    'numSpeciesAllTime': 211},
#   {'locId': 'L3308537',
#    'locName': 'Buenavista Villas/Tulemar',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.4078746,
#    'lng': -84.159738,
#    'latestObsDt': '2025-12-04 06:48',
#    'numSpeciesAllTime': 241},
#   {'locId': 'L3747719',
#    'locName': 'El Mono Azul Hotel',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.4209429,
#    'lng': -84.1594014,
#    'latestObsDt': '2025-11-14 17:02',
#    'numSpeciesAllTime': 96},
#   {'locId': 'L1855002',
#    'locName': 'Esquipulas (town)',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-SJ',
#    'lat': 9.496133,
#    'lng': -84.0478992,
#    'latestObsDt': '2025-10-24 08:14',
#    'numSpeciesAllTime': 357},
#   {'locId': 'L16052695',
#    'locName': 'Esquipulas Rainforest Lodge',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.490671,
#    'lng': -84.0472504,
#    'latestObsDt': '2025-12-14 14:38',
#    'numSpeciesAllTime': 351},
#   {'locId': 'L3942621',
#    'locName': 'Esquipulas--El diamante',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-SJ',
#    'lat': 9.517296,
#    'lng': -84.0351105,
#    'latestObsDt': '2025-05-10 07:00',
#    'numSpeciesAllTime': 270},
#   {'locId': 'L3898789',
#    'locName': 'Finca Los Alfaro Grasslands--Quepos',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.4406639,
#    'lng': -84.1601765,
#    'latestObsDt': '2025-12-06 11:25',
#    'numSpeciesAllTime': 165},
#   {'locId': 'L2364240',
#    'locName': 'Finca Maritima (Playa El Rey) rice fields',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.3791205,
#    'lng': -84.0604949,
#    'latestObsDt': '2025-12-10 11:28',
#    'numSpeciesAllTime': 351},
#   {'locId': 'L8237030',
#    'locName': 'Hot Springs Lodge and Community',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.54822,
#    'lng': -84.128942,
#    'latestObsDt': '2025-03-01 07:33',
#    'numSpeciesAllTime': 174},
#   {'locId': 'L1351111',
#    'locName': 'Hotel Costa Verde',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.3986344,
#    'lng': -84.1541689,
#    'latestObsDt': '2025-11-21 13:26',
#    'numSpeciesAllTime': 189},
#   {'locId': 'L4475440',
#    'locName': 'Hotel Gaia--Hotel and reserve.',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.4173741,
#    'lng': -84.1578805,
#    'latestObsDt': '2025-10-30 05:00',
#    'numSpeciesAllTime': 158},
#   {'locId': 'L10206898',
#    'locName': 'Hotel Makanda by the Sea (restricted access)',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.4029964,
#    'lng': -84.1626817,
#    'latestObsDt': '2025-07-29 07:17',
#    'numSpeciesAllTime': 100},
#   {'locId': 'L2249175',
#    'locName': 'Hotel Plaza Yara',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.4196357,
#    'lng': -84.1582319,
#    'latestObsDt': '2025-08-10 15:39',
#    'numSpeciesAllTime': 63},
#   {'locId': 'L2063612',
#    'locName': 'La Palapa Ecolodge Resort',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.3622681,
#    'lng': -83.9759731,
#    'latestObsDt': '2025-02-28 21:10',
#    'numSpeciesAllTime': 117},
#   {'locId': 'L2706179',
#    'locName': 'Laguna en Las vueltas de Parrita',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.5320246,
#    'lng': -84.26651,
#    'latestObsDt': '2025-08-17 14:06',
#    'numSpeciesAllTime': 141},
#   {'locId': 'L18318352',
#    'locName': 'Los Altos Resort (restricted access)',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.405456,
#    'lng': -84.1579342,
#    'latestObsDt': '2025-12-04 15:18',
#    'numSpeciesAllTime': 107},
#   {'locId': 'L3881190',
#    'locName': 'Manglar Kayak lodge (donde "Maco")',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.4842811,
#    'lng': -84.2182624,
#    'latestObsDt': '2025-12-08 09:17',
#    'numSpeciesAllTime': 205},
#   {'locId': 'L509908',
#    'locName': 'Manglares Damas',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.4619308,
#    'lng': -84.2156982,
#    'latestObsDt': '2025-12-05 14:13',
#    'numSpeciesAllTime': 247},
#   {'locId': 'L4892172',
#    'locName': 'Manuel Antonio -- Jungle Creek Villas',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.4159775,
#    'lng': -84.1546953,
#    'latestObsDt': '2025-12-15 09:22',
#    'numSpeciesAllTime': 178},
#   {'locId': 'L2480432',
#    'locName': 'Manuel Antonio--Road to Parador hotel',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.4018149,
#    'lng': -84.1604662,
#    'latestObsDt': '2025-11-13 05:45',
#    'numSpeciesAllTime': 192},
#   {'locId': 'L448817',
#    'locName': 'Manuel Antonio--hotels near park',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.3909527,
#    'lng': -84.1471936,
#    'latestObsDt': '2025-12-13 07:31',
#    'numSpeciesAllTime': 372},
#   {'locId': 'L585224',
#    'locName': 'Naranjito',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.471142,
#    'lng': -84.1052771,
#    'latestObsDt': '2025-12-06 06:07',
#    'numSpeciesAllTime': 261},
#   {'locId': 'L724260',
#    'locName': 'PN Manuel Antonio',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.3845275,
#    'lng': -84.1430619,
#    'latestObsDt': '2025-12-15 07:07',
#    'numSpeciesAllTime': 439},
#   {'locId': 'L2249173',
#    'locName': 'PN Manuel Antonio--Mangroves',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.3881252,
#    'lng': -84.1464731,
#    'latestObsDt': '2025-12-14 06:32',
#    'numSpeciesAllTime': 273},
#   {'locId': 'L3789351',
#    'locName': 'Paquita, grasslands behind the rodeo corral.',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.464894,
#    'lng': -84.1803789,
#    'latestObsDt': '2025-09-02 14:29',
#    'numSpeciesAllTime': 166},
#   {'locId': 'L1848099',
#    'locName': 'Parador Resort and Spa',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.397801,
#    'lng': -84.169388,
#    'latestObsDt': '2025-12-12 08:11',
#    'numSpeciesAllTime': 222},
#   {'locId': 'L10478874',
#    'locName': 'Parque Nahomi',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.4224968,
#    'lng': -84.1693497,
#    'latestObsDt': '2025-08-23 08:52',
#    'numSpeciesAllTime': 133},
#   {'locId': 'L1884540',
#    'locName': 'Parrita--Pueblo Nuevo shrimp farm',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.5020462,
#    'lng': -84.3230283,
#    'latestObsDt': '2025-10-11 10:30',
#    'numSpeciesAllTime': 167},
#   {'locId': 'L3527795',
#    'locName': 'Playa Espadilla Norte (Public beach outside the park).',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.3932575,
#    'lng': -84.1531813,
#    'latestObsDt': '2025-12-06 13:49',
#    'numSpeciesAllTime': 228},
#   {'locId': 'L3928059',
#    'locName': 'Playa Isla Damas',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.4551154,
#    'lng': -84.2176723,
#    'latestObsDt': '2025-11-20 06:46',
#    'numSpeciesAllTime': 143},
#   {'locId': 'L5218074',
#    'locName': 'Playa Matapalo',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.3209184,
#    'lng': -83.9582431,
#    'latestObsDt': '2025-12-14 11:39',
#    'numSpeciesAllTime': 224},
#   {'locId': 'L1878405',
#    'locName': 'Portalon',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.3544768,
#    'lng': -83.9803505,
#    'latestObsDt': '2025-06-22 15:38',
#    'numSpeciesAllTime': 211},
#   {'locId': 'L11431955',
#    'locName': 'Portasol living Birder House',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.3731784,
#    'lng': -83.9622937,
#    'latestObsDt': '2024-01-15 10:50',
#    'numSpeciesAllTime': 247},
#   {'locId': 'L17897693',
#    'locName': 'Pueblo Nuevo de Parrita',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.5127043,
#    'lng': -84.3207787,
#    'latestObsDt': '2025-08-27 11:30',
#    'numSpeciesAllTime': 109},
#   {'locId': 'L3058980',
#    'locName': 'Pueblo Real, Entrada a Isla Damas',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.4634971,
#    'lng': -84.1939616,
#    'latestObsDt': '2025-12-09 08:53',
#    'numSpeciesAllTime': 175},
#   {'locId': 'L7928552',
#    'locName': 'Quebrada Arroyo — Road',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.4737935,
#    'lng': -84.027782,
#    'latestObsDt': '2025-11-24 09:14',
#    'numSpeciesAllTime': 264},
#   {'locId': 'L501063',
#    'locName': 'Quepos',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.4318889,
#    'lng': -84.1655944,
#    'latestObsDt': '2025-12-04 14:28',
#    'numSpeciesAllTime': 359},
#   {'locId': 'L2132992',
#    'locName': 'Quepos--La Foresta Nature Resort',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.4399876,
#    'lng': -84.1367651,
#    'latestObsDt': '2025-11-21 16:14',
#    'numSpeciesAllTime': 227},
#   {'locId': 'L4829224',
#    'locName': 'Quepos--Marina Pez Vela-Pier and surroundings',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.425074,
#    'lng': -84.1696581,
#    'latestObsDt': '2025-12-09 09:01',
#    'numSpeciesAllTime': 171},
#   {'locId': 'L3094290',
#    'locName': 'Quepos--Rice fields North of high school.',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.4533798,
#    'lng': -84.1723967,
#    'latestObsDt': '2025-12-10 13:55',
#    'numSpeciesAllTime': 174},
#   {'locId': 'L6697932',
#    'locName': 'Rafiki Safari Lodge',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-SJ',
#    'lat': 9.4466065,
#    'lng': -83.9905,
#    'latestObsDt': '2025-12-07 15:34',
#    'numSpeciesAllTime': 312},
#   {'locId': 'L2103221',
#    'locName': 'Rainmaker Conservation Project',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.5766723,
#    'lng': -84.2160679,
#    'latestObsDt': '2025-12-10 08:26',
#    'numSpeciesAllTime': 244},
#   {'locId': 'L3308553',
#    'locName': 'Restaurante Finca Mona--Quepos, Puntarenas.',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.3942891,
#    'lng': -84.0691611,
#    'latestObsDt': '2025-09-22 07:03',
#    'numSpeciesAllTime': 128},
#   {'locId': 'L2795875',
#    'locName': 'Rio Parrita, frente a camaronera',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.502736,
#    'lng': -84.3282223,
#    'latestObsDt': '2025-10-11 07:14',
#    'numSpeciesAllTime': 193},
#   {'locId': 'L3871374',
#    'locName': 'Rio Parrita--boca del río',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.4913076,
#    'lng': -84.3326426,
#    'latestObsDt': '2025-11-19 17:05',
#    'numSpeciesAllTime': 190},
#   {'locId': 'L3748598',
#    'locName': 'Rio la Gallega, Naranjito',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.49845,
#    'lng': -84.11789,
#    'latestObsDt': '2025-11-18 15:46',
#    'numSpeciesAllTime': 229},
#   {'locId': 'L3938264',
#    'locName': 'Santa Juana Lodge',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.5328788,
#    'lng': -84.0780262,
#    'latestObsDt': '2025-08-23 05:30',
#    'numSpeciesAllTime': 280},
#   {'locId': 'L2577899',
#    'locName': 'Si Como No Hotel',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.4038842,
#    'lng': -84.1554773,
#    'latestObsDt': '2025-12-05 07:25',
#    'numSpeciesAllTime': 228},
#   {'locId': 'L4702312',
#    'locName': 'Villa Nueva de Quepos',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.4735718,
#    'lng': -84.0628982,
#    'latestObsDt': '2025-12-12 08:27',
#    'numSpeciesAllTime': 291}],
#  'Estero Damas, Puntarenas Province, Costa Rica': [{'locId': 'L2102226',
#    'locName': 'Arenas del Mar Resort (reserve, hotel grounds and drive way)',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.3983113,
#    'lng': -84.1629338,
#    'latestObsDt': '2025-10-12 15:09',
#    'numSpeciesAllTime': 191},
#   {'locId': 'L3300769',
#    'locName': 'Barrio Lourdes (town)',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.4505872,
#    'lng': -84.1271296,
#    'latestObsDt': '2025-12-15 06:10',
#    'numSpeciesAllTime': 101},
#   {'locId': 'L3909190',
#    'locName': 'Bejuco--manglar al sur de la costanera',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.5201984,
#    'lng': -84.4255062,
#    'latestObsDt': '2025-12-07 12:18',
#    'numSpeciesAllTime': 156},
#   {'locId': 'L2873762',
#    'locName': 'Biesanz beach',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.401709,
#    'lng': -84.1675043,
#    'latestObsDt': '2025-12-09 15:40',
#    'numSpeciesAllTime': 211},
#   {'locId': 'L3308537',
#    'locName': 'Buenavista Villas/Tulemar',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.4078746,
#    'lng': -84.159738,
#    'latestObsDt': '2025-12-04 06:48',
#    'numSpeciesAllTime': 241},
#   {'locId': 'L3747719',
#    'locName': 'El Mono Azul Hotel',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.4209429,
#    'lng': -84.1594014,
#    'latestObsDt': '2025-11-14 17:02',
#    'numSpeciesAllTime': 96},
#   {'locId': 'L1855002',
#    'locName': 'Esquipulas (town)',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-SJ',
#    'lat': 9.496133,
#    'lng': -84.0478992,
#    'latestObsDt': '2025-10-24 08:14',
#    'numSpeciesAllTime': 357},
#   {'locId': 'L16052695',
#    'locName': 'Esquipulas Rainforest Lodge',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.490671,
#    'lng': -84.0472504,
#    'latestObsDt': '2025-12-14 14:38',
#    'numSpeciesAllTime': 351},
#   {'locId': 'L3942621',
#    'locName': 'Esquipulas--El diamante',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-SJ',
#    'lat': 9.517296,
#    'lng': -84.0351105,
#    'latestObsDt': '2025-05-10 07:00',
#    'numSpeciesAllTime': 270},
#   {'locId': 'L3898789',
#    'locName': 'Finca Los Alfaro Grasslands--Quepos',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.4406639,
#    'lng': -84.1601765,
#    'latestObsDt': '2025-12-06 11:25',
#    'numSpeciesAllTime': 165},
#   {'locId': 'L2364240',
#    'locName': 'Finca Maritima (Playa El Rey) rice fields',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.3791205,
#    'lng': -84.0604949,
#    'latestObsDt': '2025-12-10 11:28',
#    'numSpeciesAllTime': 351},
#   {'locId': 'L8237030',
#    'locName': 'Hot Springs Lodge and Community',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.54822,
#    'lng': -84.128942,
#    'latestObsDt': '2025-03-01 07:33',
#    'numSpeciesAllTime': 174},
#   {'locId': 'L1351111',
#    'locName': 'Hotel Costa Verde',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.3986344,
#    'lng': -84.1541689,
#    'latestObsDt': '2025-11-21 13:26',
#    'numSpeciesAllTime': 189},
#   {'locId': 'L4475440',
#    'locName': 'Hotel Gaia--Hotel and reserve.',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.4173741,
#    'lng': -84.1578805,
#    'latestObsDt': '2025-10-30 05:00',
#    'numSpeciesAllTime': 158},
#   {'locId': 'L10206898',
#    'locName': 'Hotel Makanda by the Sea (restricted access)',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.4029964,
#    'lng': -84.1626817,
#    'latestObsDt': '2025-07-29 07:17',
#    'numSpeciesAllTime': 100},
#   {'locId': 'L2249175',
#    'locName': 'Hotel Plaza Yara',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.4196357,
#    'lng': -84.1582319,
#    'latestObsDt': '2025-08-10 15:39',
#    'numSpeciesAllTime': 63},
#   {'locId': 'L13470886',
#    'locName': 'Kuakuari Lodge',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-SJ',
#    'lat': 9.6456041,
#    'lng': -84.2475647,
#    'latestObsDt': '2025-09-27 05:42',
#    'numSpeciesAllTime': 269},
#   {'locId': 'L2706179',
#    'locName': 'Laguna en Las vueltas de Parrita',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.5320246,
#    'lng': -84.26651,
#    'latestObsDt': '2025-08-17 14:06',
#    'numSpeciesAllTime': 141},
#   {'locId': 'L18318352',
#    'locName': 'Los Altos Resort (restricted access)',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.405456,
#    'lng': -84.1579342,
#    'latestObsDt': '2025-12-04 15:18',
#    'numSpeciesAllTime': 107},
#   {'locId': 'L3881190',
#    'locName': 'Manglar Kayak lodge (donde "Maco")',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.4842811,
#    'lng': -84.2182624,
#    'latestObsDt': '2025-12-08 09:17',
#    'numSpeciesAllTime': 205},
#   {'locId': 'L509908',
#    'locName': 'Manglares Damas',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.4619308,
#    'lng': -84.2156982,
#    'latestObsDt': '2025-12-05 14:13',
#    'numSpeciesAllTime': 247},
#   {'locId': 'L4892172',
#    'locName': 'Manuel Antonio -- Jungle Creek Villas',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.4159775,
#    'lng': -84.1546953,
#    'latestObsDt': '2025-12-15 09:22',
#    'numSpeciesAllTime': 178},
#   {'locId': 'L2480432',
#    'locName': 'Manuel Antonio--Road to Parador hotel',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.4018149,
#    'lng': -84.1604662,
#    'latestObsDt': '2025-11-13 05:45',
#    'numSpeciesAllTime': 192},
#   {'locId': 'L448817',
#    'locName': 'Manuel Antonio--hotels near park',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.3909527,
#    'lng': -84.1471936,
#    'latestObsDt': '2025-12-13 07:31',
#    'numSpeciesAllTime': 372},
#   {'locId': 'L585224',
#    'locName': 'Naranjito',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.471142,
#    'lng': -84.1052771,
#    'latestObsDt': '2025-12-06 06:07',
#    'numSpeciesAllTime': 261},
#   {'locId': 'L10183671',
#    'locName': 'P.N. La Cangreja--Ruta Fila del Aguacate',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-SJ',
#    'lat': 9.6421976,
#    'lng': -84.3486156,
#    'latestObsDt': '2024-12-07 04:42',
#    'numSpeciesAllTime': 202},
#   {'locId': 'L724260',
#    'locName': 'PN Manuel Antonio',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.3845275,
#    'lng': -84.1430619,
#    'latestObsDt': '2025-12-15 07:07',
#    'numSpeciesAllTime': 439},
#   {'locId': 'L2249173',
#    'locName': 'PN Manuel Antonio--Mangroves',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.3881252,
#    'lng': -84.1464731,
#    'latestObsDt': '2025-12-14 06:32',
#    'numSpeciesAllTime': 273},
#   {'locId': 'L3789351',
#    'locName': 'Paquita, grasslands behind the rodeo corral.',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.464894,
#    'lng': -84.1803789,
#    'latestObsDt': '2025-09-02 14:29',
#    'numSpeciesAllTime': 166},
#   {'locId': 'L1848099',
#    'locName': 'Parador Resort and Spa',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.397801,
#    'lng': -84.169388,
#    'latestObsDt': '2025-12-12 08:11',
#    'numSpeciesAllTime': 222},
#   {'locId': 'L10478874',
#    'locName': 'Parque Nahomi',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.4224968,
#    'lng': -84.1693497,
#    'latestObsDt': '2025-08-23 08:52',
#    'numSpeciesAllTime': 133},
#   {'locId': 'L1884540',
#    'locName': 'Parrita--Pueblo Nuevo shrimp farm',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.5020462,
#    'lng': -84.3230283,
#    'latestObsDt': '2025-10-11 10:30',
#    'numSpeciesAllTime': 167},
#   {'locId': 'L3881182',
#    'locName': 'Playa Bandera',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.5043444,
#    'lng': -84.3824673,
#    'latestObsDt': '2025-11-07 13:12',
#    'numSpeciesAllTime': 123},
#   {'locId': 'L3296556',
#    'locName': 'Playa Bejuco',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.5150951,
#    'lng': -84.4262409,
#    'latestObsDt': '2025-11-22 14:53',
#    'numSpeciesAllTime': 178},
#   {'locId': 'L3527795',
#    'locName': 'Playa Espadilla Norte (Public beach outside the park).',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.3932575,
#    'lng': -84.1531813,
#    'latestObsDt': '2025-12-06 13:49',
#    'numSpeciesAllTime': 228},
#   {'locId': 'L3928059',
#    'locName': 'Playa Isla Damas',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.4551154,
#    'lng': -84.2176723,
#    'latestObsDt': '2025-11-20 06:46',
#    'numSpeciesAllTime': 143},
#   {'locId': 'L3155643',
#    'locName': 'Playa bandera--Rice fields in route to the beach',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.5077304,
#    'lng': -84.3825531,
#    'latestObsDt': '2025-11-29 15:49',
#    'numSpeciesAllTime': 164},
#   {'locId': 'L17897693',
#    'locName': 'Pueblo Nuevo de Parrita',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.5127043,
#    'lng': -84.3207787,
#    'latestObsDt': '2025-08-27 11:30',
#    'numSpeciesAllTime': 109},
#   {'locId': 'L3058980',
#    'locName': 'Pueblo Real, Entrada a Isla Damas',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.4634971,
#    'lng': -84.1939616,
#    'latestObsDt': '2025-12-09 08:53',
#    'numSpeciesAllTime': 175},
#   {'locId': 'L7928552',
#    'locName': 'Quebrada Arroyo — Road',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.4737935,
#    'lng': -84.027782,
#    'latestObsDt': '2025-11-24 09:14',
#    'numSpeciesAllTime': 264},
#   {'locId': 'L501063',
#    'locName': 'Quepos',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.4318889,
#    'lng': -84.1655944,
#    'latestObsDt': '2025-12-04 14:28',
#    'numSpeciesAllTime': 359},
#   {'locId': 'L2132992',
#    'locName': 'Quepos--La Foresta Nature Resort',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.4399876,
#    'lng': -84.1367651,
#    'latestObsDt': '2025-11-21 16:14',
#    'numSpeciesAllTime': 227},
#   {'locId': 'L4829224',
#    'locName': 'Quepos--Marina Pez Vela-Pier and surroundings',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.425074,
#    'lng': -84.1696581,
#    'latestObsDt': '2025-12-09 09:01',
#    'numSpeciesAllTime': 171},
#   {'locId': 'L3094290',
#    'locName': 'Quepos--Rice fields North of high school.',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.4533798,
#    'lng': -84.1723967,
#    'latestObsDt': '2025-12-10 13:55',
#    'numSpeciesAllTime': 174},
#   {'locId': 'L2103221',
#    'locName': 'Rainmaker Conservation Project',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.5766723,
#    'lng': -84.2160679,
#    'latestObsDt': '2025-12-10 08:26',
#    'numSpeciesAllTime': 244},
#   {'locId': 'L3308553',
#    'locName': 'Restaurante Finca Mona--Quepos, Puntarenas.',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.3942891,
#    'lng': -84.0691611,
#    'latestObsDt': '2025-09-22 07:03',
#    'numSpeciesAllTime': 128},
#   {'locId': 'L2795875',
#    'locName': 'Rio Parrita, frente a camaronera',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.502736,
#    'lng': -84.3282223,
#    'latestObsDt': '2025-10-11 07:14',
#    'numSpeciesAllTime': 193},
#   {'locId': 'L3871374',
#    'locName': 'Rio Parrita--boca del río',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.4913076,
#    'lng': -84.3326426,
#    'latestObsDt': '2025-11-19 17:05',
#    'numSpeciesAllTime': 190},
#   {'locId': 'L3748598',
#    'locName': 'Rio la Gallega, Naranjito',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.49845,
#    'lng': -84.11789,
#    'latestObsDt': '2025-11-18 15:46',
#    'numSpeciesAllTime': 229},
#   {'locId': 'L3938264',
#    'locName': 'Santa Juana Lodge',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.5328788,
#    'lng': -84.0780262,
#    'latestObsDt': '2025-08-23 05:30',
#    'numSpeciesAllTime': 280},
#   {'locId': 'L2577899',
#    'locName': 'Si Como No Hotel',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.4038842,
#    'lng': -84.1554773,
#    'latestObsDt': '2025-12-05 07:25',
#    'numSpeciesAllTime': 228},
#   {'locId': 'L4702312',
#    'locName': 'Villa Nueva de Quepos',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.4735718,
#    'lng': -84.0628982,
#    'latestObsDt': '2025-12-12 08:27',
#    'numSpeciesAllTime': 291}],
#  'Parque Nacional Manuel Antonio, Costa Rica': [{'locId': 'L2102226',
#    'locName': 'Arenas del Mar Resort (reserve, hotel grounds and drive way)',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.3983113,
#    'lng': -84.1629338,
#    'latestObsDt': '2025-10-12 15:09',
#    'numSpeciesAllTime': 191},
#   {'locId': 'L3300769',
#    'locName': 'Barrio Lourdes (town)',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.4505872,
#    'lng': -84.1271296,
#    'latestObsDt': '2025-12-15 06:10',
#    'numSpeciesAllTime': 101},
#   {'locId': 'L2873762',
#    'locName': 'Biesanz beach',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.401709,
#    'lng': -84.1675043,
#    'latestObsDt': '2025-12-09 15:40',
#    'numSpeciesAllTime': 211},
#   {'locId': 'L3308537',
#    'locName': 'Buenavista Villas/Tulemar',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.4078746,
#    'lng': -84.159738,
#    'latestObsDt': '2025-12-04 06:48',
#    'numSpeciesAllTime': 241},
#   {'locId': 'L1278192',
#    'locName': 'Dominical',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.2546139,
#    'lng': -83.8624105,
#    'latestObsDt': '2025-12-12 17:04',
#    'numSpeciesAllTime': 346},
#   {'locId': 'L832176',
#    'locName': 'Dominical--Roca Verde',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.2454986,
#    'lng': -83.854085,
#    'latestObsDt': '2025-12-07 11:24',
#    'numSpeciesAllTime': 165},
#   {'locId': 'L2078668',
#    'locName': 'Dominical--Villas Rio Mar',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.2634833,
#    'lng': -83.8602691,
#    'latestObsDt': '2025-12-11 06:13',
#    'numSpeciesAllTime': 306},
#   {'locId': 'L4335658',
#    'locName': 'Dominicalito Beach',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.2313169,
#    'lng': -83.8414496,
#    'latestObsDt': '2025-10-23 15:00',
#    'numSpeciesAllTime': 158},
#   {'locId': 'L3747719',
#    'locName': 'El Mono Azul Hotel',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.4209429,
#    'lng': -84.1594014,
#    'latestObsDt': '2025-11-14 17:02',
#    'numSpeciesAllTime': 96},
#   {'locId': 'L3898789',
#    'locName': 'Finca Los Alfaro Grasslands--Quepos',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.4406639,
#    'lng': -84.1601765,
#    'latestObsDt': '2025-12-06 11:25',
#    'numSpeciesAllTime': 165},
#   {'locId': 'L2364240',
#    'locName': 'Finca Maritima (Playa El Rey) rice fields',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.3791205,
#    'lng': -84.0604949,
#    'latestObsDt': '2025-12-10 11:28',
#    'numSpeciesAllTime': 351},
#   {'locId': 'L448818',
#    'locName': 'Hacienda Baru',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.2715138,
#    'lng': -83.880744,
#    'latestObsDt': '2025-12-12 09:30',
#    'numSpeciesAllTime': 436},
#   {'locId': 'L1351111',
#    'locName': 'Hotel Costa Verde',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.3986344,
#    'lng': -84.1541689,
#    'latestObsDt': '2025-11-21 13:26',
#    'numSpeciesAllTime': 189},
#   {'locId': 'L4475440',
#    'locName': 'Hotel Gaia--Hotel and reserve.',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.4173741,
#    'lng': -84.1578805,
#    'latestObsDt': '2025-10-30 05:00',
#    'numSpeciesAllTime': 158},
#   {'locId': 'L10206898',
#    'locName': 'Hotel Makanda by the Sea (restricted access)',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.4029964,
#    'lng': -84.1626817,
#    'latestObsDt': '2025-07-29 07:17',
#    'numSpeciesAllTime': 100},
#   {'locId': 'L2249175',
#    'locName': 'Hotel Plaza Yara',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.4196357,
#    'lng': -84.1582319,
#    'latestObsDt': '2025-08-10 15:39',
#    'numSpeciesAllTime': 63},
#   {'locId': 'L2063612',
#    'locName': 'La Palapa Ecolodge Resort',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.3622681,
#    'lng': -83.9759731,
#    'latestObsDt': '2025-02-28 21:10',
#    'numSpeciesAllTime': 117},
#   {'locId': 'L3859186',
#    'locName': 'La Parcela restaurante and Cabinas',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.2228237,
#    'lng': -83.8422918,
#    'latestObsDt': '2025-12-13 14:37',
#    'numSpeciesAllTime': 127},
#   {'locId': 'L18318352',
#    'locName': 'Los Altos Resort (restricted access)',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.405456,
#    'lng': -84.1579342,
#    'latestObsDt': '2025-12-04 15:18',
#    'numSpeciesAllTime': 107},
#   {'locId': 'L3881190',
#    'locName': 'Manglar Kayak lodge (donde "Maco")',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.4842811,
#    'lng': -84.2182624,
#    'latestObsDt': '2025-12-08 09:17',
#    'numSpeciesAllTime': 205},
#   {'locId': 'L509908',
#    'locName': 'Manglares Damas',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.4619308,
#    'lng': -84.2156982,
#    'latestObsDt': '2025-12-05 14:13',
#    'numSpeciesAllTime': 247},
#   {'locId': 'L4892172',
#    'locName': 'Manuel Antonio -- Jungle Creek Villas',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.4159775,
#    'lng': -84.1546953,
#    'latestObsDt': '2025-12-15 09:22',
#    'numSpeciesAllTime': 178},
#   {'locId': 'L2480432',
#    'locName': 'Manuel Antonio--Road to Parador hotel',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.4018149,
#    'lng': -84.1604662,
#    'latestObsDt': '2025-11-13 05:45',
#    'numSpeciesAllTime': 192},
#   {'locId': 'L448817',
#    'locName': 'Manuel Antonio--hotels near park',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.3909527,
#    'lng': -84.1471936,
#    'latestObsDt': '2025-12-13 07:31',
#    'numSpeciesAllTime': 372},
#   {'locId': 'L585224',
#    'locName': 'Naranjito',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.471142,
#    'lng': -84.1052771,
#    'latestObsDt': '2025-12-06 06:07',
#    'numSpeciesAllTime': 261},
#   {'locId': 'L724260',
#    'locName': 'PN Manuel Antonio',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.3845275,
#    'lng': -84.1430619,
#    'latestObsDt': '2025-12-15 07:07',
#    'numSpeciesAllTime': 439},
#   {'locId': 'L2249173',
#    'locName': 'PN Manuel Antonio--Mangroves',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.3881252,
#    'lng': -84.1464731,
#    'latestObsDt': '2025-12-14 06:32',
#    'numSpeciesAllTime': 273},
#   {'locId': 'L3789351',
#    'locName': 'Paquita, grasslands behind the rodeo corral.',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.464894,
#    'lng': -84.1803789,
#    'latestObsDt': '2025-09-02 14:29',
#    'numSpeciesAllTime': 166},
#   {'locId': 'L1848099',
#    'locName': 'Parador Resort and Spa',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.397801,
#    'lng': -84.169388,
#    'latestObsDt': '2025-12-12 08:11',
#    'numSpeciesAllTime': 222},
#   {'locId': 'L10478874',
#    'locName': 'Parque Nahomi',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.4224968,
#    'lng': -84.1693497,
#    'latestObsDt': '2025-08-23 08:52',
#    'numSpeciesAllTime': 133},
#   {'locId': 'L1884540',
#    'locName': 'Parrita--Pueblo Nuevo shrimp farm',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.5020462,
#    'lng': -84.3230283,
#    'latestObsDt': '2025-10-11 10:30',
#    'numSpeciesAllTime': 167},
#   {'locId': 'L2884089',
#    'locName': 'Pelagic--Route between Quepos to Furuno in the south pacific.',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 8.9908876,
#    'lng': -84.0344238,
#    'latestObsDt': '2025-08-31 10:00',
#    'numSpeciesAllTime': 25},
#   {'locId': 'L3527795',
#    'locName': 'Playa Espadilla Norte (Public beach outside the park).',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.3932575,
#    'lng': -84.1531813,
#    'latestObsDt': '2025-12-06 13:49',
#    'numSpeciesAllTime': 228},
#   {'locId': 'L3928059',
#    'locName': 'Playa Isla Damas',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.4551154,
#    'lng': -84.2176723,
#    'latestObsDt': '2025-11-20 06:46',
#    'numSpeciesAllTime': 143},
#   {'locId': 'L3926046',
#    'locName': 'Playa Linda--Swamp in route to the beach',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.3143,
#    'lng': -83.9448166,
#    'latestObsDt': '2025-12-10 12:29',
#    'numSpeciesAllTime': 250},
#   {'locId': 'L5218074',
#    'locName': 'Playa Matapalo',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.3209184,
#    'lng': -83.9582431,
#    'latestObsDt': '2025-12-14 11:39',
#    'numSpeciesAllTime': 224},
#   {'locId': 'L3873123',
#    'locName': 'Playa linda',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.3095886,
#    'lng': -83.9425421,
#    'latestObsDt': '2025-12-14 10:27',
#    'numSpeciesAllTime': 241},
#   {'locId': 'L1878405',
#    'locName': 'Portalon',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.3544768,
#    'lng': -83.9803505,
#    'latestObsDt': '2025-06-22 15:38',
#    'numSpeciesAllTime': 211},
#   {'locId': 'L11431955',
#    'locName': 'Portasol living Birder House',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.3731784,
#    'lng': -83.9622937,
#    'latestObsDt': '2024-01-15 10:50',
#    'numSpeciesAllTime': 247},
#   {'locId': 'L3058980',
#    'locName': 'Pueblo Real, Entrada a Isla Damas',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.4634971,
#    'lng': -84.1939616,
#    'latestObsDt': '2025-12-09 08:53',
#    'numSpeciesAllTime': 175},
#   {'locId': 'L501063',
#    'locName': 'Quepos',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.4318889,
#    'lng': -84.1655944,
#    'latestObsDt': '2025-12-04 14:28',
#    'numSpeciesAllTime': 359},
#   {'locId': 'L2132992',
#    'locName': 'Quepos--La Foresta Nature Resort',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.4399876,
#    'lng': -84.1367651,
#    'latestObsDt': '2025-11-21 16:14',
#    'numSpeciesAllTime': 227},
#   {'locId': 'L4829224',
#    'locName': 'Quepos--Marina Pez Vela-Pier and surroundings',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.425074,
#    'lng': -84.1696581,
#    'latestObsDt': '2025-12-09 09:01',
#    'numSpeciesAllTime': 171},
#   {'locId': 'L3094290',
#    'locName': 'Quepos--Rice fields North of high school.',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.4533798,
#    'lng': -84.1723967,
#    'latestObsDt': '2025-12-10 13:55',
#    'numSpeciesAllTime': 174},
#   {'locId': 'L3308553',
#    'locName': 'Restaurante Finca Mona--Quepos, Puntarenas.',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.3942891,
#    'lng': -84.0691611,
#    'latestObsDt': '2025-09-22 07:03',
#    'numSpeciesAllTime': 128},
#   {'locId': 'L3859054',
#    'locName': 'Rio Baru--river mouth',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.2534702,
#    'lng': -83.8670754,
#    'latestObsDt': '2025-12-12 16:34',
#    'numSpeciesAllTime': 251},
#   {'locId': 'L3871374',
#    'locName': 'Rio Parrita--boca del río',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.4913076,
#    'lng': -84.3326426,
#    'latestObsDt': '2025-11-19 17:05',
#    'numSpeciesAllTime': 190},
#   {'locId': 'L3859157',
#    'locName': 'Rocas de Amancio (North of Dominicalito beach)',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.2395398,
#    'lng': -83.8501078,
#    'latestObsDt': '2025-04-25 15:43',
#    'numSpeciesAllTime': 152},
#   {'locId': 'L5626588',
#    'locName': 'Seamount Furuno (4-1)',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 8.8833213,
#    'lng': -84.1753055,
#    'latestObsDt': '2024-05-09 09:50',
#    'numSpeciesAllTime': 19},
#   {'locId': 'L2577899',
#    'locName': 'Si Como No Hotel',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.4038842,
#    'lng': -84.1554773,
#    'latestObsDt': '2025-12-05 07:25',
#    'numSpeciesAllTime': 228},
#   {'locId': 'L4702312',
#    'locName': 'Villa Nueva de Quepos',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.4735718,
#    'lng': -84.0628982,
#    'latestObsDt': '2025-12-12 08:27',
#    'numSpeciesAllTime': 291},
#   {'locId': 'L441882',
#    'locName': 'manglares del Río Hatillo Viejo',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.2846859,
#    'lng': -83.9039612,
#    'latestObsDt': '2025-01-27 16:28',
#    'numSpeciesAllTime': 180}],
#  'Parque Nacional Carara, Costa Rica': [{'locId': 'L1349030',
#    'locName': 'Bahía Herradura',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.6476457,
#    'lng': -84.6571886,
#    'latestObsDt': '2025-09-27 11:38',
#    'numSpeciesAllTime': 211},
#   {'locId': 'L3536583',
#    'locName': 'BajaMar',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.8473938,
#    'lng': -84.6798277,
#    'latestObsDt': '2025-10-11 09:09',
#    'numSpeciesAllTime': 198},
#   {'locId': 'L21793817',
#    'locName': 'Boca del Río Tarcolitos',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.7583834,
#    'lng': -84.6277357,
#    'latestObsDt': '2025-12-15 16:33',
#    'numSpeciesAllTime': 242},
#   {'locId': 'L1859717',
#    'locName': 'Bocana de Puriscal',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-SJ',
#    'lat': 9.7760546,
#    'lng': -84.3687344,
#    'latestObsDt': '2025-02-26 15:30',
#    'numSpeciesAllTime': 197},
#   {'locId': 'L16383495',
#    'locName': 'Bosque Municipal de Atenas',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-A',
#    'lat': 9.9727818,
#    'lng': -84.4393194,
#    'latestObsDt': '2025-12-09 09:14',
#    'numSpeciesAllTime': 123},
#   {'locId': 'L15861828',
#    'locName': 'Casa Plinia',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-SJ',
#    'lat': 9.7011613,
#    'lng': -84.4043005,
#    'latestObsDt': '2025-11-01 11:30',
#    'numSpeciesAllTime': 229},
#   {'locId': 'L1456434',
#    'locName': 'Cerro Lodge',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.808,
#    'lng': -84.611,
#    'latestObsDt': '2025-12-15 19:07',
#    'numSpeciesAllTime': 386},
#   {'locId': 'L3541917',
#    'locName': 'Cerro Lodge entrance road',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.8201891,
#    'lng': -84.6074252,
#    'latestObsDt': '2025-12-11 19:09',
#    'numSpeciesAllTime': 332},
#   {'locId': 'L6966542',
#    'locName': 'Colegio Técnico Profesional La Gloria',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-SJ',
#    'lat': 9.6528348,
#    'lng': -84.4441366,
#    'latestObsDt': '2025-11-26 08:35',
#    'numSpeciesAllTime': 208},
#   {'locId': 'L1470777',
#    'locName': 'Estero Mata de Limón (Caldera)',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.9206938,
#    'lng': -84.7125485,
#    'latestObsDt': '2025-12-16 07:45',
#    'numSpeciesAllTime': 284},
#   {'locId': 'L20096545',
#    'locName': 'Galán de Turrubares',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-SJ',
#    'lat': 9.7441627,
#    'lng': -84.4914626,
#    'latestObsDt': '2025-01-19 15:41',
#    'numSpeciesAllTime': 79},
#   {'locId': 'L5377452',
#    'locName': 'Guacalillo--Bird Observatory',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.8013722,
#    'lng': -84.6453849,
#    'latestObsDt': '2025-06-15 08:15',
#    'numSpeciesAllTime': 244},
#   {'locId': 'L4302411',
#    'locName': 'Guacalillo--Peñón',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.8342911,
#    'lng': -84.6753135,
#    'latestObsDt': '2025-10-08 00:00',
#    'numSpeciesAllTime': 186},
#   {'locId': 'L1456808',
#    'locName': 'Guacimo Road',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.8650149,
#    'lng': -84.6504579,
#    'latestObsDt': '2025-09-15 11:12',
#    'numSpeciesAllTime': 319},
#   {'locId': 'L4333101',
#    'locName': 'Hacienda Río Carara',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-SJ',
#    'lat': 9.7743295,
#    'lng': -84.5267856,
#    'latestObsDt': '2025-08-02 08:50',
#    'numSpeciesAllTime': 238},
#   {'locId': 'L585101',
#    'locName': 'Hotel Santa Lucía',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.7568323,
#    'lng': -84.6119882,
#    'latestObsDt': '2025-12-16 05:57',
#    'numSpeciesAllTime': 402},
#   {'locId': 'L3400822',
#    'locName': 'Hotel Vista Pacifico',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.6332424,
#    'lng': -84.6344796,
#    'latestObsDt': '2025-01-31 06:18',
#    'numSpeciesAllTime': 101},
#   {'locId': 'L17372373',
#    'locName': 'Jaco Wetland',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.6364574,
#    'lng': -84.6356653,
#    'latestObsDt': '2025-12-16 06:22',
#    'numSpeciesAllTime': 226},
#   {'locId': 'L9938998',
#    'locName': 'Jacó--Humedales Quebrada Bonita',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.6374552,
#    'lng': -84.6338141,
#    'latestObsDt': '2025-12-01 12:08',
#    'numSpeciesAllTime': 357},
#   {'locId': 'L2015279',
#    'locName': 'Jacó--Localidad general',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.6269753,
#    'lng': -84.628134,
#    'latestObsDt': '2025-12-13 09:00',
#    'numSpeciesAllTime': 362},
#   {'locId': 'L1471150',
#    'locName': 'Jacó--Playa',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.6167905,
#    'lng': -84.633138,
#    'latestObsDt': '2025-12-08 15:00',
#    'numSpeciesAllTime': 264},
#   {'locId': 'L2574391',
#    'locName': 'Jacó--Río por avenida Pastor Díaz',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.6160568,
#    'lng': -84.6300781,
#    'latestObsDt': '2025-12-10 09:30',
#    'numSpeciesAllTime': 220},
#   {'locId': 'L10191490',
#    'locName': 'La Balsa',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.6398143,
#    'lng': -84.644856,
#    'latestObsDt': '2025-03-02 16:55',
#    'numSpeciesAllTime': 176},
#   {'locId': 'L4912736',
#    'locName': 'La Ceiba de Orotina',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-A',
#    'lat': 9.9009085,
#    'lng': -84.6032667,
#    'latestObsDt': '2025-12-14 16:00',
#    'numSpeciesAllTime': 278},
#   {'locId': 'L3970792',
#    'locName': 'La Potenciana',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-SJ',
#    'lat': 9.7882345,
#    'lng': -84.4144177,
#    'latestObsDt': '2025-06-15 07:00',
#    'numSpeciesAllTime': 226},
#   {'locId': 'L4071755',
#    'locName': 'La Potenciana--Hacia El cruce de La virgen. Ruta conteo Carara',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-SJ',
#    'lat': 9.7916177,
#    'lng': -84.4454777,
#    'latestObsDt': '2025-09-13 06:57',
#    'numSpeciesAllTime': 195},
#   {'locId': 'L4506189',
#    'locName': 'Llano Grande',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-SJ',
#    'lat': 9.720901,
#    'lng': -84.4355106,
#    'latestObsDt': '2024-08-17 06:00',
#    'numSpeciesAllTime': 205},
#   {'locId': 'L3592763',
#    'locName': 'Los Suenos--road to former St. Regis pad',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.668385,
#    'lng': -84.664247,
#    'latestObsDt': '2025-11-30 14:25',
#    'numSpeciesAllTime': 185},
#   {'locId': 'L1631258',
#    'locName': 'Los Sueños Resort',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.6549138,
#    'lng': -84.6566474,
#    'latestObsDt': '2025-12-11 14:46',
#    'numSpeciesAllTime': 358},
#   {'locId': 'L3650798',
#    'locName': 'Macaw Lodge',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-SJ',
#    'lat': 9.7283846,
#    'lng': -84.5186135,
#    'latestObsDt': '2025-12-14 06:02',
#    'numSpeciesAllTime': 377},
#   {'locId': 'L20904129',
#    'locName': 'Mangrove Forest Trail -- Playa Azul',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.7835,
#    'lng': -84.633379,
#    'latestObsDt': '2025-12-14 06:24',
#    'numSpeciesAllTime': 380},
#   {'locId': 'L2146450',
#    'locName': 'Orotina--central park',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-A',
#    'lat': 9.9117656,
#    'lng': -84.5235933,
#    'latestObsDt': '2025-12-06 12:33',
#    'numSpeciesAllTime': 193},
#   {'locId': 'L10183565',
#    'locName': 'P.N. La Cangreja--Puesto Santa Rosa',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-SJ',
#    'lat': 9.703204,
#    'lng': -84.3979461,
#    'latestObsDt': '2025-11-01 09:09',
#    'numSpeciesAllTime': 236},
#   {'locId': 'L10183493',
#    'locName': 'P.N. La Cangreja--Ruta Alto Limón',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-SJ',
#    'lat': 9.7374944,
#    'lng': -84.348758,
#    'latestObsDt': '2023-12-02 05:15',
#    'numSpeciesAllTime': 191},
#   {'locId': 'L10183639',
#    'locName': 'P.N. La Cangreja--Ruta Alto Vara Blanca',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-SJ',
#    'lat': 9.7373396,
#    'lng': -84.3722618,
#    'latestObsDt': '2025-07-26 06:38',
#    'numSpeciesAllTime': 159},
#   {'locId': 'L10183704',
#    'locName': 'P.N. La Cangreja--Ruta Cerro Pelón',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-SJ',
#    'lat': 9.7295737,
#    'lng': -84.3929527,
#    'latestObsDt': '2024-12-07 07:14',
#    'numSpeciesAllTime': 189},
#   {'locId': 'L10183621',
#    'locName': 'P.N. La Cangreja--Ruta Salitrales',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-SJ',
#    'lat': 9.7638317,
#    'lng': -84.3980752,
#    'latestObsDt': '2025-05-10 07:58',
#    'numSpeciesAllTime': 184},
#   {'locId': 'L10183626',
#    'locName': 'P.N. La Cangreja--Ruta San Martín',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-SJ',
#    'lat': 9.7387966,
#    'lng': -84.3911658,
#    'latestObsDt': '2023-11-11 05:49',
#    'numSpeciesAllTime': 126},
#   {'locId': 'L10183677',
#    'locName': 'P.N. La Cangreja--Ruta Santa Rosa-Mastatal',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-SJ',
#    'lat': 9.6822656,
#    'lng': -84.3957796,
#    'latestObsDt': '2024-12-07 05:33',
#    'numSpeciesAllTime': 246},
#   {'locId': 'L10183736',
#    'locName': 'P.N. La Cangreja--Ruta Sendero Río Negro',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-SJ',
#    'lat': 9.6977439,
#    'lng': -84.3808784,
#    'latestObsDt': '2025-04-12 11:30',
#    'numSpeciesAllTime': 191},
#   {'locId': 'L10183655',
#    'locName': 'P.N. La Cangreja--Ruta Yarcazú',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-SJ',
#    'lat': 9.7058305,
#    'lng': -84.3733495,
#    'latestObsDt': '2024-02-08 07:54',
#    'numSpeciesAllTime': 177},
#   {'locId': 'L10183587',
#    'locName': 'P.N. La Cangreja--Sendero Plinia (Sector Mastatal)',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-SJ',
#    'lat': 9.6873878,
#    'lng': -84.3732223,
#    'latestObsDt': '2025-07-15 07:42',
#    'numSpeciesAllTime': 187},
#   {'locId': 'L447761',
#    'locName': 'PN Carara (Localidad General)--historical please use other hotspots',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-P',
#    'lat': 9.7844453,
#    'lng': -84.5664024,
#    'latestObsDt': '2025-12-13 05:45',
#    'numSpeciesAllTime': 429},
#   {'locId': 'L325916',
#    'locName': 'PN Carara--Puente Río  Tárcoles',
#    'countryCode': 'CR',
# ...
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-A',
#    'lat': 10.0419743,
#    'lng': -84.2969067,
#    'latestObsDt': '2025-11-08 14:12',
#    'numSpeciesAllTime': 3},
#   {'locId': 'L1307821',
#    'locName': 'Colinas del Poás',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-A',
#    'lat': 10.1558088,
#    'lng': -84.1895092,
#    'latestObsDt': '2025-10-17 12:29',
#    'numSpeciesAllTime': 97},
#   {'locId': 'L10201668',
#    'locName': 'Corso Lechería Tour',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-A',
#    'lat': 10.1580064,
#    'lng': -84.1743421,
#    'latestObsDt': '2025-12-15 09:26',
#    'numSpeciesAllTime': 120},
#   {'locId': 'L2157491',
#    'locName': "Dave & Dave's Costa Rica Nature Park",
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-H',
#    'lat': 10.4132595,
#    'lng': -84.127357,
#    'latestObsDt': '2025-12-06 14:25',
#    'numSpeciesAllTime': 263},
#   {'locId': 'L9171225',
#    'locName': 'Doka Estate Coffee Tour',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-A',
#    'lat': 10.097834,
#    'lng': -84.211284,
#    'latestObsDt': '2025-12-10 11:37',
#    'numSpeciesAllTime': 238},
#   {'locId': 'L1607257',
#    'locName': 'El Plástico (Selva Tica)',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-H',
#    'lat': 10.3025809,
#    'lng': -84.0342377,
#    'latestObsDt': '2025-01-14 10:23',
#    'numSpeciesAllTime': 337},
#   {'locId': 'L11401530',
#    'locName': 'El Tirol',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-H',
#    'lat': 10.0745918,
#    'lng': -84.0882573,
#    'latestObsDt': '2025-10-15 10:53',
#    'numSpeciesAllTime': 110},
#   {'locId': 'L5431695',
#    'locName': 'El Tucano Lodge',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-A',
#    'lat': 10.365022,
#    'lng': -84.3815178,
#    'latestObsDt': '2025-09-10 02:19',
#    'numSpeciesAllTime': 222},
#   {'locId': 'L4494051',
#    'locName': 'Finca Isla Wellness Retreat',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-A',
#    'lat': 10.3712958,
#    'lng': -84.3213015,
#    'latestObsDt': '2025-09-26 00:00',
#    'numSpeciesAllTime': 113},
#   {'locId': 'L12776472',
#    'locName': 'Finca Mirador Las Palmeras',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-A',
#    'lat': 10.1106049,
#    'lng': -84.3262501,
#    'latestObsDt': '2025-02-14 07:18',
#    'numSpeciesAllTime': 109},
#   {'locId': 'L16194302',
#    'locName': 'Finca Molinas',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-A',
#    'lat': 10.0536897,
#    'lng': -84.2191508,
#    'latestObsDt': '2025-11-30 07:09',
#    'numSpeciesAllTime': 153},
#   {'locId': 'L2333406',
#    'locName': 'Finca Rosa Blanca',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-H',
#    'lat': 10.0454281,
#    'lng': -84.1516738,
#    'latestObsDt': '2025-12-07 06:56',
#    'numSpeciesAllTime': 226},
#   {'locId': 'L436224',
#    'locName': 'Galeria de Colibrí y Soda Cinchona - Mirador San Fernando',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-A',
#    'lat': 10.2221488,
#    'lng': -84.167255,
#    'latestObsDt': '2025-12-16 06:47',
#    'numSpeciesAllTime': 439},
#   {'locId': 'L1283736',
#    'locName': 'Grecia',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-A',
#    'lat': 10.0723047,
#    'lng': -84.3118286,
#    'latestObsDt': '2025-11-08 06:09',
#    'numSpeciesAllTime': 164},
#   {'locId': 'L5496914',
#    'locName': 'Hacienda Pozo Azul',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-H',
#    'lat': 10.3877434,
#    'lng': -84.1394806,
#    'latestObsDt': '2025-12-14 11:00',
#    'numSpeciesAllTime': 270},
#   {'locId': 'L2946480',
#    'locName': 'Hotel Buena Vista',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-A',
#    'lat': 10.0577163,
#    'lng': -84.1991597,
#    'latestObsDt': '2025-11-25 16:55',
#    'numSpeciesAllTime': 227},
#   {'locId': 'L7524923',
#    'locName': 'Hotel Termales Del Bosque',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-A',
#    'lat': 10.3630906,
#    'lng': -84.3902349,
#    'latestObsDt': '2025-10-06 16:04',
#    'numSpeciesAllTime': 107},
#   {'locId': 'L17684676',
#    'locName': 'Humedal, Pavas, Carrizal, Alajuela',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-A',
#    'lat': 10.0645596,
#    'lng': -84.1770515,
#    'latestObsDt': '2025-10-15 07:58',
#    'numSpeciesAllTime': 167},
#   {'locId': 'L7911554',
#    'locName': 'Jardines El Rey De Cocora',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-A',
#    'lat': 10.2093534,
#    'lng': -84.169466,
#    'latestObsDt': '2025-09-20 12:05',
#    'numSpeciesAllTime': 263},
#   {'locId': 'L6677164',
#    'locName': 'Jardín Botánico Else Kientzler (Sarchi)',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-A',
#    'lat': 10.0998452,
#    'lng': -84.3400441,
#    'latestObsDt': '2025-11-02 14:46',
#    'numSpeciesAllTime': 156},
#   {'locId': 'L445844',
#    'locName': 'La Paz Waterfall Gardens',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-H',
#    'lat': 10.2038227,
#    'lng': -84.1618352,
#    'latestObsDt': '2025-12-16 09:07',
#    'numSpeciesAllTime': 458},
#   {'locId': 'L3342922',
#    'locName': 'Laguna Hule',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-A',
#    'lat': 10.2945372,
#    'lng': -84.2088318,
#    'latestObsDt': '2025-10-23 13:16',
#    'numSpeciesAllTime': 373},
#   {'locId': 'L2095820',
#    'locName': 'Laguna San Miguel',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-A',
#    'lat': 10.301408,
#    'lng': -84.1878891,
#    'latestObsDt': '2025-12-08 11:48',
#    'numSpeciesAllTime': 165},
#   {'locId': 'L5176840',
#    'locName': 'Manzanal (Prox. Urbanización), Puente de Piedra',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-A',
#    'lat': 10.0474057,
#    'lng': -84.3103078,
#    'latestObsDt': '2025-06-13 08:33',
#    'numSpeciesAllTime': 89},
#   {'locId': 'L3993899',
#    'locName': 'Mi Cafecito restaurant and farm',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-A',
#    'lat': 10.2936212,
#    'lng': -84.185361,
#    'latestObsDt': '2025-11-30 09:20',
#    'numSpeciesAllTime': 288},
#   {'locId': 'L5928811',
#    'locName': 'Monte Tavor',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-A',
#    'lat': 10.1672853,
#    'lng': -84.2993939,
#    'latestObsDt': '2025-06-07 05:43',
#    'numSpeciesAllTime': 134},
#   {'locId': 'L6047181',
#    'locName': 'Monte de la Cruz',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-H',
#    'lat': 10.0671411,
#    'lng': -84.0760946,
#    'latestObsDt': '2025-12-06 09:59',
#    'numSpeciesAllTime': 191},
#   {'locId': 'L3636759',
#    'locName': 'NP Juan Castro Blanco--Albergue Pozo Verde',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-A',
#    'lat': 10.2541352,
#    'lng': -84.3730474,
#    'latestObsDt': '2025-11-25 10:33',
#    'numSpeciesAllTime': 203},
#   {'locId': 'L33057120',
#    'locName': 'Nacientes Manantial',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-A',
#    'lat': 10.3469362,
#    'lng': -84.3356589,
#    'latestObsDt': '2025-11-01 06:47',
#    'numSpeciesAllTime': 121},
#   {'locId': 'L441317',
#    'locName': 'Naranjo--Cerro Espíritu Santo',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-A',
#    'lat': 10.0856567,
#    'lng': -84.4059849,
#    'latestObsDt': '2025-11-26 11:42',
#    'numSpeciesAllTime': 227},
#   {'locId': 'L6146366',
#    'locName': 'Naranjo--Espítitu Santo Coffee Tour (Hda.Coopronaranjo)',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-A',
#    'lat': 10.0956016,
#    'lng': -84.3839298,
#    'latestObsDt': '2025-10-17 10:14',
#    'numSpeciesAllTime': 183},
#   {'locId': 'L6253236',
#    'locName': 'PN Braulio Carrillo--El Ceibo',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-H',
#    'lat': 10.327627,
#    'lng': -84.078238,
#    'latestObsDt': '2025-11-01 08:23',
#    'numSpeciesAllTime': 399},
#   {'locId': 'L3550808',
#    'locName': 'PN Braulio Carrillo--Volcán Barva',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-H',
#    'lat': 10.1353215,
#    'lng': -84.1091224,
#    'latestObsDt': '2025-12-15 11:30',
#    'numSpeciesAllTime': 210},
#   {'locId': 'L3608284',
#    'locName': 'PN Juan Castro Blanco--Bajos del Toro',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-A',
#    'lat': 10.2356,
#    'lng': -84.305,
#    'latestObsDt': '2025-12-15 15:21',
#    'numSpeciesAllTime': 257},
#   {'locId': 'L1331161',
#    'locName': 'PN Volcán Poás',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-A',
#    'lat': 10.1837344,
#    'lng': -84.2359457,
#    'latestObsDt': '2025-12-16 10:50',
#    'numSpeciesAllTime': 233},
#   {'locId': 'L15993754',
#    'locName': 'Parque Nacional Juan Castro Blanco--- Montaña Sagrada',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-A',
#    'lat': 10.2563953,
#    'lng': -84.364958,
#    'latestObsDt': '2025-12-08 10:00',
#    'numSpeciesAllTime': 197},
#   {'locId': 'L4466949',
#    'locName': 'Parque Recreativo Municipal Los Chorros',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-A',
#    'lat': 10.0518532,
#    'lng': -84.2774534,
#    'latestObsDt': '2025-05-31 10:36',
#    'numSpeciesAllTime': 150},
#   {'locId': 'L2280776',
#    'locName': 'Poasito',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-A',
#    'lat': 10.1610159,
#    'lng': -84.198604,
#    'latestObsDt': '2025-12-09 13:24',
#    'numSpeciesAllTime': 135},
#   {'locId': 'L5090864',
#    'locName': 'Poasito--Freddo Fresas',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-A',
#    'lat': 10.156886,
#    'lng': -84.1959963,
#    'latestObsDt': '2025-11-22 14:17',
#    'numSpeciesAllTime': 163},
#   {'locId': 'L441883',
#    'locName': 'Poás Volcano Lodge',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-H',
#    'lat': 10.1621135,
#    'lng': -84.1588247,
#    'latestObsDt': '2025-12-16 06:00',
#    'numSpeciesAllTime': 203},
#   {'locId': 'L523555',
#    'locName': 'Rara Avis',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-H',
#    'lat': 10.28173,
#    'lng': -84.04489,
#    'latestObsDt': '2021-09-21 12:10',
#    'numSpeciesAllTime': 453},
#   {'locId': 'L3605626',
#    'locName': 'Recreo Verde',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-A',
#    'lat': 10.32069,
#    'lng': -84.2434,
#    'latestObsDt': '2025-07-04 08:40',
#    'numSpeciesAllTime': 129},
#   {'locId': 'L4131068',
#    'locName': 'Refugio de Vida Silvestre Cerro Dantas',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-H',
#    'lat': 10.091079,
#    'lng': -84.060483,
#    'latestObsDt': '2025-10-11 13:25',
#    'numSpeciesAllTime': 171},
#   {'locId': 'L8005145',
#    'locName': 'Refugio de Vida Silvestre Cerro Dantas--Camino de entrada',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-H',
#    'lat': 10.0818432,
#    'lng': -84.0777102,
#    'latestObsDt': '2025-12-11 06:45',
#    'numSpeciesAllTime': 180},
#   {'locId': 'L1537452',
#    'locName': 'Reserva Ecológica Bijagual',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-H',
#    'lat': 10.3617276,
#    'lng': -84.1040038,
#    'latestObsDt': '2025-11-20 07:30',
#    'numSpeciesAllTime': 335},
#   {'locId': 'L29563278',
#    'locName': 'Reserva Mecarina (acceso restringido)',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-A',
#    'lat': 10.3685882,
#    'lng': -84.3714538,
#    'latestObsDt': '2025-06-24 11:30',
#    'numSpeciesAllTime': 120},
#   {'locId': 'L2277803',
#    'locName': 'Road to PN Volcán Poás',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-A',
#    'lat': 10.1601302,
#    'lng': -84.2276244,
#    'latestObsDt': '2025-10-09 11:38',
#    'numSpeciesAllTime': 205},
#   {'locId': 'L5796563',
#    'locName': 'San Luis de Grecia',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-A',
#    'lat': 10.1351302,
#    'lng': -84.306829,
#    'latestObsDt': '2025-12-13 09:00',
#    'numSpeciesAllTime': 224},
#   {'locId': 'L2941749',
#    'locName': 'San Miguel to Virgen del Socorro road',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-A',
#    'lat': 10.3011257,
#    'lng': -84.1706747,
#    'latestObsDt': '2025-12-15 14:09',
#    'numSpeciesAllTime': 413},
#   {'locId': 'L2310175',
#    'locName': 'San Pedro de Poas--Calle Vargas',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-A',
#    'lat': 10.053628,
#    'lng': -84.2335939,
#    'latestObsDt': '2025-06-07 07:19',
#    'numSpeciesAllTime': 111},
#   {'locId': 'L3315219',
#    'locName': 'SarapiquiS Rainforest Lodge',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-H',
#    'lat': 10.4172798,
#    'lng': -84.1233498,
#    'latestObsDt': '2025-12-13 07:50',
#    'numSpeciesAllTime': 321},
#   {'locId': 'L37802303',
#    'locName': 'Sarchí--Hda. La Eva restaurante, cafe y senderos',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-A',
#    'lat': 10.0981968,
#    'lng': -84.3470328,
#    'latestObsDt': '2025-12-07 10:00',
#    'numSpeciesAllTime': 160},
#   {'locId': 'L9820408',
#    'locName': 'Sendero Rey de Cocora',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-A',
#    'lat': 10.2048559,
#    'lng': -84.1764441,
#    'latestObsDt': '2025-03-10 13:24',
#    'numSpeciesAllTime': 201},
#   {'locId': 'L2845579',
#    'locName': 'Tacacori Eco Lodge',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-A',
#    'lat': 10.0593959,
#    'lng': -84.208349,
#    'latestObsDt': '2025-11-02 10:15',
#    'numSpeciesAllTime': 120},
#   {'locId': 'L21592770',
#    'locName': 'The Nest Nature Center',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-A',
#    'lat': 10.364506,
#    'lng': -84.3456486,
#    'latestObsDt': '2025-12-15 10:39',
#    'numSpeciesAllTime': 258},
#   {'locId': 'L10302649',
#    'locName': 'Tiquicia Lodge',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-H',
#    'lat': 10.1778166,
#    'lng': -84.1579771,
#    'latestObsDt': '2025-12-08 08:44',
#    'numSpeciesAllTime': 163},
#   {'locId': 'L470684',
#    'locName': 'Tirimbina Rainforest Center',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-H',
#    'lat': 10.41562,
#    'lng': -84.12078,
#    'latestObsDt': '2025-12-12 12:09',
#    'numSpeciesAllTime': 448},
#   {'locId': 'L3673157',
#    'locName': 'Tirimbina--Field Station',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-H',
#    'lat': 10.3995203,
#    'lng': -84.1019082,
#    'latestObsDt': '2025-11-02 13:27',
#    'numSpeciesAllTime': 330},
#   {'locId': 'L5921214',
#    'locName': 'UCR Recinto de Tacares de Grecia',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-A',
#    'lat': 10.0418435,
#    'lng': -84.3002495,
#    'latestObsDt': '2025-11-07 06:04',
#    'numSpeciesAllTime': 116},
#   {'locId': 'L19155318',
#    'locName': 'Ventisqueros Camping y Hacienda Los Trapiches',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-A',
#    'lat': 10.0683562,
#    'lng': -84.2727946,
#    'latestObsDt': '2025-05-10 09:38',
#    'numSpeciesAllTime': 91},
#   {'locId': 'L1144236',
#    'locName': 'Villa San Ignacio, Alajuela',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-A',
#    'lat': 10.0259066,
#    'lng': -84.2512751,
#    'latestObsDt': '2025-12-16 06:37',
#    'numSpeciesAllTime': 312},
#   {'locId': 'L436225',
#    'locName': 'Virgen del Socorro',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-A',
#    'lat': 10.25537,
#    'lng': -84.17019,
#    'latestObsDt': '2025-12-14 08:30',
#    'numSpeciesAllTime': 499},
#   {'locId': 'L3547676',
#    'locName': 'Volcan Poas--Restaurant El Rio',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-A',
#    'lat': 10.1621043,
#    'lng': -84.2037488,
#    'latestObsDt': '2025-11-08 12:20',
#    'numSpeciesAllTime': 137},
#   {'locId': 'L2907146',
#    'locName': 'Xandari Resort & Spa',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-A',
#    'lat': 10.0570407,
#    'lng': -84.2116223,
#    'latestObsDt': '2025-12-15 20:06',
#    'numSpeciesAllTime': 250},
#   {'locId': 'L5420709',
#    'locName': 'Zarcero - Bajos del Toro road',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-A',
#    'lat': 10.2004636,
#    'lng': -84.3334036,
#    'latestObsDt': '2025-10-30 08:58',
#    'numSpeciesAllTime': 118},
#   {'locId': 'L5983488',
#    'locName': 'Zona Protectora El Chayote',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-A',
#    'lat': 10.1833226,
#    'lng': -84.3413766,
#    'latestObsDt': '2025-11-23 13:28',
#    'numSpeciesAllTime': 205},
#   {'locId': 'L13645683',
#    'locName': 'Zona Protectora El Chayote--Alto del Rualdo',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-A',
#    'lat': 10.1707386,
#    'lng': -84.3522127,
#    'latestObsDt': '2025-09-26 10:00',
#    'numSpeciesAllTime': 146},
#   {'locId': 'L1345796',
#    'locName': 'Zoológico la Marina',
#    'countryCode': 'CR',
#    'subnational1Code': 'CR-A',
#    'lat': 10.3774582,
#    'lng': -84.3762433,
#    'latestObsDt': '2025-10-20 15:59',
#    'numSpeciesAllTime': 132}]}

# %%
all_hotspot_keys = set()
for hotspots in spots_per_loc.values():
    for spot_data in hotspots:
        all_hotspot_keys.update(spot_data.keys())

all_hotspot_keys
# Out:
# {'countryCode',
#  'lat',
#  'latestObsDt',
#  'lng',
#  'locId',
#  'locName',
#  'numSpeciesAllTime',
#  'subnational1Code'}

# %%
from birding.primitives import EBirdHotspot

hotspots_per_location = {
    loc: {EBirdHotspot.from_json(hotspot_data) for hotspot_data in hotspots}
    for loc, hotspots in spots_per_loc.items()
}

# %%
hotspots_per_location
# Out:
# {'Punta Quepos, Puntarenas Province, Costa Rica': {EBirdHotspot(location=EBirdLocation(id='L10206898', name='Hotel Makanda by the Sea (restricted access)', coord=Coordinate(latitude=9.4029964, longitude=-84.1626817), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=100),
#   EBirdHotspot(location=EBirdLocation(id='L10478874', name='Parque Nahomi', coord=Coordinate(latitude=9.4224968, longitude=-84.1693497), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=133),
#   EBirdHotspot(location=EBirdLocation(id='L11431955', name='Portasol living Birder House', coord=Coordinate(latitude=9.3731784, longitude=-83.9622937), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=247),
#   EBirdHotspot(location=EBirdLocation(id='L1351111', name='Hotel Costa Verde', coord=Coordinate(latitude=9.3986344, longitude=-84.1541689), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=189),
#   EBirdHotspot(location=EBirdLocation(id='L16052695', name='Esquipulas Rainforest Lodge', coord=Coordinate(latitude=9.490671, longitude=-84.0472504), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=351),
#   EBirdHotspot(location=EBirdLocation(id='L17897693', name='Pueblo Nuevo de Parrita', coord=Coordinate(latitude=9.5127043, longitude=-84.3207787), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=109),
#   EBirdHotspot(location=EBirdLocation(id='L18318352', name='Los Altos Resort (restricted access)', coord=Coordinate(latitude=9.405456, longitude=-84.1579342), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=107),
#   EBirdHotspot(location=EBirdLocation(id='L1848099', name='Parador Resort and Spa', coord=Coordinate(latitude=9.397801, longitude=-84.169388), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=222),
#   EBirdHotspot(location=EBirdLocation(id='L1855002', name='Esquipulas (town)', coord=Coordinate(latitude=9.496133, longitude=-84.0478992), country_code='CR', subnat1_code='CR-SJ', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=357),
#   EBirdHotspot(location=EBirdLocation(id='L1878405', name='Portalon', coord=Coordinate(latitude=9.3544768, longitude=-83.9803505), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=211),
#   EBirdHotspot(location=EBirdLocation(id='L1884540', name='Parrita--Pueblo Nuevo shrimp farm', coord=Coordinate(latitude=9.5020462, longitude=-84.3230283), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=167),
#   EBirdHotspot(location=EBirdLocation(id='L2063612', name='La Palapa Ecolodge Resort', coord=Coordinate(latitude=9.3622681, longitude=-83.9759731), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=117),
#   EBirdHotspot(location=EBirdLocation(id='L2102226', name='Arenas del Mar Resort (reserve, hotel grounds and drive way)', coord=Coordinate(latitude=9.3983113, longitude=-84.1629338), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=191),
#   EBirdHotspot(location=EBirdLocation(id='L2103221', name='Rainmaker Conservation Project', coord=Coordinate(latitude=9.5766723, longitude=-84.2160679), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=244),
#   EBirdHotspot(location=EBirdLocation(id='L2132992', name='Quepos--La Foresta Nature Resort', coord=Coordinate(latitude=9.4399876, longitude=-84.1367651), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=227),
#   EBirdHotspot(location=EBirdLocation(id='L2249173', name='PN Manuel Antonio--Mangroves', coord=Coordinate(latitude=9.3881252, longitude=-84.1464731), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=273),
#   EBirdHotspot(location=EBirdLocation(id='L2249175', name='Hotel Plaza Yara', coord=Coordinate(latitude=9.4196357, longitude=-84.1582319), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=63),
#   EBirdHotspot(location=EBirdLocation(id='L2364240', name='Finca Maritima (Playa El Rey) rice fields', coord=Coordinate(latitude=9.3791205, longitude=-84.0604949), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=351),
#   EBirdHotspot(location=EBirdLocation(id='L2480432', name='Manuel Antonio--Road to Parador hotel', coord=Coordinate(latitude=9.4018149, longitude=-84.1604662), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=192),
#   EBirdHotspot(location=EBirdLocation(id='L2577899', name='Si Como No Hotel', coord=Coordinate(latitude=9.4038842, longitude=-84.1554773), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=228),
#   EBirdHotspot(location=EBirdLocation(id='L2706179', name='Laguna en Las vueltas de Parrita', coord=Coordinate(latitude=9.5320246, longitude=-84.26651), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=141),
#   EBirdHotspot(location=EBirdLocation(id='L2795875', name='Rio Parrita, frente a camaronera', coord=Coordinate(latitude=9.502736, longitude=-84.3282223), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=193),
#   EBirdHotspot(location=EBirdLocation(id='L2873762', name='Biesanz beach', coord=Coordinate(latitude=9.401709, longitude=-84.1675043), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=211),
#   EBirdHotspot(location=EBirdLocation(id='L3058980', name='Pueblo Real, Entrada a Isla Damas', coord=Coordinate(latitude=9.4634971, longitude=-84.1939616), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=175),
#   EBirdHotspot(location=EBirdLocation(id='L3094290', name='Quepos--Rice fields North of high school.', coord=Coordinate(latitude=9.4533798, longitude=-84.1723967), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=174),
#   EBirdHotspot(location=EBirdLocation(id='L3300769', name='Barrio Lourdes (town)', coord=Coordinate(latitude=9.4505872, longitude=-84.1271296), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=101),
#   EBirdHotspot(location=EBirdLocation(id='L3308537', name='Buenavista Villas/Tulemar', coord=Coordinate(latitude=9.4078746, longitude=-84.159738), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=241),
#   EBirdHotspot(location=EBirdLocation(id='L3308553', name='Restaurante Finca Mona--Quepos, Puntarenas.', coord=Coordinate(latitude=9.3942891, longitude=-84.0691611), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=128),
#   EBirdHotspot(location=EBirdLocation(id='L3527795', name='Playa Espadilla Norte (Public beach outside the park).', coord=Coordinate(latitude=9.3932575, longitude=-84.1531813), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=228),
#   EBirdHotspot(location=EBirdLocation(id='L3747719', name='El Mono Azul Hotel', coord=Coordinate(latitude=9.4209429, longitude=-84.1594014), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=96),
#   EBirdHotspot(location=EBirdLocation(id='L3748598', name='Rio la Gallega, Naranjito', coord=Coordinate(latitude=9.49845, longitude=-84.11789), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=229),
#   EBirdHotspot(location=EBirdLocation(id='L3789351', name='Paquita, grasslands behind the rodeo corral.', coord=Coordinate(latitude=9.464894, longitude=-84.1803789), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=166),
#   EBirdHotspot(location=EBirdLocation(id='L3871374', name='Rio Parrita--boca del río', coord=Coordinate(latitude=9.4913076, longitude=-84.3326426), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=190),
#   EBirdHotspot(location=EBirdLocation(id='L3881190', name='Manglar Kayak lodge (donde "Maco")', coord=Coordinate(latitude=9.4842811, longitude=-84.2182624), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=205),
#   EBirdHotspot(location=EBirdLocation(id='L3898789', name='Finca Los Alfaro Grasslands--Quepos', coord=Coordinate(latitude=9.4406639, longitude=-84.1601765), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=165),
#   EBirdHotspot(location=EBirdLocation(id='L3928059', name='Playa Isla Damas', coord=Coordinate(latitude=9.4551154, longitude=-84.2176723), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=143),
#   EBirdHotspot(location=EBirdLocation(id='L3938264', name='Santa Juana Lodge', coord=Coordinate(latitude=9.5328788, longitude=-84.0780262), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=280),
#   EBirdHotspot(location=EBirdLocation(id='L3942621', name='Esquipulas--El diamante', coord=Coordinate(latitude=9.517296, longitude=-84.0351105), country_code='CR', subnat1_code='CR-SJ', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=270),
#   EBirdHotspot(location=EBirdLocation(id='L4475440', name='Hotel Gaia--Hotel and reserve.', coord=Coordinate(latitude=9.4173741, longitude=-84.1578805), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=158),
#   EBirdHotspot(location=EBirdLocation(id='L448817', name='Manuel Antonio--hotels near park', coord=Coordinate(latitude=9.3909527, longitude=-84.1471936), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=372),
#   EBirdHotspot(location=EBirdLocation(id='L4702312', name='Villa Nueva de Quepos', coord=Coordinate(latitude=9.4735718, longitude=-84.0628982), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=291),
#   EBirdHotspot(location=EBirdLocation(id='L4829224', name='Quepos--Marina Pez Vela-Pier and surroundings', coord=Coordinate(latitude=9.425074, longitude=-84.1696581), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=171),
#   EBirdHotspot(location=EBirdLocation(id='L4892172', name='Manuel Antonio -- Jungle Creek Villas', coord=Coordinate(latitude=9.4159775, longitude=-84.1546953), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=178),
#   EBirdHotspot(location=EBirdLocation(id='L501063', name='Quepos', coord=Coordinate(latitude=9.4318889, longitude=-84.1655944), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=359),
#   EBirdHotspot(location=EBirdLocation(id='L509908', name='Manglares Damas', coord=Coordinate(latitude=9.4619308, longitude=-84.2156982), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=247),
#   EBirdHotspot(location=EBirdLocation(id='L5218074', name='Playa Matapalo', coord=Coordinate(latitude=9.3209184, longitude=-83.9582431), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=224),
#   EBirdHotspot(location=EBirdLocation(id='L585224', name='Naranjito', coord=Coordinate(latitude=9.471142, longitude=-84.1052771), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=261),
#   EBirdHotspot(location=EBirdLocation(id='L6697932', name='Rafiki Safari Lodge', coord=Coordinate(latitude=9.4466065, longitude=-83.9905), country_code='CR', subnat1_code='CR-SJ', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=312),
#   EBirdHotspot(location=EBirdLocation(id='L724260', name='PN Manuel Antonio', coord=Coordinate(latitude=9.3845275, longitude=-84.1430619), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=439),
#   EBirdHotspot(location=EBirdLocation(id='L7928552', name='Quebrada Arroyo — Road', coord=Coordinate(latitude=9.4737935, longitude=-84.027782), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=264),
#   EBirdHotspot(location=EBirdLocation(id='L8237030', name='Hot Springs Lodge and Community', coord=Coordinate(latitude=9.54822, longitude=-84.128942), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=174)},
#  'Estero Damas, Puntarenas Province, Costa Rica': {EBirdHotspot(location=EBirdLocation(id='L10183671', name='P.N. La Cangreja--Ruta Fila del Aguacate', coord=Coordinate(latitude=9.6421976, longitude=-84.3486156), country_code='CR', subnat1_code='CR-SJ', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=202),
#   EBirdHotspot(location=EBirdLocation(id='L10206898', name='Hotel Makanda by the Sea (restricted access)', coord=Coordinate(latitude=9.4029964, longitude=-84.1626817), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=100),
#   EBirdHotspot(location=EBirdLocation(id='L10478874', name='Parque Nahomi', coord=Coordinate(latitude=9.4224968, longitude=-84.1693497), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=133),
#   EBirdHotspot(location=EBirdLocation(id='L13470886', name='Kuakuari Lodge', coord=Coordinate(latitude=9.6456041, longitude=-84.2475647), country_code='CR', subnat1_code='CR-SJ', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=269),
#   EBirdHotspot(location=EBirdLocation(id='L1351111', name='Hotel Costa Verde', coord=Coordinate(latitude=9.3986344, longitude=-84.1541689), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=189),
#   EBirdHotspot(location=EBirdLocation(id='L16052695', name='Esquipulas Rainforest Lodge', coord=Coordinate(latitude=9.490671, longitude=-84.0472504), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=351),
#   EBirdHotspot(location=EBirdLocation(id='L17897693', name='Pueblo Nuevo de Parrita', coord=Coordinate(latitude=9.5127043, longitude=-84.3207787), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=109),
#   EBirdHotspot(location=EBirdLocation(id='L18318352', name='Los Altos Resort (restricted access)', coord=Coordinate(latitude=9.405456, longitude=-84.1579342), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=107),
#   EBirdHotspot(location=EBirdLocation(id='L1848099', name='Parador Resort and Spa', coord=Coordinate(latitude=9.397801, longitude=-84.169388), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=222),
#   EBirdHotspot(location=EBirdLocation(id='L1855002', name='Esquipulas (town)', coord=Coordinate(latitude=9.496133, longitude=-84.0478992), country_code='CR', subnat1_code='CR-SJ', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=357),
#   EBirdHotspot(location=EBirdLocation(id='L1884540', name='Parrita--Pueblo Nuevo shrimp farm', coord=Coordinate(latitude=9.5020462, longitude=-84.3230283), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=167),
#   EBirdHotspot(location=EBirdLocation(id='L2102226', name='Arenas del Mar Resort (reserve, hotel grounds and drive way)', coord=Coordinate(latitude=9.3983113, longitude=-84.1629338), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=191),
#   EBirdHotspot(location=EBirdLocation(id='L2103221', name='Rainmaker Conservation Project', coord=Coordinate(latitude=9.5766723, longitude=-84.2160679), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=244),
#   EBirdHotspot(location=EBirdLocation(id='L2132992', name='Quepos--La Foresta Nature Resort', coord=Coordinate(latitude=9.4399876, longitude=-84.1367651), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=227),
#   EBirdHotspot(location=EBirdLocation(id='L2249173', name='PN Manuel Antonio--Mangroves', coord=Coordinate(latitude=9.3881252, longitude=-84.1464731), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=273),
#   EBirdHotspot(location=EBirdLocation(id='L2249175', name='Hotel Plaza Yara', coord=Coordinate(latitude=9.4196357, longitude=-84.1582319), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=63),
#   EBirdHotspot(location=EBirdLocation(id='L2364240', name='Finca Maritima (Playa El Rey) rice fields', coord=Coordinate(latitude=9.3791205, longitude=-84.0604949), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=351),
#   EBirdHotspot(location=EBirdLocation(id='L2480432', name='Manuel Antonio--Road to Parador hotel', coord=Coordinate(latitude=9.4018149, longitude=-84.1604662), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=192),
#   EBirdHotspot(location=EBirdLocation(id='L2577899', name='Si Como No Hotel', coord=Coordinate(latitude=9.4038842, longitude=-84.1554773), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=228),
#   EBirdHotspot(location=EBirdLocation(id='L2706179', name='Laguna en Las vueltas de Parrita', coord=Coordinate(latitude=9.5320246, longitude=-84.26651), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=141),
#   EBirdHotspot(location=EBirdLocation(id='L2795875', name='Rio Parrita, frente a camaronera', coord=Coordinate(latitude=9.502736, longitude=-84.3282223), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=193),
#   EBirdHotspot(location=EBirdLocation(id='L2873762', name='Biesanz beach', coord=Coordinate(latitude=9.401709, longitude=-84.1675043), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=211),
#   EBirdHotspot(location=EBirdLocation(id='L3058980', name='Pueblo Real, Entrada a Isla Damas', coord=Coordinate(latitude=9.4634971, longitude=-84.1939616), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=175),
#   EBirdHotspot(location=EBirdLocation(id='L3094290', name='Quepos--Rice fields North of high school.', coord=Coordinate(latitude=9.4533798, longitude=-84.1723967), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=174),
#   EBirdHotspot(location=EBirdLocation(id='L3155643', name='Playa bandera--Rice fields in route to the beach', coord=Coordinate(latitude=9.5077304, longitude=-84.3825531), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=164),
#   EBirdHotspot(location=EBirdLocation(id='L3296556', name='Playa Bejuco', coord=Coordinate(latitude=9.5150951, longitude=-84.4262409), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=178),
#   EBirdHotspot(location=EBirdLocation(id='L3300769', name='Barrio Lourdes (town)', coord=Coordinate(latitude=9.4505872, longitude=-84.1271296), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=101),
#   EBirdHotspot(location=EBirdLocation(id='L3308537', name='Buenavista Villas/Tulemar', coord=Coordinate(latitude=9.4078746, longitude=-84.159738), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=241),
#   EBirdHotspot(location=EBirdLocation(id='L3308553', name='Restaurante Finca Mona--Quepos, Puntarenas.', coord=Coordinate(latitude=9.3942891, longitude=-84.0691611), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=128),
#   EBirdHotspot(location=EBirdLocation(id='L3527795', name='Playa Espadilla Norte (Public beach outside the park).', coord=Coordinate(latitude=9.3932575, longitude=-84.1531813), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=228),
#   EBirdHotspot(location=EBirdLocation(id='L3747719', name='El Mono Azul Hotel', coord=Coordinate(latitude=9.4209429, longitude=-84.1594014), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=96),
#   EBirdHotspot(location=EBirdLocation(id='L3748598', name='Rio la Gallega, Naranjito', coord=Coordinate(latitude=9.49845, longitude=-84.11789), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=229),
#   EBirdHotspot(location=EBirdLocation(id='L3789351', name='Paquita, grasslands behind the rodeo corral.', coord=Coordinate(latitude=9.464894, longitude=-84.1803789), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=166),
#   EBirdHotspot(location=EBirdLocation(id='L3871374', name='Rio Parrita--boca del río', coord=Coordinate(latitude=9.4913076, longitude=-84.3326426), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=190),
#   EBirdHotspot(location=EBirdLocation(id='L3881182', name='Playa Bandera', coord=Coordinate(latitude=9.5043444, longitude=-84.3824673), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=123),
#   EBirdHotspot(location=EBirdLocation(id='L3881190', name='Manglar Kayak lodge (donde "Maco")', coord=Coordinate(latitude=9.4842811, longitude=-84.2182624), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=205),
#   EBirdHotspot(location=EBirdLocation(id='L3898789', name='Finca Los Alfaro Grasslands--Quepos', coord=Coordinate(latitude=9.4406639, longitude=-84.1601765), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=165),
#   EBirdHotspot(location=EBirdLocation(id='L3909190', name='Bejuco--manglar al sur de la costanera', coord=Coordinate(latitude=9.5201984, longitude=-84.4255062), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=156),
#   EBirdHotspot(location=EBirdLocation(id='L3928059', name='Playa Isla Damas', coord=Coordinate(latitude=9.4551154, longitude=-84.2176723), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=143),
#   EBirdHotspot(location=EBirdLocation(id='L3938264', name='Santa Juana Lodge', coord=Coordinate(latitude=9.5328788, longitude=-84.0780262), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=280),
#   EBirdHotspot(location=EBirdLocation(id='L3942621', name='Esquipulas--El diamante', coord=Coordinate(latitude=9.517296, longitude=-84.0351105), country_code='CR', subnat1_code='CR-SJ', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=270),
#   EBirdHotspot(location=EBirdLocation(id='L4475440', name='Hotel Gaia--Hotel and reserve.', coord=Coordinate(latitude=9.4173741, longitude=-84.1578805), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=158),
#   EBirdHotspot(location=EBirdLocation(id='L448817', name='Manuel Antonio--hotels near park', coord=Coordinate(latitude=9.3909527, longitude=-84.1471936), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=372),
#   EBirdHotspot(location=EBirdLocation(id='L4702312', name='Villa Nueva de Quepos', coord=Coordinate(latitude=9.4735718, longitude=-84.0628982), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=291),
#   EBirdHotspot(location=EBirdLocation(id='L4829224', name='Quepos--Marina Pez Vela-Pier and surroundings', coord=Coordinate(latitude=9.425074, longitude=-84.1696581), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=171),
#   EBirdHotspot(location=EBirdLocation(id='L4892172', name='Manuel Antonio -- Jungle Creek Villas', coord=Coordinate(latitude=9.4159775, longitude=-84.1546953), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=178),
#   EBirdHotspot(location=EBirdLocation(id='L501063', name='Quepos', coord=Coordinate(latitude=9.4318889, longitude=-84.1655944), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=359),
#   EBirdHotspot(location=EBirdLocation(id='L509908', name='Manglares Damas', coord=Coordinate(latitude=9.4619308, longitude=-84.2156982), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=247),
#   EBirdHotspot(location=EBirdLocation(id='L585224', name='Naranjito', coord=Coordinate(latitude=9.471142, longitude=-84.1052771), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=261),
#   EBirdHotspot(location=EBirdLocation(id='L724260', name='PN Manuel Antonio', coord=Coordinate(latitude=9.3845275, longitude=-84.1430619), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=439),
#   EBirdHotspot(location=EBirdLocation(id='L7928552', name='Quebrada Arroyo — Road', coord=Coordinate(latitude=9.4737935, longitude=-84.027782), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=264),
#   EBirdHotspot(location=EBirdLocation(id='L8237030', name='Hot Springs Lodge and Community', coord=Coordinate(latitude=9.54822, longitude=-84.128942), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=174)},
#  'Parque Nacional Manuel Antonio, Costa Rica': {EBirdHotspot(location=EBirdLocation(id='L10206898', name='Hotel Makanda by the Sea (restricted access)', coord=Coordinate(latitude=9.4029964, longitude=-84.1626817), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=100),
#   EBirdHotspot(location=EBirdLocation(id='L10478874', name='Parque Nahomi', coord=Coordinate(latitude=9.4224968, longitude=-84.1693497), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=133),
#   EBirdHotspot(location=EBirdLocation(id='L11431955', name='Portasol living Birder House', coord=Coordinate(latitude=9.3731784, longitude=-83.9622937), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=247),
#   EBirdHotspot(location=EBirdLocation(id='L1278192', name='Dominical', coord=Coordinate(latitude=9.2546139, longitude=-83.8624105), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=346),
#   EBirdHotspot(location=EBirdLocation(id='L1351111', name='Hotel Costa Verde', coord=Coordinate(latitude=9.3986344, longitude=-84.1541689), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=189),
#   EBirdHotspot(location=EBirdLocation(id='L18318352', name='Los Altos Resort (restricted access)', coord=Coordinate(latitude=9.405456, longitude=-84.1579342), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=107),
#   EBirdHotspot(location=EBirdLocation(id='L1848099', name='Parador Resort and Spa', coord=Coordinate(latitude=9.397801, longitude=-84.169388), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=222),
#   EBirdHotspot(location=EBirdLocation(id='L1878405', name='Portalon', coord=Coordinate(latitude=9.3544768, longitude=-83.9803505), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=211),
#   EBirdHotspot(location=EBirdLocation(id='L1884540', name='Parrita--Pueblo Nuevo shrimp farm', coord=Coordinate(latitude=9.5020462, longitude=-84.3230283), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=167),
#   EBirdHotspot(location=EBirdLocation(id='L2063612', name='La Palapa Ecolodge Resort', coord=Coordinate(latitude=9.3622681, longitude=-83.9759731), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=117),
#   EBirdHotspot(location=EBirdLocation(id='L2078668', name='Dominical--Villas Rio Mar', coord=Coordinate(latitude=9.2634833, longitude=-83.8602691), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=306),
#   EBirdHotspot(location=EBirdLocation(id='L2102226', name='Arenas del Mar Resort (reserve, hotel grounds and drive way)', coord=Coordinate(latitude=9.3983113, longitude=-84.1629338), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=191),
#   EBirdHotspot(location=EBirdLocation(id='L2132992', name='Quepos--La Foresta Nature Resort', coord=Coordinate(latitude=9.4399876, longitude=-84.1367651), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=227),
#   EBirdHotspot(location=EBirdLocation(id='L2249173', name='PN Manuel Antonio--Mangroves', coord=Coordinate(latitude=9.3881252, longitude=-84.1464731), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=273),
#   EBirdHotspot(location=EBirdLocation(id='L2249175', name='Hotel Plaza Yara', coord=Coordinate(latitude=9.4196357, longitude=-84.1582319), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=63),
#   EBirdHotspot(location=EBirdLocation(id='L2364240', name='Finca Maritima (Playa El Rey) rice fields', coord=Coordinate(latitude=9.3791205, longitude=-84.0604949), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=351),
#   EBirdHotspot(location=EBirdLocation(id='L2480432', name='Manuel Antonio--Road to Parador hotel', coord=Coordinate(latitude=9.4018149, longitude=-84.1604662), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=192),
#   EBirdHotspot(location=EBirdLocation(id='L2577899', name='Si Como No Hotel', coord=Coordinate(latitude=9.4038842, longitude=-84.1554773), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=228),
#   EBirdHotspot(location=EBirdLocation(id='L2873762', name='Biesanz beach', coord=Coordinate(latitude=9.401709, longitude=-84.1675043), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=211),
#   EBirdHotspot(location=EBirdLocation(id='L2884089', name='Pelagic--Route between Quepos to Furuno in the south pacific.', coord=Coordinate(latitude=8.9908876, longitude=-84.0344238), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=25),
#   EBirdHotspot(location=EBirdLocation(id='L3058980', name='Pueblo Real, Entrada a Isla Damas', coord=Coordinate(latitude=9.4634971, longitude=-84.1939616), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=175),
#   EBirdHotspot(location=EBirdLocation(id='L3094290', name='Quepos--Rice fields North of high school.', coord=Coordinate(latitude=9.4533798, longitude=-84.1723967), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=174),
#   EBirdHotspot(location=EBirdLocation(id='L3300769', name='Barrio Lourdes (town)', coord=Coordinate(latitude=9.4505872, longitude=-84.1271296), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=101),
#   EBirdHotspot(location=EBirdLocation(id='L3308537', name='Buenavista Villas/Tulemar', coord=Coordinate(latitude=9.4078746, longitude=-84.159738), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=241),
#   EBirdHotspot(location=EBirdLocation(id='L3308553', name='Restaurante Finca Mona--Quepos, Puntarenas.', coord=Coordinate(latitude=9.3942891, longitude=-84.0691611), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=128),
#   EBirdHotspot(location=EBirdLocation(id='L3527795', name='Playa Espadilla Norte (Public beach outside the park).', coord=Coordinate(latitude=9.3932575, longitude=-84.1531813), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=228),
#   EBirdHotspot(location=EBirdLocation(id='L3747719', name='El Mono Azul Hotel', coord=Coordinate(latitude=9.4209429, longitude=-84.1594014), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=96),
#   EBirdHotspot(location=EBirdLocation(id='L3789351', name='Paquita, grasslands behind the rodeo corral.', coord=Coordinate(latitude=9.464894, longitude=-84.1803789), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=166),
#   EBirdHotspot(location=EBirdLocation(id='L3859054', name='Rio Baru--river mouth', coord=Coordinate(latitude=9.2534702, longitude=-83.8670754), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=251),
#   EBirdHotspot(location=EBirdLocation(id='L3859157', name='Rocas de Amancio (North of Dominicalito beach)', coord=Coordinate(latitude=9.2395398, longitude=-83.8501078), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=152),
#   EBirdHotspot(location=EBirdLocation(id='L3859186', name='La Parcela restaurante and Cabinas', coord=Coordinate(latitude=9.2228237, longitude=-83.8422918), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=127),
#   EBirdHotspot(location=EBirdLocation(id='L3871374', name='Rio Parrita--boca del río', coord=Coordinate(latitude=9.4913076, longitude=-84.3326426), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=190),
#   EBirdHotspot(location=EBirdLocation(id='L3873123', name='Playa linda', coord=Coordinate(latitude=9.3095886, longitude=-83.9425421), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=241),
#   EBirdHotspot(location=EBirdLocation(id='L3881190', name='Manglar Kayak lodge (donde "Maco")', coord=Coordinate(latitude=9.4842811, longitude=-84.2182624), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=205),
#   EBirdHotspot(location=EBirdLocation(id='L3898789', name='Finca Los Alfaro Grasslands--Quepos', coord=Coordinate(latitude=9.4406639, longitude=-84.1601765), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=165),
#   EBirdHotspot(location=EBirdLocation(id='L3926046', name='Playa Linda--Swamp in route to the beach', coord=Coordinate(latitude=9.3143, longitude=-83.9448166), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=250),
#   EBirdHotspot(location=EBirdLocation(id='L3928059', name='Playa Isla Damas', coord=Coordinate(latitude=9.4551154, longitude=-84.2176723), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=143),
#   EBirdHotspot(location=EBirdLocation(id='L4335658', name='Dominicalito Beach', coord=Coordinate(latitude=9.2313169, longitude=-83.8414496), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=158),
#   EBirdHotspot(location=EBirdLocation(id='L441882', name='manglares del Río Hatillo Viejo', coord=Coordinate(latitude=9.2846859, longitude=-83.9039612), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=180),
#   EBirdHotspot(location=EBirdLocation(id='L4475440', name='Hotel Gaia--Hotel and reserve.', coord=Coordinate(latitude=9.4173741, longitude=-84.1578805), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=158),
#   EBirdHotspot(location=EBirdLocation(id='L448817', name='Manuel Antonio--hotels near park', coord=Coordinate(latitude=9.3909527, longitude=-84.1471936), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=372),
#   EBirdHotspot(location=EBirdLocation(id='L448818', name='Hacienda Baru', coord=Coordinate(latitude=9.2715138, longitude=-83.880744), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=436),
#   EBirdHotspot(location=EBirdLocation(id='L4702312', name='Villa Nueva de Quepos', coord=Coordinate(latitude=9.4735718, longitude=-84.0628982), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=291),
#   EBirdHotspot(location=EBirdLocation(id='L4829224', name='Quepos--Marina Pez Vela-Pier and surroundings', coord=Coordinate(latitude=9.425074, longitude=-84.1696581), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=171),
#   EBirdHotspot(location=EBirdLocation(id='L4892172', name='Manuel Antonio -- Jungle Creek Villas', coord=Coordinate(latitude=9.4159775, longitude=-84.1546953), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=178),
#   EBirdHotspot(location=EBirdLocation(id='L501063', name='Quepos', coord=Coordinate(latitude=9.4318889, longitude=-84.1655944), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=359),
#   EBirdHotspot(location=EBirdLocation(id='L509908', name='Manglares Damas', coord=Coordinate(latitude=9.4619308, longitude=-84.2156982), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=247),
#   EBirdHotspot(location=EBirdLocation(id='L5218074', name='Playa Matapalo', coord=Coordinate(latitude=9.3209184, longitude=-83.9582431), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=224),
#   EBirdHotspot(location=EBirdLocation(id='L5626588', name='Seamount Furuno (4-1)', coord=Coordinate(latitude=8.8833213, longitude=-84.1753055), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=19),
#   EBirdHotspot(location=EBirdLocation(id='L585224', name='Naranjito', coord=Coordinate(latitude=9.471142, longitude=-84.1052771), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=261),
#   EBirdHotspot(location=EBirdLocation(id='L724260', name='PN Manuel Antonio', coord=Coordinate(latitude=9.3845275, longitude=-84.1430619), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=439),
#   EBirdHotspot(location=EBirdLocation(id='L832176', name='Dominical--Roca Verde', coord=Coordinate(latitude=9.2454986, longitude=-83.854085), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=165)},
#  'Parque Nacional Carara, Costa Rica': {EBirdHotspot(location=EBirdLocation(id='L10183493', name='P.N. La Cangreja--Ruta Alto Limón', coord=Coordinate(latitude=9.7374944, longitude=-84.348758), country_code='CR', subnat1_code='CR-SJ', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=191),
#   EBirdHotspot(location=EBirdLocation(id='L10183565', name='P.N. La Cangreja--Puesto Santa Rosa', coord=Coordinate(latitude=9.703204, longitude=-84.3979461), country_code='CR', subnat1_code='CR-SJ', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=236),
#   EBirdHotspot(location=EBirdLocation(id='L10183587', name='P.N. La Cangreja--Sendero Plinia (Sector Mastatal)', coord=Coordinate(latitude=9.6873878, longitude=-84.3732223), country_code='CR', subnat1_code='CR-SJ', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=187),
#   EBirdHotspot(location=EBirdLocation(id='L10183621', name='P.N. La Cangreja--Ruta Salitrales', coord=Coordinate(latitude=9.7638317, longitude=-84.3980752), country_code='CR', subnat1_code='CR-SJ', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=184),
#   EBirdHotspot(location=EBirdLocation(id='L10183626', name='P.N. La Cangreja--Ruta San Martín', coord=Coordinate(latitude=9.7387966, longitude=-84.3911658), country_code='CR', subnat1_code='CR-SJ', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=126),
#   EBirdHotspot(location=EBirdLocation(id='L10183639', name='P.N. La Cangreja--Ruta Alto Vara Blanca', coord=Coordinate(latitude=9.7373396, longitude=-84.3722618), country_code='CR', subnat1_code='CR-SJ', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=159),
#   EBirdHotspot(location=EBirdLocation(id='L10183655', name='P.N. La Cangreja--Ruta Yarcazú', coord=Coordinate(latitude=9.7058305, longitude=-84.3733495), country_code='CR', subnat1_code='CR-SJ', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=177),
#   EBirdHotspot(location=EBirdLocation(id='L10183677', name='P.N. La Cangreja--Ruta Santa Rosa-Mastatal', coord=Coordinate(latitude=9.6822656, longitude=-84.3957796), country_code='CR', subnat1_code='CR-SJ', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=246),
#   EBirdHotspot(location=EBirdLocation(id='L10183704', name='P.N. La Cangreja--Ruta Cerro Pelón', coord=Coordinate(latitude=9.7295737, longitude=-84.3929527), country_code='CR', subnat1_code='CR-SJ', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=189),
#   EBirdHotspot(location=EBirdLocation(id='L10183736', name='P.N. La Cangreja--Ruta Sendero Río Negro', coord=Coordinate(latitude=9.6977439, longitude=-84.3808784), country_code='CR', subnat1_code='CR-SJ', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=191),
#   EBirdHotspot(location=EBirdLocation(id='L10191490', name='La Balsa', coord=Coordinate(latitude=9.6398143, longitude=-84.644856), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=176),
#   EBirdHotspot(location=EBirdLocation(id='L11914615', name='Playa Jaco', coord=Coordinate(latitude=9.6209702, longitude=-84.632096), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=186),
#   EBirdHotspot(location=EBirdLocation(id='L1274891', name='Tárcoles--desembocadura', coord=Coordinate(latitude=9.7819332, longitude=-84.6409464), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=333),
#   EBirdHotspot(location=EBirdLocation(id='L12997949', name='Teleferico Road', coord=Coordinate(latitude=9.6459518, longitude=-84.6051752), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=323),
#   EBirdHotspot(location=EBirdLocation(id='L1349030', name='Bahía Herradura', coord=Coordinate(latitude=9.6476457, longitude=-84.6571886), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=211),
#   EBirdHotspot(location=EBirdLocation(id='L14455273', name='San Antonio, Garabito (La Hacienda)', coord=Coordinate(latitude=9.7478697, longitude=-84.5675692), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=202),
#   EBirdHotspot(location=EBirdLocation(id='L1456434', name='Cerro Lodge', coord=Coordinate(latitude=9.808, longitude=-84.611), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=386),
#   EBirdHotspot(location=EBirdLocation(id='L1456772', name='Road from Villa Lapas to Pura Vida Waterfall Gardens', coord=Coordinate(latitude=9.7608646, longitude=-84.5978952), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=362),
#   EBirdHotspot(location=EBirdLocation(id='L1456779', name='Tárcoles--Tour en Bote', coord=Coordinate(latitude=9.7797727, longitude=-84.6263429), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=438),
#   EBirdHotspot(location=EBirdLocation(id='L1456808', name='Guacimo Road', coord=Coordinate(latitude=9.8650149, longitude=-84.6504579), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=319),
#   EBirdHotspot(location=EBirdLocation(id='L1470777', name='Estero Mata de Limón (Caldera)', coord=Coordinate(latitude=9.9206938, longitude=-84.7125485), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=284),
# ...
#   EBirdHotspot(location=EBirdLocation(id='L2310175', name='San Pedro de Poas--Calle Vargas', coord=Coordinate(latitude=10.053628, longitude=-84.2335939), country_code='CR', subnat1_code='CR-A', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=111),
#   EBirdHotspot(location=EBirdLocation(id='L2333406', name='Finca Rosa Blanca', coord=Coordinate(latitude=10.0454281, longitude=-84.1516738), country_code='CR', subnat1_code='CR-H', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=226),
#   EBirdHotspot(location=EBirdLocation(id='L2346197', name='Bosque de la Hoja', coord=Coordinate(latitude=10.0626112, longitude=-84.0957123), country_code='CR', subnat1_code='CR-H', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=174),
#   EBirdHotspot(location=EBirdLocation(id='L2845579', name='Tacacori Eco Lodge', coord=Coordinate(latitude=10.0593959, longitude=-84.208349), country_code='CR', subnat1_code='CR-A', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=120),
#   EBirdHotspot(location=EBirdLocation(id='L2907146', name='Xandari Resort & Spa', coord=Coordinate(latitude=10.0570407, longitude=-84.2116223), country_code='CR', subnat1_code='CR-A', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=250),
#   EBirdHotspot(location=EBirdLocation(id='L2941749', name='San Miguel to Virgen del Socorro road', coord=Coordinate(latitude=10.3011257, longitude=-84.1706747), country_code='CR', subnat1_code='CR-A', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=413),
#   EBirdHotspot(location=EBirdLocation(id='L2946480', name='Hotel Buena Vista', coord=Coordinate(latitude=10.0577163, longitude=-84.1991597), country_code='CR', subnat1_code='CR-A', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=227),
#   EBirdHotspot(location=EBirdLocation(id='L29563278', name='Reserva Mecarina (acceso restringido)', coord=Coordinate(latitude=10.3685882, longitude=-84.3714538), country_code='CR', subnat1_code='CR-A', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=120),
#   EBirdHotspot(location=EBirdLocation(id='L33057120', name='Nacientes Manantial', coord=Coordinate(latitude=10.3469362, longitude=-84.3356589), country_code='CR', subnat1_code='CR-A', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=121),
#   EBirdHotspot(location=EBirdLocation(id='L3315219', name='SarapiquiS Rainforest Lodge', coord=Coordinate(latitude=10.4172798, longitude=-84.1233498), country_code='CR', subnat1_code='CR-H', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=321),
#   EBirdHotspot(location=EBirdLocation(id='L3342922', name='Laguna Hule', coord=Coordinate(latitude=10.2945372, longitude=-84.2088318), country_code='CR', subnat1_code='CR-A', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=373),
#   EBirdHotspot(location=EBirdLocation(id='L3344389', name='Alajuela--Pura Vida Spa & Yoga Retreat', coord=Coordinate(latitude=10.057887, longitude=-84.185727), country_code='CR', subnat1_code='CR-A', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=114),
#   EBirdHotspot(location=EBirdLocation(id='L3547676', name='Volcan Poas--Restaurant El Rio', coord=Coordinate(latitude=10.1621043, longitude=-84.2037488), country_code='CR', subnat1_code='CR-A', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=137),
#   EBirdHotspot(location=EBirdLocation(id='L3550808', name='PN Braulio Carrillo--Volcán Barva', coord=Coordinate(latitude=10.1353215, longitude=-84.1091224), country_code='CR', subnat1_code='CR-H', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=210),
#   EBirdHotspot(location=EBirdLocation(id='L3605626', name='Recreo Verde', coord=Coordinate(latitude=10.32069, longitude=-84.2434), country_code='CR', subnat1_code='CR-A', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=129),
#   EBirdHotspot(location=EBirdLocation(id='L3608284', name='PN Juan Castro Blanco--Bajos del Toro', coord=Coordinate(latitude=10.2356, longitude=-84.305), country_code='CR', subnat1_code='CR-A', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=257),
#   EBirdHotspot(location=EBirdLocation(id='L3636759', name='NP Juan Castro Blanco--Albergue Pozo Verde', coord=Coordinate(latitude=10.2541352, longitude=-84.3730474), country_code='CR', subnat1_code='CR-A', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=203),
#   EBirdHotspot(location=EBirdLocation(id='L3673157', name='Tirimbina--Field Station', coord=Coordinate(latitude=10.3995203, longitude=-84.1019082), country_code='CR', subnat1_code='CR-H', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=330),
#   EBirdHotspot(location=EBirdLocation(id='L37188727', name='Casita Pimenta', coord=Coordinate(latitude=10.3519608, longitude=-84.3365897), country_code='CR', subnat1_code='CR-A', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=170),
#   EBirdHotspot(location=EBirdLocation(id='L37802303', name='Sarchí--Hda. La Eva restaurante, cafe y senderos', coord=Coordinate(latitude=10.0981968, longitude=-84.3470328), country_code='CR', subnat1_code='CR-A', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=160),
#   EBirdHotspot(location=EBirdLocation(id='L3993899', name='Mi Cafecito restaurant and farm', coord=Coordinate(latitude=10.2936212, longitude=-84.185361), country_code='CR', subnat1_code='CR-A', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=288),
#   EBirdHotspot(location=EBirdLocation(id='L4021011', name='Cerro Chompipe', coord=Coordinate(latitude=10.0822765, longitude=-84.0676617), country_code='CR', subnat1_code='CR-H', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=180),
#   EBirdHotspot(location=EBirdLocation(id='L4131068', name='Refugio de Vida Silvestre Cerro Dantas', coord=Coordinate(latitude=10.091079, longitude=-84.060483), country_code='CR', subnat1_code='CR-H', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=171),
#   EBirdHotspot(location=EBirdLocation(id='L436224', name='Galeria de Colibrí y Soda Cinchona - Mirador San Fernando', coord=Coordinate(latitude=10.2221488, longitude=-84.167255), country_code='CR', subnat1_code='CR-A', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=439),
#   EBirdHotspot(location=EBirdLocation(id='L436225', name='Virgen del Socorro', coord=Coordinate(latitude=10.25537, longitude=-84.17019), country_code='CR', subnat1_code='CR-A', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=499),
#   EBirdHotspot(location=EBirdLocation(id='L436231', name='Bajos del Toro', coord=Coordinate(latitude=10.21002, longitude=-84.30387), country_code='CR', subnat1_code='CR-A', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=298),
#   EBirdHotspot(location=EBirdLocation(id='L441317', name='Naranjo--Cerro Espíritu Santo', coord=Coordinate(latitude=10.0856567, longitude=-84.4059849), country_code='CR', subnat1_code='CR-A', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=227),
#   EBirdHotspot(location=EBirdLocation(id='L441883', name='Poás Volcano Lodge', coord=Coordinate(latitude=10.1621135, longitude=-84.1588247), country_code='CR', subnat1_code='CR-H', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=203),
#   EBirdHotspot(location=EBirdLocation(id='L445844', name='La Paz Waterfall Gardens', coord=Coordinate(latitude=10.2038227, longitude=-84.1618352), country_code='CR', subnat1_code='CR-H', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=458),
#   EBirdHotspot(location=EBirdLocation(id='L4466949', name='Parque Recreativo Municipal Los Chorros', coord=Coordinate(latitude=10.0518532, longitude=-84.2774534), country_code='CR', subnat1_code='CR-A', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=150),
#   EBirdHotspot(location=EBirdLocation(id='L4494051', name='Finca Isla Wellness Retreat', coord=Coordinate(latitude=10.3712958, longitude=-84.3213015), country_code='CR', subnat1_code='CR-A', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=113),
#   EBirdHotspot(location=EBirdLocation(id='L470681', name='Albegue del Socorro', coord=Coordinate(latitude=10.2689153, longitude=-84.1615927), country_code='CR', subnat1_code='CR-H', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=391),
#   EBirdHotspot(location=EBirdLocation(id='L470684', name='Tirimbina Rainforest Center', coord=Coordinate(latitude=10.41562, longitude=-84.12078), country_code='CR', subnat1_code='CR-H', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=448),
#   EBirdHotspot(location=EBirdLocation(id='L4889915', name='ASADA La Brisa', coord=Coordinate(latitude=10.2359857, longitude=-84.3669748), country_code='CR', subnat1_code='CR-A', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=106),
#   EBirdHotspot(location=EBirdLocation(id='L507414', name='Bosque de Paz', coord=Coordinate(latitude=10.2057403, longitude=-84.3172317), country_code='CR', subnat1_code='CR-A', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=433),
#   EBirdHotspot(location=EBirdLocation(id='L5090864', name='Poasito--Freddo Fresas', coord=Coordinate(latitude=10.156886, longitude=-84.1959963), country_code='CR', subnat1_code='CR-A', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=163),
#   EBirdHotspot(location=EBirdLocation(id='L5176840', name='Manzanal (Prox. Urbanización), Puente de Piedra', coord=Coordinate(latitude=10.0474057, longitude=-84.3103078), country_code='CR', subnat1_code='CR-A', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=89),
#   EBirdHotspot(location=EBirdLocation(id='L523555', name='Rara Avis', coord=Coordinate(latitude=10.28173, longitude=-84.04489), country_code='CR', subnat1_code='CR-H', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=453),
#   EBirdHotspot(location=EBirdLocation(id='L5420709', name='Zarcero - Bajos del Toro road', coord=Coordinate(latitude=10.2004636, longitude=-84.3334036), country_code='CR', subnat1_code='CR-A', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=118),
#   EBirdHotspot(location=EBirdLocation(id='L5431695', name='El Tucano Lodge', coord=Coordinate(latitude=10.365022, longitude=-84.3815178), country_code='CR', subnat1_code='CR-A', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=222),
#   EBirdHotspot(location=EBirdLocation(id='L5481517', name='Catarata la Paz--Bridge', coord=Coordinate(latitude=10.2069952, longitude=-84.1639906), country_code='CR', subnat1_code='CR-H', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=252),
#   EBirdHotspot(location=EBirdLocation(id='L5496914', name='Hacienda Pozo Azul', coord=Coordinate(latitude=10.3877434, longitude=-84.1394806), country_code='CR', subnat1_code='CR-H', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=270),
#   EBirdHotspot(location=EBirdLocation(id='L5522819', name='Bosque del Niño de Grecia', coord=Coordinate(latitude=10.1424333, longitude=-84.2476702), country_code='CR', subnat1_code='CR-A', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=238),
#   EBirdHotspot(location=EBirdLocation(id='L5796563', name='San Luis de Grecia', coord=Coordinate(latitude=10.1351302, longitude=-84.306829), country_code='CR', subnat1_code='CR-A', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=224),
#   EBirdHotspot(location=EBirdLocation(id='L5921214', name='UCR Recinto de Tacares de Grecia', coord=Coordinate(latitude=10.0418435, longitude=-84.3002495), country_code='CR', subnat1_code='CR-A', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=116),
#   EBirdHotspot(location=EBirdLocation(id='L5928811', name='Monte Tavor', coord=Coordinate(latitude=10.1672853, longitude=-84.2993939), country_code='CR', subnat1_code='CR-A', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=134),
#   EBirdHotspot(location=EBirdLocation(id='L5983488', name='Zona Protectora El Chayote', coord=Coordinate(latitude=10.1833226, longitude=-84.3413766), country_code='CR', subnat1_code='CR-A', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=205),
#   EBirdHotspot(location=EBirdLocation(id='L6047181', name='Monte de la Cruz', coord=Coordinate(latitude=10.0671411, longitude=-84.0760946), country_code='CR', subnat1_code='CR-H', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=191),
#   EBirdHotspot(location=EBirdLocation(id='L6146366', name='Naranjo--Espítitu Santo Coffee Tour (Hda.Coopronaranjo)', coord=Coordinate(latitude=10.0956016, longitude=-84.3839298), country_code='CR', subnat1_code='CR-A', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=183),
#   EBirdHotspot(location=EBirdLocation(id='L6253236', name='PN Braulio Carrillo--El Ceibo', coord=Coordinate(latitude=10.327627, longitude=-84.078238), country_code='CR', subnat1_code='CR-H', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=399),
#   EBirdHotspot(location=EBirdLocation(id='L6599956', name='Castillo Country Club', coord=Coordinate(latitude=10.0590527, longitude=-84.0808594), country_code='CR', subnat1_code='CR-H', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=182),
#   EBirdHotspot(location=EBirdLocation(id='L6677164', name='Jardín Botánico Else Kientzler (Sarchi)', coord=Coordinate(latitude=10.0998452, longitude=-84.3400441), country_code='CR', subnat1_code='CR-A', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=156),
#   EBirdHotspot(location=EBirdLocation(id='L6862958', name='Calle de acceso al Bosque del Niño, Grecia', coord=Coordinate(latitude=10.1321387, longitude=-84.2571826), country_code='CR', subnat1_code='CR-A', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=194),
#   EBirdHotspot(location=EBirdLocation(id='L7524923', name='Hotel Termales Del Bosque', coord=Coordinate(latitude=10.3630906, longitude=-84.3902349), country_code='CR', subnat1_code='CR-A', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=107),
#   EBirdHotspot(location=EBirdLocation(id='L7681233', name='Alajuela Walmart Woods', coord=Coordinate(latitude=10.002051, longitude=-84.204859), country_code='CR', subnat1_code='CR-A', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=205),
#   EBirdHotspot(location=EBirdLocation(id='L7911554', name='Jardines El Rey De Cocora', coord=Coordinate(latitude=10.2093534, longitude=-84.169466), country_code='CR', subnat1_code='CR-A', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=263),
#   EBirdHotspot(location=EBirdLocation(id='L8005145', name='Refugio de Vida Silvestre Cerro Dantas--Camino de entrada', coord=Coordinate(latitude=10.0818432, longitude=-84.0777102), country_code='CR', subnat1_code='CR-H', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=180),
#   EBirdHotspot(location=EBirdLocation(id='L9171225', name='Doka Estate Coffee Tour', coord=Coordinate(latitude=10.097834, longitude=-84.211284), country_code='CR', subnat1_code='CR-A', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=238),
#   EBirdHotspot(location=EBirdLocation(id='L9820408', name='Sendero Rey de Cocora', coord=Coordinate(latitude=10.2048559, longitude=-84.1764441), country_code='CR', subnat1_code='CR-A', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=201)}}

# %%
from geopy.distance import geodesic

# Find the nearest hotspot to each location
nearest_hotspots: dict[str, EBirdHotspot] = {}
for loc, hotspots in hotspots_per_location.items():
    loc_coord = location_coords[loc]
    nearest = min(hotspots, key=lambda hs: geodesic(loc_coord, hs.location.coord).mi)
    nearest_hotspots[loc] = nearest

nearest_hotspots
# Out:
# {'Punta Quepos, Puntarenas Province, Costa Rica': EBirdHotspot(location=EBirdLocation(id='L1848099', name='Parador Resort and Spa', coord=Coordinate(latitude=9.397801, longitude=-84.169388), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=222),
#  'Estero Damas, Puntarenas Province, Costa Rica': EBirdHotspot(location=EBirdLocation(id='L509908', name='Manglares Damas', coord=Coordinate(latitude=9.4619308, longitude=-84.2156982), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=247),
#  'Parque Nacional Manuel Antonio, Costa Rica': EBirdHotspot(location=EBirdLocation(id='L5626588', name='Seamount Furuno (4-1)', coord=Coordinate(latitude=8.8833213, longitude=-84.1753055), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=19),
#  'Parque Nacional Carara, Costa Rica': EBirdHotspot(location=EBirdLocation(id='L447761', name='PN Carara (Localidad General)--historical please use other hotspots', coord=Coordinate(latitude=9.7844453, longitude=-84.5664024), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=429),
#  'Tarcoles River, Puntarenas Province, Costa Rica': EBirdHotspot(location=EBirdLocation(id='L673538', name='Ponds north of Rio Tarcoles Bridge', coord=Coordinate(latitude=9.80838, longitude=-84.60357), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=235),
#  'Monteverde, Puntarenas Province, Costa Rica': EBirdHotspot(location=EBirdLocation(id='L2282443', name='Hotel Fonda Vela', coord=Coordinate(latitude=10.299451, longitude=-84.8061372), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=242),
#  'Reserva Bosque Nuboso Santa Elena, Tronadora, Guanacaste, Costa Rica': EBirdHotspot(location=EBirdLocation(id='L448181', name='Reserva Santa Elena', coord=Coordinate(latitude=10.3410134, longitude=-84.790634), country_code='CR', subnat1_code='CR-G', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=364),
#  'Monteverde Cloud Forest Reserve, Monteverde, Puntarenas Province, Costa Rica': EBirdHotspot(location=EBirdLocation(id='L552342', name='Reserva Biológica Bosque Nuboso Monteverde', coord=Coordinate(latitude=10.3026404, longitude=-84.7956911), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=430),
#  'Reserva Curi Cancha, Monteverde, Costa Rica': EBirdHotspot(location=EBirdLocation(id='L10209276', name='Rachel & Dwight Crandall Reserve - MVI', coord=Coordinate(latitude=10.3064728, longitude=-84.8090911), country_code='CR', subnat1_code='CR-P', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=195),
#  'La Fortuna, Alajuela Province, Costa Rica': EBirdHotspot(location=EBirdLocation(id='L2318975', name='La Fortuna de San Carlos (Arenal)', coord=Coordinate(latitude=10.4716242, longitude=-84.6455158), country_code='CR', subnat1_code='CR-A', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=418),
#  'Parque Nacional Volcán Arenal, Costa Rica': EBirdHotspot(location=EBirdLocation(id='L436229', name='Arenal Observatory Lodge', coord=Coordinate(latitude=10.4369842, longitude=-84.7096768), country_code='CR', subnat1_code='CR-A', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=511),
#  'Arenal Volcano, Alajuela Province, San Carlos, Costa Rica': EBirdHotspot(location=EBirdLocation(id='L436229', name='Arenal Observatory Lodge', coord=Coordinate(latitude=10.4369842, longitude=-84.7096768), country_code='CR', subnat1_code='CR-A', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=511),
#  'Bogarin Trail, Alajuela Province, La Fortuna, Costa Rica': EBirdHotspot(location=EBirdLocation(id='L3220631', name='Sendero Bogarín', coord=Coordinate(latitude=10.470305, longitude=-84.650772), country_code='CR', subnat1_code='CR-A', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=430),
#  'Mistico Park Hanging Bridges, La Fortuna, Alajuela Province, Costa Rica': EBirdHotspot(location=EBirdLocation(id='L1473008', name='Arenal Misticopark (Hanging Bridges)', coord=Coordinate(latitude=10.4893477, longitude=-84.7563453), country_code='CR', subnat1_code='CR-A', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=460),
#  'Parque Nacional Volcán Poás, Costa Rica': EBirdHotspot(location=EBirdLocation(id='L1331161', name='PN Volcán Poás', coord=Coordinate(latitude=10.1837344, longitude=-84.2359457), country_code='CR', subnat1_code='CR-A', subnat1_name=None, subnat2_code=None, subnat2_name=None), all_time_species=233)}

# %%
# For now, only retrieve species lists for the nearest hotspot to each location of interest
from birding.ebird_api import retrieve_species_list

for hotspot in nearest_hotspots.values():
    print(f"\n\nRetrieving bird species list for hotspot '{hotspot.location.name}'...")

    species_list = retrieve_species_list(ebird_api_key, area_code=hotspot.location.id)
    print(f"'{hotspot.location.name}' has {len(species_list)} nearby species.")
# Out:
# Retrieving bird species list for hotspot 'Parador Resort and Spa'...
# Bird species list for 'L1848099' was already cached.
# 'Parador Resort and Spa' has 223 nearby species.
#
#
# Retrieving bird species list for hotspot 'Manglares Damas'...
# Bird species list for 'L509908' was already cached.
# 'Manglares Damas' has 247 nearby species.
#
#
# Retrieving bird species list for hotspot 'Seamount Furuno (4-1)'...
# Bird species list for 'L5626588' was already cached.
# 'Seamount Furuno (4-1)' has 19 nearby species.
#
#
# Retrieving bird species list for hotspot 'PN Carara (Localidad General)--historical please use other hotspots'...
# Bird species list for 'L447761' was already cached.
# 'PN Carara (Localidad General)--historical please use other hotspots' has 430 nearby species.
#
#
# Retrieving bird species list for hotspot 'Ponds north of Rio Tarcoles Bridge'...
# Bird species list for 'L673538' was already cached.
# 'Ponds north of Rio Tarcoles Bridge' has 236 nearby species.
#
#
# Retrieving bird species list for hotspot 'Hotel Fonda Vela'...
# Bird species list for 'L2282443' was already cached.
# 'Hotel Fonda Vela' has 242 nearby species.
#
#
# Retrieving bird species list for hotspot 'Reserva Santa Elena'...
# Bird species list for 'L448181' was already cached.
# 'Reserva Santa Elena' has 364 nearby species.
#
#
# Retrieving bird species list for hotspot 'Reserva Biológica Bosque Nuboso Monteverde'...
# Bird species list for 'L552342' was already cached.
# 'Reserva Biológica Bosque Nuboso Monteverde' has 433 nearby species.
#
#
# Retrieving bird species list for hotspot 'Rachel & Dwight Crandall Reserve - MVI'...
# Bird species list for 'L10209276' was already cached.
# 'Rachel & Dwight Crandall Reserve - MVI' has 195 nearby species.
#
#
# Retrieving bird species list for hotspot 'La Fortuna de San Carlos (Arenal)'...
# Bird species list for 'L2318975' was already cached.
# 'La Fortuna de San Carlos (Arenal)' has 420 nearby species.
#
#
# Retrieving bird species list for hotspot 'Arenal Observatory Lodge'...
# Bird species list for 'L436229' was already cached.
# 'Arenal Observatory Lodge' has 514 nearby species.
#
#
# Retrieving bird species list for hotspot 'Arenal Observatory Lodge'...
# Bird species list for 'L436229' was already cached.
# 'Arenal Observatory Lodge' has 514 nearby species.
#
#
# Retrieving bird species list for hotspot 'Sendero Bogarín'...
# Bird species list for 'L3220631' was already cached.
# 'Sendero Bogarín' has 433 nearby species.
#
#
# Retrieving bird species list for hotspot 'Arenal Misticopark (Hanging Bridges)'...
# Bird species list for 'L1473008' was already cached.
# 'Arenal Misticopark (Hanging Bridges)' has 461 nearby species.
#
#
# Retrieving bird species list for hotspot 'PN Volcán Poás'...
# Bird species list for 'L1331161' was already cached.
# 'PN Volcán Poás' has 233 nearby species.

# %%
# Retrieve species lists for all subnational and national areas represented in the current data

all_species_lists: dict[str, list[str]] = {}
invalid_area_codes = {"CR-P", "CR-A", "CR-G", "CR-H"}

for loc, hotspots in hotspots_per_location.items():
    print(f"Retrieving species lists for subnational regions around '{loc}'...")
    for hotspot in hotspots:
        hs_loc = hotspot.location
        for possible_area_code in {hs_loc.subnat1_code, hs_loc.subnat2_code, hs_loc.country_code}:
            if possible_area_code is None or possible_area_code in invalid_area_codes:
                continue

            new_list = retrieve_species_list(ebird_api_key, possible_area_code)
            all_species_lists[possible_area_code] = new_list

species_union = set()
for species_list in all_species_lists.values():
    species_union.update(species_list)

print(f"Current species lists include {len(species_union)} total distinct species.")
# Out:
# Retrieving species lists for subnational regions around 'Punta Quepos, Puntarenas Province, Costa Rica'...
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR-SJ' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR-SJ' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR-SJ' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Retrieving species lists for subnational regions around 'Estero Damas, Puntarenas Province, Costa Rica'...
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR-SJ' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR-SJ' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR-SJ' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR-SJ' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Retrieving species lists for subnational regions around 'Parque Nacional Manuel Antonio, Costa Rica'...
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Retrieving species lists for subnational regions around 'Parque Nacional Carara, Costa Rica'...
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR-SJ' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR-SJ' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR-SJ' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR-SJ' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR-SJ' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR-SJ' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR-SJ' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR-SJ' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR-SJ' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR-SJ' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR-SJ' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR-SJ' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR-SJ' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR-SJ' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR-SJ' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR-SJ' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR-SJ' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR-SJ' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR-SJ' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR-SJ' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Retrieving species lists for subnational regions around 'Tarcoles River, Puntarenas Province, Costa Rica'...
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR-SJ' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR-SJ' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR-SJ' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR-SJ' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR-SJ' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR-SJ' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR-SJ' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR-SJ' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR-SJ' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR-SJ' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR-SJ' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR-SJ' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR-SJ' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR-SJ' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Retrieving species lists for subnational regions around 'Monteverde, Puntarenas Province, Costa Rica'...
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Retrieving species lists for subnational regions around 'Reserva Bosque Nuboso Santa Elena, Tronadora, Guanacaste, Costa Rica'...
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Retrieving species lists for subnational regions around 'Monteverde Cloud Forest Reserve, Monteverde, Puntarenas Province, Costa Rica'...
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Retrieving species lists for subnational regions around 'Reserva Curi Cancha, Monteverde, Costa Rica'...
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Retrieving species lists for subnational regions around 'La Fortuna, Alajuela Province, Costa Rica'...
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# ...
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Retrieving species lists for subnational regions around 'Mistico Park Hanging Bridges, La Fortuna, Alajuela Province, Costa Rica'...
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Retrieving species lists for subnational regions around 'Parque Nacional Volcán Poás, Costa Rica'...
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Bird species list for 'CR' was already cached.
# Current species lists include 971 total distinct species.

# %%
# Finally, retrieve species lists for all hotspots near our locations of interest
invalid_area_codes = {"CR-P", "CR-A", "CR-G", "CR-H"}

for loc, hotspots in hotspots_per_location.items():
    print(f"Retrieving species lists for hotspots near '{loc}'...")
    for hotspot in hotspots:
        hotspot_species = retrieve_species_list(ebird_api_key, hotspot.location.id)
        all_species_lists[hotspot.location.id] = hotspot_species

species_union = set()
for species_list in all_species_lists.values():
    species_union.update(species_list)

print(f"Current species lists include {len(species_union)} total distinct species.")
# Out:
# Retrieving species lists for hotspots near 'Punta Quepos, Puntarenas Province, Costa Rica'...
# Bird species list for 'L3058980' was already cached.
# Bird species list for 'L3308553' was already cached.
# Bird species list for 'L3527795' was already cached.
# Bird species list for 'L2102226' was already cached.
# Bird species list for 'L3942621' was already cached.
# Bird species list for 'L1848099' was already cached.
# Bird species list for 'L4829224' was already cached.
# Bird species list for 'L7928552' was already cached.
# Bird species list for 'L17897693' was already cached.
# Bird species list for 'L2132992' was already cached.
# Bird species list for 'L5218074' was already cached.
# Bird species list for 'L16052695' was already cached.
# Bird species list for 'L8237030' was already cached.
# Bird species list for 'L3871374' was already cached.
# Bird species list for 'L3881190' was already cached.
# Bird species list for 'L3300769' was already cached.
# Bird species list for 'L2480432' was already cached.
# Bird species list for 'L10478874' was already cached.
# Bird species list for 'L2063612' was already cached.
# Bird species list for 'L3938264' was already cached.
# Bird species list for 'L2103221' was already cached.
# Bird species list for 'L2249173' was already cached.
# Bird species list for 'L1884540' was already cached.
# Bird species list for 'L18318352' was already cached.
# Bird species list for 'L2364240' was already cached.
# Bird species list for 'L3928059' was already cached.
# Bird species list for 'L3308537' was already cached.
# Bird species list for 'L509908' was already cached.
# Bird species list for 'L3094290' was already cached.
# Bird species list for 'L448817' was already cached.
# Bird species list for 'L4475440' was already cached.
# Bird species list for 'L1855002' was already cached.
# Bird species list for 'L10206898' was already cached.
# Bird species list for 'L724260' was already cached.
# Bird species list for 'L1878405' was already cached.
# Bird species list for 'L2873762' was already cached.
# Bird species list for 'L2795875' was already cached.
# Bird species list for 'L3748598' was already cached.
# Bird species list for 'L4892172' was already cached.
# Bird species list for 'L11431955' was already cached.
# Bird species list for 'L2577899' was already cached.
# Bird species list for 'L4702312' was already cached.
# Bird species list for 'L3898789' was already cached.
# Bird species list for 'L2249175' was already cached.
# Bird species list for 'L6697932' was already cached.
# Bird species list for 'L3747719' was already cached.
# Bird species list for 'L3789351' was already cached.
# Bird species list for 'L501063' was already cached.
# Bird species list for 'L1351111' was already cached.
# Bird species list for 'L585224' was already cached.
# Bird species list for 'L2706179' was already cached.
# Retrieving species lists for hotspots near 'Estero Damas, Puntarenas Province, Costa Rica'...
# Bird species list for 'L3058980' was already cached.
# Bird species list for 'L3308553' was already cached.
# Bird species list for 'L3527795' was already cached.
# Bird species list for 'L2102226' was already cached.
# Bird species list for 'L3942621' was already cached.
# Bird species list for 'L10183671' was already cached.
# Bird species list for 'L1848099' was already cached.
# Bird species list for 'L4829224' was already cached.
# Bird species list for 'L7928552' was already cached.
# Bird species list for 'L17897693' was already cached.
# Bird species list for 'L2132992' was already cached.
# Bird species list for 'L16052695' was already cached.
# Bird species list for 'L13470886' was already cached.
# Bird species list for 'L3155643' was already cached.
# Bird species list for 'L8237030' was already cached.
# Bird species list for 'L3871374' was already cached.
# Bird species list for 'L3881190' was already cached.
# Bird species list for 'L3300769' was already cached.
# Bird species list for 'L2480432' was already cached.
# Bird species list for 'L10478874' was already cached.
# Bird species list for 'L3938264' was already cached.
# Bird species list for 'L2103221' was already cached.
# Bird species list for 'L2249173' was already cached.
# Bird species list for 'L1884540' was already cached.
# Bird species list for 'L18318352' was already cached.
# Bird species list for 'L3296556' was already cached.
# Bird species list for 'L2364240' was already cached.
# Bird species list for 'L3928059' was already cached.
# Bird species list for 'L3308537' was already cached.
# Bird species list for 'L509908' was already cached.
# Bird species list for 'L3094290' was already cached.
# Bird species list for 'L448817' was already cached.
# Bird species list for 'L4475440' was already cached.
# Bird species list for 'L1855002' was already cached.
# Bird species list for 'L10206898' was already cached.
# Bird species list for 'L724260' was already cached.
# Bird species list for 'L2873762' was already cached.
# Bird species list for 'L2795875' was already cached.
# Bird species list for 'L3748598' was already cached.
# Bird species list for 'L4892172' was already cached.
# Bird species list for 'L2577899' was already cached.
# Bird species list for 'L4702312' was already cached.
# Bird species list for 'L3909190' was already cached.
# Bird species list for 'L3898789' was already cached.
# Bird species list for 'L2249175' was already cached.
# Bird species list for 'L3881182' was already cached.
# Bird species list for 'L3747719' was already cached.
# Bird species list for 'L3789351' was already cached.
# Bird species list for 'L501063' was already cached.
# Bird species list for 'L1351111' was already cached.
# Bird species list for 'L585224' was already cached.
# Bird species list for 'L2706179' was already cached.
# Retrieving species lists for hotspots near 'Parque Nacional Manuel Antonio, Costa Rica'...
# Bird species list for 'L3058980' was already cached.
# Bird species list for 'L3308553' was already cached.
# Bird species list for 'L3527795' was already cached.
# Bird species list for 'L2102226' was already cached.
# Bird species list for 'L4335658' was already cached.
# Bird species list for 'L1848099' was already cached.
# Bird species list for 'L832176' was already cached.
# Bird species list for 'L4829224' was already cached.
# Bird species list for 'L2132992' was already cached.
# Bird species list for 'L5218074' was already cached.
# Bird species list for 'L3859186' was already cached.
# Bird species list for 'L3871374' was already cached.
# Bird species list for 'L3859157' was already cached.
# Bird species list for 'L3881190' was already cached.
# Bird species list for 'L3300769' was already cached.
# Bird species list for 'L2480432' was already cached.
# Bird species list for 'L10478874' was already cached.
# Bird species list for 'L2063612' was already cached.
# Bird species list for 'L3859054' was already cached.
# Bird species list for 'L5626588' was already cached.
# Bird species list for 'L2249173' was already cached.
# Bird species list for 'L1884540' was already cached.
# Bird species list for 'L18318352' was already cached.
# Bird species list for 'L2364240' was already cached.
# Bird species list for 'L3928059' was already cached.
# Bird species list for 'L3308537' was already cached.
# Bird species list for 'L509908' was already cached.
# Bird species list for 'L3094290' was already cached.
# Bird species list for 'L2078668' was already cached.
# Bird species list for 'L4475440' was already cached.
# Bird species list for 'L448817' was already cached.
# Bird species list for 'L10206898' was already cached.
# Bird species list for 'L724260' was already cached.
# Bird species list for 'L1878405' was already cached.
# Bird species list for 'L2873762' was already cached.
# Bird species list for 'L4892172' was already cached.
# Bird species list for 'L3873123' was already cached.
# Bird species list for 'L11431955' was already cached.
# Bird species list for 'L2884089' was already cached.
# Bird species list for 'L1278192' was already cached.
# Bird species list for 'L2577899' was already cached.
# Bird species list for 'L448818' was already cached.
# Bird species list for 'L3926046' was already cached.
# Bird species list for 'L3898789' was already cached.
# Bird species list for 'L4702312' was already cached.
# Bird species list for 'L441882' was already cached.
# Bird species list for 'L2249175' was already cached.
# Bird species list for 'L3747719' was already cached.
# Bird species list for 'L3789351' was already cached.
# Bird species list for 'L501063' was already cached.
# Bird species list for 'L1351111' was already cached.
# Bird species list for 'L585224' was already cached.
# Retrieving species lists for hotspots near 'Parque Nacional Carara, Costa Rica'...
# Bird species list for 'L3541917' was already cached.
# Bird species list for 'L10183621' was already cached.
# Bird species list for 'L1574928' was already cached.
# Bird species list for 'L1274891' was already cached.
# Bird species list for 'L441813' was already cached.
# Bird species list for 'L3322176' was already cached.
# Bird species list for 'L4071755' was already cached.
# Bird species list for 'L447761' was already cached.
# Bird species list for 'L4425113' was already cached.
# Bird species list for 'L2743083' was already cached.
# Bird species list for 'L16383495' was already cached.
# Bird species list for 'L10183736' was already cached.
# Bird species list for 'L3354750' was already cached.
# Bird species list for 'L4302411' was already cached.
# Bird species list for 'L7733560' was already cached.
# Bird species list for 'L3401011' was already cached.
# Bird species list for 'L20904129' was already cached.
# Bird species list for 'L2146450' was already cached.
# Bird species list for 'L3592763' was already cached.
# Bird species list for 'L20096545' was already cached.
# Bird species list for 'L3400822' was already cached.
# Bird species list for 'L9938998' was already cached.
# Bird species list for 'L10183565' was already cached.
# Bird species list for 'L10183626' was already cached.
# Bird species list for 'L442257' was already cached.
# Bird species list for 'L28741295' was already cached.
# Bird species list for 'L1349030' was already cached.
# Bird species list for 'L17372373' was already cached.
# Bird species list for 'L1456772' was already cached.
# Bird species list for 'L15861828' was already cached.
# Bird species list for 'L442983' was already cached.
# Bird species list for 'L6966542' was already cached.
# Bird species list for 'L4912736' was already cached.
# Bird species list for 'L3970792' was already cached.
# Bird species list for 'L4506189' was already cached.
# Bird species list for 'L10183639' was already cached.
# Bird species list for 'L3650798' was already cached.
# Bird species list for 'L4754863' was already cached.
# Bird species list for 'L1859717' was already cached.
# Bird species list for 'L2600528' was already cached.
# Bird species list for 'L12997949' was already cached.
# Bird species list for 'L3536583' was already cached.
# Bird species list for 'L17463582' was already cached.
# Bird species list for 'L325916' was already cached.
# Bird species list for 'L10183587' was already cached.
# Bird species list for 'L2319271' was already cached.
# Bird species list for 'L6994019' was already cached.
# Bird species list for 'L673538' was already cached.
# Bird species list for 'L1631258' was already cached.
# Bird species list for 'L25668211' was already cached.
# Bird species list for 'L1889041' was already cached.
# Bird species list for 'L10183493' was already cached.
# Bird species list for 'L10183704' was already cached.
# Bird species list for 'L11914615' was already cached.
# Bird species list for 'L585101' was already cached.
# Bird species list for 'L2681879' was already cached.
# Bird species list for 'L2574391' was already cached.
# Bird species list for 'L5377452' was already cached.
# Bird species list for 'L21793817' was already cached.
# Bird species list for 'L10191490' was already cached.
# Bird species list for 'L441919' was already cached.
# Bird species list for 'L1456434' was already cached.
# Bird species list for 'L1471150' was already cached.
# Bird species list for 'L1456808' was already cached.
# Bird species list for 'L10183677' was already cached.
# Bird species list for 'L4196504' was already cached.
# Bird species list for 'L1456779' was already cached.
# Bird species list for 'L3249909' was already cached.
# Bird species list for 'L28268896' was already cached.
# Bird species list for 'L4333101' was already cached.
# Bird species list for 'L14455273' was already cached.
# Bird species list for 'L10183655' was already cached.
# Bird species list for 'L1470777' was already cached.
# Bird species list for 'L2015279' was already cached.
# Bird species list for 'L3750237' was already cached.
# Bird species list for 'L7257481' was already cached.
# Retrieving species lists for hotspots near 'Tarcoles River, Puntarenas Province, Costa Rica'...
# Bird species list for 'L3541917' was already cached.
# Bird species list for 'L10183621' was already cached.
# Bird species list for 'L1574928' was already cached.
# Bird species list for 'L1274891' was already cached.
# Bird species list for 'L3322176' was already cached.
# Bird species list for 'L4071755' was already cached.
# Bird species list for 'L447761' was already cached.
# Bird species list for 'L4425113' was already cached.
# Bird species list for 'L2743083' was already cached.
# Bird species list for 'L16383495' was already cached.
# Bird species list for 'L3354750' was already cached.
# Bird species list for 'L7733560' was already cached.
# Bird species list for 'L4302411' was already cached.
# Bird species list for 'L3401011' was already cached.
# Bird species list for 'L20904129' was already cached.
# Bird species list for 'L2146450' was already cached.
# Bird species list for 'L3592763' was already cached.
# Bird species list for 'L20096545' was already cached.
# Bird species list for 'L3400822' was already cached.
# Bird species list for 'L9938998' was already cached.
# Bird species list for 'L10183565' was already cached.
# Bird species list for 'L10183626' was already cached.
# Bird species list for 'L442257' was already cached.
# Bird species list for 'L28741295' was already cached.
# Bird species list for 'L1349030' was already cached.
# Bird species list for 'L17372373' was already cached.
# Bird species list for 'L1456772' was already cached.
# Bird species list for 'L15861828' was already cached.
# Bird species list for 'L442983' was already cached.
# Bird species list for 'L6966542' was already cached.
# Bird species list for 'L4912736' was already cached.
# Bird species list for 'L3970792' was already cached.
# Bird species list for 'L4506189' was already cached.
# Bird species list for 'L3650798' was already cached.
# Bird species list for 'L4754863' was already cached.
# Bird species list for 'L1859717' was already cached.
# Bird species list for 'L2600528' was already cached.
# Bird species list for 'L12997949' was already cached.
# Bird species list for 'L3536583' was already cached.
# Bird species list for 'L17463582' was already cached.
# Bird species list for 'L325916' was already cached.
# Bird species list for 'L2319271' was already cached.
# Bird species list for 'L6994019' was already cached.
# Bird species list for 'L673538' was already cached.
# Bird species list for 'L1631258' was already cached.
# Bird species list for 'L25668211' was already cached.
# Bird species list for 'L11914615' was already cached.
# Bird species list for 'L10183704' was already cached.
# Bird species list for 'L585101' was already cached.
# Bird species list for 'L2681879' was already cached.
# Bird species list for 'L2574391' was already cached.
# Bird species list for 'L5377452' was already cached.
# Bird species list for 'L21793817' was already cached.
# Bird species list for 'L10191490' was already cached.
# Bird species list for 'L441919' was already cached.
# Bird species list for 'L1456434' was already cached.
# Bird species list for 'L1471150' was already cached.
# Bird species list for 'L1456808' was already cached.
# Bird species list for 'L4196504' was already cached.
# Bird species list for 'L1456779' was already cached.
# Bird species list for 'L3249909' was already cached.
# Bird species list for 'L28268896' was already cached.
# Bird species list for 'L4333101' was already cached.
# Bird species list for 'L14455273' was already cached.
# Bird species list for 'L1470777' was already cached.
# Bird species list for 'L2015279' was already cached.
# Bird species list for 'L3750237' was already cached.
# Bird species list for 'L7257481' was already cached.
# Retrieving species lists for hotspots near 'Monteverde, Puntarenas Province, Costa Rica'...
# Bird species list for 'L5123122' was already cached.
# Bird species list for 'L2605069' was already cached.
# Bird species list for 'L40449788' was already cached.
# Bird species list for 'L444570' was already cached.
# Bird species list for 'L2160384' was already cached.
# Bird species list for 'L5040956' was already cached.
# Bird species list for 'L16815215' was already cached.
# Bird species list for 'L1473008' was already cached.
# Bird species list for 'L2168448' was already cached.
# Bird species list for 'L2282598' was already cached.
# Bird species list for 'L3882042' was already cached.
# Bird species list for 'L436934' was already cached.
# Bird species list for 'L436930' was already cached.
# Bird species list for 'L863744' was already cached.
# Bird species list for 'L20236231' was already cached.
# Bird species list for 'L2171649' was already cached.
# Bird species list for 'L19107557' was already cached.
# Bird species list for 'L8323031' was already cached.
# Bird species list for 'L30538853' was already cached.
# Bird species list for 'L3176557' was already cached.
# Bird species list for 'L2171690' was already cached.
# Bird species list for 'L4498358' was already cached.
# Bird species list for 'L19271816' was already cached.
# Bird species list for 'L3331609' was already cached.
# Bird species list for 'L21249706' was already cached.
# Bird species list for 'L1899374' was already cached.
# Bird species list for 'L3236802' was already cached.
# Bird species list for 'L3250876' was already cached.
# Bird species list for 'L11818690' was already cached.
# Bird species list for 'L16750601' was already cached.
# Bird species list for 'L2020689' was already cached.
# Bird species list for 'L1001271' was already cached.
# Bird species list for 'L2276546' was already cached.
# Bird species list for 'L3579241' was already cached.
# Bird species list for 'L2247414' was already cached.
# Bird species list for 'L6622361' was already cached.
# Bird species list for 'L2268945' was already cached.
# Bird species list for 'L3747671' was already cached.
# Bird species list for 'L5048593' was already cached.
# Bird species list for 'L4809061' was already cached.
# Bird species list for 'L23319788' was already cached.
# Bird species list for 'L442612' was already cached.
# Bird species list for 'L7357378' was already cached.
# Bird species list for 'L4875736' was already cached.
# Bird species list for 'L311635' was already cached.
# Bird species list for 'L1850443' was already cached.
# Bird species list for 'L19267010' was already cached.
# Bird species list for 'L13776866' was already cached.
# Bird species list for 'L4635018' was already cached.
# Bird species list for 'L3619743' was already cached.
# Bird species list for 'L3621869' was already cached.
# Bird species list for 'L2031393' was already cached.
# Bird species list for 'L3306687' was already cached.
# Bird species list for 'L3349244' was already cached.
# Bird species list for 'L3346941' was already cached.
# Bird species list for 'L15787183' was already cached.
# Bird species list for 'L2249172' was already cached.
# Bird species list for 'L3842895' was already cached.
# Bird species list for 'L5578048' was already cached.
# Bird species list for 'L2168470' was already cached.
# Bird species list for 'L2902646' was already cached.
# Bird species list for 'L448181' was already cached.
# Bird species list for 'L2301474' was already cached.
# Bird species list for 'L744883' was already cached.
# Bird species list for 'L4592606' was already cached.
# Bird species list for 'L7515754' was already cached.
# Bird species list for 'L3502981' was already cached.
# Bird species list for 'L3517060' was already cached.
# Bird species list for 'L3766029' was already cached.
# Bird species list for 'L3792239' was already cached.
# Bird species list for 'L6700199' was already cached.
# Bird species list for 'L12343825' was already cached.
# Bird species list for 'L3580137' was already cached.
# Bird species list for 'L3747667' was already cached.
# Bird species list for 'L6347553' was already cached.
# Bird species list for 'L2086756' was already cached.
# Bird species list for 'L16552515' was already cached.
# Bird species list for 'L31620157' was already cached.
# Bird species list for 'L3352552' was already cached.
# Bird species list for 'L2168278' was already cached.
# Bird species list for 'L8500758' was already cached.
# Bird species list for 'L53612666' was already cached.
# Bird species list for 'L18578123' was already cached.
# Bird species list for 'L4626151' was already cached.
# Bird species list for 'L673542' was already cached.
# Bird species list for 'L1450737' was already cached.
# Bird species list for 'L1176862' was already cached.
# Bird species list for 'L325849' was already cached.
# Bird species list for 'L2318995' was already cached.
# Bird species list for 'L970067' was already cached.
# Bird species list for 'L2282443' was already cached.
# Bird species list for 'L436932' was already cached.
# Bird species list for 'L1144714' was already cached.
# Bird species list for 'L5419113' was already cached.
# Bird species list for 'L2359363' was already cached.
# Bird species list for 'L3873986' was already cached.
# Bird species list for 'L3307723' was already cached.
# Bird species list for 'L2374510' was already cached.
# Bird species list for 'L7732043' was already cached.
# Bird species list for 'L8712803' was already cached.
# Bird species list for 'L3356812' was already cached.
# Bird species list for 'L11878908' was already cached.
# Bird species list for 'L1144728' was already cached.
# Bird species list for 'L4988370' was already cached.
# Bird species list for 'L16612083' was already cached.
# Bird species list for 'L5259737' was already cached.
# Bird species list for 'L3108671' was already cached.
# Bird species list for 'L10543469' was already cached.
# Bird species list for 'L12527580' was already cached.
# Bird species list for 'L1156977' was already cached.
# Bird species list for 'L7515596' was already cached.
# Bird species list for 'L2098884' was already cached.
# Bird species list for 'L1026105' was already cached.
# Bird species list for 'L2319117' was already cached.
# Bird species list for 'L3850505' was already cached.
# Bird species list for 'L3338752' was already cached.
# Bird species list for 'L5226203' was already cached.
# Bird species list for 'L10209276' was already cached.
# Bird species list for 'L436229' was already cached.
# Bird species list for 'L552342' was already cached.
# Bird species list for 'L2168373' was already cached.
# Bird species list for 'L1468729' was already cached.
# Bird species list for 'L11586672' was already cached.
# Bird species list for 'L5852373' was already cached.
# Retrieving species lists for hotspots near 'Reserva Bosque Nuboso Santa Elena, Tronadora, Guanacaste, Costa Rica'...
# Bird species list for 'L5123122' was already cached.
# Bird species list for 'L3586675' was already cached.
# Bird species list for 'L2605069' was already cached.
# Bird species list for 'L40449788' was already cached.
# Bird species list for 'L444570' was already cached.
# Bird species list for 'L2160384' was already cached.
# Bird species list for 'L2318975' was already cached.
# Bird species list for 'L5040956' was already cached.
# Bird species list for 'L16815215' was already cached.
# Bird species list for 'L1894059' was already cached.
# Bird species list for 'L14675576' was already cached.
# Bird species list for 'L1473008' was already cached.
# Bird species list for 'L2168448' was already cached.
# Bird species list for 'L2282598' was already cached.
# Bird species list for 'L849155' was already cached.
# Bird species list for 'L3220631' was already cached.
# Bird species list for 'L3882042' was already cached.
# Bird species list for 'L2474991' was already cached.
# Bird species list for 'L436934' was already cached.
# Bird species list for 'L436930' was already cached.
# Bird species list for 'L863744' was already cached.
# Bird species list for 'L1886823' was already cached.
# Bird species list for 'L20236231' was already cached.
# Bird species list for 'L2171649' was already cached.
# Bird species list for 'L19107557' was already cached.
# Bird species list for 'L8323031' was already cached.
# Bird species list for 'L30538853' was already cached.
# Bird species list for 'L3176557' was already cached.
# Bird species list for 'L2171690' was already cached.
# Bird species list for 'L4498358' was already cached.
# Bird species list for 'L19271816' was already cached.
# Bird species list for 'L3331609' was already cached.
# Bird species list for 'L21249706' was already cached.
# Bird species list for 'L1899374' was already cached.
# Bird species list for 'L21927711' was already cached.
# Bird species list for 'L3236802' was already cached.
# Bird species list for 'L3250876' was already cached.
# Bird species list for 'L11818690' was already cached.
# Bird species list for 'L9934804' was already cached.
# Bird species list for 'L16750601' was already cached.
# Bird species list for 'L2020689' was already cached.
# Bird species list for 'L1001271' was already cached.
# Bird species list for 'L2276546' was already cached.
# Bird species list for 'L3579241' was already cached.
# Bird species list for 'L2247414' was already cached.
# Bird species list for 'L6996453' was already cached.
# Bird species list for 'L6448525' was already cached.
# Bird species list for 'L6622361' was already cached.
# Bird species list for 'L2268945' was already cached.
# Bird species list for 'L3747671' was already cached.
# Bird species list for 'L5048593' was already cached.
# Bird species list for 'L1873352' was already cached.
# Bird species list for 'L4809061' was already cached.
# Bird species list for 'L23319788' was already cached.
# Bird species list for 'L3025465' was already cached.
# Bird species list for 'L442612' was already cached.
# Bird species list for 'L7357378' was already cached.
# Bird species list for 'L4875736' was already cached.
# Bird species list for 'L311635' was already cached.
# Bird species list for 'L1850443' was already cached.
# Bird species list for 'L19267010' was already cached.
# Bird species list for 'L13776866' was already cached.
# Bird species list for 'L4635018' was already cached.
# Bird species list for 'L3619743' was already cached.
# Bird species list for 'L3621869' was already cached.
# Bird species list for 'L2902607' was already cached.
# Bird species list for 'L3306687' was already cached.
# Bird species list for 'L3349244' was already cached.
# Bird species list for 'L1508152' was already cached.
# Bird species list for 'L3295653' was already cached.
# Bird species list for 'L5889205' was already cached.
# Bird species list for 'L3346941' was already cached.
# Bird species list for 'L15787183' was already cached.
# Bird species list for 'L2249172' was already cached.
# Bird species list for 'L3842895' was already cached.
# Bird species list for 'L3503121' was already cached.
# Bird species list for 'L5578048' was already cached.
# Bird species list for 'L2168470' was already cached.
# Bird species list for 'L2902646' was already cached.
# Bird species list for 'L448181' was already cached.
# Bird species list for 'L2318958' was already cached.
# Bird species list for 'L2301474' was already cached.
# Bird species list for 'L2898920' was already cached.
# Bird species list for 'L744883' was already cached.
# Bird species list for 'L4592606' was already cached.
# Bird species list for 'L7515754' was already cached.
# Bird species list for 'L3502981' was already cached.
# Bird species list for 'L3517060' was already cached.
# Bird species list for 'L3766029' was already cached.
# Bird species list for 'L3792239' was already cached.
# Bird species list for 'L6700199' was already cached.
# Bird species list for 'L12343825' was already cached.
# Bird species list for 'L3580137' was already cached.
# Bird species list for 'L3747667' was already cached.
# Bird species list for 'L6347553' was already cached.
# Bird species list for 'L2086756' was already cached.
# Bird species list for 'L16552515' was already cached.
# Bird species list for 'L31620157' was already cached.
# Bird species list for 'L2155838' was already cached.
# Bird species list for 'L3352552' was already cached.
# Bird species list for 'L2168278' was already cached.
# Bird species list for 'L8500758' was already cached.
# Bird species list for 'L53612666' was already cached.
# Bird species list for 'L18578123' was already cached.
# Bird species list for 'L4626151' was already cached.
# Bird species list for 'L673542' was already cached.
# Bird species list for 'L1450737' was already cached.
# Bird species list for 'L2704815' was already cached.
# Bird species list for 'L1176862' was already cached.
# Bird species list for 'L325849' was already cached.
# Bird species list for 'L2318995' was already cached.
# Bird species list for 'L970067' was already cached.
# Bird species list for 'L26961604' was already cached.
# Bird species list for 'L2282443' was already cached.
# Bird species list for 'L436932' was already cached.
# Bird species list for 'L1144714' was already cached.
# Bird species list for 'L3539812' was already cached.
# Bird species list for 'L1808679' was already cached.
# Bird species list for 'L2397652' was already cached.
# Bird species list for 'L5419113' was already cached.
# Bird species list for 'L2359363' was already cached.
# Bird species list for 'L3873986' was already cached.
# Bird species list for 'L3307723' was already cached.
# Bird species list for 'L4530908' was already cached.
# Bird species list for 'L7732043' was already cached.
# Bird species list for 'L8712803' was already cached.
# Bird species list for 'L3356812' was already cached.
# Bird species list for 'L11878908' was already cached.
# Bird species list for 'L1144728' was already cached.
# Bird species list for 'L4988370' was already cached.
# Bird species list for 'L3647607' was already cached.
# Bird species list for 'L16612083' was already cached.
# Bird species list for 'L5259737' was already cached.
# Bird species list for 'L3108671' was already cached.
# Bird species list for 'L3744063' was already cached.
# Bird species list for 'L10543469' was already cached.
# Bird species list for 'L12527580' was already cached.
# Bird species list for 'L1156977' was already cached.
# Bird species list for 'L7515596' was already cached.
# Bird species list for 'L2098884' was already cached.
# Bird species list for 'L1026105' was already cached.
# Bird species list for 'L2319117' was already cached.
# Bird species list for 'L5204878' was already cached.
# Bird species list for 'L3850505' was already cached.
# Bird species list for 'L10581473' was already cached.
# Bird species list for 'L3338752' was already cached.
# Bird species list for 'L5226203' was already cached.
# Bird species list for 'L10209276' was already cached.
# Bird species list for 'L436229' was already cached.
# Bird species list for 'L7245583' was already cached.
# Bird species list for 'L552342' was already cached.
# Bird species list for 'L2168373' was already cached.
# Bird species list for 'L1468729' was already cached.
# Bird species list for 'L11586672' was already cached.
# Bird species list for 'L5852373' was already cached.
# Retrieving species lists for hotspots near 'Monteverde Cloud Forest Reserve, Monteverde, Puntarenas Province, Costa Rica'...
# Bird species list for 'L5123122' was already cached.
# Bird species list for 'L2605069' was already cached.
# Bird species list for 'L40449788' was already cached.
# Bird species list for 'L444570' was already cached.
# Bird species list for 'L2160384' was already cached.
# Bird species list for 'L2318975' was already cached.
# Bird species list for 'L5040956' was already cached.
# Bird species list for 'L16815215' was already cached.
# Bird species list for 'L1473008' was already cached.
# Bird species list for 'L2168448' was already cached.
# Bird species list for 'L2282598' was already cached.
# Bird species list for 'L849155' was already cached.
# Bird species list for 'L3220631' was already cached.
# Bird species list for 'L3882042' was already cached.
# Bird species list for 'L2474991' was already cached.
# Bird species list for 'L436934' was already cached.
# Bird species list for 'L436930' was already cached.
# Bird species list for 'L863744' was already cached.
# Bird species list for 'L1886823' was already cached.
# Bird species list for 'L20236231' was already cached.
# Bird species list for 'L2171649' was already cached.
# Bird species list for 'L19107557' was already cached.
# Bird species list for 'L8323031' was already cached.
# Bird species list for 'L30538853' was already cached.
# Bird species list for 'L3176557' was already cached.
# Bird species list for 'L2171690' was already cached.
# Bird species list for 'L4498358' was already cached.
# Bird species list for 'L19271816' was already cached.
# Bird species list for 'L3331609' was already cached.
# Bird species list for 'L21249706' was already cached.
# Bird species list for 'L1899374' was already cached.
# Bird species list for 'L21927711' was already cached.
# Bird species list for 'L3236802' was already cached.
# Bird species list for 'L3250876' was already cached.
# Bird species list for 'L11818690' was already cached.
# Bird species list for 'L9934804' was already cached.
# Bird species list for 'L16750601' was already cached.
# Bird species list for 'L2020689' was already cached.
# Bird species list for 'L1001271' was already cached.
# Bird species list for 'L2276546' was already cached.
# Bird species list for 'L3579241' was already cached.
# Bird species list for 'L2247414' was already cached.
# Bird species list for 'L6996453' was already cached.
# Bird species list for 'L6448525' was already cached.
# Bird species list for 'L6622361' was already cached.
# Bird species list for 'L2268945' was already cached.
# Bird species list for 'L3747671' was already cached.
# Bird species list for 'L5048593' was already cached.
# Bird species list for 'L1873352' was already cached.
# Bird species list for 'L4809061' was already cached.
# Bird species list for 'L23319788' was already cached.
# Bird species list for 'L3025465' was already cached.
# Bird species list for 'L442612' was already cached.
# Bird species list for 'L7357378' was already cached.
# Bird species list for 'L4875736' was already cached.
# Bird species list for 'L311635' was already cached.
# Bird species list for 'L1850443' was already cached.
# Bird species list for 'L19267010' was already cached.
# Bird species list for 'L13776866' was already cached.
# Bird species list for 'L4635018' was already cached.
# Bird species list for 'L3619743' was already cached.
# Bird species list for 'L3621869' was already cached.
# Bird species list for 'L3306687' was already cached.
# Bird species list for 'L3349244' was already cached.
# Bird species list for 'L3295653' was already cached.
# Bird species list for 'L5889205' was already cached.
# Bird species list for 'L3346941' was already cached.
# Bird species list for 'L15787183' was already cached.
# Bird species list for 'L2249172' was already cached.
# Bird species list for 'L3842895' was already cached.
# Bird species list for 'L3503121' was already cached.
# Bird species list for 'L5578048' was already cached.
# Bird species list for 'L2168470' was already cached.
# Bird species list for 'L2902646' was already cached.
# Bird species list for 'L448181' was already cached.
# Bird species list for 'L2301474' was already cached.
# Bird species list for 'L2898920' was already cached.
# Bird species list for 'L744883' was already cached.
# Bird species list for 'L4592606' was already cached.
# Bird species list for 'L7515754' was already cached.
# Bird species list for 'L3502981' was already cached.
# Bird species list for 'L3517060' was already cached.
# Bird species list for 'L3766029' was already cached.
# Bird species list for 'L3792239' was already cached.
# Bird species list for 'L6700199' was already cached.
# Bird species list for 'L12343825' was already cached.
# Bird species list for 'L3580137' was already cached.
# Bird species list for 'L3747667' was already cached.
# Bird species list for 'L6347553' was already cached.
# Bird species list for 'L2086756' was already cached.
# Bird species list for 'L16552515' was already cached.
# Bird species list for 'L31620157' was already cached.
# Bird species list for 'L3352552' was already cached.
# Bird species list for 'L2168278' was already cached.
# Bird species list for 'L8500758' was already cached.
# Bird species list for 'L53612666' was already cached.
# Bird species list for 'L18578123' was already cached.
# Bird species list for 'L4626151' was already cached.
# Bird species list for 'L673542' was already cached.
# Bird species list for 'L1450737' was already cached.
# Bird species list for 'L1176862' was already cached.
# Bird species list for 'L325849' was already cached.
# Bird species list for 'L2318995' was already cached.
# Bird species list for 'L970067' was already cached.
# Bird species list for 'L2282443' was already cached.
# Bird species list for 'L436932' was already cached.
# Bird species list for 'L1144714' was already cached.
# Bird species list for 'L2397652' was already cached.
# Bird species list for 'L5419113' was already cached.
# Bird species list for 'L2359363' was already cached.
# Bird species list for 'L3873986' was already cached.
# Bird species list for 'L3307723' was already cached.
# Bird species list for 'L2374510' was already cached.
# Bird species list for 'L7732043' was already cached.
# Bird species list for 'L8712803' was already cached.
# Bird species list for 'L3356812' was already cached.
# Bird species list for 'L11878908' was already cached.
# Bird species list for 'L1144728' was already cached.
# Bird species list for 'L4988370' was already cached.
# Bird species list for 'L3647607' was already cached.
# Bird species list for 'L16612083' was already cached.
# Bird species list for 'L5259737' was already cached.
# Bird species list for 'L3108671' was already cached.
# Bird species list for 'L3744063' was already cached.
# Bird species list for 'L10543469' was already cached.
# Bird species list for 'L12527580' was already cached.
# Bird species list for 'L1156977' was already cached.
# Bird species list for 'L7515596' was already cached.
# Bird species list for 'L2098884' was already cached.
# Bird species list for 'L1026105' was already cached.
# Bird species list for 'L2319117' was already cached.
# Bird species list for 'L5204878' was already cached.
# Bird species list for 'L3850505' was already cached.
# Bird species list for 'L10581473' was already cached.
# Bird species list for 'L3338752' was already cached.
# Bird species list for 'L5226203' was already cached.
# Bird species list for 'L10209276' was already cached.
# Bird species list for 'L436229' was already cached.
# Bird species list for 'L7245583' was already cached.
# Bird species list for 'L552342' was already cached.
# Bird species list for 'L2168373' was already cached.
# Bird species list for 'L1468729' was already cached.
# Bird species list for 'L11586672' was already cached.
# Bird species list for 'L5852373' was already cached.
# Retrieving species lists for hotspots near 'Reserva Curi Cancha, Monteverde, Costa Rica'...
# Bird species list for 'L5123122' was already cached.
# Bird species list for 'L2605069' was already cached.
# Bird species list for 'L40449788' was already cached.
# Bird species list for 'L444570' was already cached.
# Bird species list for 'L2160384' was already cached.
# Bird species list for 'L5040956' was already cached.
# Bird species list for 'L16815215' was already cached.
# Bird species list for 'L1473008' was already cached.
# Bird species list for 'L2168448' was already cached.
# Bird species list for 'L2282598' was already cached.
# Bird species list for 'L849155' was already cached.
# Bird species list for 'L3220631' was already cached.
# Bird species list for 'L3882042' was already cached.
# Bird species list for 'L2474991' was already cached.
# Bird species list for 'L436934' was already cached.
# Bird species list for 'L436930' was already cached.
# Bird species list for 'L863744' was already cached.
# Bird species list for 'L1886823' was already cached.
# Bird species list for 'L20236231' was already cached.
# Bird species list for 'L2171649' was already cached.
# Bird species list for 'L19107557' was already cached.
# Bird species list for 'L8323031' was already cached.
# Bird species list for 'L30538853' was already cached.
# Bird species list for 'L3176557' was already cached.
# Bird species list for 'L2171690' was already cached.
# Bird species list for 'L4498358' was already cached.
# Bird species list for 'L19271816' was already cached.
# Bird species list for 'L3331609' was already cached.
# Bird species list for 'L21249706' was already cached.
# Bird species list for 'L1899374' was already cached.
# Bird species list for 'L21927711' was already cached.
# Bird species list for 'L3236802' was already cached.
# Bird species list for 'L3250876' was already cached.
# Bird species list for 'L11818690' was already cached.
# Bird species list for 'L9934804' was already cached.
# Bird species list for 'L16750601' was already cached.
# Bird species list for 'L2020689' was already cached.
# Bird species list for 'L1001271' was already cached.
# Bird species list for 'L2276546' was already cached.
# Bird species list for 'L3579241' was already cached.
# Bird species list for 'L2247414' was already cached.
# Bird species list for 'L6996453' was already cached.
# Bird species list for 'L6448525' was already cached.
# Bird species list for 'L6622361' was already cached.
# Bird species list for 'L2268945' was already cached.
# Bird species list for 'L3747671' was already cached.
# Bird species list for 'L5048593' was already cached.
# Bird species list for 'L1873352' was already cached.
# Bird species list for 'L4809061' was already cached.
# Bird species list for 'L23319788' was already cached.
# Bird species list for 'L3025465' was already cached.
# Bird species list for 'L442612' was already cached.
# Bird species list for 'L7357378' was already cached.
# Bird species list for 'L4875736' was already cached.
# Bird species list for 'L311635' was already cached.
# Bird species list for 'L1850443' was already cached.
# Bird species list for 'L19267010' was already cached.
# Bird species list for 'L13776866' was already cached.
# Bird species list for 'L4635018' was already cached.
# Bird species list for 'L3619743' was already cached.
# Bird species list for 'L3621869' was already cached.
# Bird species list for 'L3306687' was already cached.
# Bird species list for 'L3349244' was already cached.
# Bird species list for 'L3346941' was already cached.
# Bird species list for 'L15787183' was already cached.
# Bird species list for 'L2249172' was already cached.
# Bird species list for 'L3842895' was already cached.
# Bird species list for 'L3503121' was already cached.
# Bird species list for 'L5578048' was already cached.
# Bird species list for 'L2168470' was already cached.
# Bird species list for 'L2902646' was already cached.
# Bird species list for 'L448181' was already cached.
# Bird species list for 'L2318958' was already cached.
# Bird species list for 'L2301474' was already cached.
# Bird species list for 'L744883' was already cached.
# Bird species list for 'L4592606' was already cached.
# Bird species list for 'L7515754' was already cached.
# Bird species list for 'L3502981' was already cached.
# Bird species list for 'L3517060' was already cached.
# Bird species list for 'L3766029' was already cached.
# Bird species list for 'L3792239' was already cached.
# Bird species list for 'L6700199' was already cached.
# Bird species list for 'L12343825' was already cached.
# Bird species list for 'L3580137' was already cached.
# Bird species list for 'L3747667' was already cached.
# Bird species list for 'L6347553' was already cached.
# Bird species list for 'L2086756' was already cached.
# Bird species list for 'L16552515' was already cached.
# Bird species list for 'L31620157' was already cached.
# Bird species list for 'L3352552' was already cached.
# Bird species list for 'L2168278' was already cached.
# Bird species list for 'L8500758' was already cached.
# Bird species list for 'L53612666' was already cached.
# Bird species list for 'L18578123' was already cached.
# Bird species list for 'L4626151' was already cached.
# Bird species list for 'L673542' was already cached.
# Bird species list for 'L1450737' was already cached.
# Bird species list for 'L1176862' was already cached.
# Bird species list for 'L325849' was already cached.
# Bird species list for 'L2318995' was already cached.
# Bird species list for 'L970067' was already cached.
# Bird species list for 'L26961604' was already cached.
# Bird species list for 'L2282443' was already cached.
# Bird species list for 'L436932' was already cached.
# Bird species list for 'L1144714' was already cached.
# Bird species list for 'L2397652' was already cached.
# Bird species list for 'L5419113' was already cached.
# Bird species list for 'L2359363' was already cached.
# Bird species list for 'L3873986' was already cached.
# Bird species list for 'L3307723' was already cached.
# Bird species list for 'L2374510' was already cached.
# Bird species list for 'L7732043' was already cached.
# Bird species list for 'L8712803' was already cached.
# Bird species list for 'L3356812' was already cached.
# Bird species list for 'L11878908' was already cached.
# Bird species list for 'L1144728' was already cached.
# Bird species list for 'L4988370' was already cached.
# Bird species list for 'L3647607' was already cached.
# Bird species list for 'L16612083' was already cached.
# Bird species list for 'L5259737' was already cached.
# Bird species list for 'L3108671' was already cached.
# Bird species list for 'L3744063' was already cached.
# Bird species list for 'L10543469' was already cached.
# Bird species list for 'L12527580' was already cached.
# Bird species list for 'L1156977' was already cached.
# Bird species list for 'L7515596' was already cached.
# Bird species list for 'L2098884' was already cached.
# Bird species list for 'L1026105' was already cached.
# Bird species list for 'L2319117' was already cached.
# Bird species list for 'L5204878' was already cached.
# Bird species list for 'L3850505' was already cached.
# Bird species list for 'L10581473' was already cached.
# Bird species list for 'L3338752' was already cached.
# Bird species list for 'L5226203' was already cached.
# Bird species list for 'L10209276' was already cached.
# Bird species list for 'L436229' was already cached.
# Bird species list for 'L7245583' was already cached.
# Bird species list for 'L552342' was already cached.
# Bird species list for 'L2168373' was already cached.
# Bird species list for 'L1468729' was already cached.
# Bird species list for 'L11586672' was already cached.
# Bird species list for 'L5852373' was already cached.
# Retrieving species lists for hotspots near 'La Fortuna, Alajuela Province, Costa Rica'...
# Bird species list for 'L5123122' was already cached.
# Bird species list for 'L3586675' was already cached.
# Bird species list for 'L2605069' was already cached.
# Bird species list for 'L40449788' was already cached.
# Bird species list for 'L444570' was already cached.
# Bird species list for 'L2318975' was already cached.
# Bird species list for 'L16815215' was already cached.
# Bird species list for 'L1894059' was already cached.
# Bird species list for 'L1473008' was already cached.
# Bird species list for 'L2168448' was already cached.
# Bird species list for 'L3404537' was already cached.
# Bird species list for 'L2282598' was already cached.
# Bird species list for 'L849155' was already cached.
# Bird species list for 'L3220631' was already cached.
# Bird species list for 'L11140437' was already cached.
# Bird species list for 'L2474991' was already cached.
# Bird species list for 'L863744' was already cached.
# Bird species list for 'L1886823' was already cached.
# Bird species list for 'L20236231' was already cached.
# Bird species list for 'L19107557' was already cached.
# Bird species list for 'L8323031' was already cached.
# ...
# Bird species list for 'L2902646' was already cached.
# Bird species list for 'L448181' was already cached.
# Bird species list for 'L2301474' was already cached.
# Bird species list for 'L2898920' was already cached.
# Bird species list for 'L744883' was already cached.
# Bird species list for 'L7515754' was already cached.
# Bird species list for 'L3517060' was already cached.
# Bird species list for 'L6700199' was already cached.
# Bird species list for 'L12343825' was already cached.
# Bird species list for 'L3580137' was already cached.
# Bird species list for 'L6347553' was already cached.
# Bird species list for 'L2086756' was already cached.
# Bird species list for 'L16552515' was already cached.
# Bird species list for 'L31620157' was already cached.
# Bird species list for 'L3352552' was already cached.
# Bird species list for 'L2168278' was already cached.
# Bird species list for 'L18578123' was already cached.
# Bird species list for 'L4626151' was already cached.
# Bird species list for 'L2704815' was already cached.
# Bird species list for 'L1176862' was already cached.
# Bird species list for 'L2292251' was already cached.
# Bird species list for 'L325849' was already cached.
# Bird species list for 'L2318995' was already cached.
# Bird species list for 'L436932' was already cached.
# Bird species list for 'L1144714' was already cached.
# Bird species list for 'L1808679' was already cached.
# Bird species list for 'L2397652' was already cached.
# Bird species list for 'L2359363' was already cached.
# Bird species list for 'L3873986' was already cached.
# Bird species list for 'L20759691' was already cached.
# Bird species list for 'L4530908' was already cached.
# Bird species list for 'L3356812' was already cached.
# Bird species list for 'L11878908' was already cached.
# Bird species list for 'L1144728' was already cached.
# Bird species list for 'L4988370' was already cached.
# Bird species list for 'L3647607' was already cached.
# Bird species list for 'L16612083' was already cached.
# Bird species list for 'L3108671' was already cached.
# Bird species list for 'L3744063' was already cached.
# Bird species list for 'L10543469' was already cached.
# Bird species list for 'L11032273' was already cached.
# Bird species list for 'L1156977' was already cached.
# Bird species list for 'L7515596' was already cached.
# Bird species list for 'L2319117' was already cached.
# Bird species list for 'L5204878' was already cached.
# Bird species list for 'L10581473' was already cached.
# Bird species list for 'L5226203' was already cached.
# Bird species list for 'L436229' was already cached.
# Bird species list for 'L7245583' was already cached.
# Bird species list for 'L552342' was already cached.
# Bird species list for 'L2168373' was already cached.
# Bird species list for 'L1468729' was already cached.
# Bird species list for 'L11586672' was already cached.
# Retrieving species lists for hotspots near 'Mistico Park Hanging Bridges, La Fortuna, Alajuela Province, Costa Rica'...
# Bird species list for 'L5123122' was already cached.
# Bird species list for 'L3586675' was already cached.
# Bird species list for 'L2605069' was already cached.
# Bird species list for 'L40449788' was already cached.
# Bird species list for 'L444570' was already cached.
# Bird species list for 'L2160384' was already cached.
# Bird species list for 'L2318975' was already cached.
# Bird species list for 'L5040956' was already cached.
# Bird species list for 'L16815215' was already cached.
# Bird species list for 'L1894059' was already cached.
# Bird species list for 'L14675576' was already cached.
# Bird species list for 'L1473008' was already cached.
# Bird species list for 'L2168448' was already cached.
# Bird species list for 'L2282598' was already cached.
# Bird species list for 'L849155' was already cached.
# Bird species list for 'L3220631' was already cached.
# Bird species list for 'L11140437' was already cached.
# Bird species list for 'L2474991' was already cached.
# Bird species list for 'L436934' was already cached.
# Bird species list for 'L436930' was already cached.
# Bird species list for 'L863744' was already cached.
# Bird species list for 'L1886823' was already cached.
# Bird species list for 'L20236231' was already cached.
# Bird species list for 'L2171649' was already cached.
# Bird species list for 'L19107557' was already cached.
# Bird species list for 'L8323031' was already cached.
# Bird species list for 'L30538853' was already cached.
# Bird species list for 'L3176557' was already cached.
# Bird species list for 'L2171690' was already cached.
# Bird species list for 'L4498358' was already cached.
# Bird species list for 'L19271816' was already cached.
# Bird species list for 'L3331609' was already cached.
# Bird species list for 'L21249706' was already cached.
# Bird species list for 'L1899374' was already cached.
# Bird species list for 'L21927711' was already cached.
# Bird species list for 'L3236802' was already cached.
# Bird species list for 'L3250876' was already cached.
# Bird species list for 'L11818690' was already cached.
# Bird species list for 'L9934804' was already cached.
# Bird species list for 'L16750601' was already cached.
# Bird species list for 'L2020689' was already cached.
# Bird species list for 'L1001271' was already cached.
# Bird species list for 'L2276546' was already cached.
# Bird species list for 'L2247414' was already cached.
# Bird species list for 'L6996453' was already cached.
# Bird species list for 'L6448525' was already cached.
# Bird species list for 'L6622361' was already cached.
# Bird species list for 'L2268945' was already cached.
# Bird species list for 'L3747671' was already cached.
# Bird species list for 'L5048593' was already cached.
# Bird species list for 'L1873352' was already cached.
# Bird species list for 'L4809061' was already cached.
# Bird species list for 'L23319788' was already cached.
# Bird species list for 'L3025465' was already cached.
# Bird species list for 'L442612' was already cached.
# Bird species list for 'L7357378' was already cached.
# Bird species list for 'L3539300' was already cached.
# Bird species list for 'L4875736' was already cached.
# Bird species list for 'L311635' was already cached.
# Bird species list for 'L1850443' was already cached.
# Bird species list for 'L19267010' was already cached.
# Bird species list for 'L13776866' was already cached.
# Bird species list for 'L4635018' was already cached.
# Bird species list for 'L9365875' was already cached.
# Bird species list for 'L3621869' was already cached.
# Bird species list for 'L3619743' was already cached.
# Bird species list for 'L13305808' was already cached.
# Bird species list for 'L2902607' was already cached.
# Bird species list for 'L3306687' was already cached.
# Bird species list for 'L8708619' was already cached.
# Bird species list for 'L1508152' was already cached.
# Bird species list for 'L3295653' was already cached.
# Bird species list for 'L5889205' was already cached.
# Bird species list for 'L3346941' was already cached.
# Bird species list for 'L54555766' was already cached.
# Bird species list for 'L15787183' was already cached.
# Bird species list for 'L2249172' was already cached.
# Bird species list for 'L3842895' was already cached.
# Bird species list for 'L3503121' was already cached.
# Bird species list for 'L5578048' was already cached.
# Bird species list for 'L2168470' was already cached.
# Bird species list for 'L2902646' was already cached.
# Bird species list for 'L448181' was already cached.
# Bird species list for 'L2318958' was already cached.
# Bird species list for 'L2301474' was already cached.
# Bird species list for 'L2898920' was already cached.
# Bird species list for 'L744883' was already cached.
# Bird species list for 'L4592606' was already cached.
# Bird species list for 'L7515754' was already cached.
# Bird species list for 'L3502981' was already cached.
# Bird species list for 'L3517060' was already cached.
# Bird species list for 'L3766029' was already cached.
# Bird species list for 'L6700199' was already cached.
# Bird species list for 'L12343825' was already cached.
# Bird species list for 'L3580137' was already cached.
# Bird species list for 'L3747667' was already cached.
# Bird species list for 'L2086756' was already cached.
# Bird species list for 'L31620157' was already cached.
# Bird species list for 'L2155838' was already cached.
# Bird species list for 'L3352552' was already cached.
# Bird species list for 'L2168278' was already cached.
# Bird species list for 'L53612666' was already cached.
# Bird species list for 'L18578123' was already cached.
# Bird species list for 'L54554306' was already cached.
# Bird species list for 'L4626151' was already cached.
# Bird species list for 'L673542' was already cached.
# Bird species list for 'L1450737' was already cached.
# Bird species list for 'L2704815' was already cached.
# Bird species list for 'L1176862' was already cached.
# Bird species list for 'L325849' was already cached.
# Bird species list for 'L2318995' was already cached.
# Bird species list for 'L26961604' was already cached.
# Bird species list for 'L2282443' was already cached.
# Bird species list for 'L436932' was already cached.
# Bird species list for 'L1144714' was already cached.
# Bird species list for 'L3539812' was already cached.
# Bird species list for 'L1808679' was already cached.
# Bird species list for 'L2397652' was already cached.
# Bird species list for 'L5419113' was already cached.
# Bird species list for 'L2359363' was already cached.
# Bird species list for 'L3873986' was already cached.
# Bird species list for 'L3307723' was already cached.
# Bird species list for 'L20759691' was already cached.
# Bird species list for 'L4530908' was already cached.
# Bird species list for 'L7732043' was already cached.
# Bird species list for 'L778874' was already cached.
# Bird species list for 'L3356812' was already cached.
# Bird species list for 'L11878908' was already cached.
# Bird species list for 'L1144728' was already cached.
# Bird species list for 'L4988370' was already cached.
# Bird species list for 'L3647607' was already cached.
# Bird species list for 'L16612083' was already cached.
# Bird species list for 'L5259737' was already cached.
# Bird species list for 'L3108671' was already cached.
# Bird species list for 'L3744063' was already cached.
# Bird species list for 'L10543469' was already cached.
# Bird species list for 'L11032273' was already cached.
# Bird species list for 'L1156977' was already cached.
# Bird species list for 'L7515596' was already cached.
# Bird species list for 'L2098884' was already cached.
# Bird species list for 'L2319117' was already cached.
# Bird species list for 'L5204878' was already cached.
# Bird species list for 'L3850505' was already cached.
# Bird species list for 'L10581473' was already cached.
# Bird species list for 'L3338752' was already cached.
# Bird species list for 'L5226203' was already cached.
# Bird species list for 'L10209276' was already cached.
# Bird species list for 'L436229' was already cached.
# Bird species list for 'L7245583' was already cached.
# Bird species list for 'L552342' was already cached.
# Bird species list for 'L2168373' was already cached.
# Bird species list for 'L1468729' was already cached.
# Bird species list for 'L11586672' was already cached.
# Bird species list for 'L5852373' was already cached.
# Retrieving species lists for hotspots near 'Parque Nacional Volcán Poás, Costa Rica'...
# Bird species list for 'L5090864' was already cached.
# Bird species list for 'L6599956' was already cached.
# Bird species list for 'L6677164' was already cached.
# Bird species list for 'L3636759' was already cached.
# Bird species list for 'L2240981' was already cached.
# Bird species list for 'L441883' was already cached.
# Bird species list for 'L3344389' was already cached.
# Bird species list for 'L3342922' was already cached.
# Bird species list for 'L1842989' was already cached.
# Bird species list for 'L507414' was already cached.
# Bird species list for 'L1283736' was already cached.
# Bird species list for 'L9820408' was already cached.
# Bird species list for 'L436231' was already cached.
# Bird species list for 'L5176840' was already cached.
# Bird species list for 'L4494051' was already cached.
# Bird species list for 'L1144236' was already cached.
# Bird species list for 'L2095820' was already cached.
# Bird species list for 'L3608284' was already cached.
# Bird species list for 'L5983488' was already cached.
# Bird species list for 'L16194302' was already cached.
# Bird species list for 'L5481517' was already cached.
# Bird species list for 'L2946480' was already cached.
# Bird species list for 'L1144222' was already cached.
# Bird species list for 'L2941749' was already cached.
# Bird species list for 'L1307821' was already cached.
# Bird species list for 'L2157491' was already cached.
# Bird species list for 'L5496914' was already cached.
# Bird species list for 'L5796563' was already cached.
# Bird species list for 'L6146366' was already cached.
# Bird species list for 'L6862958' was already cached.
# Bird species list for 'L2907146' was already cached.
# Bird species list for 'L21592770' was already cached.
# Bird species list for 'L5420709' was already cached.
# Bird species list for 'L5431695' was already cached.
# Bird species list for 'L19155318' was already cached.
# Bird species list for 'L5921214' was already cached.
# Bird species list for 'L4466949' was already cached.
# Bird species list for 'L445844' was already cached.
# Bird species list for 'L3550808' was already cached.
# Bird species list for 'L2280776' was already cached.
# Bird species list for 'L3315219' was already cached.
# Bird species list for 'L13645683' was already cached.
# Bird species list for 'L2310175' was already cached.
# Bird species list for 'L29563278' was already cached.
# Bird species list for 'L33057120' was already cached.
# Bird species list for 'L7681233' was already cached.
# Bird species list for 'L1488653' was already cached.
# Bird species list for 'L3673157' was already cached.
# Bird species list for 'L1331161' was already cached.
# Bird species list for 'L13324976' was already cached.
# Bird species list for 'L15157069' was already cached.
# Bird species list for 'L436224' was already cached.
# Bird species list for 'L436225' was already cached.
# Bird species list for 'L3547676' was already cached.
# Bird species list for 'L5928811' was already cached.
# Bird species list for 'L3993899' was already cached.
# Bird species list for 'L1840818' was already cached.
# Bird species list for 'L1348750' was already cached.
# Bird species list for 'L3605626' was already cached.
# Bird species list for 'L2333406' was already cached.
# Bird species list for 'L6047181' was already cached.
# Bird species list for 'L5522819' was already cached.
# Bird species list for 'L16659097' was already cached.
# Bird species list for 'L4889915' was already cached.
# Bird species list for 'L7524923' was already cached.
# Bird species list for 'L470681' was already cached.
# Bird species list for 'L4131068' was already cached.
# Bird species list for 'L15993754' was already cached.
# Bird species list for 'L17684676' was already cached.
# Bird species list for 'L441317' was already cached.
# Bird species list for 'L12776472' was already cached.
# Bird species list for 'L10302649' was already cached.
# Bird species list for 'L37188727' was already cached.
# Bird species list for 'L11401530' was already cached.
# Bird species list for 'L470684' was already cached.
# Bird species list for 'L2845579' was already cached.
# Bird species list for 'L10201668' was already cached.
# Bird species list for 'L2277803' was already cached.
# Bird species list for 'L9171225' was already cached.
# Bird species list for 'L523555' was already cached.
# Bird species list for 'L7911554' was already cached.
# Bird species list for 'L4021011' was already cached.
# Bird species list for 'L2346197' was already cached.
# Bird species list for 'L1345796' was already cached.
# Bird species list for 'L1537452' was already cached.
# Bird species list for 'L1607257' was already cached.
# Bird species list for 'L6253236' was already cached.
# Bird species list for 'L37802303' was already cached.
# Bird species list for 'L8005145' was already cached.
# Current species lists include 971 total distinct species.

# %%
import pooch

RESOLVE_ECOREGIONS_2017_URL = "https://storage.googleapis.com/teow2016/Ecoregions2017.zip"

fetcher = pooch.create(
    path=pooch.os_cache("birding_datasets"),
    base_url="",
    registry={"Ecoregions2017.zip": None},
    urls={"Ecoregions2017.zip": RESOLVE_ECOREGIONS_2017_URL},
)

zip_path = fetcher.fetch("Ecoregions2017.zip", downloader=pooch.HTTPDownloader(progressbar=True))
zip_path
# Out:
# '/home/benned/.cache/birding_datasets/Ecoregions2017.zip'

# %%
import geopandas as gpd

ecoregions = gpd.read_file(f"zip://{zip_path}!Ecoregions2017.shp")
ecoregions = ecoregions.to_crs("EPSG:4326")  # Use (long, lat) in degrees

expected_fields = ["BIOME_NAME", "BIOME_NUM", "ECO_ID", "ECO_NAME", "LICENSE", "REALM", "geometry"]
missing = [c for c in expected_fields if c not in ecoregions.columns]
if missing:
    raise KeyError(
        f"Missing expected columns in the RESOLVE dataset: {missing}. "
        f"Available: {sorted(ecoregions.columns)}"
    )

# %%
@dataclass(frozen=True)
class SurroundingSpecies:
    """A collection of species information in the regions containing a location."""

    location: EBirdLocation
    location_species: list[str]
    subnational2_species: list[str] | None
    subnational1_species: list[str] | None
    country_species: list[str]

    def __str__(self) -> str:
        """Return a human-readable string representation of the species collection."""
        species_str = f"Location ({self.location.name}) Species: {len(self.location_species)}\n"

        if self.subnational2_species is not None:
            subnat2_name = (
                self.location.subnational2_name
                if self.location.subnational2_name is not None
                else self.location.subnational2_code
            )
            n_subnat2_species = len(self.subnational2_species)
            species_str += f"Subnational Region 2 ({subnat2_name}) Species: {n_subnat2_species}\n"

        if self.subnational1_species is not None:
            subnat1_name = (
                self.location.subnational1_name
                if self.location.subnational1_name is not None
                else self.location.subnational1_code
            )
            n_subnat1_species = len(self.subnational1_species)
            species_str += f"Subnational Region 1 ({subnat1_name}) Species: {n_subnat1_species}\n"

        country_code = self.location.country_code
        species_str += f"Country ({country_code}) Species: {len(self.country_species)}"

        return species_str

# %%
species = SurroundingSpecies.from_location(nearest_hotspot.location)
species
# Out:
# SurroundingSpecies(location=EBirdLocation(id='L24184797', name='Kennedy Plaza, Providence', latitude=41.825473, longitude=-71.412127, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), location_species=['cangoo', 'mutswa', 'mallar3', 'ambduc', 'wiltur', 'rocpig', 'moudov', 'chiswi', 'ribgul', 'amhgul1', 'doccor', 'coohaw', 'rebwoo', 'dowwoo', 'perfal', 'easpho', 'blujay', 'amecro', 'fiscro', 'bkcchi', 'tuftit', 'gockin', 'whbnut', 'carwre', 'eursta', 'grycat', 'normoc', 'amerob', 'cedwax', 'houspa', 'houfin', 'amegfi', 'chispa', 'fiespa', 'sonspa', 'bnhcow', 'comgra', 'norcar'], subnational2_species=['snogoo', 'rosgoo', 'gragoo', 'x00776', 'gwfgoo', 'pifgoo', 'brant', 'bargoo', 'cacgoo1', 'cangoo', 'x00758', 'x00759', 'mutswa', 'truswa', 'tunswa', 'musduc', 'wooduc', 'buwtea', 'cintea', 'norsho', 'gadwal', 'eurwig', 'amewig', 'x00724', 'mallar3', 'ambduc', 'x00004', 'norpin', 'x00628', 'gnwtea', 'canvas', 'redhea', 'rinduc', 'tufduc', 'gresca', 'lessca', 'x00613', 'tdxsca1', 'comeid', 'sursco', 'whwsco2', 'blksco2', 'lotduc', 'buffle', 'comgol', 'bargol', 'cxbgol1', 'hoomer', 'commer', 'rebmer', 'rudduc', 'norbob', 'wiltur', 'rufgro', 'rinphe1', 'chukar', 'rocpig', 'afcdov1', 'moudov', 'yebcuc', 'bkbcuc', 'comcuc', 'comnig', 'easwpw1', 'chiswi', 'rthhum', 'rufhum', 'clarai11', 'virrai', 'corcra', 'sora', 'comgal1', 'y00475', 'sancra', 'ameoys', 'bkbplo', 'amgplo', 'killde', 'semplo', 'uplsan', 'shbdow', 'lobdow', 'amewoo', 'wilsni1', 'sposan', 'solsan', 'lesyel', 'willet1', 'greyel', 'rudtur', 'ruff', 'stisan', 'bubsan', 'sander', 'dunlin', 'pursan', 'baisan', 'whrsan', 'leasan', 'pecsan', 'semsan', 'doveki', 'bongul', 'bkhgul', 'laugul', 'mewgul', 'ribgul', 'amhgul1', 'gbbgul', 'glagul', 'lbbgul', 'y00478', 'blkski', 'sooter1', 'leater1', 'caster1', 'blkter', 'forter', 'arcter', 'comter', 'roster', 'pibgre', 'horgre', 'rengre', 'eargre', 'retloo', 'comloo', 'anhing', 'grecor', 'doccor', 'whiibi', 'gloibi', 'amebit', 'ycnher', 'bcnher', 'libher', 'snoegr', 'grnher', 'categr1', 'greegr', 'grbher3', 'amwpel', 'blkvul', 'turvul', 'osprey', 'swtkit', 'goleag', 'shshaw', 'coohaw', 'norgos', 'norhar2', 'baleag', 'miskit', 'brwhaw', 'reshaw', 'rethaw', 'x00686', 'rolhaw', 'easowl1', 'snoowl1', 'grhowl', 'brdowl', 'loeowl', 'sheowl', 'nswowl', 'belkin1', 'yebsap', 'lewwoo', 'rehwoo', 'rebwoo', 'dowwoo', 'haiwoo', 'pilwoo', 'norfli', 'amekes', 'merlin', 'perfal', 'cockat', 'monpar', 'olsfly', 'eawpew', 'yebfly', 'acafly', 'aldfly', 'wilfly', 'leafly', 'easpho', 'saypho', 'astfly', 'grcfly', 'weskin', 'easkin', 'whevir', 'yetvir', 'buhvir', 'phivir', 'eawvir1', 'reevir1', 'norshr4', 'blujay', 'amecro', 'fiscro', 'comrav', 'bkcchi', 'tuftit', 'horlar', 'banswa', 'treswa', 'purmar', 'nrwswa', 'barswa', 'cliswa', 'rewbul', 'ruckin', 'gockin', 'whbnut', 'rebnut', 'brncre', 'buggna', 'houwre', 'winwre3', 'sedwre1', 'marwre', 'carwre', 'eursta', 'grycat', 'brnthr', 'normoc', 'easblu', 'towsol', 'varthr', 'veery', 'gycthr', 'swathr', 'herthr', 'woothr', 'amerob', 'cedwax', 'houspa', 'amepip', 'evegro', 'pingro', 'houfin', 'purfin', 'redpol1', 'redcro', 'whwcro', 'pinsis', 'amegfi', 'laplon', 'snobun', 'graspa', 'chispa', 'clcspa', 'fiespa', 'larspa', 'amtspa', 'foxspa', 'daejun', 'whcspa', 'whtspa', 'x00039', 'vesspa', 'nstspa', 'sstspa', 'savspa', 'sonspa', 'linspa', 'swaspa', 'eastow', 'yebcha', 'yehbla', 'boboli', 'easmea', 'orcori', 'balori', 'rewbla', 'bnhcow', 'rusbla', 'brebla', 'comgra', 'ovenbi1', 'woewar1', 'louwat', 'norwat', 'gowwar', 'buwwar', 'brewar', 'bawwar', 'prowar', 'tenwar', 'orcwar', 'naswar', 'conwar', 'macwar', 'mouwar', 'kenwar', 'comyel', 'hoowar', 'amered', 'camwar', 'cerwar', 'norpar', 'magwar', 'babwar', 'bkbwar', 'yelwar1', 'chswar', 'bkpwar', 'btbwar', 'palwar', 'pinwar', 'yerwar', 'yetwar', 'prawar', 'towwar', 'btnwar', 'canwar', 'wlswar', 'sumtan', 'scatan', 'westan', 'norcar', 'robgro', 'blugrb1', 'indbun', 'paibun', 'dickci'], subnatio ...

# %%
print(species)
# Out:
# Location (Kennedy Plaza, Providence) Species: 38
# Subnational Region 2 (US-RI-007) Species: 328
# Subnational Region 1 (US-RI) Species: 472
# Country (US) Species: 1775
