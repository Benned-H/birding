# %% [markdown]
# Goal: Retrieve the species list for a region using the eBird API and export it to YAML.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
regions = ["Maine, United States", "Providence, Rhode Island, United States"]

# %%
# Geocode all regions of interest
from birding.geocoding import retrieve_geocode
from birding.sqlite_cache import init_db

init_db()
for region in regions:
    print(f"\n\nRetrieving geocode for region '{region}'...")
    data = retrieve_geocode(query=region)
    if data is None:
        print(f"Could not find geocode for '{region}'.")
    else:
        print(data)
# Out:
# Retrieving geocode for region 'Maine, United States'...
# Geocode for query 'Maine, United States' was already cached.
# {'place_id': 336157849, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 63512, 'lat': '45.7090970', 'lon': '-68.8590201', 'class': 'boundary', 'type': 'administrative', 'place_rank': 8, 'importance': 0.7469097285923896, 'addresstype': 'state', 'name': 'Maine', 'display_name': 'Maine, United States', 'boundingbox': ['42.9222206', '47.4598397', '-71.0841694', '-66.8854174']}
#
#
# Retrieving geocode for region 'Providence, Rhode Island, United States'...
# Geocode for query 'Providence, Rhode Island, United States' was already cached.
# {'place_id': 334465335, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 191210, 'lat': '41.8239891', 'lon': '-71.4128343', 'class': 'boundary', 'type': 'administrative', 'place_rank': 16, 'importance': 0.6540931864702114, 'addresstype': 'city', 'name': 'Providence', 'display_name': 'Providence, Providence County, Rhode Island, United States', 'boundingbox': ['41.7724345', '41.8618007', '-71.4726670', '-71.3736135']}

# %%
from birding.primitives import Coordinate

raw_geocode_data = {r: retrieve_geocode(query=r) for r in regions}
geocode_data = {r: data for r, data in raw_geocode_data.items() if data is not None}
assert len(raw_geocode_data) == len(geocode_data), "A region's geocode data was None!"

region_coords = {r: Coordinate.from_geocode_data(data) for r, data in geocode_data.items()}
region_coords
# Out:
# Geocode for query 'Maine, United States' was already cached.
# Geocode for query 'Providence, Rhode Island, United States' was already cached.
# {'Maine, United States': Coordinate(latitude=45.709097, longitude=-68.8590201),
#  'Providence, Rhode Island, United States': Coordinate(latitude=41.8239891, longitude=-71.4128343)}

# %%
from birding.ebird_api import EBirdAPI
from birding.primitives import EBirdHotspot

ebird_api = EBirdAPI()

min_hotspots = 5
max_hotspot_dist_km = 5
region_to_hotspots: dict[str, list[EBirdHotspot]] = {}

for region, coord in region_coords.items():
    print(f"\n\nRetrieving nearby hotspots for region '{region}'...")
    hotspots = ebird_api.retrieve_nearby_hotspots(coord, max_hotspot_dist_km)
    print(f"Found {len(hotspots)} nearby hotspots.")

    if len(hotspots) < min_hotspots:
        print(f"Region had less than {min_hotspots} nearby hotspots!")
        more_hotspots = ebird_api.retrieve_nearby_hotspots(coord, distance_km=50)
        print(f"Found {len(more_hotspots)} hotspots within 50 km.")

        region_to_hotspots[region] = more_hotspots
    else:
        region_to_hotspots[region] = hotspots
# Out:
# Retrieving nearby hotspots for region 'Maine, United States'...
# Nearby hotspots within 5 km of (45.7091, -68.8590) were already cached.
# Found 2 nearby hotspots.
# Region had less than 5 nearby hotspots!
# Nearby hotspots within 50 km of (45.7091, -68.8590) were already cached.
# Found 96 hotspots within 50 km.
#
#
# Retrieving nearby hotspots for region 'Providence, Rhode Island, United States'...
# Nearby hotspots within 5 km of (41.8240, -71.4128) were already cached.
# Found 41 nearby hotspots.

# %%
region_to_hotspots
# Out:
# {'Maine, United States': [EBirdHotspot(location=EBirdLocation(id='L3028558', name='AMC Gorman Chairback Lodge', coord=Coordinate(latitude=45.4616766, longitude=-69.3166101), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=101),
#   EBirdHotspot(location=EBirdLocation(id='L3896821', name='Appalachian Trail--White Cap Mountain', coord=Coordinate(latitude=45.5545086, longitude=-69.245882), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=43),
#   EBirdHotspot(location=EBirdLocation(id='L19790628', name='B-52 Site, Elephant Mtn', coord=Coordinate(latitude=45.5280512, longitude=-69.4344453), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=53),
#   EBirdHotspot(location=EBirdLocation(id='L296058', name='Baxter SP', coord=Coordinate(latitude=45.9754792, longitude=-68.9351746), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=160),
#   EBirdHotspot(location=EBirdLocation(id='L3710198', name='Baxter SP-- Foster Field Group Area', coord=Coordinate(latitude=45.9042412, longitude=-69.0378459), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=45),
#   EBirdHotspot(location=EBirdLocation(id='L2966440', name='Baxter SP--Abol Bridge', coord=Coordinate(latitude=45.8352909, longitude=-68.9679113), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=106),
#   EBirdHotspot(location=EBirdLocation(id='L9499524', name='Baxter SP--Abol Pond', coord=Coordinate(latitude=45.8395349, longitude=-68.9208344), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=68),
#   EBirdHotspot(location=EBirdLocation(id='L9733736', name='Baxter SP--Abol Trail', coord=Coordinate(latitude=45.875056, longitude=-68.960892), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=81),
#   EBirdHotspot(location=EBirdLocation(id='L19672187', name='Baxter SP--Cathedral Trail', coord=Coordinate(latitude=45.9131905, longitude=-68.9179384), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=47),
#   EBirdHotspot(location=EBirdLocation(id='L2268355', name='Baxter SP--Chimney Pond Campground', coord=Coordinate(latitude=45.9158396, longitude=-68.9126095), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=73),
#   EBirdHotspot(location=EBirdLocation(id='L966142', name='Baxter SP--Chimney Pond Trail', coord=Coordinate(latitude=45.9230115, longitude=-68.8679105), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=87),
#   EBirdHotspot(location=EBirdLocation(id='L12016792', name='Baxter SP--Cranberry Pond Trail', coord=Coordinate(latitude=45.8267882, longitude=-68.8879251), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=54),
#   EBirdHotspot(location=EBirdLocation(id='L11339066', name='Baxter SP--Daicey Pond', coord=Coordinate(latitude=45.8821159, longitude=-69.0294209), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=90),
#   EBirdHotspot(location=EBirdLocation(id='L12276709', name='Baxter SP--Dwelley Pond Trail & Pond', coord=Coordinate(latitude=46.0552517, longitude=-69.0488939), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=57),
#   EBirdHotspot(location=EBirdLocation(id='L1245172', name='Baxter SP--Grassy Pond', coord=Coordinate(latitude=45.8817632, longitude=-69.0055561), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=71),
#   EBirdHotspot(location=EBirdLocation(id='L3710240', name='Baxter SP--Grassy Pond Trail', coord=Coordinate(latitude=45.890827, longitude=-69.009712), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=83),
#   EBirdHotspot(location=EBirdLocation(id='L3724943', name='Baxter SP--Helon Taylor Trail', coord=Coordinate(latitude=45.9134935, longitude=-68.868506), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=94),
#   EBirdHotspot(location=EBirdLocation(id='L3717310', name='Baxter SP--Hunt Trail to Treeline', coord=Coordinate(latitude=45.8959962, longitude=-68.9783236), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=94),
#   EBirdHotspot(location=EBirdLocation(id='L3727119', name='Baxter SP--Katahdin Stream Campground', coord=Coordinate(latitude=45.8864518, longitude=-68.9994422), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=112),
#   EBirdHotspot(location=EBirdLocation(id='L9524104', name='Baxter SP--Kidney Pond', coord=Coordinate(latitude=45.8933449, longitude=-69.0469061), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=118),
#   EBirdHotspot(location=EBirdLocation(id='L20413418', name='Baxter SP--Ledge Falls', coord=Coordinate(latitude=45.9605227, longitude=-69.0588831), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=36),
#   EBirdHotspot(location=EBirdLocation(id='L1009552', name='Baxter SP--Lower South Branch Pond', coord=Coordinate(latitude=46.107614, longitude=-68.8998609), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=113),
#   EBirdHotspot(location=EBirdLocation(id='L1612982', name='Baxter SP--Mount Katahdin (above treeline)', coord=Coordinate(latitude=45.9044816, longitude=-68.9219728), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=69),
#   EBirdHotspot(location=EBirdLocation(id='L946347', name='Baxter SP--Nesowadnehunk Field Campground', coord=Coordinate(latitude=45.9790231, longitude=-69.0756691), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=138),
#   EBirdHotspot(location=EBirdLocation(id='L7493992', name='Baxter SP--O-J-I Mountain', coord=Coordinate(latitude=45.9283489, longitude=-69.016757), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=59),
#   EBirdHotspot(location=EBirdLocation(id='L16119758', name='Baxter SP--Pogy Notch Trail', coord=Coordinate(latitude=46.0539187, longitude=-68.8910059), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=53),
#   EBirdHotspot(location=EBirdLocation(id='L9034484', name='Baxter SP--Roaring Brook Campground', coord=Coordinate(latitude=45.920545, longitude=-68.8568477), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=95),
#   EBirdHotspot(location=EBirdLocation(id='L16119408', name='Baxter SP--Russell Pond', coord=Coordinate(latitude=45.9959688, longitude=-68.9070375), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=75),
#   EBirdHotspot(location=EBirdLocation(id='L7714717', name='Baxter SP--Saddle Trail', coord=Coordinate(latitude=45.9160493, longitude=-68.9251328), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=54),
#   EBirdHotspot(location=EBirdLocation(id='L998475', name='Baxter SP--Sandy Stream Pond Trail', coord=Coordinate(latitude=45.92772, longitude=-68.85284), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=130),
#   EBirdHotspot(location=EBirdLocation(id='L9893965', name='Baxter SP--Stump Pond', coord=Coordinate(latitude=45.866578, longitude=-68.9605766), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=79),
#   EBirdHotspot(location=EBirdLocation(id='L3707124', name='Baxter SP--Togue Pond Beach & Picnic Area', coord=Coordinate(latitude=45.8238859, longitude=-68.8860959), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=106),
#   EBirdHotspot(location=EBirdLocation(id='L998490', name='Baxter SP--Tote Road', coord=Coordinate(latitude=46.0011949, longitude=-69.0799713), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=133),
#   EBirdHotspot(location=EBirdLocation(id='L49207675', name='Baxter SP--Trout Brook Mtn Trail', coord=Coordinate(latitude=46.1565427, longitude=-68.8477039), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=32),
#   EBirdHotspot(location=EBirdLocation(id='L1607267', name='Big Moose Inn and Campground', coord=Coordinate(latitude=45.7294675, longitude=-68.8376149), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=104),
#   EBirdHotspot(location=EBirdLocation(id='L4764613', name='Cow Team Road', coord=Coordinate(latitude=45.9437494, longitude=-68.3351755), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-003', subnat2_name=None), all_time_species=46),
#   EBirdHotspot(location=EBirdLocation(id='L3896799', name='Debsconeag Lake Wilderness Camp', coord=Coordinate(latitude=45.756267, longitude=-69.0767934), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=100),
#   EBirdHotspot(location=EBirdLocation(id='L1436150', name='Debsconeag Lakes Wilderness Area (TNC)', coord=Coordinate(latitude=45.8448486, longitude=-69.0930783), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=72),
#   EBirdHotspot(location=EBirdLocation(id='L7432504', name='Debsconeag Lakes Wilderness Area (TNC)--Hale Pond', coord=Coordinate(latitude=45.8087124, longitude=-68.9710608), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=11),
#   EBirdHotspot(location=EBirdLocation(id='L6050182', name='Debsconeag Lakes Wilderness Area (TNC)--Lower Pitman Camp', coord=Coordinate(latitude=45.8339424, longitude=-68.9888835), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=29),
#   EBirdHotspot(location=EBirdLocation(id='L51328140', name='Frost Pond', coord=Coordinate(latitude=45.9014176, longitude=-69.1824532), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=16),
#   EBirdHotspot(location=EBirdLocation(id='L758332', name='Golden Road', coord=Coordinate(latitude=45.8409986, longitude=-69.0011787), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=133),
#   EBirdHotspot(location=EBirdLocation(id='L1678688', name='Gulf Hagas', coord=Coordinate(latitude=45.4951045, longitude=-69.3491246), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=83),
#   EBirdHotspot(location=EBirdLocation(id='L6810747', name='Jerry Pond', coord=Coordinate(latitude=45.6682876, longitude=-68.6834872), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-019', subnat2_name=None), all_time_species=58),
#   EBirdHotspot(location=EBirdLocation(id='L3896849', name='Katahdin Iron Works State Park', coord=Coordinate(latitude=45.445008, longitude=-69.1724024), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=70),
#   EBirdHotspot(location=EBirdLocation(id='L4959381', name='Katahdin Woods & Waters NM', coord=Coordinate(latitude=45.8747122, longitude=-68.6896026), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-019', subnat2_name=None), all_time_species=142),
#   EBirdHotspot(location=EBirdLocation(id='L19864671', name='Katahdin Woods & Waters NM--American Thread Road Bog', coord=Coordinate(latitude=46.04041, longitude=-68.57884), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-019', subnat2_name=None), all_time_species=14),
#   EBirdHotspot(location=EBirdLocation(id='L19668982', name='Katahdin Woods & Waters NM--Barnard Mountain Area', coord=Coordinate(latitude=45.9303624, longitude=-68.7543243), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-019', subnat2_name=None), all_time_species=57),
#   EBirdHotspot(location=EBirdLocation(id='L7663029', name='Katahdin Woods & Waters NM--Black Spruce Bog', coord=Coordinate(latitude=45.8587145, longitude=-68.7127667), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-019', subnat2_name=None), all_time_species=62),
#   EBirdHotspot(location=EBirdLocation(id='L17641168', name='Katahdin Woods & Waters NM--Bowlin Camps Area', coord=Coordinate(latitude=46.0361634, longitude=-68.7312277), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-019', subnat2_name=None), all_time_species=49),
#   EBirdHotspot(location=EBirdLocation(id='L7972326', name='Katahdin Woods & Waters NM--Deasey Ponds', coord=Coordinate(latitude=45.8757158, longitude=-68.6795881), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-019', subnat2_name=None), all_time_species=87),
#   EBirdHotspot(location=EBirdLocation(id='L19875336', name='Katahdin Woods & Waters NM--East Branch Road Area', coord=Coordinate(latitude=46.1100421, longitude=-68.7969699), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-019', subnat2_name=None), all_time_species=36),
#   EBirdHotspot(location=EBirdLocation(id='L9826387', name='Katahdin Woods & Waters NM--Esker Trail', coord=Coordinate(latitude=45.8664444, longitude=-68.6789173), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-019', subnat2_name=None), all_time_species=80),
#   EBirdHotspot(location=EBirdLocation(id='L19875323', name='Katahdin Woods & Waters NM--Haskell Gate Area', coord=Coordinate(latitude=46.07982, longitude=-68.795134), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-019', subnat2_name=None), all_time_species=13),
#   EBirdHotspot(location=EBirdLocation(id='L5575817', name='Katahdin Woods & Waters NM--Haskell Hut', coord=Coordinate(latitude=46.0770413, longitude=-68.7694788), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-019', subnat2_name=None), all_time_species=43),
#   EBirdHotspot(location=EBirdLocation(id='L6425034', name='Katahdin Woods & Waters NM--Haskell Hut Trail', coord=Coordinate(latitude=46.0823996, longitude=-68.7850571), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-019', subnat2_name=None), all_time_species=33),
#   EBirdHotspot(location=EBirdLocation(id='L19864642', name='Katahdin Woods & Waters NM--Kimball Deadwater', coord=Coordinate(latitude=46.014253, longitude=-68.570495), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-019', subnat2_name=None), all_time_species=81),
#   EBirdHotspot(location=EBirdLocation(id='L19668614', name='Katahdin Woods & Waters NM--Lunksoos Campsites Area', coord=Coordinate(latitude=45.908995, longitude=-68.6133868), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-019', subnat2_name=None), all_time_species=60),
#   EBirdHotspot(location=EBirdLocation(id='L5987275', name='Katahdin Woods & Waters NM--Lynx Pond, Loop Road', coord=Coordinate(latitude=45.8691097, longitude=-68.7076136), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-019', subnat2_name=None), all_time_species=110),
#   EBirdHotspot(location=EBirdLocation(id='L19860366', name='Katahdin Woods & Waters NM--Marble Ridge Road Area (4-wheel drive)', coord=Coordinate(latitude=46.0217459, longitude=-68.7085935), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-019', subnat2_name=None), all_time_species=6),
#   EBirdHotspot(location=EBirdLocation(id='L6421783', name='Katahdin Woods & Waters NM--Mile 10 Path', coord=Coordinate(latitude=45.9014176, longitude=-68.7579775), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-019', subnat2_name=None), all_time_species=4),
#   EBirdHotspot(location=EBirdLocation(id='L7600650', name='Katahdin Woods & Waters NM--Mink Frog Pond', coord=Coordinate(latitude=45.860698, longitude=-68.671686), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-019', subnat2_name=None), all_time_species=60),
#   EBirdHotspot(location=EBirdLocation(id='L17641158', name='Katahdin Woods & Waters NM--North Gate Area', coord=Coordinate(latitude=46.1234871, longitude=-68.7979376), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-019', subnat2_name=None), all_time_species=43),
#   EBirdHotspot(location=EBirdLocation(id='L6359087', name='Katahdin Woods & Waters NM--Orin Falls Trail', coord=Coordinate(latitude=45.9229458, longitude=-68.7048483), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-019', subnat2_name=None), all_time_species=72),
#   EBirdHotspot(location=EBirdLocation(id='L19864683', name='Katahdin Woods & Waters NM--Ragged Brook Area', coord=Coordinate(latitude=46.054419, longitude=-68.591132), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-019', subnat2_name=None), all_time_species=17),
#   EBirdHotspot(location=EBirdLocation(id='L5987078', name='Katahdin Woods & Waters NM--Ridge Trail', coord=Coordinate(latitude=45.8671463, longitude=-68.67924), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-019', subnat2_name=None), all_time_species=43),
#   EBirdHotspot(location=EBirdLocation(id='L7597126', name='Katahdin Woods & Waters NM--Sandbank Campsite', coord=Coordinate(latitude=45.8627, longitude=-68.67456), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-019', subnat2_name=None), all_time_species=99),
#   EBirdHotspot(location=EBirdLocation(id='L6421767', name='Katahdin Woods & Waters NM--Scenic Overlook Mile 6.2', coord=Coordinate(latitude=45.8458566, longitude=-68.7472567), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-019', subnat2_name=None), all_time_species=58),
#   EBirdHotspot(location=EBirdLocation(id='L16174958', name='Katahdin Woods & Waters NM--Seboeis Unit', coord=Coordinate(latitude=46.016276, longitude=-68.582431), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-019', subnat2_name=None), all_time_species=51),
#   EBirdHotspot(location=EBirdLocation(id='L5986902', name='Katahdin Woods & Waters NM--Side Road off Swift Brook Road', coord=Coordinate(latitude=45.8649634, longitude=-68.6768192), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-019', subnat2_name=None), all_time_species=58),
#   EBirdHotspot(location=EBirdLocation(id='L19865991', name='Katahdin Woods & Waters NM--Stacyville Road Unit', coord=Coordinate(latitude=45.88052, longitude=-68.5835043), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-019', subnat2_name=None), all_time_species=57),
#   EBirdHotspot(location=EBirdLocation(id='L19864647', name='Katahdin Woods & Waters NM--Twin Ponds', coord=Coordinate(latitude=46.032564, longitude=-68.581846), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-019', subnat2_name=None), all_time_species=29),
#   EBirdHotspot(location=EBirdLocation(id='L4890864', name='Lazy Tom Bog Campsite', coord=Coordinate(latitude=45.6919345, longitude=-69.4347686), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=88),
#   EBirdHotspot(location=EBirdLocation(id='L1678686', name='Little Lyford Lodge and Cabins', coord=Coordinate(latitude=45.5168117, longitude=-69.3590065), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=90),
#   EBirdHotspot(location=EBirdLocation(id='L2526945', name='Mattanawcook Stream, Lincoln', coord=Coordinate(latitude=45.3629109, longitude=-68.5057425), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-019', subnat2_name=None), all_time_species=57),
#   EBirdHotspot(location=EBirdLocation(id='L253095', name='Medawisla Lodge and Cabins', coord=Coordinate(latitude=45.6745866, longitude=-69.3222223), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=116),
#   EBirdHotspot(location=EBirdLocation(id='L11862333', name='Medford Road Wetland', coord=Coordinate(latitude=45.2675618, longitude=-68.9543688), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=40),
#   EBirdHotspot(location=EBirdLocation(id='L4662415', name='Michael Michaud Walking and Biking Trail', coord=Coordinate(latitude=45.6529539, longitude=-68.7068412), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-019', subnat2_name=None), all_time_species=73),
#   EBirdHotspot(location=EBirdLocation(id='L4958878', name='Millinocket Municipal Airport', coord=Coordinate(latitude=45.6503221, longitude=-68.695356), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-019', subnat2_name=None), all_time_species=79),
#   EBirdHotspot(location=EBirdLocation(id='L5797091', name='Mount Katahdin Scenic Overlook', coord=Coordinate(latitude=45.7126119, longitude=-68.4741686), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-019', subnat2_name=None), all_time_species=61),
#   EBirdHotspot(location=EBirdLocation(id='L1302634', name='Nesowadnehunk Campground', coord=Coordinate(latitude=46.0222805, longitude=-69.0707062), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=145),
#   EBirdHotspot(location=EBirdLocation(id='L11397000', name='New England Outdoor Center', coord=Coordinate(latitude=45.7261288, longitude=-68.8181904), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-019', subnat2_name=None), all_time_species=88),
#   EBirdHotspot(location=EBirdLocation(id='L4828046', name='Penobscot Pond', coord=Coordinate(latitude=45.6828882, longitude=-69.2049837), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=45),
#   EBirdHotspot(location=EBirdLocation(id='L2349682', name='Penobscot River Boat Launch', coord=Coordinate(latitude=45.3411429, longitude=-68.5704455), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-019', subnat2_name=None), all_time_species=56),
#   EBirdHotspot(location=EBirdLocation(id='L11838323', name='Penobscot River Trails', coord=Coordinate(latitude=45.7715734, longitude=-68.5730119), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-019', subnat2_name=None), all_time_species=75),
#   EBirdHotspot(location=EBirdLocation(id='L732687', name='Pond Farm WMA', coord=Coordinate(latitude=45.2939936, longitude=-68.7019215), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-019', subnat2_name=None), all_time_species=106),
#   EBirdHotspot(location=EBirdLocation(id='L11396779', name='Rice Farm Road', coord=Coordinate(latitude=45.6454366, longitude=-68.6399407), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-019', subnat2_name=None), all_time_species=20),
#   EBirdHotspot(location=EBirdLocation(id='L6050269', name='Ripogenus Dam', coord=Coordinate(latitude=45.8812554, longitude=-69.1762036), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=56),
#   EBirdHotspot(location=EBirdLocation(id='L15876676', name='Shin Pond Village and Campground', coord=Coordinate(latitude=46.1069106, longitude=-68.5583327), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-019', subnat2_name=None), all_time_species=67),
#   EBirdHotspot(location=EBirdLocation(id='L20015519', name='Sugarloaf Mountain, North Penobscot', coord=Coordinate(latitude=46.110058, longitude=-68.611475), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-019', subnat2_name=None), all_time_species=26),
#   EBirdHotspot(location=EBirdLocation(id='L2958801', name='Telos Road', coord=Coordinate(latitude=45.9883151, longitude=-69.1739345), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=127),
#   EBirdHotspot(location=EBirdLocation(id='L267075', name='Third Roach Pond', coord=Coordinate(latitude=45.6541411, longitude=-69.2248587), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=19),
#   EBirdHotspot(location=EBirdLocation(id='L4764614', name='Thousand Acre Bog, Crystal', coord=Coordinate(latitude=45.9572959, longitude=-68.3643579), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-003', subnat2_name=None), all_time_species=63),
#   EBirdHotspot(location=EBirdLocation(id='L23006411', name='West Branch Pond Camps', coord=Coordinate(latitude=45.5844421, longitude=-69.2905625), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=71),
#   EBirdHotspot(location=EBirdLocation(id='L24496303', name='Williamsburg Forest', coord=Coordinate(latitude=45.370928, longitude=-69.086556), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=28),
#   EBirdHotspot(location=EBirdLocation(id='L2424633', name='stakeout Northern Hawk-Owl, Lincoln', coord=Coordinate(latitude=45.3530741, longitude=-68.5323325), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-019', subnat2_name=None), all_time_species=45)],
#  'Providence, Rhode Island, United States': [EBirdHotspot(location=EBirdLocation(id='L6077334', name='Blackstone Boulevard, Providence', coord=Coordinate(latitude=41.8434142, longitude=-71.386435), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=52),
#   EBirdHotspot(location=EBirdLocation(id='L804728', name='Blackstone Park', coord=Coordinate(latitude=41.833327, longitude=-71.3792148), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=198),
#   EBirdHotspot(location=EBirdLocation(id='L216062', name='Bold Point Park, East Providence', coord=Coordinate(latitude=41.8144807, longitude=-71.3901623), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=159),
#   EBirdHotspot(location=EBirdLocation(id='L875821', name='Boyden Heights Conservation Area', coord=Coordinate(latitude=41.7895369, longitude=-71.370433), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=97),
#   EBirdHotspot(location=EBirdLocation(id='L7801999', name='Brown University Campus', coord=Coordinate(latitude=41.8260753, longitude=-71.403429), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=105),
#   EBirdHotspot(location=EBirdLocation(id='L11444077', name='Butler Campus', coord=Coordinate(latitude=41.8443214, longitude=-71.3815825), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=86),
#   EBirdHotspot(location=EBirdLocation(id='L29143732', name='Collier Point Park, Providence', coord=Coordinate(latitude=41.8120414, longitude=-71.401773), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=69),
#   EBirdHotspot(location=EBirdLocation(id='L1786830', name='Copps Cove', coord=Coordinate(latitude=41.7813513, longitude=-71.391461), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=70),
#   EBirdHotspot(location=EBirdLocation(id='L38433651', name='Davis Park, Providence', coord=Coordinate(latitude=41.833365, longitude=-71.430524), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=25),
#   EBirdHotspot(location=EBirdLocation(id='L38630506', name='Dexter Training Ground Park', coord=Coordinate(latitude=41.814522, longitude=-71.431343), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=17),
#   EBirdHotspot(location=EBirdLocation(id='L55322509', name='East Bay Bike Path--Veterans Memorial Parkway', coord=Coordinate(latitude=41.8091301, longitude=-71.3871416), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=17),
#   EBirdHotspot(location=EBirdLocation(id='L1139391', name='East Bay Bike Path--Watchemoket Cove to Pomham Rocks', coord=Coordinate(latitude=41.7959681, longitude=-71.3778949), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=179),
#   EBirdHotspot(location=EBirdLocation(id='L21194566', name='East Point (formerly Greenwood Point)', coord=Coordinate(latitude=41.8412036, longitude=-71.3717906), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=58),
#   EBirdHotspot(location=EBirdLocation(id='L1393330', name='Gano Park, Providence', coord=Coordinate(latitude=41.823722, longitude=-71.3885067), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=81),
#   EBirdHotspot(location=EBirdLocation(id='L8596244', name='India Point Park, Providence', coord=Coordinate(latitude=41.8172568, longitude=-71.3903618), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=92),
#   EBirdHotspot(location=EBirdLocation(id='L24184797', name='Kennedy Plaza, Providence', coord=Coordinate(latitude=41.825473, longitude=-71.412127), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=39),
#   EBirdHotspot(location=EBirdLocation(id='L55029974', name='Kent Heights Park, East Providence', coord=Coordinate(latitude=41.805105, longitude=-71.356364), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=13),
#   EBirdHotspot(location=EBirdLocation(id='L14185394', name='Lippitt Memorial Park', coord=Coordinate(latitude=41.8546509, longitude=-71.3915205), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=48),
#   EBirdHotspot(location=EBirdLocation(id='L9545732', name='Mashapaug Park, Providence', coord=Coordinate(latitude=41.7960733, longitude=-71.4301347), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=140),
#   EBirdHotspot(location=EBirdLocation(id='L3651661', name='Neutaconkanut Park', coord=Coordinate(latitude=41.8108757, longitude=-71.4654207), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=148),
#   EBirdHotspot(location=EBirdLocation(id='L4683264', name='North Burial Ground', coord=Coordinate(latitude=41.8483753, longitude=-71.4091051), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=72),
#   EBirdHotspot(location=EBirdLocation(id='L13049070', name='Omega Pond, East Providence', coord=Coordinate(latitude=41.8381258, longitude=-71.3646489), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=62),
#   EBirdHotspot(location=EBirdLocation(id='L13429477', name='Pleasant Valley Parkway, Providence', coord=Coordinate(latitude=41.8348354, longitude=-71.4422477), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=45),
#   EBirdHotspot(location=EBirdLocation(id='L4377381', name='Pocasset Cemetery', coord=Coordinate(latitude=41.8028945, longitude=-71.4596379), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=137),
#   EBirdHotspot(location=EBirdLocation(id='L16544941', name='Prospect Terrace, Providence', coord=Coordinate(latitude=41.8298931, longitude=-71.4072865), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=49),
#   EBirdHotspot(location=EBirdLocation(id='L51518007', name='Providence College', coord=Coordinate(latitude=41.843544, longitude=-71.43573), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=9),
#   EBirdHotspot(location=EBirdLocation(id='L5251233', name='Providence River (please use more specific location if possible)', coord=Coordinate(latitude=41.8002744, longitude=-71.3865166), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=59),
#   EBirdHotspot(location=EBirdLocation(id='L18152326', name='Providence River Greenway', coord=Coordinate(latitude=41.8221469, longitude=-71.4065884), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=89),
#   EBirdHotspot(location=EBirdLocation(id='L17197972', name='Public Street--Coastal Access Right of Way', coord=Coordinate(latitude=41.80863, longitude=-71.4019811), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=46),
#   EBirdHotspot(location=EBirdLocation(id='L36435856', name='Rhode Island College', coord=Coordinate(latitude=41.8417517, longitude=-71.46276), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=50),
#   EBirdHotspot(location=EBirdLocation(id='L38422558', name='Roger Williams National Memorial', coord=Coordinate(latitude=41.830073, longitude=-71.410568), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=28),
#   EBirdHotspot(location=EBirdLocation(id='L451783', name='Roger Williams Park', coord=Coordinate(latitude=41.781681, longitude=-71.4147806), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=167),
#   EBirdHotspot(location=EBirdLocation(id='L2526644', name='Save The Bay Center & Coastal Greenway', coord=Coordinate(latitude=41.7857568, longitude=-71.3817573), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=152),
#   EBirdHotspot(location=EBirdLocation(id='L5397820', name='Seekonk River (please use more specific location if possible)', coord=Coordinate(latitude=41.8364969, longitude=-71.3743988), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=109),
#   EBirdHotspot(location=EBirdLocation(id='L812502', name='Squantum Woods SP', coord=Coordinate(latitude=41.7928806, longitude=-71.3724232), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=119),
#   EBirdHotspot(location=EBirdLocation(id='L13935214', name='St. Francis Cemetery', coord=Coordinate(latitude=41.8638984, longitude=-71.4086965), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=36),
#   EBirdHotspot(location=EBirdLocation(id='L124352', name='Swan Point Cemetery', coord=Coordinate(latitude=41.8557485, longitude=-71.3812176), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=222),
#   EBirdHotspot(location=EBirdLocation(id='L16657907', name='Townie Pride Memorial Park, East Providence', coord=Coordinate(latitude=41.808964, longitude=-71.385004), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=53),
#   EBirdHotspot(location=EBirdLocation(id='L187164', name='Watchemoket Cove', coord=Coordinate(latitude=41.800495, longitude=-71.376686), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=137),
#   EBirdHotspot(location=EBirdLocation(id='L13430824', name='Waterman St. Dog Park', coord=Coordinate(latitude=41.8277178, longitude=-71.3835141), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=73),
#   EBirdHotspot(location=EBirdLocation(id='L28111910', name='Woonasquatucket River Greenway--Riverside Park to Merino Park', coord=Coordinate(latitude=41.8207141, longitude=-71.450412), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=55)]}

# %%
from geopy.distance import geodesic

from birding.primitives import EBirdHotspot

# Find the nearest hotspot to each region's coordinate
nearest_hotspots: dict[str, EBirdHotspot] = {}
for region, hotspots in region_to_hotspots.items():
    coord = region_coords[region]
    nearest = min(hotspots, key=lambda hs: geodesic(coord, hs.location.coord).mi)
    nearest_hotspots[region] = nearest

nearest_hotspots
# Out:
# {'Maine, United States': EBirdHotspot(location=EBirdLocation(id='L1607267', name='Big Moose Inn and Campground', coord=Coordinate(latitude=45.7294675, longitude=-68.8376149), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=104),
#  'Providence, Rhode Island, United States': EBirdHotspot(location=EBirdLocation(id='L24184797', name='Kennedy Plaza, Providence', coord=Coordinate(latitude=41.825473, longitude=-71.412127), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=39)}

# %%
# Verify that the dedicated function produces the same output
for region, region_coord in region_coords.items():
    nearest_per_notebook = nearest_hotspots.get(region)
    nearest_per_class = ebird_api.find_nearest_hotspot(region_coord)

    assert nearest_per_notebook == nearest_per_class, (
        f"Nearest hotspot according to the Jupyter notebook: {nearest_per_notebook}\n"
        f"Nearest hotspot according to the API class: {nearest_per_class}"
    )
# Out:
# Nearby hotspots within 0 km of (45.7091, -68.8590) were already cached.
# Nearby hotspots within 5 km of (45.7091, -68.8590) were already cached.
# Nearby hotspots within 0 km of (41.8240, -71.4128) were already cached.
# Nearby hotspots within 5 km of (41.8240, -71.4128) were already cached.

# %%
# Find eBird region codes for the regions of interest
region_codes_list = [ebird_api.find_region_code(r, c) for r, c in region_coords.items()]
region_codes_list = [c for c in region_codes_list if c is not None]
region_codes = dict(zip(regions, region_codes_list, strict=True))

region_codes
# Out:
# Nearby hotspots within 0 km of (45.7091, -68.8590) were already cached.
# Nearby hotspots within 5 km of (45.7091, -68.8590) were already cached.
# Region information for code 'US' was already cached.
# Region information for code 'US-ME' was already cached.
# Region information for code 'US-ME-021' was already cached.
# Nearby hotspots within 0 km of (41.8240, -71.4128) were already cached.
# Nearby hotspots within 5 km of (41.8240, -71.4128) were already cached.
# Region information for code 'US' was already cached.
# Region information for code 'US-RI' was already cached.
# Region information for code 'US-RI-007' was already cached.
# {'Maine, United States': 'US-ME',
#  'Providence, Rhode Island, United States': 'US-RI-007'}

# %%
# Find recent hotspots in the regions of interest
recent_hotspots: dict[str, list[EBirdHotspot]] = {
    region: ebird_api.retrieve_hotspots_in_region(code) for region, code in region_codes.items()
}
recent_hotspots
# Out:
# eBird hotspots in region 'US-ME' were already cached.
# eBird hotspots in region 'US-RI-007' were already cached.
# {'Maine, United States': [EBirdHotspot(location=EBirdLocation(id='L5867205', name='250th Anniversary Park', coord=Coordinate(latitude=43.9191617, longitude=-69.9653551), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-005', subnat2_name=None), all_time_species=78),
#   EBirdHotspot(location=EBirdLocation(id='L3028558', name='AMC Gorman Chairback Lodge', coord=Coordinate(latitude=45.4616766, longitude=-69.3166101), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=101),
#   EBirdHotspot(location=EBirdLocation(id='L459957', name='Abagadassett River Mouth', coord=Coordinate(latitude=44.0096078, longitude=-69.8517609), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-023', subnat2_name=None), all_time_species=154),
#   EBirdHotspot(location=EBirdLocation(id='L3863342', name='Abagadassett Wild Rice Fields', coord=Coordinate(latitude=44.0017674, longitude=-69.8489285), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-023', subnat2_name=None), all_time_species=79),
#   EBirdHotspot(location=EBirdLocation(id='L889345', name='Abandoned Rail Line, Rich Millpond', coord=Coordinate(latitude=43.7986806, longitude=-70.5766976), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-005', subnat2_name=None), all_time_species=91),
#   EBirdHotspot(location=EBirdLocation(id='L731948', name='Abandoned Rail Line, Sebago Lake', coord=Coordinate(latitude=43.7833025, longitude=-70.5340022), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-005', subnat2_name=None), all_time_species=57),
#   EBirdHotspot(location=EBirdLocation(id='L5078565', name='Abbott Park', coord=Coordinate(latitude=44.6658754, longitude=-70.1458704), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-007', subnat2_name=None), all_time_species=48),
#   EBirdHotspot(location=EBirdLocation(id='L5111729', name='Abby Aldrich Rockefeller Gardens (limited access)', coord=Coordinate(latitude=44.299411, longitude=-68.2525782), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=54),
#   EBirdHotspot(location=EBirdLocation(id='L2377923', name='Abel Cyr Road', coord=Coordinate(latitude=47.0866633, longitude=-68.0661392), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-003', subnat2_name=None), all_time_species=7),
#   EBirdHotspot(location=EBirdLocation(id='L27736390', name='Abner Point Road (foot traffic only)', coord=Coordinate(latitude=43.729101, longitude=-70.001244), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-005', subnat2_name=None), all_time_species=58),
#   EBirdHotspot(location=EBirdLocation(id='L11687154', name='Acadia Gateway Center Drive', coord=Coordinate(latitude=44.4696514, longitude=-68.3712919), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=44),
#   EBirdHotspot(location=EBirdLocation(id='L340581', name='Acadia NP (please use more specific location if possible)', coord=Coordinate(latitude=44.3385984, longitude=-68.2733291), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=240),
#   EBirdHotspot(location=EBirdLocation(id='L3893063', name='Acadia NP--Acadia Mountain Trail', coord=Coordinate(latitude=44.3214533, longitude=-68.3248758), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=100),
#   EBirdHotspot(location=EBirdLocation(id='L3677751', name='Acadia NP--Alder Trail', coord=Coordinate(latitude=44.3443026, longitude=-68.0561185), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=132),
#   EBirdHotspot(location=EBirdLocation(id='L25206158', name='Acadia NP--Anvil Trail', coord=Coordinate(latitude=44.3462065, longitude=-68.0505964), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=67),
#   EBirdHotspot(location=EBirdLocation(id='L5060545', name="Acadia NP--Aunt Betty's Pond Carriage Path Loop", coord=Coordinate(latitude=44.3688395, longitude=-68.2719612), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=113),
#   EBirdHotspot(location=EBirdLocation(id='L1481150', name='Acadia NP--Baker Island', coord=Coordinate(latitude=44.2414724, longitude=-68.1983643), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=106),
#   EBirdHotspot(location=EBirdLocation(id='L476600', name='Acadia NP--Bald Peak', coord=Coordinate(latitude=44.3351452, longitude=-68.2838058), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=60),
#   EBirdHotspot(location=EBirdLocation(id='L3027190', name='Acadia NP--Bar Island', coord=Coordinate(latitude=44.3985285, longitude=-68.2063437), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=146),
#   EBirdHotspot(location=EBirdLocation(id='L1533556', name='Acadia NP--Bass Harbor Marsh', coord=Coordinate(latitude=44.2533766, longitude=-68.3407102), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=163),
#   EBirdHotspot(location=EBirdLocation(id='L1567130', name='Acadia NP--Bear Brook Picnic Area', coord=Coordinate(latitude=44.3604813, longitude=-68.1987003), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=67),
#   EBirdHotspot(location=EBirdLocation(id='L1595827', name='Acadia NP--Beaver Dam Pond', coord=Coordinate(latitude=44.3623836, longitude=-68.1951383), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=111),
#   EBirdHotspot(location=EBirdLocation(id='L11168536', name='Acadia NP--Beech Mountain', coord=Coordinate(latitude=44.3104448, longitude=-68.3454215), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=85),
#   EBirdHotspot(location=EBirdLocation(id='L997169', name='Acadia NP--Beech Mountain and Beech Cliff Trails', coord=Coordinate(latitude=44.3146368, longitude=-68.3434689), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=106),
#   EBirdHotspot(location=EBirdLocation(id='L13237756', name='Acadia NP--Beehive Trail', coord=Coordinate(latitude=44.3319015, longitude=-68.186077), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=110),
#   EBirdHotspot(location=EBirdLocation(id='L29136679', name='Acadia NP--Bernard Mountain', coord=Coordinate(latitude=44.301142, longitude=-68.3724189), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=28),
#   EBirdHotspot(location=EBirdLocation(id='L476608', name='Acadia NP--Big Heath', coord=Coordinate(latitude=44.2364059, longitude=-68.3198547), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=97),
#   EBirdHotspot(location=EBirdLocation(id='L212537', name='Acadia NP--Blackwoods Campground', coord=Coordinate(latitude=44.3096007, longitude=-68.2040691), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=149),
#   EBirdHotspot(location=EBirdLocation(id='L1269544', name='Acadia NP--Blackwoods Campground Shore', coord=Coordinate(latitude=44.3065086, longitude=-68.2013869), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=125),
#   EBirdHotspot(location=EBirdLocation(id='L2345007', name='Acadia NP--Blueberry Hill', coord=Coordinate(latitude=44.3386398, longitude=-68.0454782), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=166),
#   EBirdHotspot(location=EBirdLocation(id='L3771762', name='Acadia NP--Breakneck Ponds', coord=Coordinate(latitude=44.3863961, longitude=-68.2543874), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=121),
#   EBirdHotspot(location=EBirdLocation(id='L995718', name='Acadia NP--Breakneck Road', coord=Coordinate(latitude=44.4041211, longitude=-68.2542329), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=93),
#   EBirdHotspot(location=EBirdLocation(id='L3919395', name='Acadia NP--Bubble Mountain Trails', coord=Coordinate(latitude=44.3425117, longitude=-68.2540226), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=104),
#   EBirdHotspot(location=EBirdLocation(id='L3819273', name='Acadia NP--Bubble Pond', coord=Coordinate(latitude=44.3455195, longitude=-68.2402897), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=84),
#   EBirdHotspot(location=EBirdLocation(id='L159030', name='Acadia NP--Cadillac Mountain', coord=Coordinate(latitude=44.3534831, longitude=-68.2260418), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=174),
#   EBirdHotspot(location=EBirdLocation(id='L3982459', name='Acadia NP--Cadillac Mountain South Ridge Trail', coord=Coordinate(latitude=44.3437372, longitude=-68.229879), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=118),
#   EBirdHotspot(location=EBirdLocation(id='L20068913', name='Acadia NP--Cadillac North Ridge Trail', coord=Coordinate(latitude=44.3775634, longitude=-68.2286766), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=89),
#   EBirdHotspot(location=EBirdLocation(id='L4085683', name='Acadia NP--Champlain Mountain', coord=Coordinate(latitude=44.3508187, longitude=-68.194043), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=113),
#   EBirdHotspot(location=EBirdLocation(id='L19977366', name='Acadia NP--Day Mountain', coord=Coordinate(latitude=44.3073639, longitude=-68.2319094), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=69),
#   EBirdHotspot(location=EBirdLocation(id='L1958330', name='Acadia NP--Dorr Mountain', coord=Coordinate(latitude=44.3546645, longitude=-68.2149696), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=104),
#   EBirdHotspot(location=EBirdLocation(id='L3724032', name='Acadia NP--Dorr Point and Compass Harbor', coord=Coordinate(latitude=44.375481, longitude=-68.1922996), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=171),
#   EBirdHotspot(location=EBirdLocation(id='L6032995', name='Acadia NP--Duck Brook Road', coord=Coordinate(latitude=44.3919424, longitude=-68.2302582), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=114),
#   EBirdHotspot(location=EBirdLocation(id='L476592', name='Acadia NP--Eagle Lake', coord=Coordinate(latitude=44.3766313, longitude=-68.2511902), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=154),
#   EBirdHotspot(location=EBirdLocation(id='L4998278', name='Acadia NP--East Pond', coord=Coordinate(latitude=44.3369255, longitude=-68.0492692), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=95),
#   EBirdHotspot(location=EBirdLocation(id='L1392934', name='Acadia NP--East Schoodic Drive ', coord=Coordinate(latitude=44.3625954, longitude=-68.0390396), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=134),
#   EBirdHotspot(location=EBirdLocation(id='L1481132', name='Acadia NP--Echo Lake', coord=Coordinate(latitude=44.3276176, longitude=-68.3375817), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=107),
#   EBirdHotspot(location=EBirdLocation(id='L1234492', name='Acadia NP--Echo Lake Beach', coord=Coordinate(latitude=44.314947, longitude=-68.3361143), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=85),
#   EBirdHotspot(location=EBirdLocation(id='L312591', name='Acadia NP--Fabbri Parking Lot', coord=Coordinate(latitude=44.3143854, longitude=-68.1954405), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=144),
#   EBirdHotspot(location=EBirdLocation(id='L15608513', name='Acadia NP--Flying Mountain', coord=Coordinate(latitude=44.3023735, longitude=-68.3142483), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=92),
#   EBirdHotspot(location=EBirdLocation(id='L6067006', name='Acadia NP--Frazer Creek Bike Trail', coord=Coordinate(latitude=44.3732469, longitude=-68.070074), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=96),
#   EBirdHotspot(location=EBirdLocation(id='L1538911', name='Acadia NP--Frazer Point', coord=Coordinate(latitude=44.3754377, longitude=-68.0752723), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=189),
#   EBirdHotspot(location=EBirdLocation(id='L20579607', name='Acadia NP--Giant Slide Trail, Lower Part', coord=Coordinate(latitude=44.3501842, longitude=-68.3019161), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=44),
#   EBirdHotspot(location=EBirdLocation(id='L476604', name='Acadia NP--Gorham Mountain', coord=Coordinate(latitude=44.328269, longitude=-68.1930828), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=129),
#   EBirdHotspot(location=EBirdLocation(id='L1019000', name='Acadia NP--Great Head', coord=Coordinate(latitude=44.3289251, longitude=-68.1741893), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=168),
#   EBirdHotspot(location=EBirdLocation(id='L1630801', name='Acadia NP--Great Meadow', coord=Coordinate(latitude=44.3669684, longitude=-68.2070087), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=169),
#   EBirdHotspot(location=EBirdLocation(id='L2347669', name='Acadia NP--Hadlock Pond Trail', coord=Coordinate(latitude=44.316429, longitude=-68.2879686), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=89),
#   EBirdHotspot(location=EBirdLocation(id='L6156638', name='Acadia NP--Hio Road Trail', coord=Coordinate(latitude=44.2537335, longitude=-68.3394481), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=89),
#   EBirdHotspot(location=EBirdLocation(id='L3768749', name='Acadia NP--Hunters Beach Trail', coord=Coordinate(latitude=44.2996791, longitude=-68.218108), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=81),
#   EBirdHotspot(location=EBirdLocation(id='L7657503', name='Acadia NP--Hunters Brook Trail', coord=Coordinate(latitude=44.3207778, longitude=-68.227458), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=85),
#   EBirdHotspot(location=EBirdLocation(id='L997153', name='Acadia NP--Hunters Head', coord=Coordinate(latitude=44.2984422, longitude=-68.2108198), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=96),
#   EBirdHotspot(location=EBirdLocation(id='L1218993', name='Acadia NP--Jesup Path', coord=Coordinate(latitude=44.3672499, longitude=-68.2112038), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=154),
#   EBirdHotspot(location=EBirdLocation(id='L476606', name='Acadia NP--Jordan Pond House', coord=Coordinate(latitude=44.3210234, longitude=-68.2540226), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=138),
#   EBirdHotspot(location=EBirdLocation(id='L6026515', name='Acadia NP--Jordan Pond Path', coord=Coordinate(latitude=44.3242409, longitude=-68.2499805), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=146),
#   EBirdHotspot(location=EBirdLocation(id='L16000289', name='Acadia NP--Lake Wood Pond', coord=Coordinate(latitude=44.4074188, longitude=-68.268528), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=62),
#   EBirdHotspot(location=EBirdLocation(id='L593916', name='Acadia NP--Long Pond Fire Road', coord=Coordinate(latitude=44.3287902, longitude=-68.3750504), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=102),
#   EBirdHotspot(location=EBirdLocation(id='L24923352', name='Acadia NP--Long Pond Pump Station', coord=Coordinate(latitude=44.3003567, longitude=-68.3494907), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=53),
#   EBirdHotspot(location=EBirdLocation(id='L12016825', name='Acadia NP--Long Pond Trail', coord=Coordinate(latitude=44.3080944, longitude=-68.3550911), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=75),
#   EBirdHotspot(location=EBirdLocation(id='L3763992', name='Acadia NP--Long Pond, North End', coord=Coordinate(latitude=44.3541919, longitude=-68.3634267), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=98),
#   EBirdHotspot(location=EBirdLocation(id='L1567772', name='Acadia NP--Lower Hadlock Pond', coord=Coordinate(latitude=44.3096931, longitude=-68.2903666), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=82),
#   EBirdHotspot(location=EBirdLocation(id='L3889325', name='Acadia NP--Lower Harbor Trail', coord=Coordinate(latitude=44.3841206, longitude=-68.0718599), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=89),
#   EBirdHotspot(location=EBirdLocation(id='L4628100', name='Acadia NP--Mansell Mountain Perpendicular Trail', coord=Coordinate(latitude=44.3036786, longitude=-68.357312), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=83),
#   EBirdHotspot(location=EBirdLocation(id='L9244598', name='Acadia NP--Maple Spring Trail', coord=Coordinate(latitude=44.333316, longitude=-68.281352), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=48),
#   EBirdHotspot(location=EBirdLocation(id='L160736', name='Acadia NP--Marshall Brook Fire Road', coord=Coordinate(latitude=44.2849207, longitude=-68.3442628), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=90),
#   EBirdHotspot(location=EBirdLocation(id='L3715481', name='Acadia NP--Mill Field Reservoir', coord=Coordinate(latitude=44.2970171, longitude=-68.3635826), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=48),
#   EBirdHotspot(location=EBirdLocation(id='L4753613', name='Acadia NP--Mountain Road', coord=Coordinate(latitude=44.3492636, longitude=-68.0586827), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=70),
#   EBirdHotspot(location=EBirdLocation(id='L6561463', name='Acadia NP--Ocean Drive', coord=Coordinate(latitude=44.3231322, longitude=-68.1873536), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=142),
#   EBirdHotspot(location=EBirdLocation(id='L591108', name='Acadia NP--Ocean Path', coord=Coordinate(latitude=44.3297579, longitude=-68.184886), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=154),
#   EBirdHotspot(location=EBirdLocation(id='L1269534', name='Acadia NP--Otter Cove Causeway', coord=Coordinate(latitude=44.3173389, longitude=-68.1996059), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=127),
#   EBirdHotspot(location=EBirdLocation(id='L3951706', name='Acadia NP--Otter Cove, Fish House Road', coord=Coordinate(latitude=44.3158344, longitude=-68.1976211), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=117),
#   EBirdHotspot(location=EBirdLocation(id='L781797', name='Acadia NP--Otter Point', coord=Coordinate(latitude=44.3072668, longitude=-68.1901217), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=206),
#   EBirdHotspot(location=EBirdLocation(id='L1292553', name='Acadia NP--Park Loop Road', coord=Coordinate(latitude=44.3469312, longitude=-68.1873322), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=152),
#   EBirdHotspot(location=EBirdLocation(id='L476599', name='Acadia NP--Parkman Mountain', coord=Coordinate(latitude=44.3378464, longitude=-68.285265), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=73),
#   EBirdHotspot(location=EBirdLocation(id='L6357852', name='Acadia NP--Pemetic Mountain', coord=Coordinate(latitude=44.3378835, longitude=-68.2445812), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=87),
#   EBirdHotspot(location=EBirdLocation(id='L4978722', name='Acadia NP--Penobscot Mountain', coord=Coordinate(latitude=44.3329687, longitude=-68.2666183), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=129),
#   EBirdHotspot(location=EBirdLocation(id='L476596', name='Acadia NP--Pork Chop Lane', coord=Coordinate(latitude=44.2523693, longitude=-68.3373106), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=60),
#   EBirdHotspot(location=EBirdLocation(id='L476591', name='Acadia NP--Precipice Trail', coord=Coordinate(latitude=44.3547872, longitude=-68.1897354), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=114),
#   EBirdHotspot(location=EBirdLocation(id='L1567758', name='Acadia NP--Precipice Trail Overlook', coord=Coordinate(latitude=44.3494526, longitude=-68.1878144), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=106),
#   EBirdHotspot(location=EBirdLocation(id='L1565236', name='Acadia NP--Pretty Marsh picnic area', coord=Coordinate(latitude=44.3334847, longitude=-68.4041781), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=122),
#   EBirdHotspot(location=EBirdLocation(id='L11593038', name='Acadia NP--Saint Sauveur Mountain', coord=Coordinate(latitude=44.3094113, longitude=-68.3220773), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=73),
#   EBirdHotspot(location=EBirdLocation(id='L486275', name='Acadia NP--Sand Beach', coord=Coordinate(latitude=44.3292206, longitude=-68.1822252), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=179),
#   EBirdHotspot(location=EBirdLocation(id='L1366782', name='Acadia NP--Sargent Mountain', coord=Coordinate(latitude=44.3481336, longitude=-68.2717656), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=107),
#   EBirdHotspot(location=EBirdLocation(id='L6068074', name='Acadia NP--Schoodic Bike Trail', coord=Coordinate(latitude=44.3572602, longitude=-68.047235), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=88),
#   EBirdHotspot(location=EBirdLocation(id='L3253010', name='Acadia NP--Schoodic Head', coord=Coordinate(latitude=44.3500922, longitude=-68.0540156), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=122),
#   EBirdHotspot(location=EBirdLocation(id='L7648269', name='Acadia NP--Schoodic Institute Campus', coord=Coordinate(latitude=44.3353649, longitude=-68.0611429), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=165),
#   EBirdHotspot(location=EBirdLocation(id='L8157493', name='Acadia NP--Schoodic Loop Road (Mount Desert Narrows)', coord=Coordinate(latitude=44.366956, longitude=-68.076409), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=137),
#   EBirdHotspot(location=EBirdLocation(id='L476611', name='Acadia NP--Schoodic Peninsula', coord=Coordinate(latitude=44.3403019, longitude=-68.0582428), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=237),
#   EBirdHotspot(location=EBirdLocation(id='L865421', name='Acadia NP--Schoodic Point', coord=Coordinate(latitude=44.3324746, longitude=-68.0603456), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=248),
#   EBirdHotspot(location=EBirdLocation(id='L4891126', name='Acadia NP--Schoodic Woods Campground Amphitheater', coord=Coordinate(latitude=44.3824591, longitude=-68.0677271), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=104),
#   EBirdHotspot(location=EBirdLocation(id='L1293907', name='Acadia NP--Schooner Head Overlook', coord=Coordinate(latitude=44.3396485, longitude=-68.1772259), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=147),
#   EBirdHotspot(location=EBirdLocation(id='L5854356', name='Acadia NP--Schooner Head Road Marsh', coord=Coordinate(latitude=44.3489122, longitude=-68.1854868), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=113),
#   EBirdHotspot(location=EBirdLocation(id='L4773029', name='Acadia NP--Seal Cove Pond', coord=Coordinate(latitude=44.2921527, longitude=-68.3929545), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=78),
#   EBirdHotspot(location=EBirdLocation(id='L611979', name='Acadia NP--Seawall Campground', coord=Coordinate(latitude=44.2433544, longitude=-68.3073664), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=163),
#   EBirdHotspot(location=EBirdLocation(id='L159047', name='Acadia NP--Seawall Picnic Area', coord=Coordinate(latitude=44.2373, longitude=-68.3025), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=211),
#   EBirdHotspot(location=EBirdLocation(id='L1273673', name='Acadia NP--Seawall Pond', coord=Coordinate(latitude=44.2426166, longitude=-68.299427), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=169),
#   EBirdHotspot(location=EBirdLocation(id='L159046', name='Acadia NP--Ship Harbor Trail', coord=Coordinate(latitude=44.2316668, longitude=-68.3256161), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=200),
#   EBirdHotspot(location=EBirdLocation(id='L517908', name='Acadia NP--Sieur de Monts Spring and Wild Gardens', coord=Coordinate(latitude=44.36181, longitude=-68.2079691), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=187),
#   EBirdHotspot(location=EBirdLocation(id='L3926734', name='Acadia NP--Sundew Trail', coord=Coordinate(latitude=44.3391048, longitude=-68.0674052), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=136),
#   EBirdHotspot(location=EBirdLocation(id='L8011989', name='Acadia NP--The Bowl', coord=Coordinate(latitude=44.3365559, longitude=-68.1932567), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=68),
#   EBirdHotspot(location=EBirdLocation(id='L3919411', name='Acadia NP--The Tarn', coord=Coordinate(latitude=44.3574672, longitude=-68.2063608), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=110),
#   EBirdHotspot(location=EBirdLocation(id='L1273677', name='Acadia NP--Thompson Island', coord=Coordinate(latitude=44.4267926, longitude=-68.3651733), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=177),
#   EBirdHotspot(location=EBirdLocation(id='L1436170', name='Acadia NP--Thunder Hole', coord=Coordinate(latitude=44.320651, longitude=-68.1887506), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=147),
#   EBirdHotspot(location=EBirdLocation(id='L1261286', name='Acadia NP--Upper Hadlock Pond', coord=Coordinate(latitude=44.321223, longitude=-68.2875824), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=70),
#   EBirdHotspot(location=EBirdLocation(id='L1760720', name='Acadia NP--Valley Cove', coord=Coordinate(latitude=44.3075112, longitude=-68.3174376), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=120),
#   EBirdHotspot(location=EBirdLocation(id='L476601', name='Acadia NP--Visitor Center', coord=Coordinate(latitude=44.4084752, longitude=-68.2463949), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=133),
#   EBirdHotspot(location=EBirdLocation(id='L1204297', name='Acadia NP--West Ledge Trail', coord=Coordinate(latitude=44.2921561, longitude=-68.3870116), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=68),
#   EBirdHotspot(location=EBirdLocation(id='L6145570', name='Acadia NP--West Pond', coord=Coordinate(latitude=44.34458, longitude=-68.069102), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=55),
#   EBirdHotspot(location=EBirdLocation(id='L1565318', name='Acadia NP--Western Mountain Road', coord=Coordinate(latitude=44.2833961, longitude=-68.3667183), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=86),
#   EBirdHotspot(location=EBirdLocation(id='L2932206', name='Acadia NP--Wildwood Stables', coord=Coordinate(latitude=44.3137617, longitude=-68.2369316), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=75),
#   EBirdHotspot(location=EBirdLocation(id='L1155999', name='Acadia NP--Witch Hole Pond Carriage Path Loop', coord=Coordinate(latitude=44.3990651, longitude=-68.2464695), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=154),
#   EBirdHotspot(location=EBirdLocation(id='L159029', name='Acadia NP--Wonderland Trail', coord=Coordinate(latitude=44.233752, longitude=-68.3198708), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=197),
#   EBirdHotspot(location=EBirdLocation(id='L743763', name='Acadia NP--Youngs Mountain', coord=Coordinate(latitude=44.3920276, longitude=-68.2660389), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=37),
#   EBirdHotspot(location=EBirdLocation(id='L24877172', name='Acadia Puffin Cruises (parking and dock area ONLY)', coord=Coordinate(latitude=44.474249, longitude=-67.887787), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-029', subnat2_name=None), all_time_species=86),
#   EBirdHotspot(location=EBirdLocation(id='L4034476', name='Acadian Cross Boat Landing', coord=Coordinate(latitude=47.3534836, longitude=-68.2726961), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-003', subnat2_name=None), all_time_species=133),
#   EBirdHotspot(location=EBirdLocation(id='L15954255', name='Adams Pond', coord=Coordinate(latitude=43.8923109, longitude=-69.6314044), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-015', subnat2_name=None), all_time_species=82),
#   EBirdHotspot(location=EBirdLocation(id='L457213', name='Addison Marsh and Flats (boat ramp)', coord=Coordinate(latitude=44.6174939, longitude=-67.7456826), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-029', subnat2_name=None), all_time_species=140),
#   EBirdHotspot(location=EBirdLocation(id='L2401005', name='Albert J. Sousa Preserve (SRLT)', coord=Coordinate(latitude=44.6901355, longitude=-69.4232941), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-027', subnat2_name=None), all_time_species=128),
#   EBirdHotspot(location=EBirdLocation(id='L7591085', name='Albion A. Raynes Marsh', coord=Coordinate(latitude=44.100258, longitude=-69.871779), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-023', subnat2_name=None), all_time_species=85),
#   EBirdHotspot(location=EBirdLocation(id='L4837428', name='Alder Stream Pond, Exeter Road, Corinna', coord=Coordinate(latitude=44.9257313, longitude=-69.2491543), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-019', subnat2_name=None), all_time_species=117),
#   EBirdHotspot(location=EBirdLocation(id='L20687990', name='Alder Stream Wilderness Preserve (NWT)', coord=Coordinate(latitude=45.117532, longitude=-69.045622), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=102),
#   EBirdHotspot(location=EBirdLocation(id='L16616637', name='Aldermere Farm Lily Pond Trail (MCHT)', coord=Coordinate(latitude=44.1914013, longitude=-69.06111), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-013', subnat2_name=None), all_time_species=94),
#   EBirdHotspot(location=EBirdLocation(id='L15266301', name='Alewive Woods Preserve', coord=Coordinate(latitude=43.4305618, longitude=-70.6216836), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-031', subnat2_name=None), all_time_species=78),
#   EBirdHotspot(location=EBirdLocation(id='L14268052', name='Alfond Center for Health', coord=Coordinate(latitude=44.3625, longitude=-69.7858361), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-011', subnat2_name=None), all_time_species=51),
#   EBirdHotspot(location=EBirdLocation(id='L4932259', name='Alfred Butler Memorial Trail', coord=Coordinate(latitude=44.2504372, longitude=-68.3427072), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=54),
#   EBirdHotspot(location=EBirdLocation(id='L5245159', name='Alfred Keith Wharf and Bayside Waterfront, Northport', coord=Coordinate(latitude=44.3809216, longitude=-68.9673936), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-027', subnat2_name=None), all_time_species=70),
#   EBirdHotspot(location=EBirdLocation(id='L5967071', name='Allagash (town area)', coord=Coordinate(latitude=47.0829416, longitude=-69.0418148), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-003', subnat2_name=None), all_time_species=83),
#   EBirdHotspot(location=EBirdLocation(id='L20471892', name='Allagash Wilderness Waterway--Chamberlain Lake', coord=Coordinate(latitude=46.2223274, longitude=-69.3027652), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=22),
#   EBirdHotspot(location=EBirdLocation(id='L19253840', name='Allagash Wilderness Waterway--Chisholm Brook Campsite', coord=Coordinate(latitude=46.5726392, longitude=-69.345746), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=63),
#   EBirdHotspot(location=EBirdLocation(id='L6172921', name='Allagash Wilderness Waterway--Churchill Dam', coord=Coordinate(latitude=46.4934881, longitude=-69.286952), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=80),
#   EBirdHotspot(location=EBirdLocation(id='L26426624', name='Allagash Wilderness Waterway--Eagle Lake', coord=Coordinate(latitude=46.338951, longitude=-69.36656), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=65),
#   EBirdHotspot(location=EBirdLocation(id='L2921011', name='Allagash Wilderness Waterway--Johns Bridge', coord=Coordinate(latitude=46.4155223, longitude=-69.3422531), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=62),
#   EBirdHotspot(location=EBirdLocation(id='L19252626', name='Allagash Wilderness Waterway--Johnson Pond', coord=Coordinate(latitude=46.3183191, longitude=-69.5805941), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=58),
#   EBirdHotspot(location=EBirdLocation(id='L17399608', name='Allagash Wilderness Waterway--Long Lake', coord=Coordinate(latitude=46.6516154, longitude=-69.3776934), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-003', subnat2_name=None), all_time_species=57),
#   EBirdHotspot(location=EBirdLocation(id='L26426487', name='Allagash Wilderness Waterway--Round Pond', coord=Coordinate(latitude=46.763972, longitude=-69.266673), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-003', subnat2_name=None), all_time_species=95),
#   EBirdHotspot(location=EBirdLocation(id='L20471917', name='Allagash Wilderness Waterway--Telos Lake', coord=Coordinate(latitude=46.1408934, longitude=-69.1825784), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=76),
#   EBirdHotspot(location=EBirdLocation(id='L17399559', name='Allagash Wilderness Waterway--Umsaskis Lake', coord=Coordinate(latitude=46.5975623, longitude=-69.3834686), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-003', subnat2_name=None), all_time_species=67),
#   EBirdHotspot(location=EBirdLocation(id='L47932975', name='Allen Island (restricted access)', coord=Coordinate(latitude=43.869049, longitude=-69.313134), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-013', subnat2_name=None), all_time_species=34),
#   EBirdHotspot(location=EBirdLocation(id='L15570638', name='Alna Post Office area', coord=Coordinate(latitude=44.1061723, longitude=-69.6041171), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-015', subnat2_name=None), all_time_species=113),
#   EBirdHotspot(location=EBirdLocation(id='L51015978', name='Alonzo Garcelon WMA , Cross Hill Rd', coord=Coordinate(latitude=44.372119, longitude=-69.661974), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-011', subnat2_name=None), all_time_species=51),
#   EBirdHotspot(location=EBirdLocation(id='L18918999', name='Amanda C. Rowe Elementary Trails', coord=Coordinate(latitude=43.6786426, longitude=-70.3168988), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-005', subnat2_name=None), all_time_species=52),
#   EBirdHotspot(location=EBirdLocation(id='L1099506', name='Ames Pond', coord=Coordinate(latitude=44.1594255, longitude=-68.648243), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=70),
#   EBirdHotspot(location=EBirdLocation(id='L2277173', name='Androscoggin Lake', coord=Coordinate(latitude=44.323234, longitude=-70.095005), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-011', subnat2_name=None), all_time_species=92),
#   EBirdHotspot(location=EBirdLocation(id='L4814433', name='Androscoggin Lake Boat Launch', coord=Coordinate(latitude=44.3528981, longitude=-70.0749086), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-011', subnat2_name=None), all_time_species=57),
#   EBirdHotspot(location=EBirdLocation(id='L1089483', name='Androscoggin River Bicycle Path', coord=Coordinate(latitude=43.9197129, longitude=-69.9505896), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-005', subnat2_name=None), all_time_species=93),
#   EBirdHotspot(location=EBirdLocation(id='L7735978', name='Androscoggin River, Bethel', coord=Coordinate(latitude=44.4181054, longitude=-70.8275017), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-017', subnat2_name=None), all_time_species=68),
#   EBirdHotspot(location=EBirdLocation(id='L3486354', name='Androscoggin Riverlands SP, Turner', coord=Coordinate(latitude=44.2611647, longitude=-70.1881313), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-001', subnat2_name=None), all_time_species=113),
#   EBirdHotspot(location=EBirdLocation(id='L4724790', name='Androscoggin Riverside Trail', coord=Coordinate(latitude=44.1077007, longitude=-70.2169222), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-001', subnat2_name=None), all_time_species=104),
#   EBirdHotspot(location=EBirdLocation(id='L16943906', name='Androscoggin Woods (BTLT)', coord=Coordinate(latitude=43.9857184, longitude=-70.0397721), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-023', subnat2_name=None), all_time_species=92),
#   EBirdHotspot(location=EBirdLocation(id='L53351789', name='Anna M. Tondreau Preserve', coord=Coordinate(latitude=43.8375295, longitude=-69.9124753), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-005', subnat2_name=None), all_time_species=16),
#   EBirdHotspot(location=EBirdLocation(id='L14591012', name='Annie Sturgis Sanctuary', coord=Coordinate(latitude=44.403235, longitude=-69.7094536), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-011', subnat2_name=None), all_time_species=72),
#   EBirdHotspot(location=EBirdLocation(id='L24982168', name='Anthoine Creek Slough', coord=Coordinate(latitude=43.632997, longitude=-70.258601), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-005', subnat2_name=None), all_time_species=45),
#   EBirdHotspot(location=EBirdLocation(id='L11855096', name='Appalachee Preserve (BRLT)', coord=Coordinate(latitude=43.8574922, longitude=-69.6092463), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-015', subnat2_name=None), all_time_species=70),
#   EBirdHotspot(location=EBirdLocation(id='L5879692', name='Appalachian Trail--Fly Rod Crosby Trail to Saddleback Mountain', coord=Coordinate(latitude=44.9264157, longitude=-70.5157042), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-007', subnat2_name=None), all_time_species=71),
#   EBirdHotspot(location=EBirdLocation(id='L5879655', name='Appalachian Trail--Piazza Rock to Fly Rod Crosby Trail', coord=Coordinate(latitude=44.9109478, longitude=-70.5249739), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-007', subnat2_name=None), all_time_species=33),
#   EBirdHotspot(location=EBirdLocation(id='L5879589', name='Appalachian Trail--Route 4 to Piazza Rock', coord=Coordinate(latitude=44.897087, longitude=-70.536046), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-007', subnat2_name=None), all_time_species=57),
#   EBirdHotspot(location=EBirdLocation(id='L3896821', name='Appalachian Trail--White Cap Mountain', coord=Coordinate(latitude=45.5545086, longitude=-69.245882), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=43),
#   EBirdHotspot(location=EBirdLocation(id='L5254221', name='Apple Ridge Parcel (SVLT)', coord=Coordinate(latitude=43.5335747, longitude=-70.5126518), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-031', subnat2_name=None), all_time_species=35),
#   EBirdHotspot(location=EBirdLocation(id='L35175811', name='Appleton Bog Preserve (TNC)', coord=Coordinate(latitude=44.329589, longitude=-69.2611599), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-013', subnat2_name=None), all_time_species=52),
#   EBirdHotspot(location=EBirdLocation(id='L7451935', name='Appleton Preserve (GRLT)', coord=Coordinate(latitude=44.3077784, longitude=-69.215781), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-013', subnat2_name=None), all_time_species=119),
#   EBirdHotspot(location=EBirdLocation(id='L6826450', name='Arey Cove Turnout', coord=Coordinate(latitude=44.336492, longitude=-68.0563813), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=94),
# ...
#   EBirdHotspot(location=EBirdLocation(id='L34718849', name='Robin Hollow Pond (RI)', coord=Coordinate(latitude=41.9189164, longitude=-71.3817553), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=68),
#   EBirdHotspot(location=EBirdLocation(id='L23449783', name='Rockland Cemetery', coord=Coordinate(latitude=41.7839211, longitude=-71.6751051), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=92),
#   EBirdHotspot(location=EBirdLocation(id='L22213549', name='Rocky Hill Conservation Area', coord=Coordinate(latitude=41.9465071, longitude=-71.527459), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=59),
#   EBirdHotspot(location=EBirdLocation(id='L38422558', name='Roger Williams National Memorial', coord=Coordinate(latitude=41.830073, longitude=-71.410568), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=28),
#   EBirdHotspot(location=EBirdLocation(id='L451783', name='Roger Williams Park', coord=Coordinate(latitude=41.781681, longitude=-71.4147806), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=167),
#   EBirdHotspot(location=EBirdLocation(id='L13227889', name='Round Top Management Area', coord=Coordinate(latitude=42.002181, longitude=-71.696561), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=70),
#   EBirdHotspot(location=EBirdLocation(id='L1325526', name='Sabin Point Park, East Providence', coord=Coordinate(latitude=41.7650588, longitude=-71.3690966), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=108),
#   EBirdHotspot(location=EBirdLocation(id='L17425289', name='Salter Grove North Jetty (Providence Co.)', coord=Coordinate(latitude=41.7586838, longitude=-71.3844226), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=44),
#   EBirdHotspot(location=EBirdLocation(id='L2526644', name='Save The Bay Center & Coastal Greenway', coord=Coordinate(latitude=41.7857568, longitude=-71.3817573), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=152),
#   EBirdHotspot(location=EBirdLocation(id='L4402357', name='Scituate Reservoir', coord=Coordinate(latitude=41.8358047, longitude=-71.5957975), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=72),
#   EBirdHotspot(location=EBirdLocation(id='L42686760', name='Scott Pond, Lincoln', coord=Coordinate(latitude=41.8980902, longitude=-71.4068879), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=16),
#   EBirdHotspot(location=EBirdLocation(id='L5397820', name='Seekonk River (please use more specific location if possible)', coord=Coordinate(latitude=41.8364969, longitude=-71.3743988), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=109),
#   EBirdHotspot(location=EBirdLocation(id='L41521101', name='Simmons Upper Reservoir, Johnston', coord=Coordinate(latitude=41.800645, longitude=-71.521177), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=63),
#   EBirdHotspot(location=EBirdLocation(id='L487742', name='Slater Park, Pawtucket', coord=Coordinate(latitude=41.868666, longitude=-71.3459444), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=134),
#   EBirdHotspot(location=EBirdLocation(id='L12289642', name='Snake Den Farm', coord=Coordinate(latitude=41.8444131, longitude=-71.5421457), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=180),
#   EBirdHotspot(location=EBirdLocation(id='L3997605', name='Snake Den State Park', coord=Coordinate(latitude=41.8354849, longitude=-71.5397501), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=170),
#   EBirdHotspot(location=EBirdLocation(id='L14173384', name='Snake Den State Park--Belfield Drive', coord=Coordinate(latitude=41.8362062, longitude=-71.5268898), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=82),
#   EBirdHotspot(location=EBirdLocation(id='L34718866', name='Sneech Pond, Cumberland', coord=Coordinate(latitude=41.981507, longitude=-71.451969), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=3),
#   EBirdHotspot(location=EBirdLocation(id='L2465689', name='Soucy Falls, Woonsocket', coord=Coordinate(latitude=42.0164127, longitude=-71.5067482), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=16),
#   EBirdHotspot(location=EBirdLocation(id='L49094895', name='Spencer West Property (Foster Land Trust)', coord=Coordinate(latitude=41.8183088, longitude=-71.75172), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=68),
#   EBirdHotspot(location=EBirdLocation(id='L3901801', name='Sprague Farm Town Forest (Glocester Land Trust)', coord=Coordinate(latitude=41.9029159, longitude=-71.7132139), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=118),
#   EBirdHotspot(location=EBirdLocation(id='L812502', name='Squantum Woods SP', coord=Coordinate(latitude=41.7928806, longitude=-71.3724232), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=119),
#   EBirdHotspot(location=EBirdLocation(id='L4343578', name="St. Ann's Cemetery, Cranston", coord=Coordinate(latitude=41.7909427, longitude=-71.4645999), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=130),
#   EBirdHotspot(location=EBirdLocation(id='L13935214', name='St. Francis Cemetery', coord=Coordinate(latitude=41.8638984, longitude=-71.4086965), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=36),
#   EBirdHotspot(location=EBirdLocation(id='L2913295', name='Steere Hill Conservation Area (Glocester Land Trust)', coord=Coordinate(latitude=41.8917675, longitude=-71.6142941), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=136),
#   EBirdHotspot(location=EBirdLocation(id='L4789272', name='Stillhouse Cove Park, Cranston', coord=Coordinate(latitude=41.7696052, longitude=-71.3896), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=75),
#   EBirdHotspot(location=EBirdLocation(id='L44468211', name='Stillwater Scenic Trail, Smithfield', coord=Coordinate(latitude=41.9071615, longitude=-71.53916), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=98),
#   EBirdHotspot(location=EBirdLocation(id='L12696120', name='Suckatunkanuc Hill', coord=Coordinate(latitude=41.815945, longitude=-71.504841), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=49),
#   EBirdHotspot(location=EBirdLocation(id='L124352', name='Swan Point Cemetery', coord=Coordinate(latitude=41.8557485, longitude=-71.3812176), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=222),
#   EBirdHotspot(location=EBirdLocation(id='L49057407', name='Tarkiln Road, Smithfield', coord=Coordinate(latitude=41.9142369, longitude=-71.5790024), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=30),
#   EBirdHotspot(location=EBirdLocation(id='L40384308', name='Ten Mile River Greenway--Dagget Ave. Trailhead to Armistice Blvd', coord=Coordinate(latitude=41.8824328, longitude=-71.3426111), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=27),
#   EBirdHotspot(location=EBirdLocation(id='L2599631', name='Ten Mile River Greenway--Ferris Ave. Trailhead to Slater Park', coord=Coordinate(latitude=41.8496377, longitude=-71.3443893), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=116),
#   EBirdHotspot(location=EBirdLocation(id='L5426087', name='Ten Mile River Reservation (Armistice Blvd. viewpoint)', coord=Coordinate(latitude=41.875147, longitude=-71.340459), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=112),
#   EBirdHotspot(location=EBirdLocation(id='L1458029', name='The Monastery, Cumberland', coord=Coordinate(latitude=41.9350531, longitude=-71.4075396), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=181),
#   EBirdHotspot(location=EBirdLocation(id='L17278333', name='The Tikkanen/Martin Property (Foster Land Trust)', coord=Coordinate(latitude=41.753441, longitude=-71.7871106), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=76),
#   EBirdHotspot(location=EBirdLocation(id='L21158678', name='Tom Woods Preserve (Foster Land Trust)', coord=Coordinate(latitude=41.8192403, longitude=-71.7881012), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=57),
#   EBirdHotspot(location=EBirdLocation(id='L15208246', name='Tower Hill Rd., Cumberland', coord=Coordinate(latitude=41.994098, longitude=-71.444035), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=60),
#   EBirdHotspot(location=EBirdLocation(id='L42665518', name='Town Line Swamp', coord=Coordinate(latitude=41.933718, longitude=-71.486849), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=25),
#   EBirdHotspot(location=EBirdLocation(id='L16657907', name='Townie Pride Memorial Park, East Providence', coord=Coordinate(latitude=41.808964, longitude=-71.385004), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=53),
#   EBirdHotspot(location=EBirdLocation(id='L12450396', name='Tucker Field, Cumberland', coord=Coordinate(latitude=41.9644865, longitude=-71.4426209), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=27),
#   EBirdHotspot(location=EBirdLocation(id='L41541061', name='Twin River Casino Retention Ponds, Lincoln', coord=Coordinate(latitude=41.88732, longitude=-71.444158), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=36),
#   EBirdHotspot(location=EBirdLocation(id='L8678323', name='Veterans Memorial Park, Pawtucket', coord=Coordinate(latitude=41.8794371, longitude=-71.3818826), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=47),
#   EBirdHotspot(location=EBirdLocation(id='L12545551', name='WWII Memorial State Park', coord=Coordinate(latitude=42.0096446, longitude=-71.5093249), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=22),
#   EBirdHotspot(location=EBirdLocation(id='L31745262', name='Walnut Hill Cemetery', coord=Coordinate(latitude=41.8811125, longitude=-71.3687754), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=44),
#   EBirdHotspot(location=EBirdLocation(id='L187164', name='Watchemoket Cove', coord=Coordinate(latitude=41.800495, longitude=-71.376686), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=137),
#   EBirdHotspot(location=EBirdLocation(id='L12799134', name='Waterman Reservoir', coord=Coordinate(latitude=41.8799557, longitude=-71.5805218), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=73),
#   EBirdHotspot(location=EBirdLocation(id='L13430824', name='Waterman St. Dog Park', coord=Coordinate(latitude=41.8277178, longitude=-71.3835141), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=73),
#   EBirdHotspot(location=EBirdLocation(id='L12073266', name='Willett Pond, East Providence', coord=Coordinate(latitude=41.775647, longitude=-71.356669), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=76),
#   EBirdHotspot(location=EBirdLocation(id='L47132166', name='Wolf Hill Preserve--Old Quarry Trails', coord=Coordinate(latitude=41.887409, longitude=-71.534424), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=22),
#   EBirdHotspot(location=EBirdLocation(id='L13057430', name='Wood Lake Park and Almy Reservoir', coord=Coordinate(latitude=41.8159533, longitude=-71.5271886), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=110),
#   EBirdHotspot(location=EBirdLocation(id='L31392271', name='Woonasquatucket River Greenway--Manton Pond Area to Merino Park', coord=Coordinate(latitude=41.8339789, longitude=-71.4724742), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=105),
#   EBirdHotspot(location=EBirdLocation(id='L28111910', name='Woonasquatucket River Greenway--Riverside Park to Merino Park', coord=Coordinate(latitude=41.8207141, longitude=-71.450412), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=55),
#   EBirdHotspot(location=EBirdLocation(id='L12545495', name='Woonsocket Public Library', coord=Coordinate(latitude=42.0051404, longitude=-71.5082279), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=20),
#   EBirdHotspot(location=EBirdLocation(id='L12136837', name='Woonsocket Reservoir #3', coord=Coordinate(latitude=41.9430759, longitude=-71.4980264), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=57),
#   EBirdHotspot(location=EBirdLocation(id='L13228976', name='stakeout Pine Grosbeak (Crabapple Tree)--885 S. Main St., Pascoag (2012-2013)', coord=Coordinate(latitude=41.938922, longitude=-71.682878), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=25),
#   EBirdHotspot(location=EBirdLocation(id='L12966956', name='stakeout Varied Thrush--Chepachet (2020-2021)', coord=Coordinate(latitude=41.9154969, longitude=-71.6022595), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=59)]}

# %%
# Find the species lists for the regions of interest
region_species_lists = {r: ebird_api.retrieve_species_list(c) for r, c in region_codes.items()}
for region, species_list in region_species_lists.items():
    print(f"{len(species_list)} species have been observed in region '{region}'.")
# Out:
# Bird species list for 'US-ME' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# 512 species have been observed in region 'Maine, United States'.
# 329 species have been observed in region 'Providence, Rhode Island, United States'.

# %%
# Compute distances (km) between each region and its recent hotspots
from collections import defaultdict

hotspot_distances_km: dict[str, dict[EBirdHotspot, float]] = defaultdict(dict)

for region, hotspots in recent_hotspots.items():
    region_coord = region_coords[region]
    for hotspot in hotspots:
        hotspot_distances_km[region][hotspot] = geodesic(region_coord, hotspot.location.coord).km

hotspot_distances_km = dict(hotspot_distances_km)
hotspot_distances_km
# Out:
# {'Maine, United States': {EBirdHotspot(location=EBirdLocation(id='L5867205', name='250th Anniversary Park', coord=Coordinate(latitude=43.9191617, longitude=-69.9653551), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-005', subnat2_name=None), all_time_species=78): 217.306057429487,
#   EBirdHotspot(location=EBirdLocation(id='L3028558', name='AMC Gorman Chairback Lodge', coord=Coordinate(latitude=45.4616766, longitude=-69.3166101), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=101): 45.071174496056585,
#   EBirdHotspot(location=EBirdLocation(id='L459957', name='Abagadassett River Mouth', coord=Coordinate(latitude=44.0096078, longitude=-69.8517609), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-023', subnat2_name=None), all_time_species=154): 204.509353286793,
#   EBirdHotspot(location=EBirdLocation(id='L3863342', name='Abagadassett Wild Rice Fields', coord=Coordinate(latitude=44.0017674, longitude=-69.8489285), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-023', subnat2_name=None), all_time_species=79): 205.2306963432307,
#   EBirdHotspot(location=EBirdLocation(id='L889345', name='Abandoned Rail Line, Rich Millpond', coord=Coordinate(latitude=43.7986806, longitude=-70.5766976), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-005', subnat2_name=None), all_time_species=91): 252.11617093327138,
#   EBirdHotspot(location=EBirdLocation(id='L731948', name='Abandoned Rail Line, Sebago Lake', coord=Coordinate(latitude=43.7833025, longitude=-70.5340022), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-005', subnat2_name=None), all_time_species=57): 251.7691441852051,
#   EBirdHotspot(location=EBirdLocation(id='L5078565', name='Abbott Park', coord=Coordinate(latitude=44.6658754, longitude=-70.1458704), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-007', subnat2_name=None), all_time_species=48): 153.8449716154381,
#   EBirdHotspot(location=EBirdLocation(id='L5111729', name='Abby Aldrich Rockefeller Gardens (limited access)', coord=Coordinate(latitude=44.299411, longitude=-68.2525782), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=54): 163.79328093933805,
#   EBirdHotspot(location=EBirdLocation(id='L2377923', name='Abel Cyr Road', coord=Coordinate(latitude=47.0866633, longitude=-68.0661392), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-003', subnat2_name=None), all_time_species=7): 164.82093154071345,
#   EBirdHotspot(location=EBirdLocation(id='L27736390', name='Abner Point Road (foot traffic only)', coord=Coordinate(latitude=43.729101, longitude=-70.001244), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-005', subnat2_name=None), all_time_species=58): 237.9072775679683,
#   EBirdHotspot(location=EBirdLocation(id='L11687154', name='Acadia Gateway Center Drive', coord=Coordinate(latitude=44.4696514, longitude=-68.3712919), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=44): 142.99445530179682,
#   EBirdHotspot(location=EBirdLocation(id='L340581', name='Acadia NP (please use more specific location if possible)', coord=Coordinate(latitude=44.3385984, longitude=-68.2733291), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=240): 159.14675941090493,
#   EBirdHotspot(location=EBirdLocation(id='L3893063', name='Acadia NP--Acadia Mountain Trail', coord=Coordinate(latitude=44.3214533, longitude=-68.3248758), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=100): 159.8551924389741,
#   EBirdHotspot(location=EBirdLocation(id='L3677751', name='Acadia NP--Alder Trail', coord=Coordinate(latitude=44.3443026, longitude=-68.0561185), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=132): 164.3404586572141,
#   EBirdHotspot(location=EBirdLocation(id='L25206158', name='Acadia NP--Anvil Trail', coord=Coordinate(latitude=44.3462065, longitude=-68.0505964), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=67): 164.31304567211237,
#   EBirdHotspot(location=EBirdLocation(id='L5060545', name="Acadia NP--Aunt Betty's Pond Carriage Path Loop", coord=Coordinate(latitude=44.3688395, longitude=-68.2719612), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=113): 155.96225520304685,
#   EBirdHotspot(location=EBirdLocation(id='L1481150', name='Acadia NP--Baker Island', coord=Coordinate(latitude=44.2414724, longitude=-68.1983643), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=106): 171.2204646731001,
#   EBirdHotspot(location=EBirdLocation(id='L476600', name='Acadia NP--Bald Peak', coord=Coordinate(latitude=44.3351452, longitude=-68.2838058), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=60): 159.27746430945115,
#   EBirdHotspot(location=EBirdLocation(id='L3027190', name='Acadia NP--Bar Island', coord=Coordinate(latitude=44.3985285, longitude=-68.2063437), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=146): 154.45371494403477,
#   EBirdHotspot(location=EBirdLocation(id='L1533556', name='Acadia NP--Bass Harbor Marsh', coord=Coordinate(latitude=44.2533766, longitude=-68.3407102), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=163): 166.86043031877261,
#   EBirdHotspot(location=EBirdLocation(id='L1567130', name='Acadia NP--Bear Brook Picnic Area', coord=Coordinate(latitude=44.3604813, longitude=-68.1987003), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=67): 158.64861979040836,
#   EBirdHotspot(location=EBirdLocation(id='L1595827', name='Acadia NP--Beaver Dam Pond', coord=Coordinate(latitude=44.3623836, longitude=-68.1951383), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=111): 158.54103723042027,
#   EBirdHotspot(location=EBirdLocation(id='L11168536', name='Acadia NP--Beech Mountain', coord=Coordinate(latitude=44.3104448, longitude=-68.3454215), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=85): 160.62078639066644,
#   EBirdHotspot(location=EBirdLocation(id='L997169', name='Acadia NP--Beech Mountain and Beech Cliff Trails', coord=Coordinate(latitude=44.3146368, longitude=-68.3434689), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=106): 160.2086630783298,
#   EBirdHotspot(location=EBirdLocation(id='L13237756', name='Acadia NP--Beehive Trail', coord=Coordinate(latitude=44.3319015, longitude=-68.186077), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=110): 161.97920872125667,
#   EBirdHotspot(location=EBirdLocation(id='L29136679', name='Acadia NP--Bernard Mountain', coord=Coordinate(latitude=44.301142, longitude=-68.3724189), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=28): 161.10217057063247,
#   EBirdHotspot(location=EBirdLocation(id='L476608', name='Acadia NP--Big Heath', coord=Coordinate(latitude=44.2364059, longitude=-68.3198547), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=97): 169.09696451924904,
#   EBirdHotspot(location=EBirdLocation(id='L212537', name='Acadia NP--Blackwoods Campground', coord=Coordinate(latitude=44.3096007, longitude=-68.2040691), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=149): 163.87360364391128,
#   EBirdHotspot(location=EBirdLocation(id='L1269544', name='Acadia NP--Blackwoods Campground Shore', coord=Coordinate(latitude=44.3065086, longitude=-68.2013869), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=125): 164.26676313005066,
#   EBirdHotspot(location=EBirdLocation(id='L2345007', name='Acadia NP--Blueberry Hill', coord=Coordinate(latitude=44.3386398, longitude=-68.0454782), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=166): 165.24607127940573,
#   EBirdHotspot(location=EBirdLocation(id='L3771762', name='Acadia NP--Breakneck Ponds', coord=Coordinate(latitude=44.3863961, longitude=-68.2543874), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=121): 154.51921924767035,
#   EBirdHotspot(location=EBirdLocation(id='L995718', name='Acadia NP--Breakneck Road', coord=Coordinate(latitude=44.4041211, longitude=-68.2542329), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=93): 152.64826611442533,
#   EBirdHotspot(location=EBirdLocation(id='L3919395', name='Acadia NP--Bubble Mountain Trails', coord=Coordinate(latitude=44.3425117, longitude=-68.2540226), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=104): 159.17925292661408,
#   EBirdHotspot(location=EBirdLocation(id='L3819273', name='Acadia NP--Bubble Pond', coord=Coordinate(latitude=44.3455195, longitude=-68.2402897), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=84): 159.1881485218029,
#   EBirdHotspot(location=EBirdLocation(id='L159030', name='Acadia NP--Cadillac Mountain', coord=Coordinate(latitude=44.3534831, longitude=-68.2260418), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=174): 158.69423877785334,
#   EBirdHotspot(location=EBirdLocation(id='L3982459', name='Acadia NP--Cadillac Mountain South Ridge Trail', coord=Coordinate(latitude=44.3437372, longitude=-68.229879), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=118): 159.62980744245203,
#   EBirdHotspot(location=EBirdLocation(id='L20068913', name='Acadia NP--Cadillac North Ridge Trail', coord=Coordinate(latitude=44.3775634, longitude=-68.2286766), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=89): 156.08685767014208,
#   EBirdHotspot(location=EBirdLocation(id='L4085683', name='Acadia NP--Champlain Mountain', coord=Coordinate(latitude=44.3508187, longitude=-68.194043), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=113): 159.78470496385663,
#   EBirdHotspot(location=EBirdLocation(id='L19977366', name='Acadia NP--Day Mountain', coord=Coordinate(latitude=44.3073639, longitude=-68.2319094), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=69): 163.43270235643786,
#   EBirdHotspot(location=EBirdLocation(id='L1958330', name='Acadia NP--Dorr Mountain', coord=Coordinate(latitude=44.3546645, longitude=-68.2149696), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=104): 158.84603284620204,
#   EBirdHotspot(location=EBirdLocation(id='L3724032', name='Acadia NP--Dorr Point and Compass Harbor', coord=Coordinate(latitude=44.375481, longitude=-68.1922996), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=171): 157.2404958470449,
#   EBirdHotspot(location=EBirdLocation(id='L6032995', name='Acadia NP--Duck Brook Road', coord=Coordinate(latitude=44.3919424, longitude=-68.2302582), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=114): 154.53097933616252,
#   EBirdHotspot(location=EBirdLocation(id='L476592', name='Acadia NP--Eagle Lake', coord=Coordinate(latitude=44.3766313, longitude=-68.2511902), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=154): 155.6303423055119,
#   EBirdHotspot(location=EBirdLocation(id='L4998278', name='Acadia NP--East Pond', coord=Coordinate(latitude=44.3369255, longitude=-68.0492692), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=95): 165.3064617338392,
#   EBirdHotspot(location=EBirdLocation(id='L1392934', name='Acadia NP--East Schoodic Drive ', coord=Coordinate(latitude=44.3625954, longitude=-68.0390396), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=134): 162.99116852352356,
#   EBirdHotspot(location=EBirdLocation(id='L1481132', name='Acadia NP--Echo Lake', coord=Coordinate(latitude=44.3276176, longitude=-68.3375817), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=107): 158.93204058911175,
#   EBirdHotspot(location=EBirdLocation(id='L1234492', name='Acadia NP--Echo Lake Beach', coord=Coordinate(latitude=44.314947, longitude=-68.3361143), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=85): 160.32334801693057,
#   EBirdHotspot(location=EBirdLocation(id='L312591', name='Acadia NP--Fabbri Parking Lot', coord=Coordinate(latitude=44.3143854, longitude=-68.1954405), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=144): 163.58462206547523,
#   EBirdHotspot(location=EBirdLocation(id='L15608513', name='Acadia NP--Flying Mountain', coord=Coordinate(latitude=44.3023735, longitude=-68.3142483), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=92): 162.12311383975683,
#   EBirdHotspot(location=EBirdLocation(id='L6067006', name='Acadia NP--Frazer Creek Bike Trail', coord=Coordinate(latitude=44.3732469, longitude=-68.070074), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=96): 160.94291602732045,
#   EBirdHotspot(location=EBirdLocation(id='L1538911', name='Acadia NP--Frazer Point', coord=Coordinate(latitude=44.3754377, longitude=-68.0752723), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=189): 160.56000663959762,
#   EBirdHotspot(location=EBirdLocation(id='L20579607', name='Acadia NP--Giant Slide Trail, Lower Part', coord=Coordinate(latitude=44.3501842, longitude=-68.3019161), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=44): 157.27020443825322,
#   EBirdHotspot(location=EBirdLocation(id='L476604', name='Acadia NP--Gorham Mountain', coord=Coordinate(latitude=44.328269, longitude=-68.1930828), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=129): 162.18166640890436,
#   EBirdHotspot(location=EBirdLocation(id='L1019000', name='Acadia NP--Great Head', coord=Coordinate(latitude=44.3289251, longitude=-68.1741893), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=168): 162.6007764480051,
#   EBirdHotspot(location=EBirdLocation(id='L1630801', name='Acadia NP--Great Meadow', coord=Coordinate(latitude=44.3669684, longitude=-68.2070087), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=169): 157.75249332860753,
#   EBirdHotspot(location=EBirdLocation(id='L2347669', name='Acadia NP--Hadlock Pond Trail', coord=Coordinate(latitude=44.316429, longitude=-68.2879686), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=89): 161.18236539648686,
#   EBirdHotspot(location=EBirdLocation(id='L6156638', name='Acadia NP--Hio Road Trail', coord=Coordinate(latitude=44.2537335, longitude=-68.3394481), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=89): 166.84636696032504,
#   EBirdHotspot(location=EBirdLocation(id='L3768749', name='Acadia NP--Hunters Beach Trail', coord=Coordinate(latitude=44.2996791, longitude=-68.218108), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=81): 164.57855154096575,
#   EBirdHotspot(location=EBirdLocation(id='L7657503', name='Acadia NP--Hunters Brook Trail', coord=Coordinate(latitude=44.3207778, longitude=-68.227458), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=85): 162.11827035427888,
#   EBirdHotspot(location=EBirdLocation(id='L997153', name='Acadia NP--Hunters Head', coord=Coordinate(latitude=44.2984422, longitude=-68.2108198), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=96): 164.886678801616,
#   EBirdHotspot(location=EBirdLocation(id='L1218993', name='Acadia NP--Jesup Path', coord=Coordinate(latitude=44.3672499, longitude=-68.2112038), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=154): 157.61553891937137,
#   EBirdHotspot(location=EBirdLocation(id='L476606', name='Acadia NP--Jordan Pond House', coord=Coordinate(latitude=44.3210234, longitude=-68.2540226), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=138): 161.4615653550853,
#   EBirdHotspot(location=EBirdLocation(id='L6026515', name='Acadia NP--Jordan Pond Path', coord=Coordinate(latitude=44.3242409, longitude=-68.2499805), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=146): 161.2142063479795,
#   EBirdHotspot(location=EBirdLocation(id='L16000289', name='Acadia NP--Lake Wood Pond', coord=Coordinate(latitude=44.4074188, longitude=-68.268528), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=62): 151.95138103647764,
#   EBirdHotspot(location=EBirdLocation(id='L593916', name='Acadia NP--Long Pond Fire Road', coord=Coordinate(latitude=44.3287902, longitude=-68.3750504), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=102): 158.0676229218879,
#   EBirdHotspot(location=EBirdLocation(id='L24923352', name='Acadia NP--Long Pond Pump Station', coord=Coordinate(latitude=44.3003567, longitude=-68.3494907), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=53): 161.62666895562776,
#   EBirdHotspot(location=EBirdLocation(id='L12016825', name='Acadia NP--Long Pond Trail', coord=Coordinate(latitude=44.3080944, longitude=-68.3550911), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=75): 160.68361737753364,
#   EBirdHotspot(location=EBirdLocation(id='L3763992', name='Acadia NP--Long Pond, North End', coord=Coordinate(latitude=44.3541919, longitude=-68.3634267), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=98): 155.5552793083693,
#   EBirdHotspot(location=EBirdLocation(id='L1567772', name='Acadia NP--Lower Hadlock Pond', coord=Coordinate(latitude=44.3096931, longitude=-68.2903666), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=82): 161.8494746077319,
#   EBirdHotspot(location=EBirdLocation(id='L3889325', name='Acadia NP--Lower Harbor Trail', coord=Coordinate(latitude=44.3841206, longitude=-68.0718599), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=89): 159.77215024103623,
#   EBirdHotspot(location=EBirdLocation(id='L4628100', name='Acadia NP--Mansell Mountain Perpendicular Trail', coord=Coordinate(latitude=44.3036786, longitude=-68.357312), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=83): 161.11641381091567,
#   EBirdHotspot(location=EBirdLocation(id='L9244598', name='Acadia NP--Maple Spring Trail', coord=Coordinate(latitude=44.333316, longitude=-68.281352), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=48): 159.52760911507767,
#   EBirdHotspot(location=EBirdLocation(id='L160736', name='Acadia NP--Marshall Brook Fire Road', coord=Coordinate(latitude=44.2849207, longitude=-68.3442628), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=90): 163.3918288460243,
#   EBirdHotspot(location=EBirdLocation(id='L3715481', name='Acadia NP--Mill Field Reservoir', coord=Coordinate(latitude=44.2970171, longitude=-68.3635826), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=48): 161.71452783117945,
#   EBirdHotspot(location=EBirdLocation(id='L4753613', name='Acadia NP--Mountain Road', coord=Coordinate(latitude=44.3492636, longitude=-68.0586827), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=70): 163.75286520963724,
#   EBirdHotspot(location=EBirdLocation(id='L6561463', name='Acadia NP--Ocean Drive', coord=Coordinate(latitude=44.3231322, longitude=-68.1873536), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=142): 162.86880681967835,
#   EBirdHotspot(location=EBirdLocation(id='L591108', name='Acadia NP--Ocean Path', coord=Coordinate(latitude=44.3297579, longitude=-68.184886), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=154): 162.2353257729212,
#   EBirdHotspot(location=EBirdLocation(id='L1269534', name='Acadia NP--Otter Cove Causeway', coord=Coordinate(latitude=44.3173389, longitude=-68.1996059), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=127): 163.16839369548197,
#   EBirdHotspot(location=EBirdLocation(id='L3951706', name='Acadia NP--Otter Cove, Fish House Road', coord=Coordinate(latitude=44.3158344, longitude=-68.1976211), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=117): 163.37693800625775,
#   EBirdHotspot(location=EBirdLocation(id='L781797', name='Acadia NP--Otter Point', coord=Coordinate(latitude=44.3072668, longitude=-68.1901217), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=206): 164.46924692083823,
#   EBirdHotspot(location=EBirdLocation(id='L1292553', name='Acadia NP--Park Loop Road', coord=Coordinate(latitude=44.3469312, longitude=-68.1873322), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=152): 160.36718389811867,
#   EBirdHotspot(location=EBirdLocation(id='L476599', name='Acadia NP--Parkman Mountain', coord=Coordinate(latitude=44.3378464, longitude=-68.285265), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=73): 158.9566984603777,
#   EBirdHotspot(location=EBirdLocation(id='L6357852', name='Acadia NP--Pemetic Mountain', coord=Coordinate(latitude=44.3378835, longitude=-68.2445812), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=87): 159.89431271860263,
#   EBirdHotspot(location=EBirdLocation(id='L4978722', name='Acadia NP--Penobscot Mountain', coord=Coordinate(latitude=44.3329687, longitude=-68.2666183), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=129): 159.8998041114163,
#   EBirdHotspot(location=EBirdLocation(id='L476596', name='Acadia NP--Pork Chop Lane', coord=Coordinate(latitude=44.2523693, longitude=-68.3373106), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=60): 167.03487524695188,
#   EBirdHotspot(location=EBirdLocation(id='L476591', name='Acadia NP--Precipice Trail', coord=Coordinate(latitude=44.3547872, longitude=-68.1897354), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=114): 159.4795104576704,
#   EBirdHotspot(location=EBirdLocation(id='L1567758', name='Acadia NP--Precipice Trail Overlook', coord=Coordinate(latitude=44.3494526, longitude=-68.1878144), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=106): 160.08979987853112,
#   EBirdHotspot(location=EBirdLocation(id='L1565236', name='Acadia NP--Pretty Marsh picnic area', coord=Coordinate(latitude=44.3334847, longitude=-68.4041781), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=122): 157.0211734536554,
#   EBirdHotspot(location=EBirdLocation(id='L11593038', name='Acadia NP--Saint Sauveur Mountain', coord=Coordinate(latitude=44.3094113, longitude=-68.3220773), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=73): 161.2053376646981,
#   EBirdHotspot(location=EBirdLocation(id='L486275', name='Acadia NP--Sand Beach', coord=Coordinate(latitude=44.3292206, longitude=-68.1822252), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=179): 162.36059137406792,
#   EBirdHotspot(location=EBirdLocation(id='L1366782', name='Acadia NP--Sargent Mountain', coord=Coordinate(latitude=44.3481336, longitude=-68.2717656), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=107): 158.1679573638279,
#   EBirdHotspot(location=EBirdLocation(id='L6068074', name='Acadia NP--Schoodic Bike Trail', coord=Coordinate(latitude=44.3572602, longitude=-68.047235), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=88): 163.28274870655324,
#   EBirdHotspot(location=EBirdLocation(id='L3253010', name='Acadia NP--Schoodic Head', coord=Coordinate(latitude=44.3500922, longitude=-68.0540156), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=122): 163.8097834003919,
#   EBirdHotspot(location=EBirdLocation(id='L7648269', name='Acadia NP--Schoodic Institute Campus', coord=Coordinate(latitude=44.3353649, longitude=-68.0611429), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=165): 165.1081464519992,
#   EBirdHotspot(location=EBirdLocation(id='L8157493', name='Acadia NP--Schoodic Loop Road (Mount Desert Narrows)', coord=Coordinate(latitude=44.366956, longitude=-68.076409), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=137): 161.39790222288312,
#   EBirdHotspot(location=EBirdLocation(id='L476611', name='Acadia NP--Schoodic Peninsula', coord=Coordinate(latitude=44.3403019, longitude=-68.0582428), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=237): 164.6874479073175,
#   EBirdHotspot(location=EBirdLocation(id='L865421', name='Acadia NP--Schoodic Point', coord=Coordinate(latitude=44.3324746, longitude=-68.0603456), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=248): 165.42964526435802,
#   EBirdHotspot(location=EBirdLocation(id='L4891126', name='Acadia NP--Schoodic Woods Campground Amphitheater', coord=Coordinate(latitude=44.3824591, longitude=-68.0677271), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=104): 160.06916548401279,
#   EBirdHotspot(location=EBirdLocation(id='L1293907', name='Acadia NP--Schooner Head Overlook', coord=Coordinate(latitude=44.3396485, longitude=-68.1772259), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=147): 161.3957722478938,
#   EBirdHotspot(location=EBirdLocation(id='L5854356', name='Acadia NP--Schooner Head Road Marsh', coord=Coordinate(latitude=44.3489122, longitude=-68.1854868), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=113): 160.20722691154722,
#   EBirdHotspot(location=EBirdLocation(id='L4773029', name='Acadia NP--Seal Cove Pond', coord=Coordinate(latitude=44.2921527, longitude=-68.3929545), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=78): 161.6976287262045,
#   EBirdHotspot(location=EBirdLocation(id='L611979', name='Acadia NP--Seawall Campground', coord=Coordinate(latitude=44.2433544, longitude=-68.3073664), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=163): 168.60064869204965,
#   EBirdHotspot(location=EBirdLocation(id='L159047', name='Acadia NP--Seawall Picnic Area', coord=Coordinate(latitude=44.2373, longitude=-68.3025), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=211): 169.35035918976686,
#   EBirdHotspot(location=EBirdLocation(id='L1273673', name='Acadia NP--Seawall Pond', coord=Coordinate(latitude=44.2426166, longitude=-68.299427), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=169): 168.8425297149341,
#   EBirdHotspot(location=EBirdLocation(id='L159046', name='Acadia NP--Ship Harbor Trail', coord=Coordinate(latitude=44.2316668, longitude=-68.3256161), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=200): 169.49373509342826,
#   EBirdHotspot(location=EBirdLocation(id='L517908', name='Acadia NP--Sieur de Monts Spring and Wild Gardens', coord=Coordinate(latitude=44.36181, longitude=-68.2079691), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=187): 158.27075497317122,
#   EBirdHotspot(location=EBirdLocation(id='L3926734', name='Acadia NP--Sundew Trail', coord=Coordinate(latitude=44.3391048, longitude=-68.0674052), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=136): 164.5354516115345,
#   EBirdHotspot(location=EBirdLocation(id='L8011989', name='Acadia NP--The Bowl', coord=Coordinate(latitude=44.3365559, longitude=-68.1932567), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=68): 161.3049930598309,
#   EBirdHotspot(location=EBirdLocation(id='L3919411', name='Acadia NP--The Tarn', coord=Coordinate(latitude=44.3574672, longitude=-68.2063608), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=110): 158.76896946401618,
#   EBirdHotspot(location=EBirdLocation(id='L1273677', name='Acadia NP--Thompson Island', coord=Coordinate(latitude=44.4267926, longitude=-68.3651733), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=177): 147.71743099539924,
#   EBirdHotspot(location=EBirdLocation(id='L1436170', name='Acadia NP--Thunder Hole', coord=Coordinate(latitude=44.320651, longitude=-68.1887506), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=147): 163.09423329957636,
#   EBirdHotspot(location=EBirdLocation(id='L1261286', name='Acadia NP--Upper Hadlock Pond', coord=Coordinate(latitude=44.321223, longitude=-68.2875824), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=70): 160.67893708240445,
#   EBirdHotspot(location=EBirdLocation(id='L1760720', name='Acadia NP--Valley Cove', coord=Coordinate(latitude=44.3075112, longitude=-68.3174376), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=120): 161.50554721336502,
#   EBirdHotspot(location=EBirdLocation(id='L476601', name='Acadia NP--Visitor Center', coord=Coordinate(latitude=44.4084752, longitude=-68.2463949), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=133): 152.38245245922772,
#   EBirdHotspot(location=EBirdLocation(id='L1204297', name='Acadia NP--West Ledge Trail', coord=Coordinate(latitude=44.2921561, longitude=-68.3870116), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=68): 161.80436982937104,
#   EBirdHotspot(location=EBirdLocation(id='L6145570', name='Acadia NP--West Pond', coord=Coordinate(latitude=44.34458, longitude=-68.069102), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=55): 163.92070662923683,
#   EBirdHotspot(location=EBirdLocation(id='L1565318', name='Acadia NP--Western Mountain Road', coord=Coordinate(latitude=44.2833961, longitude=-68.3667183), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=86): 163.1257525921569,
#   EBirdHotspot(location=EBirdLocation(id='L2932206', name='Acadia NP--Wildwood Stables', coord=Coordinate(latitude=44.3137617, longitude=-68.2369316), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=75): 162.63461730733894,
#   EBirdHotspot(location=EBirdLocation(id='L1155999', name='Acadia NP--Witch Hole Pond Carriage Path Loop', coord=Coordinate(latitude=44.3990651, longitude=-68.2464695), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=154): 153.3740369763891,
#   EBirdHotspot(location=EBirdLocation(id='L159029', name='Acadia NP--Wonderland Trail', coord=Coordinate(latitude=44.233752, longitude=-68.3198708), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=197): 169.38231873680306,
#   EBirdHotspot(location=EBirdLocation(id='L743763', name='Acadia NP--Youngs Mountain', coord=Coordinate(latitude=44.3920276, longitude=-68.2660389), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=37): 153.64182274584658,
#   EBirdHotspot(location=EBirdLocation(id='L24877172', name='Acadia Puffin Cruises (parking and dock area ONLY)', coord=Coordinate(latitude=44.474249, longitude=-67.887787), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-029', subnat2_name=None), all_time_species=86): 157.09080444530545,
#   EBirdHotspot(location=EBirdLocation(id='L4034476', name='Acadian Cross Boat Landing', coord=Coordinate(latitude=47.3534836, longitude=-68.2726961), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-003', subnat2_name=None), all_time_species=133): 188.24443336355824,
#   EBirdHotspot(location=EBirdLocation(id='L15954255', name='Adams Pond', coord=Coordinate(latitude=43.8923109, longitude=-69.6314044), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-015', subnat2_name=None), all_time_species=82): 210.93860117593073,
#   EBirdHotspot(location=EBirdLocation(id='L457213', name='Addison Marsh and Flats (boat ramp)', coord=Coordinate(latitude=44.6174939, longitude=-67.7456826), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-029', subnat2_name=None), all_time_species=140): 149.59425300249256,
#   EBirdHotspot(location=EBirdLocation(id='L2401005', name='Albert J. Sousa Preserve (SRLT)', coord=Coordinate(latitude=44.6901355, longitude=-69.4232941), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-027', subnat2_name=None), all_time_species=128): 121.61199000630288,
#   EBirdHotspot(location=EBirdLocation(id='L7591085', name='Albion A. Raynes Marsh', coord=Coordinate(latitude=44.100258, longitude=-69.871779), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-023', subnat2_name=None), all_time_species=85): 195.86162596759428,
#   EBirdHotspot(location=EBirdLocation(id='L4837428', name='Alder Stream Pond, Exeter Road, Corinna', coord=Coordinate(latitude=44.9257313, longitude=-69.2491543), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-019', subnat2_name=None), all_time_species=117): 92.27922788059013,
#   EBirdHotspot(location=EBirdLocation(id='L20687990', name='Alder Stream Wilderness Preserve (NWT)', coord=Coordinate(latitude=45.117532, longitude=-69.045622), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=102): 67.34943483107416,
#   EBirdHotspot(location=EBirdLocation(id='L16616637', name='Aldermere Farm Lily Pond Trail (MCHT)', coord=Coordinate(latitude=44.1914013, longitude=-69.06111), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-013', subnat2_name=None), all_time_species=94): 169.4148722166643,
#   EBirdHotspot(location=EBirdLocation(id='L15266301', name='Alewive Woods Preserve', coord=Coordinate(latitude=43.4305618, longitude=-70.6216836), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-031', subnat2_name=None), all_time_species=78): 289.31506696553316,
#   EBirdHotspot(location=EBirdLocation(id='L14268052', name='Alfond Center for Health', coord=Coordinate(latitude=44.3625, longitude=-69.7858361), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-011', subnat2_name=None), all_time_species=51): 166.51667127837638,
#   EBirdHotspot(location=EBirdLocation(id='L4932259', name='Alfred Butler Memorial Trail', coord=Coordinate(latitude=44.2504372, longitude=-68.3427072), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=54): 167.13892672770467,
#   EBirdHotspot(location=EBirdLocation(id='L5245159', name='Alfred Keith Wharf and Bayside Waterfront, Northport', coord=Coordinate(latitude=44.3809216, longitude=-68.9673936), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-027', subnat2_name=None), all_time_species=70): 147.8503598702139,
#   EBirdHotspot(location=EBirdLocation(id='L5967071', name='Allagash (town area)', coord=Coordinate(latitude=47.0829416, longitude=-69.0418148), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-003', subnat2_name=None), all_time_species=83): 153.3608569092308,
#   EBirdHotspot(location=EBirdLocation(id='L20471892', name='Allagash Wilderness Waterway--Chamberlain Lake', coord=Coordinate(latitude=46.2223274, longitude=-69.3027652), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=22): 66.61250747211723,
#   EBirdHotspot(location=EBirdLocation(id='L19253840', name='Allagash Wilderness Waterway--Chisholm Brook Campsite', coord=Coordinate(latitude=46.5726392, longitude=-69.345746), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=63): 103.0901035189389,
#   EBirdHotspot(location=EBirdLocation(id='L6172921', name='Allagash Wilderness Waterway--Churchill Dam', coord=Coordinate(latitude=46.4934881, longitude=-69.286952), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=80): 93.2548090756964,
#   EBirdHotspot(location=EBirdLocation(id='L26426624', name='Allagash Wilderness Waterway--Eagle Lake', coord=Coordinate(latitude=46.338951, longitude=-69.36656), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=65): 80.28469542216743,
#   EBirdHotspot(location=EBirdLocation(id='L2921011', name='Allagash Wilderness Waterway--Johns Bridge', coord=Coordinate(latitude=46.4155223, longitude=-69.3422531), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=62): 86.96857398579813,
#   EBirdHotspot(location=EBirdLocation(id='L19252626', name='Allagash Wilderness Waterway--Johnson Pond', coord=Coordinate(latitude=46.3183191, longitude=-69.5805941), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=58): 87.79564575687826,
#   EBirdHotspot(location=EBirdLocation(id='L17399608', name='Allagash Wilderness Waterway--Long Lake', coord=Coordinate(latitude=46.6516154, longitude=-69.3776934), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-003', subnat2_name=None), all_time_species=57): 112.15810652304636,
#   EBirdHotspot(location=EBirdLocation(id='L26426487', name='Allagash Wilderness Waterway--Round Pond', coord=Coordinate(latitude=46.763972, longitude=-69.266673), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-003', subnat2_name=None), all_time_species=95): 121.39786015789241,
#   EBirdHotspot(location=EBirdLocation(id='L20471917', name='Allagash Wilderness Waterway--Telos Lake', coord=Coordinate(latitude=46.1408934, longitude=-69.1825784), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-021', subnat2_name=None), all_time_species=76): 54.160107978036336,
#   EBirdHotspot(location=EBirdLocation(id='L17399559', name='Allagash Wilderness Waterway--Umsaskis Lake', coord=Coordinate(latitude=46.5975623, longitude=-69.3834686), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-003', subnat2_name=None), all_time_species=67): 106.742985059584,
#   EBirdHotspot(location=EBirdLocation(id='L47932975', name='Allen Island (restricted access)', coord=Coordinate(latitude=43.869049, longitude=-69.313134), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-013', subnat2_name=None), all_time_species=34): 207.61299454481107,
#   EBirdHotspot(location=EBirdLocation(id='L15570638', name='Alna Post Office area', coord=Coordinate(latitude=44.1061723, longitude=-69.6041171), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-015', subnat2_name=None), all_time_species=113): 187.5977470648422,
#   EBirdHotspot(location=EBirdLocation(id='L51015978', name='Alonzo Garcelon WMA , Cross Hill Rd', coord=Coordinate(latitude=44.372119, longitude=-69.661974), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-011', subnat2_name=None), all_time_species=51): 161.4878664934496,
#   EBirdHotspot(location=EBirdLocation(id='L18918999', name='Amanda C. Rowe Elementary Trails', coord=Coordinate(latitude=43.6786426, longitude=-70.3168988), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-005', subnat2_name=None), all_time_species=52): 253.49495316393262,
#   EBirdHotspot(location=EBirdLocation(id='L1099506', name='Ames Pond', coord=Coordinate(latitude=44.1594255, longitude=-68.648243), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-009', subnat2_name=None), all_time_species=70): 173.01741623986965,
#   EBirdHotspot(location=EBirdLocation(id='L2277173', name='Androscoggin Lake', coord=Coordinate(latitude=44.323234, longitude=-70.095005), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-011', subnat2_name=None), all_time_species=92): 182.23630605824857,
#   EBirdHotspot(location=EBirdLocation(id='L4814433', name='Androscoggin Lake Boat Launch', coord=Coordinate(latitude=44.3528981, longitude=-70.0749086), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-011', subnat2_name=None), all_time_species=57): 178.59130236409055,
#   EBirdHotspot(location=EBirdLocation(id='L1089483', name='Androscoggin River Bicycle Path', coord=Coordinate(latitude=43.9197129, longitude=-69.9505896), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-005', subnat2_name=None), all_time_species=93): 216.78215780708993,
#   EBirdHotspot(location=EBirdLocation(id='L7735978', name='Androscoggin River, Bethel', coord=Coordinate(latitude=44.4181054, longitude=-70.8275017), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-017', subnat2_name=None), all_time_species=68): 211.2232779752499,
#   EBirdHotspot(location=EBirdLocation(id='L3486354', name='Androscoggin Riverlands SP, Turner', coord=Coordinate(latitude=44.2611647, longitude=-70.1881313), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-001', subnat2_name=None), all_time_species=113): 192.0355372915653,
#   EBirdHotspot(location=EBirdLocation(id='L4724790', name='Androscoggin Riverside Trail', coord=Coordinate(latitude=44.1077007, longitude=-70.2169222), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-001', subnat2_name=None), all_time_species=104): 207.76753520109764,
#   EBirdHotspot(location=EBirdLocation(id='L16943906', name='Androscoggin Woods (BTLT)', coord=Coordinate(latitude=43.9857184, longitude=-70.0397721), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-023', subnat2_name=None), all_time_species=92): 213.0477519977383,
#   EBirdHotspot(location=EBirdLocation(id='L53351789', name='Anna M. Tondreau Preserve', coord=Coordinate(latitude=43.8375295, longitude=-69.9124753), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-005', subnat2_name=None), all_time_species=16): 224.07084688343372,
#   EBirdHotspot(location=EBirdLocation(id='L14591012', name='Annie Sturgis Sanctuary', coord=Coordinate(latitude=44.403235, longitude=-69.7094536), country_code='US', subnat1_code='US-ME', subnat1_name=None, subnat2_code='US-ME-011', subnat2_name=None), all_time_species=72): 159.8363636881482,
# ...
#   EBirdHotspot(location=EBirdLocation(id='L451783', name='Roger Williams Park', coord=Coordinate(latitude=41.781681, longitude=-71.4147806), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=167): 4.70192063997253,
#   EBirdHotspot(location=EBirdLocation(id='L13227889', name='Round Top Management Area', coord=Coordinate(latitude=42.002181, longitude=-71.696561), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=70): 30.753942648996542,
#   EBirdHotspot(location=EBirdLocation(id='L1325526', name='Sabin Point Park, East Providence', coord=Coordinate(latitude=41.7650588, longitude=-71.3690966), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=108): 7.4871376368836,
#   EBirdHotspot(location=EBirdLocation(id='L17425289', name='Salter Grove North Jetty (Providence Co.)', coord=Coordinate(latitude=41.7586838, longitude=-71.3844226), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=44): 7.62817996971519,
#   EBirdHotspot(location=EBirdLocation(id='L2526644', name='Save The Bay Center & Coastal Greenway', coord=Coordinate(latitude=41.7857568, longitude=-71.3817573), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=152): 4.9701222521207695,
#   EBirdHotspot(location=EBirdLocation(id='L4402357', name='Scituate Reservoir', coord=Coordinate(latitude=41.8358047, longitude=-71.5957975), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=72): 15.25549452320619,
#   EBirdHotspot(location=EBirdLocation(id='L42686760', name='Scott Pond, Lincoln', coord=Coordinate(latitude=41.8980902, longitude=-71.4068879), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=16): 8.245248531839184,
#   EBirdHotspot(location=EBirdLocation(id='L5397820', name='Seekonk River (please use more specific location if possible)', coord=Coordinate(latitude=41.8364969, longitude=-71.3743988), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=109): 3.482003166787353,
#   EBirdHotspot(location=EBirdLocation(id='L41521101', name='Simmons Upper Reservoir, Johnston', coord=Coordinate(latitude=41.800645, longitude=-71.521177), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=63): 9.368541831503475,
#   EBirdHotspot(location=EBirdLocation(id='L487742', name='Slater Park, Pawtucket', coord=Coordinate(latitude=41.868666, longitude=-71.3459444), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=134): 7.4487818869516325,
#   EBirdHotspot(location=EBirdLocation(id='L12289642', name='Snake Den Farm', coord=Coordinate(latitude=41.8444131, longitude=-71.5421457), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=180): 10.978245138439993,
#   EBirdHotspot(location=EBirdLocation(id='L3997605', name='Snake Den State Park', coord=Coordinate(latitude=41.8354849, longitude=-71.5397501), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=170): 10.620089273949516,
#   EBirdHotspot(location=EBirdLocation(id='L14173384', name='Snake Den State Park--Belfield Drive', coord=Coordinate(latitude=41.8362062, longitude=-71.5268898), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=82): 9.571356907747303,
#   EBirdHotspot(location=EBirdLocation(id='L34718866', name='Sneech Pond, Cumberland', coord=Coordinate(latitude=41.981507, longitude=-71.451969), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=3): 17.794533565738693,
#   EBirdHotspot(location=EBirdLocation(id='L2465689', name='Soucy Falls, Woonsocket', coord=Coordinate(latitude=42.0164127, longitude=-71.5067482), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=16): 22.748407855116714,
#   EBirdHotspot(location=EBirdLocation(id='L49094895', name='Spencer West Property (Foster Land Trust)', coord=Coordinate(latitude=41.8183088, longitude=-71.75172), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=68): 28.162472010312065,
#   EBirdHotspot(location=EBirdLocation(id='L3901801', name='Sprague Farm Town Forest (Glocester Land Trust)', coord=Coordinate(latitude=41.9029159, longitude=-71.7132139), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=118): 26.43565613593375,
#   EBirdHotspot(location=EBirdLocation(id='L812502', name='Squantum Woods SP', coord=Coordinate(latitude=41.7928806, longitude=-71.3724232), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=119): 4.818234553752285,
#   EBirdHotspot(location=EBirdLocation(id='L4343578', name="St. Ann's Cemetery, Cranston", coord=Coordinate(latitude=41.7909427, longitude=-71.4645999), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=130): 5.654822359999345,
#   EBirdHotspot(location=EBirdLocation(id='L13935214', name='St. Francis Cemetery', coord=Coordinate(latitude=41.8638984, longitude=-71.4086965), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=36): 4.446037437090628,
#   EBirdHotspot(location=EBirdLocation(id='L2913295', name='Steere Hill Conservation Area (Glocester Land Trust)', coord=Coordinate(latitude=41.8917675, longitude=-71.6142941), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=136): 18.344086743923718,
#   EBirdHotspot(location=EBirdLocation(id='L4789272', name='Stillhouse Cove Park, Cranston', coord=Coordinate(latitude=41.7696052, longitude=-71.3896), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=75): 6.341557437570764,
#   EBirdHotspot(location=EBirdLocation(id='L44468211', name='Stillwater Scenic Trail, Smithfield', coord=Coordinate(latitude=41.9071615, longitude=-71.53916), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=98): 13.976506307217992,
#   EBirdHotspot(location=EBirdLocation(id='L12696120', name='Suckatunkanuc Hill', coord=Coordinate(latitude=41.815945, longitude=-71.504841), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=49): 7.696309720097527,
#   EBirdHotspot(location=EBirdLocation(id='L124352', name='Swan Point Cemetery', coord=Coordinate(latitude=41.8557485, longitude=-71.3812176), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=222): 4.397660461828325,
#   EBirdHotspot(location=EBirdLocation(id='L49057407', name='Tarkiln Road, Smithfield', coord=Coordinate(latitude=41.9142369, longitude=-71.5790024), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=30): 17.05254558962231,
#   EBirdHotspot(location=EBirdLocation(id='L40384308', name='Ten Mile River Greenway--Dagget Ave. Trailhead to Armistice Blvd', coord=Coordinate(latitude=41.8824328, longitude=-71.3426111), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=27): 8.725997579016278,
#   EBirdHotspot(location=EBirdLocation(id='L2599631', name='Ten Mile River Greenway--Ferris Ave. Trailhead to Slater Park', coord=Coordinate(latitude=41.8496377, longitude=-71.3443893), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=116): 6.359005815664193,
#   EBirdHotspot(location=EBirdLocation(id='L5426087', name='Ten Mile River Reservation (Armistice Blvd. viewpoint)', coord=Coordinate(latitude=41.875147, longitude=-71.340459), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=112): 8.271159088693237,
#   EBirdHotspot(location=EBirdLocation(id='L1458029', name='The Monastery, Cumberland', coord=Coordinate(latitude=41.9350531, longitude=-71.4075396), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=181): 12.343809924902796,
#   EBirdHotspot(location=EBirdLocation(id='L17278333', name='The Tikkanen/Martin Property (Foster Land Trust)', coord=Coordinate(latitude=41.753441, longitude=-71.7871106), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=76): 32.08299347511099,
#   EBirdHotspot(location=EBirdLocation(id='L21158678', name='Tom Woods Preserve (Foster Land Trust)', coord=Coordinate(latitude=41.8192403, longitude=-71.7881012), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=57): 31.18226872686836,
#   EBirdHotspot(location=EBirdLocation(id='L15208246', name='Tower Hill Rd., Cumberland', coord=Coordinate(latitude=41.994098, longitude=-71.444035), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=60): 19.070764780249405,
#   EBirdHotspot(location=EBirdLocation(id='L42665518', name='Town Line Swamp', coord=Coordinate(latitude=41.933718, longitude=-71.486849), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=25): 13.64866114264039,
#   EBirdHotspot(location=EBirdLocation(id='L16657907', name='Townie Pride Memorial Park, East Providence', coord=Coordinate(latitude=41.808964, longitude=-71.385004), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=53): 2.8516808533644866,
#   EBirdHotspot(location=EBirdLocation(id='L12450396', name='Tucker Field, Cumberland', coord=Coordinate(latitude=41.9644865, longitude=-71.4426209), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=27): 15.799786836911785,
#   EBirdHotspot(location=EBirdLocation(id='L41541061', name='Twin River Casino Retention Ponds, Lincoln', coord=Coordinate(latitude=41.88732, longitude=-71.444158), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=36): 7.499688893206584,
#   EBirdHotspot(location=EBirdLocation(id='L8678323', name='Veterans Memorial Park, Pawtucket', coord=Coordinate(latitude=41.8794371, longitude=-71.3818826), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=47): 6.67347535125285,
#   EBirdHotspot(location=EBirdLocation(id='L12545551', name='WWII Memorial State Park', coord=Coordinate(latitude=42.0096446, longitude=-71.5093249), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=22): 22.120211570643605,
#   EBirdHotspot(location=EBirdLocation(id='L31745262', name='Walnut Hill Cemetery', coord=Coordinate(latitude=41.8811125, longitude=-71.3687754), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=44): 7.324053639022361,
#   EBirdHotspot(location=EBirdLocation(id='L187164', name='Watchemoket Cove', coord=Coordinate(latitude=41.800495, longitude=-71.376686), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=137): 3.9788965594169676,
#   EBirdHotspot(location=EBirdLocation(id='L12799134', name='Waterman Reservoir', coord=Coordinate(latitude=41.8799557, longitude=-71.5805218), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=73): 15.249666869743484,
#   EBirdHotspot(location=EBirdLocation(id='L13430824', name='Waterman St. Dog Park', coord=Coordinate(latitude=41.8277178, longitude=-71.3835141), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=73): 2.4707695270133923,
#   EBirdHotspot(location=EBirdLocation(id='L12073266', name='Willett Pond, East Providence', coord=Coordinate(latitude=41.775647, longitude=-71.356669), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=76): 7.114696741899128,
#   EBirdHotspot(location=EBirdLocation(id='L47132166', name='Wolf Hill Preserve--Old Quarry Trails', coord=Coordinate(latitude=41.887409, longitude=-71.534424), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=22): 12.310923826540225,
#   EBirdHotspot(location=EBirdLocation(id='L13057430', name='Wood Lake Park and Almy Reservoir', coord=Coordinate(latitude=41.8159533, longitude=-71.5271886), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=110): 9.542828820357997,
#   EBirdHotspot(location=EBirdLocation(id='L31392271', name='Woonasquatucket River Greenway--Manton Pond Area to Merino Park', coord=Coordinate(latitude=41.8339789, longitude=-71.4724742), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=105): 5.077145672039652,
#   EBirdHotspot(location=EBirdLocation(id='L28111910', name='Woonasquatucket River Greenway--Riverside Park to Merino Park', coord=Coordinate(latitude=41.8207141, longitude=-71.450412), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=55): 3.143105099938091,
#   EBirdHotspot(location=EBirdLocation(id='L12545495', name='Woonsocket Public Library', coord=Coordinate(latitude=42.0051404, longitude=-71.5082279), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=20): 21.621204762742668,
#   EBirdHotspot(location=EBirdLocation(id='L12136837', name='Woonsocket Reservoir #3', coord=Coordinate(latitude=41.9430759, longitude=-71.4980264), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=57): 14.998539168158368,
#   EBirdHotspot(location=EBirdLocation(id='L13228976', name='stakeout Pine Grosbeak (Crabapple Tree)--885 S. Main St., Pascoag (2012-2013)', coord=Coordinate(latitude=41.938922, longitude=-71.682878), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=25): 25.795072675973376,
#   EBirdHotspot(location=EBirdLocation(id='L12966956', name='stakeout Varied Thrush--Chepachet (2020-2021)', coord=Coordinate(latitude=41.9154969, longitude=-71.6022595), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=59): 18.7245843953069}}

# %%
# Find taxonomy entries for the species in the regions of interest
region_to_species_taxons = {r: ebird_api.find_species_in_region(c) for r, c in region_codes.items()}
region_to_species_taxons
# Out:
# Bird species list for 'US-ME' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# {'Maine, United States': [EBirdSpecies(common_name='Black-bellied Whistling-Duck', specific_name='autumnalis', generic_name='Dendrocygna', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='bbwduc'),
#   EBirdSpecies(common_name='Snow Goose', specific_name='caerulescens', generic_name='Anser', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='snogoo'),
#   EBirdSpecies(common_name="Ross's Goose", specific_name='rossii', generic_name='Anser', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='rosgoo'),
#   EBirdSpecies(common_name="Snow x Ross's Goose (hybrid)", specific_name='caerulescens x rossii', generic_name='Anser', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='sxrgoo1'),
#   EBirdSpecies(common_name='Graylag Goose', specific_name='anser', generic_name='Anser', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='gragoo'),
#   EBirdSpecies(common_name='Swan Goose', specific_name='cygnoides', generic_name='Anser', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='swagoo1'),
#   EBirdSpecies(common_name='Greater White-fronted Goose', specific_name='albifrons', generic_name='Anser', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='gwfgoo'),
#   EBirdSpecies(common_name='Pink-footed Goose', specific_name='brachyrhynchus', generic_name='Anser', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='pifgoo'),
#   EBirdSpecies(common_name='Brant', specific_name='bernicla', generic_name='Branta', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='brant'),
#   EBirdSpecies(common_name='Barnacle Goose', specific_name='leucopsis', generic_name='Branta', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='bargoo'),
#   EBirdSpecies(common_name='Cackling Goose', specific_name='hutchinsii', generic_name='Branta', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='cacgoo1'),
#   EBirdSpecies(common_name='Canada Goose', specific_name='canadensis', generic_name='Branta', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='cangoo'),
#   EBirdSpecies(common_name='Swan x Canada Goose (hybrid)', specific_name='cygnoides x Branta canadensis', generic_name='Anser', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='swagoo3'),
#   EBirdSpecies(common_name='Greater White-fronted x Canada Goose (hybrid)', specific_name='albifrons x Branta canadensis', generic_name='Anser', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='x00415'),
#   EBirdSpecies(common_name='Domestic goose sp. x Canada Goose (hybrid)', specific_name='sp. (Domestic type) x Branta canadensis', generic_name='Anser', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='x00759'),
#   EBirdSpecies(common_name='Mute Swan', specific_name='olor', generic_name='Cygnus', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='mutswa'),
#   EBirdSpecies(common_name='Black Swan', specific_name='atratus', generic_name='Cygnus', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='blkswa'),
#   EBirdSpecies(common_name='Trumpeter Swan', specific_name='buccinator', generic_name='Cygnus', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='truswa'),
#   EBirdSpecies(common_name='Tundra Swan', specific_name='columbianus', generic_name='Cygnus', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='tunswa'),
#   EBirdSpecies(common_name='Whooper Swan', specific_name='cygnus', generic_name='Cygnus', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='whoswa'),
#   EBirdSpecies(common_name='Egyptian Goose', specific_name='aegyptiaca', generic_name='Alopochen', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='egygoo'),
#   EBirdSpecies(common_name='Common Shelduck', specific_name='tadorna', generic_name='Tadorna', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='comshe'),
#   EBirdSpecies(common_name='Muscovy Duck', specific_name='moschata', generic_name='Cairina', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='musduc'),
#   EBirdSpecies(common_name='Wood Duck', specific_name='sponsa', generic_name='Aix', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='wooduc'),
#   EBirdSpecies(common_name='Mandarin Duck', specific_name='galericulata', generic_name='Aix', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='manduc'),
#   EBirdSpecies(common_name='Garganey', specific_name='querquedula', generic_name='Spatula', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='gargan'),
#   EBirdSpecies(common_name='Blue-winged Teal', specific_name='discors', generic_name='Spatula', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='buwtea'),
#   EBirdSpecies(common_name='Northern Shoveler', specific_name='clypeata', generic_name='Spatula', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='norsho'),
#   EBirdSpecies(common_name='Gadwall', specific_name='strepera', generic_name='Mareca', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='gadwal'),
#   EBirdSpecies(common_name='Eurasian Wigeon', specific_name='penelope', generic_name='Mareca', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='eurwig'),
#   EBirdSpecies(common_name='American Wigeon', specific_name='americana', generic_name='Mareca', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='amewig'),
#   EBirdSpecies(common_name='Mallard', specific_name='platyrhynchos', generic_name='Anas', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='mallar3'),
#   EBirdSpecies(common_name='Muscovy Duck x Mallard (hybrid)', specific_name='moschata x Anas platyrhynchos', generic_name='Cairina', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='mdxmal1'),
#   EBirdSpecies(common_name='American Wigeon x Mallard (hybrid)', specific_name='americana x Anas platyrhynchos', generic_name='Mareca', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='x00611'),
#   EBirdSpecies(common_name='American Black Duck', specific_name='rubripes', generic_name='Anas', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='ambduc'),
#   EBirdSpecies(common_name='Mallard x American Black Duck (hybrid)', specific_name='platyrhynchos x rubripes', generic_name='Anas', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='x00004'),
#   EBirdSpecies(common_name='Northern Pintail', specific_name='acuta', generic_name='Anas', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='norpin'),
#   EBirdSpecies(common_name='Mallard x Northern Pintail (hybrid)', specific_name='platyrhynchos x acuta', generic_name='Anas', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='x00628'),
#   EBirdSpecies(common_name='Green-winged Teal', specific_name='crecca', generic_name='Anas', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='gnwtea'),
#   EBirdSpecies(common_name='Northern Pintail x Green-winged Teal (hybrid)', specific_name='acuta x crecca', generic_name='Anas', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='x00725'),
#   EBirdSpecies(common_name='Canvasback', specific_name='valisineria', generic_name='Aythya', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='canvas'),
#   EBirdSpecies(common_name='Redhead', specific_name='americana', generic_name='Aythya', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='redhea'),
#   EBirdSpecies(common_name='Ring-necked Duck', specific_name='collaris', generic_name='Aythya', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='rinduc'),
#   EBirdSpecies(common_name='Redhead x Ring-necked Duck (hybrid)', specific_name='americana x collaris', generic_name='Aythya', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='x00679'),
#   EBirdSpecies(common_name='Tufted Duck', specific_name='fuligula', generic_name='Aythya', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='tufduc'),
#   EBirdSpecies(common_name='Greater Scaup', specific_name='marila', generic_name='Aythya', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='gresca'),
#   EBirdSpecies(common_name='Lesser Scaup', specific_name='affinis', generic_name='Aythya', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='lessca'),
#   EBirdSpecies(common_name='King Eider', specific_name='spectabilis', generic_name='Somateria', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='kineid'),
#   EBirdSpecies(common_name='Common Eider', specific_name='mollissima', generic_name='Somateria', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='comeid'),
#   EBirdSpecies(common_name='King x Common Eider (hybrid)', specific_name='spectabilis x mollissima', generic_name='Somateria', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='x00665'),
#   EBirdSpecies(common_name='Harlequin Duck', specific_name='histrionicus', generic_name='Histrionicus', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='harduc'),
#   EBirdSpecies(common_name='Surf Scoter', specific_name='perspicillata', generic_name='Melanitta', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='sursco'),
#   EBirdSpecies(common_name='White-winged Scoter', specific_name='deglandi', generic_name='Melanitta', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='whwsco2'),
#   EBirdSpecies(common_name='Black Scoter', specific_name='americana', generic_name='Melanitta', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='blksco2'),
#   EBirdSpecies(common_name='Long-tailed Duck', specific_name='hyemalis', generic_name='Clangula', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='lotduc'),
#   EBirdSpecies(common_name='Bufflehead', specific_name='albeola', generic_name='Bucephala', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='buffle'),
#   EBirdSpecies(common_name='Common Goldeneye', specific_name='clangula', generic_name='Bucephala', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='comgol'),
#   EBirdSpecies(common_name="Barrow's Goldeneye", specific_name='islandica', generic_name='Bucephala', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='bargol'),
#   EBirdSpecies(common_name="Common x Barrow's Goldeneye (hybrid)", specific_name='clangula x islandica', generic_name='Bucephala', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='cxbgol1'),
#   EBirdSpecies(common_name='Hooded Merganser', specific_name='cucullatus', generic_name='Lophodytes', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='hoomer'),
#   EBirdSpecies(common_name='Common Goldeneye x Hooded Merganser (hybrid)', specific_name='clangula x Lophodytes cucullatus', generic_name='Bucephala', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='x00425'),
#   EBirdSpecies(common_name='Common Merganser', specific_name='merganser', generic_name='Mergus', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='commer'),
#   EBirdSpecies(common_name='Red-breasted Merganser', specific_name='serrator', generic_name='Mergus', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='rebmer'),
#   EBirdSpecies(common_name='Ruddy Duck', specific_name='jamaicensis', generic_name='Oxyura', family_common_name='Ducks, Geese, and Waterfowl', family='Anatidae', order='Anseriformes', ebird_species_code='rudduc'),
#   EBirdSpecies(common_name='Helmeted Guineafowl', specific_name='meleagris', generic_name='Numida', family_common_name='Guineafowl', family='Numididae', order='Galliformes', ebird_species_code='helgui'),
#   EBirdSpecies(common_name='Northern Bobwhite', specific_name='virginianus', generic_name='Colinus', family_common_name='New World Quail', family='Odontophoridae', order='Galliformes', ebird_species_code='norbob'),
#   EBirdSpecies(common_name='Wild Turkey', specific_name='gallopavo', generic_name='Meleagris', family_common_name='Pheasants, Grouse, and Allies', family='Phasianidae', order='Galliformes', ebird_species_code='wiltur'),
#   EBirdSpecies(common_name='Ruffed Grouse', specific_name='umbellus', generic_name='Bonasa', family_common_name='Pheasants, Grouse, and Allies', family='Phasianidae', order='Galliformes', ebird_species_code='rufgro'),
#   EBirdSpecies(common_name='Willow Ptarmigan', specific_name='lagopus', generic_name='Lagopus', family_common_name='Pheasants, Grouse, and Allies', family='Phasianidae', order='Galliformes', ebird_species_code='wilpta'),
#   EBirdSpecies(common_name='Spruce Grouse', specific_name='canadensis', generic_name='Canachites', family_common_name='Pheasants, Grouse, and Allies', family='Phasianidae', order='Galliformes', ebird_species_code='sprgro'),
#   EBirdSpecies(common_name='Ring-necked Pheasant', specific_name='colchicus', generic_name='Phasianus', family_common_name='Pheasants, Grouse, and Allies', family='Phasianidae', order='Galliformes', ebird_species_code='rinphe1'),
#   EBirdSpecies(common_name='Indian Peafowl', specific_name='cristatus', generic_name='Pavo', family_common_name='Pheasants, Grouse, and Allies', family='Phasianidae', order='Galliformes', ebird_species_code='compea'),
#   EBirdSpecies(common_name='Red Junglefowl', specific_name='gallus', generic_name='Gallus', family_common_name='Pheasants, Grouse, and Allies', family='Phasianidae', order='Galliformes', ebird_species_code='redjun'),
#   EBirdSpecies(common_name='Chukar', specific_name='chukar', generic_name='Alectoris', family_common_name='Pheasants, Grouse, and Allies', family='Phasianidae', order='Galliformes', ebird_species_code='chukar'),
#   EBirdSpecies(common_name='Rock Pigeon', specific_name='livia', generic_name='Columba', family_common_name='Pigeons and Doves', family='Columbidae', order='Columbiformes', ebird_species_code='rocpig'),
#   EBirdSpecies(common_name='Band-tailed Pigeon', specific_name='fasciata', generic_name='Patagioenas', family_common_name='Pigeons and Doves', family='Columbidae', order='Columbiformes', ebird_species_code='batpig1'),
#   EBirdSpecies(common_name='Eurasian Collared-Dove', specific_name='decaocto', generic_name='Streptopelia', family_common_name='Pigeons and Doves', family='Columbidae', order='Columbiformes', ebird_species_code='eucdov'),
#   EBirdSpecies(common_name='African Collared-Dove', specific_name='roseogrisea', generic_name='Streptopelia', family_common_name='Pigeons and Doves', family='Columbidae', order='Columbiformes', ebird_species_code='afcdov1'),
#   EBirdSpecies(common_name='White-winged Dove', specific_name='asiatica', generic_name='Zenaida', family_common_name='Pigeons and Doves', family='Columbidae', order='Columbiformes', ebird_species_code='whwdov'),
#   EBirdSpecies(common_name='Mourning Dove', specific_name='macroura', generic_name='Zenaida', family_common_name='Pigeons and Doves', family='Columbidae', order='Columbiformes', ebird_species_code='moudov'),
#   EBirdSpecies(common_name='Yellow-billed Cuckoo', specific_name='americanus', generic_name='Coccyzus', family_common_name='Cuckoos', family='Cuculidae', order='Cuculiformes', ebird_species_code='yebcuc'),
#   EBirdSpecies(common_name='Black-billed Cuckoo', specific_name='erythropthalmus', generic_name='Coccyzus', family_common_name='Cuckoos', family='Cuculidae', order='Cuculiformes', ebird_species_code='bkbcuc'),
#   EBirdSpecies(common_name='Common Nighthawk', specific_name='minor', generic_name='Chordeiles', family_common_name='Nightjars and Allies', family='Caprimulgidae', order='Caprimulgiformes', ebird_species_code='comnig'),
#   EBirdSpecies(common_name="Chuck-will's-widow", specific_name='carolinensis', generic_name='Antrostomus', family_common_name='Nightjars and Allies', family='Caprimulgidae', order='Caprimulgiformes', ebird_species_code='chwwid'),
#   EBirdSpecies(common_name='Eastern Whip-poor-will', specific_name='vociferus', generic_name='Antrostomus', family_common_name='Nightjars and Allies', family='Caprimulgidae', order='Caprimulgiformes', ebird_species_code='easwpw1'),
#   EBirdSpecies(common_name='Chimney Swift', specific_name='pelagica', generic_name='Chaetura', family_common_name='Swifts', family='Apodidae', order='Apodiformes', ebird_species_code='chiswi'),
#   EBirdSpecies(common_name='Mexican Violetear', specific_name='thalassinus', generic_name='Colibri', family_common_name='Hummingbirds', family='Trochilidae', order='Apodiformes', ebird_species_code='grnvie1'),
#   EBirdSpecies(common_name='Ruby-throated Hummingbird', specific_name='colubris', generic_name='Archilochus', family_common_name='Hummingbirds', family='Trochilidae', order='Apodiformes', ebird_species_code='rthhum'),
#   EBirdSpecies(common_name='Calliope Hummingbird', specific_name='calliope', generic_name='Selasphorus', family_common_name='Hummingbirds', family='Trochilidae', order='Apodiformes', ebird_species_code='calhum'),
#   EBirdSpecies(common_name='Rufous Hummingbird', specific_name='rufus', generic_name='Selasphorus', family_common_name='Hummingbirds', family='Trochilidae', order='Apodiformes', ebird_species_code='rufhum'),
#   EBirdSpecies(common_name='Broad-tailed Hummingbird', specific_name='platycercus', generic_name='Selasphorus', family_common_name='Hummingbirds', family='Trochilidae', order='Apodiformes', ebird_species_code='brthum'),
#   EBirdSpecies(common_name='King Rail', specific_name='elegans', generic_name='Rallus', family_common_name='Rails, Gallinules, and Coots', family='Rallidae', order='Gruiformes', ebird_species_code='kinrai4'),
#   EBirdSpecies(common_name='Clapper Rail', specific_name='crepitans', generic_name='Rallus', family_common_name='Rails, Gallinules, and Coots', family='Rallidae', order='Gruiformes', ebird_species_code='clarai11'),
#   EBirdSpecies(common_name='Virginia Rail', specific_name='limicola', generic_name='Rallus', family_common_name='Rails, Gallinules, and Coots', family='Rallidae', order='Gruiformes', ebird_species_code='virrai'),
#   EBirdSpecies(common_name='Corn Crake', specific_name='crex', generic_name='Crex', family_common_name='Rails, Gallinules, and Coots', family='Rallidae', order='Gruiformes', ebird_species_code='corcra'),
#   EBirdSpecies(common_name='Sora', specific_name='carolina', generic_name='Porzana', family_common_name='Rails, Gallinules, and Coots', family='Rallidae', order='Gruiformes', ebird_species_code='sora'),
#   EBirdSpecies(common_name='Common Gallinule', specific_name='galeata', generic_name='Gallinula', family_common_name='Rails, Gallinules, and Coots', family='Rallidae', order='Gruiformes', ebird_species_code='comgal1'),
#   EBirdSpecies(common_name='American Coot', specific_name='americana', generic_name='Fulica', family_common_name='Rails, Gallinules, and Coots', family='Rallidae', order='Gruiformes', ebird_species_code='y00475'),
#   EBirdSpecies(common_name='Purple Gallinule', specific_name='martinica', generic_name='Porphyrio', family_common_name='Rails, Gallinules, and Coots', family='Rallidae', order='Gruiformes', ebird_species_code='purgal2'),
#   EBirdSpecies(common_name='Yellow Rail', specific_name='noveboracensis', generic_name='Coturnicops', family_common_name='Rails, Gallinules, and Coots', family='Rallidae', order='Gruiformes', ebird_species_code='yelrai'),
#   EBirdSpecies(common_name='Sandhill Crane', specific_name='canadensis', generic_name='Antigone', family_common_name='Cranes', family='Gruidae', order='Gruiformes', ebird_species_code='sancra'),
#   EBirdSpecies(common_name='Black-necked Stilt', specific_name='mexicanus', generic_name='Himantopus', family_common_name='Stilts and Avocets', family='Recurvirostridae', order='Charadriiformes', ebird_species_code='bknsti'),
#   EBirdSpecies(common_name='American Avocet', specific_name='americana', generic_name='Recurvirostra', family_common_name='Stilts and Avocets', family='Recurvirostridae', order='Charadriiformes', ebird_species_code='ameavo'),
#   EBirdSpecies(common_name='American Oystercatcher', specific_name='palliatus', generic_name='Haematopus', family_common_name='Oystercatchers', family='Haematopodidae', order='Charadriiformes', ebird_species_code='ameoys'),
#   EBirdSpecies(common_name='Black-bellied Plover', specific_name='squatarola', generic_name='Pluvialis', family_common_name='Plovers and Lapwings', family='Charadriidae', order='Charadriiformes', ebird_species_code='bkbplo'),
#   EBirdSpecies(common_name='European Golden-Plover', specific_name='apricaria', generic_name='Pluvialis', family_common_name='Plovers and Lapwings', family='Charadriidae', order='Charadriiformes', ebird_species_code='eugplo'),
#   EBirdSpecies(common_name='American Golden-Plover', specific_name='dominica', generic_name='Pluvialis', family_common_name='Plovers and Lapwings', family='Charadriidae', order='Charadriiformes', ebird_species_code='amgplo'),
#   EBirdSpecies(common_name='Pacific Golden-Plover', specific_name='fulva', generic_name='Pluvialis', family_common_name='Plovers and Lapwings', family='Charadriidae', order='Charadriiformes', ebird_species_code='pagplo'),
#   EBirdSpecies(common_name='Killdeer', specific_name='vociferus', generic_name='Charadrius', family_common_name='Plovers and Lapwings', family='Charadriidae', order='Charadriiformes', ebird_species_code='killde'),
#   EBirdSpecies(common_name='Common Ringed Plover', specific_name='hiaticula', generic_name='Charadrius', family_common_name='Plovers and Lapwings', family='Charadriidae', order='Charadriiformes', ebird_species_code='corplo'),
#   EBirdSpecies(common_name='Semipalmated Plover', specific_name='semipalmatus', generic_name='Charadrius', family_common_name='Plovers and Lapwings', family='Charadriidae', order='Charadriiformes', ebird_species_code='semplo'),
#   EBirdSpecies(common_name='Piping Plover', specific_name='melodus', generic_name='Charadrius', family_common_name='Plovers and Lapwings', family='Charadriidae', order='Charadriiformes', ebird_species_code='pipplo'),
#   EBirdSpecies(common_name='Northern Lapwing', specific_name='vanellus', generic_name='Vanellus', family_common_name='Plovers and Lapwings', family='Charadriidae', order='Charadriiformes', ebird_species_code='norlap'),
#   EBirdSpecies(common_name="Wilson's Plover", specific_name='wilsonia', generic_name='Anarhynchus', family_common_name='Plovers and Lapwings', family='Charadriidae', order='Charadriiformes', ebird_species_code='wilplo'),
#   EBirdSpecies(common_name='Snowy Plover', specific_name='nivosus', generic_name='Anarhynchus', family_common_name='Plovers and Lapwings', family='Charadriidae', order='Charadriiformes', ebird_species_code='snoplo5'),
#   EBirdSpecies(common_name='Upland Sandpiper', specific_name='longicauda', generic_name='Bartramia', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='uplsan'),
#   EBirdSpecies(common_name='Hudsonian Whimbrel', specific_name='hudsonicus', generic_name='Numenius', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='whimbr3'),
#   EBirdSpecies(common_name='Eurasian Whimbrel', specific_name='phaeopus', generic_name='Numenius', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='whimbr5'),
#   EBirdSpecies(common_name='Eskimo Curlew', specific_name='borealis', generic_name='Numenius', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='eskcur'),
#   EBirdSpecies(common_name='Bar-tailed Godwit', specific_name='lapponica', generic_name='Limosa', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='batgod'),
#   EBirdSpecies(common_name='Hudsonian Godwit', specific_name='haemastica', generic_name='Limosa', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='hudgod'),
#   EBirdSpecies(common_name='Marbled Godwit', specific_name='fedoa', generic_name='Limosa', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='margod'),
#   EBirdSpecies(common_name='Short-billed Dowitcher', specific_name='griseus', generic_name='Limnodromus', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='shbdow'),
#   EBirdSpecies(common_name='Long-billed Dowitcher', specific_name='scolopaceus', generic_name='Limnodromus', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='lobdow'),
#   EBirdSpecies(common_name='American Woodcock', specific_name='minor', generic_name='Scolopax', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='amewoo'),
#   EBirdSpecies(common_name="Wilson's Snipe", specific_name='delicata', generic_name='Gallinago', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='wilsni1'),
#   EBirdSpecies(common_name="Wilson's Phalarope", specific_name='tricolor', generic_name='Phalaropus', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='wilpha'),
#   EBirdSpecies(common_name='Red Phalarope', specific_name='fulicarius', generic_name='Phalaropus', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='redpha1'),
#   EBirdSpecies(common_name='Red-necked Phalarope', specific_name='lobatus', generic_name='Phalaropus', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='renpha'),
#   EBirdSpecies(common_name='Spotted Sandpiper', specific_name='macularius', generic_name='Actitis', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='sposan'),
#   EBirdSpecies(common_name='Solitary Sandpiper', specific_name='solitaria', generic_name='Tringa', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='solsan'),
#   EBirdSpecies(common_name='Gray-tailed Tattler', specific_name='brevipes', generic_name='Tringa', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='gyttat1'),
#   EBirdSpecies(common_name='Lesser Yellowlegs', specific_name='flavipes', generic_name='Tringa', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='lesyel'),
#   EBirdSpecies(common_name='Willet', specific_name='semipalmata', generic_name='Tringa', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='willet1'),
#   EBirdSpecies(common_name='Greater Yellowlegs', specific_name='melanoleuca', generic_name='Tringa', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='greyel'),
#   EBirdSpecies(common_name='Ruddy Turnstone', specific_name='interpres', generic_name='Arenaria', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='rudtur'),
#   EBirdSpecies(common_name='Great Knot', specific_name='tenuirostris', generic_name='Calidris', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='grekno'),
#   EBirdSpecies(common_name='Red Knot', specific_name='canutus', generic_name='Calidris', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='redkno'),
#   EBirdSpecies(common_name='Surfbird', specific_name='virgata', generic_name='Calidris', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='surfbi'),
#   EBirdSpecies(common_name='Ruff', specific_name='pugnax', generic_name='Calidris', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='ruff'),
#   EBirdSpecies(common_name='Curlew Sandpiper', specific_name='ferruginea', generic_name='Calidris', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='cursan'),
#   EBirdSpecies(common_name='Stilt Sandpiper', specific_name='himantopus', generic_name='Calidris', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='stisan'),
#   EBirdSpecies(common_name='Red-necked Stint', specific_name='ruficollis', generic_name='Calidris', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='rensti'),
#   EBirdSpecies(common_name='Buff-breasted Sandpiper', specific_name='subruficollis', generic_name='Calidris', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='bubsan'),
#   EBirdSpecies(common_name='Sanderling', specific_name='alba', generic_name='Calidris', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='sander'),
#   EBirdSpecies(common_name='Dunlin', specific_name='alpina', generic_name='Calidris', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='dunlin'),
#   EBirdSpecies(common_name='Purple Sandpiper', specific_name='maritima', generic_name='Calidris', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='pursan'),
#   EBirdSpecies(common_name="Baird's Sandpiper", specific_name='bairdii', generic_name='Calidris', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='baisan'),
#   EBirdSpecies(common_name='White-rumped Sandpiper', specific_name='fuscicollis', generic_name='Calidris', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='whrsan'),
#   EBirdSpecies(common_name='Dunlin x White-rumped Sandpiper (hybrid)', specific_name='alpina x fuscicollis', generic_name='Calidris', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='x00430'),
#   EBirdSpecies(common_name='Least Sandpiper', specific_name='minutilla', generic_name='Calidris', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='leasan'),
#   EBirdSpecies(common_name='Pectoral Sandpiper', specific_name='melanotos', generic_name='Calidris', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='pecsan'),
#   EBirdSpecies(common_name='Western Sandpiper', specific_name='mauri', generic_name='Calidris', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='wessan'),
#   EBirdSpecies(common_name='Semipalmated Sandpiper', specific_name='pusilla', generic_name='Calidris', family_common_name='Sandpipers and Allies', family='Scolopacidae', order='Charadriiformes', ebird_species_code='semsan'),
#   EBirdSpecies(common_name='Long-tailed Jaeger', specific_name='longicaudus', generic_name='Stercorarius', family_common_name='Skuas and Jaegers', family='Stercorariidae', order='Charadriiformes', ebird_species_code='lotjae'),
#   EBirdSpecies(common_name='Parasitic Jaeger', specific_name='parasiticus', generic_name='Stercorarius', family_common_name='Skuas and Jaegers', family='Stercorariidae', order='Charadriiformes', ebird_species_code='parjae'),
#   EBirdSpecies(common_name='Pomarine Jaeger', specific_name='pomarinus', generic_name='Stercorarius', family_common_name='Skuas and Jaegers', family='Stercorariidae', order='Charadriiformes', ebird_species_code='pomjae'),
#   EBirdSpecies(common_name='Great Skua', specific_name='skua', generic_name='Stercorarius', family_common_name='Skuas and Jaegers', family='Stercorariidae', order='Charadriiformes', ebird_species_code='gresku1'),
#   EBirdSpecies(common_name='South Polar Skua', specific_name='maccormicki', generic_name='Stercorarius', family_common_name='Skuas and Jaegers', family='Stercorariidae', order='Charadriiformes', ebird_species_code='sopsku1'),
#   EBirdSpecies(common_name='Tufted Puffin', specific_name='cirrhata', generic_name='Fratercula', family_common_name='Auks, Murres, and Puffins', family='Alcidae', order='Charadriiformes', ebird_species_code='tufpuf'),
#   EBirdSpecies(common_name='Atlantic Puffin', specific_name='arctica', generic_name='Fratercula', family_common_name='Auks, Murres, and Puffins', family='Alcidae', order='Charadriiformes', ebird_species_code='atlpuf'),
#   EBirdSpecies(common_name='Black Guillemot', specific_name='grylle', generic_name='Cepphus', family_common_name='Auks, Murres, and Puffins', family='Alcidae', order='Charadriiformes', ebird_species_code='blkgui'),
#   EBirdSpecies(common_name='Razorbill', specific_name='torda', generic_name='Alca', family_common_name='Auks, Murres, and Puffins', family='Alcidae', order='Charadriiformes', ebird_species_code='razorb'),
#   EBirdSpecies(common_name='Dovekie', specific_name='alle', generic_name='Alle', family_common_name='Auks, Murres, and Puffins', family='Alcidae', order='Charadriiformes', ebird_species_code='doveki'),
#   EBirdSpecies(common_name='Thick-billed Murre', specific_name='lomvia', generic_name='Uria', family_common_name='Auks, Murres, and Puffins', family='Alcidae', order='Charadriiformes', ebird_species_code='thbmur'),
#   EBirdSpecies(common_name='Common Murre', specific_name='aalge', generic_name='Uria', family_common_name='Auks, Murres, and Puffins', family='Alcidae', order='Charadriiformes', ebird_species_code='commur'),
#   EBirdSpecies(common_name='Ancient Murrelet', specific_name='antiquus', generic_name='Synthliboramphus', family_common_name='Auks, Murres, and Puffins', family='Alcidae', order='Charadriiformes', ebird_species_code='ancmur'),
#   EBirdSpecies(common_name='Little Gull', specific_name='minutus', generic_name='Hydrocoloeus', family_common_name='Gulls, Terns, and Skimmers', family='Laridae', order='Charadriiformes', ebird_species_code='litgul'),
#   EBirdSpecies(common_name='Black-legged Kittiwake', specific_name='tridactyla', generic_name='Rissa', family_common_name='Gulls, Terns, and Skimmers', family='Laridae', order='Charadriiformes', ebird_species_code='bklkit'),
#   EBirdSpecies(common_name='Ivory Gull', specific_name='eburnea', generic_name='Pagophila', family_common_name='Gulls, Terns, and Skimmers', family='Laridae', order='Charadriiformes', ebird_species_code='ivogul'),
#   EBirdSpecies(common_name="Sabine's Gull", specific_name='sabini', generic_name='Xema', family_common_name='Gulls, Terns, and Skimmers', family='Laridae', order='Charadriiformes', ebird_species_code='sabgul'),
#   EBirdSpecies(common_name="Bonaparte's Gull", specific_name='philadelphia', generic_name='Chroicocephalus', family_common_name='Gulls, Terns, and Skimmers', family='Laridae', order='Charadriiformes', ebird_species_code='bongul'),
#   EBirdSpecies(common_name='Black-headed Gull', specific_name='ridibundus', generic_name='Chroicocephalus', family_common_name='Gulls, Terns, and Skimmers', family='Laridae', order='Charadriiformes', ebird_species_code='bkhgul'),
#   EBirdSpecies(common_name='Laughing Gull', specific_name='atricilla', generic_name='Leucophaeus', family_common_name='Gulls, Terns, and Skimmers', family='Laridae', order='Charadriiformes', ebird_species_code='laugul'),
#   EBirdSpecies(common_name="Franklin's Gull", specific_name='pipixcan', generic_name='Leucophaeus', family_common_name='Gulls, Terns, and Skimmers', family='Laridae', order='Charadriiformes', ebird_species_code='fragul'),
#   EBirdSpecies(common_name='Common Gull', specific_name='canus', generic_name='Larus', family_common_name='Gulls, Terns, and Skimmers', family='Laridae', order='Charadriiformes', ebird_species_code='mewgul'),
#   EBirdSpecies(common_name='Short-billed Gull', specific_name='brachyrhynchus', generic_name='Larus', family_common_name='Gulls, Terns, and Skimmers', family='Laridae', order='Charadriiformes', ebird_species_code='mewgul2'),
#   EBirdSpecies(common_name='Ring-billed Gull', specific_name='delawarensis', generic_name='Larus', family_common_name='Gulls, Terns, and Skimmers', family='Laridae', order='Charadriiformes', ebird_species_code='ribgul'),
#   EBirdSpecies(common_name='Black-headed x Ring-billed Gull (hybrid)', specific_name='ridibundus x Larus delawarensis', generic_name='Chroicocephalus', family_common_name='Gulls, Terns, and Skimmers', family='Laridae', order='Charadriiformes', ebird_species_code='x00641'),
#   EBirdSpecies(common_name='American Herring Gull', specific_name='smithsonianus', generic_name='Larus', family_common_name='Gulls, Terns, and Skimmers', family='Laridae', order='Charadriiformes', ebird_species_code='amhgul1'),
#   EBirdSpecies(common_name='Great Black-backed Gull', specific_name='marinus', generic_name='Larus', family_common_name='Gulls, Terns, and Skimmers', family='Laridae', order='Charadriiformes', ebird_species_code='gbbgul'),
#   EBirdSpecies(common_name='American Herring x Great Black-backed Gull (hybrid)', specific_name='smithsonianus x marinus', generic_name='Larus', family_common_name='Gulls, Terns, and Skimmers', family='Laridae', order='Charadriiformes', ebird_species_code='x00047'),
#   EBirdSpecies(common_name='Glaucous Gull', specific_name='hyperboreus', generic_name='Larus', family_common_name='Gulls, Terns, and Skimmers', family='Laridae', order='Charadriiformes', ebird_species_code='glagul'),
#   EBirdSpecies(common_name='American Herring x Glaucous Gull (hybrid)', specific_name='smithsonianus x hyperboreus', generic_name='Larus', family_common_name='Gulls, Terns, and Skimmers', family='Laridae', order='Charadriiformes', ebird_species_code='x01131'),
#   EBirdSpecies(common_name='Lesser Black-backed Gull', specific_name='fuscus', generic_name='Larus', family_common_name='Gulls, Terns, and Skimmers', family='Laridae', order='Charadriiformes', ebird_species_code='lbbgul'),
#   EBirdSpecies(common_name='American Herring x Lesser Black-backed Gull (hybrid)', specific_name='smithsonianus x fuscus', generic_name='Larus', family_common_name='Gulls, Terns, and Skimmers', family='Laridae', order='Charadriiformes', ebird_species_code='x01134'),
#   EBirdSpecies(common_name='Slaty-backed Gull', specific_name='schistisagus', generic_name='Larus', family_common_name='Gulls, Terns, and Skimmers', family='Laridae', order='Charadriiformes', ebird_species_code='slbgul'),
#   EBirdSpecies(common_name='Iceland Gull', specific_name='glaucoides', generic_name='Larus', family_common_name='Gulls, Terns, and Skimmers', family='Laridae', order='Charadriiformes', ebird_species_code='y00478'),
#   EBirdSpecies(common_name='Black Skimmer', specific_name='niger', generic_name='Rynchops', family_common_name='Gulls, Terns, and Skimmers', family='Laridae', order='Charadriiformes', ebird_species_code='blkski'),
#   EBirdSpecies(common_name='Sooty Tern', specific_name='fuscatus', generic_name='Onychoprion', family_common_name='Gulls, Terns, and Skimmers', family='Laridae', order='Charadriiformes', ebird_species_code='sooter1'),
#   EBirdSpecies(common_name='Bridled Tern', specific_name='anaethetus', generic_name='Onychoprion', family_common_name='Gulls, Terns, and Skimmers', family='Laridae', order='Charadriiformes', ebird_species_code='briter1'),
#   EBirdSpecies(common_name='Least Tern', specific_name='antillarum', generic_name='Sternula', family_common_name='Gulls, Terns, and Skimmers', family='Laridae', order='Charadriiformes', ebird_species_code='leater1'),
#   EBirdSpecies(common_name='Gull-billed Tern', specific_name='nilotica', generic_name='Gelochelidon', family_common_name='Gulls, Terns, and Skimmers', family='Laridae', order='Charadriiformes', ebird_species_code='gubter2'),
#   EBirdSpecies(common_name='Caspian Tern', specific_name='caspia', generic_name='Hydroprogne', family_common_name='Gulls, Terns, and Skimmers', family='Laridae', order='Charadriiformes', ebird_species_code='caster1'),
#   EBirdSpecies(common_name='Black Tern', specific_name='niger', generic_name='Chlidonias', family_common_name='Gulls, Terns, and Skimmers', family='Laridae', order='Charadriiformes', ebird_species_code='blkter'),
#   EBirdSpecies(common_name='White-winged Tern', specific_name='leucopterus', generic_name='Chlidonias', family_common_name='Gulls, Terns, and Skimmers', family='Laridae', order='Charadriiformes', ebird_species_code='whwter'),
#   EBirdSpecies(common_name="Forster's Tern", specific_name='forsteri', generic_name='Sterna', family_common_name='Gulls, Terns, and Skimmers', family='Laridae', order='Charadriiformes', ebird_species_code='forter'),
#   EBirdSpecies(common_name='Arctic Tern', specific_name='paradisaea', generic_name='Sterna', family_common_name='Gulls, Terns, and Skimmers', family='Laridae', order='Charadriiformes', ebird_species_code='arcter'),
#   EBirdSpecies(common_name='Common Tern', specific_name='hirundo', generic_name='Sterna', family_common_name='Gulls, Terns, and Skimmers', family='Laridae', order='Charadriiformes', ebird_species_code='comter'),
#   EBirdSpecies(common_name='Common x Arctic Tern (hybrid)', specific_name='hirundo x paradisaea', generic_name='Sterna', family_common_name='Gulls, Terns, and Skimmers', family='Laridae', order='Charadriiformes', ebird_species_code='x00910'),
#   EBirdSpecies(common_name='Roseate Tern', specific_name='dougallii', generic_name='Sterna', family_common_name='Gulls, Terns, and Skimmers', family='Laridae', order='Charadriiformes', ebird_species_code='roster'),
#   EBirdSpecies(common_name='Sandwich Tern', specific_name='sandvicensis', generic_name='Thalasseus', family_common_name='Gulls, Terns, and Skimmers', family='Laridae', order='Charadriiformes', ebird_species_code='santer1'),
#   EBirdSpecies(common_name='Royal Tern', specific_name='maximus', generic_name='Thalasseus', family_common_name='Gulls, Terns, and Skimmers', family='Laridae', order='Charadriiformes', ebird_species_code='royter1'),
#   EBirdSpecies(common_name='Pied-billed Grebe', specific_name='podiceps', generic_name='Podilymbus', family_common_name='Grebes', family='Podicipedidae', order='Podicipediformes', ebird_species_code='pibgre'),
#   EBirdSpecies(common_name='Horned Grebe', specific_name='auritus', generic_name='Podiceps', family_common_name='Grebes', family='Podicipedidae', order='Podicipediformes', ebird_species_code='horgre'),
#   EBirdSpecies(common_name='Red-necked Grebe', specific_name='grisegena', generic_name='Podiceps', family_common_name='Grebes', family='Podicipedidae', order='Podicipediformes', ebird_species_code='rengre'),
#   EBirdSpecies(common_name='Eared Grebe', specific_name='nigricollis', generic_name='Podiceps', family_common_name='Grebes', family='Podicipedidae', order='Podicipediformes', ebird_species_code='eargre'),
#   EBirdSpecies(common_name='Western Grebe', specific_name='occidentalis', generic_name='Aechmophorus', family_common_name='Grebes', family='Podicipedidae', order='Podicipediformes', ebird_species_code='wesgre'),
#   EBirdSpecies(common_name="Clark's Grebe", specific_name='clarkii', generic_name='Aechmophorus', family_common_name='Grebes', family='Podicipedidae', order='Podicipediformes', ebird_species_code='clagre'),
#   EBirdSpecies(common_name='Red-billed Tropicbird', specific_name='aethereus', generic_name='Phaethon', family_common_name='Tropicbirds', family='Phaethontidae', order='Phaethontiformes', ebird_species_code='rebtro'),
#   EBirdSpecies(common_name='Red-throated Loon', specific_name='stellata', generic_name='Gavia', family_common_name='Loons', family='Gaviidae', order='Gaviiformes', ebird_species_code='retloo'),
#   EBirdSpecies(common_name='Pacific Loon', specific_name='pacifica', generic_name='Gavia', family_common_name='Loons', family='Gaviidae', order='Gaviiformes', ebird_species_code='pacloo'),
#   EBirdSpecies(common_name='Common Loon', specific_name='immer', generic_name='Gavia', family_common_name='Loons', family='Gaviidae', order='Gaviiformes', ebird_species_code='comloo'),
#   EBirdSpecies(common_name='Yellow-billed Loon', specific_name='adamsii', generic_name='Gavia', family_common_name='Loons', family='Gaviidae', order='Gaviiformes', ebird_species_code='yebloo'),
#   EBirdSpecies(common_name='Atlantic Yellow-nosed Albatross', specific_name='chlororhynchos', generic_name='Thalassarche', family_common_name='Albatrosses', family='Diomedeidae', order='Procellariiformes', ebird_species_code='yenalb2'),
#   EBirdSpecies(common_name="Wilson's Storm-Petrel", specific_name='oceanicus', generic_name='Oceanites', family_common_name='Southern Storm-Petrels', family='Oceanitidae', order='Procellariiformes', ebird_species_code='wispet'),
#   EBirdSpecies(common_name="Leach's Storm-Petrel", specific_name='leucorhous', generic_name='Hydrobates', family_common_name='Northern Storm-Petrels', family='Hydrobatidae', order='Procellariiformes', ebird_species_code='lcspet'),
# ...
#   EBirdSpecies(common_name='Lark Sparrow', specific_name='grammacus', generic_name='Chondestes', family_common_name='New World Sparrows', family='Passerellidae', order='Passeriformes', ebird_species_code='larspa'),
#   EBirdSpecies(common_name='American Tree Sparrow', specific_name='arborea', generic_name='Spizelloides', family_common_name='New World Sparrows', family='Passerellidae', order='Passeriformes', ebird_species_code='amtspa'),
#   EBirdSpecies(common_name='Fox Sparrow', specific_name='iliaca', generic_name='Passerella', family_common_name='New World Sparrows', family='Passerellidae', order='Passeriformes', ebird_species_code='foxspa'),
#   EBirdSpecies(common_name='Dark-eyed Junco', specific_name='hyemalis', generic_name='Junco', family_common_name='New World Sparrows', family='Passerellidae', order='Passeriformes', ebird_species_code='daejun'),
#   EBirdSpecies(common_name='White-crowned Sparrow', specific_name='leucophrys', generic_name='Zonotrichia', family_common_name='New World Sparrows', family='Passerellidae', order='Passeriformes', ebird_species_code='whcspa'),
#   EBirdSpecies(common_name='White-throated Sparrow', specific_name='albicollis', generic_name='Zonotrichia', family_common_name='New World Sparrows', family='Passerellidae', order='Passeriformes', ebird_species_code='whtspa'),
#   EBirdSpecies(common_name='Dark-eyed Junco x White-throated Sparrow (hybrid)', specific_name='hyemalis x Zonotrichia albicollis', generic_name='Junco', family_common_name='New World Sparrows', family='Passerellidae', order='Passeriformes', ebird_species_code='x00039'),
#   EBirdSpecies(common_name='Vesper Sparrow', specific_name='gramineus', generic_name='Pooecetes', family_common_name='New World Sparrows', family='Passerellidae', order='Passeriformes', ebird_species_code='vesspa'),
#   EBirdSpecies(common_name="Nelson's Sparrow", specific_name='nelsoni', generic_name='Ammospiza', family_common_name='New World Sparrows', family='Passerellidae', order='Passeriformes', ebird_species_code='nstspa'),
#   EBirdSpecies(common_name='Saltmarsh Sparrow', specific_name='caudacuta', generic_name='Ammospiza', family_common_name='New World Sparrows', family='Passerellidae', order='Passeriformes', ebird_species_code='sstspa'),
#   EBirdSpecies(common_name='Savannah Sparrow', specific_name='sandwichensis', generic_name='Passerculus', family_common_name='New World Sparrows', family='Passerellidae', order='Passeriformes', ebird_species_code='savspa'),
#   EBirdSpecies(common_name='Song Sparrow', specific_name='melodia', generic_name='Melospiza', family_common_name='New World Sparrows', family='Passerellidae', order='Passeriformes', ebird_species_code='sonspa'),
#   EBirdSpecies(common_name="Lincoln's Sparrow", specific_name='lincolnii', generic_name='Melospiza', family_common_name='New World Sparrows', family='Passerellidae', order='Passeriformes', ebird_species_code='linspa'),
#   EBirdSpecies(common_name='Swamp Sparrow', specific_name='georgiana', generic_name='Melospiza', family_common_name='New World Sparrows', family='Passerellidae', order='Passeriformes', ebird_species_code='swaspa'),
#   EBirdSpecies(common_name='Eastern Towhee', specific_name='erythrophthalmus', generic_name='Pipilo', family_common_name='New World Sparrows', family='Passerellidae', order='Passeriformes', ebird_species_code='eastow'),
#   EBirdSpecies(common_name='Yellow-breasted Chat', specific_name='virens', generic_name='Icteria', family_common_name='Yellow-breasted Chat', family='Icteriidae', order='Passeriformes', ebird_species_code='yebcha'),
#   EBirdSpecies(common_name='Yellow-headed Blackbird', specific_name='xanthocephalus', generic_name='Xanthocephalus', family_common_name='Troupials and Allies', family='Icteridae', order='Passeriformes', ebird_species_code='yehbla'),
#   EBirdSpecies(common_name='Bobolink', specific_name='oryzivorus', generic_name='Dolichonyx', family_common_name='Troupials and Allies', family='Icteridae', order='Passeriformes', ebird_species_code='boboli'),
#   EBirdSpecies(common_name='Eastern Meadowlark', specific_name='magna', generic_name='Sturnella', family_common_name='Troupials and Allies', family='Icteridae', order='Passeriformes', ebird_species_code='easmea'),
#   EBirdSpecies(common_name='Orchard Oriole', specific_name='spurius', generic_name='Icterus', family_common_name='Troupials and Allies', family='Icteridae', order='Passeriformes', ebird_species_code='orcori'),
#   EBirdSpecies(common_name='Baltimore Oriole', specific_name='galbula', generic_name='Icterus', family_common_name='Troupials and Allies', family='Icteridae', order='Passeriformes', ebird_species_code='balori'),
#   EBirdSpecies(common_name='Red-winged Blackbird', specific_name='phoeniceus', generic_name='Agelaius', family_common_name='Troupials and Allies', family='Icteridae', order='Passeriformes', ebird_species_code='rewbla'),
#   EBirdSpecies(common_name='Brown-headed Cowbird', specific_name='ater', generic_name='Molothrus', family_common_name='Troupials and Allies', family='Icteridae', order='Passeriformes', ebird_species_code='bnhcow'),
#   EBirdSpecies(common_name='Rusty Blackbird', specific_name='carolinus', generic_name='Euphagus', family_common_name='Troupials and Allies', family='Icteridae', order='Passeriformes', ebird_species_code='rusbla'),
#   EBirdSpecies(common_name="Brewer's Blackbird", specific_name='cyanocephalus', generic_name='Euphagus', family_common_name='Troupials and Allies', family='Icteridae', order='Passeriformes', ebird_species_code='brebla'),
#   EBirdSpecies(common_name='Common Grackle', specific_name='quiscula', generic_name='Quiscalus', family_common_name='Troupials and Allies', family='Icteridae', order='Passeriformes', ebird_species_code='comgra'),
#   EBirdSpecies(common_name='Ovenbird', specific_name='aurocapilla', generic_name='Seiurus', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='ovenbi1'),
#   EBirdSpecies(common_name='Worm-eating Warbler', specific_name='vermivorum', generic_name='Helmitheros', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='woewar1'),
#   EBirdSpecies(common_name='Louisiana Waterthrush', specific_name='motacilla', generic_name='Parkesia', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='louwat'),
#   EBirdSpecies(common_name='Northern Waterthrush', specific_name='noveboracensis', generic_name='Parkesia', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='norwat'),
#   EBirdSpecies(common_name='Golden-winged Warbler', specific_name='chrysoptera', generic_name='Vermivora', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='gowwar'),
#   EBirdSpecies(common_name='Blue-winged Warbler', specific_name='cyanoptera', generic_name='Vermivora', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='buwwar'),
#   EBirdSpecies(common_name="Brewster's Warbler (hybrid)", specific_name='chrysoptera x cyanoptera (F1 hybrid)', generic_name='Vermivora', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='brewar'),
#   EBirdSpecies(common_name='Black-and-white Warbler', specific_name='varia', generic_name='Mniotilta', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='bawwar'),
#   EBirdSpecies(common_name='Prothonotary Warbler', specific_name='citrea', generic_name='Protonotaria', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='prowar'),
#   EBirdSpecies(common_name='Tennessee Warbler', specific_name='peregrina', generic_name='Leiothlypis', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='tenwar'),
#   EBirdSpecies(common_name='Orange-crowned Warbler', specific_name='celata', generic_name='Leiothlypis', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='orcwar'),
#   EBirdSpecies(common_name='Nashville Warbler', specific_name='ruficapilla', generic_name='Leiothlypis', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='naswar'),
#   EBirdSpecies(common_name='Connecticut Warbler', specific_name='agilis', generic_name='Oporornis', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='conwar'),
#   EBirdSpecies(common_name="MacGillivray's Warbler", specific_name='tolmiei', generic_name='Geothlypis', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='macwar'),
#   EBirdSpecies(common_name='Mourning Warbler', specific_name='philadelphia', generic_name='Geothlypis', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='mouwar'),
#   EBirdSpecies(common_name='Kentucky Warbler', specific_name='formosa', generic_name='Geothlypis', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='kenwar'),
#   EBirdSpecies(common_name='Common Yellowthroat', specific_name='trichas', generic_name='Geothlypis', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='comyel'),
#   EBirdSpecies(common_name='Hooded Warbler', specific_name='citrina', generic_name='Setophaga', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='hoowar'),
#   EBirdSpecies(common_name='American Redstart', specific_name='ruticilla', generic_name='Setophaga', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='amered'),
#   EBirdSpecies(common_name='Cape May Warbler', specific_name='tigrina', generic_name='Setophaga', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='camwar'),
#   EBirdSpecies(common_name='Cerulean Warbler', specific_name='cerulea', generic_name='Setophaga', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='cerwar'),
#   EBirdSpecies(common_name='Northern Parula', specific_name='americana', generic_name='Setophaga', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='norpar'),
#   EBirdSpecies(common_name='Magnolia Warbler', specific_name='magnolia', generic_name='Setophaga', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='magwar'),
#   EBirdSpecies(common_name='Bay-breasted Warbler', specific_name='castanea', generic_name='Setophaga', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='babwar'),
#   EBirdSpecies(common_name='Blackburnian Warbler', specific_name='fusca', generic_name='Setophaga', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='bkbwar'),
#   EBirdSpecies(common_name='Northern Yellow Warbler', specific_name='aestiva', generic_name='Setophaga', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='yelwar1'),
#   EBirdSpecies(common_name='Chestnut-sided Warbler', specific_name='pensylvanica', generic_name='Setophaga', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='chswar'),
#   EBirdSpecies(common_name='Blackpoll Warbler', specific_name='striata', generic_name='Setophaga', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='bkpwar'),
#   EBirdSpecies(common_name='Black-throated Blue Warbler', specific_name='caerulescens', generic_name='Setophaga', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='btbwar'),
#   EBirdSpecies(common_name='Palm Warbler', specific_name='palmarum', generic_name='Setophaga', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='palwar'),
#   EBirdSpecies(common_name='Pine Warbler', specific_name='pinus', generic_name='Setophaga', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='pinwar'),
#   EBirdSpecies(common_name='Yellow-rumped Warbler', specific_name='coronata', generic_name='Setophaga', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='yerwar'),
#   EBirdSpecies(common_name='Yellow-throated Warbler', specific_name='dominica', generic_name='Setophaga', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='yetwar'),
#   EBirdSpecies(common_name='Prairie Warbler', specific_name='discolor', generic_name='Setophaga', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='prawar'),
#   EBirdSpecies(common_name="Townsend's Warbler", specific_name='townsendi', generic_name='Setophaga', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='towwar'),
#   EBirdSpecies(common_name='Black-throated Green Warbler', specific_name='virens', generic_name='Setophaga', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='btnwar'),
#   EBirdSpecies(common_name='Canada Warbler', specific_name='canadensis', generic_name='Cardellina', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='canwar'),
#   EBirdSpecies(common_name="Wilson's Warbler", specific_name='pusilla', generic_name='Cardellina', family_common_name='New World Warblers', family='Parulidae', order='Passeriformes', ebird_species_code='wlswar'),
#   EBirdSpecies(common_name='Summer Tanager', specific_name='rubra', generic_name='Piranga', family_common_name='Cardinals and Allies', family='Cardinalidae', order='Passeriformes', ebird_species_code='sumtan'),
#   EBirdSpecies(common_name='Scarlet Tanager', specific_name='olivacea', generic_name='Piranga', family_common_name='Cardinals and Allies', family='Cardinalidae', order='Passeriformes', ebird_species_code='scatan'),
#   EBirdSpecies(common_name='Western Tanager', specific_name='ludoviciana', generic_name='Piranga', family_common_name='Cardinals and Allies', family='Cardinalidae', order='Passeriformes', ebird_species_code='westan'),
#   EBirdSpecies(common_name='Northern Cardinal', specific_name='cardinalis', generic_name='Cardinalis', family_common_name='Cardinals and Allies', family='Cardinalidae', order='Passeriformes', ebird_species_code='norcar'),
#   EBirdSpecies(common_name='Rose-breasted Grosbeak', specific_name='ludovicianus', generic_name='Pheucticus', family_common_name='Cardinals and Allies', family='Cardinalidae', order='Passeriformes', ebird_species_code='robgro'),
#   EBirdSpecies(common_name='Blue Grosbeak', specific_name='caerulea', generic_name='Passerina', family_common_name='Cardinals and Allies', family='Cardinalidae', order='Passeriformes', ebird_species_code='blugrb1'),
#   EBirdSpecies(common_name='Indigo Bunting', specific_name='cyanea', generic_name='Passerina', family_common_name='Cardinals and Allies', family='Cardinalidae', order='Passeriformes', ebird_species_code='indbun'),
#   EBirdSpecies(common_name='Painted Bunting', specific_name='ciris', generic_name='Passerina', family_common_name='Cardinals and Allies', family='Cardinalidae', order='Passeriformes', ebird_species_code='paibun'),
#   EBirdSpecies(common_name='Dickcissel', specific_name='americana', generic_name='Spiza', family_common_name='Cardinals and Allies', family='Cardinalidae', order='Passeriformes', ebird_species_code='dickci')]}

# %%
region_to_species_yaml = {
    r: [s.to_yaml() for s in species_list] for r, species_list in region_to_species_taxons.items()
}
region_to_species_yaml
# Out:
# {'Maine, United States': [{'common_name': 'Black-bellied Whistling-Duck',
#    'scientific_name': 'Dendrocygna autumnalis',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'bbwduc'},
#   {'common_name': 'Snow Goose',
#    'scientific_name': 'Anser caerulescens',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'snogoo'},
#   {'common_name': "Ross's Goose",
#    'scientific_name': 'Anser rossii',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'rosgoo'},
#   {'common_name': "Snow x Ross's Goose (hybrid)",
#    'scientific_name': 'Anser caerulescens x rossii',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'sxrgoo1'},
#   {'common_name': 'Graylag Goose',
#    'scientific_name': 'Anser anser',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'gragoo'},
#   {'common_name': 'Swan Goose',
#    'scientific_name': 'Anser cygnoides',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'swagoo1'},
#   {'common_name': 'Greater White-fronted Goose',
#    'scientific_name': 'Anser albifrons',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'gwfgoo'},
#   {'common_name': 'Pink-footed Goose',
#    'scientific_name': 'Anser brachyrhynchus',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'pifgoo'},
#   {'common_name': 'Brant',
#    'scientific_name': 'Branta bernicla',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'brant'},
#   {'common_name': 'Barnacle Goose',
#    'scientific_name': 'Branta leucopsis',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'bargoo'},
#   {'common_name': 'Cackling Goose',
#    'scientific_name': 'Branta hutchinsii',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'cacgoo1'},
#   {'common_name': 'Canada Goose',
#    'scientific_name': 'Branta canadensis',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'cangoo'},
#   {'common_name': 'Swan x Canada Goose (hybrid)',
#    'scientific_name': 'Anser cygnoides x branta canadensis',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'swagoo3'},
#   {'common_name': 'Greater White-fronted x Canada Goose (hybrid)',
#    'scientific_name': 'Anser albifrons x branta canadensis',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'x00415'},
#   {'common_name': 'Domestic goose sp. x Canada Goose (hybrid)',
#    'scientific_name': 'Anser sp. (domestic type) x branta canadensis',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'x00759'},
#   {'common_name': 'Mute Swan',
#    'scientific_name': 'Cygnus olor',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'mutswa'},
#   {'common_name': 'Black Swan',
#    'scientific_name': 'Cygnus atratus',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'blkswa'},
#   {'common_name': 'Trumpeter Swan',
#    'scientific_name': 'Cygnus buccinator',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'truswa'},
#   {'common_name': 'Tundra Swan',
#    'scientific_name': 'Cygnus columbianus',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'tunswa'},
#   {'common_name': 'Whooper Swan',
#    'scientific_name': 'Cygnus cygnus',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'whoswa'},
#   {'common_name': 'Egyptian Goose',
#    'scientific_name': 'Alopochen aegyptiaca',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'egygoo'},
#   {'common_name': 'Common Shelduck',
#    'scientific_name': 'Tadorna tadorna',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'comshe'},
#   {'common_name': 'Muscovy Duck',
#    'scientific_name': 'Cairina moschata',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'musduc'},
#   {'common_name': 'Wood Duck',
#    'scientific_name': 'Aix sponsa',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'wooduc'},
#   {'common_name': 'Mandarin Duck',
#    'scientific_name': 'Aix galericulata',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'manduc'},
#   {'common_name': 'Garganey',
#    'scientific_name': 'Spatula querquedula',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'gargan'},
#   {'common_name': 'Blue-winged Teal',
#    'scientific_name': 'Spatula discors',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'buwtea'},
#   {'common_name': 'Northern Shoveler',
#    'scientific_name': 'Spatula clypeata',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'norsho'},
#   {'common_name': 'Gadwall',
#    'scientific_name': 'Mareca strepera',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'gadwal'},
#   {'common_name': 'Eurasian Wigeon',
#    'scientific_name': 'Mareca penelope',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'eurwig'},
#   {'common_name': 'American Wigeon',
#    'scientific_name': 'Mareca americana',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'amewig'},
#   {'common_name': 'Mallard',
#    'scientific_name': 'Anas platyrhynchos',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'mallar3'},
#   {'common_name': 'Muscovy Duck x Mallard (hybrid)',
#    'scientific_name': 'Cairina moschata x anas platyrhynchos',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'mdxmal1'},
#   {'common_name': 'American Wigeon x Mallard (hybrid)',
#    'scientific_name': 'Mareca americana x anas platyrhynchos',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'x00611'},
#   {'common_name': 'American Black Duck',
#    'scientific_name': 'Anas rubripes',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'ambduc'},
#   {'common_name': 'Mallard x American Black Duck (hybrid)',
#    'scientific_name': 'Anas platyrhynchos x rubripes',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'x00004'},
#   {'common_name': 'Northern Pintail',
#    'scientific_name': 'Anas acuta',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'norpin'},
#   {'common_name': 'Mallard x Northern Pintail (hybrid)',
#    'scientific_name': 'Anas platyrhynchos x acuta',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'x00628'},
#   {'common_name': 'Green-winged Teal',
#    'scientific_name': 'Anas crecca',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'gnwtea'},
#   {'common_name': 'Northern Pintail x Green-winged Teal (hybrid)',
#    'scientific_name': 'Anas acuta x crecca',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'x00725'},
#   {'common_name': 'Canvasback',
#    'scientific_name': 'Aythya valisineria',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'canvas'},
#   {'common_name': 'Redhead',
#    'scientific_name': 'Aythya americana',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'redhea'},
#   {'common_name': 'Ring-necked Duck',
#    'scientific_name': 'Aythya collaris',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'rinduc'},
#   {'common_name': 'Redhead x Ring-necked Duck (hybrid)',
#    'scientific_name': 'Aythya americana x collaris',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'x00679'},
#   {'common_name': 'Tufted Duck',
#    'scientific_name': 'Aythya fuligula',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'tufduc'},
#   {'common_name': 'Greater Scaup',
#    'scientific_name': 'Aythya marila',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'gresca'},
#   {'common_name': 'Lesser Scaup',
#    'scientific_name': 'Aythya affinis',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'lessca'},
#   {'common_name': 'King Eider',
#    'scientific_name': 'Somateria spectabilis',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'kineid'},
#   {'common_name': 'Common Eider',
#    'scientific_name': 'Somateria mollissima',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'comeid'},
#   {'common_name': 'King x Common Eider (hybrid)',
#    'scientific_name': 'Somateria spectabilis x mollissima',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'x00665'},
#   {'common_name': 'Harlequin Duck',
#    'scientific_name': 'Histrionicus histrionicus',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'harduc'},
#   {'common_name': 'Surf Scoter',
#    'scientific_name': 'Melanitta perspicillata',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'sursco'},
#   {'common_name': 'White-winged Scoter',
#    'scientific_name': 'Melanitta deglandi',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'whwsco2'},
#   {'common_name': 'Black Scoter',
#    'scientific_name': 'Melanitta americana',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'blksco2'},
#   {'common_name': 'Long-tailed Duck',
#    'scientific_name': 'Clangula hyemalis',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'lotduc'},
#   {'common_name': 'Bufflehead',
#    'scientific_name': 'Bucephala albeola',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'buffle'},
#   {'common_name': 'Common Goldeneye',
#    'scientific_name': 'Bucephala clangula',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'comgol'},
#   {'common_name': "Barrow's Goldeneye",
#    'scientific_name': 'Bucephala islandica',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'bargol'},
#   {'common_name': "Common x Barrow's Goldeneye (hybrid)",
#    'scientific_name': 'Bucephala clangula x islandica',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'cxbgol1'},
#   {'common_name': 'Hooded Merganser',
#    'scientific_name': 'Lophodytes cucullatus',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'hoomer'},
#   {'common_name': 'Common Goldeneye x Hooded Merganser (hybrid)',
#    'scientific_name': 'Bucephala clangula x lophodytes cucullatus',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'x00425'},
#   {'common_name': 'Common Merganser',
#    'scientific_name': 'Mergus merganser',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'commer'},
#   {'common_name': 'Red-breasted Merganser',
#    'scientific_name': 'Mergus serrator',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'rebmer'},
#   {'common_name': 'Ruddy Duck',
#    'scientific_name': 'Oxyura jamaicensis',
#    'family_common_name': 'Ducks, Geese, and Waterfowl',
#    'family': 'Anatidae',
#    'order': 'Anseriformes',
#    'ebird_species_code': 'rudduc'},
#   {'common_name': 'Helmeted Guineafowl',
#    'scientific_name': 'Numida meleagris',
#    'family_common_name': 'Guineafowl',
#    'family': 'Numididae',
#    'order': 'Galliformes',
#    'ebird_species_code': 'helgui'},
#   {'common_name': 'Northern Bobwhite',
#    'scientific_name': 'Colinus virginianus',
#    'family_common_name': 'New World Quail',
#    'family': 'Odontophoridae',
#    'order': 'Galliformes',
#    'ebird_species_code': 'norbob'},
#   {'common_name': 'Wild Turkey',
#    'scientific_name': 'Meleagris gallopavo',
#    'family_common_name': 'Pheasants, Grouse, and Allies',
#    'family': 'Phasianidae',
#    'order': 'Galliformes',
#    'ebird_species_code': 'wiltur'},
#   {'common_name': 'Ruffed Grouse',
#    'scientific_name': 'Bonasa umbellus',
#    'family_common_name': 'Pheasants, Grouse, and Allies',
#    'family': 'Phasianidae',
#    'order': 'Galliformes',
#    'ebird_species_code': 'rufgro'},
#   {'common_name': 'Willow Ptarmigan',
#    'scientific_name': 'Lagopus lagopus',
#    'family_common_name': 'Pheasants, Grouse, and Allies',
#    'family': 'Phasianidae',
#    'order': 'Galliformes',
#    'ebird_species_code': 'wilpta'},
#   {'common_name': 'Spruce Grouse',
#    'scientific_name': 'Canachites canadensis',
#    'family_common_name': 'Pheasants, Grouse, and Allies',
#    'family': 'Phasianidae',
#    'order': 'Galliformes',
#    'ebird_species_code': 'sprgro'},
#   {'common_name': 'Ring-necked Pheasant',
#    'scientific_name': 'Phasianus colchicus',
#    'family_common_name': 'Pheasants, Grouse, and Allies',
#    'family': 'Phasianidae',
#    'order': 'Galliformes',
#    'ebird_species_code': 'rinphe1'},
#   {'common_name': 'Indian Peafowl',
#    'scientific_name': 'Pavo cristatus',
#    'family_common_name': 'Pheasants, Grouse, and Allies',
#    'family': 'Phasianidae',
#    'order': 'Galliformes',
#    'ebird_species_code': 'compea'},
#   {'common_name': 'Red Junglefowl',
#    'scientific_name': 'Gallus gallus',
#    'family_common_name': 'Pheasants, Grouse, and Allies',
#    'family': 'Phasianidae',
#    'order': 'Galliformes',
#    'ebird_species_code': 'redjun'},
#   {'common_name': 'Chukar',
#    'scientific_name': 'Alectoris chukar',
#    'family_common_name': 'Pheasants, Grouse, and Allies',
#    'family': 'Phasianidae',
#    'order': 'Galliformes',
#    'ebird_species_code': 'chukar'},
#   {'common_name': 'Rock Pigeon',
#    'scientific_name': 'Columba livia',
#    'family_common_name': 'Pigeons and Doves',
#    'family': 'Columbidae',
#    'order': 'Columbiformes',
#    'ebird_species_code': 'rocpig'},
#   {'common_name': 'Band-tailed Pigeon',
#    'scientific_name': 'Patagioenas fasciata',
#    'family_common_name': 'Pigeons and Doves',
#    'family': 'Columbidae',
#    'order': 'Columbiformes',
#    'ebird_species_code': 'batpig1'},
#   {'common_name': 'Eurasian Collared-Dove',
#    'scientific_name': 'Streptopelia decaocto',
#    'family_common_name': 'Pigeons and Doves',
#    'family': 'Columbidae',
#    'order': 'Columbiformes',
#    'ebird_species_code': 'eucdov'},
#   {'common_name': 'African Collared-Dove',
#    'scientific_name': 'Streptopelia roseogrisea',
#    'family_common_name': 'Pigeons and Doves',
#    'family': 'Columbidae',
#    'order': 'Columbiformes',
#    'ebird_species_code': 'afcdov1'},
#   {'common_name': 'White-winged Dove',
#    'scientific_name': 'Zenaida asiatica',
#    'family_common_name': 'Pigeons and Doves',
#    'family': 'Columbidae',
#    'order': 'Columbiformes',
#    'ebird_species_code': 'whwdov'},
#   {'common_name': 'Mourning Dove',
#    'scientific_name': 'Zenaida macroura',
#    'family_common_name': 'Pigeons and Doves',
#    'family': 'Columbidae',
#    'order': 'Columbiformes',
#    'ebird_species_code': 'moudov'},
#   {'common_name': 'Yellow-billed Cuckoo',
#    'scientific_name': 'Coccyzus americanus',
#    'family_common_name': 'Cuckoos',
#    'family': 'Cuculidae',
#    'order': 'Cuculiformes',
#    'ebird_species_code': 'yebcuc'},
#   {'common_name': 'Black-billed Cuckoo',
#    'scientific_name': 'Coccyzus erythropthalmus',
#    'family_common_name': 'Cuckoos',
#    'family': 'Cuculidae',
#    'order': 'Cuculiformes',
#    'ebird_species_code': 'bkbcuc'},
#   {'common_name': 'Common Nighthawk',
#    'scientific_name': 'Chordeiles minor',
#    'family_common_name': 'Nightjars and Allies',
#    'family': 'Caprimulgidae',
#    'order': 'Caprimulgiformes',
#    'ebird_species_code': 'comnig'},
#   {'common_name': "Chuck-will's-widow",
#    'scientific_name': 'Antrostomus carolinensis',
#    'family_common_name': 'Nightjars and Allies',
#    'family': 'Caprimulgidae',
#    'order': 'Caprimulgiformes',
#    'ebird_species_code': 'chwwid'},
#   {'common_name': 'Eastern Whip-poor-will',
#    'scientific_name': 'Antrostomus vociferus',
#    'family_common_name': 'Nightjars and Allies',
#    'family': 'Caprimulgidae',
#    'order': 'Caprimulgiformes',
#    'ebird_species_code': 'easwpw1'},
#   {'common_name': 'Chimney Swift',
#    'scientific_name': 'Chaetura pelagica',
#    'family_common_name': 'Swifts',
#    'family': 'Apodidae',
#    'order': 'Apodiformes',
#    'ebird_species_code': 'chiswi'},
#   {'common_name': 'Mexican Violetear',
#    'scientific_name': 'Colibri thalassinus',
#    'family_common_name': 'Hummingbirds',
#    'family': 'Trochilidae',
#    'order': 'Apodiformes',
#    'ebird_species_code': 'grnvie1'},
#   {'common_name': 'Ruby-throated Hummingbird',
#    'scientific_name': 'Archilochus colubris',
#    'family_common_name': 'Hummingbirds',
#    'family': 'Trochilidae',
#    'order': 'Apodiformes',
#    'ebird_species_code': 'rthhum'},
#   {'common_name': 'Calliope Hummingbird',
#    'scientific_name': 'Selasphorus calliope',
#    'family_common_name': 'Hummingbirds',
#    'family': 'Trochilidae',
#    'order': 'Apodiformes',
#    'ebird_species_code': 'calhum'},
#   {'common_name': 'Rufous Hummingbird',
#    'scientific_name': 'Selasphorus rufus',
#    'family_common_name': 'Hummingbirds',
#    'family': 'Trochilidae',
#    'order': 'Apodiformes',
#    'ebird_species_code': 'rufhum'},
#   {'common_name': 'Broad-tailed Hummingbird',
#    'scientific_name': 'Selasphorus platycercus',
#    'family_common_name': 'Hummingbirds',
#    'family': 'Trochilidae',
#    'order': 'Apodiformes',
#    'ebird_species_code': 'brthum'},
#   {'common_name': 'King Rail',
#    'scientific_name': 'Rallus elegans',
#    'family_common_name': 'Rails, Gallinules, and Coots',
#    'family': 'Rallidae',
#    'order': 'Gruiformes',
#    'ebird_species_code': 'kinrai4'},
#   {'common_name': 'Clapper Rail',
#    'scientific_name': 'Rallus crepitans',
#    'family_common_name': 'Rails, Gallinules, and Coots',
#    'family': 'Rallidae',
#    'order': 'Gruiformes',
#    'ebird_species_code': 'clarai11'},
#   {'common_name': 'Virginia Rail',
#    'scientific_name': 'Rallus limicola',
#    'family_common_name': 'Rails, Gallinules, and Coots',
#    'family': 'Rallidae',
#    'order': 'Gruiformes',
#    'ebird_species_code': 'virrai'},
#   {'common_name': 'Corn Crake',
#    'scientific_name': 'Crex crex',
#    'family_common_name': 'Rails, Gallinules, and Coots',
#    'family': 'Rallidae',
#    'order': 'Gruiformes',
#    'ebird_species_code': 'corcra'},
#   {'common_name': 'Sora',
#    'scientific_name': 'Porzana carolina',
#    'family_common_name': 'Rails, Gallinules, and Coots',
#    'family': 'Rallidae',
#    'order': 'Gruiformes',
#    'ebird_species_code': 'sora'},
#   {'common_name': 'Common Gallinule',
#    'scientific_name': 'Gallinula galeata',
#    'family_common_name': 'Rails, Gallinules, and Coots',
#    'family': 'Rallidae',
#    'order': 'Gruiformes',
#    'ebird_species_code': 'comgal1'},
#   {'common_name': 'American Coot',
#    'scientific_name': 'Fulica americana',
#    'family_common_name': 'Rails, Gallinules, and Coots',
#    'family': 'Rallidae',
#    'order': 'Gruiformes',
#    'ebird_species_code': 'y00475'},
#   {'common_name': 'Purple Gallinule',
#    'scientific_name': 'Porphyrio martinica',
#    'family_common_name': 'Rails, Gallinules, and Coots',
#    'family': 'Rallidae',
#    'order': 'Gruiformes',
#    'ebird_species_code': 'purgal2'},
#   {'common_name': 'Yellow Rail',
#    'scientific_name': 'Coturnicops noveboracensis',
#    'family_common_name': 'Rails, Gallinules, and Coots',
#    'family': 'Rallidae',
#    'order': 'Gruiformes',
#    'ebird_species_code': 'yelrai'},
#   {'common_name': 'Sandhill Crane',
#    'scientific_name': 'Antigone canadensis',
#    'family_common_name': 'Cranes',
#    'family': 'Gruidae',
#    'order': 'Gruiformes',
#    'ebird_species_code': 'sancra'},
#   {'common_name': 'Black-necked Stilt',
#    'scientific_name': 'Himantopus mexicanus',
#    'family_common_name': 'Stilts and Avocets',
#    'family': 'Recurvirostridae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'bknsti'},
#   {'common_name': 'American Avocet',
#    'scientific_name': 'Recurvirostra americana',
#    'family_common_name': 'Stilts and Avocets',
#    'family': 'Recurvirostridae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'ameavo'},
#   {'common_name': 'American Oystercatcher',
#    'scientific_name': 'Haematopus palliatus',
#    'family_common_name': 'Oystercatchers',
#    'family': 'Haematopodidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'ameoys'},
#   {'common_name': 'Black-bellied Plover',
#    'scientific_name': 'Pluvialis squatarola',
#    'family_common_name': 'Plovers and Lapwings',
#    'family': 'Charadriidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'bkbplo'},
#   {'common_name': 'European Golden-Plover',
#    'scientific_name': 'Pluvialis apricaria',
#    'family_common_name': 'Plovers and Lapwings',
#    'family': 'Charadriidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'eugplo'},
#   {'common_name': 'American Golden-Plover',
#    'scientific_name': 'Pluvialis dominica',
#    'family_common_name': 'Plovers and Lapwings',
#    'family': 'Charadriidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'amgplo'},
#   {'common_name': 'Pacific Golden-Plover',
#    'scientific_name': 'Pluvialis fulva',
#    'family_common_name': 'Plovers and Lapwings',
#    'family': 'Charadriidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'pagplo'},
#   {'common_name': 'Killdeer',
#    'scientific_name': 'Charadrius vociferus',
#    'family_common_name': 'Plovers and Lapwings',
#    'family': 'Charadriidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'killde'},
#   {'common_name': 'Common Ringed Plover',
#    'scientific_name': 'Charadrius hiaticula',
#    'family_common_name': 'Plovers and Lapwings',
#    'family': 'Charadriidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'corplo'},
#   {'common_name': 'Semipalmated Plover',
#    'scientific_name': 'Charadrius semipalmatus',
#    'family_common_name': 'Plovers and Lapwings',
#    'family': 'Charadriidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'semplo'},
#   {'common_name': 'Piping Plover',
#    'scientific_name': 'Charadrius melodus',
#    'family_common_name': 'Plovers and Lapwings',
#    'family': 'Charadriidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'pipplo'},
#   {'common_name': 'Northern Lapwing',
#    'scientific_name': 'Vanellus vanellus',
#    'family_common_name': 'Plovers and Lapwings',
#    'family': 'Charadriidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'norlap'},
#   {'common_name': "Wilson's Plover",
#    'scientific_name': 'Anarhynchus wilsonia',
#    'family_common_name': 'Plovers and Lapwings',
#    'family': 'Charadriidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'wilplo'},
#   {'common_name': 'Snowy Plover',
#    'scientific_name': 'Anarhynchus nivosus',
#    'family_common_name': 'Plovers and Lapwings',
#    'family': 'Charadriidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'snoplo5'},
#   {'common_name': 'Upland Sandpiper',
#    'scientific_name': 'Bartramia longicauda',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'uplsan'},
#   {'common_name': 'Hudsonian Whimbrel',
#    'scientific_name': 'Numenius hudsonicus',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'whimbr3'},
#   {'common_name': 'Eurasian Whimbrel',
#    'scientific_name': 'Numenius phaeopus',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'whimbr5'},
#   {'common_name': 'Eskimo Curlew',
#    'scientific_name': 'Numenius borealis',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'eskcur'},
#   {'common_name': 'Bar-tailed Godwit',
#    'scientific_name': 'Limosa lapponica',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'batgod'},
#   {'common_name': 'Hudsonian Godwit',
#    'scientific_name': 'Limosa haemastica',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'hudgod'},
#   {'common_name': 'Marbled Godwit',
#    'scientific_name': 'Limosa fedoa',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'margod'},
#   {'common_name': 'Short-billed Dowitcher',
#    'scientific_name': 'Limnodromus griseus',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'shbdow'},
#   {'common_name': 'Long-billed Dowitcher',
#    'scientific_name': 'Limnodromus scolopaceus',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'lobdow'},
#   {'common_name': 'American Woodcock',
#    'scientific_name': 'Scolopax minor',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'amewoo'},
#   {'common_name': "Wilson's Snipe",
#    'scientific_name': 'Gallinago delicata',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'wilsni1'},
#   {'common_name': "Wilson's Phalarope",
#    'scientific_name': 'Phalaropus tricolor',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'wilpha'},
#   {'common_name': 'Red Phalarope',
#    'scientific_name': 'Phalaropus fulicarius',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'redpha1'},
#   {'common_name': 'Red-necked Phalarope',
#    'scientific_name': 'Phalaropus lobatus',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'renpha'},
#   {'common_name': 'Spotted Sandpiper',
#    'scientific_name': 'Actitis macularius',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'sposan'},
#   {'common_name': 'Solitary Sandpiper',
#    'scientific_name': 'Tringa solitaria',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'solsan'},
#   {'common_name': 'Gray-tailed Tattler',
#    'scientific_name': 'Tringa brevipes',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'gyttat1'},
#   {'common_name': 'Lesser Yellowlegs',
#    'scientific_name': 'Tringa flavipes',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'lesyel'},
#   {'common_name': 'Willet',
#    'scientific_name': 'Tringa semipalmata',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'willet1'},
#   {'common_name': 'Greater Yellowlegs',
#    'scientific_name': 'Tringa melanoleuca',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'greyel'},
#   {'common_name': 'Ruddy Turnstone',
#    'scientific_name': 'Arenaria interpres',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'rudtur'},
#   {'common_name': 'Great Knot',
#    'scientific_name': 'Calidris tenuirostris',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'grekno'},
#   {'common_name': 'Red Knot',
#    'scientific_name': 'Calidris canutus',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'redkno'},
#   {'common_name': 'Surfbird',
#    'scientific_name': 'Calidris virgata',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'surfbi'},
#   {'common_name': 'Ruff',
#    'scientific_name': 'Calidris pugnax',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'ruff'},
#   {'common_name': 'Curlew Sandpiper',
#    'scientific_name': 'Calidris ferruginea',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'cursan'},
#   {'common_name': 'Stilt Sandpiper',
#    'scientific_name': 'Calidris himantopus',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'stisan'},
#   {'common_name': 'Red-necked Stint',
#    'scientific_name': 'Calidris ruficollis',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'rensti'},
#   {'common_name': 'Buff-breasted Sandpiper',
#    'scientific_name': 'Calidris subruficollis',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'bubsan'},
#   {'common_name': 'Sanderling',
#    'scientific_name': 'Calidris alba',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'sander'},
#   {'common_name': 'Dunlin',
#    'scientific_name': 'Calidris alpina',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'dunlin'},
#   {'common_name': 'Purple Sandpiper',
#    'scientific_name': 'Calidris maritima',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'pursan'},
#   {'common_name': "Baird's Sandpiper",
#    'scientific_name': 'Calidris bairdii',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'baisan'},
#   {'common_name': 'White-rumped Sandpiper',
#    'scientific_name': 'Calidris fuscicollis',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'whrsan'},
#   {'common_name': 'Dunlin x White-rumped Sandpiper (hybrid)',
#    'scientific_name': 'Calidris alpina x fuscicollis',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'x00430'},
#   {'common_name': 'Least Sandpiper',
#    'scientific_name': 'Calidris minutilla',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'leasan'},
#   {'common_name': 'Pectoral Sandpiper',
#    'scientific_name': 'Calidris melanotos',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'pecsan'},
#   {'common_name': 'Western Sandpiper',
#    'scientific_name': 'Calidris mauri',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'wessan'},
#   {'common_name': 'Semipalmated Sandpiper',
#    'scientific_name': 'Calidris pusilla',
#    'family_common_name': 'Sandpipers and Allies',
#    'family': 'Scolopacidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'semsan'},
#   {'common_name': 'Long-tailed Jaeger',
#    'scientific_name': 'Stercorarius longicaudus',
#    'family_common_name': 'Skuas and Jaegers',
#    'family': 'Stercorariidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'lotjae'},
#   {'common_name': 'Parasitic Jaeger',
#    'scientific_name': 'Stercorarius parasiticus',
#    'family_common_name': 'Skuas and Jaegers',
#    'family': 'Stercorariidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'parjae'},
#   {'common_name': 'Pomarine Jaeger',
#    'scientific_name': 'Stercorarius pomarinus',
#    'family_common_name': 'Skuas and Jaegers',
#    'family': 'Stercorariidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'pomjae'},
#   {'common_name': 'Great Skua',
#    'scientific_name': 'Stercorarius skua',
#    'family_common_name': 'Skuas and Jaegers',
#    'family': 'Stercorariidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'gresku1'},
#   {'common_name': 'South Polar Skua',
#    'scientific_name': 'Stercorarius maccormicki',
#    'family_common_name': 'Skuas and Jaegers',
#    'family': 'Stercorariidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'sopsku1'},
#   {'common_name': 'Tufted Puffin',
#    'scientific_name': 'Fratercula cirrhata',
#    'family_common_name': 'Auks, Murres, and Puffins',
#    'family': 'Alcidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'tufpuf'},
#   {'common_name': 'Atlantic Puffin',
#    'scientific_name': 'Fratercula arctica',
#    'family_common_name': 'Auks, Murres, and Puffins',
#    'family': 'Alcidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'atlpuf'},
#   {'common_name': 'Black Guillemot',
#    'scientific_name': 'Cepphus grylle',
#    'family_common_name': 'Auks, Murres, and Puffins',
#    'family': 'Alcidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'blkgui'},
#   {'common_name': 'Razorbill',
#    'scientific_name': 'Alca torda',
#    'family_common_name': 'Auks, Murres, and Puffins',
#    'family': 'Alcidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'razorb'},
#   {'common_name': 'Dovekie',
#    'scientific_name': 'Alle alle',
#    'family_common_name': 'Auks, Murres, and Puffins',
#    'family': 'Alcidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'doveki'},
#   {'common_name': 'Thick-billed Murre',
#    'scientific_name': 'Uria lomvia',
#    'family_common_name': 'Auks, Murres, and Puffins',
#    'family': 'Alcidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'thbmur'},
#   {'common_name': 'Common Murre',
#    'scientific_name': 'Uria aalge',
#    'family_common_name': 'Auks, Murres, and Puffins',
#    'family': 'Alcidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'commur'},
#   {'common_name': 'Ancient Murrelet',
#    'scientific_name': 'Synthliboramphus antiquus',
#    'family_common_name': 'Auks, Murres, and Puffins',
#    'family': 'Alcidae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'ancmur'},
#   {'common_name': 'Little Gull',
#    'scientific_name': 'Hydrocoloeus minutus',
#    'family_common_name': 'Gulls, Terns, and Skimmers',
#    'family': 'Laridae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'litgul'},
#   {'common_name': 'Black-legged Kittiwake',
#    'scientific_name': 'Rissa tridactyla',
#    'family_common_name': 'Gulls, Terns, and Skimmers',
#    'family': 'Laridae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'bklkit'},
#   {'common_name': 'Ivory Gull',
#    'scientific_name': 'Pagophila eburnea',
#    'family_common_name': 'Gulls, Terns, and Skimmers',
#    'family': 'Laridae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'ivogul'},
#   {'common_name': "Sabine's Gull",
#    'scientific_name': 'Xema sabini',
#    'family_common_name': 'Gulls, Terns, and Skimmers',
#    'family': 'Laridae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'sabgul'},
#   {'common_name': "Bonaparte's Gull",
#    'scientific_name': 'Chroicocephalus philadelphia',
#    'family_common_name': 'Gulls, Terns, and Skimmers',
#    'family': 'Laridae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'bongul'},
#   {'common_name': 'Black-headed Gull',
#    'scientific_name': 'Chroicocephalus ridibundus',
#    'family_common_name': 'Gulls, Terns, and Skimmers',
#    'family': 'Laridae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'bkhgul'},
#   {'common_name': 'Laughing Gull',
#    'scientific_name': 'Leucophaeus atricilla',
#    'family_common_name': 'Gulls, Terns, and Skimmers',
#    'family': 'Laridae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'laugul'},
#   {'common_name': "Franklin's Gull",
#    'scientific_name': 'Leucophaeus pipixcan',
#    'family_common_name': 'Gulls, Terns, and Skimmers',
#    'family': 'Laridae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'fragul'},
#   {'common_name': 'Common Gull',
#    'scientific_name': 'Larus canus',
#    'family_common_name': 'Gulls, Terns, and Skimmers',
#    'family': 'Laridae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'mewgul'},
#   {'common_name': 'Short-billed Gull',
#    'scientific_name': 'Larus brachyrhynchus',
#    'family_common_name': 'Gulls, Terns, and Skimmers',
#    'family': 'Laridae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'mewgul2'},
#   {'common_name': 'Ring-billed Gull',
#    'scientific_name': 'Larus delawarensis',
#    'family_common_name': 'Gulls, Terns, and Skimmers',
#    'family': 'Laridae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'ribgul'},
#   {'common_name': 'Black-headed x Ring-billed Gull (hybrid)',
#    'scientific_name': 'Chroicocephalus ridibundus x larus delawarensis',
#    'family_common_name': 'Gulls, Terns, and Skimmers',
#    'family': 'Laridae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'x00641'},
#   {'common_name': 'American Herring Gull',
#    'scientific_name': 'Larus smithsonianus',
#    'family_common_name': 'Gulls, Terns, and Skimmers',
#    'family': 'Laridae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'amhgul1'},
#   {'common_name': 'Great Black-backed Gull',
#    'scientific_name': 'Larus marinus',
#    'family_common_name': 'Gulls, Terns, and Skimmers',
#    'family': 'Laridae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'gbbgul'},
#   {'common_name': 'American Herring x Great Black-backed Gull (hybrid)',
#    'scientific_name': 'Larus smithsonianus x marinus',
#    'family_common_name': 'Gulls, Terns, and Skimmers',
#    'family': 'Laridae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'x00047'},
#   {'common_name': 'Glaucous Gull',
#    'scientific_name': 'Larus hyperboreus',
#    'family_common_name': 'Gulls, Terns, and Skimmers',
#    'family': 'Laridae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'glagul'},
#   {'common_name': 'American Herring x Glaucous Gull (hybrid)',
#    'scientific_name': 'Larus smithsonianus x hyperboreus',
#    'family_common_name': 'Gulls, Terns, and Skimmers',
#    'family': 'Laridae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'x01131'},
#   {'common_name': 'Lesser Black-backed Gull',
#    'scientific_name': 'Larus fuscus',
#    'family_common_name': 'Gulls, Terns, and Skimmers',
#    'family': 'Laridae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'lbbgul'},
#   {'common_name': 'American Herring x Lesser Black-backed Gull (hybrid)',
#    'scientific_name': 'Larus smithsonianus x fuscus',
#    'family_common_name': 'Gulls, Terns, and Skimmers',
#    'family': 'Laridae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'x01134'},
#   {'common_name': 'Slaty-backed Gull',
#    'scientific_name': 'Larus schistisagus',
#    'family_common_name': 'Gulls, Terns, and Skimmers',
#    'family': 'Laridae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'slbgul'},
#   {'common_name': 'Iceland Gull',
#    'scientific_name': 'Larus glaucoides',
#    'family_common_name': 'Gulls, Terns, and Skimmers',
#    'family': 'Laridae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'y00478'},
#   {'common_name': 'Black Skimmer',
#    'scientific_name': 'Rynchops niger',
#    'family_common_name': 'Gulls, Terns, and Skimmers',
#    'family': 'Laridae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'blkski'},
#   {'common_name': 'Sooty Tern',
#    'scientific_name': 'Onychoprion fuscatus',
#    'family_common_name': 'Gulls, Terns, and Skimmers',
#    'family': 'Laridae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'sooter1'},
#   {'common_name': 'Bridled Tern',
#    'scientific_name': 'Onychoprion anaethetus',
#    'family_common_name': 'Gulls, Terns, and Skimmers',
#    'family': 'Laridae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'briter1'},
#   {'common_name': 'Least Tern',
#    'scientific_name': 'Sternula antillarum',
#    'family_common_name': 'Gulls, Terns, and Skimmers',
#    'family': 'Laridae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'leater1'},
#   {'common_name': 'Gull-billed Tern',
#    'scientific_name': 'Gelochelidon nilotica',
#    'family_common_name': 'Gulls, Terns, and Skimmers',
#    'family': 'Laridae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'gubter2'},
#   {'common_name': 'Caspian Tern',
#    'scientific_name': 'Hydroprogne caspia',
#    'family_common_name': 'Gulls, Terns, and Skimmers',
#    'family': 'Laridae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'caster1'},
#   {'common_name': 'Black Tern',
#    'scientific_name': 'Chlidonias niger',
#    'family_common_name': 'Gulls, Terns, and Skimmers',
#    'family': 'Laridae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'blkter'},
#   {'common_name': 'White-winged Tern',
#    'scientific_name': 'Chlidonias leucopterus',
#    'family_common_name': 'Gulls, Terns, and Skimmers',
#    'family': 'Laridae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'whwter'},
#   {'common_name': "Forster's Tern",
#    'scientific_name': 'Sterna forsteri',
#    'family_common_name': 'Gulls, Terns, and Skimmers',
#    'family': 'Laridae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'forter'},
#   {'common_name': 'Arctic Tern',
#    'scientific_name': 'Sterna paradisaea',
#    'family_common_name': 'Gulls, Terns, and Skimmers',
#    'family': 'Laridae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'arcter'},
#   {'common_name': 'Common Tern',
#    'scientific_name': 'Sterna hirundo',
#    'family_common_name': 'Gulls, Terns, and Skimmers',
#    'family': 'Laridae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'comter'},
#   {'common_name': 'Common x Arctic Tern (hybrid)',
#    'scientific_name': 'Sterna hirundo x paradisaea',
#    'family_common_name': 'Gulls, Terns, and Skimmers',
#    'family': 'Laridae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'x00910'},
#   {'common_name': 'Roseate Tern',
#    'scientific_name': 'Sterna dougallii',
#    'family_common_name': 'Gulls, Terns, and Skimmers',
#    'family': 'Laridae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'roster'},
#   {'common_name': 'Sandwich Tern',
#    'scientific_name': 'Thalasseus sandvicensis',
#    'family_common_name': 'Gulls, Terns, and Skimmers',
#    'family': 'Laridae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'santer1'},
#   {'common_name': 'Royal Tern',
#    'scientific_name': 'Thalasseus maximus',
#    'family_common_name': 'Gulls, Terns, and Skimmers',
#    'family': 'Laridae',
#    'order': 'Charadriiformes',
#    'ebird_species_code': 'royter1'},
#   {'common_name': 'Pied-billed Grebe',
#    'scientific_name': 'Podilymbus podiceps',
#    'family_common_name': 'Grebes',
#    'family': 'Podicipedidae',
#    'order': 'Podicipediformes',
#    'ebird_species_code': 'pibgre'},
#   {'common_name': 'Horned Grebe',
#    'scientific_name': 'Podiceps auritus',
#    'family_common_name': 'Grebes',
#    'family': 'Podicipedidae',
#    'order': 'Podicipediformes',
#    'ebird_species_code': 'horgre'},
#   {'common_name': 'Red-necked Grebe',
#    'scientific_name': 'Podiceps grisegena',
#    'family_common_name': 'Grebes',
#    'family': 'Podicipedidae',
#    'order': 'Podicipediformes',
#    'ebird_species_code': 'rengre'},
#   {'common_name': 'Eared Grebe',
#    'scientific_name': 'Podiceps nigricollis',
#    'family_common_name': 'Grebes',
#    'family': 'Podicipedidae',
#    'order': 'Podicipediformes',
#    'ebird_species_code': 'eargre'},
#   {'common_name': 'Western Grebe',
#    'scientific_name': 'Aechmophorus occidentalis',
#    'family_common_name': 'Grebes',
#    'family': 'Podicipedidae',
#    'order': 'Podicipediformes',
#    'ebird_species_code': 'wesgre'},
#   {'common_name': "Clark's Grebe",
#    'scientific_name': 'Aechmophorus clarkii',
#    'family_common_name': 'Grebes',
#    'family': 'Podicipedidae',
#    'order': 'Podicipediformes',
#    'ebird_species_code': 'clagre'},
#   {'common_name': 'Red-billed Tropicbird',
#    'scientific_name': 'Phaethon aethereus',
#    'family_common_name': 'Tropicbirds',
#    'family': 'Phaethontidae',
#    'order': 'Phaethontiformes',
#    'ebird_species_code': 'rebtro'},
#   {'common_name': 'Red-throated Loon',
#    'scientific_name': 'Gavia stellata',
# ...
#    'ebird_species_code': 'amtspa'},
#   {'common_name': 'Fox Sparrow',
#    'scientific_name': 'Passerella iliaca',
#    'family_common_name': 'New World Sparrows',
#    'family': 'Passerellidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'foxspa'},
#   {'common_name': 'Dark-eyed Junco',
#    'scientific_name': 'Junco hyemalis',
#    'family_common_name': 'New World Sparrows',
#    'family': 'Passerellidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'daejun'},
#   {'common_name': 'White-crowned Sparrow',
#    'scientific_name': 'Zonotrichia leucophrys',
#    'family_common_name': 'New World Sparrows',
#    'family': 'Passerellidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'whcspa'},
#   {'common_name': 'White-throated Sparrow',
#    'scientific_name': 'Zonotrichia albicollis',
#    'family_common_name': 'New World Sparrows',
#    'family': 'Passerellidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'whtspa'},
#   {'common_name': 'Dark-eyed Junco x White-throated Sparrow (hybrid)',
#    'scientific_name': 'Junco hyemalis x zonotrichia albicollis',
#    'family_common_name': 'New World Sparrows',
#    'family': 'Passerellidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'x00039'},
#   {'common_name': 'Vesper Sparrow',
#    'scientific_name': 'Pooecetes gramineus',
#    'family_common_name': 'New World Sparrows',
#    'family': 'Passerellidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'vesspa'},
#   {'common_name': "Nelson's Sparrow",
#    'scientific_name': 'Ammospiza nelsoni',
#    'family_common_name': 'New World Sparrows',
#    'family': 'Passerellidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'nstspa'},
#   {'common_name': 'Saltmarsh Sparrow',
#    'scientific_name': 'Ammospiza caudacuta',
#    'family_common_name': 'New World Sparrows',
#    'family': 'Passerellidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'sstspa'},
#   {'common_name': 'Savannah Sparrow',
#    'scientific_name': 'Passerculus sandwichensis',
#    'family_common_name': 'New World Sparrows',
#    'family': 'Passerellidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'savspa'},
#   {'common_name': 'Song Sparrow',
#    'scientific_name': 'Melospiza melodia',
#    'family_common_name': 'New World Sparrows',
#    'family': 'Passerellidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'sonspa'},
#   {'common_name': "Lincoln's Sparrow",
#    'scientific_name': 'Melospiza lincolnii',
#    'family_common_name': 'New World Sparrows',
#    'family': 'Passerellidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'linspa'},
#   {'common_name': 'Swamp Sparrow',
#    'scientific_name': 'Melospiza georgiana',
#    'family_common_name': 'New World Sparrows',
#    'family': 'Passerellidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'swaspa'},
#   {'common_name': 'Eastern Towhee',
#    'scientific_name': 'Pipilo erythrophthalmus',
#    'family_common_name': 'New World Sparrows',
#    'family': 'Passerellidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'eastow'},
#   {'common_name': 'Yellow-breasted Chat',
#    'scientific_name': 'Icteria virens',
#    'family_common_name': 'Yellow-breasted Chat',
#    'family': 'Icteriidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'yebcha'},
#   {'common_name': 'Yellow-headed Blackbird',
#    'scientific_name': 'Xanthocephalus xanthocephalus',
#    'family_common_name': 'Troupials and Allies',
#    'family': 'Icteridae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'yehbla'},
#   {'common_name': 'Bobolink',
#    'scientific_name': 'Dolichonyx oryzivorus',
#    'family_common_name': 'Troupials and Allies',
#    'family': 'Icteridae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'boboli'},
#   {'common_name': 'Eastern Meadowlark',
#    'scientific_name': 'Sturnella magna',
#    'family_common_name': 'Troupials and Allies',
#    'family': 'Icteridae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'easmea'},
#   {'common_name': 'Orchard Oriole',
#    'scientific_name': 'Icterus spurius',
#    'family_common_name': 'Troupials and Allies',
#    'family': 'Icteridae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'orcori'},
#   {'common_name': 'Baltimore Oriole',
#    'scientific_name': 'Icterus galbula',
#    'family_common_name': 'Troupials and Allies',
#    'family': 'Icteridae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'balori'},
#   {'common_name': 'Red-winged Blackbird',
#    'scientific_name': 'Agelaius phoeniceus',
#    'family_common_name': 'Troupials and Allies',
#    'family': 'Icteridae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'rewbla'},
#   {'common_name': 'Brown-headed Cowbird',
#    'scientific_name': 'Molothrus ater',
#    'family_common_name': 'Troupials and Allies',
#    'family': 'Icteridae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'bnhcow'},
#   {'common_name': 'Rusty Blackbird',
#    'scientific_name': 'Euphagus carolinus',
#    'family_common_name': 'Troupials and Allies',
#    'family': 'Icteridae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'rusbla'},
#   {'common_name': "Brewer's Blackbird",
#    'scientific_name': 'Euphagus cyanocephalus',
#    'family_common_name': 'Troupials and Allies',
#    'family': 'Icteridae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'brebla'},
#   {'common_name': 'Common Grackle',
#    'scientific_name': 'Quiscalus quiscula',
#    'family_common_name': 'Troupials and Allies',
#    'family': 'Icteridae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'comgra'},
#   {'common_name': 'Ovenbird',
#    'scientific_name': 'Seiurus aurocapilla',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'ovenbi1'},
#   {'common_name': 'Worm-eating Warbler',
#    'scientific_name': 'Helmitheros vermivorum',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'woewar1'},
#   {'common_name': 'Louisiana Waterthrush',
#    'scientific_name': 'Parkesia motacilla',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'louwat'},
#   {'common_name': 'Northern Waterthrush',
#    'scientific_name': 'Parkesia noveboracensis',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'norwat'},
#   {'common_name': 'Golden-winged Warbler',
#    'scientific_name': 'Vermivora chrysoptera',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'gowwar'},
#   {'common_name': 'Blue-winged Warbler',
#    'scientific_name': 'Vermivora cyanoptera',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'buwwar'},
#   {'common_name': "Brewster's Warbler (hybrid)",
#    'scientific_name': 'Vermivora chrysoptera x cyanoptera (f1 hybrid)',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'brewar'},
#   {'common_name': 'Black-and-white Warbler',
#    'scientific_name': 'Mniotilta varia',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'bawwar'},
#   {'common_name': 'Prothonotary Warbler',
#    'scientific_name': 'Protonotaria citrea',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'prowar'},
#   {'common_name': 'Tennessee Warbler',
#    'scientific_name': 'Leiothlypis peregrina',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'tenwar'},
#   {'common_name': 'Orange-crowned Warbler',
#    'scientific_name': 'Leiothlypis celata',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'orcwar'},
#   {'common_name': 'Nashville Warbler',
#    'scientific_name': 'Leiothlypis ruficapilla',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'naswar'},
#   {'common_name': 'Connecticut Warbler',
#    'scientific_name': 'Oporornis agilis',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'conwar'},
#   {'common_name': "MacGillivray's Warbler",
#    'scientific_name': 'Geothlypis tolmiei',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'macwar'},
#   {'common_name': 'Mourning Warbler',
#    'scientific_name': 'Geothlypis philadelphia',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'mouwar'},
#   {'common_name': 'Kentucky Warbler',
#    'scientific_name': 'Geothlypis formosa',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'kenwar'},
#   {'common_name': 'Common Yellowthroat',
#    'scientific_name': 'Geothlypis trichas',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'comyel'},
#   {'common_name': 'Hooded Warbler',
#    'scientific_name': 'Setophaga citrina',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'hoowar'},
#   {'common_name': 'American Redstart',
#    'scientific_name': 'Setophaga ruticilla',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'amered'},
#   {'common_name': 'Cape May Warbler',
#    'scientific_name': 'Setophaga tigrina',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'camwar'},
#   {'common_name': 'Cerulean Warbler',
#    'scientific_name': 'Setophaga cerulea',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'cerwar'},
#   {'common_name': 'Northern Parula',
#    'scientific_name': 'Setophaga americana',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'norpar'},
#   {'common_name': 'Magnolia Warbler',
#    'scientific_name': 'Setophaga magnolia',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'magwar'},
#   {'common_name': 'Bay-breasted Warbler',
#    'scientific_name': 'Setophaga castanea',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'babwar'},
#   {'common_name': 'Blackburnian Warbler',
#    'scientific_name': 'Setophaga fusca',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'bkbwar'},
#   {'common_name': 'Northern Yellow Warbler',
#    'scientific_name': 'Setophaga aestiva',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'yelwar1'},
#   {'common_name': 'Chestnut-sided Warbler',
#    'scientific_name': 'Setophaga pensylvanica',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'chswar'},
#   {'common_name': 'Blackpoll Warbler',
#    'scientific_name': 'Setophaga striata',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'bkpwar'},
#   {'common_name': 'Black-throated Blue Warbler',
#    'scientific_name': 'Setophaga caerulescens',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'btbwar'},
#   {'common_name': 'Palm Warbler',
#    'scientific_name': 'Setophaga palmarum',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'palwar'},
#   {'common_name': 'Pine Warbler',
#    'scientific_name': 'Setophaga pinus',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'pinwar'},
#   {'common_name': 'Yellow-rumped Warbler',
#    'scientific_name': 'Setophaga coronata',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'yerwar'},
#   {'common_name': 'Yellow-throated Warbler',
#    'scientific_name': 'Setophaga dominica',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'yetwar'},
#   {'common_name': 'Prairie Warbler',
#    'scientific_name': 'Setophaga discolor',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'prawar'},
#   {'common_name': "Townsend's Warbler",
#    'scientific_name': 'Setophaga townsendi',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'towwar'},
#   {'common_name': 'Black-throated Green Warbler',
#    'scientific_name': 'Setophaga virens',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'btnwar'},
#   {'common_name': 'Canada Warbler',
#    'scientific_name': 'Cardellina canadensis',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'canwar'},
#   {'common_name': "Wilson's Warbler",
#    'scientific_name': 'Cardellina pusilla',
#    'family_common_name': 'New World Warblers',
#    'family': 'Parulidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'wlswar'},
#   {'common_name': 'Summer Tanager',
#    'scientific_name': 'Piranga rubra',
#    'family_common_name': 'Cardinals and Allies',
#    'family': 'Cardinalidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'sumtan'},
#   {'common_name': 'Scarlet Tanager',
#    'scientific_name': 'Piranga olivacea',
#    'family_common_name': 'Cardinals and Allies',
#    'family': 'Cardinalidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'scatan'},
#   {'common_name': 'Western Tanager',
#    'scientific_name': 'Piranga ludoviciana',
#    'family_common_name': 'Cardinals and Allies',
#    'family': 'Cardinalidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'westan'},
#   {'common_name': 'Northern Cardinal',
#    'scientific_name': 'Cardinalis cardinalis',
#    'family_common_name': 'Cardinals and Allies',
#    'family': 'Cardinalidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'norcar'},
#   {'common_name': 'Rose-breasted Grosbeak',
#    'scientific_name': 'Pheucticus ludovicianus',
#    'family_common_name': 'Cardinals and Allies',
#    'family': 'Cardinalidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'robgro'},
#   {'common_name': 'Blue Grosbeak',
#    'scientific_name': 'Passerina caerulea',
#    'family_common_name': 'Cardinals and Allies',
#    'family': 'Cardinalidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'blugrb1'},
#   {'common_name': 'Indigo Bunting',
#    'scientific_name': 'Passerina cyanea',
#    'family_common_name': 'Cardinals and Allies',
#    'family': 'Cardinalidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'indbun'},
#   {'common_name': 'Painted Bunting',
#    'scientific_name': 'Passerina ciris',
#    'family_common_name': 'Cardinals and Allies',
#    'family': 'Cardinalidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'paibun'},
#   {'common_name': 'Dickcissel',
#    'scientific_name': 'Spiza americana',
#    'family_common_name': 'Cardinals and Allies',
#    'family': 'Cardinalidae',
#    'order': 'Passeriformes',
#    'ebird_species_code': 'dickci'}]}

# %%
import datetime
from pathlib import Path

import yaml

output_dir = Path.cwd().parent / "data"

local_tz = datetime.datetime.now().astimezone().tzinfo
d = datetime.datetime.now(tz=local_tz)
today = f"{d:%I:%M:%S %p %B %d, %Y}"

for region, species_data in region_to_species_yaml.items():
    region_code = region_codes[region]
    yaml_path = output_dir / f"{region_code}-species.yaml"
    yaml_data = {
        "region": region,
        "region_code": region_code,
        "exported_on": today,
        "species": species_data,
    }

    with yaml_path.open("w") as outfile:
        yaml.dump(yaml_data, outfile, default_flow_style=False)

# %%
# Alternative output format: Hierarchical taxonomy
from birding.taxonomies import TaxonomicClass

region_taxonomies: dict[str, TaxonomicClass] = {}

for region, species_list in region_to_species_taxons.items():
    region_taxonomy = TaxonomicClass("Aves")
    for species in species_list:
        region_taxonomy.insert_species(species)
    region_taxonomies[region] = region_taxonomy

region_taxonomies
# Out:
# {'Maine, United States': TaxonomicClass(class_name='Aves', orders={'Anseriformes': TaxonomicOrder(order_name='Anseriformes', families={'Anatidae': TaxonomicFamily(family_name='Anatidae', genera={'Dendrocygna': TaxonomicGenus(generic_name='Dendrocygna', species={'autumnalis': TaxonomicSpecies(specific_name='autumnalis')}), 'Anser': TaxonomicGenus(generic_name='Anser', species={'caerulescens': TaxonomicSpecies(specific_name='caerulescens'), 'rossii': TaxonomicSpecies(specific_name='rossii'), 'caerulescens x rossii': TaxonomicSpecies(specific_name='caerulescens x rossii'), 'anser': TaxonomicSpecies(specific_name='anser'), 'cygnoides': TaxonomicSpecies(specific_name='cygnoides'), 'albifrons': TaxonomicSpecies(specific_name='albifrons'), 'brachyrhynchus': TaxonomicSpecies(specific_name='brachyrhynchus'), 'cygnoides x Branta canadensis': TaxonomicSpecies(specific_name='cygnoides x Branta canadensis'), 'albifrons x Branta canadensis': TaxonomicSpecies(specific_name='albifrons x Branta canadensis'), 'sp. (Domestic type) x Branta canadensis': TaxonomicSpecies(specific_name='sp. (Domestic type) x Branta canadensis')}), 'Branta': TaxonomicGenus(generic_name='Branta', species={'bernicla': TaxonomicSpecies(specific_name='bernicla'), 'leucopsis': TaxonomicSpecies(specific_name='leucopsis'), 'hutchinsii': TaxonomicSpecies(specific_name='hutchinsii'), 'canadensis': TaxonomicSpecies(specific_name='canadensis')}), 'Cygnus': TaxonomicGenus(generic_name='Cygnus', species={'olor': TaxonomicSpecies(specific_name='olor'), 'atratus': TaxonomicSpecies(specific_name='atratus'), 'buccinator': TaxonomicSpecies(specific_name='buccinator'), 'columbianus': TaxonomicSpecies(specific_name='columbianus'), 'cygnus': TaxonomicSpecies(specific_name='cygnus')}), 'Alopochen': TaxonomicGenus(generic_name='Alopochen', species={'aegyptiaca': TaxonomicSpecies(specific_name='aegyptiaca')}), 'Tadorna': TaxonomicGenus(generic_name='Tadorna', species={'tadorna': TaxonomicSpecies(specific_name='tadorna')}), 'Cairina': TaxonomicGenus(generic_name='Cairina', species={'moschata': TaxonomicSpecies(specific_name='moschata'), 'moschata x Anas platyrhynchos': TaxonomicSpecies(specific_name='moschata x Anas platyrhynchos')}), 'Aix': TaxonomicGenus(generic_name='Aix', species={'sponsa': TaxonomicSpecies(specific_name='sponsa'), 'galericulata': TaxonomicSpecies(specific_name='galericulata')}), 'Spatula': TaxonomicGenus(generic_name='Spatula', species={'querquedula': TaxonomicSpecies(specific_name='querquedula'), 'discors': TaxonomicSpecies(specific_name='discors'), 'clypeata': TaxonomicSpecies(specific_name='clypeata')}), 'Mareca': TaxonomicGenus(generic_name='Mareca', species={'strepera': TaxonomicSpecies(specific_name='strepera'), 'penelope': TaxonomicSpecies(specific_name='penelope'), 'americana': TaxonomicSpecies(specific_name='americana'), 'americana x Anas platyrhynchos': TaxonomicSpecies(specific_name='americana x Anas platyrhynchos')}), 'Anas': TaxonomicGenus(generic_name='Anas', species={'platyrhynchos': TaxonomicSpecies(specific_name='platyrhynchos'), 'rubripes': TaxonomicSpecies(specific_name='rubripes'), 'platyrhynchos x rubripes': TaxonomicSpecies(specific_name='platyrhynchos x rubripes'), 'acuta': TaxonomicSpecies(specific_name='acuta'), 'platyrhynchos x acuta': TaxonomicSpecies(specific_name='platyrhynchos x acuta'), 'crecca': TaxonomicSpecies(specific_name='crecca'), 'acuta x crecca': TaxonomicSpecies(specific_name='acuta x crecca')}), 'Aythya': TaxonomicGenus(generic_name='Aythya', species={'valisineria': TaxonomicSpecies(specific_name='valisineria'), 'americana': TaxonomicSpecies(specific_name='americana'), 'collaris': TaxonomicSpecies(specific_name='collaris'), 'americana x collaris': TaxonomicSpecies(specific_name='americana x collaris'), 'fuligula': TaxonomicSpecies(specific_name='fuligula'), 'marila': TaxonomicSpecies(specific_name='marila'), 'affinis': TaxonomicSpecies(specific_name='affinis')}), 'Somateria': TaxonomicGenus(generic_name='Somateria', species={'s ...
#  'Providence, Rhode Island, United States': TaxonomicClass(class_name='Aves', orders={'Anseriformes': TaxonomicOrder(order_name='Anseriformes', families={'Anatidae': TaxonomicFamily(family_name='Anatidae', genera={'Anser': TaxonomicGenus(generic_name='Anser', species={'caerulescens': TaxonomicSpecies(specific_name='caerulescens'), 'rossii': TaxonomicSpecies(specific_name='rossii'), 'anser': TaxonomicSpecies(specific_name='anser'), 'anser x cygnoides': TaxonomicSpecies(specific_name='anser x cygnoides'), 'albifrons': TaxonomicSpecies(specific_name='albifrons'), 'brachyrhynchus': TaxonomicSpecies(specific_name='brachyrhynchus'), 'anser x Branta canadensis': TaxonomicSpecies(specific_name='anser x Branta canadensis'), 'sp. (Domestic type) x Branta canadensis': TaxonomicSpecies(specific_name='sp. (Domestic type) x Branta canadensis')}), 'Branta': TaxonomicGenus(generic_name='Branta', species={'bernicla': TaxonomicSpecies(specific_name='bernicla'), 'leucopsis': TaxonomicSpecies(specific_name='leucopsis'), 'hutchinsii': TaxonomicSpecies(specific_name='hutchinsii'), 'canadensis': TaxonomicSpecies(specific_name='canadensis')}), 'Cygnus': TaxonomicGenus(generic_name='Cygnus', species={'olor': TaxonomicSpecies(specific_name='olor'), 'buccinator': TaxonomicSpecies(specific_name='buccinator'), 'columbianus': TaxonomicSpecies(specific_name='columbianus')}), 'Cairina': TaxonomicGenus(generic_name='Cairina', species={'moschata': TaxonomicSpecies(specific_name='moschata')}), 'Aix': TaxonomicGenus(generic_name='Aix', species={'sponsa': TaxonomicSpecies(specific_name='sponsa')}), 'Spatula': TaxonomicGenus(generic_name='Spatula', species={'discors': TaxonomicSpecies(specific_name='discors'), 'cyanoptera': TaxonomicSpecies(specific_name='cyanoptera'), 'clypeata': TaxonomicSpecies(specific_name='clypeata')}), 'Mareca': TaxonomicGenus(generic_name='Mareca', species={'strepera': TaxonomicSpecies(specific_name='strepera'), 'penelope': TaxonomicSpecies(specific_name='penelope'), 'americana': TaxonomicSpecies(specific_name='americana'), 'strepera x americana': TaxonomicSpecies(specific_name='strepera x americana')}), 'Anas': TaxonomicGenus(generic_name='Anas', species={'platyrhynchos': TaxonomicSpecies(specific_name='platyrhynchos'), 'rubripes': TaxonomicSpecies(specific_name='rubripes'), 'platyrhynchos x rubripes': TaxonomicSpecies(specific_name='platyrhynchos x rubripes'), 'acuta': TaxonomicSpecies(specific_name='acuta'), 'platyrhynchos x acuta': TaxonomicSpecies(specific_name='platyrhynchos x acuta'), 'crecca': TaxonomicSpecies(specific_name='crecca')}), 'Aythya': TaxonomicGenus(generic_name='Aythya', species={'valisineria': TaxonomicSpecies(specific_name='valisineria'), 'americana': TaxonomicSpecies(specific_name='americana'), 'collaris': TaxonomicSpecies(specific_name='collaris'), 'fuligula': TaxonomicSpecies(specific_name='fuligula'), 'marila': TaxonomicSpecies(specific_name='marila'), 'affinis': TaxonomicSpecies(specific_name='affinis'), 'collaris x affinis': TaxonomicSpecies(specific_name='collaris x affinis'), 'fuligula x marila/affinis': TaxonomicSpecies(specific_name='fuligula x marila/affinis')}), 'Somateria': TaxonomicGenus(generic_name='Somateria', species={'mollissima': TaxonomicSpecies(specific_name='mollissima')}), 'Melanitta': TaxonomicGenus(generic_name='Melanitta', species={'perspicillata': TaxonomicSpecies(specific_name='perspicillata'), 'deglandi': TaxonomicSpecies(specific_name='deglandi'), 'americana': TaxonomicSpecies(specific_name='americana')}), 'Clangula': TaxonomicGenus(generic_name='Clangula', species={'hyemalis': TaxonomicSpecies(specific_name='hyemalis')}), 'Bucephala': TaxonomicGenus(generic_name='Bucephala', species={'albeola': TaxonomicSpecies(specific_name='albeola'), 'clangula': TaxonomicSpecies(specific_name='clangula'), 'islandica': TaxonomicSpecies(specific_name='islandica'), 'clangula x islandica': TaxonomicSpecies(specific_name='clangula x islandica')}), 'Lophodytes': TaxonomicGenus(generic_name='Lophodytes', s ...

# %%
local_tz = datetime.datetime.now().astimezone().tzinfo
d = datetime.datetime.now(tz=local_tz)
today = f"{d:%I:%M:%S %p %B %d, %Y}"

for region, taxonomy in region_taxonomies.items():
    region_code = region_codes[region]
    yaml_path = output_dir / f"{region_code}-hierarchy.yaml"
    yaml_data = {
        "region": region,
        "region_code": region_code,
        "exported_on": today,
        "bird_taxonomy": taxonomy.to_yaml(),
    }

    with yaml_path.open("w") as outfile:
        yaml.dump(yaml_data, outfile, default_flow_style=False)
