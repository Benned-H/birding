# %% [markdown]
# Goal: Retrieve the species checklist for a region using the eBird API.

# %%
from __future__ import annotations

# %%
from geopy.geocoders import Nominatim

geolocator = Nominatim(user_agent="eBird Checklists Notebook", timeout=10)
location = geolocator.geocode("Providence, Rhode Island")
location
# Out:
# Location(Providence, Providence County, Rhode Island, United States, (41.8239891, -71.4128343, 0.0))

# %%
print(location.address)
print(location.latitude)
print(location.longitude)
# Out:
# Providence, Providence County, Rhode Island, United States
# 41.8239891
# -71.4128343

# %%
import os

from dotenv import load_dotenv

load_dotenv()  # Read variables from a .env file and set them in os.environ
ebird_api_key = os.getenv("EBIRD_API_KEY")
assert ebird_api_key

# %%
from ebird.api.requests import get_nearby_hotspots

nearby_hotspots_raw = get_nearby_hotspots(
    token=ebird_api_key, lat=location.latitude, lng=location.longitude
)

# %%
nearby_hotspots_raw
# Out:
# [{'locId': 'L9189645',
#   'locName': 'Allen Harbor Marina',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-009',
#   'lat': 41.6197094,
#   'lng': -71.4112937,
#   'latestObsDt': '2025-11-04 15:39',
#   'numSpeciesAllTime': 121},
#  {'locId': 'L5070824',
#   'locName': "Allin's Cove (Barrington Land Trust)",
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-001',
#   'lat': 41.7442266,
#   'lng': -71.3481226,
#   'latestObsDt': '2025-11-02 14:30',
#   'numSpeciesAllTime': 123},
#  {'locId': 'L33244456',
#   'locName': 'Anthony Lawrence Wildlife Preserve',
#   'countryCode': 'US',
#   'subnational1Code': 'US-MA',
#   'subnational2Code': 'US-MA-005',
#   'lat': 41.92324,
#   'lng': -71.349151,
#   'latestObsDt': '2025-05-03 10:07',
#   'numSpeciesAllTime': 55},
#  {'locId': 'L634993',
#   'locName': 'Apponaug Cove',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-003',
#   'lat': 41.6953469,
#   'lng': -71.4527607,
#   'latestObsDt': '2025-12-09 10:11',
#   'numSpeciesAllTime': 145},
#  {'locId': 'L870123',
#   'locName': 'Arcade Ave., Seekonk',
#   'countryCode': 'US',
#   'subnational1Code': 'US-MA',
#   'subnational2Code': 'US-MA-005',
#   'lat': 41.8409524,
#   'lng': -71.3356447,
#   'latestObsDt': '2025-02-08 15:00',
#   'numSpeciesAllTime': 51},
#  {'locId': 'L450725',
#   'locName': 'Arnold Mills Reservoir, Cumberland',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.9862744,
#   'lng': -71.3969407,
#   'latestObsDt': '2025-12-12 14:45',
#   'numSpeciesAllTime': 187},
#  {'locId': 'L42925934',
#   'locName': 'Atlantic White Cedar Swamp Preserve (Cumberland Land Trust)',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.9745808,
#   'lng': -71.4355125,
#   'latestObsDt': '2025-10-18 09:26',
#   'numSpeciesAllTime': 62},
#  {'locId': 'L23891210',
#   'locName': 'Attleboro Community Garden',
#   'countryCode': 'US',
#   'subnational1Code': 'US-MA',
#   'subnational2Code': 'US-MA-005',
#   'lat': 41.9443897,
#   'lng': -71.2897038,
#   'latestObsDt': '2024-05-13 17:10',
#   'numSpeciesAllTime': 29},
#  {'locId': 'L1282270',
#   'locName': 'Attleboro Springs Wildlife Sanctuary (Mass Audubon)',
#   'countryCode': 'US',
#   'subnational1Code': 'US-MA',
#   'subnational2Code': 'US-MA-005',
#   'lat': 41.9286191,
#   'lng': -71.2647432,
#   'latestObsDt': '2025-09-26 18:29',
#   'numSpeciesAllTime': 102},
#  {'locId': 'L2875659',
#   'locName': 'Aust Family Preserve at Lime Rock (TNC)',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.924037,
#   'lng': -71.4682531,
#   'latestObsDt': '2025-11-26 10:19',
#   'numSpeciesAllTime': 99},
#  {'locId': 'L17492948',
#   'locName': 'Barney Ave./Almeida Rd. Fields, Rehoboth',
#   'countryCode': 'US',
#   'subnational1Code': 'US-MA',
#   'subnational2Code': 'US-MA-005',
#   'lat': 41.786875,
#   'lng': -71.286641,
#   'latestObsDt': '2025-11-29 15:12',
#   'numSpeciesAllTime': 43},
#  {'locId': 'L34675950',
#   'locName': 'Barney Pond, Lincoln',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.8967623,
#   'lng': -71.41608,
#   'latestObsDt': '2025-12-09 12:08',
#   'numSpeciesAllTime': 44},
#  {'locId': 'L983673',
#   'locName': 'Barrington Town Beach',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-001',
#   'lat': 41.722579,
#   'lng': -71.3087797,
#   'latestObsDt': '2025-12-08 10:44',
#   'numSpeciesAllTime': 84},
#  {'locId': 'L1670551',
#   'locName': 'Behind Home Depot in Seekonk',
#   'countryCode': 'US',
#   'subnational1Code': 'US-MA',
#   'subnational2Code': 'US-MA-005',
#   'lat': 41.7996862,
#   'lng': -71.3404841,
#   'latestObsDt': '2025-10-31 14:41',
#   'numSpeciesAllTime': 54},
#  {'locId': 'L12721457',
#   'locName': 'Belmont Park, Warwick',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-003',
#   'lat': 41.7620466,
#   'lng': -71.4219022,
#   'latestObsDt': '2024-12-15 10:25',
#   'numSpeciesAllTime': 67},
#  {'locId': 'L38649323',
#   'locName': 'Bethany Cemetery, Cranston',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.7612448,
#   'lng': -71.439414,
#   'latestObsDt': '2025-12-14 07:18',
#   'numSpeciesAllTime': 27},
#  {'locId': 'L2214089',
#   'locName': 'Big River Management Area--Carr Pond',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-003',
#   'lat': 41.6354153,
#   'lng': -71.5560842,
#   'latestObsDt': '2025-11-25 10:35',
#   'numSpeciesAllTime': 89},
#  {'locId': 'L5071219',
#   'locName': 'Big River Management Area--Model Airplane Field',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-003',
#   'lat': 41.654994,
#   'lng': -71.56379,
#   'latestObsDt': '2025-10-15 16:02',
#   'numSpeciesAllTime': 50},
#  {'locId': 'L6073694',
#   'locName': 'Big River Management Area--Sand Pit',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-003',
#   'lat': 41.6464519,
#   'lng': -71.5779448,
#   'latestObsDt': '2025-12-11 08:19',
#   'numSpeciesAllTime': 135},
#  {'locId': 'L5099232',
#   'locName': 'Big River Management Area--Tarbox Pond',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-003',
#   'lat': 41.6365854,
#   'lng': -71.5734869,
#   'latestObsDt': '2025-11-19 08:35',
#   'numSpeciesAllTime': 105},
#  {'locId': 'L2071074',
#   'locName': 'Birchwold Farm',
#   'countryCode': 'US',
#   'subnational1Code': 'US-MA',
#   'subnational2Code': 'US-MA-021',
#   'lat': 42.0231797,
#   'lng': -71.4054143,
#   'latestObsDt': '2025-11-22 14:53',
#   'numSpeciesAllTime': 118},
#  {'locId': 'L10658440',
#   'locName': 'Blackamore Pond, Cranston',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.7738778,
#   'lng': -71.4468487,
#   'latestObsDt': '2025-12-14 08:08',
#   'numSpeciesAllTime': 53},
#  {'locId': 'L6077334',
#   'locName': 'Blackstone Boulevard, Providence',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.8434142,
#   'lng': -71.386435,
#   'latestObsDt': '2025-08-27 10:12',
#   'numSpeciesAllTime': 50},
#  {'locId': 'L4423843',
#   'locName': 'Blackstone Gorge',
#   'countryCode': 'US',
#   'subnational1Code': 'US-MA',
#   'subnational2Code': 'US-MA-027',
#   'lat': 42.0151373,
#   'lng': -71.5528822,
#   'latestObsDt': '2025-11-16 15:38',
#   'numSpeciesAllTime': 93},
#  {'locId': 'L11920582',
#   'locName': 'Blackstone Gorge (RI)',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 42.0125889,
#   'lng': -71.5520399,
#   'latestObsDt': '2025-07-10 20:41',
#   'numSpeciesAllTime': 84},
#  {'locId': 'L804728',
#   'locName': 'Blackstone Park',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.833327,
#   'lng': -71.3792148,
#   'latestObsDt': '2025-12-13 14:45',
#   'numSpeciesAllTime': 197},
#  {'locId': 'L41628130',
#   'locName': 'Blackstone River Bikeway--Albion to Manville Parking Area',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.9573319,
#   'lng': -71.4622947,
#   'latestObsDt': '2025-11-28 08:19',
#   'numSpeciesAllTime': 107},
#  {'locId': 'L12894191',
#   'locName': 'Blackstone River Bikeway--Canal St.',
#   'countryCode': 'US',
#   'subnational1Code': 'US-MA',
#   'subnational2Code': 'US-MA-027',
#   'lat': 42.0165,
#   'lng': -71.538194,
#   'latestObsDt': '2025-11-25 11:05',
#   'numSpeciesAllTime': 133},
#  {'locId': 'L41527208',
#   'locName': 'Blackstone River Bikeway--Cold Spring Park to MA Border',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 42.0100697,
#   'lng': -71.528995,
#   'latestObsDt': '2025-11-22 15:55',
#   'numSpeciesAllTime': 30},
#  {'locId': 'L1615937',
#   'locName': 'Blackstone River Bikeway--Kelly House Museum to Albion Access',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.9431583,
#   'lng': -71.4372874,
#   'latestObsDt': '2025-11-29 08:24',
#   'numSpeciesAllTime': 117},
#  {'locId': 'L11516357',
#   'locName': 'Blackstone River Bikeway--Kelly House Museum to Lonsdale Drive-In',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.9247737,
#   'lng': -71.4298601,
#   'latestObsDt': '2025-12-14 08:10',
#   'numSpeciesAllTime': 113},
#  {'locId': 'L41627753',
#   'locName': 'Blackstone River Bikeway--Kelly House Trail to I-295 Visitor Center',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.9404151,
#   'lng': -71.4424413,
#   'latestObsDt': '2025-09-23 17:25',
#   'numSpeciesAllTime': 32},
#  {'locId': 'L4975633',
#   'locName': 'Blackstone River Bikeway--Lonsdale Drive-In',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.9101022,
#   'lng': -71.4004254,
#   'latestObsDt': '2025-12-10 13:59',
#   'numSpeciesAllTime': 145},
#  {'locId': 'L41628165',
#   'locName': 'Blackstone River Bikeway--Manville Access to "River\'s Edge"',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.9776132,
#   'lng': -71.4833743,
#   'latestObsDt': '2025-11-22 11:59',
#   'numSpeciesAllTime': 107},
#  {'locId': 'L8600695',
#   'locName': 'Blackstone River Bikeway--Valley Marsh',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.9027514,
#   'lng': -71.3980847,
#   'latestObsDt': '2025-12-11 10:05',
#   'numSpeciesAllTime': 161},
#  {'locId': 'L34675448',
#   'locName': 'Bleachery Pond, Lincoln',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.894042,
#   'lng': -71.4096775,
#   'latestObsDt': '2025-12-09 12:12',
#   'numSpeciesAllTime': 46},
#  {'locId': 'L2808160',
#   'locName': 'Blithewold (entry fee required)',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-001',
#   'lat': 41.6541463,
#   'lng': -71.2658536,
#   'latestObsDt': '2025-08-21 11:04',
#   'numSpeciesAllTime': 73},
#  {'locId': 'L216062',
#   'locName': 'Bold Point Park, East Providence',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.8144807,
#   'lng': -71.3901623,
#   'latestObsDt': '2025-11-06 13:46',
#   'numSpeciesAllTime': 159},
#  {'locId': 'L22351437',
#   'locName': 'Booth Pond Conservation Area & Trails',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.9803301,
#   'lng': -71.5047389,
#   'latestObsDt': '2025-12-04 09:56',
#   'numSpeciesAllTime': 120},
#  {'locId': 'L875821',
#   'locName': 'Boyden Heights Conservation Area',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.7895369,
#   'lng': -71.370433,
#   'latestObsDt': '2025-11-28 15:47',
#   'numSpeciesAllTime': 97},
#  {'locId': 'L17165257',
#   'locName': 'Boyden Park',
#   'countryCode': 'US',
#   'subnational1Code': 'US-MA',
#   'subnational2Code': 'US-MA-005',
#   'lat': 41.872801,
#   'lng': -71.125909,
#   'latestObsDt': '2025-10-19 10:54',
#   'numSpeciesAllTime': 108},
#  {'locId': 'L2683958',
#   'locName': 'Brickyard Pond & Veterans Memorial Park',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-001',
#   'lat': 41.7352359,
#   'lng': -71.3144231,
#   'latestObsDt': '2025-12-10 11:52',
#   'numSpeciesAllTime': 164},
#  {'locId': 'L44616927',
#   'locName': 'Bridgham Farm, Rumford',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.8361172,
#   'lng': -71.3457559,
#   'latestObsDt': '2025-12-01 08:50',
#   'numSpeciesAllTime': 57},
#  {'locId': 'L5133234',
#   'locName': 'Bristol Narrows',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-001',
#   'lat': 41.6971815,
#   'lng': -71.2464703,
#   'latestObsDt': '2025-11-14 09:15',
#   'numSpeciesAllTime': 79},
#  {'locId': 'L841256',
#   'locName': 'Broad Cove',
#   'countryCode': 'US',
#   'subnational1Code': 'US-MA',
#   'subnational2Code': 'US-MA-005',
#   'lat': 41.7892329,
#   'lng': -71.1252308,
#   'latestObsDt': '2025-11-30 08:20',
#   'numSpeciesAllTime': 221},
#  {'locId': 'L7801999',
#   'locName': 'Brown University Campus',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.8260753,
#   'lng': -71.403429,
#   'latestObsDt': '2025-12-10 16:39',
#   'numSpeciesAllTime': 105},
#  {'locId': 'L11866685',
#   'locName': "Bullock's Cove",
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.7601546,
#   'lng': -71.3538947,
#   'latestObsDt': '2025-12-13 11:03',
#   'numSpeciesAllTime': 109},
#  {'locId': 'L7113200',
#   'locName': "Bullock's Point (limited access)",
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.7449199,
#   'lng': -71.3578749,
#   'latestObsDt': '2025-12-14 13:10',
#   'numSpeciesAllTime': 80},
#  {'locId': 'L17262087',
#   'locName': 'Bullock’s Point Light',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.737771,
#   'lng': -71.364168,
#   'latestObsDt': '2025-04-06 15:17',
#   'numSpeciesAllTime': 6},
#  {'locId': 'L11444077',
#   'locName': 'Butler Campus',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.8443214,
#   'lng': -71.3815825,
#   'latestObsDt': '2025-09-13 14:22',
#   'numSpeciesAllTime': 85},
#  {'locId': 'L21432043',
#   'locName': 'Butterfly Farm & Pond, Lincoln',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.9070195,
#   'lng': -71.4318753,
#   'latestObsDt': '2025-11-23 10:11',
#   'numSpeciesAllTime': 63},
#  {'locId': 'L43513174',
#   'locName': 'Byron Randall Road, Scituate',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.800396,
#   'lng': -71.572942,
#   'latestObsDt': '2025-11-02 20:12',
#   'numSpeciesAllTime': 27},
#  {'locId': 'L20653314',
#   'locName': 'CCRI Lincoln',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.8953643,
#   'lng': -71.456414,
#   'latestObsDt': '2025-05-25 11:09',
#   'numSpeciesAllTime': 46},
#  {'locId': 'L5727176',
#   'locName': 'Calf Pasture Point Recreation Area--Bikepath',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-009',
#   'lat': 41.6268485,
#   'lng': -71.4154875,
#   'latestObsDt': '2025-12-06 07:43',
#   'numSpeciesAllTime': 191},
#  {'locId': 'L41322492',
#   'locName': 'Calf Pasture Point Recreation Area--Shoreline Access',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-009',
#   'lat': 41.6299993,
#   'lng': -71.4057814,
#   'latestObsDt': '2025-11-16 09:11',
#   'numSpeciesAllTime': 26},
#  {'locId': 'L30802876',
#   'locName': 'Captain Stephen Olney Memorial Park',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.855094,
#   'lng': -71.455276,
#   'latestObsDt': '2025-05-20 10:30',
#   'numSpeciesAllTime': 37},
#  {'locId': 'L734825',
#   'locName': 'Caratunk Wildlife Refuge (ASRI)',
#   'countryCode': 'US',
#   'subnational1Code': 'US-MA',
#   'subnational2Code': 'US-MA-005',
#   'lat': 41.8740347,
#   'lng': -71.3212734,
#   'latestObsDt': '2025-12-14 07:35',
#   'numSpeciesAllTime': 171},
#  {'locId': 'L25323688',
#   'locName': 'Catamint Brook Preserve (Cumberland Land Trust)',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.994465,
#   'lng': -71.43924,
#   'latestObsDt': '2025-10-18 14:47',
#   'numSpeciesAllTime': 98},
#  {'locId': 'L4658133',
#   'locName': 'Cedar Swamp Conservation Area',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.9756837,
#   'lng': -71.5357268,
#   'latestObsDt': '2025-06-11 12:25',
#   'numSpeciesAllTime': 96},
#  {'locId': 'L38376933',
#   'locName': 'Central Landfill, Johnston (limited access)',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.8075395,
#   'lng': -71.5324731,
#   'latestObsDt': '2025-11-30 12:45',
#   'numSpeciesAllTime': 84},
#  {'locId': 'L487743',
#   'locName': 'Central Pond Reservoir, East Providence',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.8591418,
#   'lng': -71.3376617,
#   'latestObsDt': '2025-03-26 17:36',
#   'numSpeciesAllTime': 92},
#  {'locId': 'L4333450',
#   'locName': 'Chase Farm, Lincoln',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.9064362,
#   'lng': -71.4288585,
#   'latestObsDt': '2025-12-03 07:21',
#   'numSpeciesAllTime': 151},
#  {'locId': 'L1391725',
#   'locName': 'Chepiwanoxet Point',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-003',
#   'lat': 41.6735417,
#   'lng': -71.4421938,
#   'latestObsDt': '2025-10-05 14:27',
#   'numSpeciesAllTime': 104},
#  {'locId': 'L734909',
#   'locName': 'Claire D. McIntosh Wildlife Refuge (ASRI)',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-001',
#   'lat': 41.7102379,
#   'lng': -71.2827596,
#   'latestObsDt': '2025-12-03 10:59',
#   'numSpeciesAllTime': 171},
#  {'locId': 'L4653581',
#   'locName': 'Coastal Greenway, Portsmouth',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-005',
#   'lat': 41.6281852,
#   'lng': -71.2611687,
#   'latestObsDt': '2025-11-09 13:20',
#   'numSpeciesAllTime': 112},
#  {'locId': 'L1406045',
#   'locName': 'Cold Spring Park, Woonsocket',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 42.0091108,
#   'lng': -71.5252876,
#   'latestObsDt': '2025-01-27 13:16',
#   'numSpeciesAllTime': 62},
#  {'locId': 'L841267',
#   'locName': 'Cole River Boat Ramp, Swansea',
#   'countryCode': 'US',
#   'subnational1Code': 'US-MA',
#   'subnational2Code': 'US-MA-005',
#   'lat': 41.7263586,
#   'lng': -71.2221336,
#   'latestObsDt': '2025-12-14 11:06',
#   'numSpeciesAllTime': 123},
#  {'locId': 'L29143732',
#   'locName': 'Collier Point Park, Providence',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.8120414,
#   'lng': -71.401773,
#   'latestObsDt': '2025-11-29 15:38',
#   'numSpeciesAllTime': 65},
#  {'locId': 'L613147',
#   'locName': 'Colt State Park',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-001',
#   'lat': 41.6806368,
#   'lng': -71.3021922,
#   'latestObsDt': '2025-12-12 11:50',
#   'numSpeciesAllTime': 241},
#  {'locId': 'L687632',
#   'locName': 'Conimicut Point Park, Warwick',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-003',
#   'lat': 41.7167491,
#   'lng': -71.360321,
#   'latestObsDt': '2025-12-06 14:14',
#   'numSpeciesAllTime': 146},
#  {'locId': 'L16672907',
#   'locName': 'Conimicut Saltmarsh, Warwick',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-003',
#   'lat': 41.7136737,
#   'lng': -71.364103,
#   'latestObsDt': '2025-12-07 13:42',
#   'numSpeciesAllTime': 76},
#  {'locId': 'L1786830',
#   'locName': 'Copps Cove',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.7813513,
#   'lng': -71.391461,
#   'latestObsDt': '2025-09-27 13:39',
#   'numSpeciesAllTime': 68},
#  {'locId': 'L9955986',
#   'locName': 'Council Oak Fields',
#   'countryCode': 'US',
#   'subnational1Code': 'US-MA',
#   'subnational2Code': 'US-MA-005',
#   'lat': 41.8190476,
#   'lng': -71.1344576,
#   'latestObsDt': '2025-11-02 08:00',
#   'numSpeciesAllTime': 105},
#  {'locId': 'L12817315',
#   'locName': 'Crescent Park, East Providence',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.7567563,
#   'lng': -71.3611223,
#   'latestObsDt': '2025-11-05 14:47',
#   'numSpeciesAllTime': 108},
#  {'locId': 'L4600100',
#   'locName': 'Crestwood Country Club',
#   'countryCode': 'US',
#   'subnational1Code': 'US-MA',
#   'subnational2Code': 'US-MA-005',
#   'lat': 41.8244527,
#   'lng': -71.277253,
#   'latestObsDt': '2025-06-08 08:00',
#   'numSpeciesAllTime': 34},
#  {'locId': 'L734901',
#   'locName': 'Davis Memorial Wildlife Refuge (ASRI)',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-009',
#   'lat': 41.6236714,
#   'lng': -71.4817259,
#   'latestObsDt': '2025-08-23 15:00',
#   'numSpeciesAllTime': 100},
#  {'locId': 'L38433651',
#   'locName': 'Davis Park, Providence',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.833365,
#   'lng': -71.430524,
#   'latestObsDt': '2025-06-08 09:02',
#   'numSpeciesAllTime': 24},
#  {'locId': 'L31398708',
#   'locName': 'Davisville Middle School Nature Paths',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-009',
#   'lat': 41.6193485,
#   'lng': -71.4648414,
#   'latestObsDt': '2025-06-27 13:55',
#   'numSpeciesAllTime': 35},
#  {'locId': 'L38630506',
#   'locName': 'Dexter Training Ground Park',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.814522,
#   'lng': -71.431343,
#   'latestObsDt': '2025-11-24 15:40',
#   'numSpeciesAllTime': 17},
#  {'locId': 'L11683398',
#   'locName': 'Diamond Hill Management Area',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 42.001108,
#   'lng': -71.431875,
#   'latestObsDt': '2025-05-31 14:20',
#   'numSpeciesAllTime': 69},
#  {'locId': 'L10059274',
#   'locName': 'Diamond Hill Park, Cumberland',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 42.0019027,
#   'lng': -71.4131983,
#   'latestObsDt': '2025-12-12 15:40',
#   'numSpeciesAllTime': 94},
#  {'locId': 'L16494250',
#   'locName': 'Diamond Hill Reservoir, Cumberland',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.997013,
#   'lng': -71.399154,
#   'latestObsDt': '2025-12-13 16:10',
#   'numSpeciesAllTime': 116},
#  {'locId': 'L2283278',
#   'locName': 'Dighton Town Landing',
#   'countryCode': 'US',
#   'subnational1Code': 'US-MA',
#   'subnational2Code': 'US-MA-005',
#   'lat': 41.7968199,
#   'lng': -71.120553,
#   'latestObsDt': '2025-02-20 12:00',
#   'numSpeciesAllTime': 130},
#  {'locId': 'L4578087',
#   'locName': 'Dighton Transfer Station',
#   'countryCode': 'US',
#   'subnational1Code': 'US-MA',
#   'subnational2Code': 'US-MA-005',
#   'lat': 41.8546988,
#   'lng': -71.1388779,
#   'latestObsDt': '2022-08-20 11:14',
#   'numSpeciesAllTime': 82},
#  {'locId': 'L4538187',
#   'locName': 'Dighton Water Pump Station (private)',
#   'countryCode': 'US',
#   'subnational1Code': 'US-MA',
#   'subnational2Code': 'US-MA-005',
#   'lat': 41.8255552,
#   'lng': -71.1267945,
#   'latestObsDt': '2024-12-29 05:23',
#   'numSpeciesAllTime': 79},
#  {'locId': 'L1135167',
#   'locName': 'Dodgeville Pond',
#   'countryCode': 'US',
#   'subnational1Code': 'US-MA',
#   'subnational2Code': 'US-MA-005',
#   'lat': 41.9232654,
#   'lng': -71.2951155,
#   'latestObsDt': '2025-03-14 17:41',
#   'numSpeciesAllTime': 65},
#  {'locId': 'L1463082',
#   'locName': 'Doug Rayner Wildlife Refuge at Nockum Hill',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-001',
#   'lat': 41.7680304,
#   'lng': -71.31198,
#   'latestObsDt': '2025-12-13 08:26',
#   'numSpeciesAllTime': 177},
#  {'locId': 'L54768291',
#   'locName': 'Dunnell Park, Pawtucket',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.864788,
#   'lng': -71.3683087,
#   'latestObsDt': '2025-11-28 11:31',
#   'numSpeciesAllTime': 30},
#  {'locId': 'L5126639',
#   'locName': 'East Bay Bike Path--Barrington River Bridge to Warren Dog Park',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-001',
#   'lat': 41.7369613,
#   'lng': -71.2859139,
#   'latestObsDt': '2025-08-02 11:13',
#   'numSpeciesAllTime': 87},
#  {'locId': 'L5123222',
#   'locName': 'East Bay Bike Path--Bay Spring Ave. to Barrington Shopping Center',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-001',
#   'lat': 41.7389245,
#   'lng': -71.3333058,
#   'latestObsDt': '2025-08-02 10:39',
#   'numSpeciesAllTime': 147},
#  {'locId': 'L730688',
#   'locName': 'East Bay Bike Path--Colt State Park to Independence Park',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-001',
#   'lat': 41.6824731,
#   'lng': -71.2813489,
#   'latestObsDt': '2025-12-14 14:36',
#   'numSpeciesAllTime': 130},
#  {'locId': 'L55322509',
#   'locName': 'East Bay Bike Path--Veterans Memorial Parkway',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.8091301,
#   'lng': -71.3871416,
#   'latestObsDt': '2025-11-21 12:32',
#   'numSpeciesAllTime': 17},
#  {'locId': 'L3567188',
#   'locName': 'East Bay Bike Path--Warren Dog Park to Colt State Park',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-001',
#   'lat': 41.705527,
#   'lng': -71.28859,
#   'latestObsDt': '2025-11-24 15:00',
#   'numSpeciesAllTime': 143},
#  {'locId': 'L1139391',
#   'locName': 'East Bay Bike Path--Watchemoket Cove to Pomham Rocks',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.7959681,
#   'lng': -71.3778949,
#   'latestObsDt': '2025-12-14 09:29',
#   'numSpeciesAllTime': 179},
#  {'locId': 'L5668641',
#   'locName': 'East Greenwich Cemetery',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-003',
#   'lat': 41.6565934,
#   'lng': -71.4570308,
#   'latestObsDt': '2025-03-19 15:03',
#   'numSpeciesAllTime': 14},
#  {'locId': 'L22412271',
#   'locName': 'East Greenwich Cove Overlook',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-003',
#   'lat': 41.656898,
#   'lng': -71.449188,
#   'latestObsDt': '2025-07-27 16:51',
#   'numSpeciesAllTime': 61},
#  {'locId': 'L7358879',
#   'locName': 'East Greenwich Nature and Cross Country Trail',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-003',
#   'lat': 41.6334947,
#   'lng': -71.4834452,
#   'latestObsDt': '2025-06-13 19:08',
#   'numSpeciesAllTime': 98},
#  {'locId': 'L21194566',
#   'locName': 'East Point (formerly Greenwood Point)',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.8412036,
#   'lng': -71.3717906,
#   'latestObsDt': '2025-12-01 09:30',
#   'numSpeciesAllTime': 56},
#  {'locId': 'L1320533',
#   'locName': 'Echo Lake, Barrington',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-001',
#   'lat': 41.7357344,
#   'lng': -71.3339496,
#   'latestObsDt': '2025-12-06 10:19',
#   'numSpeciesAllTime': 137},
#  {'locId': 'L15883704',
#   'locName': 'Fall River Heritage SP',
#   'countryCode': 'US',
#   'subnational1Code': 'US-MA',
#   'subnational2Code': 'US-MA-005',
#   'lat': 41.7048283,
#   'lng': -71.1601388,
#   'latestObsDt': '2025-11-09 13:56',
#   'numSpeciesAllTime': 44},
#  {'locId': 'L487669',
#   'locName': 'Flat River Reservoir, Coventry',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-003',
#   'lat': 41.7074586,
#   'lng': -71.6359663,
#   'latestObsDt': '2025-12-07 09:05',
#   'numSpeciesAllTime': 119},
#  {'locId': 'L357306',
#   'locName': 'Fort Wildlife Refuge (ASRI)',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.9606389,
#   'lng': -71.5533972,
#   'latestObsDt': '2025-12-12 07:37',
#   'numSpeciesAllTime': 117},
#  {'locId': 'L1458015',
#   'locName': 'Franklin Farm, Cumberland',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.9668184,
#   'lng': -71.393796,
#   'latestObsDt': '2025-12-10 13:17',
#   'numSpeciesAllTime': 124},
#  {'locId': 'L6530163',
#   'locName': 'Frenchtown Park, East Greenwich',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-003',
#   'lat': 41.626978,
#   'lng': -71.506429,
#   'latestObsDt': '2025-11-20 06:00',
#   'numSpeciesAllTime': 114},
#  {'locId': 'L1390947',
#   'locName': 'Fuller Pond',
#   'countryCode': 'US',
#   'subnational1Code': 'US-MA',
#   'subnational2Code': 'US-MA-021',
#   'lat': 42.0126642,
#   'lng': -71.3476719,
#   'latestObsDt': '2025-09-18 16:53',
#   'numSpeciesAllTime': 116},
#  {'locId': 'L13048144',
#   'locName': 'Gainsborough Commons (limited access)',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 42.008083,
#   'lng': -71.453635,
#   'latestObsDt': '2023-10-11 15:18',
#   'numSpeciesAllTime': 12},
#  {'locId': 'L1393330',
#   'locName': 'Gano Park, Providence',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.823722,
#   'lng': -71.3885067,
#   'latestObsDt': '2025-11-30 09:26',
#   'numSpeciesAllTime': 80},
#  {'locId': 'L7788167',
#   'locName': 'Gaspee Point',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-003',
#   'lat': 41.743699,
#   'lng': -71.3766397,
#   'latestObsDt': '2025-09-24 12:00',
#   'numSpeciesAllTime': 92},
#  {'locId': 'L38630101',
#   'locName': 'Gate of Heaven Cemetery, East Providence',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.792361,
#   'lng': -71.339235,
#   'latestObsDt': '2025-11-26 15:07',
#   'numSpeciesAllTime': 45},
#  {'locId': 'L15294747',
#   'locName': 'George B. Parker Woodland—Gowdey Memorial Trail (Prov. Co.)',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.729585,
#   'lng': -71.684546,
#   'latestObsDt': '2025-06-08 13:33',
#   'numSpeciesAllTime': 51},
#  {'locId': 'L2776143',
#   'locName': 'Georgiaville Pond',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.8913554,
#   'lng': -71.5088081,
#   'latestObsDt': '2025-01-01 09:45',
#   'numSpeciesAllTime': 66},
#  {'locId': 'L13158219',
#   'locName': 'Glenford Cemetery, Scituate',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.8309334,
#   'lng': -71.5904518,
#   'latestObsDt': '2025-10-11 16:43',
#   'numSpeciesAllTime': 46},
#  {'locId': 'L1007144',
#   'locName': 'Goddard Memorial SP',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-003',
#   'lat': 41.6611783,
#   'lng': -71.4358091,
#   'latestObsDt': '2025-12-12 12:51',
#   'numSpeciesAllTime': 163},
#  {'locId': 'L6182809',
#   'locName': 'Gorton Pond and Little Gorton Pond',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-003',
#   'lat': 41.7023002,
#   'lng': -71.4622879,
#   'latestObsDt': '2025-11-14 12:32',
#   'numSpeciesAllTime': 115},
#  {'locId': 'L40170320',
#   'locName': 'Governor John Notte Memorial Park, North Providence',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.8712226,
#   'lng': -71.4631462,
#   'latestObsDt': '2025-05-24 17:50',
#   'numSpeciesAllTime': 44},
#  {'locId': 'L46689195',
#   'locName': 'Grassy Plains Park, East Providence',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.768335,
#   'lng': -71.332246,
#   'latestObsDt': '2025-08-21 11:19',
#   'numSpeciesAllTime': 21},
#  {'locId': 'L4588597',
#   'locName': 'Great Woods Conservation Area',
#   'countryCode': 'US',
#   'subnational1Code': 'US-MA',
#   'subnational2Code': 'US-MA-005',
#   'lat': 41.9981564,
#   'lng': -71.2298584,
#   'latestObsDt': '2025-12-06 13:35',
#   'numSpeciesAllTime': 94},
#  {'locId': 'L5455344',
#   'locName': 'Haffenreffer Estate',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-001',
#   'lat': 41.679539,
#   'lng': -71.2362903,
#   'latestObsDt': '2024-10-14 09:56',
#   'numSpeciesAllTime': 68},
#  {'locId': 'L11913876',
#   'locName': 'Haile Farm Preserve (WLCT)',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-001',
#   'lat': 41.7514372,
#   'lng': -71.279314,
#   'latestObsDt': '2025-10-10 09:28',
#   'numSpeciesAllTime': 128},
#  {'locId': 'L39583673',
#   'locName': 'Haines Memorial State Park  (Providence County)',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.7540286,
#   'lng': -71.3514138,
#   'latestObsDt': '2025-09-18 13:45',
#   'numSpeciesAllTime': 38},
#  {'locId': 'L286912',
#   'locName': 'Haines Memorial State Park (Bristol County)',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-001',
#   'lat': 41.7531189,
#   'lng': -71.3504298,
#   'latestObsDt': '2025-10-09 13:25',
#   'numSpeciesAllTime': 122},
#  {'locId': 'L4333222',
#   'locName': 'Handy Pond Conservation Area ',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.9560605,
#   'lng': -71.4742713,
#   'latestObsDt': '2025-11-13 09:59',
#   'numSpeciesAllTime': 86},
#  {'locId': 'L13041553',
#   'locName': 'Harold Burns Memorial Wildlife Arboretum',
#   'countryCode': 'US',
#   'subnational1Code': 'US-MA',
#   'subnational2Code': 'US-MA-005',
#   'lat': 41.9958385,
#   'lng': -71.3217259,
#   'latestObsDt': '2025-11-29 09:33',
#   'numSpeciesAllTime': 44},
#  {'locId': 'L15187055',
#   'locName': 'Hemlock Rd., Foster',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.7913147,
#   'lng': -71.6825409,
#   'latestObsDt': '2025-11-25 15:12',
#   'numSpeciesAllTime': 73},
#  {'locId': 'L40521950',
#   'locName': 'Heritage Park, Glocester',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.8920702,
#   'lng': -71.6315403,
#   'latestObsDt': '2025-04-26 15:18',
#   'numSpeciesAllTime': 19},
#  {'locId': 'L14885742',
#   'locName': 'High Rock Farm Preserve',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.9565049,
#   'lng': -71.4304866,
#   'latestObsDt': '2025-12-04 13:52',
#   'numSpeciesAllTime': 94},
#  {'locId': 'L38666615',
#   'locName': 'Highland Memorial Park Cemetery',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.855466,
#   'lng': -71.4950323,
#   'latestObsDt': '2025-10-02 12:00',
#   'numSpeciesAllTime': 18},
#  {'locId': 'L24131893',
#   'locName': 'Highland Park',
#   'countryCode': 'US',
#   'subnational1Code': 'US-MA',
#   'subnational2Code': 'US-MA-005',
#   'lat': 41.9436939,
#   'lng': -71.2958576,
#   'latestObsDt': '2025-12-09 14:34',
#   'numSpeciesAllTime': 103},
#  {'locId': 'L55055686',
#   'locName': 'Hopkins Property, Foster Land Trust',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.818868,
#   'lng': -71.702845,
#   'latestObsDt': '2025-12-03 12:40',
#   'numSpeciesAllTime': 54},
#  {'locId': 'L14264549',
#   'locName': 'Howard Conservation Area (PRAWC)',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.7324417,
#   'lng': -71.4596712,
#   'latestObsDt': '2025-09-23 12:00',
#   'numSpeciesAllTime': 97},
#  {'locId': 'L7401637',
#   'locName': 'Howard Pond, Cumberland',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.9555687,
#   'lng': -71.3875294,
#   'latestObsDt': '2025-12-09 11:24',
#   'numSpeciesAllTime': 30},
#  {'locId': 'L3923511',
#   'locName': 'Hundred Acre Cove',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-001',
#   'lat': 41.7622532,
#   'lng': -71.3131356,
#   'latestObsDt': '2025-07-05 10:01',
#   'numSpeciesAllTime': 102},
#  {'locId': 'L15585790',
#   'locName': 'Hundred Acre Cove (Providence Co.)',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.7744174,
#   'lng': -71.3214949,
#   'latestObsDt': '2025-11-02 13:00',
#   'numSpeciesAllTime': 106},
#  {'locId': 'L13447055',
#   'locName': 'Hundred Acre Cove--North Trail access',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-001',
#   'lat': 41.770138,
#   'lng': -71.323482,
#   'latestObsDt': '2025-08-27 09:27',
#   'numSpeciesAllTime': 75},
#  {'locId': 'L2802133',
#   'locName': 'Hunt’s Mills Museum and Trail',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.8283457,
#   'lng': -71.3469315,
#   'latestObsDt': '2025-10-11 10:30',
#   'numSpeciesAllTime': 128},
#  {'locId': 'L2482586',
#   'locName': 'Independence Park, Bristol',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-001',
#   'lat': 41.674403,
#   'lng': -71.279586,
#   'latestObsDt': '2025-10-19 14:14',
#   'numSpeciesAllTime': 81},
#  {'locId': 'L8596244',
#   'locName': 'India Point Park, Providence',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.8172568,
#   'lng': -71.3903618,
#   'latestObsDt': '2025-11-23 08:58',
#   'numSpeciesAllTime': 91},
#  {'locId': 'L19186567',
#   'locName': 'Isthmus Rd., Foster',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.752805,
#   'lng': -71.686923,
#   'latestObsDt': '2025-06-07 13:30',
#   'numSpeciesAllTime': 72},
#  {'locId': 'L2781443',
#   'locName': "Jacob's Point Saltmarsh",
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-001',
#   'lat': 41.7106636,
#   'lng': -71.2903995,
#   'latestObsDt': '2025-12-13 06:58',
#   'numSpeciesAllTime': 196},
#  {'locId': 'L247829',
#   'locName': 'James Turner Reservoir',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.8358267,
#   'lng': -71.3394269,
#   'latestObsDt': '2025-12-01 10:46',
#   'numSpeciesAllTime': 167},
#  {'locId': 'L7456597',
#   'locName': "Joe's Rock Conservation Area",
#   'countryCode': 'US',
#   'subnational1Code': 'US-MA',
#   'subnational2Code': 'US-MA-021',
#   'lat': 42.0273639,
#   'lng': -71.4056611,
#   'latestObsDt': '2025-07-14 06:57',
#   'numSpeciesAllTime': 105},
#  {'locId': 'L12266919',
#   'locName': 'John L. Curran Management Area',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.7507133,
#   'lng': -71.5477124,
#   'latestObsDt': '2025-10-30 11:16',
#   'numSpeciesAllTime': 90},
#  {'locId': 'L7441559',
#   'locName': 'Juniper Hill Cemetery',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-001',
#   'lat': 41.6811015,
#   'lng': -71.2680531,
#   'latestObsDt': '2024-12-16 10:58',
#   'numSpeciesAllTime': 71},
#  {'locId': 'L19377129',
#   'locName': 'Kate Randall Rd., Foster',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.80447,
#   'lng': -71.697416,
#   'latestObsDt': '2025-08-03 17:01',
#   'numSpeciesAllTime': 54},
#  {'locId': 'L24184797',
#   'locName': 'Kennedy Plaza, Providence',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.825473,
#   'lng': -71.412127,
#   'latestObsDt': '2025-12-04 11:40',
#   'numSpeciesAllTime': 38},
#  {'locId': 'L55029974',
#   'locName': 'Kent Heights Park, East Providence',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.805105,
#   'lng': -71.356364,
#   'latestObsDt': '2025-11-15 09:40',
#   'numSpeciesAllTime': 13},
#  {'locId': 'L55389099',
#   'locName': 'Kickemuit River--Child Street Bridge',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-001',
#   'lat': 41.729527,
#   'lng': -71.2626966,
#   'latestObsDt': '2025-11-20 13:45',
#   'numSpeciesAllTime': 3},
#  {'locId': 'L17120086',
#   'locName': 'Kickemuit River--Schoolhouse & Serpentine Road',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-001',
#   'lat': 41.7397652,
#   'lng': -71.2602269,
#   'latestObsDt': '2025-12-04 10:31',
#   'numSpeciesAllTime': 156},
#  {'locId': 'L11806624',
#   'locName': 'Knight Farm Trail (West Bay Land Trust)',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.7529773,
#   'lng': -71.5292781,
#   'latestObsDt': '2025-11-28 07:20',
#   'numSpeciesAllTime': 47},
#  {'locId': 'L12052632',
#   'locName': 'L.A. Foster Wildlife Refuge',
#   'countryCode': 'US',
#   'subnational1Code': 'US-MA',
#   'subnational2Code': 'US-MA-005',
#   'lat': 41.9474619,
#   'lng': -71.1761466,
#   'latestObsDt': '2025-04-17 15:11',
#   'numSpeciesAllTime': 57},
#  {'locId': 'L866565',
#   'locName': 'Lake Como, Attleboro',
#   'countryCode': 'US',
#   'subnational1Code': 'US-MA',
#   'subnational2Code': 'US-MA-005',
#   'lat': 41.9262365,
#   'lng': -71.3583362,
#   'latestObsDt': '2025-10-16 08:48',
#   'numSpeciesAllTime': 55},
#  {'locId': 'L1393144',
#   'locName': 'Lake Hiawatha',
#   'countryCode': 'US',
#   'subnational1Code': 'US-MA',
#   'subnational2Code': 'US-MA-005',
#   'lat': 41.9665834,
#   'lng': -71.3233878,
#   'latestObsDt': '2025-02-01 11:11',
#   'numSpeciesAllTime': 98},
#  {'locId': 'L1393150',
#   'locName': 'Lake Mirimichi',
#   'countryCode': 'US',
#   'subnational1Code': 'US-MA',
#   'subnational2Code': 'US-MA-021',
#   'lat': 42.0279285,
#   'lng': -71.2963494,
#   'latestObsDt': '2025-08-09 17:29',
#   'numSpeciesAllTime': 82},
#  {'locId': 'L1365565',
#   'locName': 'Latham Park, Barrington',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-001',
#   'lat': 41.7457879,
#   'lng': -71.3520883,
#   'latestObsDt': '2025-09-07 15:03',
#   'numSpeciesAllTime': 79},
#  {'locId': 'L4525701',
#   'locName': 'Lawton Farm (Scituate Land Trust)',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.7574513,
#   'lng': -71.5561652,
#   'latestObsDt': '2025-11-28 10:23',
#   'numSpeciesAllTime': 130},
#  {'locId': 'L4053762',
#   'locName': 'Lewin Brook Pond',
#   'countryCode': 'US',
#   'subnational1Code': 'US-MA',
#   'subnational2Code': 'US-MA-005',
#   'lat': 41.7462816,
#   'lng': -71.1926079,
#   'latestObsDt': '2023-01-20 11:00',
#   'numSpeciesAllTime': 51},
#  {'locId': 'L393285',
#   'locName': 'Lincoln Woods State Park',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.8962718,
#   'lng': -71.4355516,
#   'latestObsDt': '2025-12-13 14:03',
#   'numSpeciesAllTime': 152},
#  {'locId': 'L14185394',
#   'locName': 'Lippitt Memorial Park',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.8546509,
#   'lng': -71.3915205,
#   'latestObsDt': '2025-07-11 08:45',
#   'numSpeciesAllTime': 48},
#  {'locId': 'L12824129',
#   'locName': 'Little Neck Cemetery',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.7667433,
#   'lng': -71.3542489,
#   'latestObsDt': '2025-11-23 14:51',
#   'numSpeciesAllTime': 84},
#  {'locId': 'L13992195',
#   'locName': 'Little Pond, Cumberland',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.9624751,
#   'lng': -71.4213747,
#   'latestObsDt': '2025-11-01 12:18',
#   'numSpeciesAllTime': 54},
#  {'locId': 'L549748',
#   'locName': 'Lonsdale General Area (please use more refined hotspot)',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.9064273,
#   'lng': -71.3999829,
#   'latestObsDt': '2024-11-12 06:20',
#   'numSpeciesAllTime': 150},
#  {'locId': 'L12295388',
#   'locName': 'Lonsdale Marsh--Lonsdale Ave. access',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.9020296,
#   'lng': -71.404301,
#   'latestObsDt': '2025-12-13 13:57',
#   'numSpeciesAllTime': 154},
#  {'locId': 'L17150946',
#   'locName': 'Mallard Point',
#   'countryCode': 'US',
#   'subnational1Code': 'US-MA',
#   'subnational2Code': 'US-MA-005',
#   'lat': 41.7726055,
#   'lng': -71.1205563,
#   'latestObsDt': '2024-05-25 08:30',
#   'numSpeciesAllTime': 63},
#  {'locId': 'L1297392',
#   'locName': 'Manchester Pond Reservoir',
#   'countryCode': 'US',
#   'subnational1Code': 'US-MA',
#   'subnational2Code': 'US-MA-005',
#   'lat': 41.9461929,
#   'lng': -71.3158393,
#   'latestObsDt': '2025-11-24 12:42',
#   'numSpeciesAllTime': 136},
#  {'locId': 'L3157427',
#   'locName': 'Maple Street Powerline Cut',
#   'countryCode': 'US',
#   'subnational1Code': 'US-MA',
#   'subnational2Code': 'US-MA-005',
#   'lat': 41.8651505,
#   'lng': -71.1994743,
#   'latestObsDt': '2025-11-09 08:29',
#   'numSpeciesAllTime': 126},
#  {'locId': 'L15210138',
#   'locName': 'Marsh Point, Warwick',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-003',
#   'lat': 41.65971,
#   'lng': -71.41081,
#   'latestObsDt': '2025-12-12 13:18',
#   'numSpeciesAllTime': 159},
#  {'locId': 'L1391689',
#   'locName': "Mary's Creek, Warwick",
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-003',
#   'lat': 41.6891348,
#   'lng': -71.4513884,
#   'latestObsDt': '2025-12-09 09:56',
#   'numSpeciesAllTime': 128},
#  {'locId': 'L9545732',
#   'locName': 'Mashapaug Park, Providence',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.7960733,
#   'lng': -71.4301347,
#   'latestObsDt': '2025-12-14 07:47',
#   'numSpeciesAllTime': 140},
#  {'locId': 'L30901951',
#   'locName': 'Mason Field',
#   'countryCode': 'US',
#   'subnational1Code': 'US-MA',
#   'subnational2Code': 'US-MA-005',
#   'lat': 41.973644,
#   'lng': -71.315139,
#   'latestObsDt': '2025-11-23 12:49',
#   'numSpeciesAllTime': 42},
#  {'locId': 'L10975778',
#   'locName': 'Massasoit Street Park',
#   'countryCode': 'US',
#   'subnational1Code': 'US-MA',
#   'subnational2Code': 'US-MA-005',
#   'lat': 41.7099274,
#   'lng': -71.1795339,
#   'latestObsDt': '2025-11-30 08:23',
#   'numSpeciesAllTime': 93},
#  {'locId': 'L15139458',
#   'locName': 'Mercy Woods Preserve, Cumberland',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 42.0149,
#   'lng': -71.408989,
#   'latestObsDt': '2025-11-30 06:32',
#   'numSpeciesAllTime': 89},
#  {'locId': 'L14975740',
#   'locName': 'Merrill S. Whipple Conservation Park',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-003',
#   'lat': 41.6885734,
#   'lng': -71.5566654,
#   'latestObsDt': '2025-07-14 16:29',
#   'numSpeciesAllTime': 88},
#  {'locId': 'L7425313',
#   'locName': 'Meshanticut State Park',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.7682996,
#   'lng': -71.4752215,
#   'latestObsDt': '2025-12-13 14:31',
#   'numSpeciesAllTime': 86},
#  {'locId': 'L3970468',
#   'locName': 'Miller St. Pond',
#   'countryCode': 'US',
#   'subnational1Code': 'US-MA',
#   'subnational2Code': 'US-MA-005',
#   'lat': 41.8037817,
#   'lng': -71.3094234,
#   'latestObsDt': '2025-12-06 10:15',
#   'numSpeciesAllTime': 88},
#  {'locId': 'L10470601',
#   'locName': 'Moshassuck Pond',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.8817272,
#   'lng': -71.4033755,
#   'latestObsDt': '2025-11-12 11:34',
#   'numSpeciesAllTime': 79},
#  {'locId': 'L38645358',
#   'locName': 'Moshassuck River Preserve (TNC)',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.9142761,
#   'lng': -71.4430424,
#   'latestObsDt': '2025-09-06 11:24',
#   'numSpeciesAllTime': 37},
#  {'locId': 'L6178635',
#   'locName': 'Mount Hope Bay',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-005',
#   'lat': 41.651619,
#   'lng': -71.236764,
#   'latestObsDt': '2024-05-02 13:29',
#   'numSpeciesAllTime': 18},
#  {'locId': 'L2430264',
#   'locName': 'Mount Hope Farm',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-001',
#   'lat': 41.6681638,
#   'lng': -71.2549775,
#   'latestObsDt': '2025-12-07 23:31',
#   'numSpeciesAllTime': 182},
#  {'locId': 'L43251693',
#   'locName': 'Mount St. Mary Cemetery, East Providence',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.8569603,
#   'lng': -71.3666189,
#   'latestObsDt': '2025-11-03 08:46',
#   'numSpeciesAllTime': 15},
#  {'locId': 'L13813738',
#   'locName': 'Mountaindale Road Marsh & Reservoir, Smithfield',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
# ...
#   'countryCode': 'US',
#   'subnational1Code': 'US-MA',
#   'subnational2Code': 'US-MA-005',
#   'lat': 41.7625573,
#   'lng': -71.2797475,
#   'latestObsDt': '2019-09-29 08:30',
#   'numSpeciesAllTime': 43},
#  {'locId': 'L2792209',
#   'locName': 'Sweets Knoll SP',
#   'countryCode': 'US',
#   'subnational1Code': 'US-MA',
#   'subnational2Code': 'US-MA-005',
#   'lat': 41.8302771,
#   'lng': -71.114858,
#   'latestObsDt': '2025-10-30 12:40',
#   'numSpeciesAllTime': 147},
#  {'locId': 'L17970931',
#   'locName': 'T.F. Green International Airport',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-003',
#   'lat': 41.7235369,
#   'lng': -71.4269578,
#   'latestObsDt': '2025-11-02 12:52',
#   'numSpeciesAllTime': 140},
#  {'locId': 'L49057407',
#   'locName': 'Tarkiln Road, Smithfield',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.9142369,
#   'lng': -71.5790024,
#   'latestObsDt': '2025-07-04 08:22',
#   'numSpeciesAllTime': 30},
#  {'locId': 'L40384308',
#   'locName': 'Ten Mile River Greenway--Dagget Ave. Trailhead to Armistice Blvd',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.8824328,
#   'lng': -71.3426111,
#   'latestObsDt': '2025-09-14 11:05',
#   'numSpeciesAllTime': 23},
#  {'locId': 'L2599631',
#   'locName': 'Ten Mile River Greenway--Ferris Ave. Trailhead to Slater Park',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.8496377,
#   'lng': -71.3443893,
#   'latestObsDt': '2025-11-27 14:45',
#   'numSpeciesAllTime': 116},
#  {'locId': 'L5426087',
#   'locName': 'Ten Mile River Reservation (Armistice Blvd. viewpoint)',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.875147,
#   'lng': -71.340459,
#   'latestObsDt': '2025-09-09 14:35',
#   'numSpeciesAllTime': 111},
#  {'locId': 'L1458029',
#   'locName': 'The Monastery, Cumberland',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.9350531,
#   'lng': -71.4075396,
#   'latestObsDt': '2025-12-14 12:43',
#   'numSpeciesAllTime': 181},
#  {'locId': 'L8920590',
#   'locName': 'Tillinghast Place / RISD Beach',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-001',
#   'lat': 41.725982,
#   'lng': -71.321841,
#   'latestObsDt': '2025-10-24 15:58',
#   'numSpeciesAllTime': 142},
#  {'locId': 'L815443',
#   'locName': 'Tiogue Lake',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-003',
#   'lat': 41.6790406,
#   'lng': -71.5503244,
#   'latestObsDt': '2025-12-11 15:59',
#   'numSpeciesAllTime': 120},
#  {'locId': 'L4207196',
#   'locName': 'Tiogue Lake--Outflow',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-003',
#   'lat': 41.685423,
#   'lng': -71.553619,
#   'latestObsDt': '2025-10-23 10:40',
#   'numSpeciesAllTime': 106},
#  {'locId': 'L213318',
#   'locName': 'Touisset Marsh Wildlife Refuge (ASRI)',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-001',
#   'lat': 41.7059838,
#   'lng': -71.2374794,
#   'latestObsDt': '2025-12-13 10:20',
#   'numSpeciesAllTime': 160},
#  {'locId': 'L15208246',
#   'locName': 'Tower Hill Rd., Cumberland',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.994098,
#   'lng': -71.444035,
#   'latestObsDt': '2025-05-31 13:35',
#   'numSpeciesAllTime': 60},
#  {'locId': 'L42665518',
#   'locName': 'Town Line Swamp',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.933718,
#   'lng': -71.486849,
#   'latestObsDt': '2025-05-11 09:23',
#   'numSpeciesAllTime': 25},
#  {'locId': 'L900794',
#   'locName': 'Town Pond (ALT)',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-005',
#   'lat': 41.6323646,
#   'lng': -71.245544,
#   'latestObsDt': '2025-12-10 10:36',
#   'numSpeciesAllTime': 152},
#  {'locId': 'L16657907',
#   'locName': 'Townie Pride Memorial Park, East Providence',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.808964,
#   'lng': -71.385004,
#   'latestObsDt': '2025-10-05 09:12',
#   'numSpeciesAllTime': 53},
#  {'locId': 'L3260829',
#   'locName': 'Tricentennial Park',
#   'countryCode': 'US',
#   'subnational1Code': 'US-MA',
#   'subnational2Code': 'US-MA-005',
#   'lat': 41.8103868,
#   'lng': -71.1191475,
#   'latestObsDt': '2025-02-20 11:35',
#   'numSpeciesAllTime': 112},
#  {'locId': 'L12450396',
#   'locName': 'Tucker Field, Cumberland',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.9644865,
#   'lng': -71.4426209,
#   'latestObsDt': '2025-04-21 18:56',
#   'numSpeciesAllTime': 27},
#  {'locId': 'L2718493',
#   'locName': 'Turnpike Lake',
#   'countryCode': 'US',
#   'subnational1Code': 'US-MA',
#   'subnational2Code': 'US-MA-021',
#   'lat': 42.0158388,
#   'lng': -71.3119447,
#   'latestObsDt': '2025-11-22 11:29',
#   'numSpeciesAllTime': 93},
#  {'locId': 'L41541061',
#   'locName': 'Twin River Casino Retention Ponds, Lincoln',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.88732,
#   'lng': -71.444158,
#   'latestObsDt': '2025-11-30 11:33',
#   'numSpeciesAllTime': 36},
#  {'locId': 'L10189488',
#   'locName': 'Venus De Milo Pond',
#   'countryCode': 'US',
#   'subnational1Code': 'US-MA',
#   'subnational2Code': 'US-MA-005',
#   'lat': 41.7429672,
#   'lng': -71.1885811,
#   'latestObsDt': '2025-10-18 11:53',
#   'numSpeciesAllTime': 52},
#  {'locId': 'L8678323',
#   'locName': 'Veterans Memorial Park, Pawtucket',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.8794371,
#   'lng': -71.3818826,
#   'latestObsDt': '2025-12-01 10:58',
#   'numSpeciesAllTime': 47},
#  {'locId': 'L29863733',
#   'locName': 'Village Park, Swansea',
#   'countryCode': 'US',
#   'subnational1Code': 'US-MA',
#   'subnational2Code': 'US-MA-005',
#   'lat': 41.7510963,
#   'lng': -71.1898653,
#   'latestObsDt': '2025-06-15 07:43',
#   'numSpeciesAllTime': 54},
#  {'locId': 'L5495329',
#   'locName': 'Village Waterfront Park, Somerset',
#   'countryCode': 'US',
#   'subnational1Code': 'US-MA',
#   'subnational2Code': 'US-MA-005',
#   'lat': 41.7696541,
#   'lng': -71.1251423,
#   'latestObsDt': '2025-10-10 11:59',
#   'numSpeciesAllTime': 70},
#  {'locId': 'L12545551',
#   'locName': 'WWII Memorial State Park',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 42.0096446,
#   'lng': -71.5093249,
#   'latestObsDt': '2023-06-30 16:59',
#   'numSpeciesAllTime': 22},
#  {'locId': 'L29020679',
#   'locName': 'Wading River Reservoir',
#   'countryCode': 'US',
#   'subnational1Code': 'US-MA',
#   'subnational2Code': 'US-MA-005',
#   'lat': 41.989602,
#   'lng': -71.254242,
#   'latestObsDt': '2025-11-02 06:52',
#   'numSpeciesAllTime': 63},
#  {'locId': 'L1888546',
#   'locName': 'Walker Cove',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-001',
#   'lat': 41.6604123,
#   'lng': -71.2706554,
#   'latestObsDt': '2025-10-05 11:35',
#   'numSpeciesAllTime': 79},
#  {'locId': 'L453500',
#   'locName': 'Walker Farm',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-001',
#   'lat': 41.7555945,
#   'lng': -71.3227701,
#   'latestObsDt': '2025-12-04 10:30',
#   'numSpeciesAllTime': 167},
#  {'locId': 'L4095950',
#   'locName': 'Walker Street Reserve, Westville Conservation Area',
#   'countryCode': 'US',
#   'subnational1Code': 'US-MA',
#   'subnational2Code': 'US-MA-005',
#   'lat': 41.8899385,
#   'lng': -71.1320382,
#   'latestObsDt': '2025-11-17 08:00',
#   'numSpeciesAllTime': 99},
#  {'locId': 'L31745262',
#   'locName': 'Walnut Hill Cemetery',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.8811125,
#   'lng': -71.3687754,
#   'latestObsDt': '2025-04-22 08:08',
#   'numSpeciesAllTime': 44},
#  {'locId': 'L6370013',
#   'locName': 'Warren Bike Path',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-001',
#   'lat': 41.7260657,
#   'lng': -71.2597087,
#   'latestObsDt': '2025-11-30 11:55',
#   'numSpeciesAllTime': 97},
#  {'locId': 'L1306965',
#   'locName': 'Warren Upper Reservoir ',
#   'countryCode': 'US',
#   'subnational1Code': 'US-MA',
#   'subnational2Code': 'US-MA-005',
#   'lat': 41.8251622,
#   'lng': -71.2174559,
#   'latestObsDt': '2025-08-08 16:30',
#   'numSpeciesAllTime': 116},
#  {'locId': 'L1325528',
#   'locName': 'Warwick City Park',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-003',
#   'lat': 41.6885579,
#   'lng': -71.4063702,
#   'latestObsDt': '2025-10-29 11:35',
#   'numSpeciesAllTime': 115},
#  {'locId': 'L22140967',
#   'locName': 'Warwick Pond',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-003',
#   'lat': 41.7238791,
#   'lng': -71.4123253,
#   'latestObsDt': '2025-04-25 12:50',
#   'numSpeciesAllTime': 46},
#  {'locId': 'L43850174',
#   'locName': 'Washington Secondary Trail--Father Tirocchi Field Area',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-003',
#   'lat': 41.7249223,
#   'lng': -71.48592,
#   'latestObsDt': '2025-07-07 12:30',
#   'numSpeciesAllTime': 37},
#  {'locId': 'L29523147',
#   'locName': 'Washington Secondary Trail--Pawtuxet River Wetland Overlook',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-003',
#   'lat': 41.696943,
#   'lng': -71.580597,
#   'latestObsDt': '2024-02-26 09:30',
#   'numSpeciesAllTime': 13},
#  {'locId': 'L187164',
#   'locName': 'Watchemoket Cove',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.800495,
#   'lng': -71.376686,
#   'latestObsDt': '2025-12-13 11:27',
#   'numSpeciesAllTime': 137},
#  {'locId': 'L12799134',
#   'locName': 'Waterman Reservoir',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.8799557,
#   'lng': -71.5805218,
#   'latestObsDt': '2025-08-22 13:41',
#   'numSpeciesAllTime': 62},
#  {'locId': 'L13430824',
#   'locName': 'Waterman St. Dog Park',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.8277178,
#   'lng': -71.3835141,
#   'latestObsDt': '2024-12-24 08:43',
#   'numSpeciesAllTime': 73},
#  {'locId': 'L12606996',
#   'locName': 'Waypoyset Preserve (Land Trust)',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-001',
#   'lat': 41.697007,
#   'lng': -71.2498423,
#   'latestObsDt': '2022-03-20 12:15',
#   'numSpeciesAllTime': 38},
#  {'locId': 'L1390952',
#   'locName': 'Wetherells Pond',
#   'countryCode': 'US',
#   'subnational1Code': 'US-MA',
#   'subnational2Code': 'US-MA-021',
#   'lat': 42.0003917,
#   'lng': -71.3375304,
#   'latestObsDt': '2025-05-02 17:44',
#   'numSpeciesAllTime': 115},
#  {'locId': 'L13121233',
#   'locName': 'Wetlands Robinson Ave. Dam',
#   'countryCode': 'US',
#   'subnational1Code': 'US-MA',
#   'subnational2Code': 'US-MA-005',
#   'lat': 41.9680397,
#   'lng': -71.3120677,
#   'latestObsDt': '2025-02-17 06:45',
#   'numSpeciesAllTime': 31},
#  {'locId': 'L2390045',
#   'locName': 'Wheaton College',
#   'countryCode': 'US',
#   'subnational1Code': 'US-MA',
#   'subnational2Code': 'US-MA-005',
#   'lat': 41.9673242,
#   'lng': -71.1837137,
#   'latestObsDt': '2025-11-21 21:15',
#   'numSpeciesAllTime': 141},
#  {'locId': 'L3300181',
#   'locName': 'Whiting Pond, North Attleborough',
#   'countryCode': 'US',
#   'subnational1Code': 'US-MA',
#   'subnational2Code': 'US-MA-005',
#   'lat': 41.9941027,
#   'lng': -71.3352263,
#   'latestObsDt': '2025-10-06 06:46',
#   'numSpeciesAllTime': 40},
#  {'locId': 'L12073266',
#   'locName': 'Willett Pond, East Providence',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.775647,
#   'lng': -71.356669,
#   'latestObsDt': '2025-11-12 10:55',
#   'numSpeciesAllTime': 76},
#  {'locId': 'L12639998',
#   'locName': 'Winslow Park',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-003',
#   'lat': 41.7252496,
#   'lng': -71.4198935,
#   'latestObsDt': '2025-12-03 12:55',
#   'numSpeciesAllTime': 78},
#  {'locId': 'L1618211',
#   'locName': 'Witch Pond, Foxboro',
#   'countryCode': 'US',
#   'subnational1Code': 'US-MA',
#   'subnational2Code': 'US-MA-021',
#   'lat': 42.0177869,
#   'lng': -71.2867241,
#   'latestObsDt': '2025-07-13 10:38',
#   'numSpeciesAllTime': 75},
#  {'locId': 'L47132166',
#   'locName': 'Wolf Hill Preserve--Old Quarry Trails',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.887409,
#   'lng': -71.534424,
#   'latestObsDt': '2025-11-09 09:35',
#   'numSpeciesAllTime': 22},
#  {'locId': 'L13057430',
#   'locName': 'Wood Lake Park and Almy Reservoir',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.8159533,
#   'lng': -71.5271886,
#   'latestObsDt': '2025-12-10 07:25',
#   'numSpeciesAllTime': 110},
#  {'locId': 'L31392271',
#   'locName': 'Woonasquatucket River Greenway--Manton Pond Area to Merino Park',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.8339789,
#   'lng': -71.4724742,
#   'latestObsDt': '2025-12-05 11:11',
#   'numSpeciesAllTime': 105},
#  {'locId': 'L28111910',
#   'locName': 'Woonasquatucket River Greenway--Riverside Park to Merino Park',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.8207141,
#   'lng': -71.450412,
#   'latestObsDt': '2025-09-17 10:08',
#   'numSpeciesAllTime': 55},
#  {'locId': 'L12545495',
#   'locName': 'Woonsocket Public Library',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 42.0051404,
#   'lng': -71.5082279,
#   'latestObsDt': '2025-05-06 15:30',
#   'numSpeciesAllTime': 20},
#  {'locId': 'L12136837',
#   'locName': 'Woonsocket Reservoir #3',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.9430759,
#   'lng': -71.4980264,
#   'latestObsDt': '2025-09-16 12:40',
#   'numSpeciesAllTime': 57},
#  {'locId': 'L40170227',
#   'locName': 'World War I Memorial Park and Zoo',
#   'countryCode': 'US',
#   'subnational1Code': 'US-MA',
#   'subnational2Code': 'US-MA-005',
#   'lat': 41.9989253,
#   'lng': -71.3135779,
#   'latestObsDt': '2025-09-20 16:20',
#   'numSpeciesAllTime': 11},
#  {'locId': 'L11430695',
#   'locName': "Zeke's Bridge Fishing Access and Trails",
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-003',
#   'lat': 41.6650256,
#   'lng': -71.618607,
#   'latestObsDt': '2025-12-06 09:58',
#   'numSpeciesAllTime': 85},
#  {'locId': 'L1878310',
#   'locName': 'stakeout Black-throated Gray Warbler, 103 James H. Luther Dr., Taunton (Jan 2013)',
#   'countryCode': 'US',
#   'subnational1Code': 'US-MA',
#   'subnational2Code': 'US-MA-005',
#   'lat': 41.8984761,
#   'lng': -71.1748638,
#   'latestObsDt': '2013-01-23 09:30',
#   'numSpeciesAllTime': 34},
#  {'locId': 'L35960144',
#   'locName': 'stakeout Lark Bunting--Norton (2024)',
#   'countryCode': 'US',
#   'subnational1Code': 'US-MA',
#   'subnational2Code': 'US-MA-005',
#   'lat': 41.9697876,
#   'lng': -71.1947624,
#   'latestObsDt': '2024-08-22 09:35',
#   'numSpeciesAllTime': 43},
#  {'locId': 'L5128475',
#   'locName': 'stakeout Sandhill Crane--Swansea (2016)',
#   'countryCode': 'US',
#   'subnational1Code': 'US-MA',
#   'subnational2Code': 'US-MA-005',
#   'lat': 41.740978,
#   'lng': -71.193583,
#   'latestObsDt': '2025-05-28 14:31',
#   'numSpeciesAllTime': 26},
#  {'locId': 'L31274340',
#   'locName': 'stakeout Swallow-Tailed Kite--Attleboro (2024)',
#   'countryCode': 'US',
#   'subnational1Code': 'US-MA',
#   'subnational2Code': 'US-MA-005',
#   'lat': 41.9131963,
#   'lng': -71.2290574,
#   'latestObsDt': '2024-05-04 12:42',
#   'numSpeciesAllTime': 10},
#  {'locId': 'L12966956',
#   'locName': 'stakeout Varied Thrush--Chepachet (2020-2021)',
#   'countryCode': 'US',
#   'subnational1Code': 'US-RI',
#   'subnational2Code': 'US-RI-007',
#   'lat': 41.9154969,
#   'lng': -71.6022595,
#   'latestObsDt': '2023-05-19 16:23',
#   'numSpeciesAllTime': 59}]

# %%
from dataclasses import dataclass
from typing import Any

Coordinate = tuple[float, float]


@dataclass(frozen=True)
class EBirdLocation:
    """A location in the eBird system."""

    id: str
    name: str
    latitude: float
    longitude: float
    country_code: str
    subnational1_code: str | None
    subnational1_name: str | None
    subnational2_code: str | None
    subnational2_name: str | None

    @classmethod
    def from_dict(cls, data: dict[str, Any]) -> EBirdLocation:
        """Construct an eBird location from a dictionary of data."""
        return EBirdLocation(
            id=data["locId"],
            name=data["locName"],
            latitude=data["lat"],
            longitude=data["lng"],
            country_code=data["countryCode"],
            subnational1_code=data.get("subnational1Code"),
            subnational1_name=data.get("subnational1Name"),
            subnational2_code=data.get("subnational2Code"),
            subnational2_name=data.get("subnational2Name"),
        )

    @property
    def coordinate(self) -> Coordinate:
        """Retrieve the (latitude, longitude) GPS coordinate of the location."""
        return (self.latitude, self.longitude)


@dataclass(frozen=True)
class EBirdHotspot:
    """A location in the eBird system with a history of bird observations."""

    location: EBirdLocation
    all_time_species: int

    @classmethod
    def from_dict(cls, data: dict[str, Any]) -> EBirdHotspot:
        """Construct an eBird hotspot from a dictionary of data."""
        location = EBirdLocation.from_dict(data)
        return EBirdHotspot(location=location, all_time_species=data["numSpeciesAllTime"])


nearby_hotspots = [EBirdHotspot.from_dict(data) for data in nearby_hotspots_raw]
nearby_hotspots
# Out:
# [EBirdHotspot(location=EBirdLocation(id='L9189645', name='Allen Harbor Marina', latitude=41.6197094, longitude=-71.4112937, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-009', subnational2_name=None), all_time_species=121),
#  EBirdHotspot(location=EBirdLocation(id='L5070824', name="Allin's Cove (Barrington Land Trust)", latitude=41.7442266, longitude=-71.3481226, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-001', subnational2_name=None), all_time_species=123),
#  EBirdHotspot(location=EBirdLocation(id='L33244456', name='Anthony Lawrence Wildlife Preserve', latitude=41.92324, longitude=-71.349151, country_code='US', subnational1_code='US-MA', subnational1_name=None, subnational2_code='US-MA-005', subnational2_name=None), all_time_species=55),
#  EBirdHotspot(location=EBirdLocation(id='L634993', name='Apponaug Cove', latitude=41.6953469, longitude=-71.4527607, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-003', subnational2_name=None), all_time_species=145),
#  EBirdHotspot(location=EBirdLocation(id='L870123', name='Arcade Ave., Seekonk', latitude=41.8409524, longitude=-71.3356447, country_code='US', subnational1_code='US-MA', subnational1_name=None, subnational2_code='US-MA-005', subnational2_name=None), all_time_species=51),
#  EBirdHotspot(location=EBirdLocation(id='L450725', name='Arnold Mills Reservoir, Cumberland', latitude=41.9862744, longitude=-71.3969407, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=187),
#  EBirdHotspot(location=EBirdLocation(id='L42925934', name='Atlantic White Cedar Swamp Preserve (Cumberland Land Trust)', latitude=41.9745808, longitude=-71.4355125, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=62),
#  EBirdHotspot(location=EBirdLocation(id='L23891210', name='Attleboro Community Garden', latitude=41.9443897, longitude=-71.2897038, country_code='US', subnational1_code='US-MA', subnational1_name=None, subnational2_code='US-MA-005', subnational2_name=None), all_time_species=29),
#  EBirdHotspot(location=EBirdLocation(id='L1282270', name='Attleboro Springs Wildlife Sanctuary (Mass Audubon)', latitude=41.9286191, longitude=-71.2647432, country_code='US', subnational1_code='US-MA', subnational1_name=None, subnational2_code='US-MA-005', subnational2_name=None), all_time_species=102),
#  EBirdHotspot(location=EBirdLocation(id='L2875659', name='Aust Family Preserve at Lime Rock (TNC)', latitude=41.924037, longitude=-71.4682531, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=99),
#  EBirdHotspot(location=EBirdLocation(id='L17492948', name='Barney Ave./Almeida Rd. Fields, Rehoboth', latitude=41.786875, longitude=-71.286641, country_code='US', subnational1_code='US-MA', subnational1_name=None, subnational2_code='US-MA-005', subnational2_name=None), all_time_species=43),
#  EBirdHotspot(location=EBirdLocation(id='L34675950', name='Barney Pond, Lincoln', latitude=41.8967623, longitude=-71.41608, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=44),
#  EBirdHotspot(location=EBirdLocation(id='L983673', name='Barrington Town Beach', latitude=41.722579, longitude=-71.3087797, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-001', subnational2_name=None), all_time_species=84),
#  EBirdHotspot(location=EBirdLocation(id='L1670551', name='Behind Home Depot in Seekonk', latitude=41.7996862, longitude=-71.3404841, country_code='US', subnational1_code='US-MA', subnational1_name=None, subnational2_code='US-MA-005', subnational2_name=None), all_time_species=54),
#  EBirdHotspot(location=EBirdLocation(id='L12721457', name='Belmont Park, Warwick', latitude=41.7620466, longitude=-71.4219022, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-003', subnational2_name=None), all_time_species=67),
#  EBirdHotspot(location=EBirdLocation(id='L38649323', name='Bethany Cemetery, Cranston', latitude=41.7612448, longitude=-71.439414, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=27),
#  EBirdHotspot(location=EBirdLocation(id='L2214089', name='Big River Management Area--Carr Pond', latitude=41.6354153, longitude=-71.5560842, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-003', subnational2_name=None), all_time_species=89),
#  EBirdHotspot(location=EBirdLocation(id='L5071219', name='Big River Management Area--Model Airplane Field', latitude=41.654994, longitude=-71.56379, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-003', subnational2_name=None), all_time_species=50),
#  EBirdHotspot(location=EBirdLocation(id='L6073694', name='Big River Management Area--Sand Pit', latitude=41.6464519, longitude=-71.5779448, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-003', subnational2_name=None), all_time_species=135),
#  EBirdHotspot(location=EBirdLocation(id='L5099232', name='Big River Management Area--Tarbox Pond', latitude=41.6365854, longitude=-71.5734869, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-003', subnational2_name=None), all_time_species=105),
#  EBirdHotspot(location=EBirdLocation(id='L2071074', name='Birchwold Farm', latitude=42.0231797, longitude=-71.4054143, country_code='US', subnational1_code='US-MA', subnational1_name=None, subnational2_code='US-MA-021', subnational2_name=None), all_time_species=118),
#  EBirdHotspot(location=EBirdLocation(id='L10658440', name='Blackamore Pond, Cranston', latitude=41.7738778, longitude=-71.4468487, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=53),
#  EBirdHotspot(location=EBirdLocation(id='L6077334', name='Blackstone Boulevard, Providence', latitude=41.8434142, longitude=-71.386435, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=50),
#  EBirdHotspot(location=EBirdLocation(id='L4423843', name='Blackstone Gorge', latitude=42.0151373, longitude=-71.5528822, country_code='US', subnational1_code='US-MA', subnational1_name=None, subnational2_code='US-MA-027', subnational2_name=None), all_time_species=93),
#  EBirdHotspot(location=EBirdLocation(id='L11920582', name='Blackstone Gorge (RI)', latitude=42.0125889, longitude=-71.5520399, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=84),
#  EBirdHotspot(location=EBirdLocation(id='L804728', name='Blackstone Park', latitude=41.833327, longitude=-71.3792148, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=197),
#  EBirdHotspot(location=EBirdLocation(id='L41628130', name='Blackstone River Bikeway--Albion to Manville Parking Area', latitude=41.9573319, longitude=-71.4622947, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=107),
#  EBirdHotspot(location=EBirdLocation(id='L12894191', name='Blackstone River Bikeway--Canal St.', latitude=42.0165, longitude=-71.538194, country_code='US', subnational1_code='US-MA', subnational1_name=None, subnational2_code='US-MA-027', subnational2_name=None), all_time_species=133),
#  EBirdHotspot(location=EBirdLocation(id='L41527208', name='Blackstone River Bikeway--Cold Spring Park to MA Border', latitude=42.0100697, longitude=-71.528995, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=30),
#  EBirdHotspot(location=EBirdLocation(id='L1615937', name='Blackstone River Bikeway--Kelly House Museum to Albion Access', latitude=41.9431583, longitude=-71.4372874, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=117),
#  EBirdHotspot(location=EBirdLocation(id='L11516357', name='Blackstone River Bikeway--Kelly House Museum to Lonsdale Drive-In', latitude=41.9247737, longitude=-71.4298601, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=113),
#  EBirdHotspot(location=EBirdLocation(id='L41627753', name='Blackstone River Bikeway--Kelly House Trail to I-295 Visitor Center', latitude=41.9404151, longitude=-71.4424413, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=32),
#  EBirdHotspot(location=EBirdLocation(id='L4975633', name='Blackstone River Bikeway--Lonsdale Drive-In', latitude=41.9101022, longitude=-71.4004254, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=145),
#  EBirdHotspot(location=EBirdLocation(id='L41628165', name='Blackstone River Bikeway--Manville Access to "River\'s Edge"', latitude=41.9776132, longitude=-71.4833743, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=107),
#  EBirdHotspot(location=EBirdLocation(id='L8600695', name='Blackstone River Bikeway--Valley Marsh', latitude=41.9027514, longitude=-71.3980847, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=161),
#  EBirdHotspot(location=EBirdLocation(id='L34675448', name='Bleachery Pond, Lincoln', latitude=41.894042, longitude=-71.4096775, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=46),
#  EBirdHotspot(location=EBirdLocation(id='L2808160', name='Blithewold (entry fee required)', latitude=41.6541463, longitude=-71.2658536, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-001', subnational2_name=None), all_time_species=73),
#  EBirdHotspot(location=EBirdLocation(id='L216062', name='Bold Point Park, East Providence', latitude=41.8144807, longitude=-71.3901623, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=159),
#  EBirdHotspot(location=EBirdLocation(id='L22351437', name='Booth Pond Conservation Area & Trails', latitude=41.9803301, longitude=-71.5047389, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=120),
#  EBirdHotspot(location=EBirdLocation(id='L875821', name='Boyden Heights Conservation Area', latitude=41.7895369, longitude=-71.370433, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=97),
#  EBirdHotspot(location=EBirdLocation(id='L17165257', name='Boyden Park', latitude=41.872801, longitude=-71.125909, country_code='US', subnational1_code='US-MA', subnational1_name=None, subnational2_code='US-MA-005', subnational2_name=None), all_time_species=108),
#  EBirdHotspot(location=EBirdLocation(id='L2683958', name='Brickyard Pond & Veterans Memorial Park', latitude=41.7352359, longitude=-71.3144231, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-001', subnational2_name=None), all_time_species=164),
#  EBirdHotspot(location=EBirdLocation(id='L44616927', name='Bridgham Farm, Rumford', latitude=41.8361172, longitude=-71.3457559, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=57),
#  EBirdHotspot(location=EBirdLocation(id='L5133234', name='Bristol Narrows', latitude=41.6971815, longitude=-71.2464703, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-001', subnational2_name=None), all_time_species=79),
#  EBirdHotspot(location=EBirdLocation(id='L841256', name='Broad Cove', latitude=41.7892329, longitude=-71.1252308, country_code='US', subnational1_code='US-MA', subnational1_name=None, subnational2_code='US-MA-005', subnational2_name=None), all_time_species=221),
#  EBirdHotspot(location=EBirdLocation(id='L7801999', name='Brown University Campus', latitude=41.8260753, longitude=-71.403429, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=105),
#  EBirdHotspot(location=EBirdLocation(id='L11866685', name="Bullock's Cove", latitude=41.7601546, longitude=-71.3538947, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=109),
#  EBirdHotspot(location=EBirdLocation(id='L7113200', name="Bullock's Point (limited access)", latitude=41.7449199, longitude=-71.3578749, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=80),
#  EBirdHotspot(location=EBirdLocation(id='L17262087', name='Bullock’s Point Light', latitude=41.737771, longitude=-71.364168, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=6),
#  EBirdHotspot(location=EBirdLocation(id='L11444077', name='Butler Campus', latitude=41.8443214, longitude=-71.3815825, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=85),
#  EBirdHotspot(location=EBirdLocation(id='L21432043', name='Butterfly Farm & Pond, Lincoln', latitude=41.9070195, longitude=-71.4318753, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=63),
#  EBirdHotspot(location=EBirdLocation(id='L43513174', name='Byron Randall Road, Scituate', latitude=41.800396, longitude=-71.572942, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=27),
#  EBirdHotspot(location=EBirdLocation(id='L20653314', name='CCRI Lincoln', latitude=41.8953643, longitude=-71.456414, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=46),
#  EBirdHotspot(location=EBirdLocation(id='L5727176', name='Calf Pasture Point Recreation Area--Bikepath', latitude=41.6268485, longitude=-71.4154875, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-009', subnational2_name=None), all_time_species=191),
#  EBirdHotspot(location=EBirdLocation(id='L41322492', name='Calf Pasture Point Recreation Area--Shoreline Access', latitude=41.6299993, longitude=-71.4057814, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-009', subnational2_name=None), all_time_species=26),
#  EBirdHotspot(location=EBirdLocation(id='L30802876', name='Captain Stephen Olney Memorial Park', latitude=41.855094, longitude=-71.455276, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=37),
#  EBirdHotspot(location=EBirdLocation(id='L734825', name='Caratunk Wildlife Refuge (ASRI)', latitude=41.8740347, longitude=-71.3212734, country_code='US', subnational1_code='US-MA', subnational1_name=None, subnational2_code='US-MA-005', subnational2_name=None), all_time_species=171),
#  EBirdHotspot(location=EBirdLocation(id='L25323688', name='Catamint Brook Preserve (Cumberland Land Trust)', latitude=41.994465, longitude=-71.43924, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=98),
#  EBirdHotspot(location=EBirdLocation(id='L4658133', name='Cedar Swamp Conservation Area', latitude=41.9756837, longitude=-71.5357268, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=96),
#  EBirdHotspot(location=EBirdLocation(id='L38376933', name='Central Landfill, Johnston (limited access)', latitude=41.8075395, longitude=-71.5324731, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=84),
#  EBirdHotspot(location=EBirdLocation(id='L487743', name='Central Pond Reservoir, East Providence', latitude=41.8591418, longitude=-71.3376617, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=92),
#  EBirdHotspot(location=EBirdLocation(id='L4333450', name='Chase Farm, Lincoln', latitude=41.9064362, longitude=-71.4288585, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=151),
#  EBirdHotspot(location=EBirdLocation(id='L1391725', name='Chepiwanoxet Point', latitude=41.6735417, longitude=-71.4421938, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-003', subnational2_name=None), all_time_species=104),
#  EBirdHotspot(location=EBirdLocation(id='L734909', name='Claire D. McIntosh Wildlife Refuge (ASRI)', latitude=41.7102379, longitude=-71.2827596, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-001', subnational2_name=None), all_time_species=171),
#  EBirdHotspot(location=EBirdLocation(id='L4653581', name='Coastal Greenway, Portsmouth', latitude=41.6281852, longitude=-71.2611687, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-005', subnational2_name=None), all_time_species=112),
#  EBirdHotspot(location=EBirdLocation(id='L1406045', name='Cold Spring Park, Woonsocket', latitude=42.0091108, longitude=-71.5252876, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=62),
#  EBirdHotspot(location=EBirdLocation(id='L841267', name='Cole River Boat Ramp, Swansea', latitude=41.7263586, longitude=-71.2221336, country_code='US', subnational1_code='US-MA', subnational1_name=None, subnational2_code='US-MA-005', subnational2_name=None), all_time_species=123),
#  EBirdHotspot(location=EBirdLocation(id='L29143732', name='Collier Point Park, Providence', latitude=41.8120414, longitude=-71.401773, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=65),
#  EBirdHotspot(location=EBirdLocation(id='L613147', name='Colt State Park', latitude=41.6806368, longitude=-71.3021922, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-001', subnational2_name=None), all_time_species=241),
#  EBirdHotspot(location=EBirdLocation(id='L687632', name='Conimicut Point Park, Warwick', latitude=41.7167491, longitude=-71.360321, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-003', subnational2_name=None), all_time_species=146),
#  EBirdHotspot(location=EBirdLocation(id='L16672907', name='Conimicut Saltmarsh, Warwick', latitude=41.7136737, longitude=-71.364103, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-003', subnational2_name=None), all_time_species=76),
#  EBirdHotspot(location=EBirdLocation(id='L1786830', name='Copps Cove', latitude=41.7813513, longitude=-71.391461, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=68),
#  EBirdHotspot(location=EBirdLocation(id='L9955986', name='Council Oak Fields', latitude=41.8190476, longitude=-71.1344576, country_code='US', subnational1_code='US-MA', subnational1_name=None, subnational2_code='US-MA-005', subnational2_name=None), all_time_species=105),
#  EBirdHotspot(location=EBirdLocation(id='L12817315', name='Crescent Park, East Providence', latitude=41.7567563, longitude=-71.3611223, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=108),
#  EBirdHotspot(location=EBirdLocation(id='L4600100', name='Crestwood Country Club', latitude=41.8244527, longitude=-71.277253, country_code='US', subnational1_code='US-MA', subnational1_name=None, subnational2_code='US-MA-005', subnational2_name=None), all_time_species=34),
#  EBirdHotspot(location=EBirdLocation(id='L734901', name='Davis Memorial Wildlife Refuge (ASRI)', latitude=41.6236714, longitude=-71.4817259, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-009', subnational2_name=None), all_time_species=100),
#  EBirdHotspot(location=EBirdLocation(id='L38433651', name='Davis Park, Providence', latitude=41.833365, longitude=-71.430524, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=24),
#  EBirdHotspot(location=EBirdLocation(id='L31398708', name='Davisville Middle School Nature Paths', latitude=41.6193485, longitude=-71.4648414, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-009', subnational2_name=None), all_time_species=35),
#  EBirdHotspot(location=EBirdLocation(id='L38630506', name='Dexter Training Ground Park', latitude=41.814522, longitude=-71.431343, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=17),
#  EBirdHotspot(location=EBirdLocation(id='L11683398', name='Diamond Hill Management Area', latitude=42.001108, longitude=-71.431875, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=69),
#  EBirdHotspot(location=EBirdLocation(id='L10059274', name='Diamond Hill Park, Cumberland', latitude=42.0019027, longitude=-71.4131983, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=94),
#  EBirdHotspot(location=EBirdLocation(id='L16494250', name='Diamond Hill Reservoir, Cumberland', latitude=41.997013, longitude=-71.399154, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=116),
#  EBirdHotspot(location=EBirdLocation(id='L2283278', name='Dighton Town Landing', latitude=41.7968199, longitude=-71.120553, country_code='US', subnational1_code='US-MA', subnational1_name=None, subnational2_code='US-MA-005', subnational2_name=None), all_time_species=130),
#  EBirdHotspot(location=EBirdLocation(id='L4578087', name='Dighton Transfer Station', latitude=41.8546988, longitude=-71.1388779, country_code='US', subnational1_code='US-MA', subnational1_name=None, subnational2_code='US-MA-005', subnational2_name=None), all_time_species=82),
#  EBirdHotspot(location=EBirdLocation(id='L4538187', name='Dighton Water Pump Station (private)', latitude=41.8255552, longitude=-71.1267945, country_code='US', subnational1_code='US-MA', subnational1_name=None, subnational2_code='US-MA-005', subnational2_name=None), all_time_species=79),
#  EBirdHotspot(location=EBirdLocation(id='L1135167', name='Dodgeville Pond', latitude=41.9232654, longitude=-71.2951155, country_code='US', subnational1_code='US-MA', subnational1_name=None, subnational2_code='US-MA-005', subnational2_name=None), all_time_species=65),
#  EBirdHotspot(location=EBirdLocation(id='L1463082', name='Doug Rayner Wildlife Refuge at Nockum Hill', latitude=41.7680304, longitude=-71.31198, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-001', subnational2_name=None), all_time_species=177),
#  EBirdHotspot(location=EBirdLocation(id='L54768291', name='Dunnell Park, Pawtucket', latitude=41.864788, longitude=-71.3683087, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=30),
#  EBirdHotspot(location=EBirdLocation(id='L5126639', name='East Bay Bike Path--Barrington River Bridge to Warren Dog Park', latitude=41.7369613, longitude=-71.2859139, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-001', subnational2_name=None), all_time_species=87),
#  EBirdHotspot(location=EBirdLocation(id='L5123222', name='East Bay Bike Path--Bay Spring Ave. to Barrington Shopping Center', latitude=41.7389245, longitude=-71.3333058, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-001', subnational2_name=None), all_time_species=147),
#  EBirdHotspot(location=EBirdLocation(id='L730688', name='East Bay Bike Path--Colt State Park to Independence Park', latitude=41.6824731, longitude=-71.2813489, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-001', subnational2_name=None), all_time_species=130),
#  EBirdHotspot(location=EBirdLocation(id='L55322509', name='East Bay Bike Path--Veterans Memorial Parkway', latitude=41.8091301, longitude=-71.3871416, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=17),
#  EBirdHotspot(location=EBirdLocation(id='L3567188', name='East Bay Bike Path--Warren Dog Park to Colt State Park', latitude=41.705527, longitude=-71.28859, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-001', subnational2_name=None), all_time_species=143),
#  EBirdHotspot(location=EBirdLocation(id='L1139391', name='East Bay Bike Path--Watchemoket Cove to Pomham Rocks', latitude=41.7959681, longitude=-71.3778949, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=179),
#  EBirdHotspot(location=EBirdLocation(id='L5668641', name='East Greenwich Cemetery', latitude=41.6565934, longitude=-71.4570308, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-003', subnational2_name=None), all_time_species=14),
#  EBirdHotspot(location=EBirdLocation(id='L22412271', name='East Greenwich Cove Overlook', latitude=41.656898, longitude=-71.449188, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-003', subnational2_name=None), all_time_species=61),
#  EBirdHotspot(location=EBirdLocation(id='L7358879', name='East Greenwich Nature and Cross Country Trail', latitude=41.6334947, longitude=-71.4834452, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-003', subnational2_name=None), all_time_species=98),
#  EBirdHotspot(location=EBirdLocation(id='L21194566', name='East Point (formerly Greenwood Point)', latitude=41.8412036, longitude=-71.3717906, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=56),
#  EBirdHotspot(location=EBirdLocation(id='L1320533', name='Echo Lake, Barrington', latitude=41.7357344, longitude=-71.3339496, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-001', subnational2_name=None), all_time_species=137),
#  EBirdHotspot(location=EBirdLocation(id='L15883704', name='Fall River Heritage SP', latitude=41.7048283, longitude=-71.1601388, country_code='US', subnational1_code='US-MA', subnational1_name=None, subnational2_code='US-MA-005', subnational2_name=None), all_time_species=44),
#  EBirdHotspot(location=EBirdLocation(id='L487669', name='Flat River Reservoir, Coventry', latitude=41.7074586, longitude=-71.6359663, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-003', subnational2_name=None), all_time_species=119),
#  EBirdHotspot(location=EBirdLocation(id='L357306', name='Fort Wildlife Refuge (ASRI)', latitude=41.9606389, longitude=-71.5533972, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=117),
#  EBirdHotspot(location=EBirdLocation(id='L1458015', name='Franklin Farm, Cumberland', latitude=41.9668184, longitude=-71.393796, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=124),
#  EBirdHotspot(location=EBirdLocation(id='L6530163', name='Frenchtown Park, East Greenwich', latitude=41.626978, longitude=-71.506429, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-003', subnational2_name=None), all_time_species=114),
#  EBirdHotspot(location=EBirdLocation(id='L1390947', name='Fuller Pond', latitude=42.0126642, longitude=-71.3476719, country_code='US', subnational1_code='US-MA', subnational1_name=None, subnational2_code='US-MA-021', subnational2_name=None), all_time_species=116),
#  EBirdHotspot(location=EBirdLocation(id='L13048144', name='Gainsborough Commons (limited access)', latitude=42.008083, longitude=-71.453635, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=12),
#  EBirdHotspot(location=EBirdLocation(id='L1393330', name='Gano Park, Providence', latitude=41.823722, longitude=-71.3885067, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=80),
#  EBirdHotspot(location=EBirdLocation(id='L7788167', name='Gaspee Point', latitude=41.743699, longitude=-71.3766397, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-003', subnational2_name=None), all_time_species=92),
#  EBirdHotspot(location=EBirdLocation(id='L38630101', name='Gate of Heaven Cemetery, East Providence', latitude=41.792361, longitude=-71.339235, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=45),
#  EBirdHotspot(location=EBirdLocation(id='L15294747', name='George B. Parker Woodland—Gowdey Memorial Trail (Prov. Co.)', latitude=41.729585, longitude=-71.684546, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=51),
#  EBirdHotspot(location=EBirdLocation(id='L2776143', name='Georgiaville Pond', latitude=41.8913554, longitude=-71.5088081, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=66),
#  EBirdHotspot(location=EBirdLocation(id='L13158219', name='Glenford Cemetery, Scituate', latitude=41.8309334, longitude=-71.5904518, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=46),
#  EBirdHotspot(location=EBirdLocation(id='L1007144', name='Goddard Memorial SP', latitude=41.6611783, longitude=-71.4358091, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-003', subnational2_name=None), all_time_species=163),
#  EBirdHotspot(location=EBirdLocation(id='L6182809', name='Gorton Pond and Little Gorton Pond', latitude=41.7023002, longitude=-71.4622879, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-003', subnational2_name=None), all_time_species=115),
#  EBirdHotspot(location=EBirdLocation(id='L40170320', name='Governor John Notte Memorial Park, North Providence', latitude=41.8712226, longitude=-71.4631462, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=44),
#  EBirdHotspot(location=EBirdLocation(id='L46689195', name='Grassy Plains Park, East Providence', latitude=41.768335, longitude=-71.332246, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=21),
#  EBirdHotspot(location=EBirdLocation(id='L4588597', name='Great Woods Conservation Area', latitude=41.9981564, longitude=-71.2298584, country_code='US', subnational1_code='US-MA', subnational1_name=None, subnational2_code='US-MA-005', subnational2_name=None), all_time_species=94),
#  EBirdHotspot(location=EBirdLocation(id='L5455344', name='Haffenreffer Estate', latitude=41.679539, longitude=-71.2362903, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-001', subnational2_name=None), all_time_species=68),
#  EBirdHotspot(location=EBirdLocation(id='L11913876', name='Haile Farm Preserve (WLCT)', latitude=41.7514372, longitude=-71.279314, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-001', subnational2_name=None), all_time_species=128),
#  EBirdHotspot(location=EBirdLocation(id='L39583673', name='Haines Memorial State Park  (Providence County)', latitude=41.7540286, longitude=-71.3514138, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=38),
#  EBirdHotspot(location=EBirdLocation(id='L286912', name='Haines Memorial State Park (Bristol County)', latitude=41.7531189, longitude=-71.3504298, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-001', subnational2_name=None), all_time_species=122),
#  EBirdHotspot(location=EBirdLocation(id='L4333222', name='Handy Pond Conservation Area ', latitude=41.9560605, longitude=-71.4742713, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=86),
#  EBirdHotspot(location=EBirdLocation(id='L13041553', name='Harold Burns Memorial Wildlife Arboretum', latitude=41.9958385, longitude=-71.3217259, country_code='US', subnational1_code='US-MA', subnational1_name=None, subnational2_code='US-MA-005', subnational2_name=None), all_time_species=44),
#  EBirdHotspot(location=EBirdLocation(id='L15187055', name='Hemlock Rd., Foster', latitude=41.7913147, longitude=-71.6825409, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=73),
#  EBirdHotspot(location=EBirdLocation(id='L40521950', name='Heritage Park, Glocester', latitude=41.8920702, longitude=-71.6315403, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=19),
#  EBirdHotspot(location=EBirdLocation(id='L14885742', name='High Rock Farm Preserve', latitude=41.9565049, longitude=-71.4304866, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=94),
#  EBirdHotspot(location=EBirdLocation(id='L38666615', name='Highland Memorial Park Cemetery', latitude=41.855466, longitude=-71.4950323, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=18),
#  EBirdHotspot(location=EBirdLocation(id='L24131893', name='Highland Park', latitude=41.9436939, longitude=-71.2958576, country_code='US', subnational1_code='US-MA', subnational1_name=None, subnational2_code='US-MA-005', subnational2_name=None), all_time_species=103),
#  EBirdHotspot(location=EBirdLocation(id='L55055686', name='Hopkins Property, Foster Land Trust', latitude=41.818868, longitude=-71.702845, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=54),
#  EBirdHotspot(location=EBirdLocation(id='L14264549', name='Howard Conservation Area (PRAWC)', latitude=41.7324417, longitude=-71.4596712, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=97),
#  EBirdHotspot(location=EBirdLocation(id='L7401637', name='Howard Pond, Cumberland', latitude=41.9555687, longitude=-71.3875294, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=30),
#  EBirdHotspot(location=EBirdLocation(id='L3923511', name='Hundred Acre Cove', latitude=41.7622532, longitude=-71.3131356, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-001', subnational2_name=None), all_time_species=102),
#  EBirdHotspot(location=EBirdLocation(id='L15585790', name='Hundred Acre Cove (Providence Co.)', latitude=41.7744174, longitude=-71.3214949, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=106),
#  EBirdHotspot(location=EBirdLocation(id='L13447055', name='Hundred Acre Cove--North Trail access', latitude=41.770138, longitude=-71.323482, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-001', subnational2_name=None), all_time_species=75),
#  EBirdHotspot(location=EBirdLocation(id='L2802133', name='Hunt’s Mills Museum and Trail', latitude=41.8283457, longitude=-71.3469315, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=128),
#  EBirdHotspot(location=EBirdLocation(id='L2482586', name='Independence Park, Bristol', latitude=41.674403, longitude=-71.279586, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-001', subnational2_name=None), all_time_species=81),
#  EBirdHotspot(location=EBirdLocation(id='L8596244', name='India Point Park, Providence', latitude=41.8172568, longitude=-71.3903618, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=91),
#  EBirdHotspot(location=EBirdLocation(id='L19186567', name='Isthmus Rd., Foster', latitude=41.752805, longitude=-71.686923, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=72),
#  EBirdHotspot(location=EBirdLocation(id='L2781443', name="Jacob's Point Saltmarsh", latitude=41.7106636, longitude=-71.2903995, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-001', subnational2_name=None), all_time_species=196),
#  EBirdHotspot(location=EBirdLocation(id='L247829', name='James Turner Reservoir', latitude=41.8358267, longitude=-71.3394269, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=167),
#  EBirdHotspot(location=EBirdLocation(id='L7456597', name="Joe's Rock Conservation Area", latitude=42.0273639, longitude=-71.4056611, country_code='US', subnational1_code='US-MA', subnational1_name=None, subnational2_code='US-MA-021', subnational2_name=None), all_time_species=105),
#  EBirdHotspot(location=EBirdLocation(id='L12266919', name='John L. Curran Management Area', latitude=41.7507133, longitude=-71.5477124, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=90),
#  EBirdHotspot(location=EBirdLocation(id='L7441559', name='Juniper Hill Cemetery', latitude=41.6811015, longitude=-71.2680531, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-001', subnational2_name=None), all_time_species=71),
#  EBirdHotspot(location=EBirdLocation(id='L19377129', name='Kate Randall Rd., Foster', latitude=41.80447, longitude=-71.697416, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=54),
#  EBirdHotspot(location=EBirdLocation(id='L24184797', name='Kennedy Plaza, Providence', latitude=41.825473, longitude=-71.412127, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=38),
#  EBirdHotspot(location=EBirdLocation(id='L55029974', name='Kent Heights Park, East Providence', latitude=41.805105, longitude=-71.356364, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=13),
#  EBirdHotspot(location=EBirdLocation(id='L55389099', name='Kickemuit River--Child Street Bridge', latitude=41.729527, longitude=-71.2626966, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-001', subnational2_name=None), all_time_species=3),
#  EBirdHotspot(location=EBirdLocation(id='L17120086', name='Kickemuit River--Schoolhouse & Serpentine Road', latitude=41.7397652, longitude=-71.2602269, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-001', subnational2_name=None), all_time_species=156),
#  EBirdHotspot(location=EBirdLocation(id='L11806624', name='Knight Farm Trail (West Bay Land Trust)', latitude=41.7529773, longitude=-71.5292781, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=47),
#  EBirdHotspot(location=EBirdLocation(id='L12052632', name='L.A. Foster Wildlife Refuge', latitude=41.9474619, longitude=-71.1761466, country_code='US', subnational1_code='US-MA', subnational1_name=None, subnational2_code='US-MA-005', subnational2_name=None), all_time_species=57),
#  EBirdHotspot(location=EBirdLocation(id='L866565', name='Lake Como, Attleboro', latitude=41.9262365, longitude=-71.3583362, country_code='US', subnational1_code='US-MA', subnational1_name=None, subnational2_code='US-MA-005', subnational2_name=None), all_time_species=55),
#  EBirdHotspot(location=EBirdLocation(id='L1393144', name='Lake Hiawatha', latitude=41.9665834, longitude=-71.3233878, country_code='US', subnational1_code='US-MA', subnational1_name=None, subnational2_code='US-MA-005', subnational2_name=None), all_time_species=98),
#  EBirdHotspot(location=EBirdLocation(id='L1393150', name='Lake Mirimichi', latitude=42.0279285, longitude=-71.2963494, country_code='US', subnational1_code='US-MA', subnational1_name=None, subnational2_code='US-MA-021', subnational2_name=None), all_time_species=82),
#  EBirdHotspot(location=EBirdLocation(id='L1365565', name='Latham Park, Barrington', latitude=41.7457879, longitude=-71.3520883, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-001', subnational2_name=None), all_time_species=79),
#  EBirdHotspot(location=EBirdLocation(id='L4525701', name='Lawton Farm (Scituate Land Trust)', latitude=41.7574513, longitude=-71.5561652, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=130),
#  EBirdHotspot(location=EBirdLocation(id='L4053762', name='Lewin Brook Pond', latitude=41.7462816, longitude=-71.1926079, country_code='US', subnational1_code='US-MA', subnational1_name=None, subnational2_code='US-MA-005', subnational2_name=None), all_time_species=51),
#  EBirdHotspot(location=EBirdLocation(id='L393285', name='Lincoln Woods State Park', latitude=41.8962718, longitude=-71.4355516, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=152),
#  EBirdHotspot(location=EBirdLocation(id='L14185394', name='Lippitt Memorial Park', latitude=41.8546509, longitude=-71.3915205, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=48),
#  EBirdHotspot(location=EBirdLocation(id='L12824129', name='Little Neck Cemetery', latitude=41.7667433, longitude=-71.3542489, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=84),
#  EBirdHotspot(location=EBirdLocation(id='L13992195', name='Little Pond, Cumberland', latitude=41.9624751, longitude=-71.4213747, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=54),
#  EBirdHotspot(location=EBirdLocation(id='L549748', name='Lonsdale General Area (please use more refined hotspot)', latitude=41.9064273, longitude=-71.3999829, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=150),
#  EBirdHotspot(location=EBirdLocation(id='L12295388', name='Lonsdale Marsh--Lonsdale Ave. access', latitude=41.9020296, longitude=-71.404301, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=154),
#  EBirdHotspot(location=EBirdLocation(id='L17150946', name='Mallard Point', latitude=41.7726055, longitude=-71.1205563, country_code='US', subnational1_code='US-MA', subnational1_name=None, subnational2_code='US-MA-005', subnational2_name=None), all_time_species=63),
#  EBirdHotspot(location=EBirdLocation(id='L1297392', name='Manchester Pond Reservoir', latitude=41.9461929, longitude=-71.3158393, country_code='US', subnational1_code='US-MA', subnational1_name=None, subnational2_code='US-MA-005', subnational2_name=None), all_time_species=136),
#  EBirdHotspot(location=EBirdLocation(id='L3157427', name='Maple Street Powerline Cut', latitude=41.8651505, longitude=-71.1994743, country_code='US', subnational1_code='US-MA', subnational1_name=None, subnational2_code='US-MA-005', subnational2_name=None), all_time_species=126),
#  EBirdHotspot(location=EBirdLocation(id='L15210138', name='Marsh Point, Warwick', latitude=41.65971, longitude=-71.41081, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-003', subnational2_name=None), all_time_species=159),
#  EBirdHotspot(location=EBirdLocation(id='L1391689', name="Mary's Creek, Warwick", latitude=41.6891348, longitude=-71.4513884, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-003', subnational2_name=None), all_time_species=128),
#  EBirdHotspot(location=EBirdLocation(id='L9545732', name='Mashapaug Park, Providence', latitude=41.7960733, longitude=-71.4301347, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=140),
#  EBirdHotspot(location=EBirdLocation(id='L30901951', name='Mason Field', latitude=41.973644, longitude=-71.315139, country_code='US', subnational1_code='US-MA', subnational1_name=None, subnational2_code='US-MA-005', subnational2_name=None), all_time_species=42),
# ...
#  EBirdHotspot(location=EBirdLocation(id='L40384308', name='Ten Mile River Greenway--Dagget Ave. Trailhead to Armistice Blvd', latitude=41.8824328, longitude=-71.3426111, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=23),
#  EBirdHotspot(location=EBirdLocation(id='L2599631', name='Ten Mile River Greenway--Ferris Ave. Trailhead to Slater Park', latitude=41.8496377, longitude=-71.3443893, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=116),
#  EBirdHotspot(location=EBirdLocation(id='L5426087', name='Ten Mile River Reservation (Armistice Blvd. viewpoint)', latitude=41.875147, longitude=-71.340459, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=111),
#  EBirdHotspot(location=EBirdLocation(id='L1458029', name='The Monastery, Cumberland', latitude=41.9350531, longitude=-71.4075396, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=181),
#  EBirdHotspot(location=EBirdLocation(id='L8920590', name='Tillinghast Place / RISD Beach', latitude=41.725982, longitude=-71.321841, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-001', subnational2_name=None), all_time_species=142),
#  EBirdHotspot(location=EBirdLocation(id='L815443', name='Tiogue Lake', latitude=41.6790406, longitude=-71.5503244, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-003', subnational2_name=None), all_time_species=120),
#  EBirdHotspot(location=EBirdLocation(id='L4207196', name='Tiogue Lake--Outflow', latitude=41.685423, longitude=-71.553619, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-003', subnational2_name=None), all_time_species=106),
#  EBirdHotspot(location=EBirdLocation(id='L213318', name='Touisset Marsh Wildlife Refuge (ASRI)', latitude=41.7059838, longitude=-71.2374794, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-001', subnational2_name=None), all_time_species=160),
#  EBirdHotspot(location=EBirdLocation(id='L15208246', name='Tower Hill Rd., Cumberland', latitude=41.994098, longitude=-71.444035, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=60),
#  EBirdHotspot(location=EBirdLocation(id='L42665518', name='Town Line Swamp', latitude=41.933718, longitude=-71.486849, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=25),
#  EBirdHotspot(location=EBirdLocation(id='L900794', name='Town Pond (ALT)', latitude=41.6323646, longitude=-71.245544, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-005', subnational2_name=None), all_time_species=152),
#  EBirdHotspot(location=EBirdLocation(id='L16657907', name='Townie Pride Memorial Park, East Providence', latitude=41.808964, longitude=-71.385004, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=53),
#  EBirdHotspot(location=EBirdLocation(id='L3260829', name='Tricentennial Park', latitude=41.8103868, longitude=-71.1191475, country_code='US', subnational1_code='US-MA', subnational1_name=None, subnational2_code='US-MA-005', subnational2_name=None), all_time_species=112),
#  EBirdHotspot(location=EBirdLocation(id='L12450396', name='Tucker Field, Cumberland', latitude=41.9644865, longitude=-71.4426209, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=27),
#  EBirdHotspot(location=EBirdLocation(id='L2718493', name='Turnpike Lake', latitude=42.0158388, longitude=-71.3119447, country_code='US', subnational1_code='US-MA', subnational1_name=None, subnational2_code='US-MA-021', subnational2_name=None), all_time_species=93),
#  EBirdHotspot(location=EBirdLocation(id='L41541061', name='Twin River Casino Retention Ponds, Lincoln', latitude=41.88732, longitude=-71.444158, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=36),
#  EBirdHotspot(location=EBirdLocation(id='L10189488', name='Venus De Milo Pond', latitude=41.7429672, longitude=-71.1885811, country_code='US', subnational1_code='US-MA', subnational1_name=None, subnational2_code='US-MA-005', subnational2_name=None), all_time_species=52),
#  EBirdHotspot(location=EBirdLocation(id='L8678323', name='Veterans Memorial Park, Pawtucket', latitude=41.8794371, longitude=-71.3818826, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=47),
#  EBirdHotspot(location=EBirdLocation(id='L29863733', name='Village Park, Swansea', latitude=41.7510963, longitude=-71.1898653, country_code='US', subnational1_code='US-MA', subnational1_name=None, subnational2_code='US-MA-005', subnational2_name=None), all_time_species=54),
#  EBirdHotspot(location=EBirdLocation(id='L5495329', name='Village Waterfront Park, Somerset', latitude=41.7696541, longitude=-71.1251423, country_code='US', subnational1_code='US-MA', subnational1_name=None, subnational2_code='US-MA-005', subnational2_name=None), all_time_species=70),
#  EBirdHotspot(location=EBirdLocation(id='L12545551', name='WWII Memorial State Park', latitude=42.0096446, longitude=-71.5093249, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=22),
#  EBirdHotspot(location=EBirdLocation(id='L29020679', name='Wading River Reservoir', latitude=41.989602, longitude=-71.254242, country_code='US', subnational1_code='US-MA', subnational1_name=None, subnational2_code='US-MA-005', subnational2_name=None), all_time_species=63),
#  EBirdHotspot(location=EBirdLocation(id='L1888546', name='Walker Cove', latitude=41.6604123, longitude=-71.2706554, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-001', subnational2_name=None), all_time_species=79),
#  EBirdHotspot(location=EBirdLocation(id='L453500', name='Walker Farm', latitude=41.7555945, longitude=-71.3227701, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-001', subnational2_name=None), all_time_species=167),
#  EBirdHotspot(location=EBirdLocation(id='L4095950', name='Walker Street Reserve, Westville Conservation Area', latitude=41.8899385, longitude=-71.1320382, country_code='US', subnational1_code='US-MA', subnational1_name=None, subnational2_code='US-MA-005', subnational2_name=None), all_time_species=99),
#  EBirdHotspot(location=EBirdLocation(id='L31745262', name='Walnut Hill Cemetery', latitude=41.8811125, longitude=-71.3687754, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=44),
#  EBirdHotspot(location=EBirdLocation(id='L6370013', name='Warren Bike Path', latitude=41.7260657, longitude=-71.2597087, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-001', subnational2_name=None), all_time_species=97),
#  EBirdHotspot(location=EBirdLocation(id='L1306965', name='Warren Upper Reservoir ', latitude=41.8251622, longitude=-71.2174559, country_code='US', subnational1_code='US-MA', subnational1_name=None, subnational2_code='US-MA-005', subnational2_name=None), all_time_species=116),
#  EBirdHotspot(location=EBirdLocation(id='L1325528', name='Warwick City Park', latitude=41.6885579, longitude=-71.4063702, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-003', subnational2_name=None), all_time_species=115),
#  EBirdHotspot(location=EBirdLocation(id='L22140967', name='Warwick Pond', latitude=41.7238791, longitude=-71.4123253, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-003', subnational2_name=None), all_time_species=46),
#  EBirdHotspot(location=EBirdLocation(id='L43850174', name='Washington Secondary Trail--Father Tirocchi Field Area', latitude=41.7249223, longitude=-71.48592, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-003', subnational2_name=None), all_time_species=37),
#  EBirdHotspot(location=EBirdLocation(id='L29523147', name='Washington Secondary Trail--Pawtuxet River Wetland Overlook', latitude=41.696943, longitude=-71.580597, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-003', subnational2_name=None), all_time_species=13),
#  EBirdHotspot(location=EBirdLocation(id='L187164', name='Watchemoket Cove', latitude=41.800495, longitude=-71.376686, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=137),
#  EBirdHotspot(location=EBirdLocation(id='L12799134', name='Waterman Reservoir', latitude=41.8799557, longitude=-71.5805218, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=62),
#  EBirdHotspot(location=EBirdLocation(id='L13430824', name='Waterman St. Dog Park', latitude=41.8277178, longitude=-71.3835141, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=73),
#  EBirdHotspot(location=EBirdLocation(id='L12606996', name='Waypoyset Preserve (Land Trust)', latitude=41.697007, longitude=-71.2498423, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-001', subnational2_name=None), all_time_species=38),
#  EBirdHotspot(location=EBirdLocation(id='L1390952', name='Wetherells Pond', latitude=42.0003917, longitude=-71.3375304, country_code='US', subnational1_code='US-MA', subnational1_name=None, subnational2_code='US-MA-021', subnational2_name=None), all_time_species=115),
#  EBirdHotspot(location=EBirdLocation(id='L13121233', name='Wetlands Robinson Ave. Dam', latitude=41.9680397, longitude=-71.3120677, country_code='US', subnational1_code='US-MA', subnational1_name=None, subnational2_code='US-MA-005', subnational2_name=None), all_time_species=31),
#  EBirdHotspot(location=EBirdLocation(id='L2390045', name='Wheaton College', latitude=41.9673242, longitude=-71.1837137, country_code='US', subnational1_code='US-MA', subnational1_name=None, subnational2_code='US-MA-005', subnational2_name=None), all_time_species=141),
#  EBirdHotspot(location=EBirdLocation(id='L3300181', name='Whiting Pond, North Attleborough', latitude=41.9941027, longitude=-71.3352263, country_code='US', subnational1_code='US-MA', subnational1_name=None, subnational2_code='US-MA-005', subnational2_name=None), all_time_species=40),
#  EBirdHotspot(location=EBirdLocation(id='L12073266', name='Willett Pond, East Providence', latitude=41.775647, longitude=-71.356669, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=76),
#  EBirdHotspot(location=EBirdLocation(id='L12639998', name='Winslow Park', latitude=41.7252496, longitude=-71.4198935, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-003', subnational2_name=None), all_time_species=78),
#  EBirdHotspot(location=EBirdLocation(id='L1618211', name='Witch Pond, Foxboro', latitude=42.0177869, longitude=-71.2867241, country_code='US', subnational1_code='US-MA', subnational1_name=None, subnational2_code='US-MA-021', subnational2_name=None), all_time_species=75),
#  EBirdHotspot(location=EBirdLocation(id='L47132166', name='Wolf Hill Preserve--Old Quarry Trails', latitude=41.887409, longitude=-71.534424, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=22),
#  EBirdHotspot(location=EBirdLocation(id='L13057430', name='Wood Lake Park and Almy Reservoir', latitude=41.8159533, longitude=-71.5271886, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=110),
#  EBirdHotspot(location=EBirdLocation(id='L31392271', name='Woonasquatucket River Greenway--Manton Pond Area to Merino Park', latitude=41.8339789, longitude=-71.4724742, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=105),
#  EBirdHotspot(location=EBirdLocation(id='L28111910', name='Woonasquatucket River Greenway--Riverside Park to Merino Park', latitude=41.8207141, longitude=-71.450412, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=55),
#  EBirdHotspot(location=EBirdLocation(id='L12545495', name='Woonsocket Public Library', latitude=42.0051404, longitude=-71.5082279, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=20),
#  EBirdHotspot(location=EBirdLocation(id='L12136837', name='Woonsocket Reservoir #3', latitude=41.9430759, longitude=-71.4980264, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=57),
#  EBirdHotspot(location=EBirdLocation(id='L40170227', name='World War I Memorial Park and Zoo', latitude=41.9989253, longitude=-71.3135779, country_code='US', subnational1_code='US-MA', subnational1_name=None, subnational2_code='US-MA-005', subnational2_name=None), all_time_species=11),
#  EBirdHotspot(location=EBirdLocation(id='L11430695', name="Zeke's Bridge Fishing Access and Trails", latitude=41.6650256, longitude=-71.618607, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-003', subnational2_name=None), all_time_species=85),
#  EBirdHotspot(location=EBirdLocation(id='L1878310', name='stakeout Black-throated Gray Warbler, 103 James H. Luther Dr., Taunton (Jan 2013)', latitude=41.8984761, longitude=-71.1748638, country_code='US', subnational1_code='US-MA', subnational1_name=None, subnational2_code='US-MA-005', subnational2_name=None), all_time_species=34),
#  EBirdHotspot(location=EBirdLocation(id='L35960144', name='stakeout Lark Bunting--Norton (2024)', latitude=41.9697876, longitude=-71.1947624, country_code='US', subnational1_code='US-MA', subnational1_name=None, subnational2_code='US-MA-005', subnational2_name=None), all_time_species=43),
#  EBirdHotspot(location=EBirdLocation(id='L5128475', name='stakeout Sandhill Crane--Swansea (2016)', latitude=41.740978, longitude=-71.193583, country_code='US', subnational1_code='US-MA', subnational1_name=None, subnational2_code='US-MA-005', subnational2_name=None), all_time_species=26),
#  EBirdHotspot(location=EBirdLocation(id='L31274340', name='stakeout Swallow-Tailed Kite--Attleboro (2024)', latitude=41.9131963, longitude=-71.2290574, country_code='US', subnational1_code='US-MA', subnational1_name=None, subnational2_code='US-MA-005', subnational2_name=None), all_time_species=10),
#  EBirdHotspot(location=EBirdLocation(id='L12966956', name='stakeout Varied Thrush--Chepachet (2020-2021)', latitude=41.9154969, longitude=-71.6022595, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=59)]

# %%
from geopy.distance import geodesic

# Find the hotspot nearest to the original location
location_coord = (location.latitude, location.longitude)


def geodesic_distance_mi(c1: Coordinate, c2: Coordinate) -> float:
    """Find the geodesic distance (in miles) between two GPS coordinates."""
    return geodesic(c1, c2).miles


nearest_hotspot = min(
    nearby_hotspots,
    key=lambda hs: geodesic_distance_mi(c1=location_coord, c2=hs.location.coordinate),
)
nearest_hotspot
# Out:
# EBirdHotspot(location=EBirdLocation(id='L24184797', name='Kennedy Plaza, Providence', latitude=41.825473, longitude=-71.412127, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), all_time_species=38)

# %%
from ebird.api.requests import get_species_list

get_species_list(token=ebird_api_key, area=nearest_hotspot.location.id)
# Out:
# ['cangoo',
#  'mutswa',
#  'mallar3',
#  'ambduc',
#  'wiltur',
#  'rocpig',
#  'moudov',
#  'chiswi',
#  'ribgul',
#  'amhgul1',
#  'doccor',
#  'coohaw',
#  'rebwoo',
#  'dowwoo',
#  'perfal',
#  'easpho',
#  'blujay',
#  'amecro',
#  'fiscro',
#  'bkcchi',
#  'tuftit',
#  'gockin',
#  'whbnut',
#  'carwre',
#  'eursta',
#  'grycat',
#  'normoc',
#  'amerob',
#  'cedwax',
#  'houspa',
#  'houfin',
#  'amegfi',
#  'chispa',
#  'fiespa',
#  'sonspa',
#  'bnhcow',
#  'comgra',
#  'norcar']

# %%
@dataclass(frozen=True)
class SurroundingSpecies:
    """A collection of species information in the regions containing a location."""

    location: EBirdLocation
    location_species: list[str]
    subnational2_species: list[str] | None
    subnational1_species: list[str] | None
    country_species: list[str]

    def __str__(self) -> str:
        """Return a human-readable string representation of the species collection."""
        species_str = f"Location ({self.location.name}) Species: {len(self.location_species)}\n"

        if self.subnational2_species is not None:
            subnat2_name = (
                self.location.subnational2_name
                if self.location.subnational2_name is not None
                else self.location.subnational2_code
            )
            n_subnat2_species = len(self.subnational2_species)
            species_str += f"Subnational Region 2 ({subnat2_name}) Species: {n_subnat2_species}\n"

        if self.subnational1_species is not None:
            subnat1_name = (
                self.location.subnational1_name
                if self.location.subnational1_name is not None
                else self.location.subnational1_code
            )
            n_subnat1_species = len(self.subnational1_species)
            species_str += f"Subnational Region 1 ({subnat1_name}) Species: {n_subnat1_species}\n"

        country_code = self.location.country_code
        species_str += f"Country ({country_code}) Species: {len(self.country_species)}"

        return species_str

    @classmethod
    def from_location(cls, location: EBirdLocation) -> SurroundingSpecies:
        """Identify the species in the various regions surrounding the given location."""
        location_species = get_species_list(ebird_api_key, location.id)

        if location.subnational1_code is not None:
            try:
                subnat1_species = get_species_list(ebird_api_key, location.subnational1_code)
            except ValueError:
                subnat1_species = None
        else:
            subnat1_species = None

        if location.subnational2_code is not None:
            try:
                subnat2_species = get_species_list(ebird_api_key, location.subnational2_code)
            except ValueError:
                subnat2_species = None
        else:
            subnat2_species = None

        country_species = get_species_list(ebird_api_key, location.country_code)

        return SurroundingSpecies(
            location, location_species, subnat2_species, subnat1_species, country_species
        )

# %%
species = SurroundingSpecies.from_location(nearest_hotspot.location)
species
# Out:
# SurroundingSpecies(location=EBirdLocation(id='L24184797', name='Kennedy Plaza, Providence', latitude=41.825473, longitude=-71.412127, country_code='US', subnational1_code='US-RI', subnational1_name=None, subnational2_code='US-RI-007', subnational2_name=None), location_species=['cangoo', 'mutswa', 'mallar3', 'ambduc', 'wiltur', 'rocpig', 'moudov', 'chiswi', 'ribgul', 'amhgul1', 'doccor', 'coohaw', 'rebwoo', 'dowwoo', 'perfal', 'easpho', 'blujay', 'amecro', 'fiscro', 'bkcchi', 'tuftit', 'gockin', 'whbnut', 'carwre', 'eursta', 'grycat', 'normoc', 'amerob', 'cedwax', 'houspa', 'houfin', 'amegfi', 'chispa', 'fiespa', 'sonspa', 'bnhcow', 'comgra', 'norcar'], subnational2_species=['snogoo', 'rosgoo', 'gragoo', 'x00776', 'gwfgoo', 'pifgoo', 'brant', 'bargoo', 'cacgoo1', 'cangoo', 'x00758', 'x00759', 'mutswa', 'truswa', 'tunswa', 'musduc', 'wooduc', 'buwtea', 'cintea', 'norsho', 'gadwal', 'eurwig', 'amewig', 'x00724', 'mallar3', 'ambduc', 'x00004', 'norpin', 'x00628', 'gnwtea', 'canvas', 'redhea', 'rinduc', 'tufduc', 'gresca', 'lessca', 'x00613', 'tdxsca1', 'comeid', 'sursco', 'whwsco2', 'blksco2', 'lotduc', 'buffle', 'comgol', 'bargol', 'cxbgol1', 'hoomer', 'commer', 'rebmer', 'rudduc', 'norbob', 'wiltur', 'rufgro', 'rinphe1', 'chukar', 'rocpig', 'afcdov1', 'moudov', 'yebcuc', 'bkbcuc', 'comcuc', 'comnig', 'easwpw1', 'chiswi', 'rthhum', 'rufhum', 'clarai11', 'virrai', 'corcra', 'sora', 'comgal1', 'y00475', 'sancra', 'ameoys', 'bkbplo', 'amgplo', 'killde', 'semplo', 'uplsan', 'shbdow', 'lobdow', 'amewoo', 'wilsni1', 'sposan', 'solsan', 'lesyel', 'willet1', 'greyel', 'rudtur', 'ruff', 'stisan', 'bubsan', 'sander', 'dunlin', 'pursan', 'baisan', 'whrsan', 'leasan', 'pecsan', 'semsan', 'doveki', 'bongul', 'bkhgul', 'laugul', 'mewgul', 'ribgul', 'amhgul1', 'gbbgul', 'glagul', 'lbbgul', 'y00478', 'blkski', 'sooter1', 'leater1', 'caster1', 'blkter', 'forter', 'arcter', 'comter', 'roster', 'pibgre', 'horgre', 'rengre', 'eargre', 'retloo', 'comloo', 'anhing', 'grecor', 'doccor', 'whiibi', 'gloibi', 'amebit', 'ycnher', 'bcnher', 'libher', 'snoegr', 'grnher', 'categr1', 'greegr', 'grbher3', 'amwpel', 'blkvul', 'turvul', 'osprey', 'swtkit', 'goleag', 'shshaw', 'coohaw', 'norgos', 'norhar2', 'baleag', 'miskit', 'brwhaw', 'reshaw', 'rethaw', 'x00686', 'rolhaw', 'easowl1', 'snoowl1', 'grhowl', 'brdowl', 'loeowl', 'sheowl', 'nswowl', 'belkin1', 'yebsap', 'lewwoo', 'rehwoo', 'rebwoo', 'dowwoo', 'haiwoo', 'pilwoo', 'norfli', 'amekes', 'merlin', 'perfal', 'cockat', 'monpar', 'olsfly', 'eawpew', 'yebfly', 'acafly', 'aldfly', 'wilfly', 'leafly', 'easpho', 'saypho', 'astfly', 'grcfly', 'weskin', 'easkin', 'whevir', 'yetvir', 'buhvir', 'phivir', 'eawvir1', 'reevir1', 'norshr4', 'blujay', 'amecro', 'fiscro', 'comrav', 'bkcchi', 'tuftit', 'horlar', 'banswa', 'treswa', 'purmar', 'nrwswa', 'barswa', 'cliswa', 'rewbul', 'ruckin', 'gockin', 'whbnut', 'rebnut', 'brncre', 'buggna', 'houwre', 'winwre3', 'sedwre1', 'marwre', 'carwre', 'eursta', 'grycat', 'brnthr', 'normoc', 'easblu', 'towsol', 'varthr', 'veery', 'gycthr', 'swathr', 'herthr', 'woothr', 'amerob', 'cedwax', 'houspa', 'amepip', 'evegro', 'pingro', 'houfin', 'purfin', 'redpol1', 'redcro', 'whwcro', 'pinsis', 'amegfi', 'laplon', 'snobun', 'graspa', 'chispa', 'clcspa', 'fiespa', 'larspa', 'amtspa', 'foxspa', 'daejun', 'whcspa', 'whtspa', 'x00039', 'vesspa', 'nstspa', 'sstspa', 'savspa', 'sonspa', 'linspa', 'swaspa', 'eastow', 'yebcha', 'yehbla', 'boboli', 'easmea', 'orcori', 'balori', 'rewbla', 'bnhcow', 'rusbla', 'brebla', 'comgra', 'ovenbi1', 'woewar1', 'louwat', 'norwat', 'gowwar', 'buwwar', 'brewar', 'bawwar', 'prowar', 'tenwar', 'orcwar', 'naswar', 'conwar', 'macwar', 'mouwar', 'kenwar', 'comyel', 'hoowar', 'amered', 'camwar', 'cerwar', 'norpar', 'magwar', 'babwar', 'bkbwar', 'yelwar1', 'chswar', 'bkpwar', 'btbwar', 'palwar', 'pinwar', 'yerwar', 'yetwar', 'prawar', 'towwar', 'btnwar', 'canwar', 'wlswar', 'sumtan', 'scatan', 'westan', 'norcar', 'robgro', 'blugrb1', 'indbun', 'paibun', 'dickci'], subnatio ...

# %%
print(species)
# Out:
# Location (Kennedy Plaza, Providence) Species: 38
# Subnational Region 2 (US-RI-007) Species: 328
# Subnational Region 1 (US-RI) Species: 472
# Country (US) Species: 1775
