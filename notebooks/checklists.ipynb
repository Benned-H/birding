# %% [markdown]
# Goal: Retrieve the species checklist for a region using the eBird API.

# %%
from __future__ import annotations

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from birding.ebird_api import get_ebird_api_key

ebird_api_key = get_ebird_api_key()

# %%
locations_of_interest = ["Providence, Rhode Island, United States"]

# %%
from birding.geocoding import retrieve_geocode
from birding.sqlite_cache import init_db

init_db()
for location in locations_of_interest:
    print(f"\n\nRetrieving geocode for location '{location}'...")
    data = retrieve_geocode(query=location)
    if data is None:
        print(f"Could not find geocode for location '{location}'.")
    else:
        print(data)
# Out:
# Retrieving geocode for location 'Providence, Rhode Island, United States'...
# Geocode for query 'Providence, Rhode Island, United States' was already cached.
# {'place_id': 334465335, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 191210, 'lat': '41.8239891', 'lon': '-71.4128343', 'class': 'boundary', 'type': 'administrative', 'place_rank': 16, 'importance': 0.6540931864702114, 'addresstype': 'city', 'name': 'Providence', 'display_name': 'Providence, Providence County, Rhode Island, United States', 'boundingbox': ['41.7724345', '41.8618007', '-71.4726670', '-71.3736135']}

# %%
from birding.primitives import Coordinate

raw_location_data = {loc: retrieve_geocode(query=loc) for loc in locations_of_interest}
location_data = {loc: data for loc, data in raw_location_data.items() if data is not None}
assert len(raw_location_data) == len(location_data), "A location's geocode data was None!"

location_coords = {loc: Coordinate.from_geocode_data(data) for loc, data in location_data.items()}
location_coords
# Out:
# Geocode for query 'Providence, Rhode Island, United States' was already cached.
# {'Providence, Rhode Island, United States': Coordinate(latitude=41.8239891, longitude=-71.4128343)}

# %%
from birding.ebird_api import retrieve_nearby_hotspots

for loc, coord in location_coords.items():
    print(f"\n\nRetrieving nearby hotspots for location '{loc}'...")
    hotspots = retrieve_nearby_hotspots(ebird_api_key, coord=coord)
    print(f"Found {len(hotspots)} nearby hotspots.")

    if len(hotspots) < 5:
        print("Location had less than 5 nearby hotspots!")
        more_hotspots = retrieve_nearby_hotspots(ebird_api_key, coord=coord, distance_km=50)
        print(f"Found {len(more_hotspots)} hotspots within 50 km.")
# Out:
# Retrieving nearby hotspots for location 'Providence, Rhode Island, United States'...
# Nearby hotspots for (41.8240, -71.4128) were already cached.
# Found 337 nearby hotspots.

# %%
spots_per_loc = {
    loc: retrieve_nearby_hotspots(ebird_api_key, coord) for loc, coord in location_coords.items()
}

spots_per_loc
# Out:
# Nearby hotspots for (41.8240, -71.4128) were already cached.
# {'Providence, Rhode Island, United States': [{'locId': 'L9189645',
#    'locName': 'Allen Harbor Marina',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-009',
#    'lat': 41.6197094,
#    'lng': -71.4112937,
#    'latestObsDt': '2025-11-04 15:39',
#    'numSpeciesAllTime': 121},
#   {'locId': 'L5070824',
#    'locName': "Allin's Cove (Barrington Land Trust)",
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-001',
#    'lat': 41.7442266,
#    'lng': -71.3481226,
#    'latestObsDt': '2025-12-18 07:39',
#    'numSpeciesAllTime': 123},
#   {'locId': 'L33244456',
#    'locName': 'Anthony Lawrence Wildlife Preserve',
#    'countryCode': 'US',
#    'subnational1Code': 'US-MA',
#    'subnational2Code': 'US-MA-005',
#    'lat': 41.92324,
#    'lng': -71.349151,
#    'latestObsDt': '2025-12-18 06:38',
#    'numSpeciesAllTime': 58},
#   {'locId': 'L634993',
#    'locName': 'Apponaug Cove',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-003',
#    'lat': 41.6953469,
#    'lng': -71.4527607,
#    'latestObsDt': '2025-12-29 11:45',
#    'numSpeciesAllTime': 145},
#   {'locId': 'L870123',
#    'locName': 'Arcade Ave., Seekonk',
#    'countryCode': 'US',
#    'subnational1Code': 'US-MA',
#    'subnational2Code': 'US-MA-005',
#    'lat': 41.8409524,
#    'lng': -71.3356447,
#    'latestObsDt': '2025-02-08 15:00',
#    'numSpeciesAllTime': 51},
#   {'locId': 'L450725',
#    'locName': 'Arnold Mills Reservoir, Cumberland',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.9862744,
#    'lng': -71.3969407,
#    'latestObsDt': '2025-12-26 14:22',
#    'numSpeciesAllTime': 187},
#   {'locId': 'L42925934',
#    'locName': 'Atlantic White Cedar Swamp Preserve (Cumberland Land Trust)',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.9745808,
#    'lng': -71.4355125,
#    'latestObsDt': '2025-10-18 09:26',
#    'numSpeciesAllTime': 62},
#   {'locId': 'L23891210',
#    'locName': 'Attleboro Community Garden',
#    'countryCode': 'US',
#    'subnational1Code': 'US-MA',
#    'subnational2Code': 'US-MA-005',
#    'lat': 41.9443897,
#    'lng': -71.2897038,
#    'latestObsDt': '2024-05-13 17:10',
#    'numSpeciesAllTime': 29},
#   {'locId': 'L1282270',
#    'locName': 'Attleboro Springs Wildlife Sanctuary (Mass Audubon)',
#    'countryCode': 'US',
#    'subnational1Code': 'US-MA',
#    'subnational2Code': 'US-MA-005',
#    'lat': 41.9286191,
#    'lng': -71.2647432,
#    'latestObsDt': '2025-09-26 18:29',
#    'numSpeciesAllTime': 102},
#   {'locId': 'L2875659',
#    'locName': 'Aust Family Preserve at Lime Rock (TNC)',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.924037,
#    'lng': -71.4682531,
#    'latestObsDt': '2025-11-26 10:19',
#    'numSpeciesAllTime': 99},
#   {'locId': 'L17492948',
#    'locName': 'Barney Ave./Almeida Rd. Fields, Rehoboth',
#    'countryCode': 'US',
#    'subnational1Code': 'US-MA',
#    'subnational2Code': 'US-MA-005',
#    'lat': 41.786875,
#    'lng': -71.286641,
#    'latestObsDt': '2025-12-18 12:33',
#    'numSpeciesAllTime': 43},
#   {'locId': 'L34675950',
#    'locName': 'Barney Pond, Lincoln',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.8967623,
#    'lng': -71.41608,
#    'latestObsDt': '2025-12-23 10:53',
#    'numSpeciesAllTime': 45},
#   {'locId': 'L983673',
#    'locName': 'Barrington Town Beach',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-001',
#    'lat': 41.722579,
#    'lng': -71.3087797,
#    'latestObsDt': '2025-12-29 10:58',
#    'numSpeciesAllTime': 84},
#   {'locId': 'L1670551',
#    'locName': 'Behind Home Depot in Seekonk',
#    'countryCode': 'US',
#    'subnational1Code': 'US-MA',
#    'subnational2Code': 'US-MA-005',
#    'lat': 41.7996862,
#    'lng': -71.3404841,
#    'latestObsDt': '2025-10-31 14:41',
#    'numSpeciesAllTime': 54},
#   {'locId': 'L12721457',
#    'locName': 'Belmont Park, Warwick',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-003',
#    'lat': 41.7620466,
#    'lng': -71.4219022,
#    'latestObsDt': '2024-12-15 10:25',
#    'numSpeciesAllTime': 67},
#   {'locId': 'L38649323',
#    'locName': 'Bethany Cemetery, Cranston',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.7612448,
#    'lng': -71.439414,
#    'latestObsDt': '2025-12-18 09:20',
#    'numSpeciesAllTime': 28},
#   {'locId': 'L2214089',
#    'locName': 'Big River Management Area--Carr Pond',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-003',
#    'lat': 41.6354153,
#    'lng': -71.5560842,
#    'latestObsDt': '2025-11-25 10:35',
#    'numSpeciesAllTime': 89},
#   {'locId': 'L5071219',
#    'locName': 'Big River Management Area--Model Airplane Field',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-003',
#    'lat': 41.654994,
#    'lng': -71.56379,
#    'latestObsDt': '2025-10-15 16:02',
#    'numSpeciesAllTime': 50},
#   {'locId': 'L6073694',
#    'locName': 'Big River Management Area--Sand Pit',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-003',
#    'lat': 41.6464519,
#    'lng': -71.5779448,
#    'latestObsDt': '2025-12-30 13:23',
#    'numSpeciesAllTime': 135},
#   {'locId': 'L5099232',
#    'locName': 'Big River Management Area--Tarbox Pond',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-003',
#    'lat': 41.6365854,
#    'lng': -71.5734869,
#    'latestObsDt': '2025-11-19 08:35',
#    'numSpeciesAllTime': 105},
#   {'locId': 'L2071074',
#    'locName': 'Birchwold Farm',
#    'countryCode': 'US',
#    'subnational1Code': 'US-MA',
#    'subnational2Code': 'US-MA-021',
#    'lat': 42.0231797,
#    'lng': -71.4054143,
#    'latestObsDt': '2025-11-22 14:53',
#    'numSpeciesAllTime': 118},
#   {'locId': 'L10658440',
#    'locName': 'Blackamore Pond, Cranston',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.7738778,
#    'lng': -71.4468487,
#    'latestObsDt': '2025-12-25 12:11',
#    'numSpeciesAllTime': 54},
#   {'locId': 'L6077334',
#    'locName': 'Blackstone Boulevard, Providence',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.8434142,
#    'lng': -71.386435,
#    'latestObsDt': '2025-12-25 15:45',
#    'numSpeciesAllTime': 51},
#   {'locId': 'L4423843',
#    'locName': 'Blackstone Gorge',
#    'countryCode': 'US',
#    'subnational1Code': 'US-MA',
#    'subnational2Code': 'US-MA-027',
#    'lat': 42.0151373,
#    'lng': -71.5528822,
#    'latestObsDt': '2025-11-16 15:38',
#    'numSpeciesAllTime': 93},
#   {'locId': 'L11920582',
#    'locName': 'Blackstone Gorge (RI)',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 42.0125889,
#    'lng': -71.5520399,
#    'latestObsDt': '2025-07-10 20:41',
#    'numSpeciesAllTime': 84},
#   {'locId': 'L804728',
#    'locName': 'Blackstone Park',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.833327,
#    'lng': -71.3792148,
#    'latestObsDt': '2025-12-30 14:15',
#    'numSpeciesAllTime': 198},
#   {'locId': 'L41628130',
#    'locName': 'Blackstone River Bikeway--Albion to Manville Parking Area',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.9573319,
#    'lng': -71.4622947,
#    'latestObsDt': '2025-11-28 08:19',
#    'numSpeciesAllTime': 107},
#   {'locId': 'L12894191',
#    'locName': 'Blackstone River Bikeway--Canal St.',
#    'countryCode': 'US',
#    'subnational1Code': 'US-MA',
#    'subnational2Code': 'US-MA-027',
#    'lat': 42.0165,
#    'lng': -71.538194,
#    'latestObsDt': '2025-11-25 11:05',
#    'numSpeciesAllTime': 133},
#   {'locId': 'L41527208',
#    'locName': 'Blackstone River Bikeway--Cold Spring Park to MA Border',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 42.0100697,
#    'lng': -71.528995,
#    'latestObsDt': '2025-11-22 15:55',
#    'numSpeciesAllTime': 30},
#   {'locId': 'L1615937',
#    'locName': 'Blackstone River Bikeway--Kelly House Museum to Albion Access',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.9431583,
#    'lng': -71.4372874,
#    'latestObsDt': '2025-12-15 14:54',
#    'numSpeciesAllTime': 117},
#   {'locId': 'L11516357',
#    'locName': 'Blackstone River Bikeway--Kelly House Museum to Lonsdale Drive-In',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.9247737,
#    'lng': -71.4298601,
#    'latestObsDt': '2025-12-18 09:31',
#    'numSpeciesAllTime': 113},
#   {'locId': 'L41627753',
#    'locName': 'Blackstone River Bikeway--Kelly House Trail to I-295 Visitor Center',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.9404151,
#    'lng': -71.4424413,
#    'latestObsDt': '2025-09-23 17:25',
#    'numSpeciesAllTime': 32},
#   {'locId': 'L4975633',
#    'locName': 'Blackstone River Bikeway--Lonsdale Drive-In',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.9101022,
#    'lng': -71.4004254,
#    'latestObsDt': '2025-12-22 14:00',
#    'numSpeciesAllTime': 145},
#   {'locId': 'L41628165',
#    'locName': 'Blackstone River Bikeway--Manville Access to "River\'s Edge"',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.9776132,
#    'lng': -71.4833743,
#    'latestObsDt': '2025-11-22 11:59',
#    'numSpeciesAllTime': 107},
#   {'locId': 'L8600695',
#    'locName': 'Blackstone River Bikeway--Valley Marsh',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.9027514,
#    'lng': -71.3980847,
#    'latestObsDt': '2025-12-30 15:32',
#    'numSpeciesAllTime': 161},
#   {'locId': 'L34675448',
#    'locName': 'Bleachery Pond, Lincoln',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.894042,
#    'lng': -71.4096775,
#    'latestObsDt': '2025-12-09 12:12',
#    'numSpeciesAllTime': 46},
#   {'locId': 'L2808160',
#    'locName': 'Blithewold (entry fee required)',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-001',
#    'lat': 41.6541463,
#    'lng': -71.2658536,
#    'latestObsDt': '2025-08-21 11:04',
#    'numSpeciesAllTime': 73},
#   {'locId': 'L216062',
#    'locName': 'Bold Point Park, East Providence',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.8144807,
#    'lng': -71.3901623,
#    'latestObsDt': '2025-12-18 09:05',
#    'numSpeciesAllTime': 159},
#   {'locId': 'L22351437',
#    'locName': 'Booth Pond Conservation Area & Trails',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.9803301,
#    'lng': -71.5047389,
#    'latestObsDt': '2025-12-04 09:56',
#    'numSpeciesAllTime': 120},
#   {'locId': 'L875821',
#    'locName': 'Boyden Heights Conservation Area',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.7895369,
#    'lng': -71.370433,
#    'latestObsDt': '2025-11-28 15:47',
#    'numSpeciesAllTime': 97},
#   {'locId': 'L17165257',
#    'locName': 'Boyden Park',
#    'countryCode': 'US',
#    'subnational1Code': 'US-MA',
#    'subnational2Code': 'US-MA-005',
#    'lat': 41.872801,
#    'lng': -71.125909,
#    'latestObsDt': '2025-10-19 10:54',
#    'numSpeciesAllTime': 108},
#   {'locId': 'L2683958',
#    'locName': 'Brickyard Pond & Veterans Memorial Park',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-001',
#    'lat': 41.7352359,
#    'lng': -71.3144231,
#    'latestObsDt': '2025-12-25 13:18',
#    'numSpeciesAllTime': 164},
#   {'locId': 'L44616927',
#    'locName': 'Bridgham Farm, Rumford',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.8361172,
#    'lng': -71.3457559,
#    'latestObsDt': '2025-12-18 11:57',
#    'numSpeciesAllTime': 58},
#   {'locId': 'L5133234',
#    'locName': 'Bristol Narrows',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-001',
#    'lat': 41.6971815,
#    'lng': -71.2464703,
#    'latestObsDt': '2025-12-30 14:40',
#    'numSpeciesAllTime': 79},
#   {'locId': 'L841256',
#    'locName': 'Broad Cove',
#    'countryCode': 'US',
#    'subnational1Code': 'US-MA',
#    'subnational2Code': 'US-MA-005',
#    'lat': 41.7892329,
#    'lng': -71.1252308,
#    'latestObsDt': '2025-12-29 09:51',
#    'numSpeciesAllTime': 222},
#   {'locId': 'L7801999',
#    'locName': 'Brown University Campus',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.8260753,
#    'lng': -71.403429,
#    'latestObsDt': '2025-12-10 16:39',
#    'numSpeciesAllTime': 105},
#   {'locId': 'L11866685',
#    'locName': "Bullock's Cove",
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.7601546,
#    'lng': -71.3538947,
#    'latestObsDt': '2025-12-27 08:30',
#    'numSpeciesAllTime': 112},
#   {'locId': 'L7113200',
#    'locName': "Bullock's Point (limited access)",
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.7449199,
#    'lng': -71.3578749,
#    'latestObsDt': '2025-12-18 07:20',
#    'numSpeciesAllTime': 81},
#   {'locId': 'L17262087',
#    'locName': 'Bullock’s Point Light',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.737771,
#    'lng': -71.364168,
#    'latestObsDt': '2025-04-06 15:17',
#    'numSpeciesAllTime': 6},
#   {'locId': 'L11444077',
#    'locName': 'Butler Campus',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.8443214,
#    'lng': -71.3815825,
#    'latestObsDt': '2025-12-18 11:44',
#    'numSpeciesAllTime': 86},
#   {'locId': 'L21432043',
#    'locName': 'Butterfly Farm & Pond, Lincoln',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.9070195,
#    'lng': -71.4318753,
#    'latestObsDt': '2025-12-18 15:57',
#    'numSpeciesAllTime': 63},
#   {'locId': 'L43513174',
#    'locName': 'Byron Randall Road, Scituate',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.800396,
#    'lng': -71.572942,
#    'latestObsDt': '2025-11-02 20:12',
#    'numSpeciesAllTime': 27},
#   {'locId': 'L20653314',
#    'locName': 'CCRI Lincoln',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.8953643,
#    'lng': -71.456414,
#    'latestObsDt': '2025-05-25 11:09',
#    'numSpeciesAllTime': 46},
#   {'locId': 'L5727176',
#    'locName': 'Calf Pasture Point Recreation Area--Bikepath',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-009',
#    'lat': 41.6268485,
#    'lng': -71.4154875,
#    'latestObsDt': '2025-12-25 11:56',
#    'numSpeciesAllTime': 191},
#   {'locId': 'L41322492',
#    'locName': 'Calf Pasture Point Recreation Area--Shoreline Access',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-009',
#    'lat': 41.6299993,
#    'lng': -71.4057814,
#    'latestObsDt': '2025-11-16 09:11',
#    'numSpeciesAllTime': 26},
#   {'locId': 'L30802876',
#    'locName': 'Captain Stephen Olney Memorial Park',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.855094,
#    'lng': -71.455276,
#    'latestObsDt': '2025-05-20 10:30',
#    'numSpeciesAllTime': 37},
#   {'locId': 'L734825',
#    'locName': 'Caratunk Wildlife Refuge (ASRI)',
#    'countryCode': 'US',
#    'subnational1Code': 'US-MA',
#    'subnational2Code': 'US-MA-005',
#    'lat': 41.8740347,
#    'lng': -71.3212734,
#    'latestObsDt': '2025-12-25 10:35',
#    'numSpeciesAllTime': 171},
#   {'locId': 'L25323688',
#    'locName': 'Catamint Brook Preserve (Cumberland Land Trust)',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.994465,
#    'lng': -71.43924,
#    'latestObsDt': '2025-10-18 14:47',
#    'numSpeciesAllTime': 98},
#   {'locId': 'L4658133',
#    'locName': 'Cedar Swamp Conservation Area',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.9756837,
#    'lng': -71.5357268,
#    'latestObsDt': '2025-06-11 12:25',
#    'numSpeciesAllTime': 96},
#   {'locId': 'L38376933',
#    'locName': 'Central Landfill, Johnston (limited access)',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.8075395,
#    'lng': -71.5324731,
#    'latestObsDt': '2025-12-30 13:00',
#    'numSpeciesAllTime': 84},
#   {'locId': 'L487743',
#    'locName': 'Central Pond Reservoir, East Providence',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.8591418,
#    'lng': -71.3376617,
#    'latestObsDt': '2025-03-26 17:36',
#    'numSpeciesAllTime': 92},
#   {'locId': 'L4333450',
#    'locName': 'Chase Farm, Lincoln',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.9064362,
#    'lng': -71.4288585,
#    'latestObsDt': '2025-12-18 06:26',
#    'numSpeciesAllTime': 154},
#   {'locId': 'L1391725',
#    'locName': 'Chepiwanoxet Point',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-003',
#    'lat': 41.6735417,
#    'lng': -71.4421938,
#    'latestObsDt': '2025-10-05 14:27',
#    'numSpeciesAllTime': 104},
#   {'locId': 'L734909',
#    'locName': 'Claire D. McIntosh Wildlife Refuge (ASRI)',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-001',
#    'lat': 41.7102379,
#    'lng': -71.2827596,
#    'latestObsDt': '2025-12-26 16:18',
#    'numSpeciesAllTime': 172},
#   {'locId': 'L4653581',
#    'locName': 'Coastal Greenway, Portsmouth',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-005',
#    'lat': 41.6281852,
#    'lng': -71.2611687,
#    'latestObsDt': '2025-11-09 13:20',
#    'numSpeciesAllTime': 112},
#   {'locId': 'L1406045',
#    'locName': 'Cold Spring Park, Woonsocket',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 42.0091108,
#    'lng': -71.5252876,
#    'latestObsDt': '2025-01-27 13:16',
#    'numSpeciesAllTime': 62},
#   {'locId': 'L841267',
#    'locName': 'Cole River Boat Ramp, Swansea',
#    'countryCode': 'US',
#    'subnational1Code': 'US-MA',
#    'subnational2Code': 'US-MA-005',
#    'lat': 41.7263586,
#    'lng': -71.2221336,
#    'latestObsDt': '2025-12-27 14:29',
#    'numSpeciesAllTime': 123},
#   {'locId': 'L29143732',
#    'locName': 'Collier Point Park, Providence',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.8120414,
#    'lng': -71.401773,
#    'latestObsDt': '2025-12-24 14:57',
#    'numSpeciesAllTime': 66},
#   {'locId': 'L613147',
#    'locName': 'Colt State Park',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-001',
#    'lat': 41.6806368,
#    'lng': -71.3021922,
#    'latestObsDt': '2025-12-30 12:33',
#    'numSpeciesAllTime': 241},
#   {'locId': 'L687632',
#    'locName': 'Conimicut Point Park, Warwick',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-003',
#    'lat': 41.7167491,
#    'lng': -71.360321,
#    'latestObsDt': '2025-12-28 12:28',
#    'numSpeciesAllTime': 146},
#   {'locId': 'L16672907',
#    'locName': 'Conimicut Saltmarsh, Warwick',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-003',
#    'lat': 41.7136737,
#    'lng': -71.364103,
#    'latestObsDt': '2025-12-29 16:00',
#    'numSpeciesAllTime': 76},
#   {'locId': 'L1786830',
#    'locName': 'Copps Cove',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.7813513,
#    'lng': -71.391461,
#    'latestObsDt': '2025-12-30 13:40',
#    'numSpeciesAllTime': 68},
#   {'locId': 'L9955986',
#    'locName': 'Council Oak Fields',
#    'countryCode': 'US',
#    'subnational1Code': 'US-MA',
#    'subnational2Code': 'US-MA-005',
#    'lat': 41.8190476,
#    'lng': -71.1344576,
#    'latestObsDt': '2025-12-28 14:21',
#    'numSpeciesAllTime': 106},
#   {'locId': 'L12817315',
#    'locName': 'Crescent Park, East Providence',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.7567563,
#    'lng': -71.3611223,
#    'latestObsDt': '2025-11-05 14:47',
#    'numSpeciesAllTime': 108},
#   {'locId': 'L4600100',
#    'locName': 'Crestwood Country Club',
#    'countryCode': 'US',
#    'subnational1Code': 'US-MA',
#    'subnational2Code': 'US-MA-005',
#    'lat': 41.8244527,
#    'lng': -71.277253,
#    'latestObsDt': '2025-06-08 08:00',
#    'numSpeciesAllTime': 34},
#   {'locId': 'L734901',
#    'locName': 'Davis Memorial Wildlife Refuge (ASRI)',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-009',
#    'lat': 41.6236714,
#    'lng': -71.4817259,
#    'latestObsDt': '2025-08-23 15:00',
#    'numSpeciesAllTime': 100},
#   {'locId': 'L38433651',
#    'locName': 'Davis Park, Providence',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.833365,
#    'lng': -71.430524,
#    'latestObsDt': '2025-12-18 12:29',
#    'numSpeciesAllTime': 25},
#   {'locId': 'L31398708',
#    'locName': 'Davisville Middle School Nature Paths',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-009',
#    'lat': 41.6193485,
#    'lng': -71.4648414,
#    'latestObsDt': '2025-06-27 13:55',
#    'numSpeciesAllTime': 35},
#   {'locId': 'L38630506',
#    'locName': 'Dexter Training Ground Park',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.814522,
#    'lng': -71.431343,
#    'latestObsDt': '2025-11-24 15:40',
#    'numSpeciesAllTime': 17},
#   {'locId': 'L11683398',
#    'locName': 'Diamond Hill Management Area',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 42.001108,
#    'lng': -71.431875,
#    'latestObsDt': '2025-05-31 14:20',
#    'numSpeciesAllTime': 69},
#   {'locId': 'L10059274',
#    'locName': 'Diamond Hill Park, Cumberland',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 42.0019027,
#    'lng': -71.4131983,
#    'latestObsDt': '2025-12-22 12:02',
#    'numSpeciesAllTime': 94},
#   {'locId': 'L16494250',
#    'locName': 'Diamond Hill Reservoir, Cumberland',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.997013,
#    'lng': -71.399154,
#    'latestObsDt': '2025-12-27 08:44',
#    'numSpeciesAllTime': 116},
#   {'locId': 'L2283278',
#    'locName': 'Dighton Town Landing',
#    'countryCode': 'US',
#    'subnational1Code': 'US-MA',
#    'subnational2Code': 'US-MA-005',
#    'lat': 41.7968199,
#    'lng': -71.120553,
#    'latestObsDt': '2025-12-29 08:49',
#    'numSpeciesAllTime': 130},
#   {'locId': 'L4578087',
#    'locName': 'Dighton Transfer Station',
#    'countryCode': 'US',
#    'subnational1Code': 'US-MA',
#    'subnational2Code': 'US-MA-005',
#    'lat': 41.8546988,
#    'lng': -71.1388779,
#    'latestObsDt': '2022-08-20 11:14',
#    'numSpeciesAllTime': 82},
#   {'locId': 'L4538187',
#    'locName': 'Dighton Water Pump Station (private)',
#    'countryCode': 'US',
#    'subnational1Code': 'US-MA',
#    'subnational2Code': 'US-MA-005',
#    'lat': 41.8255552,
#    'lng': -71.1267945,
#    'latestObsDt': '2024-12-29 05:23',
#    'numSpeciesAllTime': 79},
#   {'locId': 'L1135167',
#    'locName': 'Dodgeville Pond',
#    'countryCode': 'US',
#    'subnational1Code': 'US-MA',
#    'subnational2Code': 'US-MA-005',
#    'lat': 41.9232654,
#    'lng': -71.2951155,
#    'latestObsDt': '2025-03-14 17:41',
#    'numSpeciesAllTime': 65},
#   {'locId': 'L1463082',
#    'locName': 'Doug Rayner Wildlife Refuge at Nockum Hill',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-001',
#    'lat': 41.7680304,
#    'lng': -71.31198,
#    'latestObsDt': '2025-12-26 13:26',
#    'numSpeciesAllTime': 179},
#   {'locId': 'L54768291',
#    'locName': 'Dunnell Park, Pawtucket',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.864788,
#    'lng': -71.3683087,
#    'latestObsDt': '2025-12-18 16:12',
#    'numSpeciesAllTime': 31},
#   {'locId': 'L5126639',
#    'locName': 'East Bay Bike Path--Barrington River Bridge to Warren Dog Park',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-001',
#    'lat': 41.7369613,
#    'lng': -71.2859139,
#    'latestObsDt': '2025-08-03 17:04',
#    'numSpeciesAllTime': 87},
#   {'locId': 'L5123222',
#    'locName': 'East Bay Bike Path--Bay Spring Ave. to Barrington Shopping Center',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-001',
#    'lat': 41.7389245,
#    'lng': -71.3333058,
#    'latestObsDt': '2025-08-02 10:39',
#    'numSpeciesAllTime': 147},
#   {'locId': 'L730688',
#    'locName': 'East Bay Bike Path--Colt State Park to Independence Park',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-001',
#    'lat': 41.6824731,
#    'lng': -71.2813489,
#    'latestObsDt': '2025-12-28 13:23',
#    'numSpeciesAllTime': 130},
#   {'locId': 'L55322509',
#    'locName': 'East Bay Bike Path--Veterans Memorial Parkway',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.8091301,
#    'lng': -71.3871416,
#    'latestObsDt': '2025-11-21 12:32',
#    'numSpeciesAllTime': 17},
#   {'locId': 'L3567188',
#    'locName': 'East Bay Bike Path--Warren Dog Park to Colt State Park',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-001',
#    'lat': 41.705527,
#    'lng': -71.28859,
#    'latestObsDt': '2025-11-24 15:00',
#    'numSpeciesAllTime': 143},
#   {'locId': 'L1139391',
#    'locName': 'East Bay Bike Path--Watchemoket Cove to Pomham Rocks',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.7959681,
#    'lng': -71.3778949,
#    'latestObsDt': '2025-12-26 15:38',
#    'numSpeciesAllTime': 179},
#   {'locId': 'L5668641',
#    'locName': 'East Greenwich Cemetery',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-003',
#    'lat': 41.6565934,
#    'lng': -71.4570308,
#    'latestObsDt': '2025-03-19 15:03',
#    'numSpeciesAllTime': 14},
#   {'locId': 'L22412271',
#    'locName': 'East Greenwich Cove Overlook',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-003',
#    'lat': 41.656898,
#    'lng': -71.449188,
#    'latestObsDt': '2025-07-27 16:51',
#    'numSpeciesAllTime': 61},
#   {'locId': 'L7358879',
#    'locName': 'East Greenwich Nature and Cross Country Trail',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-003',
#    'lat': 41.6334947,
#    'lng': -71.4834452,
#    'latestObsDt': '2025-06-13 19:08',
#    'numSpeciesAllTime': 98},
#   {'locId': 'L21194566',
#    'locName': 'East Point (formerly Greenwood Point)',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.8412036,
#    'lng': -71.3717906,
#    'latestObsDt': '2025-12-26 16:11',
#    'numSpeciesAllTime': 58},
#   {'locId': 'L1320533',
#    'locName': 'Echo Lake, Barrington',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-001',
#    'lat': 41.7357344,
#    'lng': -71.3339496,
#    'latestObsDt': '2025-12-23 11:50',
#    'numSpeciesAllTime': 137},
#   {'locId': 'L15883704',
#    'locName': 'Fall River Heritage SP',
#    'countryCode': 'US',
#    'subnational1Code': 'US-MA',
#    'subnational2Code': 'US-MA-005',
#    'lat': 41.7048283,
#    'lng': -71.1601388,
#    'latestObsDt': '2025-12-28 12:53',
#    'numSpeciesAllTime': 44},
#   {'locId': 'L487669',
#    'locName': 'Flat River Reservoir, Coventry',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-003',
#    'lat': 41.7074586,
#    'lng': -71.6359663,
#    'latestObsDt': '2025-12-29 14:25',
#    'numSpeciesAllTime': 119},
#   {'locId': 'L357306',
#    'locName': 'Fort Wildlife Refuge (ASRI)',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.9606389,
#    'lng': -71.5533972,
#    'latestObsDt': '2025-12-12 07:37',
#    'numSpeciesAllTime': 117},
#   {'locId': 'L1458015',
#    'locName': 'Franklin Farm, Cumberland',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.9668184,
#    'lng': -71.393796,
#    'latestObsDt': '2025-12-22 13:35',
#    'numSpeciesAllTime': 124},
#   {'locId': 'L6530163',
#    'locName': 'Frenchtown Park, East Greenwich',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-003',
#    'lat': 41.626978,
#    'lng': -71.506429,
#    'latestObsDt': '2025-11-20 06:00',
#    'numSpeciesAllTime': 114},
#   {'locId': 'L1390947',
#    'locName': 'Fuller Pond',
#    'countryCode': 'US',
#    'subnational1Code': 'US-MA',
#    'subnational2Code': 'US-MA-021',
#    'lat': 42.0126642,
#    'lng': -71.3476719,
#    'latestObsDt': '2025-09-18 16:53',
#    'numSpeciesAllTime': 116},
#   {'locId': 'L13048144',
#    'locName': 'Gainsborough Commons (limited access)',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 42.008083,
#    'lng': -71.453635,
#    'latestObsDt': '2023-10-11 15:18',
#    'numSpeciesAllTime': 12},
#   {'locId': 'L1393330',
#    'locName': 'Gano Park, Providence',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.823722,
#    'lng': -71.3885067,
#    'latestObsDt': '2025-12-23 10:51',
#    'numSpeciesAllTime': 81},
#   {'locId': 'L7788167',
#    'locName': 'Gaspee Point',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-003',
#    'lat': 41.743699,
#    'lng': -71.3766397,
#    'latestObsDt': '2025-12-22 13:30',
#    'numSpeciesAllTime': 93},
#   {'locId': 'L38630101',
#    'locName': 'Gate of Heaven Cemetery, East Providence',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.792361,
#    'lng': -71.339235,
#    'latestObsDt': '2025-12-24 06:56',
#    'numSpeciesAllTime': 45},
#   {'locId': 'L15294747',
#    'locName': 'George B. Parker Woodland—Gowdey Memorial Trail (Prov. Co.)',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.729585,
#    'lng': -71.684546,
#    'latestObsDt': '2025-06-08 13:33',
#    'numSpeciesAllTime': 51},
#   {'locId': 'L2776143',
#    'locName': 'Georgiaville Pond',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.8913554,
#    'lng': -71.5088081,
#    'latestObsDt': '2025-01-01 09:45',
#    'numSpeciesAllTime': 66},
#   {'locId': 'L13158219',
#    'locName': 'Glenford Cemetery, Scituate',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.8309334,
#    'lng': -71.5904518,
#    'latestObsDt': '2025-10-11 16:43',
#    'numSpeciesAllTime': 46},
#   {'locId': 'L1007144',
#    'locName': 'Goddard Memorial SP',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-003',
#    'lat': 41.6611783,
#    'lng': -71.4358091,
#    'latestObsDt': '2025-12-21 10:41',
#    'numSpeciesAllTime': 163},
#   {'locId': 'L6182809',
#    'locName': 'Gorton Pond and Little Gorton Pond',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-003',
#    'lat': 41.7023002,
#    'lng': -71.4622879,
#    'latestObsDt': '2025-12-28 13:49',
#    'numSpeciesAllTime': 115},
#   {'locId': 'L40170320',
#    'locName': 'Governor John Notte Memorial Park, North Providence',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.8712226,
#    'lng': -71.4631462,
#    'latestObsDt': '2025-05-24 17:50',
#    'numSpeciesAllTime': 44},
#   {'locId': 'L46689195',
#    'locName': 'Grassy Plains Park, East Providence',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.768335,
#    'lng': -71.332246,
#    'latestObsDt': '2025-08-21 11:19',
#    'numSpeciesAllTime': 21},
#   {'locId': 'L4588597',
#    'locName': 'Great Woods Conservation Area',
#    'countryCode': 'US',
#    'subnational1Code': 'US-MA',
#    'subnational2Code': 'US-MA-005',
#    'lat': 41.9981564,
#    'lng': -71.2298584,
#    'latestObsDt': '2025-12-06 13:35',
#    'numSpeciesAllTime': 94},
#   {'locId': 'L5455344',
#    'locName': 'Haffenreffer Estate',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-001',
#    'lat': 41.679539,
#    'lng': -71.2362903,
#    'latestObsDt': '2024-10-14 09:56',
#    'numSpeciesAllTime': 68},
#   {'locId': 'L11913876',
#    'locName': 'Haile Farm Preserve (WLCT)',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-001',
#    'lat': 41.7514372,
#    'lng': -71.279314,
#    'latestObsDt': '2025-12-21 14:21',
#    'numSpeciesAllTime': 128},
#   {'locId': 'L39583673',
#    'locName': 'Haines Memorial State Park  (Providence County)',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.7540286,
#    'lng': -71.3514138,
#    'latestObsDt': '2025-12-18 14:39',
#    'numSpeciesAllTime': 45},
#   {'locId': 'L286912',
#    'locName': 'Haines Memorial State Park (Bristol County)',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-001',
#    'lat': 41.7531189,
#    'lng': -71.3504298,
#    'latestObsDt': '2025-10-09 13:25',
#    'numSpeciesAllTime': 122},
#   {'locId': 'L4333222',
#    'locName': 'Handy Pond Conservation Area ',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.9560605,
#    'lng': -71.4742713,
#    'latestObsDt': '2025-11-13 09:59',
#    'numSpeciesAllTime': 86},
#   {'locId': 'L13041553',
#    'locName': 'Harold Burns Memorial Wildlife Arboretum',
#    'countryCode': 'US',
#    'subnational1Code': 'US-MA',
#    'subnational2Code': 'US-MA-005',
#    'lat': 41.9958385,
#    'lng': -71.3217259,
#    'latestObsDt': '2025-11-29 09:33',
#    'numSpeciesAllTime': 44},
#   {'locId': 'L15187055',
#    'locName': 'Hemlock Rd., Foster',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.7913147,
#    'lng': -71.6825409,
#    'latestObsDt': '2025-11-25 15:12',
#    'numSpeciesAllTime': 73},
#   {'locId': 'L40521950',
#    'locName': 'Heritage Park, Glocester',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.8920702,
#    'lng': -71.6315403,
#    'latestObsDt': '2025-04-26 15:18',
#    'numSpeciesAllTime': 19},
#   {'locId': 'L14885742',
#    'locName': 'High Rock Farm Preserve',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.9565049,
#    'lng': -71.4304866,
#    'latestObsDt': '2025-12-04 13:52',
#    'numSpeciesAllTime': 94},
#   {'locId': 'L38666615',
#    'locName': 'Highland Memorial Park Cemetery',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.855466,
#    'lng': -71.4950323,
#    'latestObsDt': '2025-10-02 12:00',
#    'numSpeciesAllTime': 18},
#   {'locId': 'L24131893',
#    'locName': 'Highland Park',
#    'countryCode': 'US',
#    'subnational1Code': 'US-MA',
#    'subnational2Code': 'US-MA-005',
#    'lat': 41.9436939,
#    'lng': -71.2958576,
#    'latestObsDt': '2025-12-18 14:13',
#    'numSpeciesAllTime': 103},
#   {'locId': 'L55055686',
#    'locName': 'Hopkins Property, Foster Land Trust',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.818868,
#    'lng': -71.702845,
#    'latestObsDt': '2025-12-03 12:40',
#    'numSpeciesAllTime': 54},
#   {'locId': 'L14264549',
#    'locName': 'Howard Conservation Area (PRAWC)',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.7324417,
#    'lng': -71.4596712,
#    'latestObsDt': '2025-09-23 12:00',
#    'numSpeciesAllTime': 97},
#   {'locId': 'L7401637',
#    'locName': 'Howard Pond, Cumberland',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.9555687,
#    'lng': -71.3875294,
#    'latestObsDt': '2025-12-09 11:24',
#    'numSpeciesAllTime': 30},
#   {'locId': 'L3923511',
#    'locName': 'Hundred Acre Cove',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-001',
#    'lat': 41.7622532,
#    'lng': -71.3131356,
#    'latestObsDt': '2025-07-05 10:01',
#    'numSpeciesAllTime': 102},
#   {'locId': 'L15585790',
#    'locName': 'Hundred Acre Cove (Providence Co.)',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.7744174,
#    'lng': -71.3214949,
#    'latestObsDt': '2025-11-02 13:00',
#    'numSpeciesAllTime': 106},
#   {'locId': 'L13447055',
#    'locName': 'Hundred Acre Cove--North Trail access',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-001',
#    'lat': 41.770138,
#    'lng': -71.323482,
#    'latestObsDt': '2025-12-18 15:10',
#    'numSpeciesAllTime': 79},
#   {'locId': 'L2802133',
#    'locName': 'Hunt’s Mills Museum and Trail',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.8283457,
#    'lng': -71.3469315,
#    'latestObsDt': '2025-12-28 13:15',
#    'numSpeciesAllTime': 128},
#   {'locId': 'L2482586',
#    'locName': 'Independence Park, Bristol',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-001',
#    'lat': 41.674403,
#    'lng': -71.279586,
#    'latestObsDt': '2025-10-19 14:14',
#    'numSpeciesAllTime': 81},
#   {'locId': 'L8596244',
#    'locName': 'India Point Park, Providence',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.8172568,
#    'lng': -71.3903618,
#    'latestObsDt': '2025-12-29 08:34',
#    'numSpeciesAllTime': 92},
#   {'locId': 'L19186567',
#    'locName': 'Isthmus Rd., Foster',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.752805,
#    'lng': -71.686923,
#    'latestObsDt': '2025-06-07 13:30',
#    'numSpeciesAllTime': 72},
#   {'locId': 'L2781443',
#    'locName': "Jacob's Point Saltmarsh",
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-001',
#    'lat': 41.7106636,
#    'lng': -71.2903995,
#    'latestObsDt': '2025-12-27 08:40',
#    'numSpeciesAllTime': 196},
#   {'locId': 'L247829',
#    'locName': 'James Turner Reservoir',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.8358267,
#    'lng': -71.3394269,
#    'latestObsDt': '2025-12-18 11:35',
#    'numSpeciesAllTime': 167},
#   {'locId': 'L7456597',
#    'locName': "Joe's Rock Conservation Area",
#    'countryCode': 'US',
#    'subnational1Code': 'US-MA',
#    'subnational2Code': 'US-MA-021',
#    'lat': 42.0273639,
#    'lng': -71.4056611,
#    'latestObsDt': '2025-07-14 06:57',
#    'numSpeciesAllTime': 106},
#   {'locId': 'L12266919',
#    'locName': 'John L. Curran Management Area',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.7507133,
#    'lng': -71.5477124,
#    'latestObsDt': '2025-10-30 11:16',
#    'numSpeciesAllTime': 90},
#   {'locId': 'L7441559',
#    'locName': 'Juniper Hill Cemetery',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-001',
#    'lat': 41.6811015,
#    'lng': -71.2680531,
#    'latestObsDt': '2024-12-16 10:58',
#    'numSpeciesAllTime': 71},
#   {'locId': 'L19377129',
#    'locName': 'Kate Randall Rd., Foster',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.80447,
#    'lng': -71.697416,
#    'latestObsDt': '2025-08-03 17:01',
#    'numSpeciesAllTime': 54},
#   {'locId': 'L24184797',
#    'locName': 'Kennedy Plaza, Providence',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.825473,
#    'lng': -71.412127,
#    'latestObsDt': '2025-12-18 07:03',
#    'numSpeciesAllTime': 38},
#   {'locId': 'L55029974',
#    'locName': 'Kent Heights Park, East Providence',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.805105,
#    'lng': -71.356364,
#    'latestObsDt': '2025-12-18 16:53',
#    'numSpeciesAllTime': 13},
#   {'locId': 'L55389099',
#    'locName': 'Kickemuit River--Child Street Bridge',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-001',
#    'lat': 41.729527,
#    'lng': -71.2626966,
#    'latestObsDt': '2025-11-20 13:45',
#    'numSpeciesAllTime': 3},
#   {'locId': 'L17120086',
#    'locName': 'Kickemuit River--Schoolhouse & Serpentine Road',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-001',
#    'lat': 41.7397652,
#    'lng': -71.2602269,
#    'latestObsDt': '2025-12-04 10:31',
#    'numSpeciesAllTime': 156},
#   {'locId': 'L11806624',
#    'locName': 'Knight Farm Trail (West Bay Land Trust)',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.7529773,
#    'lng': -71.5292781,
#    'latestObsDt': '2025-11-28 07:20',
#    'numSpeciesAllTime': 47},
#   {'locId': 'L12052632',
#    'locName': 'L.A. Foster Wildlife Refuge',
#    'countryCode': 'US',
#    'subnational1Code': 'US-MA',
#    'subnational2Code': 'US-MA-005',
#    'lat': 41.9474619,
#    'lng': -71.1761466,
#    'latestObsDt': '2025-04-17 15:11',
#    'numSpeciesAllTime': 57},
#   {'locId': 'L866565',
#    'locName': 'Lake Como, Attleboro',
#    'countryCode': 'US',
#    'subnational1Code': 'US-MA',
#    'subnational2Code': 'US-MA-005',
#    'lat': 41.9262365,
#    'lng': -71.3583362,
#    'latestObsDt': '2025-10-16 08:48',
#    'numSpeciesAllTime': 55},
#   {'locId': 'L1393144',
#    'locName': 'Lake Hiawatha',
#    'countryCode': 'US',
#    'subnational1Code': 'US-MA',
#    'subnational2Code': 'US-MA-005',
#    'lat': 41.9665834,
#    'lng': -71.3233878,
#    'latestObsDt': '2025-02-01 11:11',
#    'numSpeciesAllTime': 98},
#   {'locId': 'L1393150',
#    'locName': 'Lake Mirimichi',
#    'countryCode': 'US',
#    'subnational1Code': 'US-MA',
#    'subnational2Code': 'US-MA-021',
#    'lat': 42.0279285,
#    'lng': -71.2963494,
#    'latestObsDt': '2025-08-09 17:29',
#    'numSpeciesAllTime': 82},
#   {'locId': 'L1365565',
#    'locName': 'Latham Park, Barrington',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-001',
#    'lat': 41.7457879,
#    'lng': -71.3520883,
#    'latestObsDt': '2025-09-07 15:03',
#    'numSpeciesAllTime': 79},
#   {'locId': 'L4525701',
#    'locName': 'Lawton Farm (Scituate Land Trust)',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.7574513,
#    'lng': -71.5561652,
#    'latestObsDt': '2025-11-28 10:23',
#    'numSpeciesAllTime': 130},
#   {'locId': 'L4053762',
#    'locName': 'Lewin Brook Pond',
#    'countryCode': 'US',
#    'subnational1Code': 'US-MA',
#    'subnational2Code': 'US-MA-005',
#    'lat': 41.7462816,
#    'lng': -71.1926079,
#    'latestObsDt': '2023-01-20 11:00',
#    'numSpeciesAllTime': 51},
#   {'locId': 'L393285',
#    'locName': 'Lincoln Woods State Park',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.8962718,
#    'lng': -71.4355516,
#    'latestObsDt': '2025-12-24 14:17',
#    'numSpeciesAllTime': 152},
#   {'locId': 'L14185394',
#    'locName': 'Lippitt Memorial Park',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.8546509,
#    'lng': -71.3915205,
#    'latestObsDt': '2025-12-26 08:28',
#    'numSpeciesAllTime': 48},
#   {'locId': 'L12824129',
#    'locName': 'Little Neck Cemetery',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.7667433,
#    'lng': -71.3542489,
#    'latestObsDt': '2025-12-18 14:18',
#    'numSpeciesAllTime': 84},
#   {'locId': 'L13992195',
#    'locName': 'Little Pond, Cumberland',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.9624751,
#    'lng': -71.4213747,
#    'latestObsDt': '2025-11-01 12:18',
#    'numSpeciesAllTime': 54},
#   {'locId': 'L549748',
#    'locName': 'Lonsdale General Area (please use more refined hotspot)',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.9064273,
#    'lng': -71.3999829,
#    'latestObsDt': '2024-11-12 06:20',
#    'numSpeciesAllTime': 150},
#   {'locId': 'L12295388',
#    'locName': 'Lonsdale Marsh--Lonsdale Ave. access',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.9020296,
#    'lng': -71.404301,
#    'latestObsDt': '2025-12-18 14:38',
#    'numSpeciesAllTime': 154},
#   {'locId': 'L17150946',
#    'locName': 'Mallard Point',
#    'countryCode': 'US',
#    'subnational1Code': 'US-MA',
#    'subnational2Code': 'US-MA-005',
#    'lat': 41.7726055,
#    'lng': -71.1205563,
#    'latestObsDt': '2024-05-25 08:30',
#    'numSpeciesAllTime': 63},
#   {'locId': 'L1297392',
#    'locName': 'Manchester Pond Reservoir',
#    'countryCode': 'US',
#    'subnational1Code': 'US-MA',
#    'subnational2Code': 'US-MA-005',
#    'lat': 41.9461929,
#    'lng': -71.3158393,
#    'latestObsDt': '2025-12-18 14:42',
#    'numSpeciesAllTime': 136},
#   {'locId': 'L3157427',
#    'locName': 'Maple Street Powerline Cut',
#    'countryCode': 'US',
#    'subnational1Code': 'US-MA',
#    'subnational2Code': 'US-MA-005',
#    'lat': 41.8651505,
#    'lng': -71.1994743,
#    'latestObsDt': '2025-11-09 08:29',
#    'numSpeciesAllTime': 126},
#   {'locId': 'L15210138',
#    'locName': 'Marsh Point, Warwick',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-003',
#    'lat': 41.65971,
#    'lng': -71.41081,
#    'latestObsDt': '2025-12-12 13:18',
#    'numSpeciesAllTime': 159},
#   {'locId': 'L1391689',
#    'locName': "Mary's Creek, Warwick",
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-003',
#    'lat': 41.6891348,
#    'lng': -71.4513884,
#    'latestObsDt': '2025-12-24 09:49',
#    'numSpeciesAllTime': 128},
#   {'locId': 'L9545732',
#    'locName': 'Mashapaug Park, Providence',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.7960733,
#    'lng': -71.4301347,
#    'latestObsDt': '2025-12-24 11:55',
#    'numSpeciesAllTime': 140},
#   {'locId': 'L30901951',
#    'locName': 'Mason Field',
#    'countryCode': 'US',
#    'subnational1Code': 'US-MA',
#    'subnational2Code': 'US-MA-005',
#    'lat': 41.973644,
#    'lng': -71.315139,
#    'latestObsDt': '2025-11-23 12:49',
#    'numSpeciesAllTime': 42},
#   {'locId': 'L10975778',
#    'locName': 'Massasoit Street Park',
#    'countryCode': 'US',
#    'subnational1Code': 'US-MA',
#    'subnational2Code': 'US-MA-005',
#    'lat': 41.7099274,
#    'lng': -71.1795339,
#    'latestObsDt': '2025-11-30 08:23',
#    'numSpeciesAllTime': 93},
#   {'locId': 'L15139458',
#    'locName': 'Mercy Woods Preserve, Cumberland',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 42.0149,
#    'lng': -71.408989,
#    'latestObsDt': '2025-11-30 06:32',
#    'numSpeciesAllTime': 89},
#   {'locId': 'L14975740',
#    'locName': 'Merrill S. Whipple Conservation Park',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-003',
#    'lat': 41.6885734,
#    'lng': -71.5566654,
#    'latestObsDt': '2025-12-27 10:07',
#    'numSpeciesAllTime': 89},
#   {'locId': 'L7425313',
#    'locName': 'Meshanticut State Park',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.7682996,
#    'lng': -71.4752215,
#    'latestObsDt': '2025-12-26 16:23',
#    'numSpeciesAllTime': 86},
#   {'locId': 'L3970468',
#    'locName': 'Miller St. Pond',
#    'countryCode': 'US',
# ...
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-003',
#    'lat': 41.7235369,
#    'lng': -71.4269578,
#    'latestObsDt': '2025-11-02 12:52',
#    'numSpeciesAllTime': 140},
#   {'locId': 'L49057407',
#    'locName': 'Tarkiln Road, Smithfield',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.9142369,
#    'lng': -71.5790024,
#    'latestObsDt': '2025-07-04 08:22',
#    'numSpeciesAllTime': 30},
#   {'locId': 'L40384308',
#    'locName': 'Ten Mile River Greenway--Dagget Ave. Trailhead to Armistice Blvd',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.8824328,
#    'lng': -71.3426111,
#    'latestObsDt': '2025-12-18 08:58',
#    'numSpeciesAllTime': 27},
#   {'locId': 'L2599631',
#    'locName': 'Ten Mile River Greenway--Ferris Ave. Trailhead to Slater Park',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.8496377,
#    'lng': -71.3443893,
#    'latestObsDt': '2025-12-18 10:18',
#    'numSpeciesAllTime': 116},
#   {'locId': 'L5426087',
#    'locName': 'Ten Mile River Reservation (Armistice Blvd. viewpoint)',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.875147,
#    'lng': -71.340459,
#    'latestObsDt': '2025-12-18 09:25',
#    'numSpeciesAllTime': 112},
#   {'locId': 'L1458029',
#    'locName': 'The Monastery, Cumberland',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.9350531,
#    'lng': -71.4075396,
#    'latestObsDt': '2025-12-28 12:32',
#    'numSpeciesAllTime': 181},
#   {'locId': 'L8920590',
#    'locName': 'Tillinghast Place / RISD Beach',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-001',
#    'lat': 41.725982,
#    'lng': -71.321841,
#    'latestObsDt': '2025-10-24 15:58',
#    'numSpeciesAllTime': 142},
#   {'locId': 'L815443',
#    'locName': 'Tiogue Lake',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-003',
#    'lat': 41.6790406,
#    'lng': -71.5503244,
#    'latestObsDt': '2025-12-29 14:50',
#    'numSpeciesAllTime': 120},
#   {'locId': 'L4207196',
#    'locName': 'Tiogue Lake--Outflow',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-003',
#    'lat': 41.685423,
#    'lng': -71.553619,
#    'latestObsDt': '2025-10-23 10:40',
#    'numSpeciesAllTime': 106},
#   {'locId': 'L213318',
#    'locName': 'Touisset Marsh Wildlife Refuge (ASRI)',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-001',
#    'lat': 41.7059838,
#    'lng': -71.2374794,
#    'latestObsDt': '2025-12-20 09:12',
#    'numSpeciesAllTime': 160},
#   {'locId': 'L15208246',
#    'locName': 'Tower Hill Rd., Cumberland',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.994098,
#    'lng': -71.444035,
#    'latestObsDt': '2025-05-31 13:35',
#    'numSpeciesAllTime': 60},
#   {'locId': 'L42665518',
#    'locName': 'Town Line Swamp',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.933718,
#    'lng': -71.486849,
#    'latestObsDt': '2025-05-11 09:23',
#    'numSpeciesAllTime': 25},
#   {'locId': 'L900794',
#    'locName': 'Town Pond (ALT)',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-005',
#    'lat': 41.6323646,
#    'lng': -71.245544,
#    'latestObsDt': '2025-12-20 07:53',
#    'numSpeciesAllTime': 152},
#   {'locId': 'L16657907',
#    'locName': 'Townie Pride Memorial Park, East Providence',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.808964,
#    'lng': -71.385004,
#    'latestObsDt': '2025-10-05 09:12',
#    'numSpeciesAllTime': 53},
#   {'locId': 'L3260829',
#    'locName': 'Tricentennial Park',
#    'countryCode': 'US',
#    'subnational1Code': 'US-MA',
#    'subnational2Code': 'US-MA-005',
#    'lat': 41.8103868,
#    'lng': -71.1191475,
#    'latestObsDt': '2025-02-20 11:35',
#    'numSpeciesAllTime': 112},
#   {'locId': 'L12450396',
#    'locName': 'Tucker Field, Cumberland',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.9644865,
#    'lng': -71.4426209,
#    'latestObsDt': '2025-04-21 18:56',
#    'numSpeciesAllTime': 27},
#   {'locId': 'L2718493',
#    'locName': 'Turnpike Lake',
#    'countryCode': 'US',
#    'subnational1Code': 'US-MA',
#    'subnational2Code': 'US-MA-021',
#    'lat': 42.0158388,
#    'lng': -71.3119447,
#    'latestObsDt': '2025-11-22 11:29',
#    'numSpeciesAllTime': 93},
#   {'locId': 'L41541061',
#    'locName': 'Twin River Casino Retention Ponds, Lincoln',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.88732,
#    'lng': -71.444158,
#    'latestObsDt': '2025-11-30 11:33',
#    'numSpeciesAllTime': 36},
#   {'locId': 'L10189488',
#    'locName': 'Venus De Milo Pond',
#    'countryCode': 'US',
#    'subnational1Code': 'US-MA',
#    'subnational2Code': 'US-MA-005',
#    'lat': 41.7429672,
#    'lng': -71.1885811,
#    'latestObsDt': '2025-12-28 12:22',
#    'numSpeciesAllTime': 54},
#   {'locId': 'L8678323',
#    'locName': 'Veterans Memorial Park, Pawtucket',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.8794371,
#    'lng': -71.3818826,
#    'latestObsDt': '2025-12-30 14:57',
#    'numSpeciesAllTime': 47},
#   {'locId': 'L29863733',
#    'locName': 'Village Park, Swansea',
#    'countryCode': 'US',
#    'subnational1Code': 'US-MA',
#    'subnational2Code': 'US-MA-005',
#    'lat': 41.7510963,
#    'lng': -71.1898653,
#    'latestObsDt': '2025-06-15 07:43',
#    'numSpeciesAllTime': 54},
#   {'locId': 'L5495329',
#    'locName': 'Village Waterfront Park, Somerset',
#    'countryCode': 'US',
#    'subnational1Code': 'US-MA',
#    'subnational2Code': 'US-MA-005',
#    'lat': 41.7696541,
#    'lng': -71.1251423,
#    'latestObsDt': '2025-10-10 11:59',
#    'numSpeciesAllTime': 70},
#   {'locId': 'L12545551',
#    'locName': 'WWII Memorial State Park',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 42.0096446,
#    'lng': -71.5093249,
#    'latestObsDt': '2023-06-30 16:59',
#    'numSpeciesAllTime': 22},
#   {'locId': 'L29020679',
#    'locName': 'Wading River Reservoir',
#    'countryCode': 'US',
#    'subnational1Code': 'US-MA',
#    'subnational2Code': 'US-MA-005',
#    'lat': 41.989602,
#    'lng': -71.254242,
#    'latestObsDt': '2025-11-02 06:52',
#    'numSpeciesAllTime': 63},
#   {'locId': 'L1888546',
#    'locName': 'Walker Cove',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-001',
#    'lat': 41.6604123,
#    'lng': -71.2706554,
#    'latestObsDt': '2025-12-17 08:52',
#    'numSpeciesAllTime': 79},
#   {'locId': 'L453500',
#    'locName': 'Walker Farm',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-001',
#    'lat': 41.7555945,
#    'lng': -71.3227701,
#    'latestObsDt': '2025-12-18 10:08',
#    'numSpeciesAllTime': 167},
#   {'locId': 'L4095950',
#    'locName': 'Walker Street Reserve, Westville Conservation Area',
#    'countryCode': 'US',
#    'subnational1Code': 'US-MA',
#    'subnational2Code': 'US-MA-005',
#    'lat': 41.8899385,
#    'lng': -71.1320382,
#    'latestObsDt': '2025-12-28 09:16',
#    'numSpeciesAllTime': 99},
#   {'locId': 'L31745262',
#    'locName': 'Walnut Hill Cemetery',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.8811125,
#    'lng': -71.3687754,
#    'latestObsDt': '2025-04-22 08:08',
#    'numSpeciesAllTime': 44},
#   {'locId': 'L6370013',
#    'locName': 'Warren Bike Path',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-001',
#    'lat': 41.7260657,
#    'lng': -71.2597087,
#    'latestObsDt': '2025-11-30 11:55',
#    'numSpeciesAllTime': 97},
#   {'locId': 'L1306965',
#    'locName': 'Warren Upper Reservoir ',
#    'countryCode': 'US',
#    'subnational1Code': 'US-MA',
#    'subnational2Code': 'US-MA-005',
#    'lat': 41.8251622,
#    'lng': -71.2174559,
#    'latestObsDt': '2025-08-31 17:19',
#    'numSpeciesAllTime': 117},
#   {'locId': 'L1325528',
#    'locName': 'Warwick City Park',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-003',
#    'lat': 41.6885579,
#    'lng': -71.4063702,
#    'latestObsDt': '2025-12-21 12:03',
#    'numSpeciesAllTime': 115},
#   {'locId': 'L22140967',
#    'locName': 'Warwick Pond',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-003',
#    'lat': 41.7238791,
#    'lng': -71.4123253,
#    'latestObsDt': '2025-04-25 12:50',
#    'numSpeciesAllTime': 46},
#   {'locId': 'L43850174',
#    'locName': 'Washington Secondary Trail--Father Tirocchi Field Area',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-003',
#    'lat': 41.7249223,
#    'lng': -71.48592,
#    'latestObsDt': '2025-07-07 12:30',
#    'numSpeciesAllTime': 37},
#   {'locId': 'L29523147',
#    'locName': 'Washington Secondary Trail--Pawtuxet River Wetland Overlook',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-003',
#    'lat': 41.696943,
#    'lng': -71.580597,
#    'latestObsDt': '2024-02-26 09:30',
#    'numSpeciesAllTime': 13},
#   {'locId': 'L187164',
#    'locName': 'Watchemoket Cove',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.800495,
#    'lng': -71.376686,
#    'latestObsDt': '2025-12-28 12:35',
#    'numSpeciesAllTime': 137},
#   {'locId': 'L12799134',
#    'locName': 'Waterman Reservoir',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.8799557,
#    'lng': -71.5805218,
#    'latestObsDt': '2025-08-22 13:41',
#    'numSpeciesAllTime': 62},
#   {'locId': 'L13430824',
#    'locName': 'Waterman St. Dog Park',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.8277178,
#    'lng': -71.3835141,
#    'latestObsDt': '2024-12-24 08:43',
#    'numSpeciesAllTime': 73},
#   {'locId': 'L12606996',
#    'locName': 'Waypoyset Preserve (Land Trust)',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-001',
#    'lat': 41.697007,
#    'lng': -71.2498423,
#    'latestObsDt': '2022-03-20 12:15',
#    'numSpeciesAllTime': 38},
#   {'locId': 'L1390952',
#    'locName': 'Wetherells Pond',
#    'countryCode': 'US',
#    'subnational1Code': 'US-MA',
#    'subnational2Code': 'US-MA-021',
#    'lat': 42.0003917,
#    'lng': -71.3375304,
#    'latestObsDt': '2025-05-02 17:44',
#    'numSpeciesAllTime': 115},
#   {'locId': 'L13121233',
#    'locName': 'Wetlands Robinson Ave. Dam',
#    'countryCode': 'US',
#    'subnational1Code': 'US-MA',
#    'subnational2Code': 'US-MA-005',
#    'lat': 41.9680397,
#    'lng': -71.3120677,
#    'latestObsDt': '2025-02-17 06:45',
#    'numSpeciesAllTime': 31},
#   {'locId': 'L2390045',
#    'locName': 'Wheaton College',
#    'countryCode': 'US',
#    'subnational1Code': 'US-MA',
#    'subnational2Code': 'US-MA-005',
#    'lat': 41.9673242,
#    'lng': -71.1837137,
#    'latestObsDt': '2025-11-21 21:15',
#    'numSpeciesAllTime': 141},
#   {'locId': 'L3300181',
#    'locName': 'Whiting Pond, North Attleborough',
#    'countryCode': 'US',
#    'subnational1Code': 'US-MA',
#    'subnational2Code': 'US-MA-005',
#    'lat': 41.9941027,
#    'lng': -71.3352263,
#    'latestObsDt': '2025-10-06 06:46',
#    'numSpeciesAllTime': 40},
#   {'locId': 'L12073266',
#    'locName': 'Willett Pond, East Providence',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.775647,
#    'lng': -71.356669,
#    'latestObsDt': '2025-11-12 10:55',
#    'numSpeciesAllTime': 76},
#   {'locId': 'L12639998',
#    'locName': 'Winslow Park',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-003',
#    'lat': 41.7252496,
#    'lng': -71.4198935,
#    'latestObsDt': '2025-12-29 11:25',
#    'numSpeciesAllTime': 79},
#   {'locId': 'L1618211',
#    'locName': 'Witch Pond, Foxboro',
#    'countryCode': 'US',
#    'subnational1Code': 'US-MA',
#    'subnational2Code': 'US-MA-021',
#    'lat': 42.0177869,
#    'lng': -71.2867241,
#    'latestObsDt': '2025-07-13 10:38',
#    'numSpeciesAllTime': 75},
#   {'locId': 'L47132166',
#    'locName': 'Wolf Hill Preserve--Old Quarry Trails',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.887409,
#    'lng': -71.534424,
#    'latestObsDt': '2025-11-09 09:35',
#    'numSpeciesAllTime': 22},
#   {'locId': 'L13057430',
#    'locName': 'Wood Lake Park and Almy Reservoir',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.8159533,
#    'lng': -71.5271886,
#    'latestObsDt': '2025-12-30 12:10',
#    'numSpeciesAllTime': 110},
#   {'locId': 'L31392271',
#    'locName': 'Woonasquatucket River Greenway--Manton Pond Area to Merino Park',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.8339789,
#    'lng': -71.4724742,
#    'latestObsDt': '2025-12-18 14:23',
#    'numSpeciesAllTime': 105},
#   {'locId': 'L28111910',
#    'locName': 'Woonasquatucket River Greenway--Riverside Park to Merino Park',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.8207141,
#    'lng': -71.450412,
#    'latestObsDt': '2025-09-17 10:08',
#    'numSpeciesAllTime': 55},
#   {'locId': 'L12545495',
#    'locName': 'Woonsocket Public Library',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 42.0051404,
#    'lng': -71.5082279,
#    'latestObsDt': '2025-05-06 15:30',
#    'numSpeciesAllTime': 20},
#   {'locId': 'L12136837',
#    'locName': 'Woonsocket Reservoir #3',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.9430759,
#    'lng': -71.4980264,
#    'latestObsDt': '2025-09-16 12:40',
#    'numSpeciesAllTime': 57},
#   {'locId': 'L40170227',
#    'locName': 'World War I Memorial Park and Zoo',
#    'countryCode': 'US',
#    'subnational1Code': 'US-MA',
#    'subnational2Code': 'US-MA-005',
#    'lat': 41.9989253,
#    'lng': -71.3135779,
#    'latestObsDt': '2025-09-20 16:20',
#    'numSpeciesAllTime': 11},
#   {'locId': 'L11430695',
#    'locName': "Zeke's Bridge Fishing Access and Trails",
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-003',
#    'lat': 41.6650256,
#    'lng': -71.618607,
#    'latestObsDt': '2025-12-06 09:58',
#    'numSpeciesAllTime': 85},
#   {'locId': 'L1878310',
#    'locName': 'stakeout Black-throated Gray Warbler, 103 James H. Luther Dr., Taunton (Jan 2013)',
#    'countryCode': 'US',
#    'subnational1Code': 'US-MA',
#    'subnational2Code': 'US-MA-005',
#    'lat': 41.8984761,
#    'lng': -71.1748638,
#    'latestObsDt': '2013-01-23 09:30',
#    'numSpeciesAllTime': 34},
#   {'locId': 'L35960144',
#    'locName': 'stakeout Lark Bunting--Norton (2024)',
#    'countryCode': 'US',
#    'subnational1Code': 'US-MA',
#    'subnational2Code': 'US-MA-005',
#    'lat': 41.9697876,
#    'lng': -71.1947624,
#    'latestObsDt': '2024-08-22 09:35',
#    'numSpeciesAllTime': 43},
#   {'locId': 'L5128475',
#    'locName': 'stakeout Sandhill Crane--Swansea (2016)',
#    'countryCode': 'US',
#    'subnational1Code': 'US-MA',
#    'subnational2Code': 'US-MA-005',
#    'lat': 41.740978,
#    'lng': -71.193583,
#    'latestObsDt': '2025-05-28 14:31',
#    'numSpeciesAllTime': 26},
#   {'locId': 'L31274340',
#    'locName': 'stakeout Swallow-Tailed Kite--Attleboro (2024)',
#    'countryCode': 'US',
#    'subnational1Code': 'US-MA',
#    'subnational2Code': 'US-MA-005',
#    'lat': 41.9131963,
#    'lng': -71.2290574,
#    'latestObsDt': '2024-05-04 12:42',
#    'numSpeciesAllTime': 10},
#   {'locId': 'L12966956',
#    'locName': 'stakeout Varied Thrush--Chepachet (2020-2021)',
#    'countryCode': 'US',
#    'subnational1Code': 'US-RI',
#    'subnational2Code': 'US-RI-007',
#    'lat': 41.9154969,
#    'lng': -71.6022595,
#    'latestObsDt': '2023-05-19 16:23',
#    'numSpeciesAllTime': 59}]}

# %%
all_hotspot_keys = set()
for hotspots in spots_per_loc.values():
    for spot_data in hotspots:
        all_hotspot_keys.update(spot_data.keys())

all_hotspot_keys
# Out:
# {'countryCode',
#  'lat',
#  'latestObsDt',
#  'lng',
#  'locId',
#  'locName',
#  'numSpeciesAllTime',
#  'subnational1Code',
#  'subnational2Code'}

# %%
from birding.primitives import EBirdHotspot

hotspots_per_location = {
    loc: {EBirdHotspot.from_json(hotspot_data) for hotspot_data in hotspots}
    for loc, hotspots in spots_per_loc.items()
}

# %%
hotspots_per_location
# Out:
# {'Providence, Rhode Island, United States': {EBirdHotspot(location=EBirdLocation(id='L10059274', name='Diamond Hill Park, Cumberland', coord=Coordinate(latitude=42.0019027, longitude=-71.4131983), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=94),
#   EBirdHotspot(location=EBirdLocation(id='L1007144', name='Goddard Memorial SP', coord=Coordinate(latitude=41.6611783, longitude=-71.4358091), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-003', subnat2_name=None), all_time_species=163),
#   EBirdHotspot(location=EBirdLocation(id='L10078182', name='North Attleboro National Fish Hatchery', coord=Coordinate(latitude=41.9927973, longitude=-71.2838421), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=157),
#   EBirdHotspot(location=EBirdLocation(id='L10135757', name='Ripley St Marsh', coord=Coordinate(latitude=41.7122204, longitude=-71.1844573), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=82),
#   EBirdHotspot(location=EBirdLocation(id='L10170471', name='St. Andrews Farm, Barrington', coord=Coordinate(latitude=41.7494135, longitude=-71.3328399), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-001', subnat2_name=None), all_time_species=69),
#   EBirdHotspot(location=EBirdLocation(id='L10189488', name='Venus De Milo Pond', coord=Coordinate(latitude=41.7429672, longitude=-71.1885811), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=54),
#   EBirdHotspot(location=EBirdLocation(id='L10470601', name='Moshassuck Pond', coord=Coordinate(latitude=41.8817272, longitude=-71.4033755), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=79),
#   EBirdHotspot(location=EBirdLocation(id='L10482078', name="Ralph's Pond, Cranston", coord=Coordinate(latitude=41.7744246, longitude=-71.4741292), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=96),
#   EBirdHotspot(location=EBirdLocation(id='L10487395', name='Passeonkquis Cove Fishing Access, Warwick', coord=Coordinate(latitude=41.747803, longitude=-71.38402), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-003', subnat2_name=None), all_time_species=128),
#   EBirdHotspot(location=EBirdLocation(id='L10658440', name='Blackamore Pond, Cranston', coord=Coordinate(latitude=41.7738778, longitude=-71.4468487), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=54),
#   EBirdHotspot(location=EBirdLocation(id='L10825088', name='Quonset Bike Path--Quonset Gateway', coord=Coordinate(latitude=41.6070005, longitude=-71.4544986), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-009', subnat2_name=None), all_time_species=77),
#   EBirdHotspot(location=EBirdLocation(id='L10975778', name='Massasoit Street Park', coord=Coordinate(latitude=41.7099274, longitude=-71.1795339), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=93),
#   EBirdHotspot(location=EBirdLocation(id='L11222818', name='Quidnessett Cemetery, North Kingstown', coord=Coordinate(latitude=41.6247735, longitude=-71.4614067), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-009', subnat2_name=None), all_time_species=120),
#   EBirdHotspot(location=EBirdLocation(id='L1135167', name='Dodgeville Pond', coord=Coordinate(latitude=41.9232654, longitude=-71.2951155), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=65),
#   EBirdHotspot(location=EBirdLocation(id='L11366118', name='Riverside Cemetery', coord=Coordinate(latitude=41.8601221, longitude=-71.3824707), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=112),
#   EBirdHotspot(location=EBirdLocation(id='L1139391', name='East Bay Bike Path--Watchemoket Cove to Pomham Rocks', coord=Coordinate(latitude=41.7959681, longitude=-71.3778949), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=179),
#   EBirdHotspot(location=EBirdLocation(id='L11430695', name="Zeke's Bridge Fishing Access and Trails", coord=Coordinate(latitude=41.6650256, longitude=-71.618607), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-003', subnat2_name=None), all_time_species=85),
#   EBirdHotspot(location=EBirdLocation(id='L11444077', name='Butler Campus', coord=Coordinate(latitude=41.8443214, longitude=-71.3815825), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=86),
#   EBirdHotspot(location=EBirdLocation(id='L11516357', name='Blackstone River Bikeway--Kelly House Museum to Lonsdale Drive-In', coord=Coordinate(latitude=41.9247737, longitude=-71.4298601), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=113),
#   EBirdHotspot(location=EBirdLocation(id='L11635308', name='Runnins River Trail', coord=Coordinate(latitude=41.83233, longitude=-71.3265787), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=59),
#   EBirdHotspot(location=EBirdLocation(id='L11683398', name='Diamond Hill Management Area', coord=Coordinate(latitude=42.001108, longitude=-71.431875), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=69),
#   EBirdHotspot(location=EBirdLocation(id='L11806624', name='Knight Farm Trail (West Bay Land Trust)', coord=Coordinate(latitude=41.7529773, longitude=-71.5292781), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=47),
#   EBirdHotspot(location=EBirdLocation(id='L11815850', name='Rumstick Point, Barrington', coord=Coordinate(latitude=41.707233, longitude=-71.303475), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-001', subnat2_name=None), all_time_species=77),
#   EBirdHotspot(location=EBirdLocation(id='L11866685', name="Bullock's Cove", coord=Coordinate(latitude=41.7601546, longitude=-71.3538947), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=112),
#   EBirdHotspot(location=EBirdLocation(id='L11913876', name='Haile Farm Preserve (WLCT)', coord=Coordinate(latitude=41.7514372, longitude=-71.279314), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-001', subnat2_name=None), all_time_species=128),
#   EBirdHotspot(location=EBirdLocation(id='L11920582', name='Blackstone Gorge (RI)', coord=Coordinate(latitude=42.0125889, longitude=-71.5520399), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=84),
#   EBirdHotspot(location=EBirdLocation(id='L12052632', name='L.A. Foster Wildlife Refuge', coord=Coordinate(latitude=41.9474619, longitude=-71.1761466), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=57),
#   EBirdHotspot(location=EBirdLocation(id='L12073266', name='Willett Pond, East Providence', coord=Coordinate(latitude=41.775647, longitude=-71.356669), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=76),
#   EBirdHotspot(location=EBirdLocation(id='L12136837', name='Woonsocket Reservoir #3', coord=Coordinate(latitude=41.9430759, longitude=-71.4980264), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=57),
#   EBirdHotspot(location=EBirdLocation(id='L12266919', name='John L. Curran Management Area', coord=Coordinate(latitude=41.7507133, longitude=-71.5477124), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=90),
#   EBirdHotspot(location=EBirdLocation(id='L12289642', name='Snake Den Farm', coord=Coordinate(latitude=41.8444131, longitude=-71.5421457), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=180),
#   EBirdHotspot(location=EBirdLocation(id='L12295388', name='Lonsdale Marsh--Lonsdale Ave. access', coord=Coordinate(latitude=41.9020296, longitude=-71.404301), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=154),
#   EBirdHotspot(location=EBirdLocation(id='L12385319', name='River Park, North Smithfield', coord=Coordinate(latitude=42.0103262, longitude=-71.5497869), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=142),
#   EBirdHotspot(location=EBirdLocation(id='L124352', name='Swan Point Cemetery', coord=Coordinate(latitude=41.8557485, longitude=-71.3812176), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=222),
#   EBirdHotspot(location=EBirdLocation(id='L12450396', name='Tucker Field, Cumberland', coord=Coordinate(latitude=41.9644865, longitude=-71.4426209), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=27),
#   EBirdHotspot(location=EBirdLocation(id='L12545495', name='Woonsocket Public Library', coord=Coordinate(latitude=42.0051404, longitude=-71.5082279), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=20),
#   EBirdHotspot(location=EBirdLocation(id='L12545551', name='WWII Memorial State Park', coord=Coordinate(latitude=42.0096446, longitude=-71.5093249), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=22),
#   EBirdHotspot(location=EBirdLocation(id='L12606996', name='Waypoyset Preserve (Land Trust)', coord=Coordinate(latitude=41.697007, longitude=-71.2498423), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-001', subnat2_name=None), all_time_species=38),
#   EBirdHotspot(location=EBirdLocation(id='L12639998', name='Winslow Park', coord=Coordinate(latitude=41.7252496, longitude=-71.4198935), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-003', subnat2_name=None), all_time_species=79),
#   EBirdHotspot(location=EBirdLocation(id='L12696120', name='Suckatunkanuc Hill', coord=Coordinate(latitude=41.815945, longitude=-71.504841), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=49),
#   EBirdHotspot(location=EBirdLocation(id='L12721457', name='Belmont Park, Warwick', coord=Coordinate(latitude=41.7620466, longitude=-71.4219022), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-003', subnat2_name=None), all_time_species=67),
#   EBirdHotspot(location=EBirdLocation(id='L12799134', name='Waterman Reservoir', coord=Coordinate(latitude=41.8799557, longitude=-71.5805218), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=62),
#   EBirdHotspot(location=EBirdLocation(id='L12817315', name='Crescent Park, East Providence', coord=Coordinate(latitude=41.7567563, longitude=-71.3611223), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=108),
#   EBirdHotspot(location=EBirdLocation(id='L1282270', name='Attleboro Springs Wildlife Sanctuary (Mass Audubon)', coord=Coordinate(latitude=41.9286191, longitude=-71.2647432), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=102),
#   EBirdHotspot(location=EBirdLocation(id='L12824129', name='Little Neck Cemetery', coord=Coordinate(latitude=41.7667433, longitude=-71.3542489), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=84),
#   EBirdHotspot(location=EBirdLocation(id='L1283703', name='Nyatt Road Access', coord=Coordinate(latitude=41.7303621, longitude=-71.3408375), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-001', subnat2_name=None), all_time_species=112),
#   EBirdHotspot(location=EBirdLocation(id='L12894191', name='Blackstone River Bikeway--Canal St.', coord=Coordinate(latitude=42.0165, longitude=-71.538194), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-027', subnat2_name=None), all_time_species=133),
#   EBirdHotspot(location=EBirdLocation(id='L12966956', name='stakeout Varied Thrush--Chepachet (2020-2021)', coord=Coordinate(latitude=41.9154969, longitude=-71.6022595), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=59),
#   EBirdHotspot(location=EBirdLocation(id='L1297392', name='Manchester Pond Reservoir', coord=Coordinate(latitude=41.9461929, longitude=-71.3158393), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=136),
#   EBirdHotspot(location=EBirdLocation(id='L13041553', name='Harold Burns Memorial Wildlife Arboretum', coord=Coordinate(latitude=41.9958385, longitude=-71.3217259), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=44),
#   EBirdHotspot(location=EBirdLocation(id='L13048089', name='Resurrection Cemetery, Cumberland', coord=Coordinate(latitude=42.006054, longitude=-71.447179), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=51),
#   EBirdHotspot(location=EBirdLocation(id='L13048144', name='Gainsborough Commons (limited access)', coord=Coordinate(latitude=42.008083, longitude=-71.453635), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=12),
#   EBirdHotspot(location=EBirdLocation(id='L13049070', name='Omega Pond, East Providence', coord=Coordinate(latitude=41.8381258, longitude=-71.3646489), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=62),
#   EBirdHotspot(location=EBirdLocation(id='L13057430', name='Wood Lake Park and Almy Reservoir', coord=Coordinate(latitude=41.8159533, longitude=-71.5271886), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=110),
#   EBirdHotspot(location=EBirdLocation(id='L1306965', name='Warren Upper Reservoir ', coord=Coordinate(latitude=41.8251622, longitude=-71.2174559), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=117),
#   EBirdHotspot(location=EBirdLocation(id='L13121233', name='Wetlands Robinson Ave. Dam', coord=Coordinate(latitude=41.9680397, longitude=-71.3120677), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=31),
#   EBirdHotspot(location=EBirdLocation(id='L13158219', name='Glenford Cemetery, Scituate', coord=Coordinate(latitude=41.8309334, longitude=-71.5904518), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=46),
#   EBirdHotspot(location=EBirdLocation(id='L1320533', name='Echo Lake, Barrington', coord=Coordinate(latitude=41.7357344, longitude=-71.3339496), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-001', subnat2_name=None), all_time_species=137),
#   EBirdHotspot(location=EBirdLocation(id='L1325526', name='Sabin Point Park, East Providence', coord=Coordinate(latitude=41.7650588, longitude=-71.3690966), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=108),
#   EBirdHotspot(location=EBirdLocation(id='L1325528', name='Warwick City Park', coord=Coordinate(latitude=41.6885579, longitude=-71.4063702), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-003', subnat2_name=None), all_time_species=115),
#   EBirdHotspot(location=EBirdLocation(id='L13429477', name='Pleasant Valley Parkway, Providence', coord=Coordinate(latitude=41.8348354, longitude=-71.4422477), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=44),
#   EBirdHotspot(location=EBirdLocation(id='L13430824', name='Waterman St. Dog Park', coord=Coordinate(latitude=41.8277178, longitude=-71.3835141), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=73),
#   EBirdHotspot(location=EBirdLocation(id='L13447055', name='Hundred Acre Cove--North Trail access', coord=Coordinate(latitude=41.770138, longitude=-71.323482), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-001', subnat2_name=None), all_time_species=79),
#   EBirdHotspot(location=EBirdLocation(id='L1365565', name='Latham Park, Barrington', coord=Coordinate(latitude=41.7457879, longitude=-71.3520883), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-001', subnat2_name=None), all_time_species=79),
#   EBirdHotspot(location=EBirdLocation(id='L13813738', name='Mountaindale Road Marsh & Reservoir, Smithfield', coord=Coordinate(latitude=41.8862882, longitude=-71.5367615), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=77),
#   EBirdHotspot(location=EBirdLocation(id='L1390947', name='Fuller Pond', coord=Coordinate(latitude=42.0126642, longitude=-71.3476719), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-021', subnat2_name=None), all_time_species=116),
#   EBirdHotspot(location=EBirdLocation(id='L1390952', name='Wetherells Pond', coord=Coordinate(latitude=42.0003917, longitude=-71.3375304), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-021', subnat2_name=None), all_time_species=115),
#   EBirdHotspot(location=EBirdLocation(id='L1391689', name="Mary's Creek, Warwick", coord=Coordinate(latitude=41.6891348, longitude=-71.4513884), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-003', subnat2_name=None), all_time_species=128),
#   EBirdHotspot(location=EBirdLocation(id='L1391725', name='Chepiwanoxet Point', coord=Coordinate(latitude=41.6735417, longitude=-71.4421938), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-003', subnat2_name=None), all_time_species=104),
#   EBirdHotspot(location=EBirdLocation(id='L1393144', name='Lake Hiawatha', coord=Coordinate(latitude=41.9665834, longitude=-71.3233878), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=98),
#   EBirdHotspot(location=EBirdLocation(id='L1393150', name='Lake Mirimichi', coord=Coordinate(latitude=42.0279285, longitude=-71.2963494), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-021', subnat2_name=None), all_time_species=82),
#   EBirdHotspot(location=EBirdLocation(id='L1393330', name='Gano Park, Providence', coord=Coordinate(latitude=41.823722, longitude=-71.3885067), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=81),
#   EBirdHotspot(location=EBirdLocation(id='L13935214', name='St. Francis Cemetery', coord=Coordinate(latitude=41.8638984, longitude=-71.4086965), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=36),
#   EBirdHotspot(location=EBirdLocation(id='L13992195', name='Little Pond, Cumberland', coord=Coordinate(latitude=41.9624751, longitude=-71.4213747), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=54),
#   EBirdHotspot(location=EBirdLocation(id='L14031193', name='Oak Swamp Reservoir (limited access)', coord=Coordinate(latitude=41.826814, longitude=-71.54223), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=39),
#   EBirdHotspot(location=EBirdLocation(id='L14031201', name='Peeptoad Brook', coord=Coordinate(latitude=41.840378, longitude=-71.602796), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=40),
#   EBirdHotspot(location=EBirdLocation(id='L1406045', name='Cold Spring Park, Woonsocket', coord=Coordinate(latitude=42.0091108, longitude=-71.5252876), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=62),
#   EBirdHotspot(location=EBirdLocation(id='L14173384', name='Snake Den State Park--Belfield Drive', coord=Coordinate(latitude=41.8362062, longitude=-71.5268898), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=82),
#   EBirdHotspot(location=EBirdLocation(id='L14185394', name='Lippitt Memorial Park', coord=Coordinate(latitude=41.8546509, longitude=-71.3915205), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=48),
#   EBirdHotspot(location=EBirdLocation(id='L14264549', name='Howard Conservation Area (PRAWC)', coord=Coordinate(latitude=41.7324417, longitude=-71.4596712), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=97),
#   EBirdHotspot(location=EBirdLocation(id='L1458015', name='Franklin Farm, Cumberland', coord=Coordinate(latitude=41.9668184, longitude=-71.393796), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=124),
#   EBirdHotspot(location=EBirdLocation(id='L1458029', name='The Monastery, Cumberland', coord=Coordinate(latitude=41.9350531, longitude=-71.4075396), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=181),
#   EBirdHotspot(location=EBirdLocation(id='L1463082', name='Doug Rayner Wildlife Refuge at Nockum Hill', coord=Coordinate(latitude=41.7680304, longitude=-71.31198), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-001', subnat2_name=None), all_time_species=179),
#   EBirdHotspot(location=EBirdLocation(id='L14885742', name='High Rock Farm Preserve', coord=Coordinate(latitude=41.9565049, longitude=-71.4304866), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=94),
#   EBirdHotspot(location=EBirdLocation(id='L14975740', name='Merrill S. Whipple Conservation Park', coord=Coordinate(latitude=41.6885734, longitude=-71.5566654), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-003', subnat2_name=None), all_time_species=89),
#   EBirdHotspot(location=EBirdLocation(id='L1499732', name='Oak Top (private)', coord=Coordinate(latitude=41.8547833, longitude=-71.1776575), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=224),
#   EBirdHotspot(location=EBirdLocation(id='L15139458', name='Mercy Woods Preserve, Cumberland', coord=Coordinate(latitude=42.0149, longitude=-71.408989), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=89),
#   EBirdHotspot(location=EBirdLocation(id='L15187055', name='Hemlock Rd., Foster', coord=Coordinate(latitude=41.7913147, longitude=-71.6825409), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=73),
#   EBirdHotspot(location=EBirdLocation(id='L15208246', name='Tower Hill Rd., Cumberland', coord=Coordinate(latitude=41.994098, longitude=-71.444035), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=60),
#   EBirdHotspot(location=EBirdLocation(id='L15210138', name='Marsh Point, Warwick', coord=Coordinate(latitude=41.65971, longitude=-71.41081), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-003', subnat2_name=None), all_time_species=159),
#   EBirdHotspot(location=EBirdLocation(id='L15294747', name='George B. Parker Woodland—Gowdey Memorial Trail (Prov. Co.)', coord=Coordinate(latitude=41.729585, longitude=-71.684546), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=51),
#   EBirdHotspot(location=EBirdLocation(id='L15585790', name='Hundred Acre Cove (Providence Co.)', coord=Coordinate(latitude=41.7744174, longitude=-71.3214949), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=106),
#   EBirdHotspot(location=EBirdLocation(id='L1571704', name='Prince Pond, Barrington', coord=Coordinate(latitude=41.743555, longitude=-71.319945), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-001', subnat2_name=None), all_time_species=62),
#   EBirdHotspot(location=EBirdLocation(id='L15883704', name='Fall River Heritage SP', coord=Coordinate(latitude=41.7048283, longitude=-71.1601388), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=44),
#   EBirdHotspot(location=EBirdLocation(id='L1615937', name='Blackstone River Bikeway--Kelly House Museum to Albion Access', coord=Coordinate(latitude=41.9431583, longitude=-71.4372874), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=117),
#   EBirdHotspot(location=EBirdLocation(id='L1618211', name='Witch Pond, Foxboro', coord=Coordinate(latitude=42.0177869, longitude=-71.2867241), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-021', subnat2_name=None), all_time_species=75),
#   EBirdHotspot(location=EBirdLocation(id='L16329835', name='Stump Pond (Coventry Land Trust)', coord=Coordinate(latitude=41.6879961, longitude=-71.6379086), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-003', subnat2_name=None), all_time_species=106),
#   EBirdHotspot(location=EBirdLocation(id='L16494250', name='Diamond Hill Reservoir, Cumberland', coord=Coordinate(latitude=41.997013, longitude=-71.399154), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=116),
#   EBirdHotspot(location=EBirdLocation(id='L16544941', name='Prospect Terrace, Providence', coord=Coordinate(latitude=41.8298931, longitude=-71.4072865), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=49),
#   EBirdHotspot(location=EBirdLocation(id='L16657907', name='Townie Pride Memorial Park, East Providence', coord=Coordinate(latitude=41.808964, longitude=-71.385004), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=53),
#   EBirdHotspot(location=EBirdLocation(id='L16672907', name='Conimicut Saltmarsh, Warwick', coord=Coordinate(latitude=41.7136737, longitude=-71.364103), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-003', subnat2_name=None), all_time_species=76),
#   EBirdHotspot(location=EBirdLocation(id='L1670551', name='Behind Home Depot in Seekonk', coord=Coordinate(latitude=41.7996862, longitude=-71.3404841), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=54),
#   EBirdHotspot(location=EBirdLocation(id='L16976973', name='Saw Mill Pond, North Kingstown', coord=Coordinate(latitude=41.6140294, longitude=-71.4653584), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-009', subnat2_name=None), all_time_species=44),
#   EBirdHotspot(location=EBirdLocation(id='L17120086', name='Kickemuit River--Schoolhouse & Serpentine Road', coord=Coordinate(latitude=41.7397652, longitude=-71.2602269), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-001', subnat2_name=None), all_time_species=156),
#   EBirdHotspot(location=EBirdLocation(id='L17150946', name='Mallard Point', coord=Coordinate(latitude=41.7726055, longitude=-71.1205563), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=63),
#   EBirdHotspot(location=EBirdLocation(id='L17165257', name='Boyden Park', coord=Coordinate(latitude=41.872801, longitude=-71.125909), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=108),
#   EBirdHotspot(location=EBirdLocation(id='L17197972', name='Public Street--Coastal Access Right of Way', coord=Coordinate(latitude=41.80863, longitude=-71.4019811), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=40),
#   EBirdHotspot(location=EBirdLocation(id='L17262087', name='Bullock’s Point Light', coord=Coordinate(latitude=41.737771, longitude=-71.364168), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=6),
#   EBirdHotspot(location=EBirdLocation(id='L17425289', name='Salter Grove North Jetty (Providence Co.)', coord=Coordinate(latitude=41.7586838, longitude=-71.3844226), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=42),
#   EBirdHotspot(location=EBirdLocation(id='L17492948', name='Barney Ave./Almeida Rd. Fields, Rehoboth', coord=Coordinate(latitude=41.786875, longitude=-71.286641), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=43),
#   EBirdHotspot(location=EBirdLocation(id='L1786830', name='Copps Cove', coord=Coordinate(latitude=41.7813513, longitude=-71.391461), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=68),
#   EBirdHotspot(location=EBirdLocation(id='L17970931', name='T.F. Green International Airport', coord=Coordinate(latitude=41.7235369, longitude=-71.4269578), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-003', subnat2_name=None), all_time_species=140),
#   EBirdHotspot(location=EBirdLocation(id='L17976310', name='North Central State Airport', coord=Coordinate(latitude=41.9201774, longitude=-71.4892662), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=110),
#   EBirdHotspot(location=EBirdLocation(id='L18152326', name='Providence River Greenway', coord=Coordinate(latitude=41.8221469, longitude=-71.4065884), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=89),
#   EBirdHotspot(location=EBirdLocation(id='L18266371', name='Pocasset River Wetland, Cranston', coord=Coordinate(latitude=41.7681453, longitude=-71.4457326), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=65),
#   EBirdHotspot(location=EBirdLocation(id='L187164', name='Watchemoket Cove', coord=Coordinate(latitude=41.800495, longitude=-71.376686), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=137),
#   EBirdHotspot(location=EBirdLocation(id='L1878310', name='stakeout Black-throated Gray Warbler, 103 James H. Luther Dr., Taunton (Jan 2013)', coord=Coordinate(latitude=41.8984761, longitude=-71.1748638), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=34),
#   EBirdHotspot(location=EBirdLocation(id='L1888546', name='Walker Cove', coord=Coordinate(latitude=41.6604123, longitude=-71.2706554), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-001', subnat2_name=None), all_time_species=79),
#   EBirdHotspot(location=EBirdLocation(id='L190070', name='Osamequin Bird Sanctuary', coord=Coordinate(latitude=41.760147, longitude=-71.32268), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-001', subnat2_name=None), all_time_species=143),
#   EBirdHotspot(location=EBirdLocation(id='L19186567', name='Isthmus Rd., Foster', coord=Coordinate(latitude=41.752805, longitude=-71.686923), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=72),
#   EBirdHotspot(location=EBirdLocation(id='L19377129', name='Kate Randall Rd., Foster', coord=Coordinate(latitude=41.80447, longitude=-71.697416), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=54),
#   EBirdHotspot(location=EBirdLocation(id='L20653314', name='CCRI Lincoln', coord=Coordinate(latitude=41.8953643, longitude=-71.456414), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=46),
#   EBirdHotspot(location=EBirdLocation(id='L2071074', name='Birchwold Farm', coord=Coordinate(latitude=42.0231797, longitude=-71.4054143), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-021', subnat2_name=None), all_time_species=118),
#   EBirdHotspot(location=EBirdLocation(id='L207451', name='Oak Knoll Wildlife Sanctuary (Mass Audubon)', coord=Coordinate(latitude=41.91704, longitude=-71.26122), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=109),
#   EBirdHotspot(location=EBirdLocation(id='L21194566', name='East Point (formerly Greenwood Point)', coord=Coordinate(latitude=41.8412036, longitude=-71.3717906), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=58),
#   EBirdHotspot(location=EBirdLocation(id='L213318', name='Touisset Marsh Wildlife Refuge (ASRI)', coord=Coordinate(latitude=41.7059838, longitude=-71.2374794), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-001', subnat2_name=None), all_time_species=160),
#   EBirdHotspot(location=EBirdLocation(id='L21432043', name='Butterfly Farm & Pond, Lincoln', coord=Coordinate(latitude=41.9070195, longitude=-71.4318753), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=63),
#   EBirdHotspot(location=EBirdLocation(id='L216062', name='Bold Point Park, East Providence', coord=Coordinate(latitude=41.8144807, longitude=-71.3901623), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=159),
#   EBirdHotspot(location=EBirdLocation(id='L2214089', name='Big River Management Area--Carr Pond', coord=Coordinate(latitude=41.6354153, longitude=-71.5560842), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-003', subnat2_name=None), all_time_species=89),
#   EBirdHotspot(location=EBirdLocation(id='L22140967', name='Warwick Pond', coord=Coordinate(latitude=41.7238791, longitude=-71.4123253), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-003', subnat2_name=None), all_time_species=46),
#   EBirdHotspot(location=EBirdLocation(id='L22213549', name='Rocky Hill Conservation Area', coord=Coordinate(latitude=41.9465071, longitude=-71.527459), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=59),
#   EBirdHotspot(location=EBirdLocation(id='L22351437', name='Booth Pond Conservation Area & Trails', coord=Coordinate(latitude=41.9803301, longitude=-71.5047389), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=120),
#   EBirdHotspot(location=EBirdLocation(id='L22412271', name='East Greenwich Cove Overlook', coord=Coordinate(latitude=41.656898, longitude=-71.449188), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-003', subnat2_name=None), all_time_species=61),
#   EBirdHotspot(location=EBirdLocation(id='L2283278', name='Dighton Town Landing', coord=Coordinate(latitude=41.7968199, longitude=-71.120553), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=130),
#   EBirdHotspot(location=EBirdLocation(id='L23449783', name='Rockland Cemetery', coord=Coordinate(latitude=41.7839211, longitude=-71.6751051), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=92),
#   EBirdHotspot(location=EBirdLocation(id='L23688813', name='Mussachuck Beach', coord=Coordinate(latitude=41.7364935, longitude=-71.3435401), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-001', subnat2_name=None), all_time_species=98),
#   EBirdHotspot(location=EBirdLocation(id='L23891210', name='Attleboro Community Garden', coord=Coordinate(latitude=41.9443897, longitude=-71.2897038), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=29),
#   EBirdHotspot(location=EBirdLocation(id='L2390045', name='Wheaton College', coord=Coordinate(latitude=41.9673242, longitude=-71.1837137), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=141),
#   EBirdHotspot(location=EBirdLocation(id='L24060186', name='Old Grist Mill Pond', coord=Coordinate(latitude=41.8174334, longitude=-71.33548), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=31),
#   EBirdHotspot(location=EBirdLocation(id='L24131893', name='Highland Park', coord=Coordinate(latitude=41.9436939, longitude=-71.2958576), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=103),
#   EBirdHotspot(location=EBirdLocation(id='L24184797', name='Kennedy Plaza, Providence', coord=Coordinate(latitude=41.825473, longitude=-71.412127), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=38),
#   EBirdHotspot(location=EBirdLocation(id='L2430264', name='Mount Hope Farm', coord=Coordinate(latitude=41.6681638, longitude=-71.2549775), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-001', subnat2_name=None), all_time_species=182),
#   EBirdHotspot(location=EBirdLocation(id='L2465689', name='Soucy Falls, Woonsocket', coord=Coordinate(latitude=42.0164127, longitude=-71.5067482), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=16),
#   EBirdHotspot(location=EBirdLocation(id='L247829', name='James Turner Reservoir', coord=Coordinate(latitude=41.8358267, longitude=-71.3394269), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=167),
#   EBirdHotspot(location=EBirdLocation(id='L2482586', name='Independence Park, Bristol', coord=Coordinate(latitude=41.674403, longitude=-71.279586), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-001', subnat2_name=None), all_time_species=81),
#   EBirdHotspot(location=EBirdLocation(id='L2526644', name='Save The Bay Center & Coastal Greenway', coord=Coordinate(latitude=41.7857568, longitude=-71.3817573), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=152),
#   EBirdHotspot(location=EBirdLocation(id='L25323688', name='Catamint Brook Preserve (Cumberland Land Trust)', coord=Coordinate(latitude=41.994465, longitude=-71.43924), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=98),
#   EBirdHotspot(location=EBirdLocation(id='L25335615', name='Old Slater Mill National Historic Landmark', coord=Coordinate(latitude=41.8775897, longitude=-71.3824332), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=38),
#   EBirdHotspot(location=EBirdLocation(id='L2597004', name='Pawtucket Boat Launch', coord=Coordinate(latitude=41.8683704, longitude=-71.379472), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=81),
#   EBirdHotspot(location=EBirdLocation(id='L2599631', name='Ten Mile River Greenway--Ferris Ave. Trailhead to Slater Park', coord=Coordinate(latitude=41.8496377, longitude=-71.3443893), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=116),
#   EBirdHotspot(location=EBirdLocation(id='L26226874', name='Prudence Island--Nag Pond', coord=Coordinate(latitude=41.6281113, longitude=-71.3198418), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-005', subnat2_name=None), all_time_species=105),
#   EBirdHotspot(location=EBirdLocation(id='L2683958', name='Brickyard Pond & Veterans Memorial Park', coord=Coordinate(latitude=41.7352359, longitude=-71.3144231), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-001', subnat2_name=None), all_time_species=164),
#   EBirdHotspot(location=EBirdLocation(id='L2718493', name='Turnpike Lake', coord=Coordinate(latitude=42.0158388, longitude=-71.3119447), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-021', subnat2_name=None), all_time_species=93),
#   EBirdHotspot(location=EBirdLocation(id='L2776143', name='Georgiaville Pond', coord=Coordinate(latitude=41.8913554, longitude=-71.5088081), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=66),
#   EBirdHotspot(location=EBirdLocation(id='L27806934', name='North Central Pond, Smithfield', coord=Coordinate(latitude=41.9138215, longitude=-71.4864678), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=34),
#   EBirdHotspot(location=EBirdLocation(id='L2781443', name="Jacob's Point Saltmarsh", coord=Coordinate(latitude=41.7106636, longitude=-71.2903995), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-001', subnat2_name=None), all_time_species=196),
#   EBirdHotspot(location=EBirdLocation(id='L2792209', name='Sweets Knoll SP', coord=Coordinate(latitude=41.8302771, longitude=-71.114858), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=147),
#   EBirdHotspot(location=EBirdLocation(id='L2802133', name='Hunt’s Mills Museum and Trail', coord=Coordinate(latitude=41.8283457, longitude=-71.3469315), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=128),
#   EBirdHotspot(location=EBirdLocation(id='L2808160', name='Blithewold (entry fee required)', coord=Coordinate(latitude=41.6541463, longitude=-71.2658536), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-001', subnat2_name=None), all_time_species=73),
#   EBirdHotspot(location=EBirdLocation(id='L28111910', name='Woonasquatucket River Greenway--Riverside Park to Merino Park', coord=Coordinate(latitude=41.8207141, longitude=-71.450412), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=55),
#   EBirdHotspot(location=EBirdLocation(id='L286912', name='Haines Memorial State Park (Bristol County)', coord=Coordinate(latitude=41.7531189, longitude=-71.3504298), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-001', subnat2_name=None), all_time_species=122),
#   EBirdHotspot(location=EBirdLocation(id='L2875659', name='Aust Family Preserve at Lime Rock (TNC)', coord=Coordinate(latitude=41.924037, longitude=-71.4682531), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=99),
#   EBirdHotspot(location=EBirdLocation(id='L29020679', name='Wading River Reservoir', coord=Coordinate(latitude=41.989602, longitude=-71.254242), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=63),
#   EBirdHotspot(location=EBirdLocation(id='L2913295', name='Steere Hill Conservation Area (Glocester Land Trust)', coord=Coordinate(latitude=41.8917675, longitude=-71.6142941), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=136),
#   EBirdHotspot(location=EBirdLocation(id='L29143732', name='Collier Point Park, Providence', coord=Coordinate(latitude=41.8120414, longitude=-71.401773), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=66),
#   EBirdHotspot(location=EBirdLocation(id='L29523147', name='Washington Secondary Trail--Pawtuxet River Wetland Overlook', coord=Coordinate(latitude=41.696943, longitude=-71.580597), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-003', subnat2_name=None), all_time_species=13),
#   EBirdHotspot(location=EBirdLocation(id='L29863733', name='Village Park, Swansea', coord=Coordinate(latitude=41.7510963, longitude=-71.1898653), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=54),
#   EBirdHotspot(location=EBirdLocation(id='L30802876', name='Captain Stephen Olney Memorial Park', coord=Coordinate(latitude=41.855094, longitude=-71.455276), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=37),
#   EBirdHotspot(location=EBirdLocation(id='L30901951', name='Mason Field', coord=Coordinate(latitude=41.973644, longitude=-71.315139), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=42),
#   EBirdHotspot(location=EBirdLocation(id='L31274340', name='stakeout Swallow-Tailed Kite--Attleboro (2024)', coord=Coordinate(latitude=41.9131963, longitude=-71.2290574), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=10),
# ...
#   EBirdHotspot(location=EBirdLocation(id='L55389099', name='Kickemuit River--Child Street Bridge', coord=Coordinate(latitude=41.729527, longitude=-71.2626966), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-001', subnat2_name=None), all_time_species=3),
#   EBirdHotspot(location=EBirdLocation(id='L55405746', name='Overlook Rock', coord=Coordinate(latitude=41.6683281, longitude=-71.2371538), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-001', subnat2_name=None), all_time_species=None),
#   EBirdHotspot(location=EBirdLocation(id='L5668641', name='East Greenwich Cemetery', coord=Coordinate(latitude=41.6565934, longitude=-71.4570308), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-003', subnat2_name=None), all_time_species=14),
#   EBirdHotspot(location=EBirdLocation(id='L5727176', name='Calf Pasture Point Recreation Area--Bikepath', coord=Coordinate(latitude=41.6268485, longitude=-71.4154875), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-009', subnat2_name=None), all_time_species=191),
#   EBirdHotspot(location=EBirdLocation(id='L5844667', name='Silver Creek', coord=Coordinate(latitude=41.6784219, longitude=-71.2765503), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-001', subnat2_name=None), all_time_species=104),
#   EBirdHotspot(location=EBirdLocation(id='L6073694', name='Big River Management Area--Sand Pit', coord=Coordinate(latitude=41.6464519, longitude=-71.5779448), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-003', subnat2_name=None), all_time_species=135),
#   EBirdHotspot(location=EBirdLocation(id='L6077334', name='Blackstone Boulevard, Providence', coord=Coordinate(latitude=41.8434142, longitude=-71.386435), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=51),
#   EBirdHotspot(location=EBirdLocation(id='L613147', name='Colt State Park', coord=Coordinate(latitude=41.6806368, longitude=-71.3021922), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-001', subnat2_name=None), all_time_species=241),
#   EBirdHotspot(location=EBirdLocation(id='L6178635', name='Mount Hope Bay', coord=Coordinate(latitude=41.651619, longitude=-71.236764), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-005', subnat2_name=None), all_time_species=18),
#   EBirdHotspot(location=EBirdLocation(id='L6182809', name='Gorton Pond and Little Gorton Pond', coord=Coordinate(latitude=41.7023002, longitude=-71.4622879), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-003', subnat2_name=None), all_time_species=115),
#   EBirdHotspot(location=EBirdLocation(id='L6271814', name="Rockwell Park & Firemen's Memorial Park", coord=Coordinate(latitude=41.6685089, longitude=-71.2780926), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-001', subnat2_name=None), all_time_species=56),
#   EBirdHotspot(location=EBirdLocation(id='L634993', name='Apponaug Cove', coord=Coordinate(latitude=41.6953469, longitude=-71.4527607), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-003', subnat2_name=None), all_time_species=145),
#   EBirdHotspot(location=EBirdLocation(id='L6370013', name='Warren Bike Path', coord=Coordinate(latitude=41.7260657, longitude=-71.2597087), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-001', subnat2_name=None), all_time_species=97),
#   EBirdHotspot(location=EBirdLocation(id='L6530163', name='Frenchtown Park, East Greenwich', coord=Coordinate(latitude=41.626978, longitude=-71.506429), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-003', subnat2_name=None), all_time_species=114),
#   EBirdHotspot(location=EBirdLocation(id='L687632', name='Conimicut Point Park, Warwick', coord=Coordinate(latitude=41.7167491, longitude=-71.360321), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-003', subnat2_name=None), all_time_species=146),
#   EBirdHotspot(location=EBirdLocation(id='L7113200', name="Bullock's Point (limited access)", coord=Coordinate(latitude=41.7449199, longitude=-71.3578749), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=81),
#   EBirdHotspot(location=EBirdLocation(id='L730688', name='East Bay Bike Path--Colt State Park to Independence Park', coord=Coordinate(latitude=41.6824731, longitude=-71.2813489), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-001', subnat2_name=None), all_time_species=130),
#   EBirdHotspot(location=EBirdLocation(id='L731326', name='Ponaganset Rd., Foster', coord=Coordinate(latitude=41.7957044, longitude=-71.6809557), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=138),
#   EBirdHotspot(location=EBirdLocation(id='L734825', name='Caratunk Wildlife Refuge (ASRI)', coord=Coordinate(latitude=41.8740347, longitude=-71.3212734), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=171),
#   EBirdHotspot(location=EBirdLocation(id='L734901', name='Davis Memorial Wildlife Refuge (ASRI)', coord=Coordinate(latitude=41.6236714, longitude=-71.4817259), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-009', subnat2_name=None), all_time_species=100),
#   EBirdHotspot(location=EBirdLocation(id='L734909', name='Claire D. McIntosh Wildlife Refuge (ASRI)', coord=Coordinate(latitude=41.7102379, longitude=-71.2827596), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-001', subnat2_name=None), all_time_species=172),
#   EBirdHotspot(location=EBirdLocation(id='L735002', name='Powder Mill Ledges Wildlife Refuge (ASRI)', coord=Coordinate(latitude=41.8685382, longitude=-71.5305823), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=108),
#   EBirdHotspot(location=EBirdLocation(id='L7358879', name='East Greenwich Nature and Cross Country Trail', coord=Coordinate(latitude=41.6334947, longitude=-71.4834452), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-003', subnat2_name=None), all_time_species=98),
#   EBirdHotspot(location=EBirdLocation(id='L739037', name="Ram's Tail Rd., Foster", coord=Coordinate(latitude=41.8140943, longitude=-71.7041266), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=115),
#   EBirdHotspot(location=EBirdLocation(id='L7401637', name='Howard Pond, Cumberland', coord=Coordinate(latitude=41.9555687, longitude=-71.3875294), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=30),
#   EBirdHotspot(location=EBirdLocation(id='L741738', name='Swansea Country Club Pond', coord=Coordinate(latitude=41.7625573, longitude=-71.2797475), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=43),
#   EBirdHotspot(location=EBirdLocation(id='L7425313', name='Meshanticut State Park', coord=Coordinate(latitude=41.7682996, longitude=-71.4752215), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=86),
#   EBirdHotspot(location=EBirdLocation(id='L7441559', name='Juniper Hill Cemetery', coord=Coordinate(latitude=41.6811015, longitude=-71.2680531), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-001', subnat2_name=None), all_time_species=71),
#   EBirdHotspot(location=EBirdLocation(id='L7456597', name="Joe's Rock Conservation Area", coord=Coordinate(latitude=42.0273639, longitude=-71.4056611), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-021', subnat2_name=None), all_time_species=106),
#   EBirdHotspot(location=EBirdLocation(id='L7704374', name='Occupessatuxet Cove', coord=Coordinate(latitude=41.7358513, longitude=-71.3844495), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-003', subnat2_name=None), all_time_species=79),
#   EBirdHotspot(location=EBirdLocation(id='L7788167', name='Gaspee Point', coord=Coordinate(latitude=41.743699, longitude=-71.3766397), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-003', subnat2_name=None), all_time_species=93),
#   EBirdHotspot(location=EBirdLocation(id='L7801999', name='Brown University Campus', coord=Coordinate(latitude=41.8260753, longitude=-71.403429), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=105),
#   EBirdHotspot(location=EBirdLocation(id='L8044419', name='Scalloptown Park', coord=Coordinate(latitude=41.6500455, longitude=-71.4542406), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-003', subnat2_name=None), all_time_species=138),
#   EBirdHotspot(location=EBirdLocation(id='L804728', name='Blackstone Park', coord=Coordinate(latitude=41.833327, longitude=-71.3792148), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=198),
#   EBirdHotspot(location=EBirdLocation(id='L812502', name='Squantum Woods SP', coord=Coordinate(latitude=41.7928806, longitude=-71.3724232), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=119),
#   EBirdHotspot(location=EBirdLocation(id='L815443', name='Tiogue Lake', coord=Coordinate(latitude=41.6790406, longitude=-71.5503244), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-003', subnat2_name=None), all_time_species=120),
#   EBirdHotspot(location=EBirdLocation(id='L830112', name='Oakland Beach', coord=Coordinate(latitude=41.6836816, longitude=-71.3963699), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-003', subnat2_name=None), all_time_species=74),
#   EBirdHotspot(location=EBirdLocation(id='L831723', name='Poppasquash Road Causeway, Bristol', coord=Coordinate(latitude=41.6801281, longitude=-71.2816384), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-001', subnat2_name=None), all_time_species=131),
#   EBirdHotspot(location=EBirdLocation(id='L841256', name='Broad Cove', coord=Coordinate(latitude=41.7892329, longitude=-71.1252308), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=222),
#   EBirdHotspot(location=EBirdLocation(id='L841267', name='Cole River Boat Ramp, Swansea', coord=Coordinate(latitude=41.7263586, longitude=-71.2221336), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=123),
#   EBirdHotspot(location=EBirdLocation(id='L8596244', name='India Point Park, Providence', coord=Coordinate(latitude=41.8172568, longitude=-71.3903618), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=92),
#   EBirdHotspot(location=EBirdLocation(id='L8600695', name='Blackstone River Bikeway--Valley Marsh', coord=Coordinate(latitude=41.9027514, longitude=-71.3980847), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=161),
#   EBirdHotspot(location=EBirdLocation(id='L866565', name='Lake Como, Attleboro', coord=Coordinate(latitude=41.9262365, longitude=-71.3583362), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=55),
#   EBirdHotspot(location=EBirdLocation(id='L8677678', name='Pawtucket Landing', coord=Coordinate(latitude=41.8720307, longitude=-71.384364), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=76),
#   EBirdHotspot(location=EBirdLocation(id='L8678323', name='Veterans Memorial Park, Pawtucket', coord=Coordinate(latitude=41.8794371, longitude=-71.3818826), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=47),
#   EBirdHotspot(location=EBirdLocation(id='L870123', name='Arcade Ave., Seekonk', coord=Coordinate(latitude=41.8409524, longitude=-71.3356447), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=51),
#   EBirdHotspot(location=EBirdLocation(id='L875821', name='Boyden Heights Conservation Area', coord=Coordinate(latitude=41.7895369, longitude=-71.370433), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=97),
#   EBirdHotspot(location=EBirdLocation(id='L8829767', name='Roosevelt Park, Blackstone', coord=Coordinate(latitude=42.0170563, longitude=-71.531947), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-027', subnat2_name=None), all_time_species=67),
#   EBirdHotspot(location=EBirdLocation(id='L8882178', name='St Andrews School Forest Property', coord=Coordinate(latitude=41.7500582, longitude=-71.3292369), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-001', subnat2_name=None), all_time_species=43),
#   EBirdHotspot(location=EBirdLocation(id='L8920590', name='Tillinghast Place / RISD Beach', coord=Coordinate(latitude=41.725982, longitude=-71.321841), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-001', subnat2_name=None), all_time_species=142),
#   EBirdHotspot(location=EBirdLocation(id='L900794', name='Town Pond (ALT)', coord=Coordinate(latitude=41.6323646, longitude=-71.245544), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-005', subnat2_name=None), all_time_species=152),
#   EBirdHotspot(location=EBirdLocation(id='L902021', name='Shad Factory Pond Dam, Rehoboth', coord=Coordinate(latitude=41.8088285, longitude=-71.2786102), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=109),
#   EBirdHotspot(location=EBirdLocation(id='L905070', name='Shad Factory Pond, Rehoboth', coord=Coordinate(latitude=41.8112436, longitude=-71.2841034), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=79),
#   EBirdHotspot(location=EBirdLocation(id='L9189645', name='Allen Harbor Marina', coord=Coordinate(latitude=41.6197094, longitude=-71.4112937), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-009', subnat2_name=None), all_time_species=121),
#   EBirdHotspot(location=EBirdLocation(id='L9545732', name='Mashapaug Park, Providence', coord=Coordinate(latitude=41.7960733, longitude=-71.4301347), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=140),
#   EBirdHotspot(location=EBirdLocation(id='L983673', name='Barrington Town Beach', coord=Coordinate(latitude=41.722579, longitude=-71.3087797), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-001', subnat2_name=None), all_time_species=84),
#   EBirdHotspot(location=EBirdLocation(id='L9955986', name='Council Oak Fields', coord=Coordinate(latitude=41.8190476, longitude=-71.1344576), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=106)}}

# %%
from geopy.distance import geodesic

# Find the nearest hotspot to each location
nearest_hotspots: dict[str, EBirdHotspot] = {}
for loc, hotspots in hotspots_per_location.items():
    loc_coord = location_coords[loc]
    nearest = min(hotspots, key=lambda hs: geodesic(loc_coord, hs.location.coord).mi)
    nearest_hotspots[loc] = nearest

nearest_hotspots
# Out:
# {'Providence, Rhode Island, United States': EBirdHotspot(location=EBirdLocation(id='L24184797', name='Kennedy Plaza, Providence', coord=Coordinate(latitude=41.825473, longitude=-71.412127), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=38)}

# %%
# For now, only retrieve species lists for the nearest hotspot to each location of interest
from birding.ebird_api import retrieve_species_list

for hotspot in nearest_hotspots.values():
    print(f"\n\nRetrieving bird species list for hotspot '{hotspot.location.name}'...")

    species_list = retrieve_species_list(ebird_api_key, area_code=hotspot.location.id)
    print(f"'{hotspot.location.name}' has {len(species_list)} nearby species.")
# Out:
# Retrieving bird species list for hotspot 'Kennedy Plaza, Providence'...
# Bird species list for 'L24184797' was already cached.
# 'Kennedy Plaza, Providence' has 38 nearby species.

# %%
# Retrieve species lists for all subnational and national areas represented in the current data

all_species_lists: dict[str, list[str]] = {}
invalid_area_codes = {}

for loc, hotspots in hotspots_per_location.items():
    print(f"Retrieving species lists for subnational regions around '{loc}'...")
    for hotspot in hotspots:
        hs_loc = hotspot.location
        for possible_area_code in {hs_loc.subnat1_code, hs_loc.subnat2_code, hs_loc.country_code}:
            if possible_area_code is None or possible_area_code in invalid_area_codes:
                continue

            new_list = retrieve_species_list(ebird_api_key, possible_area_code)
            all_species_lists[possible_area_code] = new_list

species_union = set()
for species_list in all_species_lists.values():
    species_union.update(species_list)

print(f"Current species lists include {len(species_union)} total distinct species.")
# Out:
# Retrieving species lists for subnational regions around 'Providence, Rhode Island, United States'...
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US-MA-005' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-009' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA-021' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-001' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US-MA-005' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US-MA-005' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US-MA-005' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-001' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-003' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-003' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-003' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US-MA-005' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-003' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-003' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US-MA-005' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US-MA-005' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-001' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-003' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-001' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-001' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-009' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-001' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US-MA-005' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US-MA-027' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-003' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US-MA-005' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US-MA-005' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-001' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-001' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US-MA-005' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-001' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-001' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US-MA-005' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-001' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-009' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US-MA-005' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US-MA-005' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-001' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-003' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US-MA-005' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-003' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-009' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-009' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-001' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US-MA-005' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-003' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-001' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-001' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-001' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US-MA-005' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-003' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-001' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US-MA-005' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-003' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA-021' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US-MA-005' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-003' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US-MA-005' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-003' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US-MA-005' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-003' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US-MA-005' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-001' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US-MA-005' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-005' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-009' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA-021' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-003' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US-MA-005' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-003' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-003' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-001' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-003' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US-MA-005' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-001' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US-MA-005' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-003' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US-MA-005' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-003' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-003' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US-MA-005' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US-MA-005' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US-MA-005' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-003' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US-MA-005' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-001' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US-MA-005' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US-MA-005' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-001' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-003' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US-MA-005' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US-MA-027' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA-021' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-001' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US-MA-005' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-001' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-001' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US-MA-005' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US-MA-005' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US-MA-005' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-003' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-009' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US-MA-005' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US-MA-005' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US-MA-005' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-001' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US-MA-005' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-005' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US-MA-005' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-003' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-003' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-003' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US-MA-005' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-001' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-001' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US-MA-027' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-001' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-003' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US-MA-005' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-001' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-003' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-003' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-001' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-001' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-003' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US-MA-005' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-003' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-005' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-001' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US-MA-005' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-001' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US-MA-005' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US-MA-005' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US-MA-005' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-001' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-003' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-003' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-003' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-001' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US-MA-005' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-003' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-009' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-009' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA-021' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-001' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US-MA-005' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-001' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-005' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US-MA-005' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA-021' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-001' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US-MA-005' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US-MA-005' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US-MA-005' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US-MA-005' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-003' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-001' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US-MA-005' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US-MA-005' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-001' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-001' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-001' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-001' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US-MA-005' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US-MA-005' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-MA-021' was already cached.
# Bird species list for 'US-MA' was already cached.
# Bird species list for 'US' was already cached.
# Bird species list for 'US-RI-007' was already cached.
# Bird species list for 'US-RI' was already cached.
# Current species lists include 1776 total distinct species.

# %%
# Finally, retrieve species lists for all hotspots near our locations of interest
for loc, hotspots in hotspots_per_location.items():
    print(f"Retrieving species lists for hotspots near '{loc}'...")
    for hotspot in hotspots:
        hotspot_species = retrieve_species_list(ebird_api_key, hotspot.location.id)
        all_species_lists[hotspot.location.id] = hotspot_species

species_union = set()
for species_list in all_species_lists.values():
    species_union.update(species_list)

print(f"Current species lists include {len(species_union)} total distinct species.")
# Out:
# Retrieving species lists for hotspots near 'Providence, Rhode Island, United States'...
# Bird species list for 'L1878310' was already cached.
# Bird species list for 'L804728' was already cached.
# Bird species list for 'L487743' was already cached.
# Bird species list for 'L16976973' was already cached.
# Bird species list for 'L8600695' was already cached.
# Bird species list for 'L4333450' was already cached.
# Bird species list for 'L41628130' was already cached.
# Bird species list for 'L4683264' was already cached.
# Bird species list for 'L7456597' was already cached.
# Bird species list for 'L3567188' was already cached.
# Bird species list for 'L13041553' was already cached.
# Bird species list for 'L12052632' was already cached.
# Bird species list for 'L2792209' was already cached.
# Bird species list for 'L6370013' was already cached.
# Bird species list for 'L11920582' was already cached.
# Bird species list for 'L8044419' was already cached.
# Bird species list for 'L16329835' was already cached.
# Bird species list for 'L487669' was already cached.
# Bird species list for 'L8678323' was already cached.
# Bird species list for 'L17492948' was already cached.
# Bird species list for 'L49179776' was already cached.
# Bird species list for 'L43850174' was already cached.
# Bird species list for 'L11366118' was already cached.
# Bird species list for 'L13158219' was already cached.
# Bird species list for 'L4741793' was already cached.
# Bird species list for 'L734825' was already cached.
# Bird species list for 'L2283278' was already cached.
# Bird species list for 'L1283703' was already cached.
# Bird species list for 'L18152326' was already cached.
# Bird species list for 'L46689195' was already cached.
# Bird species list for 'L1325528' was already cached.
# Bird species list for 'L38630101' was already cached.
# Bird species list for 'L10170471' was already cached.
# Bird species list for 'L124352' was already cached.
# Bird species list for 'L450725' was already cached.
# Bird species list for 'L216062' was already cached.
# Bird species list for 'L730688' was already cached.
# Bird species list for 'L11222818' was already cached.
# Bird species list for 'L11913876' was already cached.
# Bird species list for 'L13048089' was already cached.
# Bird species list for 'L29863733' was already cached.
# Bird species list for 'L4423843' was already cached.
# Bird species list for 'L1007144' was already cached.
# Bird species list for 'L4600100' was already cached.
# Bird species list for 'L2465689' was already cached.
# Bird species list for 'L14031193' was already cached.
# Bird species list for 'L3970468' was already cached.
# Bird species list for 'L8920590' was already cached.
# Bird species list for 'L1888546' was already cached.
# Bird species list for 'L38376933' was already cached.
# Bird species list for 'L23891210' was already cached.
# Bird species list for 'L5455344' was already cached.
# Bird species list for 'L33905702' was already cached.
# Bird species list for 'L4402357' was already cached.
# Bird species list for 'L13430824' was already cached.
# Bird species list for 'L43251693' was already cached.
# Bird species list for 'L2390045' was already cached.
# Bird species list for 'L55389099' was already cached.
# Bird species list for 'L13048144' was already cached.
# Bird species list for 'L4975633' was already cached.
# Bird species list for 'L40170320' was already cached.
# Bird species list for 'L34341378' was already cached.
# Bird species list for 'L12073266' was already cached.
# Bird species list for 'L11683398' was already cached.
# Bird species list for 'L41627753' was already cached.
# Bird species list for 'L35960144' was already cached.
# Bird species list for 'L31604299' was already cached.
# Bird species list for 'L2482586' was already cached.
# Bird species list for 'L11866685' was already cached.
# Bird species list for 'L30802876' was already cached.
# Bird species list for 'L875821' was already cached.
# Bird species list for 'L27806934' was already cached.
# Bird species list for 'L6073694' was already cached.
# Bird species list for 'L12817315' was already cached.
# Bird species list for 'L5251233' was already cached.
# Bird species list for 'L3157427' was already cached.
# Bird species list for 'L16672907' was already cached.
# Bird species list for 'L5727176' was already cached.
# Bird species list for 'L25335615' was already cached.
# Bird species list for 'L31398708' was already cached.
# Bird species list for 'L55405746' was already cached.
# Bird species list for 'L4053762' was already cached.
# Bird species list for 'L22412271' was already cached.
# Bird species list for 'L55322509' was already cached.
# Bird species list for 'L4369526' was already cached.
# Bird species list for 'L41541061' was already cached.
# Bird species list for 'L190070' was already cached.
# Bird species list for 'L9545732' was already cached.
# Bird species list for 'L613147' was already cached.
# Bird species list for 'L12606996' was already cached.
# Bird species list for 'L9955986' was already cached.
# Bird species list for 'L10482078' was already cached.
# Bird species list for 'L7704374' was already cached.
# Bird species list for 'L5070824' was already cached.
# Bird species list for 'L10189488' was already cached.
# Bird species list for 'L18266371' was already cached.
# Bird species list for 'L41628165' was already cached.
# Bird species list for 'L14185394' was already cached.
# Bird species list for 'L54768291' was already cached.
# Bird species list for 'L14264549' was already cached.
# Bird species list for 'L17197972' was already cached.
# Bird species list for 'L5071219' was already cached.
# Bird species list for 'L2718493' was already cached.
# Bird species list for 'L4538187' was already cached.
# Bird species list for 'L29523147' was already cached.
# Bird species list for 'L1615937' was already cached.
# Bird species list for 'L2913295' was already cached.
# Bird species list for 'L28111910' was already cached.
# Bird species list for 'L13121233' was already cached.
# Bird species list for 'L13935214' was already cached.
# Bird species list for 'L2214089' was already cached.
# Bird species list for 'L23449783' was already cached.
# Bird species list for 'L2875659' was already cached.
# Bird species list for 'L902021' was already cached.
# Bird species list for 'L4404827' was already cached.
# Bird species list for 'L40170227' was already cached.
# Bird species list for 'L1365565' was already cached.
# Bird species list for 'L34675448' was already cached.
# Bird species list for 'L870123' was already cached.
# Bird species list for 'L26226874' was already cached.
# Bird species list for 'L487742' was already cached.
# Bird species list for 'L3651661' was already cached.
# Bird species list for 'L25323688' was already cached.
# Bird species list for 'L17262087' was already cached.
# Bird species list for 'L8677678' was already cached.
# Bird species list for 'L4826425' was already cached.
# Bird species list for 'L734901' was already cached.
# Bird species list for 'L1139391' was already cached.
# Bird species list for 'L1390947' was already cached.
# Bird species list for 'L2776143' was already cached.
# Bird species list for 'L12266919' was already cached.
# Bird species list for 'L1406045' was already cached.
# Bird species list for 'L4207196' was already cached.
# Bird species list for 'L4333222' was already cached.
# Bird species list for 'L17976310' was already cached.
# Bird species list for 'L55029974' was already cached.
# Bird species list for 'L905070' was already cached.
# Bird species list for 'L7358879' was already cached.
# Bird species list for 'L14173384' was already cached.
# Bird species list for 'L4112916' was already cached.
# Bird species list for 'L12696120' was already cached.
# Bird species list for 'L831723' was already cached.
# Bird species list for 'L7788167' was already cached.
# Bird species list for 'L14031201' was already cached.
# Bird species list for 'L17150946' was already cached.
# Bird species list for 'L7441559' was already cached.
# Bird species list for 'L12295388' was already cached.
# Bird species list for 'L4578087' was already cached.
# Bird species list for 'L12721457' was already cached.
# Bird species list for 'L1135167' was already cached.
# Bird species list for 'L6182809' was already cached.
# Bird species list for 'L16494250' was already cached.
# Bird species list for 'L815443' was already cached.
# Bird species list for 'L3260829' was already cached.
# Bird species list for 'L1282270' was already cached.
# Bird species list for 'L10975778' was already cached.
# Bird species list for 'L15139458' was already cached.
# Bird species list for 'L687632' was already cached.
# Bird species list for 'L3300181' was already cached.
# Bird species list for 'L49057407' was already cached.
# Bird species list for 'L16657907' was already cached.
# Bird species list for 'L47132166' was already cached.
# Bird species list for 'L13447055' was already cached.
# Bird species list for 'L43513174' was already cached.
# Bird species list for 'L3158239' was already cached.
# Bird species list for 'L12289642' was already cached.
# Bird species list for 'L7113200' was already cached.
# Bird species list for 'L812502' was already cached.
# Bird species list for 'L33244456' was already cached.
# Bird species list for 'L21194566' was already cached.
# Bird species list for 'L2781443' was already cached.
# Bird species list for 'L393285' was already cached.
# Bird species list for 'L22140967' was already cached.
# Bird species list for 'L24060186' was already cached.
# Bird species list for 'L12966956' was already cached.
# Bird species list for 'L12894191' was already cached.
# Bird species list for 'L1393150' was already cached.
# Bird species list for 'L23688813' was already cached.
# Bird species list for 'L4538190' was already cached.
# Bird species list for 'L5123222' was already cached.
# Bird species list for 'L1786830' was already cached.
# Bird species list for 'L1463082' was already cached.
# Bird species list for 'L24131893' was already cached.
# Bird species list for 'L451783' was already cached.
# Bird species list for 'L5128475' was already cached.
# Bird species list for 'L55055686' was already cached.
# Bird species list for 'L7801999' was already cached.
# Bird species list for 'L5495329' was already cached.
# Bird species list for 'L12545495' was already cached.
# Bird species list for 'L830112' was already cached.
# Bird species list for 'L40521950' was already cached.
# Bird species list for 'L41322492' was already cached.
# Bird species list for 'L4066133' was already cached.
# Bird species list for 'L12450396' was already cached.
# Bird species list for 'L866565' was already cached.
# Bird species list for 'L31392271' was already cached.
# Bird species list for 'L41527208' was already cached.
# Bird species list for 'L20653314' was already cached.
# Bird species list for 'L19186567' was already cached.
# Bird species list for 'L5397820' was already cached.
# Bird species list for 'L13057430' was already cached.
# Bird species list for 'L247829' was already cached.
# Bird species list for 'L1393330' was already cached.
# Bird species list for 'L10078182' was already cached.
# Bird species list for 'L6271814' was already cached.
# Bird species list for 'L36435856' was already cached.
# Bird species list for 'L549748' was already cached.
# Bird species list for 'L4095950' was already cached.
# Bird species list for 'L6178635' was already cached.
# Bird species list for 'L14885742' was already cached.
# Bird species list for 'L29143732' was already cached.
# Bird species list for 'L11635308' was already cached.
# Bird species list for 'L17970931' was already cached.
# Bird species list for 'L4658133' was already cached.
# Bird species list for 'L739037' was already cached.
# Bird species list for 'L6530163' was already cached.
# Bird species list for 'L1391725' was already cached.
# Bird species list for 'L38649323' was already cached.
# Bird species list for 'L4577118' was already cached.
# Bird species list for 'L12799134' was already cached.
# Bird species list for 'L5126639' was already cached.
# Bird species list for 'L735002' was already cached.
# Bird species list for 'L5844667' was already cached.
# Bird species list for 'L21432043' was already cached.
# Bird species list for 'L8829767' was already cached.
# Bird species list for 'L1325526' was already cached.
# Bird species list for 'L3923511' was already cached.
# Bird species list for 'L22351437' was already cached.
# Bird species list for 'L10487395' was already cached.
# Bird species list for 'L841267' was already cached.
# Bird species list for 'L2808160' was already cached.
# Bird species list for 'L12136837' was already cached.
# Bird species list for 'L5426087' was already cached.
# Bird species list for 'L357306' was already cached.
# Bird species list for 'L40384308' was already cached.
# Bird species list for 'L11430695' was already cached.
# Bird species list for 'L11806624' was already cached.
# Bird species list for 'L22213549' was already cached.
# Bird species list for 'L1391689' was already cached.
# Bird species list for 'L38666615' was already cached.
# Bird species list for 'L11815850' was already cached.
# Bird species list for 'L51518007' was already cached.
# Bird species list for 'L5133234' was already cached.
# Bird species list for 'L19377129' was already cached.
# Bird species list for 'L13049070' was already cached.
# Bird species list for 'L12639998' was already cached.
# Bird species list for 'L5133105' was already cached.
# Bird species list for 'L24184797' was already cached.
# Bird species list for 'L41521101' was already cached.
# Bird species list for 'L40169532' was already cached.
# Bird species list for 'L44616927' was already cached.
# Bird species list for 'L2526644' was already cached.
# Bird species list for 'L44468211' was already cached.
# Bird species list for 'L4653581' was already cached.
# Bird species list for 'L12385319' was already cached.
# Bird species list for 'L286912' was already cached.
# Bird species list for 'L3997605' was already cached.
# Bird species list for 'L31274340' was already cached.
# Bird species list for 'L38645358' was already cached.
# Bird species list for 'L983673' was already cached.
# Bird species list for 'L1393144' was already cached.
# Bird species list for 'L1297392' was already cached.
# Bird species list for 'L15187055' was already cached.
# Bird species list for 'L34718849' was already cached.
# Bird species list for 'L1670551' was already cached.
# Bird species list for 'L12824129' was already cached.
# Bird species list for 'L8596244' was already cached.
# Bird species list for 'L1571704' was already cached.
# Bird species list for 'L1458015' was already cached.
# Bird species list for 'L4525701' was already cached.
# Bird species list for 'L38433651' was already cached.
# Bird species list for 'L4343578' was already cached.
# Bird species list for 'L42925934' was already cached.
# Bird species list for 'L38630506' was already cached.
# Bird species list for 'L6077334' was already cached.
# Bird species list for 'L15585790' was already cached.
# Bird species list for 'L16544941' was already cached.
# Bird species list for 'L15210138' was already cached.
# Bird species list for 'L634993' was already cached.
# Bird species list for 'L5668641' was already cached.
# Bird species list for 'L34718866' was already cached.
# Bird species list for 'L734909' was already cached.
# Bird species list for 'L7401637' was already cached.
# Bird species list for 'L34675950' was already cached.
# Bird species list for 'L2599631' was already cached.
# Bird species list for 'L17425289' was already cached.
# Bird species list for 'L31745262' was already cached.
# Bird species list for 'L10135757' was already cached.
# Bird species list for 'L42686760' was already cached.
# Bird species list for 'L4789272' was already cached.
# Bird species list for 'L5099232' was already cached.
# Bird species list for 'L10825088' was already cached.
# Bird species list for 'L9189645' was already cached.
# Bird species list for 'L731326' was already cached.
# Bird species list for 'L187164' was already cached.
# Bird species list for 'L10059274' was already cached.
# Bird species list for 'L1390952' was already cached.
# Bird species list for 'L12545551' was already cached.
# Bird species list for 'L453500' was already cached.
# Bird species list for 'L4588597' was already cached.
# Bird species list for 'L7425313' was already cached.
# Bird species list for 'L213318' was already cached.
# Bird species list for 'L900794' was already cached.
# Bird species list for 'L1499732' was already cached.
# Bird species list for 'L15208246' was already cached.
# Bird species list for 'L2597004' was already cached.
# Bird species list for 'L39583673' was already cached.
# Bird species list for 'L11444077' was already cached.
# Bird species list for 'L2802133' was already cached.
# Bird species list for 'L10658440' was already cached.
# Bird species list for 'L1618211' was already cached.
# Bird species list for 'L11516357' was already cached.
# Bird species list for 'L2683958' was already cached.
# Bird species list for 'L13813738' was already cached.
# Bird species list for 'L30901951' was already cached.
# Bird species list for 'L29020679' was already cached.
# Bird species list for 'L207451' was already cached.
# Bird species list for 'L1306965' was already cached.
# Bird species list for 'L38422558' was already cached.
# Bird species list for 'L14975740' was already cached.
# Bird species list for 'L8882178' was already cached.
# Bird species list for 'L841256' was already cached.
# Bird species list for 'L741738' was already cached.
# Bird species list for 'L15294747' was already cached.
# Bird species list for 'L17120086' was already cached.
# Bird species list for 'L1320533' was already cached.
# Bird species list for 'L5277851' was already cached.
# Bird species list for 'L2430264' was already cached.
# Bird species list for 'L42665518' was already cached.
# Bird species list for 'L13429477' was already cached.
# Bird species list for 'L1458029' was already cached.
# Bird species list for 'L17165257' was already cached.
# Bird species list for 'L4377381' was already cached.
# Bird species list for 'L15883704' was already cached.
# Bird species list for 'L10470601' was already cached.
# Bird species list for 'L2071074' was already cached.
# Bird species list for 'L13992195' was already cached.
# Current species lists include 1776 total distinct species.

# %%
# Compute the distances (km) from each location to all nearby hotspots
from collections import defaultdict

hotspot_distances_km: dict[str, dict[EBirdHotspot, float]] = defaultdict(dict)

for loc, hotspots in hotspots_per_location.items():
    loc_coord = location_coords[loc]
    for hotspot in hotspots:
        hotspot_distances_km[loc][hotspot] = geodesic(loc_coord, hotspot.location.coord).kilometers

dict(hotspot_distances_km)
# Out:
# {'Providence, Rhode Island, United States': {EBirdHotspot(location=EBirdLocation(id='L1878310', name='stakeout Black-throated Gray Warbler, 103 James H. Luther Dr., Taunton (Jan 2013)', coord=Coordinate(latitude=41.8984761, longitude=-71.1748638), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=34): 21.420972706982393,
#   EBirdHotspot(location=EBirdLocation(id='L804728', name='Blackstone Park', coord=Coordinate(latitude=41.833327, longitude=-71.3792148), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=198): 2.979223584202543,
#   EBirdHotspot(location=EBirdLocation(id='L487743', name='Central Pond Reservoir, East Providence', coord=Coordinate(latitude=41.8591418, longitude=-71.3376617), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=92): 7.363841960963269,
#   EBirdHotspot(location=EBirdLocation(id='L16976973', name='Saw Mill Pond, North Kingstown', coord=Coordinate(latitude=41.6140294, longitude=-71.4653584), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-009', subnat2_name=None), all_time_species=44): 23.72583006690646,
#   EBirdHotspot(location=EBirdLocation(id='L8600695', name='Blackstone River Bikeway--Valley Marsh', coord=Coordinate(latitude=41.9027514, longitude=-71.3980847), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=161): 8.833477995314507,
#   EBirdHotspot(location=EBirdLocation(id='L4333450', name='Chase Farm, Lincoln', coord=Coordinate(latitude=41.9064362, longitude=-71.4288585), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=154): 9.253592514794052,
#   EBirdHotspot(location=EBirdLocation(id='L41628130', name='Blackstone River Bikeway--Albion to Manville Parking Area', coord=Coordinate(latitude=41.9573319, longitude=-71.4622947), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=107): 15.36885692356604,
#   EBirdHotspot(location=EBirdLocation(id='L4683264', name='North Burial Ground', coord=Coordinate(latitude=41.8483753, longitude=-71.4091051), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=72): 2.7262325012432345,
#   EBirdHotspot(location=EBirdLocation(id='L7456597', name="Joe's Rock Conservation Area", coord=Coordinate(latitude=42.0273639, longitude=-71.4056611), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-021', subnat2_name=None), all_time_species=106): 22.597048055166482,
#   EBirdHotspot(location=EBirdLocation(id='L3567188', name='East Bay Bike Path--Warren Dog Park to Colt State Park', coord=Coordinate(latitude=41.705527, longitude=-71.28859), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-001', subnat2_name=None), all_time_species=143): 16.72898847659169,
#   EBirdHotspot(location=EBirdLocation(id='L13041553', name='Harold Burns Memorial Wildlife Arboretum', coord=Coordinate(latitude=41.9958385, longitude=-71.3217259), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=44): 20.52984360002333,
#   EBirdHotspot(location=EBirdLocation(id='L12052632', name='L.A. Foster Wildlife Refuge', coord=Coordinate(latitude=41.9474619, longitude=-71.1761466), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=57): 23.95826152768345,
#   EBirdHotspot(location=EBirdLocation(id='L2792209', name='Sweets Knoll SP', coord=Coordinate(latitude=41.8302771, longitude=-71.114858), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=147): 24.764105924755132,
#   EBirdHotspot(location=EBirdLocation(id='L6370013', name='Warren Bike Path', coord=Coordinate(latitude=41.7260657, longitude=-71.2597087), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-001', subnat2_name=None), all_time_species=97): 16.744402015243754,
#   EBirdHotspot(location=EBirdLocation(id='L11920582', name='Blackstone Gorge (RI)', coord=Coordinate(latitude=42.0125889, longitude=-71.5520399), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=84): 23.920274138414317,
#   EBirdHotspot(location=EBirdLocation(id='L8044419', name='Scalloptown Park', coord=Coordinate(latitude=41.6500455, longitude=-71.4542406), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-003', subnat2_name=None), all_time_species=138): 19.624280037954676,
#   EBirdHotspot(location=EBirdLocation(id='L16329835', name='Stump Pond (Coventry Land Trust)', coord=Coordinate(latitude=41.6879961, longitude=-71.6379086), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-003', subnat2_name=None), all_time_species=106): 24.05273963012378,
#   EBirdHotspot(location=EBirdLocation(id='L487669', name='Flat River Reservoir, Coventry', coord=Coordinate(latitude=41.7074586, longitude=-71.6359663), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-003', subnat2_name=None), all_time_species=119): 22.62256291053987,
#   EBirdHotspot(location=EBirdLocation(id='L8678323', name='Veterans Memorial Park, Pawtucket', coord=Coordinate(latitude=41.8794371, longitude=-71.3818826), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=47): 6.673475351252498,
#   EBirdHotspot(location=EBirdLocation(id='L17492948', name='Barney Ave./Almeida Rd. Fields, Rehoboth', coord=Coordinate(latitude=41.786875, longitude=-71.286641), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=43): 11.268098308808177,
#   EBirdHotspot(location=EBirdLocation(id='L49179776', name='Randall Pond Conservation Area (PRAWC)', coord=Coordinate(latitude=41.790326, longitude=-71.470764), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=10): 6.095419942132872,
#   EBirdHotspot(location=EBirdLocation(id='L43850174', name='Washington Secondary Trail--Father Tirocchi Field Area', coord=Coordinate(latitude=41.7249223, longitude=-71.48592), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-003', subnat2_name=None), all_time_species=37): 12.569631503069497,
#   EBirdHotspot(location=EBirdLocation(id='L11366118', name='Riverside Cemetery', coord=Coordinate(latitude=41.8601221, longitude=-71.3824707), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=112): 4.739868013282874,
#   EBirdHotspot(location=EBirdLocation(id='L13158219', name='Glenford Cemetery, Scituate', coord=Coordinate(latitude=41.8309334, longitude=-71.5904518), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=46): 14.77557359634202,
#   EBirdHotspot(location=EBirdLocation(id='L4741793', name='Pawtuxet Memorial Cemetary', coord=Coordinate(latitude=41.7543759, longitude=-71.3957101), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-003', subnat2_name=None), all_time_species=31): 7.861815212119687,
#   EBirdHotspot(location=EBirdLocation(id='L734825', name='Caratunk Wildlife Refuge (ASRI)', coord=Coordinate(latitude=41.8740347, longitude=-71.3212734), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=171): 9.418892980742497,
#   EBirdHotspot(location=EBirdLocation(id='L2283278', name='Dighton Town Landing', coord=Coordinate(latitude=41.7968199, longitude=-71.120553), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=130): 24.474217620546515,
#   EBirdHotspot(location=EBirdLocation(id='L1283703', name='Nyatt Road Access', coord=Coordinate(latitude=41.7303621, longitude=-71.3408375), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-001', subnat2_name=None), all_time_species=112): 11.998730688393215,
#   EBirdHotspot(location=EBirdLocation(id='L18152326', name='Providence River Greenway', coord=Coordinate(latitude=41.8221469, longitude=-71.4065884), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=89): 0.5577925763686061,
#   EBirdHotspot(location=EBirdLocation(id='L46689195', name='Grassy Plains Park, East Providence', coord=Coordinate(latitude=41.768335, longitude=-71.332246), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=21): 9.114526390627109,
#   EBirdHotspot(location=EBirdLocation(id='L1325528', name='Warwick City Park', coord=Coordinate(latitude=41.6885579, longitude=-71.4063702), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-003', subnat2_name=None), all_time_species=115): 15.051750971532407,
#   EBirdHotspot(location=EBirdLocation(id='L38630101', name='Gate of Heaven Cemetery, East Providence', coord=Coordinate(latitude=41.792361, longitude=-71.339235), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=45): 7.053120504917981,
#   EBirdHotspot(location=EBirdLocation(id='L10170471', name='St. Andrews Farm, Barrington', coord=Coordinate(latitude=41.7494135, longitude=-71.3328399), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-001', subnat2_name=None), all_time_species=69): 10.622012881263698,
#   EBirdHotspot(location=EBirdLocation(id='L124352', name='Swan Point Cemetery', coord=Coordinate(latitude=41.8557485, longitude=-71.3812176), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=222): 4.397660461828325,
#   EBirdHotspot(location=EBirdLocation(id='L450725', name='Arnold Mills Reservoir, Cumberland', coord=Coordinate(latitude=41.9862744, longitude=-71.3969407), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=187): 18.07343851409287,
#   EBirdHotspot(location=EBirdLocation(id='L216062', name='Bold Point Park, East Providence', coord=Coordinate(latitude=41.8144807, longitude=-71.3901623), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=159): 2.1595511886996506,
#   EBirdHotspot(location=EBirdLocation(id='L730688', name='East Bay Bike Path--Colt State Park to Independence Park', coord=Coordinate(latitude=41.6824731, longitude=-71.2813489), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-001', subnat2_name=None), all_time_species=130): 19.14791941334694,
#   EBirdHotspot(location=EBirdLocation(id='L11222818', name='Quidnessett Cemetery, North Kingstown', coord=Coordinate(latitude=41.6247735, longitude=-71.4614067), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-009', subnat2_name=None), all_time_species=120): 22.492549255643716,
#   EBirdHotspot(location=EBirdLocation(id='L11913876', name='Haile Farm Preserve (WLCT)', coord=Coordinate(latitude=41.7514372, longitude=-71.279314), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-001', subnat2_name=None), all_time_species=128): 13.715774403586323,
#   EBirdHotspot(location=EBirdLocation(id='L13048089', name='Resurrection Cemetery, Cumberland', coord=Coordinate(latitude=42.006054, longitude=-71.447179), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=51): 20.421986442199994,
#   EBirdHotspot(location=EBirdLocation(id='L29863733', name='Village Park, Swansea', coord=Coordinate(latitude=41.7510963, longitude=-71.1898653), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=54): 20.225573868940028,
#   EBirdHotspot(location=EBirdLocation(id='L4423843', name='Blackstone Gorge', coord=Coordinate(latitude=42.0151373, longitude=-71.5528822), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-027', subnat2_name=None), all_time_species=93): 24.201902581959363,
#   EBirdHotspot(location=EBirdLocation(id='L1007144', name='Goddard Memorial SP', coord=Coordinate(latitude=41.6611783, longitude=-71.4358091), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-003', subnat2_name=None), all_time_species=163): 18.183826043421774,
#   EBirdHotspot(location=EBirdLocation(id='L4600100', name='Crestwood Country Club', coord=Coordinate(latitude=41.8244527, longitude=-71.277253), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=34): 11.263991989214272,
#   EBirdHotspot(location=EBirdLocation(id='L2465689', name='Soucy Falls, Woonsocket', coord=Coordinate(latitude=42.0164127, longitude=-71.5067482), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=16): 22.748407855116714,
#   EBirdHotspot(location=EBirdLocation(id='L14031193', name='Oak Swamp Reservoir (limited access)', coord=Coordinate(latitude=41.826814, longitude=-71.54223), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=39): 10.75436530113356,
#   EBirdHotspot(location=EBirdLocation(id='L3970468', name='Miller St. Pond', coord=Coordinate(latitude=41.8037817, longitude=-71.3094234), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=88): 8.880883404838661,
#   EBirdHotspot(location=EBirdLocation(id='L8920590', name='Tillinghast Place / RISD Beach', coord=Coordinate(latitude=41.725982, longitude=-71.321841), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-001', subnat2_name=None), all_time_species=142): 13.256309014249249,
#   EBirdHotspot(location=EBirdLocation(id='L1888546', name='Walker Cove', coord=Coordinate(latitude=41.6604123, longitude=-71.2706554), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-001', subnat2_name=None), all_time_species=79): 21.678610957666816,
#   EBirdHotspot(location=EBirdLocation(id='L38376933', name='Central Landfill, Johnston (limited access)', coord=Coordinate(latitude=41.8075395, longitude=-71.5324731), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=84): 10.10721222827208,
#   EBirdHotspot(location=EBirdLocation(id='L23891210', name='Attleboro Community Garden', coord=Coordinate(latitude=41.9443897, longitude=-71.2897038), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=29): 16.83105789150114,
#   EBirdHotspot(location=EBirdLocation(id='L5455344', name='Haffenreffer Estate', coord=Coordinate(latitude=41.679539, longitude=-71.2362903), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-001', subnat2_name=None), all_time_species=68): 21.74879987179427,
#   EBirdHotspot(location=EBirdLocation(id='L33905702', name='Roger Williams University', coord=Coordinate(latitude=41.6519144, longitude=-71.2569935), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-001', subnat2_name=None), all_time_species=64): 23.094239542791403,
#   EBirdHotspot(location=EBirdLocation(id='L4402357', name='Scituate Reservoir', coord=Coordinate(latitude=41.8358047, longitude=-71.5957975), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=72): 15.255494523206277,
#   EBirdHotspot(location=EBirdLocation(id='L13430824', name='Waterman St. Dog Park', coord=Coordinate(latitude=41.8277178, longitude=-71.3835141), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=73): 2.4707695270135694,
#   EBirdHotspot(location=EBirdLocation(id='L43251693', name='Mount St. Mary Cemetery, East Providence', coord=Coordinate(latitude=41.8569603, longitude=-71.3666189), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=15): 5.305224894175383,
#   EBirdHotspot(location=EBirdLocation(id='L2390045', name='Wheaton College', coord=Coordinate(latitude=41.9673242, longitude=-71.1837137), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=141): 24.798851616456584,
#   EBirdHotspot(location=EBirdLocation(id='L55389099', name='Kickemuit River--Child Street Bridge', coord=Coordinate(latitude=41.729527, longitude=-71.2626966), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-001', subnat2_name=None), all_time_species=3): 16.30608103424058,
#   EBirdHotspot(location=EBirdLocation(id='L13048144', name='Gainsborough Commons (limited access)', coord=Coordinate(latitude=42.008083, longitude=-71.453635), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=12): 20.725873039104147,
#   EBirdHotspot(location=EBirdLocation(id='L4975633', name='Blackstone River Bikeway--Lonsdale Drive-In', coord=Coordinate(latitude=41.9101022, longitude=-71.4004254), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=145): 9.6199660904627,
#   EBirdHotspot(location=EBirdLocation(id='L40170320', name='Governor John Notte Memorial Park, North Providence', coord=Coordinate(latitude=41.8712226, longitude=-71.4631462), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=44): 6.7068105712646675,
#   EBirdHotspot(location=EBirdLocation(id='L34341378', name='Spink Neck Beach', coord=Coordinate(latitude=41.6199091, longitude=-71.4078101), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-009', subnat2_name=None), all_time_species=34): 22.670589565676508,
#   EBirdHotspot(location=EBirdLocation(id='L12073266', name='Willett Pond, East Providence', coord=Coordinate(latitude=41.775647, longitude=-71.356669), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=76): 7.11469674189736,
#   EBirdHotspot(location=EBirdLocation(id='L11683398', name='Diamond Hill Management Area', coord=Coordinate(latitude=42.001108, longitude=-71.431875), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=69): 19.736198264572785,
#   EBirdHotspot(location=EBirdLocation(id='L41627753', name='Blackstone River Bikeway--Kelly House Trail to I-295 Visitor Center', coord=Coordinate(latitude=41.9404151, longitude=-71.4424413), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=32): 13.162987548991309,
#   EBirdHotspot(location=EBirdLocation(id='L35960144', name='stakeout Lark Bunting--Norton (2024)', coord=Coordinate(latitude=41.9697876, longitude=-71.1947624), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=43): 24.284382719239407,
#   EBirdHotspot(location=EBirdLocation(id='L31604299', name='Nickerson Walking Woods Preserve', coord=Coordinate(latitude=41.9616366, longitude=-71.2549921), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=49): 20.132910236846406,
#   EBirdHotspot(location=EBirdLocation(id='L2482586', name='Independence Park, Bristol', coord=Coordinate(latitude=41.674403, longitude=-71.279586), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-001', subnat2_name=None), all_time_species=81): 19.971644177083824,
#   EBirdHotspot(location=EBirdLocation(id='L11866685', name="Bullock's Cove", coord=Coordinate(latitude=41.7601546, longitude=-71.3538947), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=112): 8.617977892490883,
#   EBirdHotspot(location=EBirdLocation(id='L30802876', name='Captain Stephen Olney Memorial Park', coord=Coordinate(latitude=41.855094, longitude=-71.455276), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=37): 4.935837077997924,
#   EBirdHotspot(location=EBirdLocation(id='L875821', name='Boyden Heights Conservation Area', coord=Coordinate(latitude=41.7895369, longitude=-71.370433), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=97): 5.201774889531818,
#   EBirdHotspot(location=EBirdLocation(id='L27806934', name='North Central Pond, Smithfield', coord=Coordinate(latitude=41.9138215, longitude=-71.4864678), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=34): 11.701514544210754,
#   EBirdHotspot(location=EBirdLocation(id='L6073694', name='Big River Management Area--Sand Pit', coord=Coordinate(latitude=41.6464519, longitude=-71.5779448), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-003', subnat2_name=None), all_time_species=135): 24.031394077340128,
#   EBirdHotspot(location=EBirdLocation(id='L12817315', name='Crescent Park, East Providence', coord=Coordinate(latitude=41.7567563, longitude=-71.3611223), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=108): 8.616252315294298,
#   EBirdHotspot(location=EBirdLocation(id='L5251233', name='Providence River (please use more specific location if possible)', coord=Coordinate(latitude=41.8002744, longitude=-71.3865166), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=59): 3.4234704935057474,
#   EBirdHotspot(location=EBirdLocation(id='L3157427', name='Maple Street Powerline Cut', coord=Coordinate(latitude=41.8651505, longitude=-71.1994743), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=126): 18.300253738339986,
#   EBirdHotspot(location=EBirdLocation(id='L16672907', name='Conimicut Saltmarsh, Warwick', coord=Coordinate(latitude=41.7136737, longitude=-71.364103), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-003', subnat2_name=None), all_time_species=76): 12.905227770780202,
#   EBirdHotspot(location=EBirdLocation(id='L5727176', name='Calf Pasture Point Recreation Area--Bikepath', coord=Coordinate(latitude=41.6268485, longitude=-71.4154875), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-009', subnat2_name=None), all_time_species=191): 21.89711612529884,
#   EBirdHotspot(location=EBirdLocation(id='L25335615', name='Old Slater Mill National Historic Landmark', coord=Coordinate(latitude=41.8775897, longitude=-71.3824332), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=38): 6.466621605286404,
#   EBirdHotspot(location=EBirdLocation(id='L31398708', name='Davisville Middle School Nature Paths', coord=Coordinate(latitude=41.6193485, longitude=-71.4648414), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-009', subnat2_name=None), all_time_species=35): 23.137307604287365,
#   EBirdHotspot(location=EBirdLocation(id='L55405746', name='Overlook Rock', coord=Coordinate(latitude=41.6683281, longitude=-71.2371538), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-001', subnat2_name=None), all_time_species=None): 22.637318740461453,
#   EBirdHotspot(location=EBirdLocation(id='L4053762', name='Lewin Brook Pond', coord=Coordinate(latitude=41.7462816, longitude=-71.1926079), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=51): 20.239684920079313,
#   EBirdHotspot(location=EBirdLocation(id='L22412271', name='East Greenwich Cove Overlook', coord=Coordinate(latitude=41.656898, longitude=-71.449188), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-003', subnat2_name=None), all_time_species=61): 18.80329490385055,
#   EBirdHotspot(location=EBirdLocation(id='L55322509', name='East Bay Bike Path--Veterans Memorial Parkway', coord=Coordinate(latitude=41.8091301, longitude=-71.3871416), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=17): 2.6983293609820502,
#   EBirdHotspot(location=EBirdLocation(id='L4369526', name="Olivia's Forest", coord=Coordinate(latitude=41.889825, longitude=-71.4954769), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=34): 10.02811090179972,
#   EBirdHotspot(location=EBirdLocation(id='L41541061', name='Twin River Casino Retention Ponds, Lincoln', coord=Coordinate(latitude=41.88732, longitude=-71.444158), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=36): 7.499688893206232,
#   EBirdHotspot(location=EBirdLocation(id='L190070', name='Osamequin Bird Sanctuary', coord=Coordinate(latitude=41.760147, longitude=-71.32268), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-001', subnat2_name=None), all_time_species=143): 10.316738280868048,
#   EBirdHotspot(location=EBirdLocation(id='L9545732', name='Mashapaug Park, Providence', coord=Coordinate(latitude=41.7960733, longitude=-71.4301347), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=140): 3.417661781465535,
#   EBirdHotspot(location=EBirdLocation(id='L613147', name='Colt State Park', coord=Coordinate(latitude=41.6806368, longitude=-71.3021922), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-001', subnat2_name=None), all_time_species=241): 18.389908357906826,
#   EBirdHotspot(location=EBirdLocation(id='L12606996', name='Waypoyset Preserve (Land Trust)', coord=Coordinate(latitude=41.697007, longitude=-71.2498423), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-001', subnat2_name=None), all_time_species=38): 19.561189570366025,
#   EBirdHotspot(location=EBirdLocation(id='L9955986', name='Council Oak Fields', coord=Coordinate(latitude=41.8190476, longitude=-71.1344576), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=106): 23.134560555461157,
#   EBirdHotspot(location=EBirdLocation(id='L10482078', name="Ralph's Pond, Cranston", coord=Coordinate(latitude=41.7744246, longitude=-71.4741292), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=96): 7.500507837435507,
#   EBirdHotspot(location=EBirdLocation(id='L7704374', name='Occupessatuxet Cove', coord=Coordinate(latitude=41.7358513, longitude=-71.3844495), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-003', subnat2_name=None), all_time_species=79): 10.06978277909826,
#   EBirdHotspot(location=EBirdLocation(id='L5070824', name="Allin's Cove (Barrington Land Trust)", coord=Coordinate(latitude=41.7442266, longitude=-71.3481226), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-001', subnat2_name=None), all_time_species=123): 10.36453049298552,
#   EBirdHotspot(location=EBirdLocation(id='L10189488', name='Venus De Milo Pond', coord=Coordinate(latitude=41.7429672, longitude=-71.1885811), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=54): 20.700753378785,
#   EBirdHotspot(location=EBirdLocation(id='L18266371', name='Pocasset River Wetland, Cranston', coord=Coordinate(latitude=41.7681453, longitude=-71.4457326), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=65): 6.778495529528997,
#   EBirdHotspot(location=EBirdLocation(id='L41628165', name='Blackstone River Bikeway--Manville Access to "River\'s Edge"', coord=Coordinate(latitude=41.9776132, longitude=-71.4833743), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=107): 18.039285768790165,
#   EBirdHotspot(location=EBirdLocation(id='L14185394', name='Lippitt Memorial Park', coord=Coordinate(latitude=41.8546509, longitude=-71.3915205), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=48): 3.8382482046740862,
#   EBirdHotspot(location=EBirdLocation(id='L54768291', name='Dunnell Park, Pawtucket', coord=Coordinate(latitude=41.864788, longitude=-71.3683087), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=31): 5.848910729341843,
#   EBirdHotspot(location=EBirdLocation(id='L14264549', name='Howard Conservation Area (PRAWC)', coord=Coordinate(latitude=41.7324417, longitude=-71.4596712), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=97): 10.888175339904777,
#   EBirdHotspot(location=EBirdLocation(id='L17197972', name='Public Street--Coastal Access Right of Way', coord=Coordinate(latitude=41.80863, longitude=-71.4019811), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=40): 1.9296120251530358,
#   EBirdHotspot(location=EBirdLocation(id='L5071219', name='Big River Management Area--Model Airplane Field', coord=Coordinate(latitude=41.654994, longitude=-71.56379), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-003', subnat2_name=None), all_time_species=50): 22.58333872099157,
#   EBirdHotspot(location=EBirdLocation(id='L2718493', name='Turnpike Lake', coord=Coordinate(latitude=42.0158388, longitude=-71.3119447), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-021', subnat2_name=None), all_time_species=93): 22.89368825318657,
#   EBirdHotspot(location=EBirdLocation(id='L4538187', name='Dighton Water Pump Station (private)', coord=Coordinate(latitude=41.8255552, longitude=-71.1267945), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=79): 23.764146493100128,
#   EBirdHotspot(location=EBirdLocation(id='L29523147', name='Washington Secondary Trail--Pawtuxet River Wetland Overlook', coord=Coordinate(latitude=41.696943, longitude=-71.580597), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-003', subnat2_name=None), all_time_species=13): 19.843219813143133,
#   EBirdHotspot(location=EBirdLocation(id='L1615937', name='Blackstone River Bikeway--Kelly House Museum to Albion Access', coord=Coordinate(latitude=41.9431583, longitude=-71.4372874), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=117): 13.390953762192602,
#   EBirdHotspot(location=EBirdLocation(id='L2913295', name='Steere Hill Conservation Area (Glocester Land Trust)', coord=Coordinate(latitude=41.8917675, longitude=-71.6142941), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=136): 18.344086743923363,
#   EBirdHotspot(location=EBirdLocation(id='L28111910', name='Woonasquatucket River Greenway--Riverside Park to Merino Park', coord=Coordinate(latitude=41.8207141, longitude=-71.450412), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=55): 3.1431050999379146,
#   EBirdHotspot(location=EBirdLocation(id='L13121233', name='Wetlands Robinson Ave. Dam', coord=Coordinate(latitude=41.9680397, longitude=-71.3120677), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=31): 18.05330862886338,
#   EBirdHotspot(location=EBirdLocation(id='L13935214', name='St. Francis Cemetery', coord=Coordinate(latitude=41.8638984, longitude=-71.4086965), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=36): 4.446037437090628,
#   EBirdHotspot(location=EBirdLocation(id='L2214089', name='Big River Management Area--Carr Pond', coord=Coordinate(latitude=41.6354153, longitude=-71.5560842), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-003', subnat2_name=None), all_time_species=89): 24.098177356905985,
#   EBirdHotspot(location=EBirdLocation(id='L23449783', name='Rockland Cemetery', coord=Coordinate(latitude=41.7839211, longitude=-71.6751051), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=92): 22.245594025381987,
#   EBirdHotspot(location=EBirdLocation(id='L2875659', name='Aust Family Preserve at Lime Rock (TNC)', coord=Coordinate(latitude=41.924037, longitude=-71.4682531), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=99): 12.027070818520945,
#   EBirdHotspot(location=EBirdLocation(id='L902021', name='Shad Factory Pond Dam, Rehoboth', coord=Coordinate(latitude=41.8088285, longitude=-71.2786102), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=109): 11.278881884311932,
#   EBirdHotspot(location=EBirdLocation(id='L4404827', name='Salter Grove Park', coord=Coordinate(latitude=41.7523129, longitude=-71.3824761), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-003', subnat2_name=None), all_time_species=149): 8.351404385855929,
#   EBirdHotspot(location=EBirdLocation(id='L40170227', name='World War I Memorial Park and Zoo', coord=Coordinate(latitude=41.9989253, longitude=-71.3135779), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=11): 21.103426440247983,
#   EBirdHotspot(location=EBirdLocation(id='L1365565', name='Latham Park, Barrington', coord=Coordinate(latitude=41.7457879, longitude=-71.3520883), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-001', subnat2_name=None), all_time_species=79): 10.046998035613171,
#   EBirdHotspot(location=EBirdLocation(id='L34675448', name='Bleachery Pond, Lincoln', coord=Coordinate(latitude=41.894042, longitude=-71.4096775), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=46): 7.78522779113578,
#   EBirdHotspot(location=EBirdLocation(id='L870123', name='Arcade Ave., Seekonk', coord=Coordinate(latitude=41.8409524, longitude=-71.3356447), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=51): 6.68305063591496,
#   EBirdHotspot(location=EBirdLocation(id='L26226874', name='Prudence Island--Nag Pond', coord=Coordinate(latitude=41.6281113, longitude=-71.3198418), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-005', subnat2_name=None), all_time_species=105): 23.09070480067289,
#   EBirdHotspot(location=EBirdLocation(id='L487742', name='Slater Park, Pawtucket', coord=Coordinate(latitude=41.868666, longitude=-71.3459444), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=133): 7.448781886950928,
#   EBirdHotspot(location=EBirdLocation(id='L3651661', name='Neutaconkanut Park', coord=Coordinate(latitude=41.8108757, longitude=-71.4654207), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=148): 4.605625154450489,
#   EBirdHotspot(location=EBirdLocation(id='L25323688', name='Catamint Brook Preserve (Cumberland Land Trust)', coord=Coordinate(latitude=41.994465, longitude=-71.43924), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=98): 19.06133922181394,
#   EBirdHotspot(location=EBirdLocation(id='L17262087', name='Bullock’s Point Light', coord=Coordinate(latitude=41.737771, longitude=-71.364168), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=6): 10.395753495500896,
#   EBirdHotspot(location=EBirdLocation(id='L8677678', name='Pawtucket Landing', coord=Coordinate(latitude=41.8720307, longitude=-71.384364), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=76): 5.836368871532342,
#   EBirdHotspot(location=EBirdLocation(id='L4826425', name='Pawtuxet Oxboes Park', coord=Coordinate(latitude=41.7695033, longitude=-71.3996208), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=155): 6.15054411706678,
#   EBirdHotspot(location=EBirdLocation(id='L734901', name='Davis Memorial Wildlife Refuge (ASRI)', coord=Coordinate(latitude=41.6236714, longitude=-71.4817259), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-009', subnat2_name=None), all_time_species=100): 22.97546100488327,
#   EBirdHotspot(location=EBirdLocation(id='L1139391', name='East Bay Bike Path--Watchemoket Cove to Pomham Rocks', coord=Coordinate(latitude=41.7959681, longitude=-71.3778949), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=179): 4.256259697986625,
#   EBirdHotspot(location=EBirdLocation(id='L1390947', name='Fuller Pond', coord=Coordinate(latitude=42.0126642, longitude=-71.3476719), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-021', subnat2_name=None), all_time_species=116): 21.642420377298624,
#   EBirdHotspot(location=EBirdLocation(id='L2776143', name='Georgiaville Pond', coord=Coordinate(latitude=41.8913554, longitude=-71.5088081), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=66): 10.931355148680307,
#   EBirdHotspot(location=EBirdLocation(id='L12266919', name='John L. Curran Management Area', coord=Coordinate(latitude=41.7507133, longitude=-71.5477124), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=90): 13.854397239045296,
#   EBirdHotspot(location=EBirdLocation(id='L1406045', name='Cold Spring Park, Woonsocket', coord=Coordinate(latitude=42.0091108, longitude=-71.5252876), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=62): 22.57911985015881,
#   EBirdHotspot(location=EBirdLocation(id='L4207196', name='Tiogue Lake--Outflow', coord=Coordinate(latitude=41.685423, longitude=-71.553619), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-003', subnat2_name=None), all_time_species=106): 19.33800017270501,
#   EBirdHotspot(location=EBirdLocation(id='L4333222', name='Handy Pond Conservation Area ', coord=Coordinate(latitude=41.9560605, longitude=-71.4742713), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=86): 15.530206541620208,
#   EBirdHotspot(location=EBirdLocation(id='L17976310', name='North Central State Airport', coord=Coordinate(latitude=41.9201774, longitude=-71.4892662), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=110): 12.425861992597932,
#   EBirdHotspot(location=EBirdLocation(id='L55029974', name='Kent Heights Park, East Providence', coord=Coordinate(latitude=41.805105, longitude=-71.356364), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=13): 5.139623984664311,
#   EBirdHotspot(location=EBirdLocation(id='L905070', name='Shad Factory Pond, Rehoboth', coord=Coordinate(latitude=41.8112436, longitude=-71.2841034), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=79): 10.78912929850008,
#   EBirdHotspot(location=EBirdLocation(id='L7358879', name='East Greenwich Nature and Cross Country Trail', coord=Coordinate(latitude=41.6334947, longitude=-71.4834452), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-003', subnat2_name=None), all_time_species=98): 21.95834463796245,
#   EBirdHotspot(location=EBirdLocation(id='L14173384', name='Snake Den State Park--Belfield Drive', coord=Coordinate(latitude=41.8362062, longitude=-71.5268898), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=82): 9.571356907747301,
#   EBirdHotspot(location=EBirdLocation(id='L4112916', name='Rocky Point State Park', coord=Coordinate(latitude=41.6898991, longitude=-71.3672733), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-003', subnat2_name=None), all_time_species=168): 15.367632956924242,
#   EBirdHotspot(location=EBirdLocation(id='L12696120', name='Suckatunkanuc Hill', coord=Coordinate(latitude=41.815945, longitude=-71.504841), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=49): 7.696309720097879,
#   EBirdHotspot(location=EBirdLocation(id='L831723', name='Poppasquash Road Causeway, Bristol', coord=Coordinate(latitude=41.6801281, longitude=-71.2816384), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-001', subnat2_name=None), all_time_species=131): 19.34881167015265,
#   EBirdHotspot(location=EBirdLocation(id='L7788167', name='Gaspee Point', coord=Coordinate(latitude=41.743699, longitude=-71.3766397), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-003', subnat2_name=None), all_time_species=93): 9.41167204139689,
#   EBirdHotspot(location=EBirdLocation(id='L14031201', name='Peeptoad Brook', coord=Coordinate(latitude=41.840378, longitude=-71.602796), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=40): 15.884399072502898,
#   EBirdHotspot(location=EBirdLocation(id='L17150946', name='Mallard Point', coord=Coordinate(latitude=41.7726055, longitude=-71.1205563), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=63): 24.95318003363936,
#   EBirdHotspot(location=EBirdLocation(id='L7441559', name='Juniper Hill Cemetery', coord=Coordinate(latitude=41.6811015, longitude=-71.2680531), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-001', subnat2_name=None), all_time_species=71): 19.921505595045655,
#   EBirdHotspot(location=EBirdLocation(id='L12295388', name='Lonsdale Marsh--Lonsdale Ave. access', coord=Coordinate(latitude=41.9020296, longitude=-71.404301), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=154): 8.69691467981971,
#   EBirdHotspot(location=EBirdLocation(id='L4578087', name='Dighton Transfer Station', coord=Coordinate(latitude=41.8546988, longitude=-71.1388779), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=82): 23.00871978263406,
#   EBirdHotspot(location=EBirdLocation(id='L12721457', name='Belmont Park, Warwick', coord=Coordinate(latitude=41.7620466, longitude=-71.4219022), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-003', subnat2_name=None), all_time_species=67): 6.921070444256009,
#   EBirdHotspot(location=EBirdLocation(id='L1135167', name='Dodgeville Pond', coord=Coordinate(latitude=41.9232654, longitude=-71.2951155), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=65): 14.73387835057402,
#   EBirdHotspot(location=EBirdLocation(id='L6182809', name='Gorton Pond and Little Gorton Pond', coord=Coordinate(latitude=41.7023002, longitude=-71.4622879), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-003', subnat2_name=None), all_time_species=115): 14.127618258797966,
#   EBirdHotspot(location=EBirdLocation(id='L16494250', name='Diamond Hill Reservoir, Cumberland', coord=Coordinate(latitude=41.997013, longitude=-71.399154), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=116): 19.25151946778512,
#   EBirdHotspot(location=EBirdLocation(id='L815443', name='Tiogue Lake', coord=Coordinate(latitude=41.6790406, longitude=-71.5503244), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-003', subnat2_name=None), all_time_species=120): 19.747198553342624,
#   EBirdHotspot(location=EBirdLocation(id='L3260829', name='Tricentennial Park', coord=Coordinate(latitude=41.8103868, longitude=-71.1191475), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=112): 24.448408058995412,
#   EBirdHotspot(location=EBirdLocation(id='L1282270', name='Attleboro Springs Wildlife Sanctuary (Mass Audubon)', coord=Coordinate(latitude=41.9286191, longitude=-71.2647432), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=102): 16.916799952588295,
#   EBirdHotspot(location=EBirdLocation(id='L10975778', name='Massasoit Street Park', coord=Coordinate(latitude=41.7099274, longitude=-71.1795339), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=93): 23.16969875884116,
#   EBirdHotspot(location=EBirdLocation(id='L15139458', name='Mercy Woods Preserve, Cumberland', coord=Coordinate(latitude=42.0149, longitude=-71.408989), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=89): 21.20720112693673,
#   EBirdHotspot(location=EBirdLocation(id='L687632', name='Conimicut Point Park, Warwick', coord=Coordinate(latitude=41.7167491, longitude=-71.360321), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-003', subnat2_name=None), all_time_species=146): 12.686119280348258,
#   EBirdHotspot(location=EBirdLocation(id='L3300181', name='Whiting Pond, North Attleborough', coord=Coordinate(latitude=41.9941027, longitude=-71.3352263), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=40): 19.96180236880954,
# ...
#   EBirdHotspot(location=EBirdLocation(id='L2599631', name='Ten Mile River Greenway--Ferris Ave. Trailhead to Slater Park', coord=Coordinate(latitude=41.8496377, longitude=-71.3443893), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=116): 6.359005815663841,
#   EBirdHotspot(location=EBirdLocation(id='L17425289', name='Salter Grove North Jetty (Providence Co.)', coord=Coordinate(latitude=41.7586838, longitude=-71.3844226), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=42): 7.628179969714833,
#   EBirdHotspot(location=EBirdLocation(id='L31745262', name='Walnut Hill Cemetery', coord=Coordinate(latitude=41.8811125, longitude=-71.3687754), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=44): 7.324053639023064,
#   EBirdHotspot(location=EBirdLocation(id='L10135757', name='Ripley St Marsh', coord=Coordinate(latitude=41.7122204, longitude=-71.1844573), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=82): 22.687391613276155,
#   EBirdHotspot(location=EBirdLocation(id='L42686760', name='Scott Pond, Lincoln', coord=Coordinate(latitude=41.8980902, longitude=-71.4068879), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=16): 8.245248531839184,
#   EBirdHotspot(location=EBirdLocation(id='L4789272', name='Stillhouse Cove Park, Cranston', coord=Coordinate(latitude=41.7696052, longitude=-71.3896), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=75): 6.341557437570765,
#   EBirdHotspot(location=EBirdLocation(id='L5099232', name='Big River Management Area--Tarbox Pond', coord=Coordinate(latitude=41.6365854, longitude=-71.5734869), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-003', subnat2_name=None), all_time_species=105): 24.736654031596174,
#   EBirdHotspot(location=EBirdLocation(id='L10825088', name='Quonset Bike Path--Quonset Gateway', coord=Coordinate(latitude=41.6070005, longitude=-71.4544986), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-009', subnat2_name=None), all_time_species=77): 24.348571117409566,
#   EBirdHotspot(location=EBirdLocation(id='L9189645', name='Allen Harbor Marina', coord=Coordinate(latitude=41.6197094, longitude=-71.4112937), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-009', subnat2_name=None), all_time_species=121): 22.68927650730731,
#   EBirdHotspot(location=EBirdLocation(id='L731326', name='Ponaganset Rd., Foster', coord=Coordinate(latitude=41.7957044, longitude=-71.6809557), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=138): 22.500460860049408,
#   EBirdHotspot(location=EBirdLocation(id='L187164', name='Watchemoket Cove', coord=Coordinate(latitude=41.800495, longitude=-71.376686), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=137): 3.978896559417677,
#   EBirdHotspot(location=EBirdLocation(id='L10059274', name='Diamond Hill Park, Cumberland', coord=Coordinate(latitude=42.0019027, longitude=-71.4131983), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=94): 19.76117014318404,
#   EBirdHotspot(location=EBirdLocation(id='L1390952', name='Wetherells Pond', coord=Coordinate(latitude=42.0003917, longitude=-71.3375304), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-021', subnat2_name=None), all_time_species=115): 20.565258244098832,
#   EBirdHotspot(location=EBirdLocation(id='L12545551', name='WWII Memorial State Park', coord=Coordinate(latitude=42.0096446, longitude=-71.5093249), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=22): 22.120211570643246,
#   EBirdHotspot(location=EBirdLocation(id='L453500', name='Walker Farm', coord=Coordinate(latitude=41.7555945, longitude=-71.3227701), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-001', subnat2_name=None), all_time_species=167): 10.665524521823286,
#   EBirdHotspot(location=EBirdLocation(id='L4588597', name='Great Woods Conservation Area', coord=Coordinate(latitude=41.9981564, longitude=-71.2298584), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=94): 24.590358616404977,
#   EBirdHotspot(location=EBirdLocation(id='L7425313', name='Meshanticut State Park', coord=Coordinate(latitude=41.7682996, longitude=-71.4752215), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=86): 8.07132917029478,
#   EBirdHotspot(location=EBirdLocation(id='L213318', name='Touisset Marsh Wildlife Refuge (ASRI)', coord=Coordinate(latitude=41.7059838, longitude=-71.2374794), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-001', subnat2_name=None), all_time_species=160): 19.606348120581114,
#   EBirdHotspot(location=EBirdLocation(id='L900794', name='Town Pond (ALT)', coord=Coordinate(latitude=41.6323646, longitude=-71.245544), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-005', subnat2_name=None), all_time_species=152): 25.43064663579886,
#   EBirdHotspot(location=EBirdLocation(id='L1499732', name='Oak Top (private)', coord=Coordinate(latitude=41.8547833, longitude=-71.1776575), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=224): 19.8306789310329,
#   EBirdHotspot(location=EBirdLocation(id='L15208246', name='Tower Hill Rd., Cumberland', coord=Coordinate(latitude=41.994098, longitude=-71.444035), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=60): 19.070764780249405,
#   EBirdHotspot(location=EBirdLocation(id='L2597004', name='Pawtucket Boat Launch', coord=Coordinate(latitude=41.8683704, longitude=-71.379472), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=81): 5.6547689650588175,
#   EBirdHotspot(location=EBirdLocation(id='L39583673', name='Haines Memorial State Park  (Providence County)', coord=Coordinate(latitude=41.7540286, longitude=-71.3514138), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=45): 9.29764560749315,
#   EBirdHotspot(location=EBirdLocation(id='L11444077', name='Butler Campus', coord=Coordinate(latitude=41.8443214, longitude=-71.3815825), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=86): 3.4407713649043177,
#   EBirdHotspot(location=EBirdLocation(id='L2802133', name='Hunt’s Mills Museum and Trail', coord=Coordinate(latitude=41.8283457, longitude=-71.3469315), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=128): 5.496274168232779,
#   EBirdHotspot(location=EBirdLocation(id='L10658440', name='Blackamore Pond, Cranston', coord=Coordinate(latitude=41.7738778, longitude=-71.4468487), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=54): 6.242615657757797,
#   EBirdHotspot(location=EBirdLocation(id='L1618211', name='Witch Pond, Foxboro', coord=Coordinate(latitude=42.0177869, longitude=-71.2867241), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-021', subnat2_name=None), all_time_species=75): 23.932884923139294,
#   EBirdHotspot(location=EBirdLocation(id='L11516357', name='Blackstone River Bikeway--Kelly House Museum to Lonsdale Drive-In', coord=Coordinate(latitude=41.9247737, longitude=-71.4298601), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=113): 11.283103188609918,
#   EBirdHotspot(location=EBirdLocation(id='L2683958', name='Brickyard Pond & Veterans Memorial Park', coord=Coordinate(latitude=41.7352359, longitude=-71.3144231), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-001', subnat2_name=None), all_time_species=164): 12.810620072633597,
#   EBirdHotspot(location=EBirdLocation(id='L13813738', name='Mountaindale Road Marsh & Reservoir, Smithfield', coord=Coordinate(latitude=41.8862882, longitude=-71.5367615), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=77): 12.40078769156201,
#   EBirdHotspot(location=EBirdLocation(id='L30901951', name='Mason Field', coord=Coordinate(latitude=41.973644, longitude=-71.315139), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=42): 18.493929621476962,
#   EBirdHotspot(location=EBirdLocation(id='L29020679', name='Wading River Reservoir', coord=Coordinate(latitude=41.989602, longitude=-71.254242), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=63): 22.616825571665036,
#   EBirdHotspot(location=EBirdLocation(id='L207451', name='Oak Knoll Wildlife Sanctuary (Mass Audubon)', coord=Coordinate(latitude=41.91704, longitude=-71.26122), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=109): 16.28632260638749,
#   EBirdHotspot(location=EBirdLocation(id='L1306965', name='Warren Upper Reservoir ', coord=Coordinate(latitude=41.8251622, longitude=-71.2174559), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=117): 16.232151825637906,
#   EBirdHotspot(location=EBirdLocation(id='L38422558', name='Roger Williams National Memorial', coord=Coordinate(latitude=41.830073, longitude=-71.410568), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=28): 0.7014761180847083,
#   EBirdHotspot(location=EBirdLocation(id='L14975740', name='Merrill S. Whipple Conservation Park', coord=Coordinate(latitude=41.6885734, longitude=-71.5566654), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-003', subnat2_name=None), all_time_species=89): 19.217198184725852,
#   EBirdHotspot(location=EBirdLocation(id='L8882178', name='St Andrews School Forest Property', coord=Coordinate(latitude=41.7500582, longitude=-71.3292369), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-001', subnat2_name=None), all_time_species=43): 10.757254118086182,
#   EBirdHotspot(location=EBirdLocation(id='L841256', name='Broad Cove', coord=Coordinate(latitude=41.7892329, longitude=-71.1252308), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=222): 24.2099229067357,
#   EBirdHotspot(location=EBirdLocation(id='L741738', name='Swansea Country Club Pond', coord=Coordinate(latitude=41.7625573, longitude=-71.2797475), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=43): 12.997027821043213,
#   EBirdHotspot(location=EBirdLocation(id='L15294747', name='George B. Parker Woodland—Gowdey Memorial Trail (Prov. Co.)', coord=Coordinate(latitude=41.729585, longitude=-71.684546), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=51): 24.90484205935799,
#   EBirdHotspot(location=EBirdLocation(id='L17120086', name='Kickemuit River--Schoolhouse & Serpentine Road', coord=Coordinate(latitude=41.7397652, longitude=-71.2602269), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-001', subnat2_name=None), all_time_species=156): 15.762699879137728,
#   EBirdHotspot(location=EBirdLocation(id='L1320533', name='Echo Lake, Barrington', coord=Coordinate(latitude=41.7357344, longitude=-71.3339496), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-001', subnat2_name=None), all_time_species=137): 11.793871650399673,
#   EBirdHotspot(location=EBirdLocation(id='L5277851', name='Perry-Tavares Farm Conservation Area, Bristol', coord=Coordinate(latitude=41.7086576, longitude=-71.2728272), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-001', subnat2_name=None), all_time_species=39): 17.309705183774216,
#   EBirdHotspot(location=EBirdLocation(id='L2430264', name='Mount Hope Farm', coord=Coordinate(latitude=41.6681638, longitude=-71.2549775), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-001', subnat2_name=None), all_time_species=182): 21.724383042565375,
#   EBirdHotspot(location=EBirdLocation(id='L42665518', name='Town Line Swamp', coord=Coordinate(latitude=41.933718, longitude=-71.486849), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=25): 13.648661142641096,
#   EBirdHotspot(location=EBirdLocation(id='L13429477', name='Pleasant Valley Parkway, Providence', coord=Coordinate(latitude=41.8348354, longitude=-71.4422477), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=44): 2.724261524447667,
#   EBirdHotspot(location=EBirdLocation(id='L1458029', name='The Monastery, Cumberland', coord=Coordinate(latitude=41.9350531, longitude=-71.4075396), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=181): 12.343809924902796,
#   EBirdHotspot(location=EBirdLocation(id='L17165257', name='Boyden Park', coord=Coordinate(latitude=41.872801, longitude=-71.125909), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=108): 24.437298054104048,
#   EBirdHotspot(location=EBirdLocation(id='L4377381', name='Pocasset Cemetery', coord=Coordinate(latitude=41.8028945, longitude=-71.4596379), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=137): 4.5402622679339455,
#   EBirdHotspot(location=EBirdLocation(id='L15883704', name='Fall River Heritage SP', coord=Coordinate(latitude=41.7048283, longitude=-71.1601388), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-005', subnat2_name=None), all_time_species=44): 24.833728290754383,
#   EBirdHotspot(location=EBirdLocation(id='L10470601', name='Moshassuck Pond', coord=Coordinate(latitude=41.8817272, longitude=-71.4033755), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=79): 6.460919118223743,
#   EBirdHotspot(location=EBirdLocation(id='L2071074', name='Birchwold Farm', coord=Coordinate(latitude=42.0231797, longitude=-71.4054143), country_code='US', subnat1_code='US-MA', subnat1_name=None, subnat2_code='US-MA-021', subnat2_name=None), all_time_species=118): 22.133018046136115,
#   EBirdHotspot(location=EBirdLocation(id='L13992195', name='Little Pond, Cumberland', coord=Coordinate(latitude=41.9624751, longitude=-71.4213747), country_code='US', subnat1_code='US-RI', subnat1_name=None, subnat2_code='US-RI-007', subnat2_name=None), all_time_species=54): 15.398128087166924}}

# %%
# Compute distance-based weightings per hotspot-location pair using log-sum-exp
import numpy as np
from scipy.special import logsumexp

loc_species_log_lists: dict[str, dict[str, list[float]]] = defaultdict(lambda: defaultdict(list))
"""Map from location names to a map from eBird species IDs to lists of log-weights."""

# Accumulate log-weights (avoid numerical issues by staying in log-space)
# Intended weighting: e^{-km / 20}
for loc, hs_km_mapping in hotspot_distances_km.items():
    for hotspot, dist_km in hs_km_mapping.items():
        log_weight = -dist_km / 20.0  # log of exp(-dist_km / 20)
        for species_id in all_species_lists[hotspot.location.id]:
            loc_species_log_lists[loc][species_id].append(log_weight)

# Convert to unnormalized log-weights using numerically stable log-sum-exp
location_species_log_weights: dict[str, dict[str, float]] = {}
for loc, species_dict in loc_species_log_lists.items():
    location_species_log_weights[loc] = {
        species_id: float(logsumexp(log_weights))  # log(sum of exp(log_weights))
        for species_id, log_weights in species_dict.items()
    }

# Normalize to get probabilities:
#       P(species_i | location) = exp(log_weight_i) / sum_j exp(log_weight_j)
# Do this in log-space for numerical stability:
#       log P(species_i) = log_weight_i - logsumexp(all_log_weights for the location)
location_species_probabilities: dict[str, dict[str, float]] = {}
for loc, species_log_weights in location_species_log_weights.items():
    log_weights_array = np.array(list(species_log_weights.values()))
    log_normalizer = float(logsumexp(log_weights_array))  # log(sum of unnormalized weights)

    location_species_probabilities[loc] = {
        species_id: float(np.exp(log_weight - log_normalizer))  # Convert to normalized probability
        for species_id, log_weight in species_log_weights.items()
    }

# Verify normalization (should sum to ~1.0)
for loc, probs in location_species_probabilities.items():
    total_prob = sum(probs.values())
    print(f"{loc}: {len(probs)} species, total probability = {total_prob:.6f}")
# Out:
# Providence, Rhode Island, United States: 354 species, total probability = 1.000000

# %%
sorted_probabilities = {
    loc: dict(sorted(probs.items(), key=lambda id_prob: -id_prob[1]))
    for loc, probs in location_species_probabilities.items()
}

sorted_probabilities
# Out:
# {'Providence, Rhode Island, United States': {'blujay': 0.011199778850727912,
#   'amerob': 0.011089723926958343,
#   'sonspa': 0.011040696534817058,
#   'norcar': 0.010942771366663608,
#   'amegfi': 0.010826700864686517,
#   'moudov': 0.010822196414735925,
#   'bkcchi': 0.010698583591829547,
#   'carwre': 0.010693119999528608,
#   'amecro': 0.010643939363553845,
#   'dowwoo': 0.010544182277998701,
#   'houspa': 0.010462133604078279,
#   'comgra': 0.010386441818823536,
#   'tuftit': 0.010354045242755934,
#   'cangoo': 0.010350446938337261,
#   'eursta': 0.01021835535481509,
#   'norfli': 0.010169681819430057,
#   'rewbla': 0.010105421490942991,
#   'houfin': 0.010089747341899878,
#   'grycat': 0.009975007771320992,
#   'mallar3': 0.009814923638324523,
#   'rebwoo': 0.009802861678323857,
#   'whbnut': 0.009707051732368542,
#   'daejun': 0.009656500999111715,
#   'rethaw': 0.009645064575295096,
#   'whtspa': 0.009426399519243673,
#   'normoc': 0.00942426337520259,
#   'chiswi': 0.00935838363652682,
#   'grbher3': 0.0091558844818198,
#   'chispa': 0.008701635795095692,
#   'bnhcow': 0.008471868962535815,
#   'amhgul1': 0.00845030725099002,
#   'ribgul': 0.00843891366567642,
#   'yelwar1': 0.008345439109200785,
#   'doccor': 0.008316883813914844,
#   'fiscro': 0.008210218916799038,
#   'balori': 0.008110067842752653,
#   'osprey': 0.008058103951182475,
#   'rocpig': 0.008020012307414483,
#   'cedwax': 0.008001918642826657,
#   'coohaw': 0.007949064360787548,
#   'easpho': 0.007907035087286287,
#   'turvul': 0.007867631636001161,
#   'mutswa': 0.0077382820611092565,
#   'belkin1': 0.007736452824257226,
#   'barswa': 0.007595930321235705,
#   'treswa': 0.0075353181380411905,
#   'yerwar': 0.0074943545326038195,
#   'haiwoo': 0.007447276976631608,
#   'hoomer': 0.007438389871321642,
#   'houwre': 0.007307396945242339,
#   'eawvir1': 0.007274212602461164,
#   'ambduc': 0.007128212452404781,
#   'gockin': 0.007085262768066895,
#   'comyel': 0.00700459658495351,
#   'baleag': 0.006861220593232944,
#   'comrav': 0.006833769256880939,
#   'easkin': 0.00681271381898658,
#   'nrwswa': 0.006570296298787508,
#   'grcfly': 0.006478026305100475,
#   'eastow': 0.006236678503376148,
#   'killde': 0.006236048163733745,
#   'reshaw': 0.006036350400938575,
#   'gbbgul': 0.006005924003031979,
#   'wooduc': 0.005984881389252333,
#   'reevir1': 0.005947025089440607,
#   'rthhum': 0.005929663133583525,
#   'ruckin': 0.005925122052342948,
#   'greegr': 0.005873819939118118,
#   'buffle': 0.005867418785515099,
#   'swaspa': 0.005866253242891136,
#   'wiltur': 0.005858414443006052,
#   'commer': 0.0056298264777154125,
#   'eawpew': 0.00555367648261284,
#   'sposan': 0.005494224040543121,
#   'brncre': 0.0054437309586879545,
#   'savspa': 0.005388869184353619,
#   'amered': 0.005171746932449754,
#   'buggna': 0.005155597697499614,
#   'grnher': 0.005116540767672551,
#   'rebmer': 0.005098613344484875,
#   'pinwar': 0.004916779937834,
#   'easblu': 0.004899919626688599,
#   'bawwar': 0.004850828723403364,
#   'comloo': 0.004830378436595935,
#   'herthr': 0.004817410441546539,
#   'shshaw': 0.004768587395666012,
#   'bkpwar': 0.004732950234678155,
#   'perfal': 0.004696124610645129,
#   'gadwal': 0.004621581893984038,
#   'fiespa': 0.0045811877583172384,
#   'palwar': 0.0045753978928290105,
#   'amtspa': 0.004557110684903893,
#   'amewig': 0.004529958956130648,
#   'rinduc': 0.004440853564095584,
#   'yebsap': 0.004436365102123652,
#   'robgro': 0.004430143255721738,
#   'comgol': 0.004391248869634968,
#   'norpar': 0.0043686372029296495,
#   'ovenbi1': 0.004275899060885708,
#   'merlin': 0.004186934315011339,
#   'winwre3': 0.004074990446689095,
#   'rebnut': 0.0040287606153801185,
#   'laugul': 0.003931672655068421,
#   'orcori': 0.003912807474560673,
#   'scatan': 0.0037843683198138175,
#   'bcnher': 0.0035994239532048055,
#   'greyel': 0.0035751484111686245,
#   'woothr': 0.0035664967867570603,
#   'purfin': 0.003485607498675446,
#   'gnwtea': 0.003447564068541957,
#   'brant': 0.003426350308972989,
#   'gresca': 0.0034215340324452565,
#   'leasan': 0.003362713956517268,
#   'pibgre': 0.0032253104814988476,
#   'norhar2': 0.003147858084404976,
#   'buhvir': 0.003144009904778165,
#   'grhowl': 0.00313709044662167,
#   'buwwar': 0.0031250862878591237,
#   'amekes': 0.0030745521454979717,
#   'pilwoo': 0.0030323275680894106,
#   'snoegr': 0.003027658923001549,
#   'blkvul': 0.0030232326686236524,
#   'prawar': 0.0030225881342154344,
#   'grecor': 0.0030165957690796745,
#   'indbun': 0.0029407254233819323,
#   'veery': 0.0029262831650729206,
#   'purmar': 0.002874756423920685,
#   'brdowl': 0.0028704828188390635,
#   'retloo': 0.0028698744178918107,
#   'solsan': 0.0028501646679246883,
#   'comter': 0.002828244617200579,
#   'brwhaw': 0.002824503127318238,
#   'btnwar': 0.0027877462387096374,
#   'pinsis': 0.0027645101930660657,
#   'norpin': 0.002755458183957654,
#   'foxspa': 0.002690738780383866,
#   'norwat': 0.0026874900031615277,
#   'banswa': 0.00266940999622545,
#   'yebcuc': 0.002664745333607097,
#   'wilfly': 0.0026218479067203894,
#   'naswar': 0.002611112352766966,
#   'x00004': 0.0025980469173677787,
#   'y00475': 0.0025474782794756155,
#   'yetvir': 0.0025301391940821443,
#   'semplo': 0.0025197156051379867,
#   'lessca': 0.0024958440960479995,
#   'magwar': 0.002487695370822081,
#   'easowl1': 0.002483031137511081,
#   'whcspa': 0.0024508599040911857,
#   'rudduc': 0.0024449354681874832,
#   'semsan': 0.0023526826691721596,
#   'amewoo': 0.0023442509408864638,
#   'brnthr': 0.0023402776132103492,
#   'comnig': 0.002290674936899183,
#   'linspa': 0.0022562219192212934,
#   'marwre': 0.0022426942935870275,
#   'btbwar': 0.002111580622513386,
#   'horgre': 0.002077767195874625,
#   'amepip': 0.0020262082601009684,
#   'chswar': 0.0019944909611500027,
#   'rusbla': 0.0019600379812180764,
#   'lesyel': 0.001933145050523589,
#   'gloibi': 0.0019123268751230563,
#   'boboli': 0.0018389687512962458,
#   'norsho': 0.0017816950824937167,
#   'ameoys': 0.001738501243238052,
#   'bkbcuc': 0.0016698922887972037,
#   'orcwar': 0.0016308129128041538,
#   'redpol1': 0.0016140850766239044,
#   'babwar': 0.001554951319500924,
#   'bongul': 0.0015547950098733058,
#   'swathr': 0.0015384531512515685,
#   'eurwig': 0.0015305040867119233,
#   'horlar': 0.0014848610370969274,
#   'wlswar': 0.0014366289823865013,
#   'leafly': 0.0014171444654216758,
#   'wilsni1': 0.0013640365442213506,
#   'tenwar': 0.0013341956798235688,
#   'whevir': 0.0013324855869788874,
#   'y00478': 0.0013260435813820628,
#   'willet1': 0.0013170052659181978,
#   'bkbwar': 0.0013161723991393665,
#   'snobun': 0.0012802601296845416,
#   'camwar': 0.0012774653594505114,
#   'forter': 0.0012755332502472497,
#   'buwtea': 0.0012136719724077246,
#   'rengre': 0.001195408149857012,
#   'canvas': 0.001192427931717347,
#   'virrai': 0.001160015305615079,
#   'libher': 0.0011333065799424306,
#   'canwar': 0.001116877643144799,
#   'bargol': 0.0011149440243100714,
#   'easmea': 0.0011130137010659103,
#   'sursco': 0.0011053195101728515,
#   'lbbgul': 0.0010582596776091283,
#   'louwat': 0.0010554553130688801,
#   'comeid': 0.001047326527808005,
#   'bkbplo': 0.00102269072186676,
#   'shbdow': 0.000992308125392658,
#   'caster1': 0.0009649298324731279,
#   'sstspa': 0.00096333348116489,
#   'lotduc': 0.0009460019425919047,
#   'woewar1': 0.0008913167470306855,
#   'pecsan': 0.0008588437089857023,
#   'blksco2': 0.0008565274998316507,
#   'sander': 0.000847798257598228,
#   'dickci': 0.0008238035762303521,
#   'rehwoo': 0.0008055292701428873,
#   'snogoo': 0.00077629898018911,
#   'tufduc': 0.0007735402533283549,
#   'ycnher': 0.0007380171985250001,
#   'whwsco2': 0.0007327536014598833,
#   'musduc': 0.0007190605213153964,
#   'redhea': 0.0006966721369501758,
#   'leater1': 0.0006582917902489095,
#   'clcspa': 0.0006560877187831332,
#   'redcro': 0.0006478548915702907,
#   'dunlin': 0.000601889859949918,
#   'hoowar': 0.000583082641390243,
#   'blugrb1': 0.0005727425891805012,
#   'phivir': 0.0005585716595624149,
#   'acafly': 0.0005425610599415586,
#   'rudtur': 0.0005350578653761756,
#   'evegro': 0.0005184580439288965,
#   'rinphe1': 0.0005056079422906775,
#   'amebit': 0.0004710422313140666,
#   'nstspa': 0.00046300313790881205,
#   'conwar': 0.0004581283864268719,
#   'cacgoo1': 0.00045792893268956336,
#   'yebcha': 0.0004489422165966425,
#   'gragoo': 0.0004213914448461116,
#   'cliswa': 0.0004204413273595746,
#   'mouwar': 0.0004052772432794723,
#   'monpar': 0.00037324838432925827,
#   'whrsan': 0.00036766973756358306,
#   'vesspa': 0.0003603655615884207,
#   'clarai11': 0.00035835529756013943,
#   'roster': 0.0003415746429080277,
#   'gwfgoo': 0.0003382116780637115,
#   'snoowl1': 0.00032802155471762314,
#   'glagul': 0.00030393320208329437,
#   'sora': 0.00028073548968751574,
#   'seaspa': 0.00027115356370495934,
#   'tunswa': 0.0002637716224234662,
#   'nswowl': 0.0002636963138576423,
#   'pursan': 0.00024630055848163824,
#   'yebfly': 0.00024604405051066624,
#   'amgplo': 0.00024102633040415866,
#   'larspa': 0.00023665417991219272,
#   'cxbgol1': 0.00023431913545518817,
#   'blkter': 0.00022830558836252525,
#   'kenwar': 0.00020761638931228107,
#   'easwpw1': 0.00020646300438217251,
#   'aldfly': 0.00020299321465042176,
#   'sumtan': 0.0002028030119798563,
#   'amwpel': 0.0001959697156306183,
#   'x00759': 0.00019568551828174014,
#   'arcter': 0.00018987007940959475,
#   'bubsan': 0.00018917700194614863,
#   'yetwar': 0.00018613342511093184,
#   'cerwar': 0.00018080776870334233,
#   'sheowl': 0.00017405830054954922,
#   'x00730': 0.00017265116592178354,
#   'comgal1': 0.00017073282834322926,
#   'olsfly': 0.00016975334611755614,
#   'graspa': 0.00016863397578180018,
#   'whimbr3': 0.0001663929588331626,
#   'blkski': 0.0001658978016574783,
#   'rolhaw': 0.00016379978631876656,
#   'bkhgul': 0.00016252051769372405,
#   'laplon': 0.00016040165328392117,
#   'miskit': 0.00015869315574301528,
#   'sancra': 0.0001576357866981363,
#   'gycthr': 0.0001556839137458756,
#   'pifgoo': 0.00015307980916907842,
#   'rufgro': 0.00015261225837050188,
#   'norshr4': 0.00015015324057834954,
#   'swtkit': 0.00014476801244248458,
#   'rosgoo': 0.00014219460600294406,
#   'uplsan': 0.0001410158163380532,
#   'whwcro': 0.00013837707852039087,
#   'mewgul': 0.00013557689700780605,
#   'tdxsca1': 0.0001329205137594991,
#   'leabit': 0.00012789144353248785,
#   'weskin': 0.00012295784134262424,
#   'baisan': 0.0001162196320562699,
#   'brewar': 0.00011407645410264738,
#   'macwar': 0.00011212758208674485,
#   'x00724': 0.00011206354857388974,
#   'truswa': 0.00010806898876824996,
#   'prowar': 0.00010708648571985371,
#   'x00628': 9.929499621167133e-05,
#   'wessan': 9.752618595991808e-05,
#   'triher': 9.145655925095051e-05,
#   'gowwar': 9.079222882174398e-05,
#   'norbob': 8.748352261683878e-05,
#   'lawwar': 8.723296848929597e-05,
#   'x00776': 8.359284967644454e-05,
#   'norgan': 8.331430115067252e-05,
#   'stisan': 8.025288112445746e-05,
#   'varthr': 7.859129606867848e-05,
#   'brebla': 7.720352184013667e-05,
#   'comcuc': 7.667541620243963e-05,
#   'saypho': 7.667541620243963e-05,
#   'x00421': 7.378746777948999e-05,
#   'margod': 7.338053132179466e-05,
#   'norgos': 6.856406321842197e-05,
#   'categr1': 6.582195903926336e-05,
#   'pipplo': 6.416486580153563e-05,
#   'hudgod': 6.19460456510065e-05,
#   'btywar': 6.113346903888591e-05,
#   'sedwre1': 6.102262147173168e-05,
#   'lobdow': 6.055122762282515e-05,
#   'ruff': 6.055122762282515e-05,
#   'bknsti': 6.042920470395139e-05,
#   'sooter1': 5.6678279121771007e-05,
#   'towsol': 5.499228004338572e-05,
#   'anhing': 5.2797783421879204e-05,
#   'towwar': 5.2797783421879204e-05,
#   'whiibi': 5.1052837882439285e-05,
#   'x00613': 4.958116949043162e-05,
#   'goleag': 4.891355974935526e-05,
#   'harduc': 4.601096745882339e-05,
#   'eargre': 4.5240619755331806e-05,
#   'afcdov1': 4.4076245630130015e-05,
#   'cintea': 4.258518821300665e-05,
#   'whfibi': 4.161639051643633e-05,
#   'x01131': 4.1178865057834716e-05,
#   'hamfly': 3.859319656660898e-05,
#   'virwar': 3.859319656660898e-05,
#   'x00686': 3.8229791634021454e-05,
#   'stseag': 3.806030794478541e-05,
#   'astfly': 3.7419691361103636e-05,
#   'fragul': 3.4884627809301006e-05,
#   'brnboo': 3.4884627809301006e-05,
#   'corshe1': 3.390412815864334e-05,
#   'bbwduc': 3.159220062419469e-05,
#   'x00611': 3.159220062419469e-05,
#   'kineid': 3.050743988216654e-05,
#   'westan': 2.9642729327869086e-05,
#   'yelrai': 2.928023799223463e-05,
#   'razorb': 2.62287677567146e-05,
#   'bklkit': 2.62287677567146e-05,
#   'royter1': 2.62287677567146e-05,
#   'norwhe': 2.62287677567146e-05,
#   'litgul': 2.51766967782747e-05,
#   'swagoo1': 2.2351417845581266e-05,
#   'renpha': 2.1225941446240265e-05,
#   'yebtea1': 2.058574756708486e-05,
#   'cavswa': 2.058574756708486e-05,
#   'moublu': 1.9782199702108794e-05,
#   'mewgul2': 1.9606400850725817e-05,
#   'larbun': 1.9533542114516696e-05,
#   'x00758': 1.9037479691416625e-05}}

# %%
import time
from pathlib import Path

import yaml

time_min = int(time.time())
output_path = Path.cwd().parent / f"data/probabilities-{time_min}.yaml"
if not output_path.exists():
    output_path.parent.mkdir(parents=True, exist_ok=True)
    output_path.touch()

with output_path.open("w") as outfile:
    yaml.dump(sorted_probabilities, outfile, sort_keys=False)

print(f"Data written to {output_path}")
# Out:
# Data written to /Users/benned/git/birding/data/probabilities-1767313880.yaml
