# %% [markdown]
# Goal: Import a lifelist downloaded from eBird.

# %%
from pathlib import Path

LIFELIST_CSV = Path.cwd().parent / "data/MyEBirdData.csv"
LIFELIST_CSV
# Out:
# PosixPath('/home/benned/git/birding/data/MyEBirdData.csv')

# %%
import pandas as pd

df = pd.read_csv(LIFELIST_CSV)
df
# Out:
#     Submission ID        Common Name        Scientific Name  Taxonomic Order  \
# 0      S177102299       Canada Goose      Branta canadensis              342
# 1      S181305115     Trumpeter Swan      Cygnus buccinator              382
# 2      S268681888          Wood Duck             Aix sponsa              455
# 3      S181141480    American Wigeon       Mareca americana              517
# 4      S192508218            Mallard     Anas platyrhynchos              545
# ..            ...                ...                    ...              ...
# 131    S188975327  Northern Cardinal  Cardinalis cardinalis            34515
# 132    S169550435  Northern Cardinal  Cardinalis cardinalis            34515
# 133    S171041840  Northern Cardinal  Cardinalis cardinalis            34515
# 134    S172219348  Northern Cardinal  Cardinalis cardinalis            34515
# 135    S195457863  Northern Cardinal  Cardinalis cardinalis            34515
#
# ...
